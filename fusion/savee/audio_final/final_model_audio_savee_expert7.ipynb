# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Orignial Notebook: https://github.com/MITESHPUTHRANNEU/Speech-Emotion-Analyzer/blob/master/final_results_gender_test.ipynb
# This notebook author: Reza Chu
# Last Editing Date: 31st May 2019

## Python
import os
import random
import sys

import IPython
from IPython.display import Audio
from IPython.display import Image
import matplotlib.pyplot as plt

## Package
import glob 
import keras
import IPython.display as ipd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.graph_objs as go
import plotly.offline as py
import plotly.tools as tls
import seaborn as sns
import scipy.io.wavfile
import tensorflow as tf
py.init_notebook_mode(connected=True)

## Keras
from keras import regularizers
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from keras.callbacks import  History, ReduceLROnPlateau, CSVLogger
from keras.models import Model, Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.preprocessing import sequence
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils
from tensorflow.keras.utils import to_categorical

## Sklearn
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder

## Rest
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile
from tqdm import tqdm

input_duration=3
# % pylab inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#only SAVEE data set
import time
import os
import librosa
from librosa import display
import matplotlib.pyplot as plt
#sad/sa2dc.avi
labels = []
video_name=[]
audio_name=[]
features=[]
count=0
start_time = time.time()
CLASSES_LIST=['KL','JK ','JE','DC']
DATASET_DIR = '/content/drive/My Drive/SAVEE'
emotion_LIST = ["neutral", "happy", "sad","angry","fearful"]
for class_index, class_name in enumerate(CLASSES_LIST):
#for subdir, dirs, files in os.walk(path):
  print(class_name)
  #dir=subdir.split('/')[4]
  #print(dir)
  
  files= os.listdir(os.path.join(DATASET_DIR, class_name))
  for file in files:
      try:
        print(file)
        #Load librosa array, obtain mfcss, store the file and the mcss information in a new array
        X, sample_rate = librosa.load(DATASET_DIR+'/'+class_name+'/'+file, res_type='kaiser_fast')
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) 
        count +=1
        # The instruction below converts the labels (from 1 to 8) to a series from 0 to 7
        # This is because our predictor needs to start from 0 otherwise it will try to predict also 0.
        #file = int(file[7:8]) - 1 
        #0 = neutral, 1 = happy, 2 = sad, 3 = angry, 4 = fearful, 6 = disgust, 7 = surprised
        if file.startswith('a'):
            emotion=3
            c='a'
    
        elif file.startswith('f'):
            emotion=4
            c='f'
        elif file.startswith('h'):
            emotion=1
            c='h'
        elif file.startswith('n'):
            emotion=0
            c='n'
        elif file.startswith('sa'):
            emotion=2
            c='sa'
       
        else:
            continue
        my_class_name=class_name
        my_class_name=my_class_name.replace(" ", "")
        num=file.split('.')[0]
        #print(num)
        if(c=='sa'):
          num=num[2:]
        else:
          num=num[1:]
        num=int(num)
        num=str(num)
        #print(num)
       
        v=emotion_LIST[emotion]+'/'+c+num+my_class_name.lower()+'.avi'
        video_name.append(v)
        a=class_name+'/'+file

        audio_name.append(a)
        labels.append(emotion)
        
        features.append(mfccs)
      # If the file is not valid, skip it
      except ValueError:
        continue

print("--- Data loaded. Loading time: %s seconds ---" % (time.time() - start_time))
# Out:
# KL
# a01.wav
# a02.wav
# a03.wav
# a04.wav
# a05.wav
# a07.wav
# a10.wav
# a09.wav
# a08.wav
# a06.wav
# a15.wav
# a14.wav
# a13.wav
# a12.wav
# a11.wav
# d05.wav
# d04.wav
# d03.wav
# d02.wav
# d01.wav
# d10.wav
# d09.wav
# d08.wav
# d07.wav
# d06.wav
# d15.wav
# d14.wav
# d13.wav
# d12.wav
# d11.wav
# f05.wav
# f04.wav
# f03.wav
# f02.wav
# f01.wav
# f10.wav
# f09.wav
# f08.wav
# f07.wav
# f06.wav
# f15.wav
# f14.wav
# f13.wav
# f12.wav
# f11.wav
# h05.wav
# h04.wav
# h03.wav
# h02.wav
# h01.wav
# h10.wav
# h09.wav
# h08.wav
# h07.wav
# h06.wav
# h15.wav
# h14.wav
# h13.wav
# h12.wav
# h11.wav
# sa05.wav
# sa04.wav
# sa03.wav
# sa02.wav
# sa01.wav
# sa10.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa11.wav
# sa14.wav
# sa13.wav
# sa12.wav
# sa15.wav
# su05.wav
# su03.wav
# su02.wav
# su01.wav
# su10.wav
# su09.wav
# su08.wav
# su07.wav
# su06.wav
# su15.wav
# su14.wav
# su13.wav
# su12.wav
# su11.wav
# su04.wav
# n01.wav
# n05.wav
# n04.wav
# n03.wav
# n02.wav
# n10.wav
# n09.wav
# n08.wav
# n07.wav
# n06.wav
# n20.wav
# n19.wav
# n18.wav
# n17.wav
# n16.wav
# n25.wav
# n24.wav
# n23.wav
# n22.wav
# n21.wav
# n30.wav
# n29.wav
# n28.wav
# n27.wav
# n26.wav
# n15.wav
# n14.wav
# n13.wav
# n12.wav
# n11.wav
# JK
# a01.wav
# a02.wav
# a03.wav
# a04.wav
# a05.wav
# a06.wav
# a07.wav
# a08.wav
# a09.wav
# a10.wav
# a11.wav
# a12.wav
# a13.wav
# a14.wav
# a15.wav
# d01.wav
# d02.wav
# d03.wav
# d04.wav
# d06.wav
# d07.wav
# d08.wav
# d09.wav
# d11.wav
# d12.wav
# d13.wav
# d14.wav
# d15.wav
# d05.wav
# d10.wav
# f01.wav
# f02.wav
# f03.wav
# f04.wav
# f05.wav
# f06.wav
# f07.wav
# f08.wav
# f10.wav
# f11.wav
# f12.wav
# f13.wav
# f14.wav
# f15.wav
# f09.wav
# h01.wav
# h02.wav
# h03.wav
# h04.wav
# h05.wav
# h06.wav
# h07.wav
# h08.wav
# h09.wav
# h10.wav
# h11.wav
# h12.wav
# h13.wav
# h14.wav
# h15.wav
# n01.wav
# n02.wav
# n03.wav
# n04.wav
# n05.wav
# n06.wav
# n07.wav
# n08.wav
# n09.wav
# n10.wav
# n11.wav
# n12.wav
# n13.wav
# n14.wav
# n15.wav
# n20.wav
# n19.wav
# n18.wav
# n17.wav
# n16.wav
# n25.wav
# n23.wav
# n22.wav
# n21.wav
# n26.wav
# n30.wav
# n29.wav
# n28.wav
# n27.wav
# sa05.wav
# sa04.wav
# sa03.wav
# sa02.wav
# sa01.wav
# sa10.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa15.wav
# sa14.wav
# sa13.wav
# sa12.wav
# sa11.wav
# su05.wav
# su04.wav
# su15.wav
# su14.wav
# su13.wav
# su12.wav
# su11.wav
# su10.wav
# su09.wav
# su08.wav
# su07.wav
# su06.wav
# su03.wav
# su02.wav
# su01.wav
# n24.wav
# JE
# a01.wav
# a02.wav
# a03.wav
# a04.wav
# a05.wav
# a07.wav
# a06.wav
# a08.wav
# a09.wav
# a10.wav
# a11.wav
# a12.wav
# a13.wav
# a14.wav
# a15.wav
# d05.wav
# d04.wav
# d03.wav
# d02.wav
# d01.wav
# d09.wav
# d08.wav
# d07.wav
# d06.wav
# d10.wav
# d15.wav
# d14.wav
# d13.wav
# d12.wav
# d11.wav
# f05.wav
# f04.wav
# f03.wav
# f02.wav
# f01.wav
# f10.wav
# f09.wav
# f08.wav
# f07.wav
# f06.wav
# f14.wav
# f13.wav
# f12.wav
# f11.wav
# f15.wav
# h05.wav
# h04.wav
# h03.wav
# h02.wav
# h01.wav
# h10.wav
# h09.wav
# h08.wav
# h07.wav
# h06.wav
# h14.wav
# h13.wav
# h12.wav
# h11.wav
# h15.wav
# n18.wav
# n17.wav
# n16.wav
# n05.wav
# n04.wav
# n03.wav
# n02.wav
# n01.wav
# n10.wav
# n09.wav
# n08.wav
# n07.wav
# n06.wav
# n15.wav
# n14.wav
# n13.wav
# n12.wav
# n11.wav
# n20.wav
# n19.wav
# n25.wav
# n24.wav
# n23.wav
# n22.wav
# n21.wav
# n30.wav
# n29.wav
# n28.wav
# n27.wav
# n26.wav
# sa04.wav
# sa03.wav
# sa02.wav
# sa01.wav
# sa13.wav
# sa12.wav
# sa11.wav
# sa05.wav
# sa10.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa15.wav
# sa14.wav
# su05.wav
# su04.wav
# su03.wav
# su02.wav
# su01.wav
# su10.wav
# su09.wav
# su08.wav
# su07.wav
# su06.wav
# su13.wav
# su12.wav
# su11.wav
# su15.wav
# su14.wav
# DC
# a15.wav
# a14.wav
# a05.wav
# a04.wav
# a03.wav
# a02.wav
# a01.wav
# a06.wav
# a07.wav
# a08.wav
# a09.wav
# a10.wav
# a13.wav
# a12.wav
# a11.wav
# d01.wav
# d02.wav
# d03.wav
# d04.wav
# d05.wav
# d10.wav
# d09.wav
# d08.wav
# d07.wav
# d06.wav
# d15.wav
# d14.wav
# d13.wav
# d12.wav
# d11.wav
# f01.wav
# f02.wav
# f03.wav
# f04.wav
# f05.wav
# f10.wav
# f09.wav
# f08.wav
# f07.wav
# f06.wav
# f15.wav
# f14.wav
# f13.wav
# f12.wav
# f11.wav
# h01.wav
# h02.wav
# h03.wav
# h04.wav
# h05.wav
# h10.wav
# h09.wav
# h08.wav
# h07.wav
# h06.wav
# h11.wav
# h12.wav
# h13.wav
# h14.wav
# h15.wav
# n05.wav
# n04.wav
# n03.wav
# n02.wav
# n01.wav
# n06.wav
# n07.wav
# n08.wav
# n09.wav
# n10.wav
# n11.wav
# n12.wav
# n13.wav
# n14.wav
# n15.wav
# n20.wav
# n19.wav
# n18.wav
# n17.wav
# n16.wav
# n21.wav
# n22.wav
# n23.wav
# n24.wav
# n25.wav
# n26.wav
# n27.wav
# n28.wav
# n29.wav
# n30.wav
# sa01.wav
# sa02.wav
# sa03.wav
# sa04.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa11.wav
# sa12.wav
# sa13.wav
# sa14.wav
# sa15.wav
# sa05.wav
# sa10.wav
# su01.wav
# su02.wav
# su03.wav
# su04.wav
# su05.wav
# su06.wav
# su07.wav
# su08.wav
# su09.wav
# su11.wav
# su12.wav
# su13.wav
# su14.wav
# su15.wav
# su10.wav
# --- Data loaded. Loading time: 122.82535099983215 seconds ---

# %%
seed_constant = 928617

# %%
from sklearn.model_selection import train_test_split
# Split the Data into Train ( 80% ) and Test Set ( 20% ).
x_train, x_test, y_train, y_test,video_train_path,video_test_path,audio_train_path,audio_test_path = train_test_split(features, labels,video_name,audio_name,
                                                                            test_size = 0.10, shuffle = True,
                                                                            random_state = seed_constant)

# %%
# Split train the Data into Train ( 80% ) and valid Set ( 20% ).
x_train, x_valid, y_train, y_valid,video_train_path,video_valid_path,audio_train_path,audio_valid_path = train_test_split(x_train, y_train,video_train_path,audio_train_path,
                                                                            test_size = 0.11, shuffle = True,
                                                                            random_state = seed_constant)

# %%
#288,36,36
len(x_train),len(x_valid),len(x_test),len(y_train),len(y_valid),len(y_test),len(video_train_path),len(video_valid_path),len(video_test_path),len(audio_train_path),len(audio_valid_path),len(audio_test_path)
# Out:
# (288, 36, 36, 288, 36, 36, 288, 36, 36, 288, 36, 36)

# %%
import joblib

save_dir = '/content/drive/My Drive/fusion/savee/audio/data_set/expert7'

savedvX = joblib.dump(y_train, os.path.join(save_dir, 'train/labels_train'))
savedvX = joblib.dump(y_test, os.path.join(save_dir, 'test/labels_test'))
savedvX = joblib.dump(y_valid, os.path.join(save_dir, 'valid/labels_valid'))
savedvX = joblib.dump(video_train_path, os.path.join(save_dir, 'train/video_train_path'))
savedvX = joblib.dump(video_test_path, os.path.join(save_dir, 'test/video_test_path'))
savedvX = joblib.dump(video_valid_path, os.path.join(save_dir, 'valid/video_valid_path'))
savedvX = joblib.dump(audio_train_path, os.path.join(save_dir, 'train/audio_train_path'))
savedvX = joblib.dump(audio_test_path, os.path.join(save_dir, 'test/audio_test_path'))
savedvX = joblib.dump(audio_valid_path, os.path.join(save_dir, 'valid/audio_valid_path'))

# %%
x_valid=np.asarray(x_valid)
x_test=np.asarray(x_test)
x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
y_test=np.asarray(y_test)
y_valid=np.asarray(y_valid)
x_valid.shape,x_test.shape,x_train.shape,y_valid.shape,y_test.shape,y_train.shape
# Out:
# ((36, 40), (36, 40), (288, 40), (36,), (36,), (288,))

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras import optimizers
from keras.models import InputLayer

model = Sequential(InputLayer((40,1)))
model.add(BatchNormalization())

model.add(Conv1D(128, 12,padding='same', ))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=(5)))


model.add(Conv1D(256,12,padding='same',))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(MaxPooling1D(pool_size=(5)))

model.add(Flatten())
model.add(Dense(5))
model.add(Activation('softmax'))
opt = tf.keras.optimizers.Adam(lr=0.0002)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 40, 1)            4
#  ormalization)
#
#  conv1d (Conv1D)             (None, 40, 128)           1664
#
#  batch_normalization_1 (Batc  (None, 40, 128)          512
#  hNormalization)
#
#  activation (Activation)     (None, 40, 128)           0
#
#  dropout (Dropout)           (None, 40, 128)           0
#
#  max_pooling1d (MaxPooling1D  (None, 8, 128)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 8, 256)            393472
#
#  batch_normalization_2 (Batc  (None, 8, 256)           1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8, 256)            0
#
#  dropout_1 (Dropout)         (None, 8, 256)            0
#
#  max_pooling1d_1 (MaxPooling  (None, 1, 256)           0
#  1D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 5)                 1285
#
#  activation_2 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 397,961
# Trainable params: 397,191
# Non-trainable params: 770
# _________________________________________________________________

# %%
x_traincnn = np.expand_dims(x_train, axis=2)
x_testcnn = np.expand_dims(x_test, axis=2)
x_valid= np.expand_dims(x_valid, axis=2)
x_traincnn.shape, x_testcnn.shape , x_valid.shape
# Out:
# ((288, 40, 1), (36, 40, 1), (36, 40, 1))

# %%
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = opt, metrics = ["accuracy"])

early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 65, mode = 'min', restore_best_weights = True)
cnnhistory=model.fit(x_traincnn, y_train, batch_size=16, epochs=500 , shuffle = True, 
                     validation_data=(x_valid, y_valid), callbacks = [early_stopping_callback])
# Out:
# Epoch 1/500
# 18/18 [==============================] - 12s 22ms/step - loss: 2.0958 - accuracy: 0.2951 - val_loss: 1.5471 - val_accuracy: 0.3611
# Epoch 2/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.7426 - accuracy: 0.3819 - val_loss: 1.7711 - val_accuracy: 0.0833
# Epoch 3/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.5079 - accuracy: 0.4201 - val_loss: 1.8455 - val_accuracy: 0.0278
# Epoch 4/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.4264 - accuracy: 0.4340 - val_loss: 1.9943 - val_accuracy: 0.0833
# Epoch 5/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.3674 - accuracy: 0.4931 - val_loss: 2.2062 - val_accuracy: 0.0833
# Epoch 6/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.2639 - accuracy: 0.5486 - val_loss: 2.1552 - val_accuracy: 0.0833
# Epoch 7/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0878 - accuracy: 0.5764 - val_loss: 2.4395 - val_accuracy: 0.0556
# Epoch 8/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.1347 - accuracy: 0.5694 - val_loss: 2.5776 - val_accuracy: 0.0833
# Epoch 9/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0662 - accuracy: 0.6007 - val_loss: 2.6792 - val_accuracy: 0.0556
# Epoch 10/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0009 - accuracy: 0.5833 - val_loss: 2.8195 - val_accuracy: 0.0556
# Epoch 11/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0467 - accuracy: 0.6424 - val_loss: 3.1547 - val_accuracy: 0.0556
# Epoch 12/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.9264 - accuracy: 0.6389 - val_loss: 2.9690 - val_accuracy: 0.0556
# Epoch 13/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.9157 - accuracy: 0.6424 - val_loss: 3.1802 - val_accuracy: 0.0556
# Epoch 14/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8815 - accuracy: 0.6875 - val_loss: 3.2005 - val_accuracy: 0.0556
# Epoch 15/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.9192 - accuracy: 0.6632 - val_loss: 3.4124 - val_accuracy: 0.0556
# Epoch 16/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8620 - accuracy: 0.6493 - val_loss: 3.3474 - val_accuracy: 0.0556
# Epoch 17/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.9046 - accuracy: 0.6736 - val_loss: 3.2213 - val_accuracy: 0.0556
# Epoch 18/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7977 - accuracy: 0.6528 - val_loss: 3.0654 - val_accuracy: 0.0556
# Epoch 19/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.9022 - accuracy: 0.6493 - val_loss: 2.9782 - val_accuracy: 0.0556
# Epoch 20/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8003 - accuracy: 0.7083 - val_loss: 3.2003 - val_accuracy: 0.0556
# Epoch 21/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8617 - accuracy: 0.6806 - val_loss: 2.9642 - val_accuracy: 0.0556
# Epoch 22/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7735 - accuracy: 0.7118 - val_loss: 2.8633 - val_accuracy: 0.0556
# Epoch 23/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.7970 - accuracy: 0.7014 - val_loss: 2.4066 - val_accuracy: 0.0833
# Epoch 24/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8220 - accuracy: 0.6667 - val_loss: 2.7456 - val_accuracy: 0.0833
# Epoch 25/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8405 - accuracy: 0.6840 - val_loss: 2.5127 - val_accuracy: 0.0833
# Epoch 26/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7748 - accuracy: 0.6840 - val_loss: 2.0454 - val_accuracy: 0.1111
# Epoch 27/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8242 - accuracy: 0.6771 - val_loss: 1.8642 - val_accuracy: 0.2222
# Epoch 28/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.7815 - accuracy: 0.7118 - val_loss: 1.6537 - val_accuracy: 0.3889
# Epoch 29/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.7390 - accuracy: 0.7083 - val_loss: 1.2097 - val_accuracy: 0.5278
# Epoch 30/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7068 - accuracy: 0.6979 - val_loss: 1.9005 - val_accuracy: 0.2778
# Epoch 31/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7168 - accuracy: 0.7396 - val_loss: 1.2055 - val_accuracy: 0.5556
# Epoch 32/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6886 - accuracy: 0.7326 - val_loss: 1.3983 - val_accuracy: 0.4722
# Epoch 33/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7354 - accuracy: 0.7014 - val_loss: 1.1425 - val_accuracy: 0.6111
# Epoch 34/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7095 - accuracy: 0.7222 - val_loss: 1.0813 - val_accuracy: 0.6111
# Epoch 35/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7054 - accuracy: 0.7292 - val_loss: 1.0176 - val_accuracy: 0.6389
# Epoch 36/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6397 - accuracy: 0.7639 - val_loss: 1.0648 - val_accuracy: 0.6111
# Epoch 37/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8158 - accuracy: 0.7014 - val_loss: 0.8207 - val_accuracy: 0.7222
# Epoch 38/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6734 - accuracy: 0.7292 - val_loss: 1.0562 - val_accuracy: 0.5833
# Epoch 39/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6588 - accuracy: 0.7361 - val_loss: 0.8342 - val_accuracy: 0.6944
# Epoch 40/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6618 - accuracy: 0.7083 - val_loss: 0.8484 - val_accuracy: 0.6944
# Epoch 41/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.7104 - accuracy: 0.7153 - val_loss: 0.8828 - val_accuracy: 0.6389
# Epoch 42/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7765 - accuracy: 0.7049 - val_loss: 0.9899 - val_accuracy: 0.5000
# Epoch 43/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6976 - accuracy: 0.7153 - val_loss: 0.8994 - val_accuracy: 0.6389
# Epoch 44/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.7204 - accuracy: 0.7083 - val_loss: 0.8179 - val_accuracy: 0.6667
# Epoch 45/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7120 - accuracy: 0.7326 - val_loss: 0.8402 - val_accuracy: 0.7500
# Epoch 46/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6097 - accuracy: 0.7465 - val_loss: 0.7920 - val_accuracy: 0.6667
# Epoch 47/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5706 - accuracy: 0.7812 - val_loss: 0.7915 - val_accuracy: 0.6667
# Epoch 48/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6249 - accuracy: 0.7326 - val_loss: 0.8795 - val_accuracy: 0.6389
# Epoch 49/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5797 - accuracy: 0.7882 - val_loss: 0.6908 - val_accuracy: 0.7222
# Epoch 50/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6617 - accuracy: 0.7361 - val_loss: 0.6862 - val_accuracy: 0.7222
# Epoch 51/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5851 - accuracy: 0.7361 - val_loss: 0.8010 - val_accuracy: 0.6667
# Epoch 52/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6636 - accuracy: 0.7257 - val_loss: 0.8255 - val_accuracy: 0.7222
# Epoch 53/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5806 - accuracy: 0.7708 - val_loss: 0.6755 - val_accuracy: 0.7500
# Epoch 54/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5968 - accuracy: 0.7847 - val_loss: 0.8716 - val_accuracy: 0.5278
# Epoch 55/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5470 - accuracy: 0.7812 - val_loss: 0.7007 - val_accuracy: 0.7222
# Epoch 56/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5976 - accuracy: 0.7639 - val_loss: 0.8629 - val_accuracy: 0.5833
# Epoch 57/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5390 - accuracy: 0.7951 - val_loss: 0.6412 - val_accuracy: 0.7222
# Epoch 58/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5831 - accuracy: 0.7812 - val_loss: 0.8001 - val_accuracy: 0.6944
# Epoch 59/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5181 - accuracy: 0.8056 - val_loss: 0.7126 - val_accuracy: 0.7500
# Epoch 60/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5961 - accuracy: 0.7674 - val_loss: 0.7410 - val_accuracy: 0.6944
# Epoch 61/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6041 - accuracy: 0.7674 - val_loss: 0.7825 - val_accuracy: 0.6111
# Epoch 62/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5375 - accuracy: 0.7674 - val_loss: 0.8619 - val_accuracy: 0.5278
# Epoch 63/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5412 - accuracy: 0.7743 - val_loss: 0.9223 - val_accuracy: 0.5556
# Epoch 64/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5136 - accuracy: 0.7986 - val_loss: 0.7265 - val_accuracy: 0.7222
# Epoch 65/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5211 - accuracy: 0.7778 - val_loss: 0.7956 - val_accuracy: 0.6667
# Epoch 66/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5350 - accuracy: 0.8056 - val_loss: 0.8631 - val_accuracy: 0.7500
# Epoch 67/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5455 - accuracy: 0.7535 - val_loss: 0.6674 - val_accuracy: 0.7778
# Epoch 68/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5294 - accuracy: 0.8125 - val_loss: 0.6746 - val_accuracy: 0.7778
# Epoch 69/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4747 - accuracy: 0.8160 - val_loss: 0.7504 - val_accuracy: 0.7778
# Epoch 70/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4285 - accuracy: 0.8264 - val_loss: 0.7012 - val_accuracy: 0.7222
# Epoch 71/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4895 - accuracy: 0.7951 - val_loss: 0.6788 - val_accuracy: 0.7500
# Epoch 72/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4664 - accuracy: 0.7951 - val_loss: 0.7526 - val_accuracy: 0.7778
# Epoch 73/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4771 - accuracy: 0.8299 - val_loss: 0.7759 - val_accuracy: 0.7500
# Epoch 74/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4741 - accuracy: 0.8299 - val_loss: 0.7044 - val_accuracy: 0.5833
# Epoch 75/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4386 - accuracy: 0.8438 - val_loss: 0.8074 - val_accuracy: 0.6944
# Epoch 76/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4335 - accuracy: 0.8021 - val_loss: 0.6655 - val_accuracy: 0.7500
# Epoch 77/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4242 - accuracy: 0.8299 - val_loss: 0.6520 - val_accuracy: 0.6944
# Epoch 78/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5342 - accuracy: 0.7708 - val_loss: 0.7279 - val_accuracy: 0.6944
# Epoch 79/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5502 - accuracy: 0.7743 - val_loss: 0.6078 - val_accuracy: 0.8056
# Epoch 80/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4371 - accuracy: 0.8229 - val_loss: 0.6159 - val_accuracy: 0.8056
# Epoch 81/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4010 - accuracy: 0.8264 - val_loss: 0.6431 - val_accuracy: 0.7778
# Epoch 82/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3884 - accuracy: 0.8472 - val_loss: 0.6202 - val_accuracy: 0.8056
# Epoch 83/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4177 - accuracy: 0.8229 - val_loss: 0.6962 - val_accuracy: 0.6667
# Epoch 84/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3993 - accuracy: 0.8368 - val_loss: 0.6575 - val_accuracy: 0.7222
# Epoch 85/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4284 - accuracy: 0.8299 - val_loss: 0.6900 - val_accuracy: 0.7222
# Epoch 86/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4442 - accuracy: 0.8403 - val_loss: 0.7735 - val_accuracy: 0.7778
# Epoch 87/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4062 - accuracy: 0.8333 - val_loss: 0.7368 - val_accuracy: 0.6667
# Epoch 88/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3847 - accuracy: 0.8299 - val_loss: 0.6397 - val_accuracy: 0.7500
# Epoch 89/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4259 - accuracy: 0.8125 - val_loss: 0.6978 - val_accuracy: 0.7778
# Epoch 90/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3932 - accuracy: 0.8576 - val_loss: 0.8169 - val_accuracy: 0.6111
# Epoch 91/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4093 - accuracy: 0.8472 - val_loss: 0.6450 - val_accuracy: 0.7222
# Epoch 92/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4160 - accuracy: 0.8333 - val_loss: 0.6778 - val_accuracy: 0.7222
# Epoch 93/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4082 - accuracy: 0.8299 - val_loss: 0.7286 - val_accuracy: 0.6944
# Epoch 94/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3798 - accuracy: 0.8646 - val_loss: 0.7763 - val_accuracy: 0.6111
# Epoch 95/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3634 - accuracy: 0.8403 - val_loss: 0.6538 - val_accuracy: 0.8056
# Epoch 96/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3795 - accuracy: 0.8576 - val_loss: 0.6138 - val_accuracy: 0.7222
# Epoch 97/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3980 - accuracy: 0.8507 - val_loss: 0.7240 - val_accuracy: 0.7500
# Epoch 98/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4074 - accuracy: 0.8229 - val_loss: 0.7215 - val_accuracy: 0.7500
# Epoch 99/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3624 - accuracy: 0.8542 - val_loss: 0.6093 - val_accuracy: 0.8056
# Epoch 100/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3330 - accuracy: 0.8681 - val_loss: 0.6948 - val_accuracy: 0.8056
# Epoch 101/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3061 - accuracy: 0.8715 - val_loss: 0.7270 - val_accuracy: 0.6111
# Epoch 102/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2843 - accuracy: 0.8958 - val_loss: 0.6272 - val_accuracy: 0.6944
# Epoch 103/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3150 - accuracy: 0.8785 - val_loss: 0.5788 - val_accuracy: 0.8333
# Epoch 104/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3186 - accuracy: 0.8681 - val_loss: 0.6727 - val_accuracy: 0.7778
# Epoch 105/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3604 - accuracy: 0.8299 - val_loss: 0.7811 - val_accuracy: 0.7222
# Epoch 106/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3782 - accuracy: 0.8681 - val_loss: 0.7050 - val_accuracy: 0.7222
# Epoch 107/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2736 - accuracy: 0.9062 - val_loss: 0.6498 - val_accuracy: 0.6944
# Epoch 108/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3295 - accuracy: 0.8819 - val_loss: 0.7224 - val_accuracy: 0.7778
# Epoch 109/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2927 - accuracy: 0.8785 - val_loss: 0.6257 - val_accuracy: 0.7500
# Epoch 110/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3284 - accuracy: 0.8611 - val_loss: 0.7095 - val_accuracy: 0.7222
# Epoch 111/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2652 - accuracy: 0.8924 - val_loss: 0.6787 - val_accuracy: 0.7778
# Epoch 112/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3153 - accuracy: 0.8646 - val_loss: 0.6349 - val_accuracy: 0.8056
# Epoch 113/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2626 - accuracy: 0.8819 - val_loss: 0.7336 - val_accuracy: 0.6389
# Epoch 114/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2786 - accuracy: 0.8958 - val_loss: 0.6830 - val_accuracy: 0.8056
# Epoch 115/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3072 - accuracy: 0.8819 - val_loss: 0.5528 - val_accuracy: 0.7500
# Epoch 116/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2488 - accuracy: 0.8958 - val_loss: 0.8334 - val_accuracy: 0.7778
# Epoch 117/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2636 - accuracy: 0.8819 - val_loss: 0.6555 - val_accuracy: 0.7778
# Epoch 118/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2824 - accuracy: 0.8993 - val_loss: 0.7173 - val_accuracy: 0.7500
# Epoch 119/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2752 - accuracy: 0.9201 - val_loss: 0.6221 - val_accuracy: 0.8056
# Epoch 120/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2603 - accuracy: 0.9028 - val_loss: 0.6409 - val_accuracy: 0.8333
# Epoch 121/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3183 - accuracy: 0.8715 - val_loss: 0.6670 - val_accuracy: 0.7500
# Epoch 122/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3156 - accuracy: 0.8750 - val_loss: 0.7758 - val_accuracy: 0.7778
# Epoch 123/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2937 - accuracy: 0.8993 - val_loss: 0.8493 - val_accuracy: 0.7222
# Epoch 124/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2757 - accuracy: 0.8924 - val_loss: 0.7614 - val_accuracy: 0.7222
# Epoch 125/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2296 - accuracy: 0.9132 - val_loss: 0.6571 - val_accuracy: 0.7500
# Epoch 126/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2682 - accuracy: 0.9132 - val_loss: 0.6573 - val_accuracy: 0.6667
# Epoch 127/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2484 - accuracy: 0.8958 - val_loss: 0.7453 - val_accuracy: 0.8056
# Epoch 128/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2368 - accuracy: 0.9236 - val_loss: 0.5933 - val_accuracy: 0.7778
# Epoch 129/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2607 - accuracy: 0.8889 - val_loss: 0.6049 - val_accuracy: 0.7222
# Epoch 130/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2994 - accuracy: 0.8785 - val_loss: 0.9192 - val_accuracy: 0.5833
# Epoch 131/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2198 - accuracy: 0.9097 - val_loss: 0.6391 - val_accuracy: 0.6111
# Epoch 132/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2446 - accuracy: 0.9028 - val_loss: 0.6360 - val_accuracy: 0.7500
# Epoch 133/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1968 - accuracy: 0.9340 - val_loss: 0.6751 - val_accuracy: 0.6944
# Epoch 134/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2517 - accuracy: 0.9062 - val_loss: 0.7555 - val_accuracy: 0.6389
# Epoch 135/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2282 - accuracy: 0.9097 - val_loss: 0.7861 - val_accuracy: 0.6389
# Epoch 136/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2282 - accuracy: 0.9028 - val_loss: 0.6189 - val_accuracy: 0.6944
# Epoch 137/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2221 - accuracy: 0.9097 - val_loss: 0.6196 - val_accuracy: 0.7222
# Epoch 138/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1693 - accuracy: 0.9306 - val_loss: 0.7032 - val_accuracy: 0.6111
# Epoch 139/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2099 - accuracy: 0.9132 - val_loss: 0.6408 - val_accuracy: 0.7778
# Epoch 140/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2057 - accuracy: 0.9201 - val_loss: 0.5628 - val_accuracy: 0.6944
# Epoch 141/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2326 - accuracy: 0.9236 - val_loss: 0.7253 - val_accuracy: 0.6389
# Epoch 142/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2446 - accuracy: 0.9062 - val_loss: 0.5941 - val_accuracy: 0.7778
# Epoch 143/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1765 - accuracy: 0.9444 - val_loss: 0.6329 - val_accuracy: 0.7778
# Epoch 144/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1922 - accuracy: 0.9201 - val_loss: 0.5961 - val_accuracy: 0.7500
# Epoch 145/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2264 - accuracy: 0.9132 - val_loss: 0.6215 - val_accuracy: 0.7500
# Epoch 146/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2040 - accuracy: 0.9132 - val_loss: 0.7047 - val_accuracy: 0.7778
# Epoch 147/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1827 - accuracy: 0.9340 - val_loss: 0.6784 - val_accuracy: 0.7500
# Epoch 148/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1584 - accuracy: 0.9549 - val_loss: 0.6520 - val_accuracy: 0.7500
# Epoch 149/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1512 - accuracy: 0.9410 - val_loss: 0.7485 - val_accuracy: 0.6389
# Epoch 150/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1410 - accuracy: 0.9618 - val_loss: 0.6613 - val_accuracy: 0.6944
# Epoch 151/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1854 - accuracy: 0.9340 - val_loss: 0.6239 - val_accuracy: 0.6667
# Epoch 152/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1682 - accuracy: 0.9410 - val_loss: 0.7202 - val_accuracy: 0.6389
# Epoch 153/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1731 - accuracy: 0.9236 - val_loss: 0.6310 - val_accuracy: 0.7778
# Epoch 154/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2391 - accuracy: 0.9167 - val_loss: 0.7224 - val_accuracy: 0.6389
# Epoch 155/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1991 - accuracy: 0.9201 - val_loss: 0.6823 - val_accuracy: 0.6944
# Epoch 156/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1590 - accuracy: 0.9444 - val_loss: 0.6246 - val_accuracy: 0.7222
# Epoch 157/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1560 - accuracy: 0.9340 - val_loss: 0.6234 - val_accuracy: 0.7500
# Epoch 158/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1547 - accuracy: 0.9514 - val_loss: 0.6796 - val_accuracy: 0.7500
# Epoch 159/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1538 - accuracy: 0.9271 - val_loss: 0.7871 - val_accuracy: 0.6111
# Epoch 160/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1536 - accuracy: 0.9306 - val_loss: 0.7116 - val_accuracy: 0.5833
# Epoch 161/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1656 - accuracy: 0.9410 - val_loss: 0.6846 - val_accuracy: 0.6389
# Epoch 162/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1546 - accuracy: 0.9340 - val_loss: 0.5474 - val_accuracy: 0.7500
# Epoch 163/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1859 - accuracy: 0.9549 - val_loss: 0.8963 - val_accuracy: 0.6389
# Epoch 164/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1848 - accuracy: 0.9201 - val_loss: 0.6777 - val_accuracy: 0.7500
# Epoch 165/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1496 - accuracy: 0.9410 - val_loss: 0.7650 - val_accuracy: 0.7778
# Epoch 166/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1372 - accuracy: 0.9549 - val_loss: 0.7225 - val_accuracy: 0.7778
# Epoch 167/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1261 - accuracy: 0.9653 - val_loss: 0.7798 - val_accuracy: 0.7222
# Epoch 168/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1502 - accuracy: 0.9410 - val_loss: 0.6566 - val_accuracy: 0.6944
# Epoch 169/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1383 - accuracy: 0.9514 - val_loss: 0.9349 - val_accuracy: 0.7500
# Epoch 170/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1936 - accuracy: 0.9167 - val_loss: 0.7868 - val_accuracy: 0.7500
# Epoch 171/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1903 - accuracy: 0.9201 - val_loss: 0.6916 - val_accuracy: 0.7778
# Epoch 172/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1686 - accuracy: 0.9306 - val_loss: 0.6749 - val_accuracy: 0.6944
# Epoch 173/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1190 - accuracy: 0.9757 - val_loss: 0.6584 - val_accuracy: 0.6389
# Epoch 174/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1327 - accuracy: 0.9514 - val_loss: 0.7030 - val_accuracy: 0.6944
# Epoch 175/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1359 - accuracy: 0.9479 - val_loss: 0.7161 - val_accuracy: 0.7500
# Epoch 176/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1530 - accuracy: 0.9306 - val_loss: 0.6965 - val_accuracy: 0.6667
# Epoch 177/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1368 - accuracy: 0.9583 - val_loss: 0.6634 - val_accuracy: 0.6667
# Epoch 178/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1270 - accuracy: 0.9618 - val_loss: 0.6812 - val_accuracy: 0.7500
# Epoch 179/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1364 - accuracy: 0.9479 - val_loss: 0.7334 - val_accuracy: 0.7500
# Epoch 180/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0900 - accuracy: 0.9618 - val_loss: 0.6735 - val_accuracy: 0.7500
# Epoch 181/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1320 - accuracy: 0.9549 - val_loss: 0.6991 - val_accuracy: 0.7500
# Epoch 182/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1648 - accuracy: 0.9306 - val_loss: 0.6759 - val_accuracy: 0.7500
# Epoch 183/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1558 - accuracy: 0.9340 - val_loss: 0.9104 - val_accuracy: 0.5833
# Epoch 184/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1168 - accuracy: 0.9653 - val_loss: 0.6408 - val_accuracy: 0.7500
# Epoch 185/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1118 - accuracy: 0.9653 - val_loss: 0.6512 - val_accuracy: 0.7500
# Epoch 186/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1342 - accuracy: 0.9653 - val_loss: 0.8250 - val_accuracy: 0.5833
# Epoch 187/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1464 - accuracy: 0.9549 - val_loss: 0.6781 - val_accuracy: 0.8056
# Epoch 188/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1329 - accuracy: 0.9514 - val_loss: 0.7350 - val_accuracy: 0.7500
# Epoch 189/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1224 - accuracy: 0.9479 - val_loss: 0.5840 - val_accuracy: 0.7500
# Epoch 190/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1388 - accuracy: 0.9653 - val_loss: 0.7928 - val_accuracy: 0.6111
# Epoch 191/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1133 - accuracy: 0.9653 - val_loss: 0.6786 - val_accuracy: 0.6667
# Epoch 192/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1016 - accuracy: 0.9688 - val_loss: 0.6241 - val_accuracy: 0.7500
# Epoch 193/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1158 - accuracy: 0.9583 - val_loss: 0.8248 - val_accuracy: 0.6389
# Epoch 194/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0828 - accuracy: 0.9757 - val_loss: 0.8736 - val_accuracy: 0.7500
# Epoch 195/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1238 - accuracy: 0.9653 - val_loss: 0.7317 - val_accuracy: 0.7778
# Epoch 196/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1144 - accuracy: 0.9618 - val_loss: 0.8197 - val_accuracy: 0.7778
# Epoch 197/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1033 - accuracy: 0.9792 - val_loss: 0.6252 - val_accuracy: 0.7500
# Epoch 198/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0899 - accuracy: 0.9757 - val_loss: 0.6955 - val_accuracy: 0.7222
# Epoch 199/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0766 - accuracy: 0.9826 - val_loss: 0.6382 - val_accuracy: 0.6667
# Epoch 200/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1129 - accuracy: 0.9549 - val_loss: 0.8726 - val_accuracy: 0.6389
# Epoch 201/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1370 - accuracy: 0.9410 - val_loss: 0.6698 - val_accuracy: 0.7500
# Epoch 202/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1220 - accuracy: 0.9549 - val_loss: 0.8363 - val_accuracy: 0.7500
# Epoch 203/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1070 - accuracy: 0.9757 - val_loss: 0.7704 - val_accuracy: 0.7222
# Epoch 204/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0999 - accuracy: 0.9653 - val_loss: 0.6918 - val_accuracy: 0.7500
# Epoch 205/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1092 - accuracy: 0.9479 - val_loss: 0.7487 - val_accuracy: 0.6944
# Epoch 206/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1412 - accuracy: 0.9410 - val_loss: 0.7907 - val_accuracy: 0.7222
# Epoch 207/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1620 - accuracy: 0.9340 - val_loss: 0.8062 - val_accuracy: 0.6944
# Epoch 208/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1423 - accuracy: 0.9444 - val_loss: 0.6993 - val_accuracy: 0.6111
# Epoch 209/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1148 - accuracy: 0.9653 - val_loss: 0.6682 - val_accuracy: 0.7222
# Epoch 210/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1108 - accuracy: 0.9583 - val_loss: 0.8550 - val_accuracy: 0.6389
# Epoch 211/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1285 - accuracy: 0.9479 - val_loss: 0.8112 - val_accuracy: 0.6944
# Epoch 212/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1107 - accuracy: 0.9653 - val_loss: 0.7553 - val_accuracy: 0.7778
# Epoch 213/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1015 - accuracy: 0.9583 - val_loss: 0.7696 - val_accuracy: 0.7500
# Epoch 214/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0980 - accuracy: 0.9583 - val_loss: 0.8406 - val_accuracy: 0.7778
# Epoch 215/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0936 - accuracy: 0.9722 - val_loss: 0.7254 - val_accuracy: 0.7500
# Epoch 216/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1197 - accuracy: 0.9549 - val_loss: 0.8626 - val_accuracy: 0.6944
# Epoch 217/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0864 - accuracy: 0.9792 - val_loss: 0.7887 - val_accuracy: 0.7500
# Epoch 218/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1240 - accuracy: 0.9514 - val_loss: 0.6546 - val_accuracy: 0.6667
# Epoch 219/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0760 - accuracy: 0.9826 - val_loss: 0.7311 - val_accuracy: 0.7778
# Epoch 220/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0819 - accuracy: 0.9722 - val_loss: 0.6051 - val_accuracy: 0.7500
# Epoch 221/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0972 - accuracy: 0.9688 - val_loss: 0.8192 - val_accuracy: 0.6389
# Epoch 222/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0881 - accuracy: 0.9688 - val_loss: 0.5741 - val_accuracy: 0.6944
# Epoch 223/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1103 - accuracy: 0.9583 - val_loss: 0.6946 - val_accuracy: 0.7222
# Epoch 224/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0760 - accuracy: 0.9757 - val_loss: 0.7082 - val_accuracy: 0.7778
# Epoch 225/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0614 - accuracy: 0.9792 - val_loss: 0.6425 - val_accuracy: 0.7500
# Epoch 226/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0823 - accuracy: 0.9688 - val_loss: 0.6796 - val_accuracy: 0.7222
# Epoch 227/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0554 - accuracy: 0.9861 - val_loss: 0.7135 - val_accuracy: 0.7500

# %%
plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.plot(cnnhistory.history['accuracy'])
plt.plot(cnnhistory.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %%
loss, acc =model.evaluate(x_traincnn,y_train )
print("Restored model train, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1000 - accuracy: 0.9931
# Restored model train, accuracy: 99.31%

# %%
loss, acc = model.evaluate(x_test, y_test)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4925 - accuracy: 0.7500
# Restored model, accuracy: 75.00%

# %%
#predictions = model.predict_classes(x_testcnn)
predictions = model.predict(x_test)
predictions
# Out:
# array([[1.29312111e-05, 3.53256823e-03, 1.06036168e-06, 1.41133647e-03,
#         9.95042086e-01],
#        [9.15729848e-04, 1.30415719e-03, 2.86408700e-04, 9.97159123e-01,
#         3.34592740e-04],
#        [9.51099157e-01, 6.07105577e-03, 2.92164180e-02, 3.98082193e-03,
#         9.63255577e-03],
#        [3.72526352e-03, 3.58339436e-02, 1.56864058e-03, 8.35215271e-01,
#         1.23656876e-01],
#        [8.82126114e-05, 3.46205229e-06, 9.99761999e-01, 3.68556903e-05,
#         1.09531902e-04],
#        [1.17091869e-04, 2.28913724e-01, 1.43322896e-03, 7.69434988e-01,
#         1.00998819e-04],
#        [1.42842725e-06, 9.98453498e-01, 3.75283139e-06, 9.64548090e-05,
#         1.44489866e-03],
#        [8.45974922e-01, 4.35160659e-02, 5.83136193e-02, 4.03367691e-02,
#         1.18586039e-02],
#        [9.76750314e-01, 4.28452768e-04, 2.14040875e-02, 1.78060625e-04,
#         1.23900687e-03],
#        [9.90699351e-01, 9.46146702e-06, 1.86782260e-03, 7.30766915e-03,
#         1.15747396e-04],
#        [9.88909066e-01, 2.71877616e-05, 8.40348192e-03, 2.65184767e-03,
#         8.31650686e-06],
#        [8.86038661e-01, 5.95253147e-03, 5.96963614e-02, 7.36838067e-03,
#         4.09440659e-02],
#        [1.31990045e-01, 5.70292734e-02, 9.27410368e-03, 4.52514216e-02,
#         7.56455123e-01],
#        [9.86896932e-01, 6.58769350e-05, 8.25466029e-03, 4.65891510e-03,
#         1.23603866e-04],
#        [8.92430326e-05, 9.40831423e-01, 6.92932663e-05, 5.20279296e-02,
#         6.98216958e-03],
#        [5.22803166e-04, 2.79056281e-01, 1.73518006e-02, 6.85977340e-01,
#         1.70917269e-02],
#        [9.97274458e-01, 1.96426281e-05, 1.92148017e-03, 7.63091724e-04,
#         2.14423017e-05],
#        [3.00529450e-06, 9.89578187e-01, 1.23659411e-04, 3.39343050e-03,
#         6.90181646e-03],
#        [7.15089243e-07, 9.97896910e-01, 5.65626897e-06, 1.26411824e-03,
#         8.32543592e-04],
#        [6.51328489e-02, 5.42439229e-04, 2.03144640e-01, 7.28841066e-01,
#         2.33903248e-03],
#        [3.82292259e-04, 5.94452262e-01, 2.15372915e-04, 4.04262185e-01,
#         6.87962398e-04],
#        [2.69411474e-01, 8.19244422e-04, 7.28954196e-01, 4.55309433e-04,
#         3.59784957e-04],
#        [1.22319498e-05, 9.91010591e-02, 6.56607735e-05, 8.99567366e-01,
#         1.25365832e-03],
#        [4.73799497e-01, 5.32129707e-06, 5.26114166e-01, 4.92479230e-05,
#         3.18067032e-05],
#        [9.73847568e-01, 9.69391331e-05, 5.11086080e-03, 2.03622263e-02,
#         5.82479697e-04],
#        [1.26272198e-06, 1.52341183e-03, 1.47533647e-05, 9.97874856e-01,
#         5.85764996e-04],
#        [3.47427995e-05, 2.68440956e-04, 3.16275873e-05, 9.98304725e-01,
#         1.36042060e-03],
#        [4.39858735e-01, 8.13781662e-05, 5.58616936e-01, 3.33177013e-04,
#         1.10973301e-03],
#        [8.06937896e-05, 1.60979480e-01, 5.54840481e-05, 8.38788331e-01,
#         9.59537283e-05],
#        [1.43153025e-04, 1.00901656e-01, 1.25555787e-03, 8.44698846e-01,
#         5.30006588e-02],
#        [4.11158763e-02, 4.12223637e-01, 1.23010604e-02, 4.66171920e-01,
#         6.81875274e-02],
#        [2.51634028e-05, 3.52466375e-01, 1.18220756e-04, 6.01361036e-01,
#         4.60291542e-02],
#        [3.84905306e-03, 6.20209100e-03, 1.40805394e-04, 9.81873631e-01,
#         7.93438777e-03],
#        [6.12212287e-04, 7.56915212e-01, 7.39864558e-02, 1.07608214e-01,
#         6.08779341e-02],
#        [2.94998135e-05, 2.93223234e-03, 9.72365320e-01, 9.25178640e-04,
#         2.37477329e-02],
#        [1.23270793e-05, 4.83563163e-05, 9.09278810e-01, 6.77496544e-04,
#         8.99830461e-02]], dtype=float32)

# %%
df_audio_test = pd.DataFrame(predictions,columns=["OA_"+str(i) for i in range(5)])

# %%
y_test
# Out:
# array([4, 3, 0, 3, 2, 1, 1, 0, 0, 0, 0, 0, 4, 0, 1, 1, 0, 1, 1, 2, 1, 0,
#        3, 0, 0, 3, 3, 2, 1, 4, 1, 4, 3, 1, 2, 2])

# %%
new_Ytest = y_test.astype(int)
new_Ytest
# Out:
# array([4, 3, 0, 3, 2, 1, 1, 0, 0, 0, 0, 0, 4, 0, 1, 1, 0, 1, 1, 2, 1, 0,
#        3, 0, 0, 3, 3, 2, 1, 4, 1, 4, 3, 1, 2, 2])

# %%
preds1=predictions.argmax(axis=1)
preds1
# Out:
# array([4, 3, 0, 3, 2, 3, 1, 0, 0, 0, 0, 0, 4, 0, 1, 3, 0, 1, 1, 3, 1, 2,
#        3, 2, 0, 3, 3, 2, 3, 3, 3, 3, 3, 1, 2, 2])

# %%
abc = preds1.astype(int).flatten()
from sklearn.metrics import confusion_matrix
c = confusion_matrix(new_Ytest, abc) 
c
# Out:
# array([[9, 0, 2, 0, 0],
#        [0, 6, 0, 4, 0],
#        [0, 0, 4, 1, 0],
#        [0, 0, 0, 6, 0],
#        [0, 0, 0, 2, 2]])

# %%
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
import seaborn as sn

print(classification_report(y_test,abc))

acc = float(accuracy_score(y_test,abc))*100
print("----accuracy score %s ----" % acc)

cm = confusion_matrix(y_test,abc)
#df_cm = pd.DataFrame(cm)
class_names = ['neutral', 'happy','sad','angry', 'fearful' ]
df_cm = pd.DataFrame(cm, index=class_names, columns=class_names,)
sn.heatmap(df_cm, annot=True, fmt='')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90        11
#            1       1.00      0.60      0.75        10
#            2       0.67      0.80      0.73         5
#            3       0.46      1.00      0.63         6
#            4       1.00      0.50      0.67         4
#
#     accuracy                           0.75        36
#    macro avg       0.83      0.74      0.74        36
# weighted avg       0.86      0.75      0.76        36
#
# ----accuracy score 75.0 ----

# %%
model.save('/content/drive/My Drive/fusion/savee/audio/model/expert7/best_CNN_model')
print("MODEL SAVED")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/fusion/savee/audio/model/expert7/best_CNN_model/assets
# MODEL SAVED

# %%
model_file_name = f'/content/drive/My Drive/fusion/savee/audio/model/expert7/best_CNN_model___Loss_{loss}___Accuracy_{acc}.h5'

# Save the Model.
model.save(model_file_name)

# %%
# serialize model to JSON
model_json = model.to_json()
with open("/content/drive/My Drive/fusion/savee/audio/model/expert7/best_CNN_model.json", "w") as json_file:
    json_file.write(model_json)

# %%
prediction_train = model.predict(x_traincnn)
prediction_train
# Out:
# array([[1.3664589e-04, 2.0891972e-02, 4.5383472e-06, 9.7892612e-01,
#         4.0762199e-05],
#        [6.5134302e-02, 3.3596597e-04, 9.1611624e-01, 4.3392642e-03,
#         1.4074301e-02],
#        [1.4548178e-05, 9.9319261e-01, 6.1005852e-05, 5.9090741e-03,
#         8.2269212e-04],
#        ...,
#        [8.3681880e-06, 8.3613154e-03, 1.7116487e-05, 5.9510203e-04,
#         9.9101806e-01],
#        [4.7989115e-03, 2.2196617e-04, 9.8866755e-01, 5.2540945e-03,
#         1.0574795e-03],
#        [1.6179249e-03, 1.3247898e-03, 5.6297146e-04, 9.6605420e-01,
#         3.0440152e-02]], dtype=float32)

# %%
df_audio_train = pd.DataFrame(prediction_train,columns=["OA_"+str(i) for i in range(5)])

# %%
prediction_valid = model.predict(x_valid)
prediction_valid
# Out:
# array([[5.81824422e-01, 2.45810734e-05, 3.70366246e-01, 1.83452480e-02,
#         2.94395406e-02],
#        [6.87000453e-01, 4.39670373e-04, 3.08776528e-01, 2.77017243e-04,
#         3.50633264e-03],
#        [9.99852180e-01, 6.60220894e-06, 6.80023513e-05, 7.20956668e-05,
#         1.24266023e-06],
#        [6.00154996e-01, 4.81962878e-03, 3.82077515e-01, 1.20777506e-02,
#         8.70097196e-04],
#        [3.18815917e-01, 1.69913098e-03, 6.76779389e-01, 1.30847108e-03,
#         1.39711599e-03],
#        [9.80529487e-01, 3.96794894e-06, 1.85198430e-02, 9.24045395e-04,
#         2.26912161e-05],
#        [3.54629941e-02, 3.43488937e-04, 9.48190510e-01, 6.08346099e-03,
#         9.91956610e-03],
#        [1.52310906e-06, 6.49988826e-04, 3.30235434e-06, 9.99341667e-01,
#         3.44137993e-06],
#        [1.30875371e-04, 2.84665763e-01, 1.31707066e-05, 7.15078950e-01,
#         1.11229470e-04],
#        [1.24614269e-01, 6.44629006e-04, 8.64333749e-01, 1.01844231e-02,
#         2.22909366e-04],
#        [8.60015929e-01, 1.11215581e-04, 1.36878952e-01, 1.39118158e-04,
#         2.85480940e-03],
#        [1.36667062e-04, 7.21569479e-01, 2.25156091e-05, 2.76725650e-01,
#         1.54568511e-03],
#        [3.20149539e-03, 6.96603733e-04, 9.12587166e-01, 7.93208703e-02,
#         4.19385312e-03],
#        [7.84599960e-01, 6.17215410e-05, 2.15121388e-01, 1.84891018e-04,
#         3.19445790e-05],
#        [2.02352256e-01, 8.04109499e-03, 1.11375041e-01, 6.77624285e-01,
#         6.07337628e-04],
#        [2.38292969e-07, 1.47549445e-02, 1.12476116e-02, 1.13234408e-02,
#         9.62673724e-01],
#        [4.16833162e-01, 3.44863183e-05, 5.81262589e-01, 1.78678497e-03,
#         8.30452045e-05],
#        [4.64260608e-01, 7.04336399e-03, 5.27201712e-01, 1.26938836e-03,
#         2.24928095e-04],
#        [9.84320104e-01, 9.91708002e-05, 1.49218142e-02, 2.31755170e-04,
#         4.27198393e-04],
#        [2.95207906e-06, 9.28144515e-01, 1.90379842e-06, 2.93137971e-03,
#         6.89192340e-02],
#        [6.81871825e-05, 5.94338953e-01, 4.55965819e-05, 2.22541634e-02,
#         3.83293092e-01],
#        [4.85716343e-01, 4.04275805e-02, 1.55991584e-01, 1.32904053e-01,
#         1.84960455e-01],
#        [6.15257442e-01, 5.51747507e-04, 3.78745645e-01, 5.35811158e-03,
#         8.70572767e-05],
#        [1.04236215e-05, 5.51055312e-01, 6.09005848e-03, 5.27627505e-02,
#         3.90081406e-01],
#        [3.96201467e-05, 2.56820233e-04, 2.62470711e-02, 5.45328017e-04,
#         9.72911119e-01],
#        [2.73288811e-06, 4.06335015e-03, 3.19289029e-07, 3.67541652e-04,
#         9.95566070e-01],
#        [1.03307844e-04, 3.13901436e-03, 2.37952173e-01, 3.71733367e-01,
#         3.87072116e-01],
#        [8.93742561e-01, 1.74492845e-04, 1.02545291e-01, 3.05437716e-03,
#         4.83236450e-04],
#        [9.98002231e-01, 6.47634533e-06, 1.94969715e-03, 3.84911655e-05,
#         3.14864633e-06],
#        [8.73172760e-01, 1.26195711e-03, 4.94825877e-02, 7.52266198e-02,
#         8.56079801e-04],
#        [9.82825220e-01, 1.98952257e-05, 1.64129678e-02, 7.20065495e-04,
#         2.17593206e-05],
#        [6.69081628e-01, 2.34191219e-04, 3.01189691e-01, 8.08428740e-04,
#         2.86861099e-02],
#        [2.65432477e-01, 2.06561992e-03, 7.21690416e-01, 9.39586386e-03,
#         1.41569541e-03],
#        [4.40483491e-05, 3.85008790e-02, 8.38813139e-06, 9.30038214e-01,
#         3.14084180e-02],
#        [4.56026495e-02, 7.15252245e-04, 9.52580333e-01, 1.64392877e-05,
#         1.08539255e-03],
#        [9.35282826e-01, 9.04278022e-06, 6.37314245e-02, 4.77827329e-04,
#         4.98818175e-04]], dtype=float32)

# %%
df_audio_valid = pd.DataFrame(prediction_valid,columns=["OA_"+str(i) for i in range(5)])

# %%
import joblib

save_dir = '/content/drive/My Drive/fusion/savee/audio/data_set/expert7'

savedvX = joblib.dump(df_audio_train, os.path.join(save_dir, 'train/predict_train'))
savedvX = joblib.dump(df_audio_test, os.path.join(save_dir, 'test/predict_test'))
savedvX = joblib.dump(df_audio_valid, os.path.join(save_dir, 'valid/predict_valid'))
