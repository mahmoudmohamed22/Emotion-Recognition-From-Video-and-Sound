# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, glob
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import warnings; warnings.filterwarnings('ignore') #matplot lib complains about librosa

# %%
# RAVDESS native sample rate is 48k
sample_rate = 48000

# Mel Spectrograms are not directly used as a feature in this model
# Mel Spectrograms are used in calculating MFCCs, which are a higher-level representation of pitch transition
# MFCCs work better - left the mel spectrogram function here in case anyone wants to experiment
def feature_melspectrogram(
    waveform, 
    sample_rate,
    fft = 1024,
    winlen = 512,
    window='hamming',
    hop=256,
    mels=128,
    ):
    
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram = librosa.feature.melspectrogram(
        y=waveform, 
        sr=sample_rate, 
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2)
    
    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms 
    melspectrogram = librosa.power_to_db(melspectrogram, ref=np.max)
    
    return melspectrogram

def feature_mfcc(
    waveform, 
    sample_rate,
    n_mfcc = 40,
    fft = 1024,
    winlen = 512,
    window='hamming',
    #hop=256, # increases # of time steps; was not helpful
    mels=128
    ):

    # Compute the MFCCs for all STFT frames 
    # 40 mel filterbanks (n_mfcc) = 40 coefficients
    mfc_coefficients=librosa.feature.mfcc(
        y=waveform, 
        sr=sample_rate, 
        n_mfcc=n_mfcc,
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        #hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2
        ) 

    return mfc_coefficients

def get_features(waveforms, features, samplerate):

    # initialize counter to track progress
    file_count = 0

    # process each waveform individually to get its MFCCs
    for waveform in waveforms:
        mfccs = feature_mfcc(waveform, sample_rate)
        features.append(mfccs)
        file_count += 1
        # print progress 
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')
    
    # return all features from list of waveforms
    return features

def get_waveforms(file):
    
    # load an individual sample audio file
    # read the full 3 seconds of the file, cut off the first 0.5s of silence; native sample rate = 48k
    # don't need to store the sample rate that librosa.load returns
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)
    
    # make sure waveform vectors are homogenous by defining explicitly
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform
    
    # return a single file's waveform                                      
    return waveform_homo
    
# RAVDESS dataset emotions
# shift emotions left to be 0 indexed for PyTorch
emotions_dict ={
 '''
    '0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
    '7':'disgust'  '''

   
    '0':'neutral',
    '1':'calm',
    '2':'happy',
    '3':'sad',
    '4':'angry',
    '5':'fearful',
    

}

# Additional attributes from RAVDESS to play with
emotion_attributes = {
    '01': 'normal',
    '02': 'strong'
}

# %%
# path to data for glob
data_path = 'ravadessspeechsong'

##'RAVDESS dataset/Actor_*/*.wav'
dir_list = os.listdir(data_path)
dir_list.sort()
dir_list
# Out:
# ['.ipynb_checkpoints',
#  'Actor_01',
#  'Actor_02',
#  'Actor_03',
#  'Actor_04',
#  'Actor_05',
#  'Actor_06',
#  'Actor_07',
#  'Actor_08',
#  'Actor_09',
#  'Actor_10',
#  'Actor_11',
#  'Actor_12',
#  'Actor_13',
#  'Actor_14',
#  'Actor_15',
#  'Actor_16',
#  'Actor_17',
#  'Actor_18',
#  'Actor_19',
#  'Actor_20',
#  'Actor_21',
#  'Actor_22',
#  'Actor_23',
#  'Actor_24']

# %%
def load_data():
  # features and labels
  emotions = []
  # raw waveforms to augment later
  waveforms = []
  # extra labels
  intensities, genders = [],[]
  # progress counter
  file_count = 0
  for i in dir_list:
    #print(i)
    file_name = os.listdir(data_path + '/' +i+'/')
    for file in file_name:
     # print(file)
      #print(file_name)
      if file =='.ipynb_checkpoints' :continue    
      file=data_path + '/' +i+'/'+file
      nm = file.split('.')[0].split('-')
      # get emotion label from the sample's file
      emotion = int(nm[2])
      #  move surprise to 0 for cleaner behaviour with PyTorch/0-indexing
      if emotion == 1:  emotion = 0
      if emotion == 2:  emotion = 1
      if emotion == 3:  emotion = 2
      if emotion == 4:  emotion = 3
      if emotion == 5:  emotion = 4
      if emotion == 6:  emotion = 5
      if emotion == 7:  continue
      if emotion == 8:  continue      # surprise is now at 0 index; other emotion indeces unchanged

      # can convert emotion label to emotion string if desired, but
      # training on number is better; better convert to emotion string after predictions are ready
      # emotion = emotions_dict[str(emotion)]
            
      # get other labels we might want
      #intensity = emotion_attributes[int(nm[3])]
      if nm[3] == '01':
            intensity = 0
      else:
            intensity = 1
      # even actors are female, odd are male
      if (int((file.split("-")[6]).split(".")[0]))%2==0: 
          gender = 'female' 
      else: 
          gender = 'male'
                
      # get waveform from the sample
      waveform = get_waveforms(file)
            
      # store waveforms and labels
      waveforms.append(waveform)
      emotions.append(emotion)
      intensities.append(intensity) # store intensity in case we wish to predict
      genders.append(gender) # store gender in case we wish to predict 
            
      file_count += 1
      # keep track of data loader's progress
      print('\r'+f' Processed {file_count}/{1440} audio samples',end='')
 

  return waveforms, emotions, intensities, genders

# %%
# load data 
# init explicitly to prevent data leakage from past sessions, since load_data() appends
waveforms, emotions, intensities, genders = [],[],[],[]
waveforms, emotions, intensities, genders = load_data()
# Out:
#  Processed 2068/1440 audio samples

# %%
print(f'Waveforms set: {len(waveforms)} samples')
# we have 1440 waveforms but we need to know their length too; should be 3 sec * 48k = 144k
print(f'Waveform signal length: {len(waveforms[0])}')
print(f'Emotions set: {len(emotions)} sample labels')
# Out:
# Waveforms set: 2068 samples
# Waveform signal length: 144000
# Emotions set: 2068 sample labels

# %%
# create storage for train, validation, test sets and their indices
train_set,valid_set,test_set = [],[],[]
X_train,X_valid,X_test = [],[],[]
y_train,y_valid,y_test = [],[],[]

# convert waveforms to array for processing
waveforms = np.array(waveforms)

# process each emotion separately to make sure we builf balanced train/valid/test sets 
for emotion_num in range(len(emotions_dict)):
        
    # find all indices of a single unique emotion
    emotion_indices = [index for index, emotion in enumerate(emotions) if emotion==emotion_num]

    # seed for reproducibility 
    np.random.seed(69)
    # shuffle indicies 
    emotion_indices = np.random.permutation(emotion_indices)

    # store dim (length) of the emotion list to make indices
    dim = len(emotion_indices)

    # store indices of training, validation and test sets in 80/10/10 proportion
    # train set is first 80%
    train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
    valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
    test_indices = emotion_indices[int(0.9*dim):]

    # create train waveforms/labels sets
    X_train.append(waveforms[train_indices,:])
    y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
    X_valid.append(waveforms[valid_indices,:])
    y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
    X_test.append(waveforms[test_indices,:])
    y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets 
    train_set.append(train_indices)
    valid_set.append(valid_indices)
    test_set.append(test_indices)

# concatenate, in order, all waveforms back into one array 
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array 
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

# make sure train, validation, test sets have no overlap/are unique
# get all unique indices across all sets and how many times each index appears (count)
uniques, count = np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)

# if each index appears just once, and we have 1440 such unique indices, then all sets are unique
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# Training waveforms:(1650, 144000), y_train:(1650,)
# Validation waveforms:(209, 144000), y_valid:(209,)
# Test waveforms:(209, 144000), y_test:(209,)
#
# Sets are unique: 2068 samples out of 2068 are unique

# %%
# initialize feature arrays
# We extract MFCC features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features 
features_train = get_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = get_features(X_valid, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features 
features_test = get_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'Features (MFC coefficient matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
#  Processed 1650/1650 waveforms
#
# Validation waveforms:
#  Processed 209/209 waveforms
#
# Test waveforms:
#  Processed 209/209 waveforms
#
# Features set: 2068 total, 1650 train, 209 validation, 209 test samples
# Features (MFC coefficient matrix) shape: 40 mel frequency coefficients x 282 time steps

# %%
def awgn_augmentation(waveform, multiples=2, bits=16, snr_min=15, snr_max=30): 
    
    # get length of waveform (should be 3*48k = 144k)
    wave_len = len(waveform)
    
    # Generate normally distributed (Gaussian) noises
    # one for each waveform and multiple (i.e. wave_len*multiples noises)
    noise = np.random.normal(size=(multiples, wave_len))
    
    # Normalize waveform and noise
    norm_constant = 2.0**(bits-1)
    norm_wave = waveform / norm_constant
    norm_noise = noise / norm_constant
    
    # Compute power of waveform and power of noise
    signal_power = np.sum(norm_wave ** 2) / wave_len
    noise_power = np.sum(norm_noise ** 2, axis=1) / wave_len
    
    # Choose random SNR in decibels in range [15,30]
    snr = np.random.randint(snr_min, snr_max)
    
    # Apply whitening transformation: make the Gaussian noise into Gaussian white noise
    # Compute the covariance matrix used to whiten each noise 
    # actual SNR = signal/noise (power)
    # actual noise power = 10**(-snr/10)
    covariance = np.sqrt((signal_power / noise_power) * 10 ** (- snr / 10))
    # Get covariance matrix with dim: (144000, 2) so we can transform 2 noises: dim (2, 144000)
    covariance = np.ones((wave_len, multiples)) * covariance

    # Since covariance and noise are arrays, * is the haddamard product 
    # Take Haddamard product of covariance and noise to generate white noise
    multiple_augmented_waveforms = waveform + covariance.T * noise
    
    return multiple_augmented_waveforms
def augment_waveforms(waveforms, features, emotions, multiples):
    # keep track of how many waveforms we've processed so we can add correct emotion label in the same order
    emotion_count = 0
    # keep track of how many augmented samples we've added
    added_count = 0
    # convert emotion array to list for more efficient appending
    emotions = emotions.tolist()

    for waveform in waveforms:

        # Generate 2 augmented multiples of the dataset, i.e. 1440 native + 1440*2 noisy = 4320 samples total
        augmented_waveforms = awgn_augmentation(waveform, multiples=multiples)

        # compute spectrogram for each of 2 augmented waveforms
        for augmented_waveform in augmented_waveforms:

            # Compute MFCCs over augmented waveforms
            augmented_mfcc = feature_mfcc(augmented_waveform, sample_rate=sample_rate)

            # append the augmented spectrogram to the rest of the native data
            features.append(augmented_mfcc)
            emotions.append(emotions[emotion_count])

            # keep track of new augmented samples
            added_count += 1

            # check progress
            print('\r'+f'Processed {emotion_count + 1}/{len(waveforms)} waveforms for {added_count}/{len(waveforms)*multiples} new augmented samples',end='')

        # keep track of the emotion labels to append in order
        emotion_count += 1
        
        # store augmented waveforms to check their shape
        augmented_waveforms_temp.append(augmented_waveforms)
    
    return features, emotions

# %%
# store augmented waveforms to verify their shape and random-ness
augmented_waveforms_temp = []

# specify multiples of our dataset to add as augmented data
multiples = 2

print('Train waveforms:') # augment waveforms of training set
features_train , y_train = augment_waveforms(X_train, features_train, y_train, multiples)


# Check new shape of extracted features and data:
print(f'\n\nNative + Augmented Features set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'{len(y_train)} training sample labels, {len(y_valid)} validation sample labels, {len(y_test)} test sample labels')
print(f'Features (MFCC matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
# Processed 1650/1650 waveforms for 3300/3300 new augmented samples
#
# Native + Augmented Features set: 5368 total, 4950 train, 209 validation, 209 test samples
# 4950 training sample labels, 209 validation sample labels, 209 test sample labels
# Features (MFCC matrix) shape: 40 mel frequency coefficients x 282 time steps

# %%
# need to make dummy input channel for CNN input feature tensor
X_train = np.expand_dims(features_train,1)
X_valid = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test,1)

# convert emotion labels from list back to numpy arrays for PyTorch to work with 
y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)

# confiorm that we have tensor-ready 4D data array
# should print (batch, channel, width, height) == (4320, 1, 128, 282) when multiples==2
print(f'Shape of 4D feature array for input tensor: {X_train.shape} train, {X_valid.shape} validation, {X_test.shape} test')
print(f'Shape of emotion labels: {y_train.shape} train, {y_valid.shape} validation, {y_test.shape} test')
# Out:
# Shape of 4D feature array for input tensor: (4950, 1, 40, 282) train, (209, 1, 40, 282) validation, (209, 1, 40, 282) test
# Shape of emotion labels: (4950,) train, (209,) validation, (209,) test

# %%
# free up some RAM - no longer need full feature set or any waveforms 
del features_train, features_valid, features_test, waveforms, augmented_waveforms_temp

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#### Scale the training data ####
# store shape so we can transform it back 
N,C,H,W = X_train.shape
# Reshape to 1D because StandardScaler operates on a 1D array
# tell numpy to infer shape of 1D array with '-1' argument
X_train = np.reshape(X_train, (N,-1)) 
X_train = scaler.fit_transform(X_train)
# Transform back to NxCxHxW 4D tensor format
X_train = np.reshape(X_train, (N,C,H,W))

##### Scale the validation set ####
N,C,H,W = X_valid.shape
X_valid = np.reshape(X_valid, (N,-1))
X_valid = scaler.transform(X_valid)
X_valid = np.reshape(X_valid, (N,C,H,W))

#### Scale the test set ####
N,C,H,W = X_test.shape
X_test = np.reshape(X_test, (N,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, (N,C,H,W))

# check shape of each set again
print(f'X_train scaled:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid scaled:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test scaled:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train scaled:(4950, 1, 40, 282), y_train:(4950,)
# X_valid scaled:(209, 1, 40, 282), y_valid:(209,)
# X_test scaled:(209, 1, 40, 282), y_test:(209,)

# %%
###### SAVE #########
# choose save file name 
filename = 'features+labels.npy'

# open file in write mode and write data
with open(filename, 'wb') as f:
    np.save(f, X_train)
    np.save(f, X_valid)
    np.save(f, X_test)
    np.save(f, y_train)
    np.save(f, y_valid)
    np.save(f, y_test)

print(f'Features and labels saved to {filename}')
# Out:
# Features and labels saved to features+labels.npy

# %%
##### LOAD #########
# choose load file name 
filename = 'features+labels.npy'

# open file in read mode and read data 
with open(filename, 'rb') as f:
    X_train = np.load(f)
    X_valid = np.load(f)
    X_test = np.load(f)
    y_train = np.load(f)
    y_valid = np.load(f)
    y_test = np.load(f)

# Check that we've recovered the right data
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train:(4950, 1, 40, 282), y_train:(4950,)
# X_valid:(209, 1, 40, 282), y_valid:(209,)
# X_test:(209, 1, 40, 282), y_test:(209,)

# %%
#change nn.sequential to take dict to make more readable 

class parallel_all_you_want(nn.Module):
    # Define all layers present in the network
    def __init__(self,num_emotions):
        super().__init__() 
        
        ################ TRANSFORMER BLOCK #############################
        # maxpool the input feature map/tensor to the transformer 
        # a rectangular kernel worked better here for the rectangular input spectrogram feature map/tensor
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1,4], stride=[1,4])
        
        # define single transformer encoder layer
        # self-attention + feedforward network from "Attention is All You Need" paper
        # 4 multi-head self-attention layers each with 40-->512--->40 feedforward network
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40, # input feature (frequency) dim after maxpooling 40*282 -> 40*70 (MFC*time)
            nhead=2, # 4 self-attention layers in each multi-head self-attention layer in each encoder block
            dim_feedforward=384, # 2 linear layers in each encoder block's feedforward network: dim 40-->512--->40
            dropout=0.4, 
            activation='relu' # ReLU: avoid saturation/tame gradient/reduce compute time
        )
        
        # I'm using 4 instead of the 6 identical stacked encoder layrs used in Attention is All You Need paper
        # Complete transformer block contains 4 full transformer encoder layers (each w/ multihead self-attention+feedforward)
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=2)
        
        ############### 1ST PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock1 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        ############### 2ND PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock2 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )

        ################# FINAL LINEAR BLOCK ####################
        # Linear softmax layer to take final concatenated embedding tensor 
        #    from parallel 2D convolutional and transformer blocks, output 8 logits 
        # Each full convolution block outputs (64*1*8) embedding flattened to dim 512 1D array 
        # Full transformer block outputs 40*70 feature map, which we time-avg to dim 40 1D array
        # 512*2+40 == 1064 input features --> 8 output emotions 
        self.fc1_linear = nn.Linear(384*2+296,num_emotions) 
        
        ### Softmax layer for the 8 output logits from final FC linear layer 
        self.softmax_out = nn.Softmax(dim=1) # dim==1 is the freq embedding
        
    # define one complete parallel fwd pass of input feature tensor thru 2*conv+1*transformer blocks
    def forward(self,x):
        
        ############ 1st parallel Conv2D block: 4 Convolutional layers ############################
        # create final feature embedding from 1st convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding1 = self.conv2Dblock1(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding1 = torch.flatten(conv2d_embedding1, start_dim=1) 
        
        ############ 2nd parallel Conv2D block: 4 Convolutional layers #############################
        # create final feature embedding from 2nd convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding2 = self.conv2Dblock2(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding2 = torch.flatten(conv2d_embedding2, start_dim=1) 
        
         
        ########## 4-encoder-layer Transformer block w/ 40-->512-->40 feedfwd network ##############
        # maxpool input feature map: 1*40*282 w/ 1*4 kernel --> 1*40*70
        x_maxpool = self.transformer_maxpool(x)

        # remove channel dim: 1*40*70 --> 40*70
        x_maxpool_reduced = torch.squeeze(x_maxpool,1)
        
        # convert maxpooled feature map format: batch * freq * time ---> time * batch * freq format
        # because transformer encoder layer requires tensor in format: time * batch * embedding (freq)
        x = x_maxpool_reduced.permute(2,0,1) 
        
        # finally, pass reduced input feature map x into transformer encoder layers
        transformer_output = self.transformer_encoder(x)
        
        # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
        # transformer outputs 2x40 (MFCC embedding*time) feature map, take mean of columns i.e. take time average
        transformer_embedding = torch.mean(transformer_output, dim=0) # dim 40x70 --> 40
        
        ############# concatenate freq embeddings from convolutional and transformer blocks ######
        # concatenate embedding tensors output by parallel 2*conv and 1*transformer blocks
        complete_embedding = torch.cat([conv2d_embedding1, conv2d_embedding2,transformer_embedding], dim=1)  

        ######### final FC linear layer, need logits for loss #########################
        output_logits = self.fc1_linear(complete_embedding)  
        
        ######### Final Softmax layer: use logits from FC linear, get softmax for prediction ######
        output_softmax = self.softmax_out(output_logits)
        
        # need output logits to compute cross entropy loss, need softmax probabilities to predict class
        return output_logits, output_softmax

# %%
from torchsummary import summary

# need device to instantiate model
device = 'cuda'

# instantiate model for 8 emotions and move to GPU 
model = parallel_all_you_want(len(emotions_dict)).to(device)

# include input feature map dims in call to summary()
#summary(model,(1,1,1))

# %%
# define loss function; CrossEntropyLoss() fairly standard for multiclass problems 
def criterion(predictions, targets): 
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# %%
# define function to create a single step of the training phase
def make_train_step(model, criterion, optimizer):
    
    # define the training step of the training phase
    def train_step(X,Y):
        
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        
        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y) 
        
        # compute gradients for the optimizer to use 
        loss.backward()
        
        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()
        
        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad() 
        
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,criterion):
    def validate(X,Y):
        
        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase: 
        with torch.no_grad(): 
            
            # set model to validation phase i.e. turn off dropout and batchnorm layers 
            model.eval()
      
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            
            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits,Y)
            
        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint(): 
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint

def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
# get training set size to calculate # iterations and minibatch indices
train_size = X_train.shape[0]

# pick minibatch size (of 32... always)
minibatch = 32

# set device to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'{device} selected')

# instantiate model and move to GPU for training
model = parallel_all_you_want(num_emotions=len(emotions_dict)).to(device) 
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )

# encountered bugs in google colab only, unless I explicitly defined optimizer in this cell...
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# instantiate the checkpoint save function
save_checkpoint = make_save_checkpoint()

# instantiate the training step function 
train_step = make_train_step(model, criterion, optimizer=optimizer)

# instantiate the validation loop function
validate = make_validate_fnc(model,criterion)

# instantiate lists to hold scalar performance metrics to plot later
train_losses=[]
valid_losses = []

# create training loop for one complete epoch (entire training set)
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):

    for epoch in range(num_epochs):
        
        # set model to train phase
        model.train()         
        
        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size) 
        
        # shuffle the training set for each epoch:
        X_train = X_train[train_indices,:,:,:] 
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate 
        epoch_acc = 0 
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)
        
        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):
            
            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch 
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size) 
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start 
            
            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:] 
            # get training minibatch labels 
            Y = Y_train[batch_start:batch_end] 

            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float() 
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor,Y_tensor) 
            
            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size
            
            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}',end='')
        
        # create tensors from validation set
        X_valid_tensor = torch.tensor(X_valid,device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor,Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
                  
        # Save checkpoint of the model
        #checkpoint_filename = '/content/gdrive/My Drive/DL/models/checkpoints/parallel_all_you_wantFINAL-{:03d}.pkl'.format(epoch)
        checkpoint_filename = 'checkpoint/parallel_all_you_wantFINAL-{:03d}.pkl'.format(epoch)
        save_checkpoint(optimizer, model, epoch, checkpoint_filename)
        
        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')
# Out:
# cuda selected
# Number of trainable params:  129158

# %%
# choose number of epochs higher than reasonable so we can manually stop training 
num_epochs = 350

# train it!
train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
# Out:
# Epoch 0: iteration 153/154
# Epoch 0 --- loss:2.401, Epoch accuracy:29.74%, Validation loss:1.611, Validation accuracy:36.36%
# Epoch 1: iteration 153/154
# Epoch 1 --- loss:1.351, Epoch accuracy:43.11%, Validation loss:1.395, Validation accuracy:46.89%
# Epoch 2: iteration 153/154
# Epoch 2 --- loss:1.214, Epoch accuracy:49.45%, Validation loss:1.479, Validation accuracy:44.98%
# Epoch 3: iteration 153/154
# Epoch 3 --- loss:1.120, Epoch accuracy:54.14%, Validation loss:1.324, Validation accuracy:49.28%
# Epoch 4: iteration 153/154
# Epoch 4 --- loss:1.023, Epoch accuracy:59.11%, Validation loss:1.091, Validation accuracy:66.03%
# Epoch 5: iteration 153/154
# Epoch 5 --- loss:0.974, Epoch accuracy:61.43%, Validation loss:1.083, Validation accuracy:64.11%
# Epoch 6: iteration 153/154
# Epoch 6 --- loss:0.906, Epoch accuracy:64.16%, Validation loss:1.108, Validation accuracy:61.24%
# Epoch 7: iteration 153/154
# Epoch 7 --- loss:0.868, Epoch accuracy:65.54%, Validation loss:0.960, Validation accuracy:66.03%
# Epoch 8: iteration 153/154
# Epoch 8 --- loss:0.825, Epoch accuracy:67.98%, Validation loss:1.066, Validation accuracy:62.68%
# Epoch 9: iteration 153/154
# Epoch 9 --- loss:0.779, Epoch accuracy:69.68%, Validation loss:1.006, Validation accuracy:63.64%
# Epoch 10: iteration 153/154
# Epoch 10 --- loss:0.763, Epoch accuracy:70.32%, Validation loss:0.829, Validation accuracy:71.29%
# Epoch 11: iteration 153/154
# Epoch 11 --- loss:0.714, Epoch accuracy:72.18%, Validation loss:1.026, Validation accuracy:62.68%
# Epoch 12: iteration 153/154
# Epoch 12 --- loss:0.679, Epoch accuracy:73.15%, Validation loss:0.903, Validation accuracy:67.46%
# Epoch 13: iteration 153/154
# Epoch 13 --- loss:0.644, Epoch accuracy:74.83%, Validation loss:0.883, Validation accuracy:69.38%
# Epoch 14: iteration 153/154
# Epoch 14 --- loss:0.622, Epoch accuracy:75.41%, Validation loss:0.802, Validation accuracy:71.29%
# Epoch 15: iteration 153/154
# Epoch 15 --- loss:0.593, Epoch accuracy:77.27%, Validation loss:0.930, Validation accuracy:70.33%
# Epoch 16: iteration 153/154
# Epoch 16 --- loss:0.565, Epoch accuracy:78.04%, Validation loss:0.874, Validation accuracy:66.51%
# Epoch 17: iteration 153/154
# Epoch 17 --- loss:0.557, Epoch accuracy:77.62%, Validation loss:0.771, Validation accuracy:73.68%
# Epoch 18: iteration 153/154
# Epoch 18 --- loss:0.529, Epoch accuracy:79.54%, Validation loss:0.756, Validation accuracy:76.08%
# Epoch 19: iteration 153/154
# Epoch 19 --- loss:0.511, Epoch accuracy:79.70%, Validation loss:0.802, Validation accuracy:75.12%
# Epoch 20: iteration 153/154
# Epoch 20 --- loss:0.503, Epoch accuracy:80.20%, Validation loss:0.768, Validation accuracy:74.16%
# Epoch 21: iteration 153/154
# Epoch 21 --- loss:0.462, Epoch accuracy:81.72%, Validation loss:0.793, Validation accuracy:72.73%
# Epoch 22: iteration 153/154
# Epoch 22 --- loss:0.437, Epoch accuracy:82.89%, Validation loss:0.741, Validation accuracy:79.43%
# Epoch 23: iteration 153/154
# Epoch 23 --- loss:0.425, Epoch accuracy:83.29%, Validation loss:0.698, Validation accuracy:77.03%
# Epoch 24: iteration 153/154
# Epoch 24 --- loss:0.416, Epoch accuracy:84.18%, Validation loss:0.744, Validation accuracy:76.56%
# Epoch 25: iteration 153/154
# Epoch 25 --- loss:0.388, Epoch accuracy:84.93%, Validation loss:0.735, Validation accuracy:77.03%
# Epoch 26: iteration 153/154
# Epoch 26 --- loss:0.396, Epoch accuracy:84.14%, Validation loss:0.780, Validation accuracy:76.08%
# Epoch 27: iteration 153/154
# Epoch 27 --- loss:0.369, Epoch accuracy:85.52%, Validation loss:0.827, Validation accuracy:74.64%
# Epoch 28: iteration 153/154
# Epoch 28 --- loss:0.351, Epoch accuracy:86.46%, Validation loss:0.710, Validation accuracy:76.56%
# Epoch 29: iteration 153/154
# Epoch 29 --- loss:0.328, Epoch accuracy:87.37%, Validation loss:0.745, Validation accuracy:79.43%
# Epoch 30: iteration 153/154
# Epoch 30 --- loss:0.325, Epoch accuracy:87.72%, Validation loss:0.772, Validation accuracy:76.08%
# Epoch 31: iteration 153/154
# Epoch 31 --- loss:0.324, Epoch accuracy:87.47%, Validation loss:0.696, Validation accuracy:80.86%
# Epoch 32: iteration 153/154
# Epoch 32 --- loss:0.294, Epoch accuracy:88.26%, Validation loss:0.735, Validation accuracy:73.68%
# Epoch 33: iteration 153/154
# Epoch 33 --- loss:0.301, Epoch accuracy:88.34%, Validation loss:0.712, Validation accuracy:80.38%
# Epoch 34: iteration 153/154
# Epoch 34 --- loss:0.290, Epoch accuracy:88.48%, Validation loss:0.705, Validation accuracy:80.38%
# Epoch 35: iteration 153/154
# Epoch 35 --- loss:0.284, Epoch accuracy:88.55%, Validation loss:0.760, Validation accuracy:77.51%
# Epoch 36: iteration 153/154
# Epoch 36 --- loss:0.258, Epoch accuracy:90.28%, Validation loss:0.741, Validation accuracy:77.03%
# Epoch 37: iteration 153/154
# Epoch 37 --- loss:0.265, Epoch accuracy:89.64%, Validation loss:0.708, Validation accuracy:78.95%
# Epoch 38: iteration 153/154
# Epoch 38 --- loss:0.252, Epoch accuracy:90.26%, Validation loss:0.725, Validation accuracy:76.56%
# Epoch 39: iteration 153/154
# Epoch 39 --- loss:0.225, Epoch accuracy:91.54%, Validation loss:0.808, Validation accuracy:74.16%
# Epoch 40: iteration 153/154
# Epoch 40 --- loss:0.239, Epoch accuracy:91.03%, Validation loss:0.715, Validation accuracy:79.43%
# Epoch 41: iteration 153/154
# Epoch 41 --- loss:0.217, Epoch accuracy:91.94%, Validation loss:0.781, Validation accuracy:77.99%
# Epoch 42: iteration 153/154
# Epoch 42 --- loss:0.211, Epoch accuracy:91.58%, Validation loss:0.680, Validation accuracy:79.43%
# Epoch 43: iteration 153/154
# Epoch 43 --- loss:0.216, Epoch accuracy:91.66%, Validation loss:0.733, Validation accuracy:80.86%
# Epoch 44: iteration 153/154
# Epoch 44 --- loss:0.205, Epoch accuracy:92.40%, Validation loss:0.832, Validation accuracy:77.51%
# Epoch 45: iteration 153/154
# Epoch 45 --- loss:0.203, Epoch accuracy:92.04%, Validation loss:0.758, Validation accuracy:79.90%
# Epoch 46: iteration 153/154
# Epoch 46 --- loss:0.200, Epoch accuracy:92.30%, Validation loss:0.697, Validation accuracy:78.47%
# Epoch 47: iteration 153/154
# Epoch 47 --- loss:0.168, Epoch accuracy:94.06%, Validation loss:0.675, Validation accuracy:80.38%
# Epoch 48: iteration 153/154
# Epoch 48 --- loss:0.181, Epoch accuracy:92.91%, Validation loss:0.690, Validation accuracy:78.47%
# Epoch 49: iteration 153/154
# Epoch 49 --- loss:0.176, Epoch accuracy:93.13%, Validation loss:0.732, Validation accuracy:78.47%
# Epoch 50: iteration 153/154
# Epoch 50 --- loss:0.165, Epoch accuracy:93.78%, Validation loss:0.731, Validation accuracy:81.82%
# Epoch 51: iteration 153/154
# Epoch 51 --- loss:0.158, Epoch accuracy:94.20%, Validation loss:0.686, Validation accuracy:81.34%
# Epoch 52: iteration 153/154
# Epoch 52 --- loss:0.170, Epoch accuracy:93.31%, Validation loss:0.712, Validation accuracy:79.43%
# Epoch 53: iteration 153/154
# Epoch 53 --- loss:0.159, Epoch accuracy:93.94%, Validation loss:0.722, Validation accuracy:81.34%
# Epoch 54: iteration 153/154
# Epoch 54 --- loss:0.148, Epoch accuracy:94.36%, Validation loss:0.790, Validation accuracy:79.90%
# Epoch 55: iteration 153/154
# Epoch 55 --- loss:0.149, Epoch accuracy:94.30%, Validation loss:0.805, Validation accuracy:80.86%
# Epoch 56: iteration 153/154
# Epoch 56 --- loss:0.146, Epoch accuracy:94.22%, Validation loss:0.777, Validation accuracy:77.51%
# Epoch 57: iteration 153/154
# Epoch 57 --- loss:0.137, Epoch accuracy:94.87%, Validation loss:0.775, Validation accuracy:77.99%
# Epoch 58: iteration 153/154
# Epoch 58 --- loss:0.141, Epoch accuracy:94.28%, Validation loss:0.800, Validation accuracy:81.34%
# Epoch 59: iteration 153/154
# Epoch 59 --- loss:0.128, Epoch accuracy:95.31%, Validation loss:0.703, Validation accuracy:79.90%
# Epoch 60: iteration 153/154
# Epoch 60 --- loss:0.136, Epoch accuracy:94.85%, Validation loss:0.740, Validation accuracy:80.38%
# Epoch 61: iteration 153/154
# Epoch 61 --- loss:0.126, Epoch accuracy:95.25%, Validation loss:0.718, Validation accuracy:82.30%
# Epoch 62: iteration 153/154
# Epoch 62 --- loss:0.125, Epoch accuracy:95.11%, Validation loss:0.701, Validation accuracy:77.51%
# Epoch 63: iteration 153/154
# Epoch 63 --- loss:0.140, Epoch accuracy:94.16%, Validation loss:0.815, Validation accuracy:79.43%
# Epoch 64: iteration 153/154
# Epoch 64 --- loss:0.122, Epoch accuracy:95.47%, Validation loss:0.812, Validation accuracy:79.90%
# Epoch 65: iteration 153/154
# Epoch 65 --- loss:0.122, Epoch accuracy:95.43%, Validation loss:0.851, Validation accuracy:75.60%
# Epoch 66: iteration 153/154
# Epoch 66 --- loss:0.134, Epoch accuracy:95.03%, Validation loss:0.657, Validation accuracy:82.30%
# Epoch 67: iteration 153/154
# Epoch 67 --- loss:0.126, Epoch accuracy:95.11%, Validation loss:0.765, Validation accuracy:79.43%
# Epoch 68: iteration 153/154
# Epoch 68 --- loss:0.116, Epoch accuracy:95.54%, Validation loss:0.901, Validation accuracy:79.43%
# Epoch 69: iteration 153/154
# Epoch 69 --- loss:0.116, Epoch accuracy:95.58%, Validation loss:0.776, Validation accuracy:77.03%
# Epoch 70: iteration 153/154
# Epoch 70 --- loss:0.114, Epoch accuracy:95.74%, Validation loss:0.747, Validation accuracy:81.82%
# Epoch 71: iteration 153/154
# Epoch 71 --- loss:0.111, Epoch accuracy:95.86%, Validation loss:0.792, Validation accuracy:80.38%
# Epoch 72: iteration 153/154
# Epoch 72 --- loss:0.096, Epoch accuracy:96.44%, Validation loss:0.752, Validation accuracy:81.34%
# Epoch 73: iteration 153/154
# Epoch 73 --- loss:0.109, Epoch accuracy:95.68%, Validation loss:0.756, Validation accuracy:82.78%
# Epoch 74: iteration 153/154
# Epoch 74 --- loss:0.102, Epoch accuracy:96.12%, Validation loss:0.854, Validation accuracy:76.08%
# Epoch 75: iteration 153/154
# Epoch 75 --- loss:0.087, Epoch accuracy:96.67%, Validation loss:0.720, Validation accuracy:79.90%
# Epoch 76: iteration 153/154
# Epoch 76 --- loss:0.095, Epoch accuracy:96.57%, Validation loss:0.830, Validation accuracy:80.86%
# Epoch 77: iteration 153/154
# Epoch 77 --- loss:0.103, Epoch accuracy:95.86%, Validation loss:0.641, Validation accuracy:82.78%
# Epoch 78: iteration 153/154
# Epoch 78 --- loss:0.091, Epoch accuracy:96.73%, Validation loss:0.807, Validation accuracy:80.86%
# Epoch 79: iteration 153/154
# Epoch 79 --- loss:0.099, Epoch accuracy:96.28%, Validation loss:0.726, Validation accuracy:80.38%
# Epoch 80: iteration 153/154
# Epoch 80 --- loss:0.109, Epoch accuracy:95.80%, Validation loss:0.765, Validation accuracy:78.47%
# Epoch 81: iteration 153/154
# Epoch 81 --- loss:0.098, Epoch accuracy:96.14%, Validation loss:0.796, Validation accuracy:80.86%
# Epoch 82: iteration 153/154
# Epoch 82 --- loss:0.078, Epoch accuracy:97.05%, Validation loss:0.793, Validation accuracy:80.38%
# Epoch 83: iteration 153/154
# Epoch 83 --- loss:0.071, Epoch accuracy:97.58%, Validation loss:0.767, Validation accuracy:79.43%
# Epoch 84: iteration 153/154
# Epoch 84 --- loss:0.093, Epoch accuracy:96.38%, Validation loss:0.809, Validation accuracy:78.47%
# Epoch 85: iteration 153/154
# Epoch 85 --- loss:0.094, Epoch accuracy:96.36%, Validation loss:0.760, Validation accuracy:81.34%
# Epoch 86: iteration 153/154
# Epoch 86 --- loss:0.075, Epoch accuracy:97.29%, Validation loss:0.723, Validation accuracy:79.90%
# Epoch 87: iteration 153/154
# Epoch 87 --- loss:0.078, Epoch accuracy:96.89%, Validation loss:0.749, Validation accuracy:79.43%
# Epoch 88: iteration 153/154
# Epoch 88 --- loss:0.080, Epoch accuracy:96.87%, Validation loss:0.817, Validation accuracy:79.90%
# Epoch 89: iteration 153/154
# Epoch 89 --- loss:0.081, Epoch accuracy:97.05%, Validation loss:0.688, Validation accuracy:82.30%
# Epoch 90: iteration 153/154
# Epoch 90 --- loss:0.070, Epoch accuracy:97.35%, Validation loss:0.729, Validation accuracy:80.38%
# Epoch 91: iteration 153/154
# Epoch 91 --- loss:0.085, Epoch accuracy:96.91%, Validation loss:0.755, Validation accuracy:79.43%
# Epoch 92: iteration 153/154
# Epoch 92 --- loss:0.072, Epoch accuracy:97.35%, Validation loss:0.850, Validation accuracy:79.43%
# Epoch 93: iteration 153/154
# Epoch 93 --- loss:0.084, Epoch accuracy:96.71%, Validation loss:0.732, Validation accuracy:80.38%
# Epoch 94: iteration 153/154
# Epoch 94 --- loss:0.070, Epoch accuracy:97.47%, Validation loss:0.741, Validation accuracy:81.34%
# Epoch 95: iteration 153/154
# Epoch 95 --- loss:0.080, Epoch accuracy:96.81%, Validation loss:0.839, Validation accuracy:80.86%
# Epoch 96: iteration 153/154
# Epoch 96 --- loss:0.069, Epoch accuracy:97.45%, Validation loss:0.816, Validation accuracy:79.90%
# Epoch 97: iteration 153/154
# Epoch 97 --- loss:0.072, Epoch accuracy:97.23%, Validation loss:0.784, Validation accuracy:78.95%
# Epoch 98: iteration 153/154
# Epoch 98 --- loss:0.095, Epoch accuracy:96.44%, Validation loss:0.762, Validation accuracy:81.82%
# Epoch 99: iteration 153/154
# Epoch 99 --- loss:0.071, Epoch accuracy:97.31%, Validation loss:0.881, Validation accuracy:79.43%
# Epoch 100: iteration 153/154
# Epoch 100 --- loss:0.096, Epoch accuracy:96.16%, Validation loss:0.854, Validation accuracy:77.99%
# Epoch 101: iteration 153/154
# Epoch 101 --- loss:0.074, Epoch accuracy:97.17%, Validation loss:0.768, Validation accuracy:80.38%
# Epoch 102: iteration 153/154
# Epoch 102 --- loss:0.070, Epoch accuracy:97.43%, Validation loss:0.748, Validation accuracy:80.38%
# Epoch 103: iteration 153/154
# Epoch 103 --- loss:0.065, Epoch accuracy:97.49%, Validation loss:0.796, Validation accuracy:83.25%
# Epoch 104: iteration 153/154
# Epoch 104 --- loss:0.065, Epoch accuracy:97.56%, Validation loss:0.740, Validation accuracy:82.30%
# Epoch 105: iteration 153/154
# Epoch 105 --- loss:0.079, Epoch accuracy:96.71%, Validation loss:0.793, Validation accuracy:82.78%
# Epoch 106: iteration 153/154
# Epoch 106 --- loss:0.074, Epoch accuracy:97.33%, Validation loss:0.738, Validation accuracy:83.73%
# Epoch 107: iteration 153/154
# Epoch 107 --- loss:0.062, Epoch accuracy:97.66%, Validation loss:0.792, Validation accuracy:81.82%
# Epoch 108: iteration 153/154
# Epoch 108 --- loss:0.070, Epoch accuracy:97.39%, Validation loss:0.778, Validation accuracy:78.47%
# Epoch 109: iteration 153/154
# Epoch 109 --- loss:0.067, Epoch accuracy:97.70%, Validation loss:0.862, Validation accuracy:80.86%
# Epoch 110: iteration 153/154
# Epoch 110 --- loss:0.057, Epoch accuracy:97.76%, Validation loss:0.756, Validation accuracy:79.90%
# Epoch 111: iteration 153/154
# Epoch 111 --- loss:0.077, Epoch accuracy:96.93%, Validation loss:0.732, Validation accuracy:81.34%
# Epoch 112: iteration 153/154
# Epoch 112 --- loss:0.052, Epoch accuracy:98.12%, Validation loss:0.690, Validation accuracy:82.30%
# Epoch 113: iteration 153/154
# Epoch 113 --- loss:0.049, Epoch accuracy:98.34%, Validation loss:0.750, Validation accuracy:80.38%
# Epoch 114: iteration 153/154
# Epoch 114 --- loss:0.050, Epoch accuracy:98.00%, Validation loss:0.755, Validation accuracy:81.34%
# Epoch 115: iteration 153/154
# Epoch 115 --- loss:0.060, Epoch accuracy:97.60%, Validation loss:0.728, Validation accuracy:79.90%
# Epoch 116: iteration 153/154
# Epoch 116 --- loss:0.062, Epoch accuracy:97.35%, Validation loss:0.750, Validation accuracy:80.86%
# Epoch 117: iteration 153/154
# Epoch 117 --- loss:0.050, Epoch accuracy:98.18%, Validation loss:0.879, Validation accuracy:77.99%
# Epoch 118: iteration 153/154
# Epoch 118 --- loss:0.072, Epoch accuracy:97.19%, Validation loss:0.715, Validation accuracy:82.30%
# Epoch 119: iteration 153/154
# Epoch 119 --- loss:0.069, Epoch accuracy:97.33%, Validation loss:0.929, Validation accuracy:79.43%
# Epoch 120: iteration 153/154
# Epoch 120 --- loss:0.066, Epoch accuracy:97.49%, Validation loss:0.788, Validation accuracy:80.38%
# Epoch 121: iteration 153/154
# Epoch 121 --- loss:0.058, Epoch accuracy:97.98%, Validation loss:0.861, Validation accuracy:80.38%
# Epoch 122: iteration 153/154
# Epoch 122 --- loss:0.060, Epoch accuracy:97.74%, Validation loss:0.777, Validation accuracy:80.86%
# Epoch 123: iteration 153/154
# Epoch 123 --- loss:0.059, Epoch accuracy:97.88%, Validation loss:0.749, Validation accuracy:81.82%
# Epoch 124: iteration 153/154
# Epoch 124 --- loss:0.074, Epoch accuracy:97.35%, Validation loss:0.818, Validation accuracy:77.99%
# Epoch 125: iteration 153/154
# Epoch 125 --- loss:0.066, Epoch accuracy:97.29%, Validation loss:0.743, Validation accuracy:81.82%
# Epoch 126: iteration 153/154
# Epoch 126 --- loss:0.048, Epoch accuracy:98.16%, Validation loss:0.791, Validation accuracy:82.30%
# Epoch 127: iteration 153/154
# Epoch 127 --- loss:0.061, Epoch accuracy:97.49%, Validation loss:0.712, Validation accuracy:79.43%
# Epoch 128: iteration 153/154
# Epoch 128 --- loss:0.070, Epoch accuracy:97.62%, Validation loss:0.787, Validation accuracy:78.47%
# Epoch 129: iteration 153/154
# Epoch 129 --- loss:0.053, Epoch accuracy:97.90%, Validation loss:0.783, Validation accuracy:79.90%
# Epoch 130: iteration 153/154
# Epoch 130 --- loss:0.052, Epoch accuracy:98.00%, Validation loss:0.741, Validation accuracy:78.95%
# Epoch 131: iteration 153/154
# Epoch 131 --- loss:0.067, Epoch accuracy:97.19%, Validation loss:0.716, Validation accuracy:80.86%
# Epoch 132: iteration 153/154
# Epoch 132 --- loss:0.047, Epoch accuracy:98.26%, Validation loss:0.848, Validation accuracy:78.47%
# Epoch 133: iteration 153/154
# Epoch 133 --- loss:0.062, Epoch accuracy:97.62%, Validation loss:0.856, Validation accuracy:81.34%
# Epoch 134: iteration 153/154
# Epoch 134 --- loss:0.063, Epoch accuracy:97.70%, Validation loss:0.768, Validation accuracy:81.82%
# Epoch 135: iteration 153/154
# Epoch 135 --- loss:0.063, Epoch accuracy:97.47%, Validation loss:0.635, Validation accuracy:78.95%
# Epoch 136: iteration 153/154
# Epoch 136 --- loss:0.057, Epoch accuracy:97.80%, Validation loss:0.725, Validation accuracy:81.82%
# Epoch 137: iteration 153/154
# Epoch 137 --- loss:0.062, Epoch accuracy:97.74%, Validation loss:0.757, Validation accuracy:82.78%
# Epoch 138: iteration 153/154
# Epoch 138 --- loss:0.048, Epoch accuracy:98.10%, Validation loss:0.689, Validation accuracy:81.82%
# Epoch 139: iteration 153/154
# Epoch 139 --- loss:0.047, Epoch accuracy:98.26%, Validation loss:1.212, Validation accuracy:76.56%
# Epoch 140: iteration 153/154
# Epoch 140 --- loss:0.054, Epoch accuracy:98.04%, Validation loss:0.692, Validation accuracy:79.90%
# Epoch 141: iteration 153/154
# Epoch 141 --- loss:0.051, Epoch accuracy:97.98%, Validation loss:0.782, Validation accuracy:80.38%
# Epoch 142: iteration 153/154
# Epoch 142 --- loss:0.057, Epoch accuracy:97.82%, Validation loss:0.880, Validation accuracy:80.38%
# Epoch 143: iteration 153/154
# Epoch 143 --- loss:0.060, Epoch accuracy:97.60%, Validation loss:0.780, Validation accuracy:80.86%
# Epoch 144: iteration 153/154
# Epoch 144 --- loss:0.069, Epoch accuracy:97.35%, Validation loss:0.734, Validation accuracy:82.78%
# Epoch 145: iteration 153/154
# Epoch 145 --- loss:0.057, Epoch accuracy:97.86%, Validation loss:0.774, Validation accuracy:79.90%
# Epoch 146: iteration 153/154
# Epoch 146 --- loss:0.051, Epoch accuracy:97.92%, Validation loss:0.905, Validation accuracy:79.43%
# Epoch 147: iteration 153/154
# Epoch 147 --- loss:0.059, Epoch accuracy:97.80%, Validation loss:0.758, Validation accuracy:80.86%
# Epoch 148: iteration 153/154
# Epoch 148 --- loss:0.060, Epoch accuracy:97.72%, Validation loss:0.745, Validation accuracy:80.86%
# Epoch 149: iteration 153/154
# Epoch 149 --- loss:0.070, Epoch accuracy:97.21%, Validation loss:0.818, Validation accuracy:80.86%
# Epoch 150: iteration 153/154
# Epoch 150 --- loss:0.071, Epoch accuracy:97.27%, Validation loss:0.700, Validation accuracy:83.25%
# Epoch 151: iteration 153/154
# Epoch 151 --- loss:0.064, Epoch accuracy:97.41%, Validation loss:0.800, Validation accuracy:81.34%
# Epoch 152: iteration 153/154
# Epoch 152 --- loss:0.072, Epoch accuracy:97.15%, Validation loss:0.787, Validation accuracy:79.90%
# Epoch 153: iteration 153/154
# Epoch 153 --- loss:0.047, Epoch accuracy:98.34%, Validation loss:0.874, Validation accuracy:78.95%
# Epoch 154: iteration 153/154
# Epoch 154 --- loss:0.060, Epoch accuracy:97.54%, Validation loss:0.759, Validation accuracy:81.82%
# Epoch 155: iteration 153/154
# Epoch 155 --- loss:0.050, Epoch accuracy:98.22%, Validation loss:0.752, Validation accuracy:85.17%
# Epoch 156: iteration 153/154
# Epoch 156 --- loss:0.052, Epoch accuracy:98.08%, Validation loss:0.770, Validation accuracy:80.86%
# Epoch 157: iteration 153/154
# Epoch 157 --- loss:0.051, Epoch accuracy:97.94%, Validation loss:1.030, Validation accuracy:77.99%
# Epoch 158: iteration 153/154
# Epoch 158 --- loss:0.060, Epoch accuracy:97.60%, Validation loss:0.890, Validation accuracy:78.47%
# Epoch 159: iteration 153/154
# Epoch 159 --- loss:0.048, Epoch accuracy:98.14%, Validation loss:0.675, Validation accuracy:82.78%
# Epoch 160: iteration 153/154
# Epoch 160 --- loss:0.060, Epoch accuracy:97.60%, Validation loss:0.884, Validation accuracy:79.90%
# Epoch 161: iteration 153/154
# Epoch 161 --- loss:0.065, Epoch accuracy:97.82%, Validation loss:0.756, Validation accuracy:80.38%
# Epoch 162: iteration 153/154
# Epoch 162 --- loss:0.042, Epoch accuracy:98.38%, Validation loss:0.953, Validation accuracy:79.90%
# Epoch 163: iteration 153/154
# Epoch 163 --- loss:0.057, Epoch accuracy:97.76%, Validation loss:0.944, Validation accuracy:77.03%
# Epoch 164: iteration 153/154
# Epoch 164 --- loss:0.062, Epoch accuracy:97.56%, Validation loss:0.862, Validation accuracy:81.82%
# Epoch 165: iteration 153/154
# Epoch 165 --- loss:0.069, Epoch accuracy:97.68%, Validation loss:0.798, Validation accuracy:82.78%
# Epoch 166: iteration 153/154
# Epoch 166 --- loss:0.043, Epoch accuracy:98.40%, Validation loss:0.843, Validation accuracy:80.38%
# Epoch 167: iteration 153/154
# Epoch 167 --- loss:0.057, Epoch accuracy:97.80%, Validation loss:0.744, Validation accuracy:80.38%
# Epoch 168: iteration 153/154
# Epoch 168 --- loss:0.054, Epoch accuracy:97.86%, Validation loss:0.890, Validation accuracy:80.38%
# Epoch 169: iteration 153/154
# Epoch 169 --- loss:0.066, Epoch accuracy:97.37%, Validation loss:0.839, Validation accuracy:77.51%
# Epoch 170: iteration 153/154
# Epoch 170 --- loss:0.055, Epoch accuracy:97.58%, Validation loss:0.788, Validation accuracy:77.51%
# Epoch 171: iteration 153/154
# Epoch 171 --- loss:0.054, Epoch accuracy:97.98%, Validation loss:0.946, Validation accuracy:81.82%
# Epoch 172: iteration 153/154
# Epoch 172 --- loss:0.051, Epoch accuracy:97.98%, Validation loss:0.832, Validation accuracy:82.30%
# Epoch 173: iteration 153/154
# Epoch 173 --- loss:0.060, Epoch accuracy:97.56%, Validation loss:1.043, Validation accuracy:77.99%
# Epoch 174: iteration 153/154
# Epoch 174 --- loss:0.043, Epoch accuracy:98.38%, Validation loss:0.707, Validation accuracy:80.86%
# Epoch 175: iteration 153/154
# Epoch 175 --- loss:0.064, Epoch accuracy:97.78%, Validation loss:0.859, Validation accuracy:80.86%
# Epoch 176: iteration 153/154
# Epoch 176 --- loss:0.047, Epoch accuracy:98.14%, Validation loss:0.752, Validation accuracy:81.34%
# Epoch 177: iteration 153/154
# Epoch 177 --- loss:0.042, Epoch accuracy:98.40%, Validation loss:0.851, Validation accuracy:83.25%
# Epoch 178: iteration 153/154
# Epoch 178 --- loss:0.049, Epoch accuracy:98.00%, Validation loss:0.840, Validation accuracy:83.25%
# Epoch 179: iteration 153/154
# Epoch 179 --- loss:0.058, Epoch accuracy:97.86%, Validation loss:0.789, Validation accuracy:79.43%
# Epoch 180: iteration 153/154
# Epoch 180 --- loss:0.044, Epoch accuracy:98.36%, Validation loss:0.804, Validation accuracy:81.82%
# Epoch 181: iteration 153/154
# Epoch 181 --- loss:0.057, Epoch accuracy:97.72%, Validation loss:0.823, Validation accuracy:79.90%
# Epoch 182: iteration 153/154
# Epoch 182 --- loss:0.070, Epoch accuracy:97.25%, Validation loss:1.277, Validation accuracy:76.56%
# Epoch 183: iteration 153/154
# Epoch 183 --- loss:0.089, Epoch accuracy:96.63%, Validation loss:0.904, Validation accuracy:80.38%
# Epoch 184: iteration 153/154
# Epoch 184 --- loss:0.049, Epoch accuracy:98.24%, Validation loss:0.810, Validation accuracy:83.73%
# Epoch 185: iteration 153/154
# Epoch 185 --- loss:0.042, Epoch accuracy:98.48%, Validation loss:0.794, Validation accuracy:81.34%
# Epoch 186: iteration 153/154
# Epoch 186 --- loss:0.040, Epoch accuracy:98.48%, Validation loss:0.814, Validation accuracy:85.17%
# Epoch 187: iteration 153/154
# Epoch 187 --- loss:0.043, Epoch accuracy:98.36%, Validation loss:0.773, Validation accuracy:82.30%
# Epoch 188: iteration 153/154
# Epoch 188 --- loss:0.056, Epoch accuracy:97.88%, Validation loss:0.943, Validation accuracy:83.73%
# Epoch 189: iteration 153/154
# Epoch 189 --- loss:0.040, Epoch accuracy:98.42%, Validation loss:0.882, Validation accuracy:79.90%
# Epoch 190: iteration 153/154
# Epoch 190 --- loss:0.062, Epoch accuracy:97.49%, Validation loss:0.665, Validation accuracy:81.82%
# Epoch 191: iteration 153/154
# Epoch 191 --- loss:0.045, Epoch accuracy:98.22%, Validation loss:0.731, Validation accuracy:82.78%
# Epoch 192: iteration 153/154
# Epoch 192 --- loss:0.053, Epoch accuracy:98.10%, Validation loss:0.861, Validation accuracy:80.38%
# Epoch 193: iteration 153/154
# Epoch 193 --- loss:0.070, Epoch accuracy:97.35%, Validation loss:0.834, Validation accuracy:78.95%
# Epoch 194: iteration 153/154
# Epoch 194 --- loss:0.053, Epoch accuracy:98.14%, Validation loss:0.739, Validation accuracy:81.82%
# Epoch 195: iteration 153/154
# Epoch 195 --- loss:0.049, Epoch accuracy:97.90%, Validation loss:0.803, Validation accuracy:81.82%
# Epoch 196: iteration 153/154
# Epoch 196 --- loss:0.042, Epoch accuracy:98.22%, Validation loss:0.781, Validation accuracy:81.34%
# Epoch 197: iteration 153/154
# Epoch 197 --- loss:0.055, Epoch accuracy:97.92%, Validation loss:0.797, Validation accuracy:79.90%
# Epoch 198: iteration 153/154
# Epoch 198 --- loss:0.059, Epoch accuracy:97.98%, Validation loss:0.840, Validation accuracy:80.86%
# Epoch 199: iteration 153/154
# Epoch 199 --- loss:0.049, Epoch accuracy:98.10%, Validation loss:0.854, Validation accuracy:79.43%
# Epoch 200: iteration 153/154
# Epoch 200 --- loss:0.039, Epoch accuracy:98.40%, Validation loss:0.855, Validation accuracy:83.73%
# Epoch 201: iteration 153/154
# Epoch 201 --- loss:0.051, Epoch accuracy:98.14%, Validation loss:1.029, Validation accuracy:77.51%
# Epoch 202: iteration 153/154
# Epoch 202 --- loss:0.066, Epoch accuracy:97.43%, Validation loss:1.020, Validation accuracy:79.90%
# Epoch 203: iteration 153/154
# Epoch 203 --- loss:0.055, Epoch accuracy:97.80%, Validation loss:0.880, Validation accuracy:78.47%
# Epoch 204: iteration 153/154
# Epoch 204 --- loss:0.058, Epoch accuracy:97.70%, Validation loss:0.836, Validation accuracy:76.08%
# Epoch 205: iteration 153/154
# Epoch 205 --- loss:0.052, Epoch accuracy:98.08%, Validation loss:0.742, Validation accuracy:81.82%
# Epoch 206: iteration 153/154
# Epoch 206 --- loss:0.051, Epoch accuracy:98.10%, Validation loss:0.729, Validation accuracy:81.82%
# Epoch 207: iteration 153/154
# Epoch 207 --- loss:0.046, Epoch accuracy:98.22%, Validation loss:0.729, Validation accuracy:83.73%
# Epoch 208: iteration 153/154
# Epoch 208 --- loss:0.056, Epoch accuracy:97.84%, Validation loss:0.948, Validation accuracy:81.34%
# Epoch 209: iteration 153/154
# Epoch 209 --- loss:0.047, Epoch accuracy:98.36%, Validation loss:0.772, Validation accuracy:82.78%
# Epoch 210: iteration 153/154
# Epoch 210 --- loss:0.050, Epoch accuracy:98.12%, Validation loss:0.790, Validation accuracy:80.38%
# Epoch 211: iteration 153/154
# Epoch 211 --- loss:0.055, Epoch accuracy:97.94%, Validation loss:1.034, Validation accuracy:77.03%
# Epoch 212: iteration 153/154
# Epoch 212 --- loss:0.071, Epoch accuracy:97.07%, Validation loss:0.902, Validation accuracy:79.43%
# Epoch 213: iteration 153/154
# Epoch 213 --- loss:0.048, Epoch accuracy:98.18%, Validation loss:0.827, Validation accuracy:78.95%
# Epoch 214: iteration 153/154
# Epoch 214 --- loss:0.048, Epoch accuracy:98.12%, Validation loss:0.752, Validation accuracy:81.82%
# Epoch 215: iteration 153/154
# Epoch 215 --- loss:0.043, Epoch accuracy:98.22%, Validation loss:0.804, Validation accuracy:80.38%
# Epoch 216: iteration 153/154
# Epoch 216 --- loss:0.061, Epoch accuracy:97.52%, Validation loss:0.809, Validation accuracy:82.30%
# Epoch 217: iteration 153/154
# Epoch 217 --- loss:0.074, Epoch accuracy:96.97%, Validation loss:0.737, Validation accuracy:82.78%
# Epoch 218: iteration 153/154
# Epoch 218 --- loss:0.045, Epoch accuracy:98.36%, Validation loss:0.748, Validation accuracy:84.69%
# Epoch 219: iteration 153/154
# Epoch 219 --- loss:0.043, Epoch accuracy:98.24%, Validation loss:0.786, Validation accuracy:80.38%
# Epoch 220: iteration 153/154
# Epoch 220 --- loss:0.053, Epoch accuracy:98.02%, Validation loss:0.815, Validation accuracy:79.90%
# Epoch 221: iteration 153/154
# Epoch 221 --- loss:0.036, Epoch accuracy:98.65%, Validation loss:0.950, Validation accuracy:77.03%
# Epoch 222: iteration 153/154
# Epoch 222 --- loss:0.058, Epoch accuracy:97.78%, Validation loss:0.845, Validation accuracy:81.82%
# Epoch 223: iteration 153/154
# Epoch 223 --- loss:0.051, Epoch accuracy:97.86%, Validation loss:0.816, Validation accuracy:79.43%
# Epoch 224: iteration 153/154
# Epoch 224 --- loss:0.044, Epoch accuracy:98.20%, Validation loss:0.753, Validation accuracy:79.90%
# Epoch 225: iteration 153/154
# Epoch 225 --- loss:0.051, Epoch accuracy:98.10%, Validation loss:0.953, Validation accuracy:80.38%
# Epoch 226: iteration 153/154
# Epoch 226 --- loss:0.054, Epoch accuracy:97.78%, Validation loss:0.709, Validation accuracy:81.82%
# Epoch 227: iteration 153/154
# Epoch 227 --- loss:0.065, Epoch accuracy:97.47%, Validation loss:0.871, Validation accuracy:80.38%
# Epoch 228: iteration 153/154
# Epoch 228 --- loss:0.047, Epoch accuracy:98.14%, Validation loss:0.914, Validation accuracy:79.43%
# Epoch 229: iteration 153/154
# Epoch 229 --- loss:0.054, Epoch accuracy:98.02%, Validation loss:0.871, Validation accuracy:79.90%
# Epoch 230: iteration 153/154
# Epoch 230 --- loss:0.044, Epoch accuracy:98.32%, Validation loss:0.832, Validation accuracy:83.73%
# Epoch 231: iteration 153/154
# Epoch 231 --- loss:0.043, Epoch accuracy:98.28%, Validation loss:0.855, Validation accuracy:79.90%
# Epoch 232: iteration 153/154
# Epoch 232 --- loss:0.053, Epoch accuracy:97.86%, Validation loss:0.771, Validation accuracy:78.47%
# Epoch 233: iteration 153/154
# Epoch 233 --- loss:0.064, Epoch accuracy:97.58%, Validation loss:0.821, Validation accuracy:81.34%
# Epoch 234: iteration 153/154
# Epoch 234 --- loss:0.044, Epoch accuracy:98.22%, Validation loss:0.748, Validation accuracy:82.78%
# Epoch 235: iteration 153/154
# Epoch 235 --- loss:0.046, Epoch accuracy:98.14%, Validation loss:0.820, Validation accuracy:82.30%
# Epoch 236: iteration 153/154
# Epoch 236 --- loss:0.041, Epoch accuracy:98.30%, Validation loss:0.813, Validation accuracy:81.34%
# Epoch 237: iteration 153/154
# Epoch 237 --- loss:0.042, Epoch accuracy:98.22%, Validation loss:0.798, Validation accuracy:80.38%
# Epoch 238: iteration 153/154
# Epoch 238 --- loss:0.068, Epoch accuracy:97.25%, Validation loss:0.806, Validation accuracy:84.69%
# Epoch 239: iteration 153/154
# Epoch 239 --- loss:0.042, Epoch accuracy:98.36%, Validation loss:0.779, Validation accuracy:81.82%
# Epoch 240: iteration 153/154
# Epoch 240 --- loss:0.068, Epoch accuracy:97.23%, Validation loss:0.730, Validation accuracy:81.82%
# Epoch 241: iteration 153/154
# Epoch 241 --- loss:0.051, Epoch accuracy:98.02%, Validation loss:0.750, Validation accuracy:82.78%
# Epoch 242: iteration 153/154
# Epoch 242 --- loss:0.052, Epoch accuracy:98.14%, Validation loss:0.723, Validation accuracy:82.78%
# Epoch 243: iteration 153/154
# Epoch 243 --- loss:0.039, Epoch accuracy:98.55%, Validation loss:0.844, Validation accuracy:81.34%
# Epoch 244: iteration 153/154
# Epoch 244 --- loss:0.050, Epoch accuracy:98.18%, Validation loss:0.781, Validation accuracy:80.86%
# Epoch 245: iteration 153/154
# Epoch 245 --- loss:0.041, Epoch accuracy:98.53%, Validation loss:0.750, Validation accuracy:82.30%
# Epoch 246: iteration 153/154
# Epoch 246 --- loss:0.033, Epoch accuracy:98.71%, Validation loss:0.753, Validation accuracy:81.82%
# Epoch 247: iteration 153/154
# Epoch 247 --- loss:0.038, Epoch accuracy:98.38%, Validation loss:1.008, Validation accuracy:78.95%
# Epoch 248: iteration 153/154
# Epoch 248 --- loss:0.068, Epoch accuracy:97.21%, Validation loss:0.821, Validation accuracy:80.86%
# Epoch 249: iteration 153/154
# Epoch 249 --- loss:0.065, Epoch accuracy:97.33%, Validation loss:0.946, Validation accuracy:79.43%
# Epoch 250: iteration 153/154
# Epoch 250 --- loss:0.054, Epoch accuracy:97.94%, Validation loss:0.788, Validation accuracy:79.43%
# Epoch 251: iteration 153/154
# Epoch 251 --- loss:0.053, Epoch accuracy:98.02%, Validation loss:0.830, Validation accuracy:80.86%
# Epoch 252: iteration 153/154
# Epoch 252 --- loss:0.040, Epoch accuracy:98.32%, Validation loss:0.863, Validation accuracy:81.82%
# Epoch 253: iteration 153/154
# Epoch 253 --- loss:0.046, Epoch accuracy:98.08%, Validation loss:0.775, Validation accuracy:82.30%
# Epoch 254: iteration 153/154
# Epoch 254 --- loss:0.036, Epoch accuracy:98.69%, Validation loss:0.705, Validation accuracy:81.82%
# Epoch 255: iteration 153/154
# Epoch 255 --- loss:0.038, Epoch accuracy:98.42%, Validation loss:0.808, Validation accuracy:83.25%
# Epoch 256: iteration 153/154
# Epoch 256 --- loss:0.093, Epoch accuracy:96.26%, Validation loss:0.734, Validation accuracy:80.86%
# Epoch 257: iteration 153/154
# Epoch 257 --- loss:0.077, Epoch accuracy:96.79%, Validation loss:0.904, Validation accuracy:81.34%
# Epoch 258: iteration 153/154
# Epoch 258 --- loss:0.062, Epoch accuracy:97.39%, Validation loss:0.870, Validation accuracy:80.38%
# Epoch 259: iteration 153/154
# Epoch 259 --- loss:0.042, Epoch accuracy:98.36%, Validation loss:0.640, Validation accuracy:82.78%
# Epoch 260: iteration 153/154
# Epoch 260 --- loss:0.037, Epoch accuracy:98.57%, Validation loss:0.760, Validation accuracy:81.82%
# Epoch 261: iteration 153/154
# Epoch 261 --- loss:0.042, Epoch accuracy:98.36%, Validation loss:0.952, Validation accuracy:77.03%
# Epoch 262: iteration 153/154
# Epoch 262 --- loss:0.046, Epoch accuracy:98.18%, Validation loss:0.832, Validation accuracy:80.86%
# Epoch 263: iteration 153/154
# Epoch 263 --- loss:0.041, Epoch accuracy:98.32%, Validation loss:0.794, Validation accuracy:80.86%
# Epoch 264: iteration 153/154
# Epoch 264 --- loss:0.043, Epoch accuracy:98.38%, Validation loss:0.949, Validation accuracy:79.43%
# Epoch 265: iteration 153/154
# Epoch 265 --- loss:0.048, Epoch accuracy:98.02%, Validation loss:1.040, Validation accuracy:77.51%
# Epoch 266: iteration 153/154
# Epoch 266 --- loss:0.039, Epoch accuracy:98.55%, Validation loss:0.826, Validation accuracy:83.73%
# Epoch 267: iteration 153/154
# Epoch 267 --- loss:0.050, Epoch accuracy:97.90%, Validation loss:0.871, Validation accuracy:82.30%
# Epoch 268: iteration 153/154
# Epoch 268 --- loss:0.055, Epoch accuracy:97.72%, Validation loss:0.663, Validation accuracy:83.73%
# Epoch 269: iteration 153/154
# Epoch 269 --- loss:0.044, Epoch accuracy:98.18%, Validation loss:0.828, Validation accuracy:83.25%
# Epoch 270: iteration 153/154
# Epoch 270 --- loss:0.056, Epoch accuracy:97.82%, Validation loss:0.818, Validation accuracy:80.86%
# Epoch 271: iteration 153/154
# Epoch 271 --- loss:0.037, Epoch accuracy:98.50%, Validation loss:0.756, Validation accuracy:85.17%
# Epoch 272: iteration 153/154
# Epoch 272 --- loss:0.045, Epoch accuracy:98.16%, Validation loss:0.832, Validation accuracy:79.90%
# Epoch 273: iteration 153/154
# Epoch 273 --- loss:0.037, Epoch accuracy:98.50%, Validation loss:0.754, Validation accuracy:80.86%
# Epoch 274: iteration 153/154
# Epoch 274 --- loss:0.029, Epoch accuracy:98.77%, Validation loss:0.874, Validation accuracy:78.95%
# Epoch 275: iteration 153/154
# Epoch 275 --- loss:0.060, Epoch accuracy:97.47%, Validation loss:0.787, Validation accuracy:81.34%
# Epoch 276: iteration 153/154
# Epoch 276 --- loss:0.044, Epoch accuracy:98.36%, Validation loss:0.880, Validation accuracy:81.34%
# Epoch 277: iteration 153/154
# Epoch 277 --- loss:0.040, Epoch accuracy:98.32%, Validation loss:0.970, Validation accuracy:79.90%
# Epoch 278: iteration 153/154
# Epoch 278 --- loss:0.046, Epoch accuracy:98.24%, Validation loss:0.772, Validation accuracy:84.21%
# Epoch 279: iteration 153/154
# Epoch 279 --- loss:0.046, Epoch accuracy:98.20%, Validation loss:0.846, Validation accuracy:81.34%
# Epoch 280: iteration 153/154
# Epoch 280 --- loss:0.041, Epoch accuracy:98.40%, Validation loss:0.704, Validation accuracy:84.21%
# Epoch 281: iteration 153/154
# Epoch 281 --- loss:0.039, Epoch accuracy:98.59%, Validation loss:0.818, Validation accuracy:78.95%
# Epoch 282: iteration 153/154
# Epoch 282 --- loss:0.039, Epoch accuracy:98.50%, Validation loss:0.911, Validation accuracy:81.82%
# Epoch 283: iteration 153/154
# Epoch 283 --- loss:0.030, Epoch accuracy:98.77%, Validation loss:0.912, Validation accuracy:79.43%
# Epoch 284: iteration 153/154
# Epoch 284 --- loss:0.046, Epoch accuracy:98.30%, Validation loss:0.797, Validation accuracy:81.34%
# Epoch 285: iteration 153/154
# Epoch 285 --- loss:0.039, Epoch accuracy:98.48%, Validation loss:0.858, Validation accuracy:78.95%
# Epoch 286: iteration 153/154
# Epoch 286 --- loss:0.060, Epoch accuracy:97.82%, Validation loss:0.786, Validation accuracy:81.82%
# Epoch 287: iteration 153/154
# Epoch 287 --- loss:0.080, Epoch accuracy:97.03%, Validation loss:1.030, Validation accuracy:80.38%
# Epoch 288: iteration 153/154
# Epoch 288 --- loss:0.050, Epoch accuracy:97.92%, Validation loss:1.076, Validation accuracy:78.47%
# Epoch 289: iteration 153/154
# Epoch 289 --- loss:0.046, Epoch accuracy:98.34%, Validation loss:0.794, Validation accuracy:81.34%
# Epoch 290: iteration 153/154
# Epoch 290 --- loss:0.033, Epoch accuracy:98.71%, Validation loss:0.767, Validation accuracy:80.38%
# Epoch 291: iteration 153/154
# Epoch 291 --- loss:0.045, Epoch accuracy:98.34%, Validation loss:0.866, Validation accuracy:81.82%
# Epoch 292: iteration 153/154
# Epoch 292 --- loss:0.042, Epoch accuracy:98.44%, Validation loss:1.044, Validation accuracy:79.43%
# Epoch 293: iteration 153/154
# Epoch 293 --- loss:0.087, Epoch accuracy:96.38%, Validation loss:0.856, Validation accuracy:82.30%
# Epoch 294: iteration 153/154
# Epoch 294 --- loss:0.050, Epoch accuracy:97.96%, Validation loss:0.821, Validation accuracy:80.86%
# Epoch 295: iteration 153/154
# Epoch 295 --- loss:0.044, Epoch accuracy:98.26%, Validation loss:0.755, Validation accuracy:82.30%
# Epoch 296: iteration 153/154
# Epoch 296 --- loss:0.047, Epoch accuracy:98.02%, Validation loss:0.764, Validation accuracy:82.30%
# Epoch 297: iteration 153/154
# Epoch 297 --- loss:0.058, Epoch accuracy:97.70%, Validation loss:0.997, Validation accuracy:76.08%
# Epoch 298: iteration 153/154
# Epoch 298 --- loss:0.057, Epoch accuracy:97.76%, Validation loss:0.879, Validation accuracy:80.38%
# Epoch 299: iteration 153/154
# Epoch 299 --- loss:0.049, Epoch accuracy:98.22%, Validation loss:0.824, Validation accuracy:81.82%
# Epoch 300: iteration 153/154
# Epoch 300 --- loss:0.048, Epoch accuracy:98.20%, Validation loss:0.903, Validation accuracy:82.78%
# Epoch 301: iteration 153/154
# Epoch 301 --- loss:0.032, Epoch accuracy:98.79%, Validation loss:0.804, Validation accuracy:80.38%
# Epoch 302: iteration 153/154
# Epoch 302 --- loss:0.042, Epoch accuracy:98.32%, Validation loss:0.760, Validation accuracy:84.21%
# Epoch 303: iteration 153/154
# Epoch 303 --- loss:0.033, Epoch accuracy:98.77%, Validation loss:0.834, Validation accuracy:79.90%
# Epoch 304: iteration 153/154
# Epoch 304 --- loss:0.043, Epoch accuracy:98.40%, Validation loss:0.739, Validation accuracy:82.78%
# Epoch 305: iteration 153/154
# Epoch 305 --- loss:0.036, Epoch accuracy:98.61%, Validation loss:0.751, Validation accuracy:81.82%
# Epoch 306: iteration 153/154
# Epoch 306 --- loss:0.045, Epoch accuracy:98.16%, Validation loss:0.850, Validation accuracy:80.38%
# Epoch 307: iteration 153/154
# Epoch 307 --- loss:0.055, Epoch accuracy:97.92%, Validation loss:0.760, Validation accuracy:81.82%
# Epoch 308: iteration 153/154
# Epoch 308 --- loss:0.060, Epoch accuracy:97.58%, Validation loss:1.100, Validation accuracy:78.95%
# Epoch 309: iteration 153/154
# Epoch 309 --- loss:0.048, Epoch accuracy:98.12%, Validation loss:0.770, Validation accuracy:81.82%
# Epoch 310: iteration 153/154
# Epoch 310 --- loss:0.044, Epoch accuracy:98.30%, Validation loss:0.837, Validation accuracy:81.82%
# Epoch 311: iteration 153/154
# Epoch 311 --- loss:0.037, Epoch accuracy:98.63%, Validation loss:0.904, Validation accuracy:80.86%
# Epoch 312: iteration 153/154
# Epoch 312 --- loss:0.039, Epoch accuracy:98.40%, Validation loss:0.809, Validation accuracy:81.82%
# Epoch 313: iteration 153/154
# Epoch 313 --- loss:0.042, Epoch accuracy:98.34%, Validation loss:0.772, Validation accuracy:84.21%
# Epoch 314: iteration 153/154
# Epoch 314 --- loss:0.035, Epoch accuracy:98.48%, Validation loss:1.103, Validation accuracy:77.51%
# Epoch 315: iteration 153/154
# Epoch 315 --- loss:0.083, Epoch accuracy:96.93%, Validation loss:1.030, Validation accuracy:80.86%
# Epoch 316: iteration 153/154
# Epoch 316 --- loss:0.038, Epoch accuracy:98.59%, Validation loss:0.741, Validation accuracy:81.34%
# Epoch 317: iteration 153/154
# Epoch 317 --- loss:0.036, Epoch accuracy:98.69%, Validation loss:0.775, Validation accuracy:81.34%
# Epoch 318: iteration 153/154
# Epoch 318 --- loss:0.042, Epoch accuracy:98.34%, Validation loss:0.831, Validation accuracy:82.30%
# Epoch 319: iteration 153/154
# Epoch 319 --- loss:0.048, Epoch accuracy:98.12%, Validation loss:0.879, Validation accuracy:80.86%
# Epoch 320: iteration 153/154
# Epoch 320 --- loss:0.047, Epoch accuracy:98.02%, Validation loss:0.946, Validation accuracy:78.95%
# Epoch 321: iteration 153/154
# Epoch 321 --- loss:0.045, Epoch accuracy:98.00%, Validation loss:0.872, Validation accuracy:83.25%
# Epoch 322: iteration 153/154
# Epoch 322 --- loss:0.047, Epoch accuracy:98.24%, Validation loss:0.801, Validation accuracy:82.30%
# Epoch 323: iteration 153/154
# Epoch 323 --- loss:0.046, Epoch accuracy:98.32%, Validation loss:0.865, Validation accuracy:79.43%
# Epoch 324: iteration 153/154
# Epoch 324 --- loss:0.049, Epoch accuracy:98.02%, Validation loss:0.924, Validation accuracy:81.34%
# Epoch 325: iteration 153/154
# Epoch 325 --- loss:0.051, Epoch accuracy:98.06%, Validation loss:0.962, Validation accuracy:79.43%
# Epoch 326: iteration 153/154
# Epoch 326 --- loss:0.056, Epoch accuracy:97.52%, Validation loss:0.782, Validation accuracy:82.30%
# Epoch 327: iteration 153/154
# Epoch 327 --- loss:0.037, Epoch accuracy:98.57%, Validation loss:0.859, Validation accuracy:81.34%
# Epoch 328: iteration 153/154
# Epoch 328 --- loss:0.037, Epoch accuracy:98.46%, Validation loss:0.785, Validation accuracy:80.86%
# Epoch 329: iteration 153/154
# Epoch 329 --- loss:0.053, Epoch accuracy:97.94%, Validation loss:0.860, Validation accuracy:82.30%
# Epoch 330: iteration 153/154
# Epoch 330 --- loss:0.041, Epoch accuracy:98.38%, Validation loss:0.866, Validation accuracy:78.47%
# Epoch 331: iteration 153/154
# Epoch 331 --- loss:0.031, Epoch accuracy:98.93%, Validation loss:0.782, Validation accuracy:80.86%
# Epoch 332: iteration 153/154
# Epoch 332 --- loss:0.032, Epoch accuracy:98.83%, Validation loss:0.879, Validation accuracy:81.82%
# Epoch 333: iteration 153/154
# Epoch 333 --- loss:0.049, Epoch accuracy:98.16%, Validation loss:0.776, Validation accuracy:80.86%
# Epoch 334: iteration 153/154
# Epoch 334 --- loss:0.040, Epoch accuracy:98.32%, Validation loss:0.863, Validation accuracy:80.86%
# Epoch 335: iteration 153/154
# Epoch 335 --- loss:0.038, Epoch accuracy:98.51%, Validation loss:0.952, Validation accuracy:78.95%
# Epoch 336: iteration 153/154
# Epoch 336 --- loss:0.065, Epoch accuracy:97.35%, Validation loss:0.802, Validation accuracy:84.21%
# Epoch 337: iteration 153/154
# Epoch 337 --- loss:0.040, Epoch accuracy:98.42%, Validation loss:0.814, Validation accuracy:80.38%
# Epoch 338: iteration 153/154
# Epoch 338 --- loss:0.039, Epoch accuracy:98.48%, Validation loss:0.811, Validation accuracy:82.78%
# Epoch 339: iteration 153/154
# Epoch 339 --- loss:0.030, Epoch accuracy:98.89%, Validation loss:0.790, Validation accuracy:80.38%
# Epoch 340: iteration 153/154
# Epoch 340 --- loss:0.043, Epoch accuracy:98.26%, Validation loss:0.910, Validation accuracy:82.78%
# Epoch 341: iteration 153/154
# Epoch 341 --- loss:0.070, Epoch accuracy:97.13%, Validation loss:0.870, Validation accuracy:80.86%
# Epoch 342: iteration 153/154
# Epoch 342 --- loss:0.038, Epoch accuracy:98.51%, Validation loss:0.918, Validation accuracy:81.34%
# Epoch 343: iteration 153/154
# Epoch 343 --- loss:0.048, Epoch accuracy:97.94%, Validation loss:0.912, Validation accuracy:80.38%
# Epoch 344: iteration 153/154
# Epoch 344 --- loss:0.051, Epoch accuracy:98.10%, Validation loss:0.851, Validation accuracy:82.78%
# Epoch 345: iteration 153/154
# Epoch 345 --- loss:0.061, Epoch accuracy:97.66%, Validation loss:0.811, Validation accuracy:79.90%
# Epoch 346: iteration 153/154
# Epoch 346 --- loss:0.055, Epoch accuracy:97.76%, Validation loss:1.085, Validation accuracy:77.51%
# Epoch 347: iteration 153/154
# Epoch 347 --- loss:0.055, Epoch accuracy:97.72%, Validation loss:0.758, Validation accuracy:83.73%
# Epoch 348: iteration 153/154
# Epoch 348 --- loss:0.045, Epoch accuracy:98.32%, Validation loss:0.760, Validation accuracy:81.34%
# Epoch 349: iteration 153/154
# Epoch 349 --- loss:0.046, Epoch accuracy:97.92%, Validation loss:0.948, Validation accuracy:78.95%

# %%
plt.title('Loss Curve for Parallel is All You Want Model')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_losses[:],'b')
plt.plot(valid_losses[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()

# %%
max=0
for i in range(250):
        # pick load folder  
        load_folder = 'checkpoint'  

        # pick the epoch to load
        x=i+100
        epoch = str(x)
        model_name = f'parallel_all_you_wantFINAL-{epoch}.pkl'

        # make full load path
        load_path = os.path.join(load_folder, model_name)

        ## instantiate empty model and populate with params from binary 
        model = parallel_all_you_want(len(emotions_dict))
        load_checkpoint(optimizer, model, load_path)

        print(f'Loaded model from {load_path}')
        # reinitialize validation function with model from chosen checkpoint
        validate = make_validate_fnc(model,criterion)

        # Convert 4D test feature set array to tensor and move to GPU
        X_test_tensor = torch.tensor(X_test,device=device).float()
        # Convert 4D test label set array to tensor and move to GPU
        y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
        inputs =  X_test_tensor                     # this is what you had
        labels =  y_test_tensor
        #inputs, labels = inputs.cuda(), labels.cuda() # add this line
        # Get the model's performance metrics using the validation function we defined

        #device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

        #inputs, labels = inputs.to(device), labels.to(device)
        model.to('cuda') 
        inputs = inputs.to('cuda')

        model.to('cuda') 
        labels = labels.to('cuda')

        test_loss, test_acc, predicted_emotions = validate(X_test_tensor,y_test_tensor)
        if test_acc>=max : max=test_acc
        print(f'Test accuracy is {test_acc:.2f}%')
print(f'MAX Test accuracy is {max:.2f}%')
# Out:
# Loaded model from checkpoint/parallel_all_you_wantFINAL-100.pkl
# Test accuracy is 69.38%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-101.pkl
# Test accuracy is 70.33%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-102.pkl
# Test accuracy is 70.33%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-103.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-104.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-105.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-106.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-107.pkl
# Test accuracy is 68.90%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-108.pkl
# Test accuracy is 70.33%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-109.pkl
# Test accuracy is 70.81%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-110.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-111.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-112.pkl
# Test accuracy is 68.90%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-113.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-114.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-115.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-116.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-117.pkl
# Test accuracy is 70.81%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-118.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-119.pkl
# Test accuracy is 67.46%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-120.pkl
# Test accuracy is 70.81%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-121.pkl
# Test accuracy is 69.38%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-122.pkl
# Test accuracy is 71.77%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-123.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-124.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-125.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-126.pkl
# Test accuracy is 70.33%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-127.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-128.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-129.pkl
# Test accuracy is 68.90%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-130.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-131.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-132.pkl
# Test accuracy is 70.33%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-133.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-134.pkl
# Test accuracy is 69.86%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-135.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-136.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-137.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-138.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-139.pkl
# Test accuracy is 68.42%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-140.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-141.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-142.pkl
# Test accuracy is 71.77%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-143.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-144.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-145.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-146.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-147.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-148.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-149.pkl
# Test accuracy is 70.81%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-150.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-151.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-152.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-153.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-154.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-155.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-156.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-157.pkl
# Test accuracy is 66.51%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-158.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-159.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-160.pkl
# Test accuracy is 70.33%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-161.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-162.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-163.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-164.pkl
# Test accuracy is 68.90%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-165.pkl
# Test accuracy is 70.33%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-166.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-167.pkl
# Test accuracy is 76.56%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-168.pkl
# Test accuracy is 69.86%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-169.pkl
# Test accuracy is 75.60%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-170.pkl
# Test accuracy is 70.33%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-171.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-172.pkl
# Test accuracy is 71.77%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-173.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-174.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-175.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-176.pkl
# Test accuracy is 75.60%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-177.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-178.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-179.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-180.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-181.pkl
# Test accuracy is 70.81%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-182.pkl
# Test accuracy is 68.42%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-183.pkl
# Test accuracy is 68.90%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-184.pkl
# Test accuracy is 69.38%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-185.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-186.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-187.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-188.pkl
# Test accuracy is 70.81%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-189.pkl
# Test accuracy is 70.81%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-190.pkl
# Test accuracy is 77.03%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-191.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-192.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-193.pkl
# Test accuracy is 75.60%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-194.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-195.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-196.pkl
# Test accuracy is 71.77%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-197.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-198.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-199.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-200.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-201.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-202.pkl
# Test accuracy is 63.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-203.pkl
# Test accuracy is 71.77%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-204.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-205.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-206.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-207.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-208.pkl
# Test accuracy is 70.33%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-209.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-210.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-211.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-212.pkl
# Test accuracy is 71.77%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-213.pkl
# Test accuracy is 75.60%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-214.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-215.pkl
# Test accuracy is 69.38%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-216.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-217.pkl
# Test accuracy is 71.77%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-218.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-219.pkl
# Test accuracy is 75.60%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-220.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-221.pkl
# Test accuracy is 70.81%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-222.pkl
# Test accuracy is 70.81%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-223.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-224.pkl
# Test accuracy is 75.60%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-225.pkl
# Test accuracy is 70.33%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-226.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-227.pkl
# Test accuracy is 71.77%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-228.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-229.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-230.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-231.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-232.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-233.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-234.pkl
# Test accuracy is 76.56%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-235.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-236.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-237.pkl
# Test accuracy is 69.86%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-238.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-239.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-240.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-241.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-242.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-243.pkl
# Test accuracy is 71.77%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-244.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-245.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-246.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-247.pkl
# Test accuracy is 70.33%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-248.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-249.pkl
# Test accuracy is 69.86%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-250.pkl
# Test accuracy is 75.60%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-251.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-252.pkl
# Test accuracy is 76.08%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-253.pkl
# Test accuracy is 76.56%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-254.pkl
# Test accuracy is 77.03%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-255.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-256.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-257.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-258.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-259.pkl
# Test accuracy is 77.03%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-260.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-261.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-262.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-263.pkl
# Test accuracy is 76.08%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-264.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-265.pkl
# Test accuracy is 69.86%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-266.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-267.pkl
# Test accuracy is 71.77%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-268.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-269.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-270.pkl
# Test accuracy is 71.77%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-271.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-272.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-273.pkl
# Test accuracy is 76.08%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-274.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-275.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-276.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-277.pkl
# Test accuracy is 68.42%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-278.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-279.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-280.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-281.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-282.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-283.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-284.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-285.pkl
# Test accuracy is 69.86%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-286.pkl
# Test accuracy is 70.33%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-287.pkl
# Test accuracy is 71.77%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-288.pkl
# Test accuracy is 70.81%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-289.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-290.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-291.pkl
# Test accuracy is 75.60%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-292.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-293.pkl
# Test accuracy is 72.25%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-294.pkl
# Test accuracy is 76.56%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-295.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-296.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-297.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-298.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-299.pkl
# Test accuracy is 71.77%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-300.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-301.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-302.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-303.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-304.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-305.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-306.pkl
# Test accuracy is 76.08%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-307.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-308.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-309.pkl
# Test accuracy is 76.08%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-310.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-311.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-312.pkl
# Test accuracy is 70.81%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-313.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-314.pkl
# Test accuracy is 66.03%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-315.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-316.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-317.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-318.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-319.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-320.pkl
# Test accuracy is 75.60%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-321.pkl
# Test accuracy is 70.81%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-322.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-323.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-324.pkl
# Test accuracy is 77.03%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-325.pkl
# Test accuracy is 76.08%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-326.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-327.pkl
# Test accuracy is 77.51%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-328.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-329.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-330.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-331.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-332.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-333.pkl
# Test accuracy is 77.03%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-334.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-335.pkl
# Test accuracy is 77.03%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-336.pkl
# Test accuracy is 73.21%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-337.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-338.pkl
# Test accuracy is 74.16%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-339.pkl
# Test accuracy is 75.12%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-340.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-341.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-342.pkl
# Test accuracy is 72.73%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-343.pkl
# Test accuracy is 77.99%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-344.pkl
# Test accuracy is 76.56%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-345.pkl
# Test accuracy is 73.68%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-346.pkl
# Test accuracy is 71.29%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-347.pkl
# Test accuracy is 74.64%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-348.pkl
# Test accuracy is 75.60%
# Loaded model from checkpoint/parallel_all_you_wantFINAL-349.pkl
# Test accuracy is 71.29%
# MAX Test accuracy is 77.99%
