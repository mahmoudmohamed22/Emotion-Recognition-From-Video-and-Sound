# %%
# IMPORT NECESSARY LIBRARIES
import numpy as np
from tensorflow.keras import layers, models, Model, optimizers
import tensorflow as tf
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator, load_img
import pandas as pd
from sklearn.metrics import confusion_matrix
import sys
import matplotlib.pyplot as plt
import itertools

import warnings
# ignore warnings 
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
import keras
from keras.models import Sequential, Model, model_from_json
from keras.layers import Conv1D, MaxPooling2D, AveragePooling1D
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Dense, Embedding, LSTM
from keras.regularizers import l2
from keras.constraints import max_norm
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import shuffle
from tensorflow.python.keras import layers, models, Model, optimizers
from tensorflow.keras import regularizers
from tensorflow.keras import layers, models, Model, optimizers
from tensorflow.keras.utils import to_categorical
from keras.utils import np_utils
from random import randint
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from matplotlib import pyplot

# %%
import glob
angry = glob.glob('trainclasses/angry/*.*')
calm = glob.glob('trainclasses/calm/*.*')
disgust = glob.glob('trainclasses/disgust/*.*')
fearful = glob.glob('trainclasses/fearful/*.*')
happy = glob.glob('trainclasses/happy/*.*')
neutral = glob.glob('trainclasses/neutral/*.*')
sad = glob.glob('trainclasses/sad/*.*')
surprised = glob.glob('trainclasses/surprised/*.*')

# %%
train_data = []
train_labels = []

for i in angry:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    train_data.append(image)
    train_labels.append('Angry')
for i in calm:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    train_data.append(image)
    train_labels.append('Calm')
for i in disgust:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    train_data.append(image)
    train_labels.append('Disgust')
for i in fearful:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    train_data.append(image)
    train_labels.append('Fearful')
for i in happy:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    train_data.append(image)
    train_labels.append('Happy')
for i in neutral:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    train_data.append(image)
    train_labels.append('Neutral')
for i in sad:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    train_data.append(image)
    train_labels.append('Sad')
for i in surprised:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    train_data.append(image)
    train_labels.append('Surprised')

train_data = np.array(train_data)
train_labels = np.array(train_labels)

# %%
X_train=train_data
y_train=train_labels

# %%
import glob
angry = glob.glob('testclasses/angry/*.*')
calm = glob.glob('testclasses/calm/*.*')
disgust = glob.glob('testclasses/disgust/*.*')
fearful = glob.glob('testclasses/fearful/*.*')
happy = glob.glob('testclasses/happy/*.*')
neutral = glob.glob('testclasses/neutral/*.*')
sad = glob.glob('testclasses/sad/*.*')
surprised = glob.glob('testclasses/surprised/*.*')

# %%
test_data = []
test_labels = []

for i in angry:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    test_data.append(image)
    test_labels.append('Angry')
for i in calm:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    test_data.append(image)
    test_labels.append('Calm')
for i in disgust:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    test_data.append(image)
    test_labels.append('Disgust')
for i in fearful:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    test_data.append(image)
    test_labels.append('Fearful')
for i in happy:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    test_data.append(image)
    test_labels.append('Happy')
for i in neutral:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    test_data.append(image)
    test_labels.append('Neutral')
for i in sad:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    test_data.append(image)
    test_labels.append('Sad')
for i in surprised:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (224,224))
    image=np.array(image)
    test_data.append(image)
    test_labels.append('Surprised')

test_data = np.array(test_data)
test_labels = np.array(test_labels)

# %%
X_test=test_data
y_test=test_labels

# %%
def get_classlabel(class_code):
    labels = {'Angry':'Angry', 'Calm':'Calm', 'Disgust':'Disgust', 'Fearful':'Fearful', 'Happy':'Happy', 'Neutral':'Neutral','Sad':'Sad','Surprised':'Surprised'}
    
    return labels[class_code]

f,ax = plt.subplots(5,5) 
f.subplots_adjust(0,0,3,3)
for i in range(0,5,1):
    for j in range(0,5,1):
        rnd_number = randint(0,len(train_data))
        ax[i,j].imshow(train_data[rnd_number])
        ax[i,j].set_title(get_classlabel(train_labels[rnd_number]))
        ax[i,j].axis('off')

# %%
# Check shapes of training and testing sets
print('X_train has a shape of {}, y_train has a shape of {}'.format(X_train.shape,y_train.shape))
print('X_test has a shape of {}, y_test has a shape of {}'.format(X_test.shape,y_test.shape))
# Out:
# X_train has a shape of (1200, 224, 224, 3), y_train has a shape of (1200,)
# X_test has a shape of (240, 224, 224, 3), y_test has a shape of (240,)

# %%
# Finally, we normalize pixels in X_train and X_test to the range [0,1] for faster convergence
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# %%
lb = LabelEncoder()

y_train = np_utils.to_categorical(lb.fit_transform(y_train))
y_test = np_utils.to_categorical(lb.fit_transform(y_test))

# %%
from tensorflow.keras.applications import VGG16

vgg_model = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 3s 0us/step
# 58900480/58889256 [==============================] - 3s 0us/step

# %%
for layer in vgg_model.layers[:15]:
    layer.trainable = False

# %%
x = vgg_model.output
x = Flatten()(x) # Flatten dimensions to for use in FC layers
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x) # Dropout layer to reduce overfitting
x = Dense(256, activation='relu')(x)
x = Dense(8, activation='softmax')(x) # Softmax for multiclass
transfer_model = Model(inputs=vgg_model.input, outputs=x)

# %%
for i, layer in enumerate(transfer_model.layers):
    print(i, layer.name, layer.trainable)
# Out:
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool True
# 19 flatten True
# 20 dense True
# 21 dropout True
# 22 dense_1 True
# 23 dense_2 True

# %%
# reduce learning rate when val_accuracy has stopped improving
lr_reduce = ReduceLROnPlateau(monitor='val_accuracy', 
                              patience = 2, 
                              verbose=1,
                              factor=0.95, 
                              min_lr=0.000001)

checkpoint = ModelCheckpoint('ftzq.h15', monitor= 'val_accuracy', mode= 'max', save_best_only = True, verbose= 1)

# %%
train_datagen = ImageDataGenerator(
                                    zoom_range=0.3,
                                   rotation_range=20,
                                   width_shift_range=0.15)
#                                   #  height_shift_range=0.4,
#                                   #  shear_range=0.3,
#                                   #  horizontal_flip=True, 
#                                   #  fill_mode='nearest')

train_generator = train_datagen.flow(X_train,
                                     y_train,
                                     batch_size=1)

# %%
img_rows, img_cols = 224, 224

for x, y in train_datagen.flow(X_train, y_train, batch_size=9):
    # Show the first 9 images
    for i in range(0, 9):
        pyplot.subplot(330 + 1 + i)
        pyplot.imshow(x[i].reshape(img_rows, img_cols, 3))
    # show the plot
    pyplot.show()
    break

# %%
from tensorflow.keras import layers, models, Model, optimizers

learning_rate= 5e-5
transfer_model.compile(loss="categorical_crossentropy", optimizer=optimizers.Adam(lr=learning_rate), metrics=["accuracy"])

history = transfer_model.fit_generator(train_generator,
                    # steps_per_epoch=10,
                    validation_data=(X_test,y_test),
                    # validation_steps=20,
                    epochs=80,
                    callbacks=[lr_reduce,checkpoint])
                    # shuffle=True)
# Out:
# Epoch 1/80
# 1200/1200 [==============================] - ETA: 0s - loss: 2.0483 - accuracy: 0.1708
# Epoch 00001: val_accuracy improved from -inf to 0.32083, saving model to ftzq.h15
# INFO:tensorflow:Assets written to: ftzq.h15/assets
# 1200/1200 [==============================] - 227s 189ms/step - loss: 2.0483 - accuracy: 0.1708 - val_loss: 2.1248 - val_accuracy: 0.3208 - lr: 5.0000e-05
# Epoch 2/80
# 1200/1200 [==============================] - ETA: 0s - loss: 1.8301 - accuracy: 0.3033
# Epoch 00002: val_accuracy improved from 0.32083 to 0.37917, saving model to ftzq.h15
# INFO:tensorflow:Assets written to: ftzq.h15/assets
# 1200/1200 [==============================] - 226s 189ms/step - loss: 1.8301 - accuracy: 0.3033 - val_loss: 1.7478 - val_accuracy: 0.3792 - lr: 5.0000e-05
# Epoch 3/80
# 1200/1200 [==============================] - ETA: 0s - loss: 1.6103 - accuracy: 0.4033
# Epoch 00003: val_accuracy improved from 0.37917 to 0.46250, saving model to ftzq.h15
# INFO:tensorflow:Assets written to: ftzq.h15/assets
# 1200/1200 [==============================] - 228s 190ms/step - loss: 1.6103 - accuracy: 0.4033 - val_loss: 1.4523 - val_accuracy: 0.4625 - lr: 5.0000e-05
# Epoch 4/80
# 1200/1200 [==============================] - ETA: 0s - loss: 1.4557 - accuracy: 0.4658
# Epoch 00004: val_accuracy improved from 0.46250 to 0.47083, saving model to ftzq.h15
# INFO:tensorflow:Assets written to: ftzq.h15/assets
# 1200/1200 [==============================] - 226s 188ms/step - loss: 1.4557 - accuracy: 0.4658 - val_loss: 1.5691 - val_accuracy: 0.4708 - lr: 5.0000e-05
# Epoch 5/80
# 1200/1200 [==============================] - ETA: 0s - loss: 1
val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 219s 182ms/step - loss: 0.5121 - accuracy: 0.8183 - val_loss: 1.8301 - val_accuracy: 0.5917 - lr: 4.0725e-05
# Epoch 19/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.5121 - accuracy: 0.8308
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.868904459523037e-05.
#
# Epoch 00019: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 219s 182ms/step - loss: 0.5121 - accuracy: 0.8308 - val_loss: 1.8756 - val_accuracy: 0.5625 - lr: 4.0725e-05
# Epoch 20/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.4249 - accuracy: 0.8583
# Epoch 00020: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 219s 182ms/step - loss: 0.4249 - accuracy: 0.8583 - val_loss: 2.0361 - val_accuracy: 0.5625 - lr: 3.8689e-05
# Epoch 21/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.4228 - accuracy: 0.8567
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 3.6754593747900795e-05.
#
# Epoch 00021: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 220s 183ms/step - loss: 0.4228 - accuracy: 0.8567 - val_loss: 1.7745 - val_accuracy: 0.6000 - lr: 3.8689e-05
# Epoch 22/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.3812 - accuracy: 0.8583
# Epoch 00022: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 220s 183ms/step - loss: 0.3812 - accuracy: 0.8583 - val_loss: 2.0844 - val_accuracy: 0.5667 - lr: 3.6755e-05
# Epoch 23/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.3786 - accuracy: 0.8683
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 3.491686475172173e-05.
#
# Epoch 00023: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 219s 183ms/step - loss: 0.3786 - accuracy: 0.8683 - val_loss: 2.1064 - val_accuracy: 0.5500 - lr: 3.6755e-05
# Epoch 24/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.3499 - accuracy: 0.8867
# Epoch 00024: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 218s 182ms/step - loss: 0.3499 - accuracy: 0.8867 - val_loss: 2.6439 - val_accuracy: 0.5417 - lr: 3.4917e-05
# Epoch 25/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.3510 - accuracy: 0.8850
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.3171022550959606e-05.
#
# Epoch 00025: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 219s 182ms/step - loss: 0.3510 - accuracy: 0.8850 - val_loss: 2.1938 - val_accuracy: 0.5958 - lr: 3.4917e-05
# Epoch 26/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.3152 - accuracy: 0.8908
# Epoch 00026: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 220s 183ms/step - loss: 0.3152 - accuracy: 0.8908 - val_loss: 2.0491 - val_accuracy: 0.5833 - lr: 3.3171e-05
# Epoch 27/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.2517 - accuracy: 0.9133
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 3.1512470559391656e-05.
#
# Epoch 00027: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 221s 184ms/step - loss: 0.2517 - accuracy: 0.9133 - val_loss: 2.6457 - val_accuracy: 0.5458 - lr: 3.3171e-05
# Epoch 28/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.2562 - accuracy: 0.9192
# Epoch 00028: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 218s 182ms/step - loss: 0.2562 - accuracy: 0.9192 - val_loss: 2.5471 - val_accuracy: 0.5958 - lr: 3.1512e-05
# Epoch 29/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.2151 - accuracy: 0.9342
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 2.9936847204226067e-05.
#
# Epoch 00029: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 220s 183ms/step - loss: 0.2151 - accuracy: 0.9342 - val_loss: 2.3796 - val_accuracy: 0.5750 - lr: 3.1512e-05
# Epoch 30/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.1961 - accuracy: 0.9325
# Epoch 00030: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 218s 182ms/step - loss: 0.1961 - accuracy: 0.9325 - val_loss: 3.1523 - val_accuracy: 0.5417 - lr: 2.9937e-05
# Epoch 31/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.2023 - accuracy: 0.9375
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 2.844000518962275e-05.
#
# Epoch 00031: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 218s 182ms/step - loss: 0.2023 - accuracy: 0.9375 - val_loss: 2.7931 - val_accuracy: 0.5667 - lr: 2.9937e-05
# Epoch 32/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.2069 - accuracy: 0.9250
# Epoch 00032: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 218s 182ms/step - loss: 0.2069 - accuracy: 0.9250 - val_loss: 2.7689 - val_accuracy: 0.5750 - lr: 2.8440e-05
# Epoch 33/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.1875 - accuracy: 0.9317
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 2.7018004584533627e-05.
#
# Epoch 00033: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 218s 182ms/step - loss: 0.1875 - accuracy: 0.9317 - val_loss: 2.5723 - val_accuracy: 0.6000 - lr: 2.8440e-05
# Epoch 34/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.9433
# Epoch 00034: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 219s 182ms/step - loss: 0.1877 - accuracy: 0.9433 - val_loss: 2.9020 - val_accuracy: 0.5750 - lr: 2.7018e-05
# Epoch 35/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9617
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 2.5667104182502953e-05.
#
# Epoch 00035: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 221s 184ms/step - loss: 0.1439 - accuracy: 0.9617 - val_loss: 3.5623 - val_accuracy: 0.5500 - lr: 2.7018e-05
# Epoch 36/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.1239 - accuracy: 0.9592
# Epoch 00036: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 218s 182ms/step - loss: 0.1239 - accuracy: 0.9592 - val_loss: 3.2214 - val_accuracy: 0.5792 - lr: 2.5667e-05
# Epoch 37/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9600
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 2.438374940538779e-05.
#
# Epoch 00037: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 219s 183ms/step - loss: 0.1414 - accuracy: 0.9600 - val_loss: 3.5766 - val_accuracy: 0.5250 - lr: 2.5667e-05
# Epoch 38/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.1569 - accuracy: 0.9483
# Epoch 00038: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 218s 182ms/step - loss: 0.1569 - accuracy: 0.9483 - val_loss: 3.3995 - val_accuracy: 0.5667 - lr: 2.4384e-05
# Epoch 39/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.1259 - accuracy: 0.9583
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 2.31645619351184e-05.
#
# Epoch 00039: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 218s 182ms/step - loss: 0.1259 - accuracy: 0.9583 - val_loss: 2.6589 - val_accuracy: 0.5875 - lr: 2.4384e-05
# Epoch 40/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9675
# Epoch 00040: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 221s 184ms/step - loss: 0.1011 - accuracy: 0.9675 - val_loss: 3.0693 - val_accuracy: 0.6000 - lr: 2.3165e-05
# Epoch 41/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.1007 - accuracy: 0.9692
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 2.2006334529578452e-05.
#
# Epoch 00041: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 217s 181ms/step - loss: 0.1007 - accuracy: 0.9692 - val_loss: 3.3679 - val_accuracy: 0.5917 - lr: 2.3165e-05
# Epoch 42/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.1537 - accuracy: 0.9575
# Epoch 00042: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 219s 183ms/step - loss: 0.1537 - accuracy: 0.9575 - val_loss: 3.2442 - val_accuracy: 0.5833 - lr: 2.2006e-05
# Epoch 43/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.9725
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 2.0906017198285554e-05.
#
# Epoch 00043: val_accuracy did not improve from 0.60000
# 1200/1200 [==============================] - 217s 181ms/step - loss: 0.0855 - accuracy: 0.9725 - val_loss: 3.7643 - val_accuracy: 0.5667 - lr: 2.2006e-05
# Epoch 44/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.9600
# Epoch 00044: val_accuracy improved from 0.60000 to 0.60417, saving model to ftzq.h15
# INFO:tensorflow:Assets written to: ftzq.h15/assets
# 1200/1200 [==============================] - 231s 192ms/step - loss: 0.1226 - accuracy: 0.9600 - val_loss: 3.2473 - val_accuracy: 0.6042 - lr: 2.0906e-05
# Epoch 45/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9675
# Epoch 00045: val_accuracy did not improve from 0.60417
# 1200/1200 [==============================] - 226s 189ms/step - loss: 0.1137 - accuracy: 0.9675 - val_loss: 3.0406 - val_accuracy: 0.5875 - lr: 2.0906e-05
# Epoch 46/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0814 - accuracy: 0.9750
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1.9860715474351307e-05.
#
# Epoch 00046: val_accuracy did not improve from 0.60417
# 1200/1200 [==============================] - 222s 185ms/step - loss: 0.0814 - accuracy: 0.9750 - val_loss: 3.2726 - val_accuracy: 0.6000 - lr: 2.0906e-05
# Epoch 47/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9742
# Epoch 00047: val_accuracy did not improve from 0.60417
# 1200/1200 [==============================] - 220s 183ms/step - loss: 0.0768 - accuracy: 0.9742 - val_loss: 3.5628 - val_accuracy: 0.5792 - lr: 1.9861e-05
# Epoch 48/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0679 - accuracy: 0.9783
# Epoch 00048: val_accuracy improved from 0.60417 to 0.61250, saving model to ftzq.h15
# INFO:tensorflow:Assets written to: ftzq.h15/assets
# 1200/1200 [==============================] - 225s 188ms/step - loss: 0.0679 - accuracy: 0.9783 - val_loss: 3.2065 - val_accuracy: 0.6125 - lr: 1.9861e-05
# Epoch 49/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9858
# Epoch 00049: val_accuracy did not improve from 0.61250
# 1200/1200 [==============================] - 221s 184ms/step - loss: 0.0455 - accuracy: 0.9858 - val_loss: 4.2401 - val_accuracy: 0.5833 - lr: 1.9861e-05
# Epoch 50/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.1121 - accuracy: 0.9708
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 1.886768004624173e-05.
#
# Epoch 00050: val_accuracy did not improve from 0.61250
# 1200/1200 [==============================] - 220s 183ms/step - loss: 0.1121 - accuracy: 0.9708 - val_loss: 3.8190 - val_accuracy: 0.5958 - lr: 1.9861e-05
# Epoch 51/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.9808
# Epoch 00051: val_accuracy did not improve from 0.61250
# 1200/1200 [==============================] - 220s 183ms/step - loss: 0.0803 - accuracy: 0.9808 - val_loss: 4.2084 - val_accuracy: 0.5792 - lr: 1.8868e-05
# Epoch 52/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.9708
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 1.792429638953763e-05.
#
# Epoch 00052: val_accuracy did not improve from 0.61250
# 1200/1200 [==============================] - 219s 183ms/step - loss: 0
ms/step - loss: 0.0177 - accuracy: 0.9942 - val_loss: 4.1678 - val_accuracy: 0.5792 - lr: 1.1891e-05
# Epoch 71/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9883
# Epoch 00071: val_accuracy did not improve from 0.61250
# 1200/1200 [==============================] - 229s 190ms/step - loss: 0.0395 - accuracy: 0.9883 - val_loss: 4.0876 - val_accuracy: 0.6000 - lr: 1.1297e-05
# Epoch 72/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9933
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 1.073193843694753e-05.
#
# Epoch 00072: val_accuracy did not improve from 0.61250
# 1200/1200 [==============================] - 227s 189ms/step - loss: 0.0184 - accuracy: 0.9933 - val_loss: 4.8862 - val_accuracy: 0.5875 - lr: 1.1297e-05
# Epoch 73/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.9842
# Epoch 00073: val_accuracy did not improve from 0.61250
# 1200/1200 [==============================] - 225s 187ms/step - loss: 0.0572 - accuracy: 0.9842 - val_loss: 4.3832 - val_accuracy: 0.5833 - lr: 1.0732e-05
# Epoch 74/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9908
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 1.0195341428698156e-05.
#
# Epoch 00074: val_accuracy did not improve from 0.61250
# 1200/1200 [==============================] - 224s 187ms/step - loss: 0.0362 - accuracy: 0.9908 - val_loss: 4.2694 - val_accuracy: 0.5792 - lr: 1.0732e-05
# Epoch 75/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9917
# Epoch 00075: val_accuracy did not improve from 0.61250
# 1200/1200 [==============================] - 228s 190ms/step - loss: 0.0188 - accuracy: 0.9917 - val_loss: 5.0252 - val_accuracy: 0.5667 - lr: 1.0195e-05
# Epoch 76/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9917
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 9.685573968454263e-06.
#
# Epoch 00076: val_accuracy did not improve from 0.61250
# 1200/1200 [==============================] - 226s 188ms/step - loss: 0.0213 - accuracy: 0.9917 - val_loss: 5.0034 - val_accuracy: 0.5833 - lr: 1.0195e-05
# Epoch 77/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9958
# Epoch 00077: val_accuracy did not improve from 0.61250
# 1200/1200 [==============================] - 224s 187ms/step - loss: 0.0230 - accuracy: 0.9958 - val_loss: 4.9358 - val_accuracy: 0.5875 - lr: 9.6856e-06
# Epoch 78/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9933
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 9.201295097227557e-06.
#
# Epoch 00078: val_accuracy did not improve from 0.61250
# 1200/1200 [==============================] - 226s 188ms/step - loss: 0.0286 - accuracy: 0.9933 - val_loss: 4.3401 - val_accuracy: 0.6000 - lr: 9.6856e-06
# Epoch 79/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9908
# Epoch 00079: val_accuracy did not improve from 0.61250
# 1200/1200 [==============================] - 237s 198ms/step - loss: 0.0241 - accuracy: 0.9908 - val_loss: 4.9905 - val_accuracy: 0.5792 - lr: 9.2013e-06
# Epoch 80/80
# 1200/1200 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9967
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 8.741230385567177e-06.
#
# Epoch 00080: val_accuracy did not improve from 0.61250
# 1200/1200 [==============================] - 225s 188ms/step - loss: 0.0122 - accuracy: 0.9967 - val_loss: 4.7548 - val_accuracy: 0.5792 - lr: 9.2013e-06

# %%
transfer_model.save_weights("vgg16fineaugment_weights.h5")
transfer_model.save('vgg16fineaugment.h5')
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
        # PRINT MODEL HISTORY OF ACCURACY AND LOSS OVER EPOCHS
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')

plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
# plt.savefig('Augmented_Model_Accuracy.png')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
# plt.savefig('Augmented_Model_Loss.png')
plt.show()

# %%
from tensorflow import keras
model = keras.models.load_model('vgg16fineaugment.h5')

# %%
y_pred = transfer_model.predict(X_test)
Y_pred_classes = np.argmax(y_pred,axis=1) 
Y_true = np.argmax(y_test,axis=1)
dict_characters = {0: 'angry', 1: 'calm', 2: 'disgust', 3: 'fearful', 4: 'happy', 5: 'neutral', 6: 'sad', 7: 'surprised'}

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_true, Y_pred_classes, target_names = ['angry','calm','disgust','fearful','happy','neutral','sad','surprised']))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.60      0.81      0.69        32
#         calm       0.69      0.62      0.66        32
#      disgust       0.55      0.66      0.60        32
#      fearful       0.59      0.53      0.56        32
#        happy       0.57      0.25      0.35        32
#      neutral       0.50      0.44      0.47        16
#          sad       0.34      0.41      0.37        32
#    surprised       0.77      0.84      0.81        32
#
#     accuracy                           0.58       240
#    macro avg       0.58      0.57      0.56       240
# weighted avg       0.58      0.58      0.57       240
