# %%
# Discard the output of this cell.
#%%capture

# Install the required libraries.
# !pip install tensorflow opencv-contrib-python youtube-dl moviepy pydot
# !pip install git+https://github.com/TahaAnwar/pafy.git#egg=pafy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.8.2+zzzcolab20220527125636)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Collecting youtube-dl
#   Downloading youtube_dl-2021.12.17-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 5.1 MB/s
# Requirement already satisfied: moviepy in /usr/local/lib/python3.7/dist-packages (0.2.3.5)
# Requirement already satisfied: pydot in /usr/local/lib/python3.7/dist-packages (1.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (4.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.46.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow) (1.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.23.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from moviepy) (4.64.0)
# Requirement already satisfied: imageio<3.0,>=2.1.2 in /usr/local/lib/python3.7/dist-packages (from moviepy) (2.4.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.1.2->moviepy) (7.1.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from pydot) (3.0.9)
# Installing collected packages: youtube-dl
# Successfully installed youtube-dl-2021.12.17
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pafy
#   Cloning https://github.com/TahaAnwar/pafy.git to /tmp/pip-install-ihx9ebu9/pafy_e31e19d2d0584ceba044dd1b418ecbe2
#   Running command git clone -q https://github.com/TahaAnwar/pafy.git /tmp/pip-install-ihx9ebu9/pafy_e31e19d2d0584ceba044dd1b418ecbe2
# Building wheels for collected packages: pafy
#   Building wheel for pafy (setup.py) ... done
#   Created wheel for pafy: filename=pafy-0.5.5-py2.py3-none-any.whl size=35706 sha256=9b8dcfb32d8dbb5164db1f6787eb8a050e9905130650892b7be788aee57b5b06
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zew0kw1x/wheels/64/82/dd/3d7823b3bbbe1aca9b30f8cf0d6bb6c1b72ccd95e3360f8190
# Successfully built pafy
# Installing collected packages: pafy
# Successfully installed pafy-0.5.5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import the required libraries.
import os
import cv2
import pafy
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

from moviepy.editor import *
# %matplotlib inline

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %%
seed_constant = 27
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %%
# Create a Matplotlib figure and specify the size of the figure.
plt.figure(figsize = (20, 20))

# Get the names of all classes/categories in UCF50.
all_classes_names = os.listdir('/content/drive/MyDrive/SAVEEvideowithlabel')

# Generate a list of 20 random values. The values will be between 0-50, 
# where 50 is the total number of class in the dataset. 
random_range = random.sample(range(len(all_classes_names)),5)

# Iterating through all the generated random values.
for counter, random_index in enumerate(random_range, 1):

    # Retrieve a Class Name using the Random Index.
    selected_class_Name = all_classes_names[random_index]

    # Retrieve the list of all the video files present in the randomly selected Class Directory.
    video_files_names_list = os.listdir(f'/content/drive/MyDrive/SAVEEvideowithlabel/{selected_class_Name}')

    # Randomly select a video file from the list retrieved from the randomly selected Class Directory.
    selected_video_file_name = random.choice(video_files_names_list)

    # Initialize a VideoCapture object to read from the video File.
    video_reader = cv2.VideoCapture(f'/content/drive/MyDrive/SAVEEvideowithlabel/{selected_class_Name}/{selected_video_file_name}')
    
    # Read the first frame of the video file.
    _, bgr_frame = video_reader.read()

    # Release the VideoCapture object. 
    video_reader.release()

    # Convert the frame from BGR into RGB format. 
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)

    # Write the class name on the video frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    
 # Adding The Class Name Text on top of the Video Frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

    # Display the frame.
    plt.subplot(5, 4, counter);plt.imshow(rgb_frame);plt.axis('off')

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 64, 64

# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 30

# Specify the directory containing the UCF50 dataset. 
#DATASET_DIR = "/content/drive/MyDrive/videospeechsong_label"

# Specify the list containing the names of the classes used for training. Feel free to choose any set of classes.
CLASSES_LIST = ["neutral", "happy", "sad","angry","fearful"]

# %%
import joblib
features = joblib.load('/content/drive/My Drive/SAVEEfeatures/features_data')
labels = joblib.load('/content/drive/MyDrive/SAVEEfeatures/labels')
video_files_paths = joblib.load('/content/drive/My Drive/SAVEEfeatures/video_path')

# %%
features = np.asarray(features)
labels = np.array(labels)

# %%
features.shape
# Out:
# (360, 30, 64, 64, 3)

# %%
# Using Keras's to_categorical method to convert labels into one-hot-encoded vectors
one_hot_encoded_labels = to_categorical(labels)

# %%
# Split the Data into Train ( 80% ) and Test Set ( 20% ).
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels,
                                                                            test_size = 0.10, shuffle = True,
                                                                            random_state = seed_constant)

# %%
def create_LRCN_model():
    '''
    This function will construct the required LRCN model.
    Returns:
        model: It is the required constructed LRCN model.
    '''

    # We will use a Sequential model for model construction.
    model = Sequential()
   
    # Define the Model Architecture.
    ########################################################################################################################
    
    model.add(TimeDistributed(Conv2D(16, (5, 5), padding='same'),
                              input_shape = (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(Activation('relu')))
    model.add(TimeDistributed(MaxPooling2D((4, 4)))) 
    model.add(TimeDistributed(Dropout(0.1)))
    
    model.add(TimeDistributed(Conv2D(32, (5, 5), padding='same')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(Activation('relu')))
    model.add(TimeDistributed(MaxPooling2D((4, 4))))
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(TimeDistributed(Conv2D(64, (5, 5), padding='same')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(Activation('relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Dropout(0.3)))
    
    model.add(TimeDistributed(Conv2D(64, (5, 5), padding='same')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(Activation('relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    #model.add(TimeDistributed(Dropout(0.25)))
                                      
    model.add(TimeDistributed(Flatten()))
                                      
    model.add(LSTM(64))
                                      
    model.add(Dense(len(CLASSES_LIST), activation = 'softmax'))

    ########################################################################################################################

    # Display the models summary.
    model.summary()
    
    # Return the constructed LRCN model.
    return model

# %%
# Construct the required LRCN model.
LRCN_model = create_LRCN_model()

# Display the success message.
print("Model Created Successfully!")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 30, 64, 64, 16)   1216
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 30, 64, 64, 16)   64
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 30, 64, 64, 16)   0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 30, 16, 16, 16)   0
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 30, 16, 16, 16)   0
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 30, 16, 16, 32)   12832
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 30, 16, 16, 32)   128
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 30, 16, 16, 32)   0
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 30, 4, 4, 32)     0
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 30, 4, 4, 32)     0
#  tributed)
#
#  time_distributed_10 (TimeDi  (None, 30, 4, 4, 64)     51264
#  stributed)
#
#  time_distributed_11 (TimeDi  (None, 30, 4, 4, 64)     256
#  stributed)
#
#  time_distributed_12 (TimeDi  (None, 30, 4, 4, 64)     0
#  stributed)
#
#  time_distributed_13 (TimeDi  (None, 30, 2, 2, 64)     0
#  stributed)
#
#  time_distributed_14 (TimeDi  (None, 30, 2, 2, 64)     0
#  stributed)
#
#  time_distributed_15 (TimeDi  (None, 30, 2, 2, 64)     102464
#  stributed)
#
#  time_distributed_16 (TimeDi  (None, 30, 2, 2, 64)     256
#  stributed)
#
#  time_distributed_17 (TimeDi  (None, 30, 2, 2, 64)     0
#  stributed)
#
#  time_distributed_18 (TimeDi  (None, 30, 1, 1, 64)     0
#  stributed)
#
#  time_distributed_19 (TimeDi  (None, 30, 64)           0
#  stributed)
#
#  lstm (LSTM)                 (None, 64)                33024
#
#  dense (Dense)               (None, 5)                 325
#
# =================================================================
# Total params: 201,829
# Trainable params: 201,477
# Non-trainable params: 352
# _________________________________________________________________
# Model Created Successfully!

# %%
# Create an Instance of Early Stopping Callback.
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 25, mode = 'min', restore_best_weights = True)
 
# Compile the model and specify loss function, optimizer and metrics to the model.
LRCN_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# Start training the model.
LRCN_model_training_history = LRCN_model.fit(x = features_train, y = labels_train, epochs = 100, batch_size = 4 ,
                                             shuffle = True, validation_split = 0.1, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/100
# 73/73 [==============================] - 17s 30ms/step - loss: 1.5952 - accuracy: 0.3127 - val_loss: 1.6319 - val_accuracy: 0.3030
# Epoch 2/100
# 73/73 [==============================] - 1s 16ms/step - loss: 1.5721 - accuracy: 0.3368 - val_loss: 1.6118 - val_accuracy: 0.1818
# Epoch 3/100
# 73/73 [==============================] - 1s 16ms/step - loss: 1.4921 - accuracy: 0.4055 - val_loss: 1.6920 - val_accuracy: 0.3636
# Epoch 4/100
# 73/73 [==============================] - 1s 16ms/step - loss: 1.4554 - accuracy: 0.4089 - val_loss: 1.6908 - val_accuracy: 0.3030
# Epoch 5/100
# 73/73 [==============================] - 1s 16ms/step - loss: 1.4127 - accuracy: 0.3952 - val_loss: 1.5239 - val_accuracy: 0.3636
# Epoch 6/100
# 73/73 [==============================] - 1s 16ms/step - loss: 1.4335 - accuracy: 0.4124 - val_loss: 1.5633 - val_accuracy: 0.3030
# Epoch 7/100
# 73/73 [==============================] - 1s 16ms/step - loss: 1.3543 - accuracy: 0.4192 - val_loss: 1.4505 - val_accuracy: 0.3333
# Epoch 8/100
# 73/73 [==============================] - 1s 16ms/step - loss: 1.3053 - accuracy: 0.4364 - val_loss: 1.9366 - val_accuracy: 0.3333
# Epoch 9/100
# 73/73 [==============================] - 1s 16ms/step - loss: 1.2429 - accuracy: 0.4467 - val_loss: 1.4689 - val_accuracy: 0.2727
# Epoch 10/100
# 73/73 [==============================] - 1s 16ms/step - loss: 1.1639 - accuracy: 0.4983 - val_loss: 1.4226 - val_accuracy: 0.3030
# Epoch 11/100
# 73/73 [==============================] - 1s 16ms/step - loss: 1.1151 - accuracy: 0.4811 - val_loss: 1.6757 - val_accuracy: 0.3939
# Epoch 12/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.9937 - accuracy: 0.5223 - val_loss: 2.7403 - val_accuracy: 0.2727
# Epoch 13/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.9583 - accuracy: 0.5670 - val_loss: 1.1566 - val_accuracy: 0.5152
# Epoch 14/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.9167 - accuracy: 0.5945 - val_loss: 0.7997 - val_accuracy: 0.5455
# Epoch 15/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.8032 - accuracy: 0.6117 - val_loss: 1.5413 - val_accuracy: 0.5152
# Epoch 16/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.8333 - accuracy: 0.6323 - val_loss: 1.4321 - val_accuracy: 0.4848
# Epoch 17/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.7440 - accuracy: 0.6770 - val_loss: 0.7124 - val_accuracy: 0.6667
# Epoch 18/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.6464 - accuracy: 0.7216 - val_loss: 1.0753 - val_accuracy: 0.5152
# Epoch 19/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.7288 - accuracy: 0.6907 - val_loss: 1.0452 - val_accuracy: 0.5758
# Epoch 20/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.6595 - accuracy: 0.7285 - val_loss: 0.6316 - val_accuracy: 0.6667
# Epoch 21/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.5809 - accuracy: 0.7251 - val_loss: 0.8047 - val_accuracy: 0.6364
# Epoch 22/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.6435 - accuracy: 0.7216 - val_loss: 0.6503 - val_accuracy: 0.7576
# Epoch 23/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.4369 - accuracy: 0.8316 - val_loss: 0.7550 - val_accuracy: 0.7576
# Epoch 24/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.4498 - accuracy: 0.8419 - val_loss: 1.0519 - val_accuracy: 0.6061
# Epoch 25/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.4308 - accuracy: 0.8454 - val_loss: 0.7668 - val_accuracy: 0.7273
# Epoch 26/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.4388 - accuracy: 0.8454 - val_loss: 1.0679 - val_accuracy: 0.5758
# Epoch 27/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.2983 - accuracy: 0.8832 - val_loss: 0.7374 - val_accuracy: 0.6970
# Epoch 28/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.3415 - accuracy: 0.8729 - val_loss: 0.4015 - val_accuracy: 0.8182
# Epoch 29/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.2252 - accuracy: 0.9141 - val_loss: 0.3995 - val_accuracy: 0.8788
# Epoch 30/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.2941 - accuracy: 0.8969 - val_loss: 0.2240 - val_accuracy: 0.9091
# Epoch 31/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.3075 - accuracy: 0.9107 - val_loss: 0.5084 - val_accuracy: 0.7576
# Epoch 32/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1925 - accuracy: 0.9450 - val_loss: 0.2876 - val_accuracy: 0.9091
# Epoch 33/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.2445 - accuracy: 0.9313 - val_loss: 0.3977 - val_accuracy: 0.8485
# Epoch 34/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.2057 - accuracy: 0.9141 - val_loss: 0.3459 - val_accuracy: 0.8788
# Epoch 35/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.2702 - accuracy: 0.9072 - val_loss: 0.8720 - val_accuracy: 0.7273
# Epoch 36/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.2155 - accuracy: 0.9313 - val_loss: 0.7691 - val_accuracy: 0.7576
# Epoch 37/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.2958 - accuracy: 0.8969 - val_loss: 0.1508 - val_accuracy: 0.9394
# Epoch 38/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1416 - accuracy: 0.9588 - val_loss: 0.3297 - val_accuracy: 0.8788
# Epoch 39/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1698 - accuracy: 0.9485 - val_loss: 0.2352 - val_accuracy: 0.8788
# Epoch 40/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1301 - accuracy: 0.9588 - val_loss: 0.2965 - val_accuracy: 0.8788
# Epoch 41/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1989 - accuracy: 0.9210 - val_loss: 0.5754 - val_accuracy: 0.8182
# Epoch 42/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.2032 - accuracy: 0.9416 - val_loss: 0.3932 - val_accuracy: 0.8788
# Epoch 43/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.2083 - accuracy: 0.9175 - val_loss: 0.2337 - val_accuracy: 0.9091
# Epoch 44/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0921 - accuracy: 0.9656 - val_loss: 0.1606 - val_accuracy: 0.9394
# Epoch 45/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0888 - accuracy: 0.9759 - val_loss: 0.1095 - val_accuracy: 0.9697
# Epoch 46/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0663 - accuracy: 0.9759 - val_loss: 0.1467 - val_accuracy: 0.9394
# Epoch 47/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1000 - accuracy: 0.9656 - val_loss: 0.5084 - val_accuracy: 0.8182
# Epoch 48/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0752 - accuracy: 0.9759 - val_loss: 0.1277 - val_accuracy: 0.9394
# Epoch 49/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1299 - accuracy: 0.9553 - val_loss: 2.7875 - val_accuracy: 0.2424
# Epoch 50/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1200 - accuracy: 0.9656 - val_loss: 0.6498 - val_accuracy: 0.8485
# Epoch 51/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0775 - accuracy: 0.9725 - val_loss: 0.2793 - val_accuracy: 0.9394
# Epoch 52/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0485 - accuracy: 0.9863 - val_loss: 0.3142 - val_accuracy: 0.9394
# Epoch 53/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.3236 - val_accuracy: 0.9091
# Epoch 54/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0954 - accuracy: 0.9588 - val_loss: 0.1528 - val_accuracy: 0.9697
# Epoch 55/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1001 - accuracy: 0.9656 - val_loss: 0.6063 - val_accuracy: 0.8485
# Epoch 56/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1477 - accuracy: 0.9588 - val_loss: 0.1975 - val_accuracy: 0.9091
# Epoch 57/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1298 - accuracy: 0.9656 - val_loss: 0.1773 - val_accuracy: 0.9394
# Epoch 58/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0652 - accuracy: 0.9794 - val_loss: 0.2062 - val_accuracy: 0.9697
# Epoch 59/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0619 - accuracy: 0.9897 - val_loss: 0.2993 - val_accuracy: 0.9091
# Epoch 60/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0633 - accuracy: 0.9759 - val_loss: 0.1035 - val_accuracy: 0.9697
# Epoch 61/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1192 - accuracy: 0.9725 - val_loss: 0.3116 - val_accuracy: 0.9394
# Epoch 62/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0461 - accuracy: 0.9863 - val_loss: 0.2999 - val_accuracy: 0.9091
# Epoch 63/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.1962 - val_accuracy: 0.9091
# Epoch 64/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.1968 - val_accuracy: 0.9394
# Epoch 65/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0162 - accuracy: 0.9966 - val_loss: 0.1073 - val_accuracy: 0.9697
# Epoch 66/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1029 - accuracy: 0.9691 - val_loss: 0.1219 - val_accuracy: 0.9394
# Epoch 67/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1131 - accuracy: 0.9485 - val_loss: 0.7983 - val_accuracy: 0.7273
# Epoch 68/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0893 - accuracy: 0.9794 - val_loss: 0.3588 - val_accuracy: 0.9394
# Epoch 69/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0190 - accuracy: 0.9966 - val_loss: 0.0435 - val_accuracy: 1.0000
# Epoch 70/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0585 - accuracy: 0.9759 - val_loss: 0.2317 - val_accuracy: 0.9091
# Epoch 71/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.0755 - val_accuracy: 0.9697
# Epoch 72/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1239 - accuracy: 0.9553 - val_loss: 0.1319 - val_accuracy: 0.9394
# Epoch 73/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0629 - accuracy: 0.9794 - val_loss: 0.1894 - val_accuracy: 0.9394
# Epoch 74/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0768 - accuracy: 0.9794 - val_loss: 0.2678 - val_accuracy: 0.9091
# Epoch 75/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1853 - accuracy: 0.9313 - val_loss: 0.4573 - val_accuracy: 0.8182
# Epoch 76/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.1378 - accuracy: 0.9622 - val_loss: 0.2441 - val_accuracy: 0.9091
# Epoch 77/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0525 - accuracy: 0.9863 - val_loss: 0.4197 - val_accuracy: 0.8485
# Epoch 78/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0492 - accuracy: 0.9863 - val_loss: 0.4111 - val_accuracy: 0.9091
# Epoch 79/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0413 - accuracy: 0.9828 - val_loss: 0.2266 - val_accuracy: 0.9394
# Epoch 80/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9697
# Epoch 81/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0132 - accuracy: 0.9966 - val_loss: 0.0533 - val_accuracy: 0.9697
# Epoch 82/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0764 - accuracy: 0.9725 - val_loss: 0.1343 - val_accuracy: 0.9394
# Epoch 83/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0161 - accuracy: 0.9966 - val_loss: 0.1066 - val_accuracy: 0.9697
# Epoch 84/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0107 - accuracy: 0.9966 - val_loss: 0.1793 - val_accuracy: 0.9697
# Epoch 85/100
# 73/73 [==============================] - 1s 17ms/step - loss: 0.0149 - accuracy: 0.9931 - val_loss: 0.1871 - val_accuracy: 0.9394
# Epoch 86/100
# 73/73 [==============================] - 1s 17ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1299 - val_accuracy: 0.9697
# Epoch 87/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0071 - accuracy: 0.9966 - val_loss: 0.1736 - val_accuracy: 0.9394
# Epoch 88/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2355 - val_accuracy: 0.9394
# Epoch 89/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1605 - val_accuracy: 0.9394
# Epoch 90/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1120 - val_accuracy: 0.9394
# Epoch 91/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0764 - val_accuracy: 0.9697
# Epoch 92/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0965 - val_accuracy: 0.9697
# Epoch 93/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0132 - accuracy: 0.9966 - val_loss: 0.9734 - val_accuracy: 0.7576
# Epoch 94/100
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2627 - val_accuracy: 0.9091

# %%
# Evaluate the trained model.
model_evaluation_history = LRCN_model.evaluate(features_test, labels_test)
# Out:
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1308 - accuracy: 0.9444

# %%
# Get the loss and accuracy from model_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time_format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)
    
# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'LRCN_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'

# Save the Model.
LRCN_model.save(model_file_name)

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    '''
    This function will plot the metrics passed to it in a graph.
    Args:
        model_training_history: A history object containing a record of training and validation 
                                loss values and metrics values at successive epochs
        metric_name_1:          The name of the first metric that needs to be plotted in the graph.
        metric_name_2:          The name of the second metric that needs to be plotted in the graph.
        plot_name:              The title of the graph.
    '''
    
    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]
    
    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))

    # Plot the Graph.
    plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)

    # Add title to the plot.
    plt.title(str(plot_name))

    # Add legend to the plot.
    plt.legend()

# %%
# Visualize the training and validation loss metrices.
plot_metric(LRCN_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
# Visualize the training and validation accuracy metrices.
plot_metric(LRCN_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %%
predictions =  LRCN_model.predict(features_test)
predictions
# Out:
# array([[5.2536791e-03, 4.7998640e-04, 9.7782612e-01, 6.1254520e-03,
#         1.0314770e-02],
#        [6.5779112e-02, 3.0008338e-02, 4.2143916e-03, 8.2392216e-01,
#         7.6075941e-02],
#        [1.2850358e-05, 9.9739081e-01, 3.8677960e-04, 8.3748333e-04,
#         1.3720316e-03],
#        [1.9271602e-04, 5.8496697e-04, 1.6290635e-03, 8.0798727e-06,
#         9.9758518e-01],
#        [7.0634903e-04, 4.1755312e-03, 1.1333288e-03, 9.9349666e-01,
#         4.8821516e-04],
#        [8.8900402e-03, 5.0321547e-04, 3.2712287e-01, 7.2862243e-04,
#         6.6275525e-01],
#        [9.7572785e-03, 3.6426279e-04, 9.5313978e-01, 2.9648165e-03,
#         3.3773903e-02],
#        [4.5210724e-03, 4.7079034e-04, 9.7961491e-01, 5.4096761e-03,
#         9.9836225e-03],
#        [6.0936180e-04, 1.4405847e-03, 1.2022676e-03, 9.9643266e-01,
#         3.1508409e-04],
#        [1.9919706e-04, 5.5247860e-04, 1.1533767e-03, 8.6748269e-06,
#         9.9808633e-01],
#        [9.9904507e-01, 2.4379364e-05, 1.4850519e-04, 6.4711325e-04,
#         1.3485120e-04],
#        [9.9916863e-01, 2.3689008e-05, 1.6510794e-04, 3.9102838e-04,
#         2.5150256e-04],
#        [9.6361974e-04, 1.9204502e-03, 1.0088940e-02, 2.8323074e-04,
#         9.8674381e-01],
#        [6.7679852e-05, 9.8226190e-01, 1.0141465e-03, 3.6268174e-03,
#         1.3029490e-02],
#        [2.8888782e-04, 9.0412842e-04, 7.3461575e-03, 3.2652108e-05,
#         9.9142820e-01],
#        [9.3847248e-06, 9.9795097e-01, 3.2552693e-04, 6.7494792e-04,
#         1.0391059e-03],
#        [9.9934739e-01, 1.5506463e-05, 1.3724550e-04, 3.6296053e-04,
#         1.3692808e-04],
#        [9.9886703e-01, 2.4564320e-05, 2.0123206e-04, 6.8160635e-04,
#         2.2564598e-04],
#        [6.3665479e-04, 1.7239200e-03, 9.8664057e-04, 9.9634260e-01,
#         3.1017174e-04],
#        [9.9910957e-01, 2.3555574e-05, 1.7316107e-04, 4.7811851e-04,
#         2.1557992e-04],
#        [9.9931848e-01, 2.0392499e-05, 1.4338471e-04, 3.6132577e-04,
#         1.5645682e-04],
#        [6.7570480e-03, 3.7674489e-04, 9.7519344e-01, 4.0752487e-03,
#         1.3597507e-02],
#        [6.2839082e-04, 1.7144918e-03, 9.5842051e-04, 9.9639207e-01,
#         3.0652655e-04],
#        [9.9930525e-01, 1.7457343e-05, 1.3594930e-04, 4.1090834e-04,
#         1.3033532e-04],
#        [9.9920422e-01, 1.8342429e-05, 1.8707708e-04, 4.2621669e-04,
#         1.6408222e-04],
#        [9.9936801e-01, 1.5855150e-05, 1.3341021e-04, 3.5083506e-04,
#         1.3190020e-04],
#        [4.0820407e-05, 9.9163657e-01, 4.2645706e-04, 2.6459810e-03,
#         5.2501885e-03],
#        [7.1269169e-04, 1.6555177e-03, 8.7975635e-04, 9.9650300e-01,
#         2.4897978e-04],
#        [7.5150182e-04, 1.3586407e-03, 7.3190493e-04, 9.9694687e-01,
#         2.1120605e-04],
#        [9.9922311e-01, 2.1593747e-05, 1.4739024e-04, 4.5146706e-04,
#         1.5654996e-04],
#        [9.9838686e-01, 2.5854120e-05, 1.9147438e-04, 1.1902206e-03,
#         2.0569745e-04],
#        [9.2263436e-03, 1.2057815e-03, 6.9568196e-04, 9.8836982e-01,
#         5.0242280e-04],
#        [6.6826395e-03, 4.7257147e-04, 9.6660286e-01, 4.0468876e-03,
#         2.2195032e-02],
#        [1.5655240e-03, 1.4810911e-01, 2.4438217e-02, 5.2133065e-02,
#         7.7375406e-01],
#        [2.1755835e-03, 1.4220029e-03, 8.7979768e-04, 9.9472344e-01,
#         7.9922087e-04],
#        [5.1285428e-01, 9.4620924e-04, 4.1061205e-01, 5.1261976e-02,
#         2.4325490e-02]], dtype=float32)

# %%
preds=predictions.argmax(axis=1)
preds
# Out:
# array([2, 3, 1, 4, 3, 4, 2, 2, 3, 4, 0, 0, 4, 1, 4, 1, 0, 0, 3, 0, 0, 2,
#        3, 0, 0, 0, 1, 3, 3, 0, 0, 3, 2, 4, 3, 0])

# %%
new_preds = preds.astype(int).flatten()
new_preds
# Out:
# array([2, 3, 1, 4, 3, 4, 2, 2, 3, 4, 0, 0, 4, 1, 4, 1, 0, 0, 3, 0, 0, 2,
#        3, 0, 0, 0, 1, 3, 3, 0, 0, 3, 2, 4, 3, 0])

# %%
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
import seaborn as sn
import pandas as pd
import numpy as np
new_labels=np.argmax(labels_test, axis=1)
print(classification_report(new_labels,new_preds))

acc = float(accuracy_score(new_labels,new_preds))*100
print("----accuracy score %s ----" % acc)

cm = confusion_matrix(new_labels,new_preds)
#df_cm = pd.DataFrame(cm)
class_names = ['neutral', 'happy','sad','angry', 'fearful' ]
df_cm = pd.DataFrame(cm, index=class_names, columns=class_names,)
sn.heatmap(df_cm, annot=True, fmt='')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        11
#            1       1.00      1.00      1.00         4
#            2       1.00      0.83      0.91         6
#            3       1.00      0.90      0.95        10
#            4       0.83      1.00      0.91         5
#
#     accuracy                           0.94        36
#    macro avg       0.95      0.95      0.94        36
# weighted avg       0.95      0.94      0.94        36
#
# ----accuracy score 94.44444444444444 ----
