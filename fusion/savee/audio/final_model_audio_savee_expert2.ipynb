# %%
# Orignial Notebook: https://github.com/MITESHPUTHRANNEU/Speech-Emotion-Analyzer/blob/master/final_results_gender_test.ipynb
# This notebook author: Reza Chu
# Last Editing Date: 31st May 2019

## Python
import os
import random
import sys

import IPython
from IPython.display import Audio
from IPython.display import Image
import matplotlib.pyplot as plt

## Package
import glob 
import keras
import IPython.display as ipd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.graph_objs as go
import plotly.offline as py
import plotly.tools as tls
import seaborn as sns
import scipy.io.wavfile
import tensorflow as tf
py.init_notebook_mode(connected=True)

## Keras
from keras import regularizers
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from keras.callbacks import  History, ReduceLROnPlateau, CSVLogger
from keras.models import Model, Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.preprocessing import sequence
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils
from tensorflow.keras.utils import to_categorical

## Sklearn
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder

## Rest
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile
from tqdm import tqdm

input_duration=3
# % pylab inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#only SAVEE data set
import time
import os
import librosa
from librosa import display
import matplotlib.pyplot as plt
#sad/sa2dc.avi
labels = []
video_name=[]
audio_name=[]
count=0
start_time = time.time()
CLASSES_LIST=['KL','JK ','JE','DC']
DATASET_DIR = '/content/drive/My Drive/SAVEE'
emotion_LIST = ["neutral", "calm", "happy", "sad","angry","fearful"]
for class_index, class_name in enumerate(CLASSES_LIST):
#for subdir, dirs, files in os.walk(path):
  print(class_name)
  #dir=subdir.split('/')[4]
  #print(dir)
  
  files= os.listdir(os.path.join(DATASET_DIR, class_name))
  for file in files:
      try:
        print(file)
        #Load librosa array, obtain mfcss, store the file and the mcss information in a new array
        #X, sample_rate = librosa.load(os.path.join(subdir,file), res_type='kaiser_fast')
        #mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) 
        count +=1
        # The instruction below converts the labels (from 1 to 8) to a series from 0 to 7
        # This is because our predictor needs to start from 0 otherwise it will try to predict also 0.
        #file = int(file[7:8]) - 1 
        #0 = neutral, 1 = happy, 2 = sad, 3 = angry, 4 = fearful, 6 = disgust, 7 = surprised
        if file.startswith('a'):
            emotion=3
       # elif file.startswith('d'):
         #   emotion=6
        elif file.startswith('f'):
            emotion=4
        elif file.startswith('h'):
            emotion=1
        elif file.startswith('n'):
            emotion=0
        elif file.startswith('sa'):
            emotion=2
       # elif file.startswith('su'):
        #    emotion=7
        else:
            continue
        v=emotion_LIST[emotion]+'/'+file.split('.')[0]+class_name.lower()+'.avi'
        video_name.append(v)
        a=class_name+'/'+file

        audio_name.append(a)
        #arr = mfccs, emotion
        labels.append(emotion)
      # If the file is not valid, skip it
      except ValueError:
        continue

print("--- Data loaded. Loading time: %s seconds ---" % (time.time() - start_time))
# Out:
# KL
# a01.wav
# a02.wav
# a03.wav
# a04.wav
# a05.wav
# a07.wav
# a10.wav
# a09.wav
# a08.wav
# a06.wav
# a15.wav
# a14.wav
# a13.wav
# a12.wav
# a11.wav
# d05.wav
# d04.wav
# d03.wav
# d02.wav
# d01.wav
# d10.wav
# d09.wav
# d08.wav
# d07.wav
# d06.wav
# d15.wav
# d14.wav
# d13.wav
# d12.wav
# d11.wav
# f05.wav
# f04.wav
# f03.wav
# f02.wav
# f01.wav
# f10.wav
# f09.wav
# f08.wav
# f07.wav
# f06.wav
# f15.wav
# f14.wav
# f13.wav
# f12.wav
# f11.wav
# h05.wav
# h04.wav
# h03.wav
# h02.wav
# h01.wav
# h10.wav
# h09.wav
# h08.wav
# h07.wav
# h06.wav
# h15.wav
# h14.wav
# h13.wav
# h12.wav
# h11.wav
# sa05.wav
# sa04.wav
# sa03.wav
# sa02.wav
# sa01.wav
# sa10.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa11.wav
# sa14.wav
# sa13.wav
# sa12.wav
# sa15.wav
# su05.wav
# su03.wav
# su02.wav
# su01.wav
# su10.wav
# su09.wav
# su08.wav
# su07.wav
# su06.wav
# su15.wav
# su14.wav
# su13.wav
# su12.wav
# su11.wav
# su04.wav
# n01.wav
# n05.wav
# n04.wav
# n03.wav
# n02.wav
# n10.wav
# ...

# %%
audio_name
# Out:
# ['KL/a01.wav',
#  'KL/a02.wav',
#  'KL/a03.wav',
#  'KL/a04.wav',
#  'KL/a05.wav',
#  'KL/a07.wav',
#  'KL/a10.wav',
#  'KL/a09.wav',
#  'KL/a08.wav',
#  'KL/a06.wav',
#  'KL/a15.wav',
#  'KL/a14.wav',
#  'KL/a13.wav',
#  'KL/a12.wav',
#  'KL/a11.wav',
#  'KL/f05.wav',
#  'KL/f04.wav',
#  'KL/f03.wav',
#  'KL/f02.wav',
#  'KL/f01.wav',
#  'KL/f10.wav',
#  'KL/f09.wav',
#  'KL/f08.wav',
#  'KL/f07.wav',
#  'KL/f06.wav',
#  'KL/f15.wav',
#  'KL/f14.wav',
#  'KL/f13.wav',
#  'KL/f12.wav',
#  'KL/f11.wav',
#  'KL/h05.wav',
#  'KL/h04.wav',
#  'KL/h03.wav',
#  'KL/h02.wav',
#  'KL/h01.wav',
#  'KL/h10.wav',
#  'KL/h09.wav',
#  'KL/h08.wav',
#  'KL/h07.wav',
#  'KL/h06.wav',
#  'KL/h15.wav',
#  'KL/h14.wav',
#  'KL/h13.wav',
#  'KL/h12.wav',
#  'KL/h11.wav',
#  'KL/sa05.wav',
#  'KL/sa04.wav',
#  'KL/sa03.wav',
#  'KL/sa02.wav',
#  'KL/sa01.wav',
#  'KL/sa10.wav',
#  'KL/sa09.wav',
#  'KL/sa08.wav',
#  'KL/sa07.wav',
#  'KL/sa06.wav',
#  'KL/sa11.wav',
#  'KL/sa14.wav',
#  'KL/sa13.wav',
# ...

# %%
video_name
# Out:
# ['sad/a01kl.avi',
#  'sad/a02kl.avi',
#  'sad/a03kl.avi',
#  'sad/a04kl.avi',
#  'sad/a05kl.avi',
#  'sad/a07kl.avi',
#  'sad/a10kl.avi',
#  'sad/a09kl.avi',
#  'sad/a08kl.avi',
#  'sad/a06kl.avi',
#  'sad/a15kl.avi',
#  'sad/a14kl.avi',
#  'sad/a13kl.avi',
#  'sad/a12kl.avi',
#  'sad/a11kl.avi',
#  'angry/f05kl.avi',
#  'angry/f04kl.avi',
#  'angry/f03kl.avi',
#  'angry/f02kl.avi',
#  'angry/f01kl.avi',
#  'angry/f10kl.avi',
#  'angry/f09kl.avi',
#  'angry/f08kl.avi',
#  'angry/f07kl.avi',
#  'angry/f06kl.avi',
#  'angry/f15kl.avi',
#  'angry/f14kl.avi',
#  'angry/f13kl.avi',
#  'angry/f12kl.avi',
#  'angry/f11kl.avi',
#  'calm/h05kl.avi',
#  'calm/h04kl.avi',
#  'calm/h03kl.avi',
#  'calm/h02kl.avi',
#  'calm/h01kl.avi',
#  'calm/h10kl.avi',
#  'calm/h09kl.avi',
#  'calm/h08kl.avi',
#  'calm/h07kl.avi',
#  'calm/h06kl.avi',
#  'calm/h15kl.avi',
#  'calm/h14kl.avi',
#  'calm/h13kl.avi',
#  'calm/h12kl.avi',
#  'calm/h11kl.avi',
#  'happy/sa05kl.avi',
#  'happy/sa04kl.avi',
# ...

# %%
seed_constant = np.random.randint(1000000)
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)
seed_constant
# Out:
# 545807

# %%
from sklearn.model_selection import train_test_split
# Split the Data into Train ( 80% ) and Test Set ( 20% ).
audio_train, audio_test, labels_train, labels_test,video_train_path,video_test_path = train_test_split(audio_name, labels,video_name,
                                                                            test_size = 0.10, shuffle = True,
                                                                            random_state = seed_constant)

# %%
# Split train the Data into Train ( 80% ) and valid Set ( 20% ).
audio_train, audio_valid, labels_train, labels_valid,video_train_path,video_valid_path = train_test_split(audio_train, labels_train,video_train_path,
                                                                            test_size = 0.11, shuffle = True,
                                                                            random_state = seed_constant)

# %%
#288,36,36
len(audio_train),len(audio_valid),len(audio_test),len(labels_train),len(labels_valid),len(labels_test),len(video_train_path),len(video_valid_path),len(video_test_path)
# Out:
# (288, 36, 36, 288, 36, 36, 288, 36, 36)

# %%
import joblib

save_dir = '/content/drive/My Drive/fusion/savee/audio/data_set/expert2'

savedvX = joblib.dump(labels_train, os.path.join(save_dir, 'train/labels_train'))
savedvX = joblib.dump(labels_test, os.path.join(save_dir, 'test/labels_test'))
savedvX = joblib.dump(labels_valid, os.path.join(save_dir, 'valid/labels_valid'))
savedvX = joblib.dump(video_train_path, os.path.join(save_dir, 'train/video_train_path'))
savedvX = joblib.dump(video_test_path, os.path.join(save_dir, 'test/video_test_path'))
savedvX = joblib.dump(video_valid_path, os.path.join(save_dir, 'valid/video_valid_path'))

# %%
#radvass speech and song
import time
import os
import librosa
from librosa import display
import matplotlib.pyplot as plt
DATASET_DIR = '/content/drive/My Drive/SAVEE/'
count=0
x_test = []
X_valid=[]
start_time = time.time()

for path in audio_valid :
      try:
        count +=1
        #Load librosa array, obtain mfcss, store the file and the mcss information in a new array
        X, sample_rate = librosa.load(DATASET_DIR+path, res_type='kaiser_fast')
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) 
        # The instruction below converts the labels (from 1 to 8) to a series from 0 to 7
        # This is because our predictor needs to start from 0 otherwise it will try to predict also 0.
        #emo = int(file[7:8]) - 1 
        #arr = X, emo
        X_valid.append(mfccs)
      # If the file is not valid, skip it
      except ValueError:
        continue

for path in audio_test:
      try:
        count +=1
        #Load librosa array, obtain mfcss, store the file and the mcss information in a new array
        X, sample_rate = librosa.load(DATASET_DIR+path, res_type='kaiser_fast')
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) 
        # The instruction below converts the labels (from 1 to 8) to a series from 0 to 7
        # This is because our predictor needs to start from 0 otherwise it will try to predict also 0.
        #emo = int(file[7:8]) - 1 
        #arr = X, emo
        x_test.append(mfccs)
      # If the file is not valid, skip it
      except ValueError:
        continue
print("--- Data loaded. Loading time: %s seconds ---" % (time.time() - start_time))
# Out:
# --- Data loaded. Loading time: 6.491170167922974 seconds ---

# %%
X_valid=np.asarray(X_valid)
x_test=np.asarray(x_test)
X_valid.shape,x_test.shape
# Out:
# ((36, 40), (36, 40))

# %%
train_lst=[]
for i in range(len(audio_train)):
  X, sample_rate = librosa.load(DATASET_DIR+audio_train[i], res_type='kaiser_fast')
  emo=labels_train[i]
  x=X
  arr=x,emo
  train_lst.append(arr)
  x=librosa.effects.time_stretch(X,0.5)
  arr=x,emo
  train_lst.append(arr)
  x=librosa.effects.time_stretch(X,1.5)
  arr=x,emo
  train_lst.append(arr)
  x=librosa.effects.pitch_shift(X,sample_rate,2)
  arr=x,emo
  train_lst.append(arr)

# %%
x_train, y_train = zip(*train_lst)

# %%
x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
y_train.shape
# Out:
# (1152,)

# %%
X_train=[]
for i in range(x_train.size):
  X_train.append(np.mean(librosa.feature.mfcc(y=x_train[i], sr=sample_rate, n_mfcc=40).T,axis=0))

# %%
X_train=np.asarray(X_train)
labels_valid=np.asarray(labels_valid)
labels_test=np.asarray(labels_test)
X_train.shape,y_train.shape,X_valid.shape,labels_valid.shape,x_test.shape,labels_test.shape
# Out:
# ((1152, 40), (1152,), (36, 40), (36,), (36, 40), (36,))

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras import optimizers
from keras.models import InputLayer

model = Sequential(InputLayer((40,1)))
model.add(BatchNormalization())

model.add(Conv1D(128, 12,padding='same', ))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=(5)))


model.add(Conv1D(256,12,padding='same',))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(MaxPooling1D(pool_size=(5)))

model.add(Flatten())
model.add(Dense(5))
model.add(Activation('softmax'))

opt = tf.keras.optimizers.Adam(lr=0.0002)
#opt = tf.keras.optimizers.RMSprop(lr=0.0001, rho=0.9, epsilon=1e-07, decay=0.0)
#opt = tf.keras.optimizers.SGD(lr=0.001, momentum=0.0, decay=0.0, nesterov=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  batch_normalization (BatchN  (None, 40, 1)            4
#  ormalization)
#
#  conv1d (Conv1D)             (None, 40, 128)           1664
#
#  batch_normalization_1 (Batc  (None, 40, 128)          512
#  hNormalization)
#
#  activation (Activation)     (None, 40, 128)           0
#
#  dropout (Dropout)           (None, 40, 128)           0
#
#  max_pooling1d (MaxPooling1D  (None, 8, 128)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 8, 256)            393472
#
#  batch_normalization_2 (Batc  (None, 8, 256)           1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8, 256)            0
#
#  dropout_1 (Dropout)         (None, 8, 256)            0
#
#  max_pooling1d_1 (MaxPooling  (None, 1, 256)           0
#  1D)
#
#  flatten (Flatten)           (None, 256)               0
#
# ...

# %%
# Create an Instance of Early Stopping Callback.
#early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 25, mode = 'min', restore_best_weights = True)
 
# Compile the model and specify loss function, optimizer and metrics to the model.
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = opt, metrics = ["accuracy"])

# Start training the model.
cnnhistory = model.fit(X_train, y_train, epochs = 200, batch_size = 16 ,
                                             #shuffle = True,
                        validation_data=(X_valid, labels_valid))
                                             #, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/200
# 72/72 [==============================] - 3s 8ms/step - loss: 1.6080 - accuracy: 0.4123 - val_loss: 1.6133 - val_accuracy: 0.1667
# Epoch 2/200
# 72/72 [==============================] - 0s 5ms/step - loss: 1.2325 - accuracy: 0.5347 - val_loss: 2.0591 - val_accuracy: 0.1667
# Epoch 3/200
# 72/72 [==============================] - 1s 8ms/step - loss: 1.0682 - accuracy: 0.6024 - val_loss: 2.4187 - val_accuracy: 0.1667
# Epoch 4/200
# 72/72 [==============================] - 0s 6ms/step - loss: 0.9736 - accuracy: 0.6276 - val_loss: 2.8722 - val_accuracy: 0.1667
# Epoch 5/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.9068 - accuracy: 0.6484 - val_loss: 1.9364 - val_accuracy: 0.1944
# Epoch 6/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.9090 - accuracy: 0.6502 - val_loss: 1.6212 - val_accuracy: 0.2778
# Epoch 7/200
# ...

# %%
plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
loss, acc = model.evaluate(x_test, labels_test)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6383 - accuracy: 0.8056
# Restored model, accuracy: 80.56%

# %%
#predictions = model.predict_classes(x_testcnn)
predictions = model.predict(x_test)
predictions
# Out:
# array([[9.99995470e-01, 5.42651968e-09, 4.47107641e-06, 8.75346657e-08,
#         1.27054225e-08],
#        [9.97798383e-01, 1.81414234e-03, 3.33483680e-04, 1.58923285e-05,
#         3.80915117e-05],
#        [4.79517657e-05, 9.37344372e-01, 2.49168777e-04, 6.46798348e-04,
#         6.17117137e-02],
#        [9.78982806e-01, 1.76066707e-04, 1.98133998e-02, 8.79029045e-04,
#         1.48712643e-04],
#        [8.07260513e-01, 1.65583959e-04, 1.92522019e-01, 2.56918847e-05,
#         2.61336318e-05],
#        [1.62820681e-04, 7.99258947e-01, 1.34407792e-05, 1.97404131e-01,
#         3.16056935e-03],
#        [6.34188533e-01, 7.37017945e-06, 3.38957965e-01, 3.71062924e-05,
#         2.68090647e-02],
#        [9.98803616e-01, 1.16527826e-05, 1.17771910e-03, 6.62633113e-07,
#         6.32224192e-06],
#        [3.90231937e-01, 6.36293771e-05, 6.05562747e-01, 6.81643030e-07,
#         4.14106296e-03],
#        [7.80849041e-06, 1.70975136e-06, 9.98226583e-01, 1.46345956e-05,
# ...

# %%
df_audio_test = pd.DataFrame(predictions,columns=["OA_"+str(i) for i in range(5)])

# %%
labels_test
# Out:
# array([0, 0, 1, 2, 0, 1, 0, 0, 2, 2, 3, 0, 0, 0, 4, 2, 0, 2, 0, 0, 0, 1,
#        0, 0, 4, 2, 2, 3, 1, 4, 0, 4, 3, 3, 0, 0])

# %%
new_Ytest = labels_test.astype(int)
new_Ytest
# Out:
# array([0, 0, 1, 2, 0, 1, 0, 0, 2, 2, 3, 0, 0, 0, 4, 2, 0, 2, 0, 0, 0, 1,
#        0, 0, 4, 2, 2, 3, 1, 4, 0, 4, 3, 3, 0, 0])

# %%
preds1=predictions.argmax(axis=1)
preds1
# Out:
# array([0, 0, 1, 0, 0, 1, 0, 0, 2, 2, 1, 0, 0, 0, 4, 0, 0, 2, 0, 0, 0, 3,
#        0, 0, 4, 0, 2, 3, 1, 4, 0, 2, 4, 3, 0, 0])

# %%
abc = preds1.astype(int).flatten()
from sklearn.metrics import confusion_matrix
c = confusion_matrix(new_Ytest, abc) 
c
# Out:
# array([[17,  0,  0,  0,  0],
#        [ 0,  3,  0,  1,  0],
#        [ 3,  0,  4,  0,  0],
#        [ 0,  1,  0,  2,  1],
#        [ 0,  0,  1,  0,  3]])

# %%
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
import seaborn as sn

print(classification_report(labels_test,abc))

acc = float(accuracy_score(labels_test,abc))*100
print("----accuracy score %s ----" % acc)

cm = confusion_matrix(labels_test,abc)
#df_cm = pd.DataFrame(cm)
class_names = ['neutral', 'happy','sad','angry', 'fearful' ]
df_cm = pd.DataFrame(cm, index=class_names, columns=class_names,)
sn.heatmap(df_cm, annot=True, fmt='')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        17
#            1       0.75      0.75      0.75         4
#            2       0.80      0.57      0.67         7
#            3       0.67      0.50      0.57         4
#            4       0.75      0.75      0.75         4
#
#     accuracy                           0.81        36
#    macro avg       0.76      0.71      0.73        36
# weighted avg       0.80      0.81      0.79        36
#
# ----accuracy score 80.55555555555556 ----

# %%
model.save('/content/drive/My Drive/fusion/savee/audio/model/expert2/best_CNN_model')
print("MODEL SAVED")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/fusion/savee/audio/model/expert2/best_CNN_model/assets
# MODEL SAVED

# %%
model_file_name = f'/content/drive/My Drive/fusion/savee/audio/model/expert2/best_CNN_model___Loss_{loss}___Accuracy_{acc}.h5'

# Save the Model.
model.save(model_file_name)

# %%
# serialize model to JSON
model_json = model.to_json()
with open("/content/drive/My Drive/fusion/savee/audio/model/expert2/best_CNN_model.json", "w") as json_file:
    json_file.write(model_json)

# %%
count=0
new_x_train=[]
for path in audio_train :
      try:
        count +=1
        #Load librosa array, obtain mfcss, store the file and the mcss information in a new array
        X, sample_rate = librosa.load(DATASET_DIR+path, res_type='kaiser_fast')
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) 
        # The instruction below converts the labels (from 1 to 8) to a series from 0 to 7
        # This is because our predictor needs to start from 0 otherwise it will try to predict also 0.
        #emo = int(file[7:8]) - 1 
        #arr = X, emo
        new_x_train.append(mfccs)
      # If the file is not valid, skip it
      except ValueError:
        continue
print("--- Data loaded. Loading time: %s seconds ---" % (time.time() - start_time))
# Out:
# --- Data loaded. Loading time: 254.1142294406891 seconds ---

# %%
new_x_train=np.asarray(new_x_train)
prediction_train = model.predict(new_x_train)
prediction_train
# Out:
# array([[1.00000000e+00, 2.16793639e-10, 3.09014769e-09, 1.58220619e-08,
#         1.17186139e-09],
#        [9.99728382e-01, 1.00823581e-05, 2.48187480e-05, 2.06432625e-04,
#         3.02808294e-05],
#        [4.08351724e-07, 4.87431644e-05, 2.80900395e-06, 6.30122258e-06,
#         9.99941707e-01],
#        ...,
#        [9.93530929e-01, 6.21044092e-05, 6.39118068e-03, 1.04061269e-06,
#         1.48058725e-05],
#        [7.09371317e-09, 1.48020138e-03, 1.78933291e-07, 9.98490691e-01,
#         2.88383126e-05],
#        [1.04588644e-05, 1.45457223e-01, 3.55597308e-06, 6.07406313e-04,
#         8.53921354e-01]], dtype=float32)

# %%
df_audio_train = pd.DataFrame(prediction_train,columns=["OA_"+str(i) for i in range(5)])

# %%
prediction_valid = model.predict(X_valid)
prediction_valid
# Out:
# array([[2.59610829e-07, 9.39055145e-01, 3.66282302e-06, 5.00448719e-02,
#         1.08961090e-02],
#        [6.42785244e-06, 1.50133111e-02, 4.51247979e-05, 7.60559706e-05,
#         9.84859049e-01],
#        [1.18975389e-04, 5.50163559e-09, 6.15705940e-05, 1.99806664e-06,
#         9.99817431e-01],
#        [9.84971344e-01, 1.01791079e-06, 1.50127755e-02, 5.41712006e-06,
#         9.39850452e-06],
#        [2.03206528e-05, 1.34558510e-03, 9.95035410e-01, 1.89760249e-05,
#         3.57973482e-03],
#        [5.35906642e-04, 1.20357606e-06, 9.98791873e-01, 6.45819237e-04,
#         2.52869577e-05],
#        [9.99997854e-01, 8.50101785e-08, 2.00552176e-06, 6.53781456e-08,
#         7.04924075e-09],
#        [1.60786451e-03, 4.12098229e-01, 2.74136057e-03, 5.82499683e-01,
#         1.05288380e-03],
#        [2.47243279e-05, 9.52070892e-01, 2.38002485e-05, 4.74157855e-02,
#         4.64721699e-04],
#        [1.84164950e-04, 2.29210236e-05, 5.10721118e-04, 3.43982130e-03,
# ...

# %%
df_audio_valid = pd.DataFrame(prediction_valid,columns=["OA_"+str(i) for i in range(5)])

# %%
import joblib

save_dir = '/content/drive/My Drive/fusion/savee/audio/data_set/expert2'

savedvX = joblib.dump(df_audio_train, os.path.join(save_dir, 'train/predict_train'))
savedvX = joblib.dump(df_audio_test, os.path.join(save_dir, 'test/predict_test'))
savedvX = joblib.dump(df_audio_valid, os.path.join(save_dir, 'valid/predict_valid'))
