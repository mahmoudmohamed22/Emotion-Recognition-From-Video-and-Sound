# %%
import numpy as np
import pandas as pd
import os
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import matplotlib.pyplot as plt

#from google.colab import drive

#rive.mount('/content/drive', force_remount = True)

EMOTIONS = {1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 0:'surprise'} # surprise je promenjen sa 8 na 0
DATA_PATH ='dataset'


SAMPLE_RATE = 48000
data = pd.DataFrame(columns=['Emotion', 'Emotion intensity', 'Gender','Path'])
for dirname, _, filenames in os.walk(DATA_PATH):
    for filename in filenames:
        file_path = os.path.join(dirname, filename)
        identifiers = filename.split('.')[0].split('-')
        emotion = (int(identifiers[2]))
        if emotion == 8: # promeni surprise sa 8 na 0
            emotion = 0
        if int(identifiers[3]) == 1:
            emotion_intensity = 'normal' 
        else:
            emotion_intensity = 'strong'
        if int(identifiers[6])%2 == 0:
            gender = 'female'
        else:
            gender = 'male'
        
        data = data.append({"Emotion": emotion,
                            "Emotion intensity": emotion_intensity,
                            "Gender": gender,
                            "Path": file_path
                             },
                             ignore_index = True
                          )
# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
print("number of files is {}".format(len(data)))
data.head()
# Out:
# number of files is 960
#   Emotion Emotion intensity  Gender                                       Path
# 0       6            normal  female  dataset/Actor_04/03-01-06-01-02-01-04.wav
# 1       7            normal  female  dataset/Actor_04/03-01-07-01-01-02-04.wav
# 2       2            normal  female  dataset/Actor_04/03-01-02-01-02-01-04.wav
# 3       3            normal  female  dataset/Actor_04/03-01-03-01-01-01-04.wav
# 4       6            normal  female  dataset/Actor_04/03-01-06-01-01-01-04.wav

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(x=range(8), height=data['Emotion'].value_counts())
ax.set_xticks(ticks=range(8))
ax.set_xticklabels([EMOTIONS[i] for i in range(8)],fontsize=10)
ax.set_xlabel('Emotions')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
counts = data['Gender'].value_counts()
ax.bar(x=[0,1], height=counts.values)
ax.set_xticks(ticks=[0,1])
ax.set_xticklabels(list(counts.index))
ax.set_xlabel('Gender')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
counts = data['Emotion intensity'].value_counts()
ax.bar(x=[0,1], height=counts.values)
ax.set_xticks(ticks=[0,1])
ax.set_xticklabels(list(counts.index))
ax.set_xlabel('Gender')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %%
mel_spectrograms = []
signals = []
for i, file_path in enumerate(data.Path):
    audio, sample_rate = librosa.load(file_path, duration=3, offset=0.5, sr=SAMPLE_RATE)
    signal = np.zeros((int(SAMPLE_RATE*3,)))
    signal[:len(audio)] = audio
    signals.append(signal)
    print("\r Processed {}/{} files".format(i,len(data)),end='')
signals = np.stack(signals,axis=0)
# Out:
#  Processed 959/960 files

# %%
X = signals
train_ind,test_ind,val_ind = [],[],[]
X_train,X_val,X_test = [],[],[]
Y_train,Y_val,Y_test = [],[],[]
for emotion in range(len(EMOTIONS)):
    emotion_ind = list(data.loc[data.Emotion==emotion,'Emotion'].index)
    emotion_ind = np.random.permutation(emotion_ind)
    m = len(emotion_ind)
    ind_train = emotion_ind[:int(0.8*m)]
    ind_val = emotion_ind[int(0.8*m):int(0.9*m)]
    ind_test = emotion_ind[int(0.9*m):]
    X_train.append(X[ind_train,:])
    Y_train.append(np.array([emotion]*len(ind_train),dtype=np.int32))
    X_val.append(X[ind_val,:])
    Y_val.append(np.array([emotion]*len(ind_val),dtype=np.int32))
    X_test.append(X[ind_test,:])
    Y_test.append(np.array([emotion]*len(ind_test),dtype=np.int32))
    train_ind.append(ind_train)
    test_ind.append(ind_test)
    val_ind.append(ind_val)
X_train = np.concatenate(X_train,0)
X_val = np.concatenate(X_val,0)
X_test = np.concatenate(X_test,0)
Y_train = np.concatenate(Y_train,0)
Y_val = np.concatenate(Y_val,0)
Y_test = np.concatenate(Y_test,0)
train_ind = np.concatenate(train_ind,0)
val_ind = np.concatenate(val_ind,0)
test_ind = np.concatenate(test_ind,0)
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# check if all are unique
unique, count = np.unique(np.concatenate([train_ind,test_ind,val_ind],0), return_counts=True)
print("Number of unique indexes is {}, out of {}".format(sum(count==1), X.shape[0]))

del X
# Out:
# X_train:(765, 144000), Y_train:(765,)
# X_val:(97, 144000), Y_val:(97,)
# X_test:(98, 144000), Y_test:(98,)
# Number of unique indexes is 960, out of 960

# %%
def addAWGN(signal, num_bits=16, augmented_num=2, snr_low=15, snr_high=30): 
    signal_len = len(signal)
    # Generate White Gaussian noise
    noise = np.random.normal(size=(augmented_num, signal_len))
    # Normalize signal and noise
    norm_constant = 2.0**(num_bits-1)
    signal_norm = signal / norm_constant
    noise_norm = noise / norm_constant
    # Compute signal and noise power
    s_power = np.sum(signal_norm ** 2) / signal_len
    n_power = np.sum(noise_norm ** 2, axis=1) / signal_len
    # Random SNR: Uniform [15, 30] in dB
    target_snr = np.random.randint(snr_low, snr_high)
    # Compute K (covariance matrix) for each noise 
    K = np.sqrt((s_power / n_power) * 10 ** (- target_snr / 10))
    K = np.ones((signal_len, augmented_num)) * K  
    # Generate noisy signal
    return signal + K.T * noise

# %%
aug_signals = []
aug_labels = []
for i in range(X_train.shape[0]):
    signal = X_train[i,:]
    augmented_signals = addAWGN(signal)
    for j in range(augmented_signals.shape[0]):
        aug_labels.append(data.loc[i,"Emotion"])
        aug_signals.append(augmented_signals[j,:])
        data = data.append(data.iloc[i], ignore_index=True)
    print("\r Processed {}/{} files".format(i,X_train.shape[0]),end='')
aug_signals = np.stack(aug_signals,axis=0)
X_train = np.concatenate([X_train,aug_signals],axis=0)
aug_labels = np.stack(aug_labels,axis=0)
Y_train = np.concatenate([Y_train,aug_labels])
print('')
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
# Out:
#  Processed 764/765 files
# X_train:(2295, 144000), Y_train:(2295,)

# %%
def getMELspectrogram(audio, sample_rate):
    mel_spec = librosa.feature.melspectrogram(y=audio,
                                              sr=sample_rate,
                                              n_fft=1024,
                                              win_length = 512,
                                              window='hamming',
                                              hop_length = 256,
                                              n_mels=128,
                                              fmax=sample_rate/2
                                             )
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    return mel_spec_db

# test function
audio, sample_rate = librosa.load(data.loc[0,'Path'], duration=3, offset=0.5,sr=SAMPLE_RATE)
signal = np.zeros((int(SAMPLE_RATE*3,)))
signal[:len(audio)] = audio
mel_spectrogram = getMELspectrogram(signal, SAMPLE_RATE)
librosa.display.specshow(mel_spectrogram, y_axis='mel', x_axis='time')
print('MEL spectrogram shape: ',mel_spectrogram.shape)
# Out:
# MEL spectrogram shape:  (128, 563)

# %%
mel_train = []
print("Calculatin mel spectrograms for train set")
for i in range(X_train.shape[0]):
    mel_spectrogram = getMELspectrogram(X_train[i,:], sample_rate=SAMPLE_RATE)
    mel_train.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_train.shape[0]),end='')
print('')
mel_train = np.stack(mel_train,axis=0)
del X_train
X_train = mel_train

mel_val = []
print("Calculatin mel spectrograms for val set")
for i in range(X_val.shape[0]):
    mel_spectrogram = getMELspectrogram(X_val[i,:], sample_rate=SAMPLE_RATE)
    mel_val.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_val.shape[0]),end='')
print('')
mel_val = np.stack(mel_val,axis=0)
del X_val
X_val = mel_val

mel_test = []
print("Calculatin mel spectrograms for test set")
for i in range(X_test.shape[0]):
    mel_spectrogram = getMELspectrogram(X_test[i,:], sample_rate=SAMPLE_RATE)
    mel_test.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_test.shape[0]),end='')
print('')
mel_test = np.stack(mel_test,axis=0)
del X_test
X_test = mel_test

print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# Out:
# Calculatin mel spectrograms for train set
#  Processed 2294/2295 files
# Calculatin mel spectrograms for val set
#  Processed 96/97 files
# Calculatin mel spectrograms for test set
#  Processed 97/98 files
# X_train:(2295, 128, 563), Y_train:(2295,)
# X_val:(97, 128, 563), Y_val:(97,)
# X_test:(98, 128, 563), Y_test:(98,)

# %%
import torch
import torch.nn as nn

class ParallelModel(nn.Module):
    def __init__(self,num_emotions):
        super().__init__()
        # conv block
        self.conv2Dblock = nn.Sequential(
            # 1. conv block
            nn.Conv2d(in_channels=1,
                       out_channels=16,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),
            # 2. conv block
            nn.Conv2d(in_channels=16,
                       out_channels=32,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # 3. conv block
            nn.Conv2d(in_channels=32,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # 4. conv block
            nn.Conv2d(in_channels=64,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3)
        )
        # LSTM block
        self.lstm_maxpool = nn.MaxPool2d(kernel_size=[2,4], stride=[2,4])
        hidden_size = 128
        self.lstm = nn.LSTM(input_size=64,hidden_size=hidden_size,bidirectional=True, batch_first=True)
        self.dropout_lstm = nn.Dropout(0.1)
        self.attention_linear = nn.Linear(2*hidden_size,1) # 2*hidden_size for the 2 outputs of bidir LSTM
        # Linear softmax layer
        self.out_linear = nn.Linear(2*hidden_size+256,num_emotions)
        self.dropout_linear = nn.Dropout(p=0)
        self.out_softmax = nn.Softmax(dim=1)
    def forward(self,x):
        # conv embedding
        conv_embedding = self.conv2Dblock(x) #(b,channel,freq,time)
        conv_embedding = torch.flatten(conv_embedding, start_dim=1) # do not flatten batch dimension
        # lstm embedding
        x_reduced = self.lstm_maxpool(x)
        x_reduced = torch.squeeze(x_reduced,1)
        x_reduced = x_reduced.permute(0,2,1) # (b,t,freq)
        lstm_embedding, (h,c) = self.lstm(x_reduced) # (b, time, hidden_size*2)
        lstm_embedding = self.dropout_lstm(lstm_embedding)
        batch_size,T,_ = lstm_embedding.shape 
        attention_weights = [None]*T
        for t in range(T):
            embedding = lstm_embedding[:,t,:]
            attention_weights[t] = self.attention_linear(embedding)
        attention_weights_norm = nn.functional.softmax(torch.stack(attention_weights,-1),-1)
        attention = torch.bmm(attention_weights_norm,lstm_embedding) # (Bx1xT)*(B,T,hidden_size*2)=(B,1,2*hidden_size)
        attention = torch.squeeze(attention, 1)
        # concatenate
        complete_embedding = torch.cat([conv_embedding, attention], dim=1) 
        
        output_logits = self.out_linear(complete_embedding)
        output_logits = self.dropout_linear(output_logits)
        output_softmax = self.out_softmax(output_logits)
        return output_logits, output_softmax, attention_weights_norm

# %%
def loss_fnc(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions,target=targets)

# %%
def make_train_step(model, loss_fnc, optimizer):
    def train_step(X,Y):
        # set model to train mode
        model.train()
        # forward pass
        output_logits, output_softmax, attention_weights_norm = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        # compute loss
        loss = loss_fnc(output_logits, Y)
        # compute gradients
        loss.backward()
        # update parameters and zero gradients
        optimizer.step()
        optimizer.zero_grad()
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,loss_fnc):
    def validate(X,Y):
        with torch.no_grad():
            model.eval()
            output_logits, output_softmax, attention_weights_norm = model(X)
            predictions = torch.argmax(output_softmax,dim=1)
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            loss = loss_fnc(output_logits,Y)
        return loss.item(), accuracy*100, predictions
    return validate

# %%
from sklearn.preprocessing import StandardScaler

X_train = np.expand_dims(X_train,1)
X_val = np.expand_dims(X_val,1)
X_test = np.expand_dims(X_test,1)

scaler = StandardScaler()

b,c,h,w = X_train.shape
X_train = np.reshape(X_train, newshape=(b,-1))
X_train = scaler.fit_transform(X_train)
X_train = np.reshape(X_train, newshape=(b,c,h,w))

b,c,h,w = X_test.shape
X_test = np.reshape(X_test, newshape=(b,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, newshape=(b,c,h,w))

b,c,h,w = X_val.shape
X_val = np.reshape(X_val, newshape=(b,-1))
X_val = scaler.transform(X_val)
X_val = np.reshape(X_val, newshape=(b,c,h,w))

# %%
EPOCHS=1500
DATASET_SIZE = X_train.shape[0]
BATCH_SIZE = 32
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Selected device is {}'.format(device))
model = ParallelModel(num_emotions=len(EMOTIONS)).to(device)
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )
OPTIMIZER = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

train_step = make_train_step(model, loss_fnc, optimizer=OPTIMIZER)
validate = make_validate_fnc(model,loss_fnc)
losses=[]
val_losses = []
for epoch in range(EPOCHS):
    # schuffle data
    ind = np.random.permutation(DATASET_SIZE)
    X_train = X_train[ind,:,:,:]
    Y_train = Y_train[ind]
    epoch_acc = 0
    epoch_loss = 0
    iters = int(DATASET_SIZE / BATCH_SIZE)
    for i in range(iters):
        batch_start = i * BATCH_SIZE
        batch_end = min(batch_start + BATCH_SIZE, DATASET_SIZE)
        actual_batch_size = batch_end-batch_start
        X = X_train[batch_start:batch_end,:,:,:]
        Y = Y_train[batch_start:batch_end]
        X_tensor = torch.tensor(X,device=device).float()
        Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
        loss, acc = train_step(X_tensor,Y_tensor)
        epoch_acc += acc*actual_batch_size/DATASET_SIZE
        epoch_loss += loss*actual_batch_size/DATASET_SIZE
        print(f"\r Epoch {epoch}: iteration {i}/{iters}",end='')
    X_val_tensor = torch.tensor(X_val,device=device).float()
    Y_val_tensor = torch.tensor(Y_val,dtype=torch.long,device=device)
    val_loss, val_acc, _ = validate(X_val_tensor,Y_val_tensor)
    losses.append(epoch_loss)
    val_losses.append(val_loss)
    print('')
    print(f"Epoch {epoch} --> loss:{epoch_loss:.4f}, acc:{epoch_acc:.2f}%, val_loss:{val_loss:.4f}, val_acc:{val_acc:.2f}%")
# Out:
# Selected device is cuda
# Number of trainable params:  263593
#  Epoch 0: iteration 70/71
# Epoch 0 --> loss:2.3483, acc:13.38%, val_loss:2.0789, val_acc:20.62%
#  Epoch 1: iteration 70/71
# Epoch 1 --> loss:2.1793, acc:13.81%, val_loss:2.0684, val_acc:16.49%
#  Epoch 2: iteration 70/71
# Epoch 2 --> loss:2.1350, acc:16.03%, val_loss:2.0533, val_acc:21.65%
#  Epoch 3: iteration 70/71
# Epoch 3 --> loss:2.1142, acc:15.56%, val_loss:1.9964, val_acc:20.62%
#  Epoch 4: iteration 70/71
# Epoch 4 --> loss:2.0929, acc:16.69%, val_loss:2.0086, val_acc:14.43%
#  Epoch 5: iteration 70/71
# Epoch 5 --> loss:2.0619, acc:18.00%, val_loss:1.9912, val_acc:16.49%
#  Epoch 6: iteration 70/71
# Epoch 6 --> loss:2.0633, acc:17.60%, val_loss:1.9520, val_acc:23.71%
#  Epoch 7: iteration 70/71
# Epoch 7 --> loss:2.0239, acc:19.22%, val_loss:2.0465, val_acc:24.74%
#  Epoch 8: iteration 70/71
# Epoch 8 --> loss:2.0308, acc:18.30%, val_loss:1.9651, val_acc:18.56%
#  Epoch 9: iteration 70/71
# Epoch 9 --> loss:2.0068, acc:19.74%, val_loss:1.9309, val_acc:23.71%
#  Epoch 10: iteration 70/71
# Epoch 10 --> loss:1.9897, acc:20.13%, val_loss:1.9017, val_acc:20.62%
#  Epoch 11: iteration 70/71
# Epoch 11 --> loss:1.9908, acc:19.61%, val_loss:1.8819, val_acc:24.74%
#  Epoch 12: iteration 70/71
# Epoch 12 --> loss:1.9806, acc:21.09%, val_loss:1.8969, val_acc:27.84%
#  Epoch 13: iteration 70/71
# Epoch 13 --> loss:1.9743, acc:21.31%, val_loss:1.8623, val_acc:32.99%
#  Epoch 14: iteration 70/71
# Epoch 14 --> loss:1.9610, acc:21.22%, val_loss:1.8271, val_acc:35.05%
#  Epoch 15: iteration 70/71
# Epoch 15 --> loss:1.9454, acc:23.36%, val_loss:1.8203, val_acc:23.71%
#  Epoch 16: iteration 70/71
# Epoch 16 --> loss:1.9288, acc:23.53%, val_loss:1.8157, val_acc:25.77%
#  Epoch 17: iteration 70/71
# Epoch 17 --> loss:1.9276, acc:22.48%, val_loss:1.7984, val_acc:36.08%
#  Epoch 18: iteration 70/71
# Epoch 18 --> loss:1.9000, acc:23.97%, val_loss:1.8128, val_acc:34.02%
#  Epoch 19: iteration 70/71
# Epoch 19 --> loss:1.9033, acc:23.70%, val_loss:1.7322, val_acc:34.02%
#  Epoch 20: iteration 70/71
# Epoch 20 --> loss:1.8742, acc:24.79%, val_loss:1.7734, val_acc:36.08%
#  Epoch 21: iteration 70/71
# Epoch 21 --> loss:1.8776, acc:26.01%, val_loss:1.7348, val_acc:40.21%
#  Epoch 22: iteration 70/71
# Epoch 22 --> loss:1.8691, acc:25.58%, val_loss:1.7607, val_acc:35.05%
#  Epoch 23: iteration 70/71
# Epoch 23 --> loss:1.8564, acc:26.49%, val_loss:1.7310, val_acc:35.05%
#  Epoch 24: iteration 70/71
# Epoch 24 --> loss:1.8575, acc:27.02%, val_loss:1.7142, val_acc:35.05%
#  Epoch 25: iteration 70/71
# Epoch 25 --> loss:1.8411, acc:28.28%, val_loss:1.6603, val_acc:44.33%
#  Epoch 26: iteration 70/71
# Epoch 26 --> loss:1.8220, acc:27.89%, val_loss:1.6816, val_acc:36.08%
#  Epoch 27: iteration 70/71
# Epoch 27 --> loss:1.8206, acc:28.93%, val_loss:1.6446, val_acc:40.21%
#  Epoch 28: iteration 70/71
# Epoch 28 --> loss:1.8091, acc:30.11%, val_loss:1.6253, val_acc:43.30%
#  Epoch 29: iteration 70/71
# Epoch 29 --> loss:1.8119, acc:30.07%, val_loss:1.6348, val_acc:41.24%
#  Epoch 30: iteration 70/71
# Epoch 30 --> loss:1.7939, acc:29.85%, val_loss:1.6070, val_acc:41.24%
#  Epoch 31: iteration 70/71
# Epoch 31 --> loss:1.7739, acc:30.89%, val_loss:1.6107, val_acc:42.27%
#  Epoch 32: iteration 70/71
# Epoch 32 --> loss:1.7691, acc:31.59%, val_loss:1.6018, val_acc:44.33%
#  Epoch 33: iteration 70/71
# Epoch 33 --> loss:1.7514, acc:33.29%, val_loss:1.5575, val_acc:43.30%
#  Epoch 34: iteration 70/71
# Epoch 34 --> loss:1.7596, acc:31.94%, val_loss:1.5709, val_acc:37.11%
#  Epoch 35: iteration 70/71
# Epoch 35 --> loss:1.7488, acc:32.16%, val_loss:1.5612, val_acc:45.36%
#  Epoch 36: iteration 70/71
# Epoch 36 --> loss:1.7256, acc:32.77%, val_loss:1.5249, val_acc:49.48%
#  Epoch 37: iteration 70/71
# Epoch 37 --> loss:1.7117, acc:34.81%, val_loss:1.5072, val_acc:45.36%
#  Epoch 38: iteration 70/71
# Epoch 38 --> loss:1.7125, acc:34.07%, val_loss:1.5037, val_acc:42.27%
#  Epoch 39: iteration 70/71
# Epoch 39 --> loss:1.7103, acc:34.20%, val_loss:1.4937, val_acc:45.36%
#  Epoch 40: iteration 70/71
# Epoch 40 --> loss:1.6983, acc:34.16%, val_loss:1.5021, val_acc:39.18%
#  Epoch 41: iteration 70/71
# Epoch 41 --> loss:1.6809, acc:35.42%, val_loss:1.4494, val_acc:47.42%
#  Epoch 42: iteration 70/71
# Epoch 42 --> loss:1.6914, acc:35.95%, val_loss:1.4266, val_acc:48.45%
#  Epoch 43: iteration 70/71
# Epoch 43 --> loss:1.6510, acc:37.08%, val_loss:1.4133, val_acc:50.52%
#  Epoch 44: iteration 70/71
# Epoch 44 --> loss:1.6443, acc:38.39%, val_loss:1.3634, val_acc:48.45%
#  Epoch 45: iteration 70/71
# Epoch 45 --> loss:1.6310, acc:36.78%, val_loss:1.3302, val_acc:51.55%
#  Epoch 46: iteration 70/71
# Epoch 46 --> loss:1.6098, acc:39.61%, val_loss:1.3140, val_acc:52.58%
#  Epoch 47: iteration 70/71
# Epoch 47 --> loss:1.6350, acc:37.65%, val_loss:1.2887, val_acc:56.70%
#  Epoch 48: iteration 70/71
# Epoch 48 --> loss:1.5880, acc:39.96%, val_loss:1.2944, val_acc:50.52%
#  Epoch 49: iteration 70/71
# Epoch 49 --> loss:1.6001, acc:39.52%, val_loss:1.2343, val_acc:58.76%
#  Epoch 50: iteration 70/71
# Epoch 50 --> loss:1.5788, acc:39.74%, val_loss:1.2331, val_acc:54.64%
#  Epoch 51: iteration 70/71
# Epoch 51 --> loss:1.5720, acc:40.52%, val_loss:1.3686, val_acc:53.61%
#  Epoch 52: iteration 70/71
# Epoch 52 --> loss:1.5579, acc:42.22%, val_loss:1.2150, val_acc:55.67%
#  Epoch 53: iteration 70/71
# Epoch 53 --> loss:1.5615, acc:40.78%, val_loss:1.2326, val_acc:52.58%
#  Epoch 54: iteration 70/71
# Epoch 54 --> loss:1.5395, acc:43.36%, val_loss:1.1924, val_acc:55.67%
#  Epoch 55: iteration 70/71
# Epoch 55 --> loss:1.5320, acc:42.44%, val_loss:1.1560, val_acc:61.86%
#  Epoch 56: iteration 70/71
# Epoch 56 --> loss:1.5246, acc:42.61%, val_loss:1.1635, val_acc:57.73%
#  Epoch 57: iteration 70/71
# Epoch 57 --> loss:1.5079, acc:43.31%, val_loss:1.1339, val_acc:56.70%
#  Epoch 58: iteration 70/71
# Epoch 58 --> loss:1.5176, acc:43.40%, val_loss:1.1689, val_acc:58.76%
#  Epoch 59: iteration 70/71
# Epoch 59 --> loss:1.4815, acc:44.05%, val_loss:1.0814, val_acc:56.70%
#  Epoch 60: iteration 70/71
# Epoch 60 --> loss:1.4729, acc:44.71%, val_loss:1.2095, val_acc:52.58%
#  Epoch 61: iteration 70/71
# Epoch 61 --> loss:1.4458, acc:46.27%, val_loss:1.1291, val_acc:57.73%
#  Epoch 62: iteration 70/71
# Epoch 62 --> loss:1.4473, acc:46.58%, val_loss:1.0897, val_acc:61.86%
#  Epoch 63: iteration 70/71
# Epoch 63 --> loss:1.4294, acc:46.62%, val_loss:1.0927, val_acc:62.89%
#  Epoch 64: iteration 70/71
# Epoch 64 --> loss:1.4176, acc:47.41%, val_loss:1.1457, val_acc:59.79%
#  Epoch 65: iteration 70/71
# Epoch 65 --> loss:1.4133, acc:46.93%, val_loss:1.1133, val_acc:62.89%
#  Epoch 66: iteration 70/71
# Epoch 66 --> loss:1.4107, acc:46.10%, val_loss:1.2259, val_acc:55.67%
#  Epoch 67: iteration 70/71
# Epoch 67 --> loss:1.3979, acc:47.76%, val_loss:1.0969, val_acc:61.86%
#  Epoch 68: iteration 70/71
# Epoch 68 --> loss:1.3533, acc:49.06%, val_loss:1.1213, val_acc:57.73%
#  Epoch 69: iteration 70/71
# Epoch 69 --> loss:1.3582, acc:49.50%, val_loss:1.0449, val_acc:64.95%
#  Epoch 70: iteration 70/71
# Epoch 70 --> loss:1.3469, acc:49.19%, val_loss:1.0190, val_acc:63.92%
#  Epoch 71: iteration 70/71
# Epoch 71 --> loss:1.3356, acc:50.72%, val_loss:0.9657, val_acc:64.95%
#  Epoch 72: iteration 70/71
# Epoch 72 --> loss:1.3417, acc:50.81%, val_loss:1.0353, val_acc:63.92%
#  Epoch 73: iteration 70/71
# Epoch 73 --> loss:1.3139, acc:51.33%, val_loss:1.0616, val_acc:64.95%
#  Epoch 74: iteration 70/71
# Epoch 74 --> loss:1.2888, acc:52.46%, val_loss:1.0200, val_acc:61.86%
#  Epoch 75: iteration 70/71
# Epoch 75 --> loss:1.2722, acc:53.55%, val_loss:0.9473, val_acc:68.04%
#  Epoch 76: iteration 70/71
# Epoch 76 --> loss:1.2429, acc:52.51%, val_loss:0.9853, val_acc:65.98%
#  Epoch 77: iteration 70/71
# Epoch 77 --> loss:1.2494, acc:53.29%, val_loss:0.9242, val_acc:64.95%
#  Epoch 78: iteration 70/71
# Epoch 78 --> loss:1.2029, acc:56.03%, val_loss:0.9886, val_acc:67.01%
#  Epoch 79: iteration 70/71
# Epoch 79 --> loss:1.2054, acc:55.95%, val_loss:1.0808, val_acc:54.64%
#  Epoch 80: iteration 70/71
# Epoch 80 --> loss:1.2051, acc:56.38%, val_loss:1.0443, val_acc:61.86%
#  Epoch 81: iteration 70/71
# Epoch 81 --> loss:1.1766, acc:57.04%, val_loss:0.8960, val_acc:65.98%
#  Epoch 82: iteration 70/71
# Epoch 82 --> loss:1.1657, acc:56.47%, val_loss:1.0212, val_acc:60.82%
#  Epoch 83: iteration 70/71
# Epoch 83 --> loss:1.1767, acc:56.99%, val_loss:0.9829, val_acc:61.86%
#  Epoch 84: iteration 70/71
# Epoch 84 --> loss:1.1388, acc:58.00%, val_loss:1.0381, val_acc:64.95%
#  Epoch 85: iteration 70/71
# Epoch 85 --> loss:1.1213, acc:58.78%, val_loss:0.9496, val_acc:61.86%
#  Epoch 86: iteration 70/71
# Epoch 86 --> loss:1.1202, acc:58.52%, val_loss:1.0188, val_acc:67.01%
#  Epoch 87: iteration 70/71
# Epoch 87 --> loss:1.0994, acc:60.70%, val_loss:0.8146, val_acc:74.23%
#  Epoch 88: iteration 70/71
# Epoch 88 --> loss:1.0847, acc:60.00%, val_loss:0.8482, val_acc:64.95%
#  Epoch 89: iteration 70/71
# Epoch 89 --> loss:1.0658, acc:61.44%, val_loss:0.9891, val_acc:71.13%
#  Epoch 90: iteration 70/71
# Epoch 90 --> loss:1.0533, acc:62.00%, val_loss:1.3489, val_acc:60.82%
#  Epoch 91: iteration 70/71
# Epoch 91 --> loss:1.0647, acc:62.27%, val_loss:0.8598, val_acc:70.10%
#  Epoch 92: iteration 70/71
# Epoch 92 --> loss:1.0197, acc:63.57%, val_loss:0.9803, val_acc:70.10%
#  Epoch 93: iteration 70/71
# Epoch 93 --> loss:0.9946, acc:63.97%, val_loss:0.8702, val_acc:68.04%
#  Epoch 94: iteration 70/71
# Epoch 94 --> loss:1.0418, acc:62.22%, val_loss:0.8791, val_acc:70.10%
#  Epoch 95: iteration 70/71
# Epoch 95 --> loss:0.9836, acc:64.79%, val_loss:0.7611, val_acc:74.23%
#  Epoch 96: iteration 70/71
# Epoch 96 --> loss:0.9623, acc:66.58%, val_loss:1.1661, val_acc:56.70%
#  Epoch 97: iteration 70/71
# Epoch 97 --> loss:0.9723, acc:64.84%, val_loss:0.7810, val_acc:70.10%
#  Epoch 98: iteration 70/71
# Epoch 98 --> loss:0.9197, acc:68.93%, val_loss:0.9316, val_acc:69.07%
#  Epoch 99: iteration 70/71
# Epoch 99 --> loss:0.9390, acc:65.27%, val_loss:0.8205, val_acc:73.20%
#  Epoch 100: iteration 70/71
# Epoch 100 --> loss:0.8929, acc:69.11%, val_loss:0.8319, val_acc:68.04%
#  Epoch 101: iteration 70/71
# Epoch 101 --> loss:0.8749, acc:69.32%, val_loss:0.8576, val_acc:73.20%
#  Epoch 102: iteration 70/71
# Epoch 102 --> loss:0.8850, acc:67.02%, val_loss:0.8675, val_acc:69.07%
#  Epoch 103: iteration 70/71
# Epoch 103 --> loss:0.8561, acc:69.37%, val_loss:0.9523, val_acc:71.13%
#  Epoch 104: iteration 70/71
# Epoch 104 --> loss:0.8318, acc:69.63%, val_loss:0.9378, val_acc:71.13%
#  Epoch 105: iteration 70/71
# Epoch 105 --> loss:0.8245, acc:70.94%, val_loss:0.7488, val_acc:77.32%
#  Epoch 106: iteration 70/71
# Epoch 106 --> loss:0.8733, acc:69.19%, val_loss:1.1908, val_acc:69.07%
#  Epoch 107: iteration 70/71
# Epoch 107 --> loss:0.8351, acc:69.63%, val_loss:1.1207, val_acc:65.98%
#  Epoch 108: iteration 70/71
# Epoch 108 --> loss:0.7771, acc:71.42%, val_loss:0.9244, val_acc:74.23%
#  Epoch 109: iteration 70/71
# Epoch 109 --> loss:0.7552, acc:73.73%, val_loss:0.9662, val_acc:69.07%
#  Epoch 110: iteration 70/71
# Epoch 110 --> loss:0.8017, acc:70.94%, val_loss:0.9268, val_acc:74.23%
#  Epoch 111: iteration 70/71
# Epoch 111 --> loss:0.7172, acc:75.34%, val_loss:0.7982, val_acc:74.23%
#  Epoch 112: iteration 70/71
# Epoch 112 --> loss:0.8201, acc:71.24%, val_loss:1.1719, val_acc:68.04%
#  Epoch 113: iteration 70/71
# Epoch 113 --> loss:0.7734, acc:72.20%, val_loss:0.9170, val_acc:70.10%
#  Epoch 114: iteration 70/71
# Epoch 114 --> loss:0.7287, acc:74.55%, val_loss:0.8978, val_acc:69.07%
#  Epoch 115: iteration 70/71
# Epoch 115 --> loss:0.6997, acc:76.21%, val_loss:0.9430, val_acc:73.20%
#  Epoch 116: iteration 70/71
# Epoch 116 --> loss:0.6898, acc:76.60%, val_loss:0.8788, val_acc:70.10%
#  Epoch 117: iteration 70/71
# Epoch 117 --> loss:0.6477, acc:79.13%, val_loss:0.8474, val_acc:77.32%
#  Epoch 118: iteration 70/71
# Epoch 118 --> loss:0.6368, acc:78.39%, val_loss:0.8570, val_acc:68.04%
#  Epoch 119: iteration 70/71
# Epoch 119 --> loss:0.5771, acc:80.74%, val_loss:0.8862, val_acc:72.16%
#  Epoch 120: iteration 70/71
# Epoch 120 --> loss:0.6518, acc:77.39%, val_loss:1.3593, val_acc:61.86%
#  Epoch 121: iteration 70/71
# Epoch 121 --> loss:0.6428, acc:77.25%, val_loss:0.9710, val_acc:68.04%
#  Epoch 122: iteration 70/71
# Epoch 122 --> loss:0.6086, acc:78.74%, val_loss:0.9496, val_acc:73.20%
#  Epoch 123: iteration 70/71
# Epoch 123 --> loss:0.5490, acc:82.00%, val_loss:1.1753, val_acc:67.01%
#  Epoch 124: iteration 70/71
# Epoch 124 --> loss:0.5522, acc:81.26%, val_loss:0.9427, val_acc:74.23%
#  Epoch 125: iteration 70/71
# Epoch 125 --> loss:0.5073, acc:82.66%, val_loss:1.0383, val_acc:71.13%
#  Epoch 126: iteration 70/71
# Epoch 126 --> loss:0.5264, acc:82.18%, val_loss:1.2686, val_acc:64.95%
#  Epoch 127: iteration 70/71
# Epoch 127 --> loss:0.5543, acc:81.18%, val_loss:1.1106, val_acc:65.98%
#  Epoch 128: iteration 70/71
# Epoch 128 --> loss:0.5055, acc:82.66%, val_loss:1.0302, val_acc:70.10%
#  Epoch 129: iteration 70/71
# Epoch 129 --> loss:0.4672, acc:84.31%, val_loss:1.3804, val_acc:63.92%
#  Epoch 130: iteration 70/71
# Epoch 130 --> loss:0.4796, acc:84.27%, val_loss:1.0251, val_acc:75.26%
#  Epoch 131: iteration 70/71
# Epoch 131 --> loss:0.4608, acc:84.71%, val_loss:1.0749, val_acc:71.13%
#  Epoch 132: iteration 70/71
# Epoch 132 --> loss:0.4150, acc:86.27%, val_loss:0.9596, val_acc:75.26%
#  Epoch 133: iteration 70/71
# Epoch 133 --> loss:0.4054, acc:87.06%, val_loss:1.0886, val_acc:72.16%
#  Epoch 134: iteration 70/71
# Epoch 134 --> loss:0.4236, acc:86.49%, val_loss:1.0235, val_acc:76.29%
#  Epoch 135: iteration 70/71
# Epoch 135 --> loss:0.4017, acc:86.62%, val_loss:1.1474, val_acc:71.13%
#  Epoch 136: iteration 70/71
# Epoch 136 --> loss:0.4271, acc:86.36%, val_loss:1.1816, val_acc:71.13%
#  Epoch 137: iteration 70/71
# Epoch 137 --> loss:0.5115, acc:82.57%, val_loss:1.5304, val_acc:69.07%
#  Epoch 138: iteration 70/71
# Epoch 138 --> loss:0.4679, acc:84.31%, val_loss:1.3580, val_acc:62.89%
#  Epoch 139: iteration 70/71
# Epoch 139 --> loss:0.3810, acc:87.41%, val_loss:1.1072, val_acc:72.16%
#  Epoch 140: iteration 70/71
# Epoch 140 --> loss:0.4330, acc:85.10%, val_loss:1.3684, val_acc:63.92%
#  Epoch 141: iteration 70/71
# Epoch 141 --> loss:0.4208, acc:85.62%, val_loss:1.0445, val_acc:69.07%
#  Epoch 142: iteration 70/71
# Epoch 142 --> loss:0.3463, acc:88.71%, val_loss:0.9282, val_acc:71.13%
#  Epoch 143: iteration 70/71
# Epoch 143 --> loss:0.3221, acc:89.93%, val_loss:1.1542, val_acc:67.01%
#  Epoch 144: iteration 70/71
# Epoch 144 --> loss:0.3800, acc:88.10%, val_loss:1.0758, val_acc:72.16%
#  Epoch 145: iteration 70/71
# Epoch 145 --> loss:0.3137, acc:90.46%, val_loss:0.9491, val_acc:74.23%
#  Epoch 146: iteration 70/71
# Epoch 146 --> loss:0.3003, acc:89.76%, val_loss:1.0010, val_acc:70.10%
#  Epoch 147: iteration 70/71
# Epoch 147 --> loss:0.2786, acc:91.85%, val_loss:0.9798, val_acc:73.20%
#  Epoch 148: iteration 70/71
# Epoch 148 --> loss:0.2701, acc:91.76%, val_loss:1.0456, val_acc:71.13%
#  Epoch 149: iteration 70/71
# Epoch 149 --> loss:0.2246, acc:93.81%, val_loss:0.8831, val_acc:73.20%
#  Epoch 150: iteration 70/71
# Epoch 150 --> loss:0.2452, acc:92.24%, val_loss:1.0304, val_acc:70.10%
#  Epoch 151: iteration 70/71
# Epoch 151 --> loss:0.2094, acc:94.12%, val_loss:0.9667, val_acc:78.35%
#  Epoch 152: iteration 70/71
# Epoch 152 --> loss:0.2033, acc:94.64%, val_loss:0.9888, val_acc:77.32%
#  Epoch 153: iteration 70/71
# Epoch 153 --> loss:0.2407, acc:92.64%, val_loss:0.8976, val_acc:74.23%
#  Epoch 154: iteration 70/71
# Epoch 154 --> loss:0.2429, acc:92.98%, val_loss:1.1415, val_acc:72.16%
#  Epoch 155: iteration 70/71
# Epoch 155 --> loss:0.2221, acc:93.42%, val_loss:1.0348, val_acc:73.20%
#  Epoch 156: iteration 70/71
# Epoch 156 --> loss:0.2255, acc:93.46%, val_loss:1.0966, val_acc:72.16%
#  Epoch 157: iteration 70/71
# Epoch 157 --> loss:0.1995, acc:94.38%, val_loss:1.1275, val_acc:73.20%
#  Epoch 158: iteration 70/71
# Epoch 158 --> loss:0.1978, acc:94.16%, val_loss:1.1629, val_acc:71.13%
#  Epoch 159: iteration 70/71
# Epoch 159 --> loss:0.1908, acc:94.55%, val_loss:1.4148, val_acc:65.98%
#  Epoch 160: iteration 70/71
# Epoch 160 --> loss:0.2156, acc:93.12%, val_loss:1.2061, val_acc:73.20%
#  Epoch 161: iteration 70/71
# Epoch 161 --> loss:0.2041, acc:93.64%, val_loss:0.9069, val_acc:76.29%
#  Epoch 162: iteration 70/71
# Epoch 162 --> loss:0.2012, acc:93.64%, val_loss:1.0210, val_acc:71.13%
#  Epoch 163: iteration 70/71
# Epoch 163 --> loss:0.2026, acc:94.20%, val_loss:1.3693, val_acc:70.10%
#  Epoch 164: iteration 70/71
# Epoch 164 --> loss:0.4065, acc:85.88%, val_loss:1.1469, val_acc:70.10%
#  Epoch 165: iteration 70/71
# Epoch 165 --> loss:0.3508, acc:87.84%, val_loss:1.0771, val_acc:69.07%
#  Epoch 166: iteration 70/71
# Epoch 166 --> loss:0.3552, acc:88.80%, val_loss:1.2715, val_acc:74.23%
#  Epoch 167: iteration 70/71
# Epoch 167 --> loss:0.2398, acc:92.85%, val_loss:1.3677, val_acc:62.89%
#  Epoch 168: iteration 70/71
# Epoch 168 --> loss:0.2251, acc:93.16%, val_loss:1.0984, val_acc:73.20%
#  Epoch 169: iteration 70/71
# Epoch 169 --> loss:0.1762, acc:94.90%, val_loss:0.9809, val_acc:78.35%
#  Epoch 170: iteration 70/71
# Epoch 170 --> loss:0.1933, acc:93.90%, val_loss:1.1491, val_acc:72.16%
#  Epoch 171: iteration 70/71
# Epoch 171 --> loss:0.1755, acc:94.86%, val_loss:1.1135, val_acc:74.23%
#  Epoch 172: iteration 70/71
# Epoch 172 --> loss:0.1436, acc:96.12%, val_loss:0.9744, val_acc:72.16%
#  Epoch 173: iteration 70/71
# Epoch 173 --> loss:0.1245, acc:97.12%, val_loss:0.9958, val_acc:76.29%
#  Epoch 174: iteration 70/71
# Epoch 174 --> loss:0.1229, acc:97.17%, val_loss:1.1364, val_acc:73.20%
#  Epoch 175: iteration 70/71
# Epoch 175 --> loss:0.1521, acc:95.29%, val_loss:1.0660, val_acc:72.16%
#  Epoch 176: iteration 70/71
# Epoch 176 --> loss:0.1430, acc:95.60%, val_loss:1.1100, val_acc:73.20%
#  Epoch 177: iteration 70/71
# Epoch 177 --> loss:0.1188, acc:96.86%, val_loss:0.9968, val_acc:74.23%
#  Epoch 178: iteration 70/71
# Epoch 178 --> loss:0.1330, acc:96.03%, val_loss:1.2047, val_acc:71.13%
#  Epoch 179: iteration 70/71
# Epoch 179 --> loss:0.1176, acc:96.86%, val_loss:1.2018, val_acc:76.29%
#  Epoch 180: iteration 70/71
# Epoch 180 --> loss:0.0918, acc:97.86%, val_loss:1.1919, val_acc:74.23%
#  Epoch 181: iteration 70/71
# Epoch 181 --> loss:0.0832, acc:97.86%, val_loss:1.1518, val_acc:74.23%
#  Epoch 182: iteration 70/71
# Epoch 182 --> loss:0.0818, acc:97.65%, val_loss:1.4552, val_acc:70.10%
#  Epoch 183: iteration 70/71
# Epoch 183 --> loss:0.0864, acc:97.52%, val_loss:1.1944, val_acc:73.20%
#  Epoch 184: iteration 70/71
# Epoch 184 --> loss:0.1081, acc:96.73%, val_loss:1.3208, val_acc:74.23%
#  Epoch 185: iteration 70/71
# Epoch 185 --> loss:0.2219, acc:93.20%, val_loss:1.2141, val_acc:68.04%
#  Epoch 186: iteration 70/71
# Epoch 186 --> loss:0.4707, acc:84.18%, val_loss:1.1724, val_acc:68.04%
#  Epoch 187: iteration 70/71
# Epoch 187 --> loss:0.3623, acc:87.15%, val_loss:1.3747, val_acc:60.82%
#  Epoch 188: iteration 70/71
# Epoch 188 --> loss:0.4009, acc:86.14%, val_loss:1.3661, val_acc:64.95%
#  Epoch 189: iteration 70/71
# Epoch 189 --> loss:0.2822, acc:91.33%, val_loss:1.2880, val_acc:64.95%
#  Epoch 190: iteration 70/71
# Epoch 190 --> loss:0.2025, acc:94.16%, val_loss:1.0840, val_acc:67.01%
#  Epoch 191: iteration 70/71
# Epoch 191 --> loss:0.1647, acc:95.21%, val_loss:1.2553, val_acc:69.07%
#  Epoch 192: iteration 70/71
# Epoch 192 --> loss:0.1803, acc:94.42%, val_loss:1.2212, val_acc:73.20%
#  Epoch 193: iteration 70/71
# Epoch 193 --> loss:0.2404, acc:91.76%, val_loss:1.1654, val_acc:70.10%
#  Epoch 194: iteration 70/71
# Epoch 194 --> loss:0.1242, acc:96.69%, val_loss:1.1011, val_acc:73.20%
#  Epoch 195: iteration 70/71
# Epoch 195 --> loss:0.0954, acc:97.69%, val_loss:1.0614, val_acc:70.10%
#  Epoch 196: iteration 70/71
# Epoch 196 --> loss:0.1002, acc:97.25%, val_loss:1.1564, val_acc:75.26%
#  Epoch 197: iteration 70/71
# Epoch 197 --> loss:0.1181, acc:96.38%, val_loss:0.9482, val_acc:75.26%
#  Epoch 198: iteration 70/71
# Epoch 198 --> loss:0.0890, acc:97.78%, val_loss:1.0024, val_acc:75.26%
#  Epoch 199: iteration 70/71
# Epoch 199 --> loss:0.1077, acc:96.78%, val_loss:1.0378, val_acc:70.10%
#  Epoch 200: iteration 70/71
# Epoch 200 --> loss:0.0800, acc:98.04%, val_loss:1.0492, val_acc:70.10%
#  Epoch 201: iteration 70/71
# Epoch 201 --> loss:0.0989, acc:97.12%, val_loss:1.0701, val_acc:74.23%
#  Epoch 202: iteration 70/71
# Epoch 202 --> loss:0.0738, acc:98.00%, val_loss:0.9304, val_acc:72.16%
#  Epoch 203: iteration 70/71
# Epoch 203 --> loss:0.0683, acc:98.04%, val_loss:1.0945, val_acc:70.10%
#  Epoch 204: iteration 70/71
# Epoch 204 --> loss:0.0596, acc:98.52%, val_loss:1.0724, val_acc:73.20%
#  Epoch 205: iteration 70/71
# Epoch 205 --> loss:0.0607, acc:98.47%, val_loss:1.0588, val_acc:72.16%
#  Epoch 206: iteration 70/71
# Epoch 206 --> loss:0.0743, acc:97.91%, val_loss:1.1379, val_acc:72.16%
#  Epoch 207: iteration 70/71
# Epoch 207 --> loss:0.0788, acc:97.91%, val_loss:1.1980, val_acc:73.20%
#  Epoch 208: iteration 70/71
# Epoch 208 --> loss:0.0672, acc:97.91%, val_loss:1.1351, val_acc:65.98%
#  Epoch 209: iteration 70/71
# Epoch 209 --> loss:0.0568, acc:98.34%, val_loss:1.1883, val_acc:69.07%
#  Epoch 210: iteration 70/71
# Epoch 210 --> loss:0.0541, acc:98.34%, val_loss:1.0653, val_acc:75.26%
#  Epoch 211: iteration 70/71
# Epoch 211 --> loss:0.0548, acc:98.43%, val_loss:1.0619, val_acc:75.26%
#  Epoch 212: iteration 70/71
# Epoch 212 --> loss:0.0444, acc:98.74%, val_loss:1.1161, val_acc:72.16%
#  Epoch 213: iteration 70/71
# Epoch 213 --> loss:0.0434, acc:98.56%, val_loss:1.1066, val_acc:73.20%
#  Epoch 214: iteration 70/71
# Epoch 214 --> loss:0.0394, acc:98.87%, val_loss:1.0849, val_acc:73.20%
#  Epoch 215: iteration 70/71
# Epoch 215 --> loss:0.0409, acc:98.69%, val_loss:1.0585, val_acc:72.16%
#  Epoch 216: iteration 70/71
# Epoch 216 --> loss:0.0378, acc:98.69%, val_loss:1.1199, val_acc:70.10%
#  Epoch 217: iteration 70/71
# Epoch 217 --> loss:0.0414, acc:98.74%, val_loss:1.1065, val_acc:73.20%
#  Epoch 218: iteration 70/71
# Epoch 218 --> loss:0.0471, acc:98.39%, val_loss:1.0469, val_acc:75.26%
#  Epoch 219: iteration 70/71
# Epoch 219 --> loss:0.0477, acc:98.52%, val_loss:1.1674, val_acc:78.35%
#  Epoch 220: iteration 70/71
# Epoch 220 --> loss:0.0424, acc:98.65%, val_loss:1.1840, val_acc:72.16%
#  Epoch 221: iteration 70/71
# Epoch 221 --> loss:0.0413, acc:98.65%, val_loss:1.1650, val_acc:79.38%
#  Epoch 222: iteration 70/71
# Epoch 222 --> loss:0.0323, acc:98.82%, val_loss:1.1076, val_acc:77.32%
#  Epoch 223: iteration 70/71
# Epoch 223 --> loss:0.0833, acc:97.12%, val_loss:1.3081, val_acc:69.07%
#  Epoch 224: iteration 70/71
# Epoch 224 --> loss:0.2687, acc:91.90%, val_loss:1.2849, val_acc:69.07%
#  Epoch 225: iteration 70/71
# Epoch 225 --> loss:0.1652, acc:94.25%, val_loss:1.3060, val_acc:70.10%
#  Epoch 226: iteration 70/71
# Epoch 226 --> loss:0.4128, acc:85.93%, val_loss:1.2210, val_acc:65.98%
#  Epoch 227: iteration 70/71
# Epoch 227 --> loss:0.2720, acc:91.07%, val_loss:0.9297, val_acc:72.16%
#  Epoch 228: iteration 70/71
# Epoch 228 --> loss:0.1336, acc:96.38%, val_loss:1.0521, val_acc:71.13%
#  Epoch 229: iteration 70/71
# Epoch 229 --> loss:0.0882, acc:97.73%, val_loss:1.0131, val_acc:74.23%
#  Epoch 230: iteration 70/71
# Epoch 230 --> loss:0.0710, acc:98.08%, val_loss:0.9849, val_acc:74.23%
#  Epoch 231: iteration 70/71
# Epoch 231 --> loss:0.0573, acc:98.52%, val_loss:1.0769, val_acc:72.16%
#  Epoch 232: iteration 70/71
# Epoch 232 --> loss:0.0448, acc:98.82%, val_loss:1.0593, val_acc:75.26%
#  Epoch 233: iteration 70/71
# Epoch 233 --> loss:0.0490, acc:98.43%, val_loss:1.1331, val_acc:73.20%
#  Epoch 234: iteration 70/71
# Epoch 234 --> loss:0.0487, acc:98.61%, val_loss:1.0374, val_acc:74.23%
#  Epoch 235: iteration 70/71
# Epoch 235 --> loss:0.0388, acc:98.82%, val_loss:1.0990, val_acc:70.10%
#  Epoch 236: iteration 70/71
# Epoch 236 --> loss:0.0358, acc:98.95%, val_loss:1.1260, val_acc:71.13%
#  Epoch 237: iteration 70/71
# Epoch 237 --> loss:0.0470, acc:98.34%, val_loss:1.1930, val_acc:72.16%
#  Epoch 238: iteration 70/71
# Epoch 238 --> loss:0.0461, acc:98.69%, val_loss:1.0840, val_acc:73.20%
#  Epoch 239: iteration 70/71
# Epoch 239 --> loss:0.0385, acc:98.74%, val_loss:1.1344, val_acc:76.29%
#  Epoch 240: iteration 70/71
# Epoch 240 --> loss:0.0448, acc:98.52%, val_loss:1.1438, val_acc:72.16%
#  Epoch 241: iteration 70/71
# Epoch 241 --> loss:0.0705, acc:97.95%, val_loss:1.2111, val_acc:72.16%
#  Epoch 242: iteration 70/71
# Epoch 242 --> loss:0.0528, acc:98.17%, val_loss:1.1284, val_acc:74.23%
#  Epoch 243: iteration 70/71
# Epoch 243 --> loss:0.0378, acc:98.69%, val_loss:1.0873, val_acc:74.23%
#  Epoch 244: iteration 70/71
# Epoch 244 --> loss:0.0333, acc:98.82%, val_loss:1.1106, val_acc:75.26%
#  Epoch 245: iteration 70/71
# Epoch 245 --> loss:0.0309, acc:98.82%, val_loss:1.0456, val_acc:75.26%
#  Epoch 246: iteration 70/71
# Epoch 246 --> loss:0.0281, acc:98.78%, val_loss:1.1116, val_acc:75.26%
#  Epoch 247: iteration 70/71
# Epoch 247 --> loss:0.0491, acc:98.30%, val_loss:1.0082, val_acc:74.23%
#  Epoch 248: iteration 70/71
# Epoch 248 --> loss:0.0766, acc:97.34%, val_loss:1.1441, val_acc:70.10%
#  Epoch 249: iteration 70/71
# Epoch 249 --> loss:0.2300, acc:92.11%, val_loss:1.2952, val_acc:70.10%
#  Epoch 250: iteration 70/71
# Epoch 250 --> loss:0.1397, acc:95.38%, val_loss:1.2536, val_acc:69.07%
#  Epoch 251: iteration 70/71
# Epoch 251 --> loss:0.1399, acc:95.95%, val_loss:1.1308, val_acc:73.20%
#  Epoch 252: iteration 70/71
# Epoch 252 --> loss:0.1077, acc:96.82%, val_loss:1.0422, val_acc:72.16%
#  Epoch 253: iteration 70/71
# Epoch 253 --> loss:0.0682, acc:97.95%, val_loss:1.0516, val_acc:73.20%
#  Epoch 254: iteration 70/71
# Epoch 254 --> loss:0.0438, acc:98.69%, val_loss:1.0598, val_acc:76.29%
#  Epoch 255: iteration 70/71
# Epoch 255 --> loss:0.0338, acc:98.91%, val_loss:1.0953, val_acc:73.20%
#  Epoch 256: iteration 70/71
# Epoch 256 --> loss:0.0341, acc:98.78%, val_loss:1.0364, val_acc:75.26%
#  Epoch 257: iteration 70/71
# Epoch 257 --> loss:0.0297, acc:98.95%, val_loss:1.0435, val_acc:76.29%
#  Epoch 258: iteration 70/71
# Epoch 258 --> loss:0.0282, acc:98.87%, val_loss:1.0016, val_acc:73.20%
#  Epoch 259: iteration 70/71
# Epoch 259 --> loss:0.0312, acc:98.74%, val_loss:0.9922, val_acc:74.23%
#  Epoch 260: iteration 70/71
# Epoch 260 --> loss:0.0249, acc:98.95%, val_loss:1.0129, val_acc:71.13%
#  Epoch 261: iteration 70/71
# Epoch 261 --> loss:0.0280, acc:98.82%, val_loss:0.9922, val_acc:75.26%
#  Epoch 262: iteration 70/71
# Epoch 262 --> loss:0.0289, acc:98.78%, val_loss:1.0173, val_acc:74.23%
#  Epoch 263: iteration 70/71
# Epoch 263 --> loss:0.0229, acc:98.95%, val_loss:1.0114, val_acc:75.26%
#  Epoch 264: iteration 70/71
# Epoch 264 --> loss:0.0248, acc:98.91%, val_loss:1.0586, val_acc:74.23%
#  Epoch 265: iteration 70/71
# Epoch 265 --> loss:0.0236, acc:99.00%, val_loss:1.0824, val_acc:72.16%
#  Epoch 266: iteration 70/71
# Epoch 266 --> loss:0.0294, acc:98.82%, val_loss:1.0813, val_acc:68.04%
#  Epoch 267: iteration 70/71
# Epoch 267 --> loss:0.0293, acc:98.95%, val_loss:1.2445, val_acc:71.13%
#  Epoch 268: iteration 70/71
# Epoch 268 --> loss:0.0262, acc:98.87%, val_loss:1.0961, val_acc:75.26%
#  Epoch 269: iteration 70/71
# Epoch 269 --> loss:0.0230, acc:98.91%, val_loss:1.0661, val_acc:76.29%
#  Epoch 270: iteration 70/71
# Epoch 270 --> loss:0.0247, acc:98.95%, val_loss:1.0726, val_acc:73.20%
#  Epoch 271: iteration 70/71
# Epoch 271 --> loss:0.0223, acc:98.91%, val_loss:1.1294, val_acc:73.20%
#  Epoch 272: iteration 70/71
# Epoch 272 --> loss:0.0221, acc:98.95%, val_loss:1.0479, val_acc:76.29%
#  Epoch 273: iteration 70/71
# Epoch 273 --> loss:0.0226, acc:99.00%, val_loss:1.0768, val_acc:73.20%
#  Epoch 274: iteration 70/71
# Epoch 274 --> loss:0.0233, acc:98.95%, val_loss:1.0803, val_acc:76.29%
#  Epoch 275: iteration 70/71
# Epoch 275 --> loss:0.0226, acc:98.87%, val_loss:1.1099, val_acc:73.20%
#  Epoch 276: iteration 70/71
# Epoch 276 --> loss:0.0202, acc:98.95%, val_loss:1.0614, val_acc:72.16%
#  Epoch 277: iteration 70/71
# Epoch 277 --> loss:0.0221, acc:98.91%, val_loss:1.0593, val_acc:74.23%
#  Epoch 278: iteration 70/71
# Epoch 278 --> loss:0.0237, acc:98.95%, val_loss:1.0620, val_acc:76.29%
#  Epoch 279: iteration 70/71
# Epoch 279 --> loss:0.0210, acc:99.00%, val_loss:1.0645, val_acc:74.23%
#  Epoch 280: iteration 70/71
# Epoch 280 --> loss:0.0210, acc:98.91%, val_loss:0.9742, val_acc:75.26%
#  Epoch 281: iteration 70/71
# Epoch 281 --> loss:0.0272, acc:98.91%, val_loss:1.0706, val_acc:73.20%
#  Epoch 282: iteration 70/71
# Epoch 282 --> loss:0.1489, acc:94.90%, val_loss:1.6016, val_acc:65.98%
#  Epoch 283: iteration 70/71
# Epoch 283 --> loss:0.7758, acc:73.42%, val_loss:1.6417, val_acc:59.79%
#  Epoch 284: iteration 70/71
# Epoch 284 --> loss:0.3373, acc:88.06%, val_loss:1.0999, val_acc:67.01%
#  Epoch 285: iteration 70/71
# Epoch 285 --> loss:0.1849, acc:94.25%, val_loss:0.9512, val_acc:71.13%
#  Epoch 286: iteration 70/71
# Epoch 286 --> loss:0.1632, acc:94.99%, val_loss:1.2419, val_acc:63.92%
#  Epoch 287: iteration 70/71
# Epoch 287 --> loss:0.1626, acc:95.12%, val_loss:1.0138, val_acc:69.07%
#  Epoch 288: iteration 70/71
# Epoch 288 --> loss:0.0943, acc:97.25%, val_loss:1.0264, val_acc:76.29%
#  Epoch 289: iteration 70/71
# Epoch 289 --> loss:0.0642, acc:98.30%, val_loss:1.1324, val_acc:74.23%
#  Epoch 290: iteration 70/71
# Epoch 290 --> loss:0.0510, acc:98.47%, val_loss:1.0658, val_acc:75.26%
#  Epoch 291: iteration 70/71
# Epoch 291 --> loss:0.0481, acc:98.65%, val_loss:1.0627, val_acc:71.13%
#  Epoch 292: iteration 70/71
# Epoch 292 --> loss:0.0718, acc:97.86%, val_loss:1.2147, val_acc:74.23%
#  Epoch 293: iteration 70/71
# Epoch 293 --> loss:0.0483, acc:98.43%, val_loss:1.0522, val_acc:73.20%
#  Epoch 294: iteration 70/71
# Epoch 294 --> loss:0.0407, acc:98.74%, val_loss:1.0245, val_acc:71.13%
#  Epoch 295: iteration 70/71
# Epoch 295 --> loss:0.0341, acc:98.91%, val_loss:1.0582, val_acc:75.26%
#  Epoch 296: iteration 70/71
# Epoch 296 --> loss:0.0353, acc:98.91%, val_loss:1.0935, val_acc:75.26%
#  Epoch 297: iteration 70/71
# Epoch 297 --> loss:0.0283, acc:99.00%, val_loss:1.0667, val_acc:75.26%
#  Epoch 298: iteration 70/71
# Epoch 298 --> loss:0.0263, acc:98.95%, val_loss:1.0832, val_acc:75.26%
#  Epoch 299: iteration 70/71
# Epoch 299 --> loss:0.0284, acc:98.95%, val_loss:1.0910, val_acc:75.26%
#  Epoch 300: iteration 70/71
# Epoch 300 --> loss:0.0283, acc:98.95%, val_loss:1.0858, val_acc:76.29%
#  Epoch 301: iteration 70/71
# Epoch 301 --> loss:0.0258, acc:98.82%, val_loss:1.0836, val_acc:74.23%
#  Epoch 302: iteration 70/71
# Epoch 302 --> loss:0.0267, acc:98.87%, val_loss:1.1351, val_acc:74.23%
#  Epoch 303: iteration 70/71
# Epoch 303 --> loss:0.0688, acc:97.56%, val_loss:1.1078, val_acc:72.16%
#  Epoch 304: iteration 70/71
# Epoch 304 --> loss:0.0844, acc:97.39%, val_loss:1.0428, val_acc:73.20%
#  Epoch 305: iteration 70/71
# Epoch 305 --> loss:0.0636, acc:98.21%, val_loss:1.1315, val_acc:76.29%
#  Epoch 306: iteration 70/71
# Epoch 306 --> loss:0.0368, acc:98.91%, val_loss:0.9967, val_acc:75.26%
#  Epoch 307: iteration 70/71
# Epoch 307 --> loss:0.0268, acc:98.91%, val_loss:1.0374, val_acc:76.29%
#  Epoch 308: iteration 70/71
# Epoch 308 --> loss:0.0262, acc:98.95%, val_loss:1.0041, val_acc:77.32%
#  Epoch 309: iteration 70/71
# Epoch 309 --> loss:0.0251, acc:98.78%, val_loss:1.0307, val_acc:78.35%
#  Epoch 310: iteration 70/71
# Epoch 310 --> loss:0.0297, acc:98.95%, val_loss:1.0571, val_acc:75.26%
#  Epoch 311: iteration 70/71
# Epoch 311 --> loss:0.0221, acc:99.00%, val_loss:1.0395, val_acc:77.32%
#  Epoch 312: iteration 70/71
# Epoch 312 --> loss:0.0220, acc:98.95%, val_loss:1.0041, val_acc:78.35%
#  Epoch 313: iteration 70/71
# Epoch 313 --> loss:0.0210, acc:98.91%, val_loss:1.0229, val_acc:77.32%
#  Epoch 314: iteration 70/71
# Epoch 314 --> loss:0.0332, acc:98.69%, val_loss:1.1256, val_acc:77.32%
#  Epoch 315: iteration 70/71
# Epoch 315 --> loss:0.1001, acc:96.30%, val_loss:0.9474, val_acc:77.32%
#  Epoch 316: iteration 70/71
# Epoch 316 --> loss:0.1965, acc:93.16%, val_loss:1.3069, val_acc:72.16%
#  Epoch 317: iteration 70/71
# Epoch 317 --> loss:0.1819, acc:94.20%, val_loss:1.2612, val_acc:72.16%
#  Epoch 318: iteration 70/71
# Epoch 318 --> loss:0.1502, acc:95.51%, val_loss:1.2132, val_acc:74.23%
#  Epoch 319: iteration 70/71
# Epoch 319 --> loss:0.1671, acc:94.51%, val_loss:1.3285, val_acc:65.98%
#  Epoch 320: iteration 70/71
# Epoch 320 --> loss:0.2044, acc:93.07%, val_loss:1.1673, val_acc:72.16%
#  Epoch 321: iteration 70/71
# Epoch 321 --> loss:0.0788, acc:97.60%, val_loss:1.3679, val_acc:69.07%
#  Epoch 322: iteration 70/71
# Epoch 322 --> loss:0.1461, acc:94.73%, val_loss:1.1787, val_acc:74.23%
#  Epoch 323: iteration 70/71
# Epoch 323 --> loss:0.1383, acc:95.77%, val_loss:1.2408, val_acc:69.07%
#  Epoch 324: iteration 70/71
# Epoch 324 --> loss:0.1489, acc:95.51%, val_loss:1.1221, val_acc:70.10%
#  Epoch 325: iteration 70/71
# Epoch 325 --> loss:0.0817, acc:97.39%, val_loss:1.0836, val_acc:73.20%
#  Epoch 326: iteration 70/71
# Epoch 326 --> loss:0.0316, acc:98.95%, val_loss:1.0622, val_acc:75.26%
#  Epoch 327: iteration 70/71
# Epoch 327 --> loss:0.0301, acc:98.91%, val_loss:1.1194, val_acc:72.16%
#  Epoch 328: iteration 70/71
# Epoch 328 --> loss:0.0267, acc:99.00%, val_loss:1.0756, val_acc:70.10%
#  Epoch 329: iteration 70/71
# Epoch 329 --> loss:0.0246, acc:98.95%, val_loss:1.0553, val_acc:73.20%
#  Epoch 330: iteration 70/71
# Epoch 330 --> loss:0.0246, acc:99.00%, val_loss:1.1219, val_acc:72.16%
#  Epoch 331: iteration 70/71
# Epoch 331 --> loss:0.0215, acc:99.00%, val_loss:1.0797, val_acc:72.16%
#  Epoch 332: iteration 70/71
# Epoch 332 --> loss:0.0212, acc:98.95%, val_loss:1.0797, val_acc:73.20%
#  Epoch 333: iteration 70/71
# Epoch 333 --> loss:0.0216, acc:98.91%, val_loss:1.0641, val_acc:74.23%
#  Epoch 334: iteration 70/71
# Epoch 334 --> loss:0.0207, acc:98.95%, val_loss:1.1179, val_acc:74.23%
#  Epoch 335: iteration 70/71
# Epoch 335 --> loss:0.0186, acc:98.91%, val_loss:1.0723, val_acc:75.26%
#  Epoch 336: iteration 70/71
# Epoch 336 --> loss:0.0177, acc:99.00%, val_loss:1.0589, val_acc:74.23%
#  Epoch 337: iteration 70/71
# Epoch 337 --> loss:0.0185, acc:99.00%, val_loss:1.0349, val_acc:75.26%
#  Epoch 338: iteration 70/71
# Epoch 338 --> loss:0.0185, acc:99.00%, val_loss:1.0761, val_acc:77.32%
#  Epoch 339: iteration 70/71
# Epoch 339 --> loss:0.0437, acc:98.47%, val_loss:1.1577, val_acc:70.10%
#  Epoch 340: iteration 70/71
# Epoch 340 --> loss:0.0283, acc:98.82%, val_loss:1.1044, val_acc:73.20%
#  Epoch 341: iteration 70/71
# Epoch 341 --> loss:0.0195, acc:99.00%, val_loss:1.0639, val_acc:76.29%
#  Epoch 342: iteration 70/71
# Epoch 342 --> loss:0.0167, acc:99.00%, val_loss:1.0909, val_acc:75.26%
#  Epoch 343: iteration 70/71
# Epoch 343 --> loss:0.0193, acc:98.95%, val_loss:1.0914, val_acc:74.23%
#  Epoch 344: iteration 70/71
# Epoch 344 --> loss:0.0185, acc:99.00%, val_loss:1.1547, val_acc:70.10%
#  Epoch 345: iteration 70/71
# Epoch 345 --> loss:0.0175, acc:99.00%, val_loss:1.0826, val_acc:74.23%
#  Epoch 346: iteration 70/71
# Epoch 346 --> loss:0.0186, acc:99.00%, val_loss:1.0552, val_acc:73.20%
#  Epoch 347: iteration 70/71
# Epoch 347 --> loss:0.0173, acc:99.00%, val_loss:1.0888, val_acc:73.20%
#  Epoch 348: iteration 70/71
# Epoch 348 --> loss:0.0186, acc:98.95%, val_loss:1.1151, val_acc:72.16%
#  Epoch 349: iteration 70/71
# Epoch 349 --> loss:0.0157, acc:99.00%, val_loss:1.0744, val_acc:72.16%
#  Epoch 350: iteration 70/71
# Epoch 350 --> loss:0.0198, acc:98.95%, val_loss:1.1285, val_acc:70.10%
#  Epoch 351: iteration 70/71
# Epoch 351 --> loss:0.0191, acc:98.95%, val_loss:1.1006, val_acc:72.16%
#  Epoch 352: iteration 70/71
# Epoch 352 --> loss:0.0158, acc:99.00%, val_loss:1.0927, val_acc:71.13%
#  Epoch 353: iteration 70/71
# Epoch 353 --> loss:0.0163, acc:99.00%, val_loss:1.0685, val_acc:74.23%
#  Epoch 354: iteration 70/71
# Epoch 354 --> loss:0.0159, acc:98.95%, val_loss:1.0644, val_acc:73.20%
#  Epoch 355: iteration 70/71
# Epoch 355 --> loss:0.0158, acc:99.00%, val_loss:1.0530, val_acc:73.20%
#  Epoch 356: iteration 70/71
# Epoch 356 --> loss:0.0161, acc:98.95%, val_loss:1.0376, val_acc:75.26%
#  Epoch 357: iteration 70/71
# Epoch 357 --> loss:0.0168, acc:99.00%, val_loss:1.0812, val_acc:71.13%
#  Epoch 358: iteration 70/71
# Epoch 358 --> loss:0.0161, acc:99.00%, val_loss:1.0637, val_acc:72.16%
#  Epoch 359: iteration 70/71
# Epoch 359 --> loss:0.0156, acc:99.00%, val_loss:1.0454, val_acc:74.23%
#  Epoch 360: iteration 70/71
# Epoch 360 --> loss:0.0159, acc:99.00%, val_loss:1.0671, val_acc:75.26%
#  Epoch 361: iteration 70/71
# Epoch 361 --> loss:0.0157, acc:98.95%, val_loss:1.0852, val_acc:74.23%
#  Epoch 362: iteration 70/71
# Epoch 362 --> loss:0.0148, acc:99.00%, val_loss:1.1290, val_acc:71.13%
#  Epoch 363: iteration 70/71
# Epoch 363 --> loss:0.0154, acc:99.00%, val_loss:1.1362, val_acc:74.23%
#  Epoch 364: iteration 70/71
# Epoch 364 --> loss:0.0271, acc:98.74%, val_loss:1.2134, val_acc:72.16%
#  Epoch 365: iteration 70/71
# Epoch 365 --> loss:0.4782, acc:84.36%, val_loss:1.3241, val_acc:64.95%
#  Epoch 366: iteration 70/71
# Epoch 366 --> loss:0.4392, acc:84.66%, val_loss:1.4462, val_acc:59.79%
#  Epoch 367: iteration 70/71
# Epoch 367 --> loss:0.3520, acc:88.41%, val_loss:1.2802, val_acc:68.04%
#  Epoch 368: iteration 70/71
# Epoch 368 --> loss:0.2616, acc:91.63%, val_loss:1.1908, val_acc:68.04%
#  Epoch 369: iteration 70/71
# Epoch 369 --> loss:0.3088, acc:89.93%, val_loss:1.1758, val_acc:71.13%
#  Epoch 370: iteration 70/71
# Epoch 370 --> loss:0.2654, acc:92.03%, val_loss:1.1017, val_acc:65.98%
#  Epoch 371: iteration 70/71
# Epoch 371 --> loss:0.1253, acc:96.30%, val_loss:0.9915, val_acc:75.26%
#  Epoch 372: iteration 70/71
# Epoch 372 --> loss:0.1086, acc:97.08%, val_loss:1.0753, val_acc:69.07%
#  Epoch 373: iteration 70/71
# Epoch 373 --> loss:0.0840, acc:97.82%, val_loss:0.9456, val_acc:75.26%
#  Epoch 374: iteration 70/71
# Epoch 374 --> loss:0.0453, acc:98.74%, val_loss:1.0033, val_acc:72.16%
#  Epoch 375: iteration 70/71
# Epoch 375 --> loss:0.0472, acc:98.52%, val_loss:0.9518, val_acc:73.20%
#  Epoch 376: iteration 70/71
# Epoch 376 --> loss:0.0383, acc:98.87%, val_loss:0.8325, val_acc:77.32%
#  Epoch 377: iteration 70/71
# Epoch 377 --> loss:0.0379, acc:98.69%, val_loss:1.0319, val_acc:76.29%
#  Epoch 378: iteration 70/71
# Epoch 378 --> loss:0.1286, acc:95.69%, val_loss:1.6187, val_acc:67.01%
#  Epoch 379: iteration 70/71
# Epoch 379 --> loss:0.3236, acc:89.19%, val_loss:1.1825, val_acc:69.07%
#  Epoch 380: iteration 70/71
# Epoch 380 --> loss:0.1784, acc:94.64%, val_loss:1.1428, val_acc:75.26%
#  Epoch 381: iteration 70/71
# Epoch 381 --> loss:0.1125, acc:96.86%, val_loss:1.1606, val_acc:72.16%
#  Epoch 382: iteration 70/71
# Epoch 382 --> loss:0.0555, acc:98.47%, val_loss:1.1570, val_acc:74.23%
#  Epoch 383: iteration 70/71
# Epoch 383 --> loss:0.0422, acc:98.78%, val_loss:1.1232, val_acc:74.23%
#  Epoch 384: iteration 70/71
# Epoch 384 --> loss:0.0406, acc:98.56%, val_loss:1.1380, val_acc:73.20%
#  Epoch 385: iteration 70/71
# Epoch 385 --> loss:0.0346, acc:98.91%, val_loss:1.3977, val_acc:59.79%
#  Epoch 386: iteration 70/71
# Epoch 386 --> loss:0.0527, acc:98.21%, val_loss:1.0752, val_acc:69.07%
#  Epoch 387: iteration 70/71
# Epoch 387 --> loss:0.0380, acc:98.61%, val_loss:1.0997, val_acc:73.20%
#  Epoch 388: iteration 70/71
# Epoch 388 --> loss:0.0309, acc:98.95%, val_loss:1.1538, val_acc:70.10%
#  Epoch 389: iteration 70/71
# Epoch 389 --> loss:0.0245, acc:98.95%, val_loss:1.0744, val_acc:73.20%
#  Epoch 390: iteration 70/71
# Epoch 390 --> loss:0.0230, acc:99.00%, val_loss:1.0798, val_acc:72.16%
#  Epoch 391: iteration 70/71
# Epoch 391 --> loss:0.0262, acc:98.74%, val_loss:1.1191, val_acc:70.10%
#  Epoch 392: iteration 70/71
# Epoch 392 --> loss:0.0219, acc:98.95%, val_loss:1.1073, val_acc:73.20%
#  Epoch 393: iteration 70/71
# Epoch 393 --> loss:0.0207, acc:99.00%, val_loss:1.1281, val_acc:76.29%
#  Epoch 394: iteration 70/71
# Epoch 394 --> loss:0.0191, acc:99.00%, val_loss:1.0975, val_acc:73.20%
#  Epoch 395: iteration 70/71
# Epoch 395 --> loss:0.0211, acc:98.95%, val_loss:1.0902, val_acc:72.16%
#  Epoch 396: iteration 70/71
# Epoch 396 --> loss:0.0200, acc:99.00%, val_loss:1.1361, val_acc:71.13%
#  Epoch 397: iteration 70/71
# Epoch 397 --> loss:0.0200, acc:98.91%, val_loss:1.1616, val_acc:67.01%
#  Epoch 398: iteration 70/71
# Epoch 398 --> loss:0.0189, acc:99.00%, val_loss:1.1167, val_acc:72.16%
#  Epoch 399: iteration 70/71
# Epoch 399 --> loss:0.0180, acc:98.95%, val_loss:1.1593, val_acc:70.10%
#  Epoch 400: iteration 70/71
# Epoch 400 --> loss:0.2217, acc:92.33%, val_loss:1.4172, val_acc:62.89%
#  Epoch 401: iteration 70/71
# Epoch 401 --> loss:0.3564, acc:87.84%, val_loss:1.4845, val_acc:58.76%
#  Epoch 402: iteration 70/71
# Epoch 402 --> loss:0.2141, acc:92.68%, val_loss:1.0612, val_acc:70.10%
#  Epoch 403: iteration 70/71
# Epoch 403 --> loss:0.1009, acc:96.91%, val_loss:1.1551, val_acc:71.13%
#  Epoch 404: iteration 70/71
# Epoch 404 --> loss:0.0680, acc:97.86%, val_loss:1.1536, val_acc:65.98%
#  Epoch 405: iteration 70/71
# Epoch 405 --> loss:0.0460, acc:98.65%, val_loss:1.1018, val_acc:70.10%
#  Epoch 406: iteration 70/71
# Epoch 406 --> loss:0.0348, acc:98.69%, val_loss:1.0881, val_acc:67.01%
#  Epoch 407: iteration 70/71
# Epoch 407 --> loss:0.0279, acc:98.82%, val_loss:1.0283, val_acc:70.10%
#  Epoch 408: iteration 70/71
# Epoch 408 --> loss:0.0235, acc:99.00%, val_loss:1.0514, val_acc:75.26%
#  Epoch 409: iteration 70/71
# Epoch 409 --> loss:0.0211, acc:98.95%, val_loss:1.0552, val_acc:76.29%
#  Epoch 410: iteration 70/71
# Epoch 410 --> loss:0.0227, acc:98.87%, val_loss:1.0650, val_acc:69.07%
#  Epoch 411: iteration 70/71
# Epoch 411 --> loss:0.0216, acc:98.95%, val_loss:1.0738, val_acc:71.13%
#  Epoch 412: iteration 70/71
# Epoch 412 --> loss:0.0195, acc:98.95%, val_loss:1.0409, val_acc:71.13%
#  Epoch 413: iteration 70/71
# Epoch 413 --> loss:0.1266, acc:95.73%, val_loss:1.1805, val_acc:64.95%
#  Epoch 414: iteration 70/71
# Epoch 414 --> loss:0.2324, acc:92.24%, val_loss:1.5510, val_acc:59.79%
#  Epoch 415: iteration 70/71
# Epoch 415 --> loss:0.2425, acc:91.81%, val_loss:1.4539, val_acc:64.95%
#  Epoch 416: iteration 70/71
# Epoch 416 --> loss:0.0762, acc:97.73%, val_loss:1.2847, val_acc:69.07%
#  Epoch 417: iteration 70/71
# Epoch 417 --> loss:0.1816, acc:93.90%, val_loss:1.0826, val_acc:74.23%
#  Epoch 418: iteration 70/71
# Epoch 418 --> loss:0.0550, acc:98.47%, val_loss:1.0317, val_acc:73.20%
#  Epoch 419: iteration 70/71
# Epoch 419 --> loss:0.0329, acc:98.74%, val_loss:0.9921, val_acc:73.20%
#  Epoch 420: iteration 70/71
# Epoch 420 --> loss:0.0259, acc:98.87%, val_loss:1.0242, val_acc:71.13%
#  Epoch 421: iteration 70/71
# Epoch 421 --> loss:0.0199, acc:98.95%, val_loss:1.0656, val_acc:74.23%
#  Epoch 422: iteration 70/71
# Epoch 422 --> loss:0.0203, acc:99.00%, val_loss:1.1002, val_acc:72.16%
#  Epoch 423: iteration 70/71
# Epoch 423 --> loss:0.0169, acc:99.00%, val_loss:1.0972, val_acc:71.13%
#  Epoch 424: iteration 70/71
# Epoch 424 --> loss:0.0173, acc:99.00%, val_loss:1.1344, val_acc:72.16%
#  Epoch 425: iteration 70/71
# Epoch 425 --> loss:0.0164, acc:99.00%, val_loss:1.1402, val_acc:72.16%
#  Epoch 426: iteration 70/71
# Epoch 426 --> loss:0.0153, acc:98.95%, val_loss:1.1252, val_acc:71.13%
#  Epoch 427: iteration 70/71
# Epoch 427 --> loss:0.0172, acc:99.00%, val_loss:1.1602, val_acc:70.10%
#  Epoch 428: iteration 70/71
# Epoch 428 --> loss:0.0155, acc:99.00%, val_loss:1.1365, val_acc:71.13%
#  Epoch 429: iteration 70/71
# Epoch 429 --> loss:0.0173, acc:98.95%, val_loss:1.1598, val_acc:72.16%
#  Epoch 430: iteration 70/71
# Epoch 430 --> loss:0.0145, acc:99.00%, val_loss:1.1574, val_acc:71.13%
#  Epoch 431: iteration 70/71
# Epoch 431 --> loss:0.0155, acc:99.00%, val_loss:1.1424, val_acc:73.20%
#  Epoch 432: iteration 70/71
# Epoch 432 --> loss:0.0144, acc:99.00%, val_loss:1.1437, val_acc:72.16%
#  Epoch 433: iteration 70/71
# Epoch 433 --> loss:0.0153, acc:98.95%, val_loss:1.1039, val_acc:72.16%
#  Epoch 434: iteration 70/71
# Epoch 434 --> loss:0.0169, acc:98.91%, val_loss:1.1319, val_acc:72.16%
#  Epoch 435: iteration 70/71
# Epoch 435 --> loss:0.0139, acc:99.00%, val_loss:1.0944, val_acc:76.29%
#  Epoch 436: iteration 70/71
# Epoch 436 --> loss:0.0141, acc:99.00%, val_loss:1.1075, val_acc:73.20%
#  Epoch 437: iteration 70/71
# Epoch 437 --> loss:0.0144, acc:99.00%, val_loss:1.0809, val_acc:73.20%
#  Epoch 438: iteration 70/71
# Epoch 438 --> loss:0.0167, acc:98.95%, val_loss:1.0782, val_acc:73.20%
#  Epoch 439: iteration 70/71
# Epoch 439 --> loss:0.0170, acc:98.91%, val_loss:1.0963, val_acc:74.23%
#  Epoch 440: iteration 70/71
# Epoch 440 --> loss:0.0142, acc:99.00%, val_loss:1.0881, val_acc:72.16%
#  Epoch 441: iteration 70/71
# Epoch 441 --> loss:0.0144, acc:99.00%, val_loss:1.1133, val_acc:73.20%
#  Epoch 442: iteration 70/71
# Epoch 442 --> loss:0.0137, acc:99.00%, val_loss:1.1281, val_acc:71.13%
#  Epoch 443: iteration 70/71
# Epoch 443 --> loss:0.0141, acc:99.00%, val_loss:1.1288, val_acc:71.13%
#  Epoch 444: iteration 70/71
# Epoch 444 --> loss:0.0138, acc:99.00%, val_loss:1.1322, val_acc:72.16%
#  Epoch 445: iteration 70/71
# Epoch 445 --> loss:0.0141, acc:99.00%, val_loss:1.1133, val_acc:70.10%
#  Epoch 446: iteration 70/71
# Epoch 446 --> loss:0.0134, acc:99.00%, val_loss:1.1120, val_acc:73.20%
#  Epoch 447: iteration 70/71
# Epoch 447 --> loss:0.0132, acc:99.00%, val_loss:1.1512, val_acc:71.13%
#  Epoch 448: iteration 70/71
# Epoch 448 --> loss:0.0146, acc:98.91%, val_loss:1.0998, val_acc:68.04%
#  Epoch 449: iteration 70/71
# Epoch 449 --> loss:0.0135, acc:99.00%, val_loss:1.0973, val_acc:71.13%
#  Epoch 450: iteration 70/71
# Epoch 450 --> loss:0.0135, acc:99.00%, val_loss:1.0846, val_acc:73.20%
#  Epoch 451: iteration 70/71
# Epoch 451 --> loss:0.0131, acc:99.00%, val_loss:1.1244, val_acc:72.16%
#  Epoch 452: iteration 70/71
# Epoch 452 --> loss:0.0143, acc:99.00%, val_loss:1.1310, val_acc:70.10%
#  Epoch 453: iteration 70/71
# Epoch 453 --> loss:0.0133, acc:99.00%, val_loss:1.1614, val_acc:69.07%
#  Epoch 454: iteration 70/71
# Epoch 454 --> loss:0.0140, acc:99.00%, val_loss:1.2066, val_acc:68.04%
#  Epoch 455: iteration 70/71
# Epoch 455 --> loss:0.0143, acc:99.00%, val_loss:1.1508, val_acc:69.07%
#  Epoch 456: iteration 70/71
# Epoch 456 --> loss:0.0130, acc:99.00%, val_loss:1.1639, val_acc:71.13%
#  Epoch 457: iteration 70/71
# Epoch 457 --> loss:0.0136, acc:99.00%, val_loss:1.1655, val_acc:70.10%
#  Epoch 458: iteration 70/71
# Epoch 458 --> loss:0.3101, acc:89.06%, val_loss:1.5313, val_acc:58.76%
#  Epoch 459: iteration 70/71
# Epoch 459 --> loss:0.4023, acc:86.23%, val_loss:0.9691, val_acc:64.95%
#  Epoch 460: iteration 70/71
# Epoch 460 --> loss:0.2203, acc:93.07%, val_loss:1.1365, val_acc:67.01%
#  Epoch 461: iteration 70/71
# Epoch 461 --> loss:0.1349, acc:96.30%, val_loss:1.1392, val_acc:62.89%
#  Epoch 462: iteration 70/71
# Epoch 462 --> loss:0.0793, acc:97.60%, val_loss:1.2048, val_acc:63.92%
#  Epoch 463: iteration 70/71
# Epoch 463 --> loss:0.3432, acc:88.15%, val_loss:1.2920, val_acc:67.01%
#  Epoch 464: iteration 70/71
# Epoch 464 --> loss:0.2799, acc:90.72%, val_loss:1.3813, val_acc:60.82%
#  Epoch 465: iteration 70/71
# Epoch 465 --> loss:0.1864, acc:93.86%, val_loss:1.2262, val_acc:61.86%
#  Epoch 466: iteration 70/71
# Epoch 466 --> loss:0.1053, acc:96.86%, val_loss:1.1857, val_acc:70.10%
#  Epoch 467: iteration 70/71
# Epoch 467 --> loss:0.0490, acc:98.74%, val_loss:1.1619, val_acc:68.04%
#  Epoch 468: iteration 70/71
# Epoch 468 --> loss:0.0320, acc:98.87%, val_loss:1.1018, val_acc:68.04%
#  Epoch 469: iteration 70/71
# Epoch 469 --> loss:0.0373, acc:98.56%, val_loss:1.1384, val_acc:67.01%
#  Epoch 470: iteration 70/71
# Epoch 470 --> loss:0.0271, acc:98.95%, val_loss:1.0513, val_acc:68.04%
#  Epoch 471: iteration 70/71
# Epoch 471 --> loss:0.0249, acc:98.95%, val_loss:1.0515, val_acc:69.07%
#  Epoch 472: iteration 70/71
# Epoch 472 --> loss:0.0216, acc:99.00%, val_loss:1.1216, val_acc:70.10%
#  Epoch 473: iteration 70/71
# Epoch 473 --> loss:0.0195, acc:99.00%, val_loss:1.1263, val_acc:68.04%
#  Epoch 474: iteration 70/71
# Epoch 474 --> loss:0.0190, acc:98.91%, val_loss:1.1286, val_acc:68.04%
#  Epoch 475: iteration 70/71
# Epoch 475 --> loss:0.0185, acc:99.00%, val_loss:1.1116, val_acc:68.04%
#  Epoch 476: iteration 70/71
# Epoch 476 --> loss:0.0167, acc:98.95%, val_loss:1.0756, val_acc:65.98%
#  Epoch 477: iteration 70/71
# Epoch 477 --> loss:0.0162, acc:99.00%, val_loss:1.1219, val_acc:67.01%
#  Epoch 478: iteration 70/71
# Epoch 478 --> loss:0.0159, acc:99.00%, val_loss:1.0867, val_acc:70.10%
#  Epoch 479: iteration 70/71
# Epoch 479 --> loss:0.0161, acc:99.00%, val_loss:1.1059, val_acc:67.01%
#  Epoch 480: iteration 70/71
# Epoch 480 --> loss:0.0142, acc:99.00%, val_loss:1.1037, val_acc:70.10%
#  Epoch 481: iteration 70/71
# Epoch 481 --> loss:0.0181, acc:98.91%, val_loss:1.3111, val_acc:71.13%
#  Epoch 482: iteration 70/71
# Epoch 482 --> loss:0.0214, acc:98.91%, val_loss:1.1072, val_acc:69.07%
#  Epoch 483: iteration 70/71
# Epoch 483 --> loss:0.0146, acc:99.00%, val_loss:1.0924, val_acc:70.10%
#  Epoch 484: iteration 70/71
# Epoch 484 --> loss:0.0152, acc:99.00%, val_loss:1.0947, val_acc:67.01%
#  Epoch 485: iteration 70/71
# Epoch 485 --> loss:0.0159, acc:99.00%, val_loss:1.0990, val_acc:70.10%
#  Epoch 486: iteration 70/71
# ...
#  Epoch 1342: iteration 70/71
# Epoch 1342 --> loss:0.0081, acc:99.00%, val_loss:1.2941, val_acc:69.07%
#  Epoch 1343: iteration 70/71
# Epoch 1343 --> loss:0.0078, acc:99.00%, val_loss:1.3065, val_acc:68.04%
#  Epoch 1344: iteration 70/71
# Epoch 1344 --> loss:0.0080, acc:99.00%, val_loss:1.3239, val_acc:67.01%
#  Epoch 1345: iteration 70/71
# Epoch 1345 --> loss:0.0076, acc:99.00%, val_loss:1.3242, val_acc:69.07%
#  Epoch 1346: iteration 70/71
# Epoch 1346 --> loss:0.0124, acc:98.91%, val_loss:1.3814, val_acc:67.01%
#  Epoch 1347: iteration 70/71
# Epoch 1347 --> loss:0.6253, acc:78.65%, val_loss:1.5240, val_acc:54.64%
#  Epoch 1348: iteration 70/71
# Epoch 1348 --> loss:0.4535, acc:84.36%, val_loss:1.2196, val_acc:62.89%
#  Epoch 1349: iteration 70/71
# Epoch 1349 --> loss:0.2748, acc:91.29%, val_loss:1.4939, val_acc:54.64%
#  Epoch 1350: iteration 70/71
# Epoch 1350 --> loss:0.3109, acc:90.07%, val_loss:1.2247, val_acc:64.95%
#  Epoch 1351: iteration 70/71
# Epoch 1351 --> loss:0.2123, acc:92.77%, val_loss:1.2063, val_acc:61.86%
#  Epoch 1352: iteration 70/71
# Epoch 1352 --> loss:0.2609, acc:91.02%, val_loss:1.1912, val_acc:68.04%
#  Epoch 1353: iteration 70/71
# Epoch 1353 --> loss:0.1978, acc:93.25%, val_loss:1.3326, val_acc:54.64%
#  Epoch 1354: iteration 70/71
# Epoch 1354 --> loss:0.2047, acc:93.03%, val_loss:1.0298, val_acc:71.13%
#  Epoch 1355: iteration 70/71
# Epoch 1355 --> loss:0.0996, acc:97.04%, val_loss:0.9925, val_acc:76.29%
#  Epoch 1356: iteration 70/71
# Epoch 1356 --> loss:0.0457, acc:98.39%, val_loss:1.1347, val_acc:68.04%
#  Epoch 1357: iteration 70/71
# Epoch 1357 --> loss:0.0279, acc:98.82%, val_loss:1.0077, val_acc:74.23%
#  Epoch 1358: iteration 70/71
# Epoch 1358 --> loss:0.0148, acc:99.00%, val_loss:1.0573, val_acc:74.23%
#  Epoch 1359: iteration 70/71
# Epoch 1359 --> loss:0.0321, acc:98.47%, val_loss:1.1308, val_acc:71.13%
#  Epoch 1360: iteration 70/71
# Epoch 1360 --> loss:0.0309, acc:98.87%, val_loss:1.0801, val_acc:70.10%
#  Epoch 1361: iteration 70/71
# Epoch 1361 --> loss:0.0161, acc:98.95%, val_loss:1.0884, val_acc:69.07%
#  Epoch 1362: iteration 70/71
# Epoch 1362 --> loss:0.0117, acc:99.00%, val_loss:1.2129, val_acc:68.04%
#  Epoch 1363: iteration 70/71
# Epoch 1363 --> loss:0.0098, acc:99.00%, val_loss:1.1156, val_acc:72.16%
#  Epoch 1364: iteration 70/71
# Epoch 1364 --> loss:0.0089, acc:99.00%, val_loss:1.1061, val_acc:71.13%
#  Epoch 1365: iteration 70/71
# Epoch 1365 --> loss:0.0083, acc:99.00%, val_loss:1.1536, val_acc:72.16%
#  Epoch 1366: iteration 70/71
# Epoch 1366 --> loss:0.0078, acc:99.00%, val_loss:1.1737, val_acc:71.13%
#  Epoch 1367: iteration 70/71
# Epoch 1367 --> loss:0.0077, acc:99.00%, val_loss:1.1864, val_acc:73.20%
#  Epoch 1368: iteration 70/71
# Epoch 1368 --> loss:0.0074, acc:99.00%, val_loss:1.1691, val_acc:72.16%
#  Epoch 1369: iteration 70/71
# Epoch 1369 --> loss:0.0079, acc:99.00%, val_loss:1.1391, val_acc:71.13%
#  Epoch 1370: iteration 70/71
# Epoch 1370 --> loss:0.0071, acc:99.00%, val_loss:1.1799, val_acc:73.20%
#  Epoch 1371: iteration 70/71
# Epoch 1371 --> loss:0.0071, acc:99.00%, val_loss:1.1472, val_acc:71.13%
#  Epoch 1372: iteration 70/71
# Epoch 1372 --> loss:0.0072, acc:99.00%, val_loss:1.1475, val_acc:72.16%
#  Epoch 1373: iteration 70/71
# Epoch 1373 --> loss:0.0068, acc:99.00%, val_loss:1.1659, val_acc:71.13%
#  Epoch 1374: iteration 70/71
# Epoch 1374 --> loss:0.0068, acc:99.00%, val_loss:1.1713, val_acc:71.13%
#  Epoch 1375: iteration 70/71
# Epoch 1375 --> loss:0.0069, acc:99.00%, val_loss:1.1739, val_acc:72.16%
#  Epoch 1376: iteration 70/71
# Epoch 1376 --> loss:0.0071, acc:99.00%, val_loss:1.1797, val_acc:72.16%
#  Epoch 1377: iteration 70/71
# Epoch 1377 --> loss:0.0068, acc:99.00%, val_loss:1.1913, val_acc:71.13%
#  Epoch 1378: iteration 70/71
# Epoch 1378 --> loss:0.0065, acc:99.00%, val_loss:1.1726, val_acc:72.16%
#  Epoch 1379: iteration 70/71
# Epoch 1379 --> loss:0.0066, acc:99.00%, val_loss:1.1892, val_acc:72.16%
#  Epoch 1380: iteration 70/71
# Epoch 1380 --> loss:0.0069, acc:99.00%, val_loss:1.2215, val_acc:69.07%
#  Epoch 1381: iteration 70/71
# Epoch 1381 --> loss:0.0065, acc:99.00%, val_loss:1.2022, val_acc:72.16%
#  Epoch 1382: iteration 70/71
# Epoch 1382 --> loss:0.0070, acc:99.00%, val_loss:1.1917, val_acc:72.16%
#  Epoch 1383: iteration 70/71
# Epoch 1383 --> loss:0.0070, acc:99.00%, val_loss:1.2008, val_acc:71.13%
#  Epoch 1384: iteration 70/71
# Epoch 1384 --> loss:0.0068, acc:99.00%, val_loss:1.2073, val_acc:72.16%
#  Epoch 1385: iteration 70/71
# Epoch 1385 --> loss:0.0070, acc:99.00%, val_loss:1.2222, val_acc:72.16%
#  Epoch 1386: iteration 70/71
# Epoch 1386 --> loss:0.0068, acc:99.00%, val_loss:1.2061, val_acc:70.10%
#  Epoch 1387: iteration 70/71
# Epoch 1387 --> loss:0.0068, acc:99.00%, val_loss:1.2468, val_acc:69.07%
#  Epoch 1388: iteration 70/71
# Epoch 1388 --> loss:0.0067, acc:99.00%, val_loss:1.2414, val_acc:68.04%
#  Epoch 1389: iteration 70/71
# Epoch 1389 --> loss:0.0070, acc:99.00%, val_loss:1.2409, val_acc:71.13%
#  Epoch 1390: iteration 70/71
# Epoch 1390 --> loss:0.0071, acc:99.00%, val_loss:1.2405, val_acc:70.10%
#  Epoch 1391: iteration 70/71
# Epoch 1391 --> loss:0.0071, acc:99.00%, val_loss:1.2528, val_acc:71.13%
#  Epoch 1392: iteration 70/71
# Epoch 1392 --> loss:0.0068, acc:99.00%, val_loss:1.2433, val_acc:71.13%
#  Epoch 1393: iteration 70/71
# Epoch 1393 --> loss:0.0070, acc:99.00%, val_loss:1.2347, val_acc:71.13%
#  Epoch 1394: iteration 70/71
# Epoch 1394 --> loss:0.0069, acc:99.00%, val_loss:1.2440, val_acc:69.07%
#  Epoch 1395: iteration 70/71
# Epoch 1395 --> loss:0.0070, acc:99.00%, val_loss:1.2627, val_acc:70.10%
#  Epoch 1396: iteration 70/71
# Epoch 1396 --> loss:0.0071, acc:99.00%, val_loss:1.2440, val_acc:71.13%
#  Epoch 1397: iteration 70/71
# Epoch 1397 --> loss:0.0092, acc:98.95%, val_loss:1.2256, val_acc:71.13%
#  Epoch 1398: iteration 70/71
# Epoch 1398 --> loss:0.0072, acc:99.00%, val_loss:1.2320, val_acc:71.13%
#  Epoch 1399: iteration 70/71
# Epoch 1399 --> loss:0.0071, acc:99.00%, val_loss:1.2383, val_acc:71.13%
#  Epoch 1400: iteration 70/71
# Epoch 1400 --> loss:0.0072, acc:99.00%, val_loss:1.2351, val_acc:71.13%
#  Epoch 1401: iteration 70/71
# Epoch 1401 --> loss:0.0074, acc:99.00%, val_loss:1.2248, val_acc:70.10%
#  Epoch 1402: iteration 70/71
# Epoch 1402 --> loss:0.0076, acc:99.00%, val_loss:1.2066, val_acc:69.07%
#  Epoch 1403: iteration 70/71
# Epoch 1403 --> loss:0.0072, acc:99.00%, val_loss:1.2093, val_acc:68.04%
#  Epoch 1404: iteration 70/71
# Epoch 1404 --> loss:0.0072, acc:99.00%, val_loss:1.2077, val_acc:68.04%
#  Epoch 1405: iteration 70/71
# Epoch 1405 --> loss:0.0071, acc:99.00%, val_loss:1.2463, val_acc:68.04%
#  Epoch 1406: iteration 70/71
# Epoch 1406 --> loss:0.0070, acc:99.00%, val_loss:1.2587, val_acc:68.04%
#  Epoch 1407: iteration 70/71
# Epoch 1407 --> loss:0.0073, acc:99.00%, val_loss:1.2791, val_acc:68.04%
#  Epoch 1408: iteration 70/71
# Epoch 1408 --> loss:0.0074, acc:99.00%, val_loss:1.2496, val_acc:69.07%
#  Epoch 1409: iteration 70/71
# Epoch 1409 --> loss:0.0074, acc:99.00%, val_loss:1.2674, val_acc:69.07%
#  Epoch 1410: iteration 70/71
# Epoch 1410 --> loss:0.0075, acc:99.00%, val_loss:1.2940, val_acc:68.04%
#  Epoch 1411: iteration 70/71
# Epoch 1411 --> loss:0.0079, acc:99.00%, val_loss:1.2894, val_acc:69.07%
#  Epoch 1412: iteration 70/71
# Epoch 1412 --> loss:0.0077, acc:99.00%, val_loss:1.2892, val_acc:68.04%
#  Epoch 1413: iteration 70/71
# Epoch 1413 --> loss:0.0073, acc:99.00%, val_loss:1.2854, val_acc:69.07%
#  Epoch 1414: iteration 70/71
# Epoch 1414 --> loss:0.0080, acc:99.00%, val_loss:1.3163, val_acc:67.01%
#  Epoch 1415: iteration 70/71
# Epoch 1415 --> loss:0.0075, acc:99.00%, val_loss:1.3088, val_acc:69.07%
#  Epoch 1416: iteration 70/71
# Epoch 1416 --> loss:0.0075, acc:99.00%, val_loss:1.2857, val_acc:70.10%
#  Epoch 1417: iteration 70/71
# Epoch 1417 --> loss:0.0076, acc:99.00%, val_loss:1.3149, val_acc:68.04%
#  Epoch 1418: iteration 70/71
# Epoch 1418 --> loss:0.0078, acc:99.00%, val_loss:1.3353, val_acc:67.01%
#  Epoch 1419: iteration 70/71
# Epoch 1419 --> loss:0.0072, acc:99.00%, val_loss:1.3209, val_acc:68.04%
#  Epoch 1420: iteration 70/71
# Epoch 1420 --> loss:0.0076, acc:99.00%, val_loss:1.3853, val_acc:67.01%
#  Epoch 1421: iteration 70/71
# Epoch 1421 --> loss:0.0074, acc:99.00%, val_loss:1.3291, val_acc:68.04%
#  Epoch 1422: iteration 70/71
# Epoch 1422 --> loss:0.0078, acc:99.00%, val_loss:1.3133, val_acc:68.04%
#  Epoch 1423: iteration 70/71
# Epoch 1423 --> loss:0.0076, acc:99.00%, val_loss:1.3325, val_acc:67.01%
#  Epoch 1424: iteration 70/71
# Epoch 1424 --> loss:0.0075, acc:99.00%, val_loss:1.3044, val_acc:68.04%
#  Epoch 1425: iteration 70/71
# Epoch 1425 --> loss:0.0078, acc:99.00%, val_loss:1.3619, val_acc:68.04%
#  Epoch 1426: iteration 70/71
# Epoch 1426 --> loss:0.0080, acc:99.00%, val_loss:1.3350, val_acc:65.98%
#  Epoch 1427: iteration 70/71
# Epoch 1427 --> loss:0.0079, acc:99.00%, val_loss:1.3571, val_acc:68.04%
#  Epoch 1428: iteration 70/71
# Epoch 1428 --> loss:0.0075, acc:99.00%, val_loss:1.3516, val_acc:68.04%
#  Epoch 1429: iteration 70/71
# Epoch 1429 --> loss:0.0078, acc:99.00%, val_loss:1.3825, val_acc:67.01%
#  Epoch 1430: iteration 70/71
# Epoch 1430 --> loss:0.0078, acc:99.00%, val_loss:1.3947, val_acc:65.98%
#  Epoch 1431: iteration 70/71
# Epoch 1431 --> loss:0.0081, acc:99.00%, val_loss:1.4139, val_acc:67.01%
#  Epoch 1432: iteration 70/71
# Epoch 1432 --> loss:0.0082, acc:99.00%, val_loss:1.4097, val_acc:67.01%
#  Epoch 1433: iteration 70/71
# Epoch 1433 --> loss:0.0078, acc:99.00%, val_loss:1.4188, val_acc:65.98%
#  Epoch 1434: iteration 70/71
# Epoch 1434 --> loss:0.0082, acc:99.00%, val_loss:1.4189, val_acc:67.01%
#  Epoch 1435: iteration 70/71
# Epoch 1435 --> loss:0.0078, acc:99.00%, val_loss:1.3871, val_acc:67.01%
#  Epoch 1436: iteration 70/71
# Epoch 1436 --> loss:0.0078, acc:99.00%, val_loss:1.4081, val_acc:67.01%
#  Epoch 1437: iteration 70/71
# Epoch 1437 --> loss:0.0081, acc:99.00%, val_loss:1.4197, val_acc:67.01%
#  Epoch 1438: iteration 70/71
# Epoch 1438 --> loss:0.0079, acc:99.00%, val_loss:1.4080, val_acc:68.04%
#  Epoch 1439: iteration 70/71
# Epoch 1439 --> loss:0.0085, acc:99.00%, val_loss:1.5102, val_acc:63.92%
#  Epoch 1440: iteration 70/71
# Epoch 1440 --> loss:0.0076, acc:99.00%, val_loss:1.4272, val_acc:64.95%
#  Epoch 1441: iteration 70/71
# Epoch 1441 --> loss:0.0077, acc:99.00%, val_loss:1.3766, val_acc:68.04%
#  Epoch 1442: iteration 70/71
# Epoch 1442 --> loss:0.0080, acc:99.00%, val_loss:1.4323, val_acc:68.04%
#  Epoch 1443: iteration 70/71
# Epoch 1443 --> loss:0.0081, acc:99.00%, val_loss:1.4460, val_acc:67.01%
#  Epoch 1444: iteration 70/71
# Epoch 1444 --> loss:0.0079, acc:99.00%, val_loss:1.4412, val_acc:65.98%
#  Epoch 1445: iteration 70/71
# Epoch 1445 --> loss:0.0077, acc:99.00%, val_loss:1.3874, val_acc:65.98%
#  Epoch 1446: iteration 70/71
# Epoch 1446 --> loss:0.0080, acc:99.00%, val_loss:1.4703, val_acc:64.95%
#  Epoch 1447: iteration 70/71
# Epoch 1447 --> loss:0.0078, acc:99.00%, val_loss:1.5103, val_acc:64.95%
#  Epoch 1448: iteration 70/71
# Epoch 1448 --> loss:0.0080, acc:99.00%, val_loss:1.5298, val_acc:62.89%
#  Epoch 1449: iteration 70/71
# Epoch 1449 --> loss:0.0082, acc:99.00%, val_loss:1.3886, val_acc:65.98%
#  Epoch 1450: iteration 70/71
# Epoch 1450 --> loss:0.0079, acc:99.00%, val_loss:1.4053, val_acc:68.04%
#  Epoch 1451: iteration 70/71
# Epoch 1451 --> loss:0.0081, acc:99.00%, val_loss:1.4635, val_acc:64.95%
#  Epoch 1452: iteration 70/71
# Epoch 1452 --> loss:0.0080, acc:99.00%, val_loss:1.4135, val_acc:64.95%
#  Epoch 1453: iteration 70/71
# Epoch 1453 --> loss:0.0080, acc:99.00%, val_loss:1.4680, val_acc:65.98%
#  Epoch 1454: iteration 70/71
# Epoch 1454 --> loss:0.0078, acc:99.00%, val_loss:1.3799, val_acc:68.04%
#  Epoch 1455: iteration 70/71
# Epoch 1455 --> loss:0.3506, acc:88.89%, val_loss:1.8511, val_acc:35.05%
#  Epoch 1456: iteration 70/71
# Epoch 1456 --> loss:1.0374, acc:63.49%, val_loss:1.2449, val_acc:63.92%
#  Epoch 1457: iteration 70/71
# Epoch 1457 --> loss:0.6058, acc:80.04%, val_loss:1.2053, val_acc:62.89%
#  Epoch 1458: iteration 70/71
# Epoch 1458 --> loss:0.4991, acc:83.31%, val_loss:1.1038, val_acc:71.13%
#  Epoch 1459: iteration 70/71
# Epoch 1459 --> loss:0.4137, acc:86.45%, val_loss:1.2079, val_acc:70.10%
#  Epoch 1460: iteration 70/71
# Epoch 1460 --> loss:0.3768, acc:86.67%, val_loss:1.3237, val_acc:59.79%
#  Epoch 1461: iteration 70/71
# Epoch 1461 --> loss:0.3828, acc:86.71%, val_loss:1.2404, val_acc:63.92%
#  Epoch 1462: iteration 70/71
# Epoch 1462 --> loss:0.2626, acc:91.37%, val_loss:1.1591, val_acc:65.98%
#  Epoch 1463: iteration 70/71
# Epoch 1463 --> loss:0.1576, acc:95.25%, val_loss:1.2820, val_acc:64.95%
#  Epoch 1464: iteration 70/71
# Epoch 1464 --> loss:0.1714, acc:94.42%, val_loss:1.2631, val_acc:64.95%
#  Epoch 1465: iteration 70/71
# Epoch 1465 --> loss:0.1958, acc:93.86%, val_loss:1.2208, val_acc:69.07%
#  Epoch 1466: iteration 70/71
# Epoch 1466 --> loss:0.1500, acc:95.16%, val_loss:1.1329, val_acc:67.01%
#  Epoch 1467: iteration 70/71
# Epoch 1467 --> loss:0.1450, acc:95.21%, val_loss:1.6161, val_acc:59.79%
#  Epoch 1468: iteration 70/71
# Epoch 1468 --> loss:0.1419, acc:95.47%, val_loss:1.3166, val_acc:62.89%
#  Epoch 1469: iteration 70/71
# Epoch 1469 --> loss:0.1503, acc:94.90%, val_loss:1.0671, val_acc:71.13%
#  Epoch 1470: iteration 70/71
# Epoch 1470 --> loss:0.0412, acc:98.56%, val_loss:0.9829, val_acc:72.16%
#  Epoch 1471: iteration 70/71
# Epoch 1471 --> loss:0.0227, acc:98.87%, val_loss:1.0870, val_acc:72.16%
#  Epoch 1472: iteration 70/71
# Epoch 1472 --> loss:0.0148, acc:99.00%, val_loss:1.0911, val_acc:73.20%
#  Epoch 1473: iteration 70/71
# Epoch 1473 --> loss:0.0117, acc:99.00%, val_loss:1.0968, val_acc:72.16%
#  Epoch 1474: iteration 70/71
# Epoch 1474 --> loss:0.0107, acc:99.00%, val_loss:1.1433, val_acc:72.16%
#  Epoch 1475: iteration 70/71
# Epoch 1475 --> loss:0.0096, acc:99.00%, val_loss:1.1966, val_acc:72.16%
#  Epoch 1476: iteration 70/71
# Epoch 1476 --> loss:0.0094, acc:99.00%, val_loss:1.1923, val_acc:72.16%
#  Epoch 1477: iteration 70/71
# Epoch 1477 --> loss:0.0083, acc:99.00%, val_loss:1.1686, val_acc:72.16%
#  Epoch 1478: iteration 70/71
# Epoch 1478 --> loss:0.0081, acc:99.00%, val_loss:1.2000, val_acc:71.13%
#  Epoch 1479: iteration 70/71
# Epoch 1479 --> loss:0.0076, acc:99.00%, val_loss:1.2018, val_acc:73.20%
#  Epoch 1480: iteration 70/71
# Epoch 1480 --> loss:0.0073, acc:99.00%, val_loss:1.2185, val_acc:72.16%
#  Epoch 1481: iteration 70/71
# Epoch 1481 --> loss:0.0075, acc:99.00%, val_loss:1.1874, val_acc:73.20%
#  Epoch 1482: iteration 70/71
# Epoch 1482 --> loss:0.0071, acc:99.00%, val_loss:1.2257, val_acc:72.16%
#  Epoch 1483: iteration 70/71
# Epoch 1483 --> loss:0.0072, acc:99.00%, val_loss:1.2344, val_acc:72.16%
#  Epoch 1484: iteration 70/71
# Epoch 1484 --> loss:0.0067, acc:99.00%, val_loss:1.2419, val_acc:73.20%
#  Epoch 1485: iteration 70/71
# Epoch 1485 --> loss:0.0074, acc:99.00%, val_loss:1.2695, val_acc:71.13%
#  Epoch 1486: iteration 70/71
# Epoch 1486 --> loss:0.0069, acc:99.00%, val_loss:1.2446, val_acc:73.20%
#  Epoch 1487: iteration 70/71
# Epoch 1487 --> loss:0.0074, acc:99.00%, val_loss:1.2314, val_acc:73.20%
#  Epoch 1488: iteration 70/71
# Epoch 1488 --> loss:0.0069, acc:99.00%, val_loss:1.3109, val_acc:70.10%
#  Epoch 1489: iteration 70/71
# Epoch 1489 --> loss:0.0068, acc:99.00%, val_loss:1.2881, val_acc:72.16%
#  Epoch 1490: iteration 70/71
# Epoch 1490 --> loss:0.0070, acc:99.00%, val_loss:1.2790, val_acc:72.16%
#  Epoch 1491: iteration 70/71
# Epoch 1491 --> loss:0.0068, acc:99.00%, val_loss:1.2825, val_acc:71.13%
#  Epoch 1492: iteration 70/71
# Epoch 1492 --> loss:0.0070, acc:99.00%, val_loss:1.2889, val_acc:72.16%
#  Epoch 1493: iteration 70/71
# Epoch 1493 --> loss:0.0067, acc:99.00%, val_loss:1.2948, val_acc:72.16%
#  Epoch 1494: iteration 70/71
# Epoch 1494 --> loss:0.0066, acc:99.00%, val_loss:1.2927, val_acc:71.13%
#  Epoch 1495: iteration 70/71
# Epoch 1495 --> loss:0.0064, acc:99.00%, val_loss:1.2960, val_acc:72.16%
#  Epoch 1496: iteration 70/71
# Epoch 1496 --> loss:0.0065, acc:99.00%, val_loss:1.3110, val_acc:72.16%
#  Epoch 1497: iteration 70/71
# Epoch 1497 --> loss:0.0074, acc:99.00%, val_loss:1.3226, val_acc:72.16%
#  Epoch 1498: iteration 70/71
# Epoch 1498 --> loss:0.0066, acc:99.00%, val_loss:1.3186, val_acc:72.16%
#  Epoch 1499: iteration 70/71
# Epoch 1499 --> loss:0.0065, acc:99.00%, val_loss:1.3155, val_acc:72.16%

# %%
SAVE_PATH = os.path.join(os.getcwd(),'models')
os.makedirs('models',exist_ok=True)
torch.save(model.state_dict(),os.path.join(SAVE_PATH,'cnn_lstm_parallel_modellast.pt'))
print('Model is saved to {}'.format(os.path.join(SAVE_PATH,'cnn_lstm_parallel_modellast.pt')))
# Out:
# Model is saved to /notebooks/models/cnn_lstm_parallel_modellast.pt

# %%
LOAD_PATH = os.path.join(os.getcwd(),'models')
model = ParallelModel(len(EMOTIONS))
model.load_state_dict(torch.load(os.path.join(LOAD_PATH,'cnn_lstm_parallel_modellast.pt')))
print('Model is loaded from {}'.format(os.path.join(LOAD_PATH,'cnn_lstm_parallel_modellast.pt')))
# Out:
# Model is loaded from /notebooks/models/cnn_lstm_parallel_modellast.pt

# %%
X_test_tensor = torch.tensor(X_test,device=device).float()
Y_test_tensor = torch.tensor(Y_test,dtype=torch.long,device=device)
test_loss, test_acc, predictions = validate(X_test_tensor,Y_test_tensor)
print(f'Test loss is {test_loss:.3f}')
print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test loss is 1.535
# Test accuracy is 64.29%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

predictions = predictions.cpu().numpy()
cm = confusion_matrix(Y_test, predictions)
names = [EMOTIONS[ind] for ind in range(len(EMOTIONS))]
df_cm = pd.DataFrame(cm, index=names, columns=names)
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %%
correct_strong = 0
correct_normal = 0
wrong_strong = 0
wrong_normal = 0
for i in range(len(X_test)):
    intensity = data.loc[test_ind[i],'Emotion intensity']
    if Y_test[i] == predictions[i]: # correct prediction
        if  intensity == 'normal':
            correct_normal += 1
        else:
            correct_strong += 1
    else: # wrong prediction
        if intensity == 'normal':
            wrong_normal += 1
        else:
            wrong_strong += 1
array = np.array([[wrong_normal,wrong_strong],[correct_normal,correct_strong]])
df = pd.DataFrame(array,['wrong','correct'],['normal','strong'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %%
correct_male = 0
correct_female = 0
wrong_male = 0
wrong_female = 0
for i in range(len(X_test)):
    gender = data.loc[test_ind[i],'Gender']
    if Y_test[i] == predictions[i]: # correct prediction
        if  gender == 'male':
            correct_male += 1
        else:
            correct_female += 1
    else: # wrong prediction
        if gender == 'male':
            wrong_male += 1
        else:
            wrong_female += 1
array = np.array([[wrong_male,wrong_female],[correct_male,correct_female]])
df = pd.DataFrame(array,['wrong','correct'],['male','female'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %%
plt.plot(losses,'b')
plt.plot(val_losses,'r')
plt.legend(['train loss','val loss'])
