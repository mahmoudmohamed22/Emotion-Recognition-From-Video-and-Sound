# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, glob
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import warnings; warnings.filterwarnings('ignore') #matplot lib complains about librosa

# %%
# RAVDESS native sample rate is 48k
sample_rate = 48000

# Mel Spectrograms are not directly used as a feature in this model
# Mel Spectrograms are used in calculating MFCCs, which are a higher-level representation of pitch transition
# MFCCs work better - left the mel spectrogram function here in case anyone wants to experiment
def feature_melspectrogram(
    waveform, 
    sample_rate,
    fft = 1024,
    winlen = 512,
    window='hamming',
    hop=256,
    mels=128,
    ):
    
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram = librosa.feature.melspectrogram(
        y=waveform, 
        sr=sample_rate, 
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2)
    
    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms 
    melspectrogram = librosa.power_to_db(melspectrogram, ref=np.max)
    
    return melspectrogram

def feature_mfcc(
    waveform, 
    sample_rate,
    n_mfcc = 40,
    fft = 1024,
    winlen = 512,
    window='hamming',
    #hop=256, # increases # of time steps; was not helpful
    mels=128
    ):

    # Compute the MFCCs for all STFT frames 
    # 40 mel filterbanks (n_mfcc) = 40 coefficients
    mfc_coefficients=librosa.feature.mfcc(
        y=waveform, 
        sr=sample_rate, 
        n_mfcc=n_mfcc,
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        #hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2
        ) 

    return mfc_coefficients

def get_features(waveforms, features, samplerate):

    # initialize counter to track progress
    file_count = 0

    # process each waveform individually to get its MFCCs
    for waveform in waveforms:
        mfccs = feature_mfcc(waveform, sample_rate)
        features.append(mfccs)
        file_count += 1
        # print progress 
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')
    
    # return all features from list of waveforms
    return features

def get_waveforms(file):
    
    # load an individual sample audio file
    # read the full 3 seconds of the file, cut off the first 0.5s of silence; native sample rate = 48k
    # don't need to store the sample rate that librosa.load returns
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)
    
    # make sure waveform vectors are homogenous by defining explicitly
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform
    
    # return a single file's waveform                                      
    return waveform_homo
    
# RAVDESS dataset emotions
# shift emotions left to be 0 indexed for PyTorch
emotions_dict ={
    '0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
  # '7':'disgust'
}

# Additional attributes from RAVDESS to play with
emotion_attributes = {
    '01': 'normal',
    '02': 'strong'
}

# %%
# path to data for glob
data_path = 'data'

##'RAVDESS dataset/Actor_*/*.wav'
dir_list = os.listdir(data_path)
dir_list.sort()
dir_list
# Out:
# ['.ipynb_checkpoints',
#  'Actor_01',
#  'Actor_02',
#  'Actor_03',
#  'Actor_04',
#  'Actor_05',
#  'Actor_06',
#  'Actor_07',
#  'Actor_08',
#  'Actor_09',
#  'Actor_10',
#  'Actor_11',
#  'Actor_12',
#  'Actor_13',
#  'Actor_14',
#  'Actor_15',
#  'Actor_16',
#  'Actor_17',
#  'Actor_18',
#  'Actor_19',
#  'Actor_20',
#  'Actor_21',
#  'Actor_22',
#  'Actor_23',
#  'Actor_24']

# %%
def load_data():
  # features and labels
  emotions = []
  # raw waveforms to augment later
  waveforms = []
  # extra labels
  intensities, genders = [],[]
  # progress counter
  file_count = 0
  for i in dir_list:
    #print(i)
    file_name = os.listdir(data_path + '/' +i+'/')
    for file in file_name:
     # print(file)
      #print(file_name)
      file=data_path + '/' +i+'/'+file
      nm = file.split('.')[0].split('-')
      # get emotion label from the sample's file
      emotion = int(nm[2])
      #  move surprise to 0 for cleaner behaviour with PyTorch/0-indexing
      if emotion == 8: emotion = 0 # surprise is now at 0 index; other emotion indeces unchanged

      # can convert emotion label to emotion string if desired, but
      # training on number is better; better convert to emotion string after predictions are ready
      # emotion = emotions_dict[str(emotion)]
            
      # get other labels we might want
      #intensity = emotion_attributes[int(nm[3])]
      if nm[3] == '01':
            intensity = 0
      else:
            intensity = 1
      # even actors are female, odd are male
      if (int((file.split("-")[6]).split(".")[0]))%2==0: 
          gender = 'female' 
      else: 
          gender = 'male'
                
      # get waveform from the sample
      waveform = get_waveforms(file)
            
      # store waveforms and labels
      waveforms.append(waveform)
      emotions.append(emotion)
      intensities.append(intensity) # store intensity in case we wish to predict
      genders.append(gender) # store gender in case we wish to predict 
            
      file_count += 1
      # keep track of data loader's progress
      print('\r'+f' Processed {file_count}/{1440} audio samples',end='')

  return waveforms, emotions, intensities, genders
      #****************************#

# %%
# load data 
# init explicitly to prevent data leakage from past sessions, since load_data() appends
waveforms, emotions, intensities, genders = [],[],[],[]
waveforms, emotions, intensities, genders = load_data()
# Out:
#  Processed 2452/1440 audio samples

# %%
print(f'Waveforms set: {len(waveforms)} samples')
# we have 1440 waveforms but we need to know their length too; should be 3 sec * 48k = 144k
print(f'Waveform signal length: {len(waveforms[0])}')
print(f'Emotions set: {len(emotions)} sample labels')
# Out:
# Waveforms set: 2452 samples
# Waveform signal length: 144000
# Emotions set: 2452 sample labels

# %%
# create storage for train, validation, test sets and their indices
train_set,valid_set,test_set = [],[],[]
X_train,X_valid,X_test = [],[],[]
y_train,y_valid,y_test = [],[],[]

# convert waveforms to array for processing
waveforms = np.array(waveforms)

# process each emotion separately to make sure we builf balanced train/valid/test sets 
for emotion_num in range(len(emotions_dict)):
        
    # find all indices of a single unique emotion
    emotion_indices = [index for index, emotion in enumerate(emotions) if emotion==emotion_num]

    # seed for reproducibility 
    np.random.seed(69)
    # shuffle indicies 
    emotion_indices = np.random.permutation(emotion_indices)

    # store dim (length) of the emotion list to make indices
    dim = len(emotion_indices)

    # store indices of training, validation and test sets in 80/10/10 proportion
    # train set is first 80%
    train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
    valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
    test_indices = emotion_indices[int(0.9*dim):]

    # create train waveforms/labels sets
    X_train.append(waveforms[train_indices,:])
    y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
    X_valid.append(waveforms[valid_indices,:])
    y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
    X_test.append(waveforms[test_indices,:])
    y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets 
    train_set.append(train_indices)
    valid_set.append(valid_indices)
    test_set.append(test_indices)

# concatenate, in order, all waveforms back into one array 
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array 
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

# make sure train, validation, test sets have no overlap/are unique
# get all unique indices across all sets and how many times each index appears (count)
uniques, count = np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)

# if each index appears just once, and we have 1440 such unique indices, then all sets are unique
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# Training waveforms:(1803, 144000), y_train:(1803,)
# Validation waveforms:(228, 144000), y_valid:(228,)
# Test waveforms:(229, 144000), y_test:(229,)
#
# Sets are NOT unique: 2260 samples out of 2452 are unique

# %%
# initialize feature arrays
# We extract MFCC features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features 
features_train = get_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = get_features(X_valid, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features 
features_test = get_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'Features (MFC coefficient matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
#  Processed 1803/1803 waveforms
#
# Validation waveforms:
#  Processed 228/228 waveforms
#
# Test waveforms:
#  Processed 229/229 waveforms
#
# Features set: 2260 total, 1803 train, 228 validation, 229 test samples
# Features (MFC coefficient matrix) shape: 40 mel frequency coefficients x 282 time steps

# %%
def awgn_augmentation(waveform, multiples=2, bits=16, snr_min=15, snr_max=30): 
    
    # get length of waveform (should be 3*48k = 144k)
    wave_len = len(waveform)
    
    # Generate normally distributed (Gaussian) noises
    # one for each waveform and multiple (i.e. wave_len*multiples noises)
    noise = np.random.normal(size=(multiples, wave_len))
    
    # Normalize waveform and noise
    norm_constant = 2.0**(bits-1)
    norm_wave = waveform / norm_constant
    norm_noise = noise / norm_constant
    
    # Compute power of waveform and power of noise
    signal_power = np.sum(norm_wave ** 2) / wave_len
    noise_power = np.sum(norm_noise ** 2, axis=1) / wave_len
    
    # Choose random SNR in decibels in range [15,30]
    snr = np.random.randint(snr_min, snr_max)
    
    # Apply whitening transformation: make the Gaussian noise into Gaussian white noise
    # Compute the covariance matrix used to whiten each noise 
    # actual SNR = signal/noise (power)
    # actual noise power = 10**(-snr/10)
    covariance = np.sqrt((signal_power / noise_power) * 10 ** (- snr / 10))
    # Get covariance matrix with dim: (144000, 2) so we can transform 2 noises: dim (2, 144000)
    covariance = np.ones((wave_len, multiples)) * covariance

    # Since covariance and noise are arrays, * is the haddamard product 
    # Take Haddamard product of covariance and noise to generate white noise
    multiple_augmented_waveforms = waveform + covariance.T * noise
    
    return multiple_augmented_waveforms
def augment_waveforms(waveforms, features, emotions, multiples):
    # keep track of how many waveforms we've processed so we can add correct emotion label in the same order
    emotion_count = 0
    # keep track of how many augmented samples we've added
    added_count = 0
    # convert emotion array to list for more efficient appending
    emotions = emotions.tolist()

    for waveform in waveforms:

        # Generate 2 augmented multiples of the dataset, i.e. 1440 native + 1440*2 noisy = 4320 samples total
        augmented_waveforms = awgn_augmentation(waveform, multiples=multiples)

        # compute spectrogram for each of 2 augmented waveforms
        for augmented_waveform in augmented_waveforms:

            # Compute MFCCs over augmented waveforms
            augmented_mfcc = feature_mfcc(augmented_waveform, sample_rate=sample_rate)

            # append the augmented spectrogram to the rest of the native data
            features.append(augmented_mfcc)
            emotions.append(emotions[emotion_count])

            # keep track of new augmented samples
            added_count += 1

            # check progress
            print('\r'+f'Processed {emotion_count + 1}/{len(waveforms)} waveforms for {added_count}/{len(waveforms)*multiples} new augmented samples',end='')

        # keep track of the emotion labels to append in order
        emotion_count += 1
        
        # store augmented waveforms to check their shape
        augmented_waveforms_temp.append(augmented_waveforms)
    
    return features, emotions

# %%
# store augmented waveforms to verify their shape and random-ness
#augmented_waveforms_temp = []

# specify multiples of our dataset to add as augmented data
#multiples = 2

#print('Train waveforms:') # augment waveforms of training set
#features_train , y_train = augment_waveforms(X_train, features_train, y_train, multiples)

#print('\n\nValidation waveforms:') # augment waveforms of validation set
#features_valid, y_valid = augment_waveforms(X_valid, features_valid, y_valid, multiples)

#print('\n\nTest waveforms:') # augment waveforms of test set 
#features_test, y_test = augment_waveforms(X_test, features_test, y_test, multiples)


# Check new shape of extracted features and data:
#print(f'\n\nNative + Augmented Features set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
#print(f'{len(y_train)} training sample labels, {len(y_valid)} validation sample labels, {len(y_test)} test sample labels')
#print(f'Features (MFCC matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')

# %%
'''# pick a random waveform, but same one from native and augmented set for easier comparison
plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveplot(waveforms[12], sr=sample_rate)
plt.title('Native')

plt.subplot(1, 2, 2)
# augmented waveforms are 2D len 1440 list with 2 waveforms in each position
librosa.display.waveplot(augmented_waveforms_temp[0][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveplot(augmented_waveforms_temp[2][0], sr=sample_rate)
plt.title('AWGN Augmented')

plt.subplot(1, 2, 2)
librosa.display.waveplot(augmented_waveforms_temp[7][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()'''
# Out:
# "# pick a random waveform, but same one from native and augmented set for easier comparison\nplt.figure(figsize=(15,4))\nplt.subplot(1, 2, 1)\nlibrosa.display.waveplot(waveforms[12], sr=sample_rate)\nplt.title('Native')\n\nplt.subplot(1, 2, 2)\n# augmented waveforms are 2D len 1440 list with 2 waveforms in each position\nlibrosa.display.waveplot(augmented_waveforms_temp[0][0], sr=sample_rate)\nplt.title('AWGN Augmented')\nplt.show()\n\nplt.figure(figsize=(15,4))\nplt.subplot(1, 2, 1)\nlibrosa.display.waveplot(augmented_waveforms_temp[2][0], sr=sample_rate)\nplt.title('AWGN Augmented')\n\nplt.subplot(1, 2, 2)\nlibrosa.display.waveplot(augmented_waveforms_temp[7][0], sr=sample_rate)\nplt.title('AWGN Augmented')\nplt.show()"

# %%
# need to make dummy input channel for CNN input feature tensor
X_train = np.expand_dims(features_train,1)
X_valid = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test,1)

# convert emotion labels from list back to numpy arrays for PyTorch to work with 
y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)

# confiorm that we have tensor-ready 4D data array
# should print (batch, channel, width, height) == (4320, 1, 128, 282) when multiples==2
print(f'Shape of 4D feature array for input tensor: {X_train.shape} train, {X_valid.shape} validation, {X_test.shape} test')
print(f'Shape of emotion labels: {y_train.shape} train, {y_valid.shape} validation, {y_test.shape} test')
# Out:
# Shape of 4D feature array for input tensor: (1803, 1, 40, 282) train, (228, 1, 40, 282) validation, (229, 1, 40, 282) test
# Shape of emotion labels: (1803,) train, (228,) validation, (229,) test

# %%
# free up some RAM - no longer need full feature set or any waveforms 
#del features_train, features_valid, features_test, waveforms, augmented_waveforms_temp

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#### Scale the training data ####
# store shape so we can transform it back 
N,C,H,W = X_train.shape
# Reshape to 1D because StandardScaler operates on a 1D array
# tell numpy to infer shape of 1D array with '-1' argument
X_train = np.reshape(X_train, (N,-1)) 
X_train = scaler.fit_transform(X_train)
# Transform back to NxCxHxW 4D tensor format
X_train = np.reshape(X_train, (N,C,H,W))

##### Scale the validation set ####
N,C,H,W = X_valid.shape
X_valid = np.reshape(X_valid, (N,-1))
X_valid = scaler.transform(X_valid)
X_valid = np.reshape(X_valid, (N,C,H,W))

#### Scale the test set ####
N,C,H,W = X_test.shape
X_test = np.reshape(X_test, (N,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, (N,C,H,W))

# check shape of each set again
print(f'X_train scaled:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid scaled:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test scaled:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train scaled:(1803, 1, 40, 282), y_train:(1803,)
# X_valid scaled:(228, 1, 40, 282), y_valid:(228,)
# X_test scaled:(229, 1, 40, 282), y_test:(229,)

# %%
###### SAVE #########
# choose save file name 
filename = 'features+labels.npy'

# open file in write mode and write data
with open(filename, 'wb') as f:
    np.save(f, X_train)
    np.save(f, X_valid)
    np.save(f, X_test)
    np.save(f, y_train)
    np.save(f, y_valid)
    np.save(f, y_test)

print(f'Features and labels saved to {filename}')
# Out:
# Features and labels saved to features+labels.npy

# %%
##### LOAD #########
# choose load file name 
filename = 'features+labels.npy'

# open file in read mode and read data 
with open(filename, 'rb') as f:
    X_train = np.load(f)
    X_valid = np.load(f)
    X_test = np.load(f)
    y_train = np.load(f)
    y_valid = np.load(f)
    y_test = np.load(f)

# Check that we've recovered the right data
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train:(1803, 1, 40, 282), y_train:(1803,)
# X_valid:(228, 1, 40, 282), y_valid:(228,)
# X_test:(229, 1, 40, 282), y_test:(229,)

# %%
#change nn.sequential to take dict to make more readable 

class parallel_all_you_want(nn.Module):
    # Define all layers present in the network
    def __init__(self,num_emotions):
        super().__init__() 
        
        ################ TRANSFORMER BLOCK #############################
        # maxpool the input feature map/tensor to the transformer 
        # a rectangular kernel worked better here for the rectangular input spectrogram feature map/tensor
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1,4], stride=[1,4])
        
        # define single transformer encoder layer
        # self-attention + feedforward network from "Attention is All You Need" paper
        # 4 multi-head self-attention layers each with 40-->512--->40 feedforward network
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40, # input feature (frequency) dim after maxpooling 40*282 -> 40*70 (MFC*time)
            nhead=4, # 4 self-attention layers in each multi-head self-attention layer in each encoder block
            dim_feedforward=512, # 2 linear layers in each encoder block's feedforward network: dim 40-->512--->40
            dropout=0.4, 
            activation='relu' # ReLU: avoid saturation/tame gradient/reduce compute time
        )
        
        # I'm using 4 instead of the 6 identical stacked encoder layrs used in Attention is All You Need paper
        # Complete transformer block contains 4 full transformer encoder layers (each w/ multihead self-attention+feedforward)
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=4)
        
        ############### 1ST PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock1 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        ############### 2ND PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock2 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )

        ################# FINAL LINEAR BLOCK ####################
        # Linear softmax layer to take final concatenated embedding tensor 
        #    from parallel 2D convolutional and transformer blocks, output 8 logits 
        # Each full convolution block outputs (64*1*8) embedding flattened to dim 512 1D array 
        # Full transformer block outputs 40*70 feature map, which we time-avg to dim 40 1D array
        # 512*2+40 == 1064 input features --> 8 output emotions 
        self.fc1_linear = nn.Linear(512*2+40,num_emotions) 
        
        ### Softmax layer for the 8 output logits from final FC linear layer 
        self.softmax_out = nn.Softmax(dim=1) # dim==1 is the freq embedding
        
    # define one complete parallel fwd pass of input feature tensor thru 2*conv+1*transformer blocks
    def forward(self,x):
        
        ############ 1st parallel Conv2D block: 4 Convolutional layers ############################
        # create final feature embedding from 1st convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding1 = self.conv2Dblock1(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding1 = torch.flatten(conv2d_embedding1, start_dim=1) 
        
        ############ 2nd parallel Conv2D block: 4 Convolutional layers #############################
        # create final feature embedding from 2nd convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding2 = self.conv2Dblock2(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding2 = torch.flatten(conv2d_embedding2, start_dim=1) 
        
         
        ########## 4-encoder-layer Transformer block w/ 40-->512-->40 feedfwd network ##############
        # maxpool input feature map: 1*40*282 w/ 1*4 kernel --> 1*40*70
        x_maxpool = self.transformer_maxpool(x)

        # remove channel dim: 1*40*70 --> 40*70
        x_maxpool_reduced = torch.squeeze(x_maxpool,1)
        
        # convert maxpooled feature map format: batch * freq * time ---> time * batch * freq format
        # because transformer encoder layer requires tensor in format: time * batch * embedding (freq)
        x = x_maxpool_reduced.permute(2,0,1) 
        
        # finally, pass reduced input feature map x into transformer encoder layers
        transformer_output = self.transformer_encoder(x)
        
        # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
        # transformer outputs 2x40 (MFCC embedding*time) feature map, take mean of columns i.e. take time average
        transformer_embedding = torch.mean(transformer_output, dim=0) # dim 40x70 --> 40
        
        ############# concatenate freq embeddings from convolutional and transformer blocks ######
        # concatenate embedding tensors output by parallel 2*conv and 1*transformer blocks
        complete_embedding = torch.cat([conv2d_embedding1, conv2d_embedding2,transformer_embedding], dim=1)  

        ######### final FC linear layer, need logits for loss #########################
        output_logits = self.fc1_linear(complete_embedding)  
        
        ######### Final Softmax layer: use logits from FC linear, get softmax for prediction ######
        output_softmax = self.softmax_out(output_logits)
        
        # need output logits to compute cross entropy loss, need softmax probabilities to predict class
        return output_logits, output_softmax

# %%
from torchsummary import summary

# need device to instantiate model
device = 'cuda'

# instantiate model for 8 emotions and move to GPU 
model = parallel_all_you_want(len(emotions_dict)).to(device)

# include input feature map dims in call to summary()
#summary(model, input_size=(1,40,282))

# %%
# define loss function; CrossEntropyLoss() fairly standard for multiclass problems 
def criterion(predictions, targets): 
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# %%
# define function to create a single step of the training phase
def make_train_step(model, criterion, optimizer):
    
    # define the training step of the training phase
    def train_step(X,Y):
        
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        
        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y) 
        
        # compute gradients for the optimizer to use 
        loss.backward()
        
        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()
        
        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad() 
        
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,criterion):
    def validate(X,Y):
        
        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase: 
        with torch.no_grad(): 
            
            # set model to validation phase i.e. turn off dropout and batchnorm layers 
            model.eval()
      
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            
            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits,Y)
            
        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint(): 
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint

def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
# get training set size to calculate # iterations and minibatch indices
train_size = X_train.shape[0]

# pick minibatch size (of 32... always)
minibatch = 32

# set device to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'{device} selected')

# instantiate model and move to GPU for training
model = parallel_all_you_want(num_emotions=len(emotions_dict)).to(device) 
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )

# encountered bugs in google colab only, unless I explicitly defined optimizer in this cell...
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# instantiate the checkpoint save function
save_checkpoint = make_save_checkpoint()

# instantiate the training step function 
train_step = make_train_step(model, criterion, optimizer=optimizer)

# instantiate the validation loop function
validate = make_validate_fnc(model,criterion)

# instantiate lists to hold scalar performance metrics to plot later
train_losses=[]
valid_losses = []

# create training loop for one complete epoch (entire training set)
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):

    for epoch in range(num_epochs):
        
        # set model to train phase
        model.train()         
        
        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size) 
        
        # shuffle the training set for each epoch:
        X_train = X_train[train_indices,:,:,:] 
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate 
        epoch_acc = 0 
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)
        
        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):
            
            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch 
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size) 
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start 
            
            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:] 
            # get training minibatch labels 
            Y = Y_train[batch_start:batch_end] 

            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float() 
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor,Y_tensor) 
            
            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size
            
            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}',end='')
        
        # create tensors from validation set
        X_valid_tensor = torch.tensor(X_valid,device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor,Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
                  
        # Save checkpoint of the model
        #checkpoint_filename = '/content/gdrive/My Drive/DL/models/checkpoints/parallel_all_you_wantFINAL-{:03d}.pkl'.format(epoch)
        checkpoint_filename = 'checkpoint/parallel_all_you_wantFINAL-{:03d}.pkl'.format(epoch)
        save_checkpoint(optimizer, model, epoch, checkpoint_filename)
        
        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')
# Out:
# cuda selected
# Number of trainable params:  247423

# %%
# choose number of epochs higher than reasonable so we can manually stop training 
num_epochs = 250

# train it!
train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
# Out:
# Epoch 0: iteration 55/56
# Epoch 0 --- loss:4.379, Epoch accuracy:26.01%, Validation loss:2.007, Validation accuracy:24.56%
# Epoch 1: iteration 55/56
# Epoch 1 --- loss:1.547, Epoch accuracy:39.49%, Validation loss:1.641, Validation accuracy:30.26%
# Epoch 2: iteration 55/56
# Epoch 2 --- loss:1.515, Epoch accuracy:41.76%, Validation loss:1.696, Validation accuracy:38.60%
# Epoch 3: iteration 55/56
# Epoch 3 --- loss:1.414, Epoch accuracy:44.04%, Validation loss:1.662, Validation accuracy:37.28%
# Epoch 4: iteration 55/56
# Epoch 4 --- loss:1.327, Epoch accuracy:48.31%, Validation loss:1.677, Validation accuracy:36.84%
# Epoch 5: iteration 55/56
# Epoch 5 --- loss:1.212, Epoch accuracy:53.74%, Validation loss:1.481, Validation accuracy:50.44%
# Epoch 6: iteration 55/56
# Epoch 6 --- loss:1.184, Epoch accuracy:54.46%, Validation loss:1.455, Validation accuracy:46.05%
# Epoch 7: iteration 55/56
# Epoch 7 --- loss:1.129, Epoch accuracy:55.07%, Validation loss:1.210, Validation accuracy:58.33%
# Epoch 8: iteration 55/56
# Epoch 8 --- loss:1.106, Epoch accuracy:56.41%, Validation loss:1.421, Validation accuracy:51.75%
# Epoch 9: iteration 55/56
# Epoch 9 --- loss:1.082, Epoch accuracy:57.07%, Validation loss:1.362, Validation accuracy:53.51%
# Epoch 10: iteration 55/56
# Epoch 10 --- loss:1.013, Epoch accuracy:60.18%, Validation loss:1.267, Validation accuracy:53.51%
# Epoch 11: iteration 55/56
# Epoch 11 --- loss:0.982, Epoch accuracy:61.29%, Validation loss:1.083, Validation accuracy:63.16%
# Epoch 12: iteration 55/56
# Epoch 12 --- loss:0.937, Epoch accuracy:63.84%, Validation loss:1.047, Validation accuracy:64.47%
# Epoch 13: iteration 55/56
# Epoch 13 --- loss:0.915, Epoch accuracy:64.56%, Validation loss:1.275, Validation accuracy:56.14%
# Epoch 14: iteration 55/56
# Epoch 14 --- loss:0.930, Epoch accuracy:63.89%, Validation loss:0.973, Validation accuracy:67.11%
# Epoch 15: iteration 55/56
# Epoch 15 --- loss:0.871, Epoch accuracy:65.45%, Validation loss:0.968, Validation accuracy:64.91%
# Epoch 16: iteration 55/56
# Epoch 16 --- loss:0.830, Epoch accuracy:68.61%, Validation loss:1.061, Validation accuracy:66.67%
# Epoch 17: iteration 55/56
# Epoch 17 --- loss:0.796, Epoch accuracy:68.50%, Validation loss:1.147, Validation accuracy:60.09%
# Epoch 18: iteration 55/56
# Epoch 18 --- loss:0.819, Epoch accuracy:68.66%, Validation loss:0.973, Validation accuracy:66.23%
# Epoch 19: iteration 55/56
# Epoch 19 --- loss:0.762, Epoch accuracy:70.99%, Validation loss:1.050, Validation accuracy:65.35%
# Epoch 20: iteration 55/56
# Epoch 20 --- loss:0.757, Epoch accuracy:71.16%, Validation loss:0.977, Validation accuracy:68.42%
# Epoch 21: iteration 55/56
# Epoch 21 --- loss:0.729, Epoch accuracy:72.43%, Validation loss:1.103, Validation accuracy:64.04%
# Epoch 22: iteration 55/56
# Epoch 22 --- loss:0.710, Epoch accuracy:72.99%, Validation loss:1.089, Validation accuracy:63.16%
# Epoch 23: iteration 55/56
# Epoch 23 --- loss:0.694, Epoch accuracy:72.27%, Validation loss:0.948, Validation accuracy:68.86%
# Epoch 24: iteration 55/56
# Epoch 24 --- loss:0.676, Epoch accuracy:72.99%, Validation loss:0.907, Validation accuracy:68.86%
# Epoch 25: iteration 55/56
# Epoch 25 --- loss:0.645, Epoch accuracy:74.88%, Validation loss:0.929, Validation accuracy:69.74%
# Epoch 26: iteration 55/56
# Epoch 26 --- loss:0.654, Epoch accuracy:74.43%, Validation loss:0.892, Validation accuracy:74.12%
# Epoch 27: iteration 55/56
# Epoch 27 --- loss:0.640, Epoch accuracy:75.82%, Validation loss:0.981, Validation accuracy:70.18%
# Epoch 28: iteration 55/56
# Epoch 28 --- loss:0.611, Epoch accuracy:76.10%, Validation loss:0.927, Validation accuracy:70.61%
# Epoch 29: iteration 55/56
# Epoch 29 --- loss:0.569, Epoch accuracy:78.37%, Validation loss:0.919, Validation accuracy:70.18%
# Epoch 30: iteration 55/56
# Epoch 30 --- loss:0.569, Epoch accuracy:78.20%, Validation loss:1.090, Validation accuracy:66.67%
# Epoch 31: iteration 55/56
# Epoch 31 --- loss:0.557, Epoch accuracy:78.42%, Validation loss:0.978, Validation accuracy:69.74%
# Epoch 32: iteration 55/56
# Epoch 32 --- loss:0.522, Epoch accuracy:80.20%, Validation loss:1.015, Validation accuracy:70.61%
# Epoch 33: iteration 55/56
# Epoch 33 --- loss:0.504, Epoch accuracy:81.03%, Validation loss:1.013, Validation accuracy:66.23%
# Epoch 34: iteration 55/56
# Epoch 34 --- loss:0.518, Epoch accuracy:79.81%, Validation loss:0.957, Validation accuracy:67.98%
# Epoch 35: iteration 55/56
# Epoch 35 --- loss:0.465, Epoch accuracy:82.58%, Validation loss:0.951, Validation accuracy:72.37%
# Epoch 36: iteration 55/56
# Epoch 36 --- loss:0.473, Epoch accuracy:81.92%, Validation loss:1.146, Validation accuracy:67.11%
# Epoch 37: iteration 55/56
# Epoch 37 --- loss:0.503, Epoch accuracy:80.09%, Validation loss:0.904, Validation accuracy:69.74%
# Epoch 38: iteration 55/56
# Epoch 38 --- loss:0.439, Epoch accuracy:82.47%, Validation loss:0.797, Validation accuracy:74.56%
# Epoch 39: iteration 55/56
# Epoch 39 --- loss:0.433, Epoch accuracy:83.19%, Validation loss:0.937, Validation accuracy:75.00%
# Epoch 40: iteration 55/56
# Epoch 40 --- loss:0.430, Epoch accuracy:83.42%, Validation loss:0.960, Validation accuracy:68.86%
# Epoch 41: iteration 55/56
# Epoch 41 --- loss:0.421, Epoch accuracy:84.03%, Validation loss:0.968, Validation accuracy:73.25%
# Epoch 42: iteration 55/56
# Epoch 42 --- loss:0.425, Epoch accuracy:83.86%, Validation loss:0.822, Validation accuracy:75.00%
# Epoch 43: iteration 55/56
# Epoch 43 --- loss:0.434, Epoch accuracy:82.70%, Validation loss:1.097, Validation accuracy:66.67%
# Epoch 44: iteration 55/56
# Epoch 44 --- loss:0.377, Epoch accuracy:85.30%, Validation loss:0.896, Validation accuracy:70.61%
# Epoch 45: iteration 55/56
# Epoch 45 --- loss:0.391, Epoch accuracy:84.91%, Validation loss:0.943, Validation accuracy:73.25%
# Epoch 46: iteration 55/56
# Epoch 46 --- loss:0.348, Epoch accuracy:87.13%, Validation loss:0.861, Validation accuracy:73.68%
# Epoch 47: iteration 55/56
# Epoch 47 --- loss:0.313, Epoch accuracy:88.02%, Validation loss:0.896, Validation accuracy:73.25%
# Epoch 48: iteration 55/56
# Epoch 48 --- loss:0.323, Epoch accuracy:87.69%, Validation loss:0.865, Validation accuracy:74.12%
# Epoch 49: iteration 55/56
# Epoch 49 --- loss:0.325, Epoch accuracy:87.63%, Validation loss:0.977, Validation accuracy:71.49%
# Epoch 50: iteration 55/56
# Epoch 50 --- loss:0.317, Epoch accuracy:87.69%, Validation loss:1.000, Validation accuracy:72.37%
# Epoch 51: iteration 55/56
# Epoch 51 --- loss:0.345, Epoch accuracy:86.19%, Validation loss:1.383, Validation accuracy:69.74%
# Epoch 52: iteration 55/56
# Epoch 52 --- loss:0.320, Epoch accuracy:87.58%, Validation loss:0.871, Validation accuracy:75.88%
# Epoch 53: iteration 55/56
# Epoch 53 --- loss:0.316, Epoch accuracy:87.08%, Validation loss:0.866, Validation accuracy:75.44%
# Epoch 54: iteration 55/56
# Epoch 54 --- loss:0.295, Epoch accuracy:88.52%, Validation loss:0.917, Validation accuracy:74.56%
# Epoch 55: iteration 55/56
# Epoch 55 --- loss:0.260, Epoch accuracy:90.13%, Validation loss:0.921, Validation accuracy:71.93%
# Epoch 56: iteration 55/56
# Epoch 56 --- loss:0.267, Epoch accuracy:89.35%, Validation loss:0.920, Validation accuracy:75.88%
# Epoch 57: iteration 55/56
# Epoch 57 --- loss:0.257, Epoch accuracy:89.57%, Validation loss:1.033, Validation accuracy:74.56%
# Epoch 58: iteration 55/56
# Epoch 58 --- loss:0.244, Epoch accuracy:90.29%, Validation loss:1.040, Validation accuracy:72.37%
# Epoch 59: iteration 55/56
# Epoch 59 --- loss:0.243, Epoch accuracy:90.52%, Validation loss:1.003, Validation accuracy:70.61%
# Epoch 60: iteration 55/56
# Epoch 60 --- loss:0.222, Epoch accuracy:91.63%, Validation loss:0.994, Validation accuracy:74.56%
# Epoch 61: iteration 55/56
# Epoch 61 --- loss:0.214, Epoch accuracy:92.29%, Validation loss:1.108, Validation accuracy:69.74%
# Epoch 62: iteration 55/56
# Epoch 62 --- loss:0.195, Epoch accuracy:92.46%, Validation loss:1.002, Validation accuracy:73.25%
# Epoch 63: iteration 55/56
# Epoch 63 --- loss:0.210, Epoch accuracy:92.51%, Validation loss:1.126, Validation accuracy:72.81%
# Epoch 64: iteration 55/56
# Epoch 64 --- loss:0.228, Epoch accuracy:91.85%, Validation loss:0.981, Validation accuracy:72.37%
# Epoch 65: iteration 55/56
# Epoch 65 --- loss:0.206, Epoch accuracy:92.35%, Validation loss:1.053, Validation accuracy:71.93%
# Epoch 66: iteration 55/56
# Epoch 66 --- loss:0.202, Epoch accuracy:92.51%, Validation loss:0.988, Validation accuracy:72.81%
# Epoch 67: iteration 55/56
# Epoch 67 --- loss:0.176, Epoch accuracy:93.62%, Validation loss:1.018, Validation accuracy:72.81%
# Epoch 68: iteration 55/56
# Epoch 68 --- loss:0.183, Epoch accuracy:92.96%, Validation loss:0.958, Validation accuracy:75.88%
# Epoch 69: iteration 55/56
# Epoch 69 --- loss:0.166, Epoch accuracy:94.29%, Validation loss:1.145, Validation accuracy:74.56%
# Epoch 70: iteration 55/56
# Epoch 70 --- loss:0.216, Epoch accuracy:91.46%, Validation loss:1.058, Validation accuracy:72.81%
# Epoch 71: iteration 55/56
# Epoch 71 --- loss:0.206, Epoch accuracy:91.40%, Validation loss:1.010, Validation accuracy:72.37%
# Epoch 72: iteration 55/56
# Epoch 72 --- loss:0.191, Epoch accuracy:92.18%, Validation loss:1.167, Validation accuracy:71.49%
# Epoch 73: iteration 55/56
# Epoch 73 --- loss:0.167, Epoch accuracy:93.90%, Validation loss:1.091, Validation accuracy:73.68%
# Epoch 74: iteration 55/56
# Epoch 74 --- loss:0.192, Epoch accuracy:92.07%, Validation loss:1.012, Validation accuracy:74.56%
# Epoch 75: iteration 55/56
# Epoch 75 --- loss:0.137, Epoch accuracy:95.12%, Validation loss:1.049, Validation accuracy:73.25%
# Epoch 76: iteration 55/56
# Epoch 76 --- loss:0.159, Epoch accuracy:94.01%, Validation loss:1.204, Validation accuracy:71.05%
# Epoch 77: iteration 55/56
# Epoch 77 --- loss:0.166, Epoch accuracy:93.51%, Validation loss:0.970, Validation accuracy:75.00%
# Epoch 78: iteration 55/56
# Epoch 78 --- loss:0.173, Epoch accuracy:93.23%, Validation loss:1.037, Validation accuracy:76.75%
# Epoch 79: iteration 55/56
# Epoch 79 --- loss:0.121, Epoch accuracy:95.95%, Validation loss:1.002, Validation accuracy:75.44%
# Epoch 80: iteration 55/56
# Epoch 80 --- loss:0.146, Epoch accuracy:94.12%, Validation loss:1.160, Validation accuracy:75.44%
# Epoch 81: iteration 55/56
# Epoch 81 --- loss:0.127, Epoch accuracy:95.56%, Validation loss:1.057, Validation accuracy:75.00%
# Epoch 82: iteration 55/56
# Epoch 82 --- loss:0.136, Epoch accuracy:94.68%, Validation loss:1.059, Validation accuracy:75.00%
# Epoch 83: iteration 55/56
# Epoch 83 --- loss:0.161, Epoch accuracy:93.84%, Validation loss:1.149, Validation accuracy:75.88%
# Epoch 84: iteration 55/56
# Epoch 84 --- loss:0.112, Epoch accuracy:95.95%, Validation loss:1.178, Validation accuracy:74.12%
# Epoch 85: iteration 55/56
# Epoch 85 --- loss:0.114, Epoch accuracy:95.78%, Validation loss:1.113, Validation accuracy:75.00%
# Epoch 86: iteration 55/56
# Epoch 86 --- loss:0.122, Epoch accuracy:95.34%, Validation loss:1.042, Validation accuracy:74.56%
# Epoch 87: iteration 55/56
# Epoch 87 --- loss:0.128, Epoch accuracy:95.17%, Validation loss:1.219, Validation accuracy:71.93%
# Epoch 88: iteration 55/56
# Epoch 88 --- loss:0.148, Epoch accuracy:94.07%, Validation loss:1.023, Validation accuracy:75.88%
# Epoch 89: iteration 55/56
# Epoch 89 --- loss:0.133, Epoch accuracy:95.06%, Validation loss:1.061, Validation accuracy:73.68%
# Epoch 90: iteration 55/56
# Epoch 90 --- loss:0.105, Epoch accuracy:96.28%, Validation loss:1.028, Validation accuracy:73.25%
# Epoch 91: iteration 55/56
# Epoch 91 --- loss:0.094, Epoch accuracy:96.34%, Validation loss:1.158, Validation accuracy:74.56%
# Epoch 92: iteration 55/56
# Epoch 92 --- loss:0.099, Epoch accuracy:96.78%, Validation loss:1.175, Validation accuracy:74.12%
# Epoch 93: iteration 55/56
# Epoch 93 --- loss:0.091, Epoch accuracy:96.51%, Validation loss:1.202, Validation accuracy:73.68%
# Epoch 94: iteration 55/56
# Epoch 94 --- loss:0.134, Epoch accuracy:94.23%, Validation loss:1.198, Validation accuracy:75.00%
# Epoch 95: iteration 55/56
# Epoch 95 --- loss:0.121, Epoch accuracy:94.79%, Validation loss:1.027, Validation accuracy:76.32%
# Epoch 96: iteration 55/56
# Epoch 96 --- loss:0.090, Epoch accuracy:96.39%, Validation loss:1.092, Validation accuracy:74.56%
# Epoch 97: iteration 55/56
# Epoch 97 --- loss:0.115, Epoch accuracy:95.73%, Validation loss:1.250, Validation accuracy:74.12%
# Epoch 98: iteration 55/56
# Epoch 98 --- loss:0.138, Epoch accuracy:94.79%, Validation loss:1.102, Validation accuracy:75.00%
# Epoch 99: iteration 55/56
# Epoch 99 --- loss:0.132, Epoch accuracy:94.68%, Validation loss:1.259, Validation accuracy:72.81%
# Epoch 100: iteration 55/56
# Epoch 100 --- loss:0.104, Epoch accuracy:96.12%, Validation loss:1.285, Validation accuracy:72.81%
# Epoch 101: iteration 55/56
# Epoch 101 --- loss:0.086, Epoch accuracy:96.45%, Validation loss:1.182, Validation accuracy:73.68%
# Epoch 102: iteration 55/56
# Epoch 102 --- loss:0.072, Epoch accuracy:97.62%, Validation loss:1.131, Validation accuracy:75.00%
# Epoch 103: iteration 55/56
# Epoch 103 --- loss:0.070, Epoch accuracy:97.50%, Validation loss:1.217, Validation accuracy:74.12%
# Epoch 104: iteration 55/56
# Epoch 104 --- loss:0.073, Epoch accuracy:97.12%, Validation loss:1.439, Validation accuracy:74.56%
# Epoch 105: iteration 55/56
# Epoch 105 --- loss:0.064, Epoch accuracy:97.78%, Validation loss:1.108, Validation accuracy:74.12%
# Epoch 106: iteration 55/56
# Epoch 106 --- loss:0.056, Epoch accuracy:98.28%, Validation loss:1.275, Validation accuracy:71.93%
# Epoch 107: iteration 55/56
# Epoch 107 --- loss:0.068, Epoch accuracy:97.39%, Validation loss:1.195, Validation accuracy:74.56%
# Epoch 108: iteration 55/56
# Epoch 108 --- loss:0.084, Epoch accuracy:96.84%, Validation loss:1.204, Validation accuracy:75.44%
# Epoch 109: iteration 55/56
# Epoch 109 --- loss:0.083, Epoch accuracy:96.95%, Validation loss:1.205, Validation accuracy:73.25%
# Epoch 110: iteration 55/56
# Epoch 110 --- loss:0.124, Epoch accuracy:94.90%, Validation loss:1.188, Validation accuracy:70.61%
# Epoch 111: iteration 55/56
# Epoch 111 --- loss:0.075, Epoch accuracy:96.95%, Validation loss:1.231, Validation accuracy:73.68%
# Epoch 112: iteration 55/56
# Epoch 112 --- loss:0.058, Epoch accuracy:97.95%, Validation loss:1.194, Validation accuracy:75.88%
# Epoch 113: iteration 55/56
# Epoch 113 --- loss:0.076, Epoch accuracy:97.06%, Validation loss:1.334, Validation accuracy:75.44%
# Epoch 114: iteration 55/56
# Epoch 114 --- loss:0.095, Epoch accuracy:96.39%, Validation loss:1.162, Validation accuracy:74.12%
# Epoch 115: iteration 55/56
# Epoch 115 --- loss:0.063, Epoch accuracy:97.73%, Validation loss:1.077, Validation accuracy:76.32%
# Epoch 116: iteration 55/56
# Epoch 116 --- loss:0.056, Epoch accuracy:97.84%, Validation loss:1.088, Validation accuracy:75.44%
# Epoch 117: iteration 55/56
# Epoch 117 --- loss:0.054, Epoch accuracy:97.78%, Validation loss:1.144, Validation accuracy:75.44%
# Epoch 118: iteration 55/56
# Epoch 118 --- loss:0.052, Epoch accuracy:98.11%, Validation loss:1.099, Validation accuracy:76.32%
# Epoch 119: iteration 55/56
# Epoch 119 --- loss:0.046, Epoch accuracy:98.34%, Validation loss:1.171, Validation accuracy:73.68%
# Epoch 120: iteration 55/56
# Epoch 120 --- loss:0.045, Epoch accuracy:98.39%, Validation loss:1.143, Validation accuracy:76.32%
# Epoch 121: iteration 55/56
# Epoch 121 --- loss:0.043, Epoch accuracy:98.39%, Validation loss:1.150, Validation accuracy:73.68%
# Epoch 122: iteration 55/56
# Epoch 122 --- loss:0.063, Epoch accuracy:97.34%, Validation loss:1.401, Validation accuracy:72.37%
# Epoch 123: iteration 55/56
# Epoch 123 --- loss:0.068, Epoch accuracy:97.39%, Validation loss:1.211, Validation accuracy:73.25%
# Epoch 124: iteration 55/56
# Epoch 124 --- loss:0.051, Epoch accuracy:98.11%, Validation loss:1.296, Validation accuracy:72.81%
# Epoch 125: iteration 55/56
# Epoch 125 --- loss:0.049, Epoch accuracy:98.11%, Validation loss:1.212, Validation accuracy:75.00%
# Epoch 126: iteration 55/56
# Epoch 126 --- loss:0.041, Epoch accuracy:98.28%, Validation loss:1.198, Validation accuracy:72.81%
# Epoch 127: iteration 55/56
# Epoch 127 --- loss:0.056, Epoch accuracy:97.78%, Validation loss:1.152, Validation accuracy:73.68%
# Epoch 128: iteration 55/56
# Epoch 128 --- loss:0.055, Epoch accuracy:97.56%, Validation loss:1.167, Validation accuracy:71.93%
# Epoch 129: iteration 55/56
# Epoch 129 --- loss:0.062, Epoch accuracy:97.45%, Validation loss:1.365, Validation accuracy:71.05%
# Epoch 130: iteration 55/56
# Epoch 130 --- loss:0.166, Epoch accuracy:93.34%, Validation loss:1.200, Validation accuracy:73.25%
# Epoch 131: iteration 55/56
# Epoch 131 --- loss:0.069, Epoch accuracy:97.01%, Validation loss:1.299, Validation accuracy:70.61%
# Epoch 132: iteration 55/56
# Epoch 132 --- loss:0.073, Epoch accuracy:96.73%, Validation loss:1.317, Validation accuracy:69.30%
# Epoch 133: iteration 55/56
# Epoch 133 --- loss:0.069, Epoch accuracy:97.23%, Validation loss:1.439, Validation accuracy:71.49%
# Epoch 134: iteration 55/56
# Epoch 134 --- loss:0.061, Epoch accuracy:97.50%, Validation loss:1.134, Validation accuracy:74.56%
# Epoch 135: iteration 55/56
# Epoch 135 --- loss:0.112, Epoch accuracy:95.84%, Validation loss:1.313, Validation accuracy:71.49%
# Epoch 136: iteration 55/56
# Epoch 136 --- loss:0.054, Epoch accuracy:97.67%, Validation loss:1.173, Validation accuracy:75.44%
# Epoch 137: iteration 55/56
# Epoch 137 --- loss:0.032, Epoch accuracy:98.95%, Validation loss:1.204, Validation accuracy:73.25%
# Epoch 138: iteration 55/56
# Epoch 138 --- loss:0.036, Epoch accuracy:98.72%, Validation loss:1.270, Validation accuracy:72.81%
# Epoch 139: iteration 55/56
# Epoch 139 --- loss:0.032, Epoch accuracy:98.72%, Validation loss:1.224, Validation accuracy:76.32%
# Epoch 140: iteration 55/56
# Epoch 140 --- loss:0.034, Epoch accuracy:98.50%, Validation loss:1.357, Validation accuracy:70.61%
# Epoch 141: iteration 55/56
# Epoch 141 --- loss:0.044, Epoch accuracy:98.28%, Validation loss:1.208, Validation accuracy:74.56%
# Epoch 142: iteration 55/56
# Epoch 142 --- loss:0.049, Epoch accuracy:98.00%, Validation loss:1.308, Validation accuracy:75.44%
# Epoch 143: iteration 55/56
# Epoch 143 --- loss:0.041, Epoch accuracy:98.11%, Validation loss:1.176, Validation accuracy:75.88%
# Epoch 144: iteration 55/56
# Epoch 144 --- loss:0.038, Epoch accuracy:98.56%, Validation loss:1.197, Validation accuracy:73.68%
# Epoch 145: iteration 55/56
# Epoch 145 --- loss:0.043, Epoch accuracy:98.34%, Validation loss:1.175, Validation accuracy:75.88%
# Epoch 146: iteration 55/56
# Epoch 146 --- loss:0.031, Epoch accuracy:98.84%, Validation loss:1.329, Validation accuracy:74.12%
# Epoch 147: iteration 55/56
# Epoch 147 --- loss:0.029, Epoch accuracy:98.50%, Validation loss:1.160, Validation accuracy:75.00%
# Epoch 148: iteration 55/56
# Epoch 148 --- loss:0.039, Epoch accuracy:98.50%, Validation loss:1.278, Validation accuracy:74.56%
# Epoch 149: iteration 55/56
# Epoch 149 --- loss:0.052, Epoch accuracy:98.11%, Validation loss:1.135, Validation accuracy:72.81%
# Epoch 150: iteration 55/56
# Epoch 150 --- loss:0.033, Epoch accuracy:98.72%, Validation loss:1.193, Validation accuracy:75.00%
# Epoch 151: iteration 55/56
# Epoch 151 --- loss:0.026, Epoch accuracy:99.06%, Validation loss:1.233, Validation accuracy:73.68%
# Epoch 152: iteration 55/56
# Epoch 152 --- loss:0.040, Epoch accuracy:98.34%, Validation loss:1.274, Validation accuracy:72.37%
# Epoch 153: iteration 55/56
# Epoch 153 --- loss:0.037, Epoch accuracy:98.50%, Validation loss:1.281, Validation accuracy:76.32%
# Epoch 154: iteration 55/56
# Epoch 154 --- loss:0.038, Epoch accuracy:98.50%, Validation loss:1.232, Validation accuracy:73.25%
# Epoch 155: iteration 55/56
# Epoch 155 --- loss:0.020, Epoch accuracy:99.28%, Validation loss:1.240, Validation accuracy:78.07%
# Epoch 156: iteration 55/56
# Epoch 156 --- loss:0.023, Epoch accuracy:99.00%, Validation loss:1.174, Validation accuracy:76.75%
# Epoch 157: iteration 55/56
# Epoch 157 --- loss:0.022, Epoch accuracy:99.00%, Validation loss:1.252, Validation accuracy:75.00%
# Epoch 158: iteration 55/56
# Epoch 158 --- loss:0.017, Epoch accuracy:99.22%, Validation loss:1.218, Validation accuracy:73.25%
# Epoch 159: iteration 55/56
# Epoch 159 --- loss:0.026, Epoch accuracy:98.84%, Validation loss:1.479, Validation accuracy:73.25%
# Epoch 160: iteration 55/56
# Epoch 160 --- loss:0.029, Epoch accuracy:98.56%, Validation loss:1.311, Validation accuracy:75.00%
# Epoch 161: iteration 55/56
# Epoch 161 --- loss:0.034, Epoch accuracy:98.67%, Validation loss:1.518, Validation accuracy:70.61%
# Epoch 162: iteration 55/56
# Epoch 162 --- loss:0.035, Epoch accuracy:98.34%, Validation loss:1.194, Validation accuracy:78.07%
# Epoch 163: iteration 55/56
# Epoch 163 --- loss:0.024, Epoch accuracy:99.06%, Validation loss:1.231, Validation accuracy:75.00%
# Epoch 164: iteration 55/56
# Epoch 164 --- loss:0.034, Epoch accuracy:98.45%, Validation loss:1.430, Validation accuracy:71.49%
# Epoch 165: iteration 55/56
# Epoch 165 --- loss:0.034, Epoch accuracy:98.45%, Validation loss:1.229, Validation accuracy:74.12%
# Epoch 166: iteration 55/56
# Epoch 166 --- loss:0.030, Epoch accuracy:98.67%, Validation loss:1.272, Validation accuracy:75.44%
# Epoch 167: iteration 55/56
# Epoch 167 --- loss:0.022, Epoch accuracy:99.11%, Validation loss:1.204, Validation accuracy:73.68%
# Epoch 168: iteration 55/56
# Epoch 168 --- loss:0.027, Epoch accuracy:99.00%, Validation loss:1.296, Validation accuracy:74.56%
# Epoch 169: iteration 55/56
# Epoch 169 --- loss:0.036, Epoch accuracy:98.34%, Validation loss:1.315, Validation accuracy:72.37%
# Epoch 170: iteration 55/56
# Epoch 170 --- loss:0.035, Epoch accuracy:98.56%, Validation loss:1.208, Validation accuracy:73.68%
# Epoch 171: iteration 55/56
# Epoch 171 --- loss:0.019, Epoch accuracy:99.11%, Validation loss:1.228, Validation accuracy:74.56%
# Epoch 172: iteration 55/56
# Epoch 172 --- loss:0.019, Epoch accuracy:99.22%, Validation loss:1.202, Validation accuracy:75.44%
# Epoch 173: iteration 55/56
# Epoch 173 --- loss:0.054, Epoch accuracy:97.78%, Validation loss:1.194, Validation accuracy:77.19%
# Epoch 174: iteration 55/56
# Epoch 174 --- loss:0.126, Epoch accuracy:94.90%, Validation loss:1.568, Validation accuracy:69.74%
# Epoch 175: iteration 55/56
# Epoch 175 --- loss:0.055, Epoch accuracy:97.78%, Validation loss:1.340, Validation accuracy:71.93%
# Epoch 176: iteration 55/56
# Epoch 176 --- loss:0.062, Epoch accuracy:97.39%, Validation loss:1.483, Validation accuracy:70.18%
# Epoch 177: iteration 55/56
# Epoch 177 --- loss:0.032, Epoch accuracy:98.84%, Validation loss:1.222, Validation accuracy:74.12%
# Epoch 178: iteration 55/56
# Epoch 178 --- loss:0.025, Epoch accuracy:98.84%, Validation loss:1.252, Validation accuracy:74.12%
# Epoch 179: iteration 55/56
# Epoch 179 --- loss:0.023, Epoch accuracy:99.17%, Validation loss:1.221, Validation accuracy:75.00%
# Epoch 180: iteration 55/56
# Epoch 180 --- loss:0.035, Epoch accuracy:98.45%, Validation loss:1.294, Validation accuracy:73.68%
# Epoch 181: iteration 55/56
# Epoch 181 --- loss:0.022, Epoch accuracy:99.11%, Validation loss:1.279, Validation accuracy:73.68%
# Epoch 182: iteration 55/56
# Epoch 182 --- loss:0.064, Epoch accuracy:97.45%, Validation loss:1.561, Validation accuracy:73.68%
# Epoch 183: iteration 55/56
# Epoch 183 --- loss:0.039, Epoch accuracy:98.28%, Validation loss:1.318, Validation accuracy:73.68%
# Epoch 184: iteration 55/56
# Epoch 184 --- loss:0.024, Epoch accuracy:98.95%, Validation loss:1.323, Validation accuracy:71.93%
# Epoch 185: iteration 55/56
# Epoch 185 --- loss:0.024, Epoch accuracy:98.78%, Validation loss:1.231, Validation accuracy:76.32%
# Epoch 186: iteration 55/56
# Epoch 186 --- loss:0.049, Epoch accuracy:97.84%, Validation loss:1.464, Validation accuracy:71.93%
# Epoch 187: iteration 55/56
# Epoch 187 --- loss:0.025, Epoch accuracy:98.84%, Validation loss:1.212, Validation accuracy:76.75%
# Epoch 188: iteration 55/56
# Epoch 188 --- loss:0.019, Epoch accuracy:99.28%, Validation loss:1.322, Validation accuracy:73.25%
# Epoch 189: iteration 55/56
# Epoch 189 --- loss:0.017, Epoch accuracy:99.22%, Validation loss:1.217, Validation accuracy:76.32%
# Epoch 190: iteration 55/56
# Epoch 190 --- loss:0.013, Epoch accuracy:99.39%, Validation loss:1.250, Validation accuracy:74.12%
# Epoch 191: iteration 55/56
# Epoch 191 --- loss:0.015, Epoch accuracy:99.33%, Validation loss:1.226, Validation accuracy:72.81%
# Epoch 192: iteration 55/56
# Epoch 192 --- loss:0.019, Epoch accuracy:99.17%, Validation loss:1.220, Validation accuracy:75.88%
# Epoch 193: iteration 55/56
# Epoch 193 --- loss:0.015, Epoch accuracy:99.22%, Validation loss:1.264, Validation accuracy:75.00%
# Epoch 194: iteration 55/56
# Epoch 194 --- loss:0.013, Epoch accuracy:99.33%, Validation loss:1.180, Validation accuracy:74.56%
# Epoch 195: iteration 55/56
# Epoch 195 --- loss:0.021, Epoch accuracy:98.95%, Validation loss:1.415, Validation accuracy:71.49%
# Epoch 196: iteration 55/56
# Epoch 196 --- loss:0.040, Epoch accuracy:98.45%, Validation loss:1.349, Validation accuracy:73.25%
# Epoch 197: iteration 55/56
# Epoch 197 --- loss:0.068, Epoch accuracy:96.95%, Validation loss:1.336, Validation accuracy:74.56%
# Epoch 198: iteration 55/56
# Epoch 198 --- loss:0.029, Epoch accuracy:98.72%, Validation loss:1.316, Validation accuracy:72.81%
# Epoch 199: iteration 55/56
# Epoch 199 --- loss:0.018, Epoch accuracy:99.17%, Validation loss:1.331, Validation accuracy:73.68%
# Epoch 200: iteration 55/56
# Epoch 200 --- loss:0.064, Epoch accuracy:97.17%, Validation loss:1.243, Validation accuracy:72.37%
# Epoch 201: iteration 55/56
# Epoch 201 --- loss:0.147, Epoch accuracy:94.84%, Validation loss:1.916, Validation accuracy:64.47%
# Epoch 202: iteration 55/56
# Epoch 202 --- loss:0.160, Epoch accuracy:93.68%, Validation loss:1.343, Validation accuracy:71.05%
# Epoch 203: iteration 55/56
# Epoch 203 --- loss:0.056, Epoch accuracy:97.95%, Validation loss:1.297, Validation accuracy:74.56%
# Epoch 204: iteration 55/56
# Epoch 204 --- loss:0.036, Epoch accuracy:98.56%, Validation loss:1.174, Validation accuracy:73.25%
# Epoch 205: iteration 55/56
# Epoch 205 --- loss:0.026, Epoch accuracy:98.89%, Validation loss:1.211, Validation accuracy:73.25%
# Epoch 206: iteration 55/56
# Epoch 206 --- loss:0.026, Epoch accuracy:98.78%, Validation loss:1.234, Validation accuracy:72.81%
# Epoch 207: iteration 55/56
# Epoch 207 --- loss:0.016, Epoch accuracy:99.33%, Validation loss:1.147, Validation accuracy:75.00%
# Epoch 208: iteration 55/56
# Epoch 208 --- loss:0.018, Epoch accuracy:99.22%, Validation loss:1.124, Validation accuracy:78.95%
# Epoch 209: iteration 55/56
# Epoch 209 --- loss:0.026, Epoch accuracy:98.78%, Validation loss:1.179, Validation accuracy:73.68%
# Epoch 210: iteration 55/56
# Epoch 210 --- loss:0.018, Epoch accuracy:99.11%, Validation loss:1.214, Validation accuracy:75.00%
# Epoch 211: iteration 55/56
# Epoch 211 --- loss:0.016, Epoch accuracy:99.17%, Validation loss:1.162, Validation accuracy:74.12%
# Epoch 212: iteration 55/56
# Epoch 212 --- loss:0.013, Epoch accuracy:99.39%, Validation loss:1.121, Validation accuracy:76.75%
# Epoch 213: iteration 55/56
# Epoch 213 --- loss:0.010, Epoch accuracy:99.39%, Validation loss:1.113, Validation accuracy:76.32%
# Epoch 214: iteration 55/56
# Epoch 214 --- loss:0.012, Epoch accuracy:99.39%, Validation loss:1.120, Validation accuracy:75.00%
# Epoch 215: iteration 55/56
# Epoch 215 --- loss:0.012, Epoch accuracy:99.33%, Validation loss:1.140, Validation accuracy:75.88%
# Epoch 216: iteration 55/56
# Epoch 216 --- loss:0.014, Epoch accuracy:99.22%, Validation loss:1.134, Validation accuracy:77.19%
# Epoch 217: iteration 55/56
# Epoch 217 --- loss:0.011, Epoch accuracy:99.39%, Validation loss:1.182, Validation accuracy:76.75%
# Epoch 218: iteration 55/56
# Epoch 218 --- loss:0.012, Epoch accuracy:99.33%, Validation loss:1.136, Validation accuracy:75.44%
# Epoch 219: iteration 55/56
# Epoch 219 --- loss:0.009, Epoch accuracy:99.33%, Validation loss:1.145, Validation accuracy:75.44%
# Epoch 220: iteration 55/56
# Epoch 220 --- loss:0.013, Epoch accuracy:99.28%, Validation loss:1.154, Validation accuracy:74.12%
# Epoch 221: iteration 55/56
# Epoch 221 --- loss:0.011, Epoch accuracy:99.39%, Validation loss:1.150, Validation accuracy:73.68%
# Epoch 222: iteration 55/56
# Epoch 222 --- loss:0.013, Epoch accuracy:99.33%, Validation loss:1.109, Validation accuracy:75.44%
# Epoch 223: iteration 55/56
# Epoch 223 --- loss:0.009, Epoch accuracy:99.39%, Validation loss:1.216, Validation accuracy:73.25%
# Epoch 224: iteration 55/56
# Epoch 224 --- loss:0.012, Epoch accuracy:99.33%, Validation loss:1.216, Validation accuracy:76.32%
# Epoch 225: iteration 55/56
# Epoch 225 --- loss:0.013, Epoch accuracy:99.39%, Validation loss:1.184, Validation accuracy:77.19%
# Epoch 226: iteration 55/56
# Epoch 226 --- loss:0.041, Epoch accuracy:98.06%, Validation loss:1.272, Validation accuracy:70.61%
# Epoch 227: iteration 55/56
# Epoch 227 --- loss:0.041, Epoch accuracy:98.50%, Validation loss:1.240, Validation accuracy:74.12%
# Epoch 228: iteration 55/56
# Epoch 228 --- loss:0.025, Epoch accuracy:98.84%, Validation loss:1.300, Validation accuracy:72.37%
# Epoch 229: iteration 55/56
# Epoch 229 --- loss:0.016, Epoch accuracy:99.22%, Validation loss:1.287, Validation accuracy:74.12%
# Epoch 230: iteration 55/56
# Epoch 230 --- loss:0.039, Epoch accuracy:98.56%, Validation loss:1.291, Validation accuracy:73.25%
# Epoch 231: iteration 55/56
# Epoch 231 --- loss:0.028, Epoch accuracy:98.56%, Validation loss:1.200, Validation accuracy:78.07%
# Epoch 232: iteration 55/56
# Epoch 232 --- loss:0.030, Epoch accuracy:98.61%, Validation loss:1.258, Validation accuracy:71.49%
# Epoch 233: iteration 55/56
# Epoch 233 --- loss:0.025, Epoch accuracy:98.95%, Validation loss:1.182, Validation accuracy:74.12%
# Epoch 234: iteration 55/56
# Epoch 234 --- loss:0.014, Epoch accuracy:99.28%, Validation loss:1.172, Validation accuracy:75.00%
# Epoch 235: iteration 55/56
# Epoch 235 --- loss:0.024, Epoch accuracy:99.06%, Validation loss:1.201, Validation accuracy:75.44%
# Epoch 236: iteration 55/56
# Epoch 236 --- loss:0.017, Epoch accuracy:99.17%, Validation loss:1.172, Validation accuracy:75.00%
# Epoch 237: iteration 55/56
# Epoch 237 --- loss:0.011, Epoch accuracy:99.33%, Validation loss:1.151, Validation accuracy:76.75%
# Epoch 238: iteration 55/56
# Epoch 238 --- loss:0.016, Epoch accuracy:99.22%, Validation loss:1.275, Validation accuracy:71.49%
# Epoch 239: iteration 55/56
# Epoch 239 --- loss:0.014, Epoch accuracy:99.28%, Validation loss:1.257, Validation accuracy:72.81%
# Epoch 240: iteration 55/56
# Epoch 240 --- loss:0.013, Epoch accuracy:99.22%, Validation loss:1.174, Validation accuracy:76.75%
# Epoch 241: iteration 55/56
# Epoch 241 --- loss:0.019, Epoch accuracy:99.00%, Validation loss:1.258, Validation accuracy:73.68%
# Epoch 242: iteration 55/56
# Epoch 242 --- loss:0.018, Epoch accuracy:99.22%, Validation loss:1.301, Validation accuracy:73.25%
# Epoch 243: iteration 55/56
# Epoch 243 --- loss:0.014, Epoch accuracy:99.28%, Validation loss:1.151, Validation accuracy:77.19%
# Epoch 244: iteration 55/56
# Epoch 244 --- loss:0.012, Epoch accuracy:99.39%, Validation loss:1.155, Validation accuracy:77.63%
# Epoch 245: iteration 55/56
# Epoch 245 --- loss:0.008, Epoch accuracy:99.39%, Validation loss:1.174, Validation accuracy:76.75%
# Epoch 246: iteration 55/56
# Epoch 246 --- loss:0.010, Epoch accuracy:99.33%, Validation loss:1.192, Validation accuracy:78.07%
# Epoch 247: iteration 55/56
# Epoch 247 --- loss:0.011, Epoch accuracy:99.22%, Validation loss:1.143, Validation accuracy:76.75%
# Epoch 248: iteration 55/56
# Epoch 248 --- loss:0.014, Epoch accuracy:99.17%, Validation loss:1.268, Validation accuracy:74.12%
# Epoch 249: iteration 55/56
# Epoch 249 --- loss:0.013, Epoch accuracy:99.33%, Validation loss:1.148, Validation accuracy:77.19%

# %%
plt.title('Loss Curve for Parallel is All You Want Model')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_losses[:],'b')
plt.plot(valid_losses[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()

# %%
# pick load folder  
load_folder = 'checkpoint'  

# pick the epoch to load
epoch = '230'
model_name = f'parallel_all_you_wantFINAL-{epoch}.pkl'

# make full load path
load_path = os.path.join(load_folder, model_name)

## instantiate empty model and populate with params from binary 
model = parallel_all_you_want(len(emotions_dict))
load_checkpoint(optimizer, model, load_path)

print(f'Loaded model from {load_path}')
# Out:
# Loaded model from checkpoint/parallel_all_you_wantFINAL-230.pkl

# %%
# reinitialize validation function with model from chosen checkpoint
validate = make_validate_fnc(model,criterion)

# Convert 4D test feature set array to tensor and move to GPU
X_test_tensor = torch.tensor(X_test,device=device).float()
# Convert 4D test label set array to tensor and move to GPU
y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
inputs =  X_test_tensor                     # this is what you had
labels =  y_test_tensor
#inputs, labels = inputs.cuda(), labels.cuda() # add this line
# Get the model's performance metrics using the validation function we defined

#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

#inputs, labels = inputs.to(device), labels.to(device)
model.to('cuda') 
inputs = inputs.to('cuda')

model.to('cuda') 
labels = labels.to('cuda')

test_loss, test_acc, predicted_emotions = validate(X_test_tensor,y_test_tensor)

print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test accuracy is 72.05%
