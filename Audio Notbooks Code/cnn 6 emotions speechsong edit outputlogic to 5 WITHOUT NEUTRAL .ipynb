# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, glob
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import warnings; warnings.filterwarnings('ignore') #matplot lib complains about librosa

# %%
# RAVDESS native sample rate is 48k
sample_rate = 48000

# Mel Spectrograms are not directly used as a feature in this model
# Mel Spectrograms are used in calculating MFCCs, which are a higher-level representation of pitch transition
# MFCCs work better - left the mel spectrogram function here in case anyone wants to experiment
def feature_melspectrogram(
    waveform, 
    sample_rate,
    fft = 1024,
    winlen = 512,
    window='hamming',
    hop=256,
    mels=128,
    ):
    
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram = librosa.feature.melspectrogram(
        y=waveform, 
        sr=sample_rate, 
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2)
    
    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms 
    melspectrogram = librosa.power_to_db(melspectrogram, ref=np.max)
    
    return melspectrogram

def feature_mfcc(
    waveform, 
    sample_rate,
    n_mfcc = 40,
    fft = 1024,
    winlen = 512,
    window='hamming',
    #hop=256, # increases # of time steps; was not helpful
    mels=128
    ):

    # Compute the MFCCs for all STFT frames 
    # 40 mel filterbanks (n_mfcc) = 40 coefficients
    mfc_coefficients=librosa.feature.mfcc(
        y=waveform, 
        sr=sample_rate, 
        n_mfcc=n_mfcc,
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        #hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2
        ) 

    return mfc_coefficients

def get_features(waveforms, features, samplerate):

    # initialize counter to track progress
    file_count = 0

    # process each waveform individually to get its MFCCs
    for waveform in waveforms:
        mfccs = feature_mfcc(waveform, sample_rate)
        features.append(mfccs)
        file_count += 1
        # print progress 
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')
    
    # return all features from list of waveforms
    return features

def get_waveforms(file):
    
    # load an individual sample audio file
    # read the full 3 seconds of the file, cut off the first 0.5s of silence; native sample rate = 48k
    # don't need to store the sample rate that librosa.load returns
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)
    
    # make sure waveform vectors are homogenous by defining explicitly
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform
    
    # return a single file's waveform                                      
    return waveform_homo
    
# RAVDESS dataset emotions
# shift emotions left to be 0 indexed for PyTorch
emotions_dict ={
 '''
    '0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
    '7':'disgust'  '''

   
  
    '0':'calm',
    '1':'happy',
    '2':'sad',
    '3':'angry',
    '4':'fearful',
    

}

# Additional attributes from RAVDESS to play with
emotion_attributes = {
    '01': 'normal',
    '02': 'strong'
}

# %%
# path to data for glob
data_path = 'ravadessspeechsong'

##'RAVDESS dataset/Actor_*/*.wav'
dir_list = os.listdir(data_path)
dir_list.sort()
dir_list
# Out:
# ['.ipynb_checkpoints',
#  'Actor_01',
#  'Actor_02',
#  'Actor_03',
#  'Actor_04',
#  'Actor_05',
#  'Actor_06',
#  'Actor_07',
#  'Actor_08',
#  'Actor_09',
#  'Actor_10',
#  'Actor_11',
#  'Actor_12',
#  'Actor_13',
#  'Actor_14',
#  'Actor_15',
#  'Actor_16',
#  'Actor_17',
#  'Actor_18',
#  'Actor_19',
#  'Actor_20',
#  'Actor_21',
#  'Actor_22',
#  'Actor_23',
#  'Actor_24']

# %%
def load_data():
  # features and labels
  emotions = []
  # raw waveforms to augment later
  waveforms = []
  # extra labels
  intensities, genders = [],[]
  # progress counter
  file_count = 0
  for i in dir_list:
    #print(i)
    
    file_name = os.listdir(data_path + '/' +i+'/')
    for file in file_name:
      if file == '.ipynb_checkpoints' : continue
      #print(file_name)
      file=data_path + '/' +i+'/'+file
      nm = file.split('.')[0].split('-')
      # get emotion label from the sample's file
      emotion = int(nm[2])
      #  move surprise to 0 for cleaner behaviour with PyTorch/0-indexing
      if emotion == 1:  continue
      if emotion == 2:  emotion = 0
      if emotion == 3:  emotion = 1
      if emotion == 4:  emotion = 2
      if emotion == 5:  emotion = 3
      if emotion == 6:  emotion = 4
      if emotion == 7:  continue
      if emotion == 8:  continue      # surprise is now at 0 index; other emotion indeces unchanged

      # can convert emotion label to emotion string if desired, but
      # training on number is better; better convert to emotion string after predictions are ready
      # emotion = emotions_dict[str(emotion)]
            
      # get other labels we might want
      #intensity = emotion_attributes[int(nm[3])]
      if nm[3] == '01':
            intensity = 0
      else:
            intensity = 1
      # even actors are female, odd are male
      if (int((file.split("-")[6]).split(".")[0]))%2==0: 
          gender = 'female' 
      else: 
          gender = 'male'
                
      # get waveform from the sample
      waveform = get_waveforms(file)
            
      # store waveforms and labels
      waveforms.append(waveform)
      emotions.append(emotion)
      intensities.append(intensity) # store intensity in case we wish to predict
      genders.append(gender) # store gender in case we wish to predict 
            
      file_count += 1
      # keep track of data loader's progress
      print('\r'+f' Processed {file_count}/{1440} audio samples',end='')
  return waveforms, emotions, intensities, genders

# %%
# load data 
# init explicitly to prevent data leakage from past sessions, since load_data() appends
waveforms, emotions, intensities, genders = [],[],[],[]
waveforms, emotions, intensities, genders = load_data()
# Out:
#  Processed 1880/1440 audio samples

# %%
print(f'Waveforms set: {len(waveforms)} samples')
# we have 1440 waveforms but we need to know their length too; should be 3 sec * 48k = 144k
print(f'Waveform signal length: {len(waveforms[0])}')
print(f'Emotions set: {len(emotions)} sample labels')
# Out:
# Waveforms set: 1880 samples
# Waveform signal length: 144000
# Emotions set: 1880 sample labels

# %%
# create storage for train, validation, test sets and their indices
train_set,valid_set,test_set = [],[],[]
X_train,X_valid,X_test = [],[],[]
y_train,y_valid,y_test = [],[],[]

# convert waveforms to array for processing
waveforms = np.array(waveforms)

# process each emotion separately to make sure we builf balanced train/valid/test sets 
for emotion_num in range(len(emotions_dict)):
        
    # find all indices of a single unique emotion
    emotion_indices = [index for index, emotion in enumerate(emotions) if emotion==emotion_num]

    # seed for reproducibility 
    np.random.seed(69)
    # shuffle indicies 
    emotion_indices = np.random.permutation(emotion_indices)

    # store dim (length) of the emotion list to make indices
    dim = len(emotion_indices)

    # store indices of training, validation and test sets in 80/10/10 proportion
    # train set is first 80%
    train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
    valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
    test_indices = emotion_indices[int(0.9*dim):]

    # create train waveforms/labels sets
    X_train.append(waveforms[train_indices,:])
    y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
    X_valid.append(waveforms[valid_indices,:])
    y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
    X_test.append(waveforms[test_indices,:])
    y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets 
    train_set.append(train_indices)
    valid_set.append(valid_indices)
    test_set.append(test_indices)

# concatenate, in order, all waveforms back into one array 
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array 
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

# make sure train, validation, test sets have no overlap/are unique
# get all unique indices across all sets and how many times each index appears (count)
uniques, count = np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)

# if each index appears just once, and we have 1440 such unique indices, then all sets are unique
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# Training waveforms:(1500, 144000), y_train:(1500,)
# Validation waveforms:(190, 144000), y_valid:(190,)
# Test waveforms:(190, 144000), y_test:(190,)
#
# Sets are unique: 1880 samples out of 1880 are unique

# %%
# initialize feature arrays
# We extract MFCC features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features 
features_train = get_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = get_features(X_valid, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features 
features_test = get_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'Features (MFC coefficient matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
#  Processed 1500/1500 waveforms
#
# Validation waveforms:
#  Processed 190/190 waveforms
#
# Test waveforms:
#  Processed 190/190 waveforms
#
# Features set: 1880 total, 1500 train, 190 validation, 190 test samples
# Features (MFC coefficient matrix) shape: 40 mel frequency coefficients x 282 time steps

# %%
def awgn_augmentation(waveform, multiples=2, bits=16, snr_min=15, snr_max=30): 
    
    # get length of waveform (should be 3*48k = 144k)
    wave_len = len(waveform)
    
    # Generate normally distributed (Gaussian) noises
    # one for each waveform and multiple (i.e. wave_len*multiples noises)
    noise = np.random.normal(size=(multiples, wave_len))
    
    # Normalize waveform and noise
    norm_constant = 2.0**(bits-1)
    norm_wave = waveform / norm_constant
    norm_noise = noise / norm_constant
    
    # Compute power of waveform and power of noise
    signal_power = np.sum(norm_wave ** 2) / wave_len
    noise_power = np.sum(norm_noise ** 2, axis=1) / wave_len
    
    # Choose random SNR in decibels in range [15,30]
    snr = np.random.randint(snr_min, snr_max)
    
    # Apply whitening transformation: make the Gaussian noise into Gaussian white noise
    # Compute the covariance matrix used to whiten each noise 
    # actual SNR = signal/noise (power)
    # actual noise power = 10**(-snr/10)
    covariance = np.sqrt((signal_power / noise_power) * 10 ** (- snr / 10))
    # Get covariance matrix with dim: (144000, 2) so we can transform 2 noises: dim (2, 144000)
    covariance = np.ones((wave_len, multiples)) * covariance

    # Since covariance and noise are arrays, * is the haddamard product 
    # Take Haddamard product of covariance and noise to generate white noise
    multiple_augmented_waveforms = waveform + covariance.T * noise
    
    return multiple_augmented_waveforms
def augment_waveforms(waveforms, features, emotions, multiples):
    # keep track of how many waveforms we've processed so we can add correct emotion label in the same order
    emotion_count = 0
    # keep track of how many augmented samples we've added
    added_count = 0
    # convert emotion array to list for more efficient appending
    emotions = emotions.tolist()

    for waveform in waveforms:

        # Generate 2 augmented multiples of the dataset, i.e. 1440 native + 1440*2 noisy = 4320 samples total
        augmented_waveforms = awgn_augmentation(waveform, multiples=multiples)

        # compute spectrogram for each of 2 augmented waveforms
        for augmented_waveform in augmented_waveforms:

            # Compute MFCCs over augmented waveforms
            augmented_mfcc = feature_mfcc(augmented_waveform, sample_rate=sample_rate)

            # append the augmented spectrogram to the rest of the native data
            features.append(augmented_mfcc)
            emotions.append(emotions[emotion_count])

            # keep track of new augmented samples
            added_count += 1

            # check progress
            print('\r'+f'Processed {emotion_count + 1}/{len(waveforms)} waveforms for {added_count}/{len(waveforms)*multiples} new augmented samples',end='')

        # keep track of the emotion labels to append in order
        emotion_count += 1
        
        # store augmented waveforms to check their shape
        augmented_waveforms_temp.append(augmented_waveforms)
    
    return features, emotions

# %%
# store augmented waveforms to verify their shape and random-ness
augmented_waveforms_temp = []

# specify multiples of our dataset to add as augmented data
multiples = 2

print('Train waveforms:') # augment waveforms of training set
features_train , y_train = augment_waveforms(X_train, features_train, y_train, multiples)


# Check new shape of extracted features and data:
print(f'\n\nNative + Augmented Features set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'{len(y_train)} training sample labels, {len(y_valid)} validation sample labels, {len(y_test)} test sample labels')
print(f'Features (MFCC matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
# Processed 1500/1500 waveforms for 3000/3000 new augmented samples
#
# Native + Augmented Features set: 4880 total, 4500 train, 190 validation, 190 test samples
# 4500 training sample labels, 190 validation sample labels, 190 test sample labels
# Features (MFCC matrix) shape: 40 mel frequency coefficients x 282 time steps

# %%
# need to make dummy input channel for CNN input feature tensor
X_train = np.expand_dims(features_train,1)
X_valid = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test,1)

# convert emotion labels from list back to numpy arrays for PyTorch to work with 
y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)

# confiorm that we have tensor-ready 4D data array
# should print (batch, channel, width, height) == (4320, 1, 128, 282) when multiples==2
print(f'Shape of 4D feature array for input tensor: {X_train.shape} train, {X_valid.shape} validation, {X_test.shape} test')
print(f'Shape of emotion labels: {y_train.shape} train, {y_valid.shape} validation, {y_test.shape} test')
# Out:
# Shape of 4D feature array for input tensor: (4500, 1, 40, 282) train, (190, 1, 40, 282) validation, (190, 1, 40, 282) test
# Shape of emotion labels: (4500,) train, (190,) validation, (190,) test

# %%
# free up some RAM - no longer need full feature set or any waveforms 
del features_train, features_valid, features_test, waveforms, augmented_waveforms_temp

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#### Scale the training data ####
# store shape so we can transform it back 
N,C,H,W = X_train.shape
# Reshape to 1D because StandardScaler operates on a 1D array
# tell numpy to infer shape of 1D array with '-1' argument
X_train = np.reshape(X_train, (N,-1)) 
X_train = scaler.fit_transform(X_train)
# Transform back to NxCxHxW 4D tensor format
X_train = np.reshape(X_train, (N,C,H,W))

##### Scale the validation set ####
N,C,H,W = X_valid.shape
X_valid = np.reshape(X_valid, (N,-1))
X_valid = scaler.transform(X_valid)
X_valid = np.reshape(X_valid, (N,C,H,W))

#### Scale the test set ####
N,C,H,W = X_test.shape
X_test = np.reshape(X_test, (N,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, (N,C,H,W))

# check shape of each set again
print(f'X_train scaled:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid scaled:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test scaled:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train scaled:(4500, 1, 40, 282), y_train:(4500,)
# X_valid scaled:(190, 1, 40, 282), y_valid:(190,)
# X_test scaled:(190, 1, 40, 282), y_test:(190,)

# %%
###### SAVE #########
# choose save file name 
filename = 'features+labels.npy'

# open file in write mode and write data
with open(filename, 'wb') as f:
    np.save(f, X_train)
    np.save(f, X_valid)
    np.save(f, X_test)
    np.save(f, y_train)
    np.save(f, y_valid)
    np.save(f, y_test)

print(f'Features and labels saved to {filename}')
# Out:
# Features and labels saved to features+labels.npy

# %%
##### LOAD #########
# choose load file name 
filename = 'features+labels.npy'

# open file in read mode and read data 
with open(filename, 'rb') as f:
    X_train = np.load(f)
    X_valid = np.load(f)
    X_test = np.load(f)
    y_train = np.load(f)
    y_valid = np.load(f)
    y_test = np.load(f)

# Check that we've recovered the right data
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train:(4500, 1, 40, 282), y_train:(4500,)
# X_valid:(190, 1, 40, 282), y_valid:(190,)
# X_test:(190, 1, 40, 282), y_test:(190,)

# %%
#change nn.sequential to take dict to make more readable 

class parallel_all_you_want(nn.Module):
    # Define all layers present in the network
    def __init__(self,num_emotions):
        super().__init__() 
        
        ################ TRANSFORMER BLOCK #############################
        # maxpool the input feature map/tensor to the transformer 
        # a rectangular kernel worked better here for the rectangular input spectrogram feature map/tensor
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1,4], stride=[1,4])
        
        # define single transformer encoder layer
        # self-attention + feedforward network from "Attention is All You Need" paper
        # 4 multi-head self-attention layers each with 40-->512--->40 feedforward network
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40, # input feature (frequency) dim after maxpooling 40*282 -> 40*70 (MFC*time)
            nhead=4, # 4 self-attention layers in each multi-head self-attention layer in each encoder block
            dim_feedforward=320, # 2 linear layers in each encoder block's feedforward network: dim 40-->512--->40
            dropout=0.4, 
            activation='relu' # ReLU: avoid saturation/tame gradient/reduce compute time
        )
        
        # I'm using 4 instead of the 6 identical stacked encoder layrs used in Attention is All You Need paper
        # Complete transformer block contains 4 full transformer encoder layers (each w/ multihead self-attention+feedforward)
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=4)
        
        ############### 1ST PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock1 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        ############### 2ND PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock2 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )

        ################# FINAL LINEAR BLOCK ####################
        # Linear softmax layer to take final concatenated embedding tensor 
        #    from parallel 2D convolutional and transformer blocks, output 8 logits 
        # Each full convolution block outputs (64*1*8) embedding flattened to dim 512 1D array 
        # Full transformer block outputs 40*70 feature map, which we time-avg to dim 40 1D array
        # 512*2+40 == 1064 input features --> 8 output emotions 
        self.fc1_linear = nn.Linear(320*2+424,num_emotions) 
        
        ### Softmax layer for the 8 output logits from final FC linear layer 
        self.softmax_out = nn.Softmax(dim=1) # dim==1 is the freq embedding
        
    # define one complete parallel fwd pass of input feature tensor thru 2*conv+1*transformer blocks
    def forward(self,x):
        
        ############ 1st parallel Conv2D block: 4 Convolutional layers ############################
        # create final feature embedding from 1st convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding1 = self.conv2Dblock1(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding1 = torch.flatten(conv2d_embedding1, start_dim=1) 
        
        ############ 2nd parallel Conv2D block: 4 Convolutional layers #############################
        # create final feature embedding from 2nd convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding2 = self.conv2Dblock2(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding2 = torch.flatten(conv2d_embedding2, start_dim=1) 
        
         
        ########## 4-encoder-layer Transformer block w/ 40-->512-->40 feedfwd network ##############
        # maxpool input feature map: 1*40*282 w/ 1*4 kernel --> 1*40*70
        x_maxpool = self.transformer_maxpool(x)

        # remove channel dim: 1*40*70 --> 40*70
        x_maxpool_reduced = torch.squeeze(x_maxpool,1)
        
        # convert maxpooled feature map format: batch * freq * time ---> time * batch * freq format
        # because transformer encoder layer requires tensor in format: time * batch * embedding (freq)
        x = x_maxpool_reduced.permute(2,0,1) 
        
        # finally, pass reduced input feature map x into transformer encoder layers
        transformer_output = self.transformer_encoder(x)
        
        # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
        # transformer outputs 2x40 (MFCC embedding*time) feature map, take mean of columns i.e. take time average
        transformer_embedding = torch.mean(transformer_output, dim=0) # dim 40x70 --> 40
        
        ############# concatenate freq embeddings from convolutional and transformer blocks ######
        # concatenate embedding tensors output by parallel 2*conv and 1*transformer blocks
        complete_embedding = torch.cat([conv2d_embedding1, conv2d_embedding2,transformer_embedding], dim=1)  

        ######### final FC linear layer, need logits for loss #########################
        output_logits = self.fc1_linear(complete_embedding)  
        
        ######### Final Softmax layer: use logits from FC linear, get softmax for prediction ######
        output_softmax = self.softmax_out(output_logits)
        
        # need output logits to compute cross entropy loss, need softmax probabilities to predict class
        return output_logits, output_softmax

# %%
from torchsummary import summary

# need device to instantiate model
device = 'cuda'

# instantiate model for 8 emotions and move to GPU 
model = parallel_all_you_want(len(emotions_dict)).to(device)

# include input feature map dims in call to summary()
#summary(model,(1,1,1))

# %%
# define loss function; CrossEntropyLoss() fairly standard for multiclass problems 
def criterion(predictions, targets): 
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# %%
# define function to create a single step of the training phase
def make_train_step(model, criterion, optimizer):
    
    # define the training step of the training phase
    def train_step(X,Y):
        
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        
        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y) 
        
        # compute gradients for the optimizer to use 
        loss.backward()
        
        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()
        
        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad() 
        
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,criterion):
    def validate(X,Y):
        
        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase: 
        with torch.no_grad(): 
            
            # set model to validation phase i.e. turn off dropout and batchnorm layers 
            model.eval()
      
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            
            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits,Y)
            
        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint(): 
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint

def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
# get training set size to calculate # iterations and minibatch indices
train_size = X_train.shape[0]

# pick minibatch size (of 32... always)
minibatch = 32

# set device to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'{device} selected')

# instantiate model and move to GPU for training
model = parallel_all_you_want(num_emotions=len(emotions_dict)).to(device) 
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )

# encountered bugs in google colab only, unless I explicitly defined optimizer in this cell...
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# instantiate the checkpoint save function
save_checkpoint = make_save_checkpoint()

# instantiate the training step function 
train_step = make_train_step(model, criterion, optimizer=optimizer)

# instantiate the validation loop function
validate = make_validate_fnc(model,criterion)

# instantiate lists to hold scalar performance metrics to plot later
train_losses=[]
valid_losses = []

# create training loop for one complete epoch (entire training set)
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):

    for epoch in range(num_epochs):
        
        # set model to train phase
        model.train()         
        
        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size) 
        
        # shuffle the training set for each epoch:
        X_train = X_train[train_indices,:,:,:] 
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate 
        epoch_acc = 0 
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)
        
        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):
            
            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch 
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size) 
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start 
            
            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:] 
            # get training minibatch labels 
            Y = Y_train[batch_start:batch_end] 

            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float() 
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor,Y_tensor) 
            
            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size
            
            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}',end='')
        
        # create tensors from validation set
        X_valid_tensor = torch.tensor(X_valid,device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor,Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
                  
        # Save checkpoint of the model
        #checkpoint_filename = '/content/gdrive/My Drive/DL/models/checkpoints/parallel_all_you_wantFINAL-{:03d}.pkl'.format(epoch)
        checkpoint_filename = 'checkpoint/parallel_all_you_wantFINAL-{:03d}.pkl'.format(epoch)
        save_checkpoint(optimizer, model, epoch, checkpoint_filename)
        
        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')
# Out:
# cuda selected
# Number of trainable params:  183085

# %%
# choose number of epochs higher than reasonable so we can manually stop training 
num_epochs = 350

# train it!
train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
# Out:
# Epoch 0: iteration 139/140
# Epoch 0 --- loss:2.214, Epoch accuracy:34.96%, Validation loss:1.568, Validation accuracy:42.11%
# Epoch 1: iteration 139/140
# Epoch 1 --- loss:1.190, Epoch accuracy:49.76%, Validation loss:1.426, Validation accuracy:48.95%
# Epoch 2: iteration 139/140
# Epoch 2 --- loss:1.080, Epoch accuracy:54.89%, Validation loss:1.458, Validation accuracy:54.74%
# Epoch 3: iteration 139/140
# Epoch 3 --- loss:0.989, Epoch accuracy:58.87%, Validation loss:1.386, Validation accuracy:52.11%
# Epoch 4: iteration 139/140
# Epoch 4 --- loss:0.886, Epoch accuracy:63.11%, Validation loss:1.168, Validation accuracy:61.58%
# Epoch 5: iteration 139/140
# Epoch 5 --- loss:0.857, Epoch accuracy:64.58%, Validation loss:1.169, Validation accuracy:62.63%
# Epoch 6: iteration 139/140
# Epoch 6 --- loss:0.787, Epoch accuracy:67.89%, Validation loss:1.010, Validation accuracy:64.21%
# Epoch 7: iteration 139/140
# Epoch 7 --- loss:0.729, Epoch accuracy:70.11%, Validation loss:1.055, Validation accuracy:63.16%
# Epoch 8: iteration 139/140
# Epoch 8 --- loss:0.707, Epoch accuracy:71.20%, Validation loss:1.021, Validation accuracy:63.16%
# Epoch 9: iteration 139/140
# Epoch 9 --- loss:0.656, Epoch accuracy:72.96%, Validation loss:1.030, Validation accuracy:66.84%
# Epoch 10: iteration 139/140
# Epoch 10 --- loss:0.624, Epoch accuracy:74.87%, Validation loss:0.956, Validation accuracy:67.89%
# Epoch 11: iteration 139/140
# Epoch 11 --- loss:0.556, Epoch accuracy:77.56%, Validation loss:0.856, Validation accuracy:72.11%
# Epoch 12: iteration 139/140
# Epoch 12 --- loss:0.546, Epoch accuracy:77.64%, Validation loss:0.704, Validation accuracy:74.21%
# Epoch 13: iteration 139/140
# Epoch 13 --- loss:0.499, Epoch accuracy:79.49%, Validation loss:0.746, Validation accuracy:70.53%
# Epoch 14: iteration 139/140
# Epoch 14 --- loss:0.460, Epoch accuracy:81.18%, Validation loss:0.779, Validation accuracy:72.63%
# Epoch 15: iteration 139/140
# Epoch 15 --- loss:0.437, Epoch accuracy:82.56%, Validation loss:0.804, Validation accuracy:72.63%
# Epoch 16: iteration 139/140
# Epoch 16 --- loss:0.433, Epoch accuracy:82.67%, Validation loss:0.721, Validation accuracy:70.53%
# Epoch 17: iteration 139/140
# Epoch 17 --- loss:0.380, Epoch accuracy:84.38%, Validation loss:0.792, Validation accuracy:73.16%
# Epoch 18: iteration 139/140
# Epoch 18 --- loss:0.369, Epoch accuracy:85.00%, Validation loss:0.803, Validation accuracy:71.05%
# Epoch 19: iteration 139/140
# Epoch 19 --- loss:0.348, Epoch accuracy:85.73%, Validation loss:0.687, Validation accuracy:76.84%
# Epoch 20: iteration 139/140
# Epoch 20 --- loss:0.352, Epoch accuracy:85.71%, Validation loss:0.726, Validation accuracy:73.68%
# Epoch 21: iteration 139/140
# Epoch 21 --- loss:0.326, Epoch accuracy:87.18%, Validation loss:0.959, Validation accuracy:68.95%
# Epoch 22: iteration 139/140
# Epoch 22 --- loss:0.320, Epoch accuracy:86.69%, Validation loss:0.790, Validation accuracy:74.21%
# Epoch 23: iteration 139/140
# Epoch 23 --- loss:0.278, Epoch accuracy:88.84%, Validation loss:0.718, Validation accuracy:78.95%
# Epoch 24: iteration 139/140
# Epoch 24 --- loss:0.282, Epoch accuracy:88.44%, Validation loss:0.879, Validation accuracy:73.68%
# Epoch 25: iteration 139/140
# Epoch 25 --- loss:0.264, Epoch accuracy:89.51%, Validation loss:0.871, Validation accuracy:71.58%
# Epoch 26: iteration 139/140
# Epoch 26 --- loss:0.242, Epoch accuracy:90.24%, Validation loss:0.734, Validation accuracy:74.74%
# Epoch 27: iteration 139/140
# Epoch 27 --- loss:0.232, Epoch accuracy:90.64%, Validation loss:0.713, Validation accuracy:77.37%
# Epoch 28: iteration 139/140
# Epoch 28 --- loss:0.225, Epoch accuracy:91.04%, Validation loss:0.837, Validation accuracy:76.32%
# Epoch 29: iteration 139/140
# Epoch 29 --- loss:0.207, Epoch accuracy:91.76%, Validation loss:0.886, Validation accuracy:73.68%
# Epoch 30: iteration 139/140
# Epoch 30 --- loss:0.221, Epoch accuracy:91.42%, Validation loss:0.739, Validation accuracy:77.37%
# Epoch 31: iteration 139/140
# Epoch 31 --- loss:0.216, Epoch accuracy:91.64%, Validation loss:0.819, Validation accuracy:75.79%
# Epoch 32: iteration 139/140
# Epoch 32 --- loss:0.190, Epoch accuracy:92.62%, Validation loss:0.839, Validation accuracy:77.89%
# Epoch 33: iteration 139/140
# Epoch 33 --- loss:0.172, Epoch accuracy:93.58%, Validation loss:0.934, Validation accuracy:74.74%
# Epoch 34: iteration 139/140
# Epoch 34 --- loss:0.176, Epoch accuracy:92.82%, Validation loss:0.998, Validation accuracy:76.32%
# Epoch 35: iteration 139/140
# Epoch 35 --- loss:0.201, Epoch accuracy:92.24%, Validation loss:1.008, Validation accuracy:74.21%
# Epoch 36: iteration 139/140
# Epoch 36 --- loss:0.162, Epoch accuracy:93.20%, Validation loss:0.859, Validation accuracy:75.26%
# Epoch 37: iteration 139/140
# Epoch 37 --- loss:0.182, Epoch accuracy:92.80%, Validation loss:0.944, Validation accuracy:75.79%
# Epoch 38: iteration 139/140
# Epoch 38 --- loss:0.150, Epoch accuracy:94.02%, Validation loss:0.927, Validation accuracy:74.74%
# Epoch 39: iteration 139/140
# Epoch 39 --- loss:0.169, Epoch accuracy:93.27%, Validation loss:0.914, Validation accuracy:77.89%
# Epoch 40: iteration 139/140
# Epoch 40 --- loss:0.141, Epoch accuracy:94.49%, Validation loss:0.995, Validation accuracy:76.32%
# Epoch 41: iteration 139/140
# Epoch 41 --- loss:0.161, Epoch accuracy:93.18%, Validation loss:0.881, Validation accuracy:75.26%
# Epoch 42: iteration 139/140
# Epoch 42 --- loss:0.142, Epoch accuracy:94.27%, Validation loss:1.075, Validation accuracy:72.63%
# Epoch 43: iteration 139/140
# Epoch 43 --- loss:0.125, Epoch accuracy:95.13%, Validation loss:0.798, Validation accuracy:77.37%
# Epoch 44: iteration 139/140
# Epoch 44 --- loss:0.121, Epoch accuracy:95.16%, Validation loss:0.898, Validation accuracy:74.74%
# Epoch 45: iteration 139/140
# Epoch 45 --- loss:0.120, Epoch accuracy:95.31%, Validation loss:1.035, Validation accuracy:74.74%
# Epoch 46: iteration 139/140
# Epoch 46 --- loss:0.139, Epoch accuracy:94.56%, Validation loss:0.863, Validation accuracy:75.79%
# Epoch 47: iteration 139/140
# Epoch 47 --- loss:0.124, Epoch accuracy:95.29%, Validation loss:1.002, Validation accuracy:74.74%
# Epoch 48: iteration 139/140
# Epoch 48 --- loss:0.098, Epoch accuracy:96.24%, Validation loss:0.849, Validation accuracy:74.21%
# Epoch 49: iteration 139/140
# Epoch 49 --- loss:0.104, Epoch accuracy:96.11%, Validation loss:0.977, Validation accuracy:75.79%
# Epoch 50: iteration 139/140
# Epoch 50 --- loss:0.104, Epoch accuracy:95.96%, Validation loss:0.976, Validation accuracy:73.68%
# Epoch 51: iteration 139/140
# Epoch 51 --- loss:0.100, Epoch accuracy:95.89%, Validation loss:0.983, Validation accuracy:76.32%
# Epoch 52: iteration 139/140
# Epoch 52 --- loss:0.092, Epoch accuracy:96.38%, Validation loss:1.174, Validation accuracy:73.68%
# Epoch 53: iteration 139/140
# Epoch 53 --- loss:0.101, Epoch accuracy:95.91%, Validation loss:0.920, Validation accuracy:80.53%
# Epoch 54: iteration 139/140
# Epoch 54 --- loss:0.096, Epoch accuracy:96.47%, Validation loss:0.937, Validation accuracy:77.37%
# Epoch 55: iteration 139/140
# Epoch 55 --- loss:0.090, Epoch accuracy:96.51%, Validation loss:0.916, Validation accuracy:80.00%
# Epoch 56: iteration 139/140
# Epoch 56 --- loss:0.089, Epoch accuracy:96.31%, Validation loss:0.943, Validation accuracy:75.79%
# Epoch 57: iteration 139/140
# Epoch 57 --- loss:0.076, Epoch accuracy:96.98%, Validation loss:1.133, Validation accuracy:73.68%
# Epoch 58: iteration 139/140
# Epoch 58 --- loss:0.088, Epoch accuracy:96.62%, Validation loss:1.077, Validation accuracy:77.37%
# Epoch 59: iteration 139/140
# Epoch 59 --- loss:0.097, Epoch accuracy:95.98%, Validation loss:1.145, Validation accuracy:73.16%
# Epoch 60: iteration 139/140
# Epoch 60 --- loss:0.088, Epoch accuracy:96.64%, Validation loss:0.921, Validation accuracy:77.37%
# Epoch 61: iteration 139/140
# Epoch 61 --- loss:0.061, Epoch accuracy:97.60%, Validation loss:1.105, Validation accuracy:74.74%
# Epoch 62: iteration 139/140
# Epoch 62 --- loss:0.083, Epoch accuracy:96.76%, Validation loss:0.713, Validation accuracy:80.53%
# Epoch 63: iteration 139/140
# Epoch 63 --- loss:0.084, Epoch accuracy:96.42%, Validation loss:0.868, Validation accuracy:76.84%
# Epoch 64: iteration 139/140
# Epoch 64 --- loss:0.061, Epoch accuracy:97.47%, Validation loss:0.981, Validation accuracy:80.00%
# Epoch 65: iteration 139/140
# Epoch 65 --- loss:0.068, Epoch accuracy:97.18%, Validation loss:0.882, Validation accuracy:78.42%
# Epoch 66: iteration 139/140
# Epoch 66 --- loss:0.062, Epoch accuracy:97.51%, Validation loss:0.927, Validation accuracy:77.89%
# Epoch 67: iteration 139/140
# Epoch 67 --- loss:0.084, Epoch accuracy:96.58%, Validation loss:0.968, Validation accuracy:75.79%
# Epoch 68: iteration 139/140
# Epoch 68 --- loss:0.064, Epoch accuracy:97.56%, Validation loss:0.834, Validation accuracy:78.95%
# Epoch 69: iteration 139/140
# Epoch 69 --- loss:0.074, Epoch accuracy:96.89%, Validation loss:0.879, Validation accuracy:76.84%
# Epoch 70: iteration 139/140
# Epoch 70 --- loss:0.052, Epoch accuracy:97.98%, Validation loss:0.858, Validation accuracy:78.95%
# Epoch 71: iteration 139/140
# Epoch 71 --- loss:0.079, Epoch accuracy:96.76%, Validation loss:0.970, Validation accuracy:77.89%
# Epoch 72: iteration 139/140
# Epoch 72 --- loss:0.093, Epoch accuracy:96.40%, Validation loss:0.876, Validation accuracy:77.37%
# Epoch 73: iteration 139/140
# Epoch 73 --- loss:0.074, Epoch accuracy:97.04%, Validation loss:0.880, Validation accuracy:78.42%
# Epoch 74: iteration 139/140
# Epoch 74 --- loss:0.052, Epoch accuracy:98.20%, Validation loss:1.003, Validation accuracy:78.42%
# Epoch 75: iteration 139/140
# Epoch 75 --- loss:0.046, Epoch accuracy:98.29%, Validation loss:0.897, Validation accuracy:78.42%
# Epoch 76: iteration 139/140
# Epoch 76 --- loss:0.061, Epoch accuracy:97.87%, Validation loss:0.787, Validation accuracy:80.00%
# Epoch 77: iteration 139/140
# Epoch 77 --- loss:0.092, Epoch accuracy:96.33%, Validation loss:0.993, Validation accuracy:77.37%
# Epoch 78: iteration 139/140
# Epoch 78 --- loss:0.057, Epoch accuracy:97.67%, Validation loss:0.879, Validation accuracy:80.00%
# Epoch 79: iteration 139/140
# Epoch 79 --- loss:0.072, Epoch accuracy:96.91%, Validation loss:0.919, Validation accuracy:77.37%
# Epoch 80: iteration 139/140
# Epoch 80 --- loss:0.057, Epoch accuracy:97.84%, Validation loss:0.906, Validation accuracy:79.47%
# Epoch 81: iteration 139/140
# Epoch 81 --- loss:0.042, Epoch accuracy:98.11%, Validation loss:1.019, Validation accuracy:76.32%
# Epoch 82: iteration 139/140
# Epoch 82 --- loss:0.055, Epoch accuracy:97.93%, Validation loss:0.943, Validation accuracy:77.37%
# Epoch 83: iteration 139/140
# Epoch 83 --- loss:0.070, Epoch accuracy:97.11%, Validation loss:0.885, Validation accuracy:76.84%
# Epoch 84: iteration 139/140
# Epoch 84 --- loss:0.059, Epoch accuracy:97.49%, Validation loss:0.918, Validation accuracy:78.95%
# Epoch 85: iteration 139/140
# Epoch 85 --- loss:0.056, Epoch accuracy:97.78%, Validation loss:0.944, Validation accuracy:78.95%
# Epoch 86: iteration 139/140
# Epoch 86 --- loss:0.043, Epoch accuracy:98.31%, Validation loss:0.968, Validation accuracy:80.00%
# Epoch 87: iteration 139/140
# Epoch 87 --- loss:0.047, Epoch accuracy:98.18%, Validation loss:0.896, Validation accuracy:81.05%
# Epoch 88: iteration 139/140
# Epoch 88 --- loss:0.035, Epoch accuracy:98.62%, Validation loss:0.894, Validation accuracy:78.95%
# Epoch 89: iteration 139/140
# Epoch 89 --- loss:0.050, Epoch accuracy:97.89%, Validation loss:1.087, Validation accuracy:76.84%
# Epoch 90: iteration 139/140
# Epoch 90 --- loss:0.047, Epoch accuracy:98.16%, Validation loss:0.898, Validation accuracy:80.53%
# Epoch 91: iteration 139/140
# Epoch 91 --- loss:0.053, Epoch accuracy:97.71%, Validation loss:0.944, Validation accuracy:79.47%
# Epoch 92: iteration 139/140
# Epoch 92 --- loss:0.054, Epoch accuracy:97.96%, Validation loss:0.896, Validation accuracy:78.95%
# Epoch 93: iteration 139/140
# Epoch 93 --- loss:0.051, Epoch accuracy:97.93%, Validation loss:0.933, Validation accuracy:79.47%
# Epoch 94: iteration 139/140
# Epoch 94 --- loss:0.058, Epoch accuracy:97.62%, Validation loss:0.942, Validation accuracy:79.47%
# Epoch 95: iteration 139/140
# Epoch 95 --- loss:0.048, Epoch accuracy:97.73%, Validation loss:1.096, Validation accuracy:81.05%
# Epoch 96: iteration 139/140
# Epoch 96 --- loss:0.039, Epoch accuracy:98.24%, Validation loss:1.268, Validation accuracy:75.26%
# Epoch 97: iteration 139/140
# Epoch 97 --- loss:0.080, Epoch accuracy:96.76%, Validation loss:0.909, Validation accuracy:78.42%
# Epoch 98: iteration 139/140
# Epoch 98 --- loss:0.041, Epoch accuracy:98.36%, Validation loss:1.098, Validation accuracy:77.37%
# Epoch 99: iteration 139/140
# Epoch 99 --- loss:0.066, Epoch accuracy:97.38%, Validation loss:0.970, Validation accuracy:78.95%
# Epoch 100: iteration 139/140
# Epoch 100 --- loss:0.045, Epoch accuracy:98.20%, Validation loss:1.040, Validation accuracy:77.89%
# Epoch 101: iteration 139/140
# Epoch 101 --- loss:0.050, Epoch accuracy:97.93%, Validation loss:1.136, Validation accuracy:76.84%
# Epoch 102: iteration 139/140
# Epoch 102 --- loss:0.034, Epoch accuracy:98.60%, Validation loss:0.878, Validation accuracy:80.00%
# Epoch 103: iteration 139/140
# Epoch 103 --- loss:0.047, Epoch accuracy:98.09%, Validation loss:0.903, Validation accuracy:80.00%
# Epoch 104: iteration 139/140
# Epoch 104 --- loss:0.083, Epoch accuracy:96.78%, Validation loss:0.953, Validation accuracy:78.95%
# Epoch 105: iteration 139/140
# Epoch 105 --- loss:0.053, Epoch accuracy:97.89%, Validation loss:0.929, Validation accuracy:77.37%
# Epoch 106: iteration 139/140
# Epoch 106 --- loss:0.034, Epoch accuracy:98.76%, Validation loss:0.784, Validation accuracy:80.00%
# Epoch 107: iteration 139/140
# Epoch 107 --- loss:0.053, Epoch accuracy:97.89%, Validation loss:0.944, Validation accuracy:77.89%
# Epoch 108: iteration 139/140
# Epoch 108 --- loss:0.050, Epoch accuracy:97.80%, Validation loss:0.931, Validation accuracy:78.42%
# Epoch 109: iteration 139/140
# Epoch 109 --- loss:0.025, Epoch accuracy:98.87%, Validation loss:0.911, Validation accuracy:80.00%
# Epoch 110: iteration 139/140
# Epoch 110 --- loss:0.032, Epoch accuracy:98.49%, Validation loss:0.968, Validation accuracy:80.53%
# Epoch 111: iteration 139/140
# Epoch 111 --- loss:0.028, Epoch accuracy:98.82%, Validation loss:1.095, Validation accuracy:75.26%
# Epoch 112: iteration 139/140
# Epoch 112 --- loss:0.051, Epoch accuracy:97.98%, Validation loss:0.902, Validation accuracy:77.89%
# Epoch 113: iteration 139/140
# Epoch 113 --- loss:0.092, Epoch accuracy:96.18%, Validation loss:1.019, Validation accuracy:76.84%
# Epoch 114: iteration 139/140
# Epoch 114 --- loss:0.047, Epoch accuracy:98.24%, Validation loss:0.956, Validation accuracy:79.47%
# Epoch 115: iteration 139/140
# Epoch 115 --- loss:0.043, Epoch accuracy:98.24%, Validation loss:0.895, Validation accuracy:81.05%
# Epoch 116: iteration 139/140
# Epoch 116 --- loss:0.031, Epoch accuracy:98.80%, Validation loss:0.964, Validation accuracy:77.37%
# Epoch 117: iteration 139/140
# Epoch 117 --- loss:0.047, Epoch accuracy:98.02%, Validation loss:1.027, Validation accuracy:77.89%
# Epoch 118: iteration 139/140
# Epoch 118 --- loss:0.046, Epoch accuracy:98.07%, Validation loss:0.881, Validation accuracy:79.47%
# Epoch 119: iteration 139/140
# Epoch 119 --- loss:0.036, Epoch accuracy:98.36%, Validation loss:0.929, Validation accuracy:77.37%
# Epoch 120: iteration 139/140
# Epoch 120 --- loss:0.053, Epoch accuracy:97.84%, Validation loss:0.972, Validation accuracy:78.95%
# Epoch 121: iteration 139/140
# Epoch 121 --- loss:0.033, Epoch accuracy:98.67%, Validation loss:0.959, Validation accuracy:80.53%
# Epoch 122: iteration 139/140
# Epoch 122 --- loss:0.032, Epoch accuracy:98.53%, Validation loss:0.990, Validation accuracy:80.00%
# Epoch 123: iteration 139/140
# Epoch 123 --- loss:0.057, Epoch accuracy:97.47%, Validation loss:1.358, Validation accuracy:73.16%
# Epoch 124: iteration 139/140
# Epoch 124 --- loss:0.052, Epoch accuracy:97.91%, Validation loss:0.944, Validation accuracy:81.05%
# Epoch 125: iteration 139/140
# Epoch 125 --- loss:0.037, Epoch accuracy:98.36%, Validation loss:0.768, Validation accuracy:81.58%
# Epoch 126: iteration 139/140
# Epoch 126 --- loss:0.034, Epoch accuracy:98.36%, Validation loss:1.010, Validation accuracy:80.00%
# Epoch 127: iteration 139/140
# Epoch 127 --- loss:0.028, Epoch accuracy:98.84%, Validation loss:1.196, Validation accuracy:76.84%
# Epoch 128: iteration 139/140
# Epoch 128 --- loss:0.024, Epoch accuracy:98.96%, Validation loss:1.037, Validation accuracy:78.95%
# Epoch 129: iteration 139/140
# Epoch 129 --- loss:0.052, Epoch accuracy:97.62%, Validation loss:0.987, Validation accuracy:77.89%
# Epoch 130: iteration 139/140
# Epoch 130 --- loss:0.061, Epoch accuracy:97.38%, Validation loss:0.971, Validation accuracy:77.37%
# Epoch 131: iteration 139/140
# Epoch 131 --- loss:0.047, Epoch accuracy:98.02%, Validation loss:0.994, Validation accuracy:78.42%
# Epoch 132: iteration 139/140
# Epoch 132 --- loss:0.045, Epoch accuracy:98.24%, Validation loss:0.802, Validation accuracy:82.63%
# Epoch 133: iteration 139/140
# Epoch 133 --- loss:0.032, Epoch accuracy:98.80%, Validation loss:0.914, Validation accuracy:77.89%
# Epoch 134: iteration 139/140
# Epoch 134 --- loss:0.050, Epoch accuracy:98.00%, Validation loss:1.028, Validation accuracy:78.95%
# Epoch 135: iteration 139/140
# Epoch 135 --- loss:0.064, Epoch accuracy:97.27%, Validation loss:0.802, Validation accuracy:83.16%
# Epoch 136: iteration 139/140
# Epoch 136 --- loss:0.041, Epoch accuracy:98.36%, Validation loss:0.845, Validation accuracy:81.58%
# Epoch 137: iteration 139/140
# Epoch 137 --- loss:0.043, Epoch accuracy:98.31%, Validation loss:0.812, Validation accuracy:79.47%
# Epoch 138: iteration 139/140
# Epoch 138 --- loss:0.029, Epoch accuracy:98.78%, Validation loss:0.910, Validation accuracy:79.47%
# Epoch 139: iteration 139/140
# Epoch 139 --- loss:0.036, Epoch accuracy:98.49%, Validation loss:0.786, Validation accuracy:80.53%
# Epoch 140: iteration 139/140
# Epoch 140 --- loss:0.022, Epoch accuracy:99.00%, Validation loss:0.882, Validation accuracy:78.42%
# Epoch 141: iteration 139/140
# Epoch 141 --- loss:0.060, Epoch accuracy:97.64%, Validation loss:0.953, Validation accuracy:80.00%
# Epoch 142: iteration 139/140
# Epoch 142 --- loss:0.041, Epoch accuracy:98.36%, Validation loss:0.872, Validation accuracy:80.53%
# Epoch 143: iteration 139/140
# Epoch 143 --- loss:0.030, Epoch accuracy:98.84%, Validation loss:0.917, Validation accuracy:80.53%
# Epoch 144: iteration 139/140
# Epoch 144 --- loss:0.027, Epoch accuracy:98.80%, Validation loss:0.921, Validation accuracy:80.53%
# Epoch 145: iteration 139/140
# Epoch 145 --- loss:0.030, Epoch accuracy:98.64%, Validation loss:1.039, Validation accuracy:77.89%
# Epoch 146: iteration 139/140
# Epoch 146 --- loss:0.034, Epoch accuracy:98.53%, Validation loss:0.950, Validation accuracy:80.53%
# Epoch 147: iteration 139/140
# Epoch 147 --- loss:0.049, Epoch accuracy:97.78%, Validation loss:1.072, Validation accuracy:78.42%
# Epoch 148: iteration 139/140
# Epoch 148 --- loss:0.076, Epoch accuracy:96.96%, Validation loss:1.080, Validation accuracy:80.00%
# Epoch 149: iteration 139/140
# Epoch 149 --- loss:0.057, Epoch accuracy:97.64%, Validation loss:0.914, Validation accuracy:78.95%
# Epoch 150: iteration 139/140
# Epoch 150 --- loss:0.022, Epoch accuracy:99.00%, Validation loss:0.944, Validation accuracy:79.47%
# Epoch 151: iteration 139/140
# Epoch 151 --- loss:0.033, Epoch accuracy:98.64%, Validation loss:1.049, Validation accuracy:75.79%
# Epoch 152: iteration 139/140
# Epoch 152 --- loss:0.080, Epoch accuracy:96.98%, Validation loss:1.036, Validation accuracy:77.89%
# Epoch 153: iteration 139/140
# Epoch 153 --- loss:0.045, Epoch accuracy:98.29%, Validation loss:0.966, Validation accuracy:77.89%
# Epoch 154: iteration 139/140
# Epoch 154 --- loss:0.041, Epoch accuracy:98.02%, Validation loss:1.111, Validation accuracy:77.37%
# Epoch 155: iteration 139/140
# Epoch 155 --- loss:0.024, Epoch accuracy:99.09%, Validation loss:0.886, Validation accuracy:80.53%
# Epoch 156: iteration 139/140
# Epoch 156 --- loss:0.025, Epoch accuracy:98.87%, Validation loss:0.847, Validation accuracy:80.53%
# Epoch 157: iteration 139/140
# Epoch 157 --- loss:0.034, Epoch accuracy:98.58%, Validation loss:0.840, Validation accuracy:80.00%
# Epoch 158: iteration 139/140
# Epoch 158 --- loss:0.022, Epoch accuracy:99.02%, Validation loss:0.905, Validation accuracy:80.53%
# Epoch 159: iteration 139/140
# Epoch 159 --- loss:0.032, Epoch accuracy:98.64%, Validation loss:0.850, Validation accuracy:80.00%
# Epoch 160: iteration 139/140
# Epoch 160 --- loss:0.027, Epoch accuracy:98.93%, Validation loss:0.964, Validation accuracy:78.42%
# Epoch 161: iteration 139/140
# Epoch 161 --- loss:0.026, Epoch accuracy:98.80%, Validation loss:0.864, Validation accuracy:83.16%
# Epoch 162: iteration 139/140
# Epoch 162 --- loss:0.053, Epoch accuracy:97.42%, Validation loss:0.943, Validation accuracy:81.58%
# Epoch 163: iteration 139/140
# Epoch 163 --- loss:0.036, Epoch accuracy:98.47%, Validation loss:1.236, Validation accuracy:74.21%
# Epoch 164: iteration 139/140
# Epoch 164 --- loss:0.047, Epoch accuracy:97.87%, Validation loss:0.881, Validation accuracy:81.58%
# Epoch 165: iteration 139/140
# Epoch 165 --- loss:0.033, Epoch accuracy:98.42%, Validation loss:0.803, Validation accuracy:80.00%
# Epoch 166: iteration 139/140
# Epoch 166 --- loss:0.022, Epoch accuracy:99.18%, Validation loss:0.913, Validation accuracy:81.05%
# Epoch 167: iteration 139/140
# Epoch 167 --- loss:0.033, Epoch accuracy:98.62%, Validation loss:1.129, Validation accuracy:77.89%
# Epoch 168: iteration 139/140
# Epoch 168 --- loss:0.095, Epoch accuracy:96.51%, Validation loss:1.034, Validation accuracy:77.37%
# Epoch 169: iteration 139/140
# Epoch 169 --- loss:0.034, Epoch accuracy:98.51%, Validation loss:0.944, Validation accuracy:77.89%
# Epoch 170: iteration 139/140
# Epoch 170 --- loss:0.031, Epoch accuracy:98.62%, Validation loss:0.994, Validation accuracy:79.47%
# Epoch 171: iteration 139/140
# Epoch 171 --- loss:0.034, Epoch accuracy:98.47%, Validation loss:0.972, Validation accuracy:80.00%
# Epoch 172: iteration 139/140
# Epoch 172 --- loss:0.020, Epoch accuracy:99.11%, Validation loss:0.933, Validation accuracy:80.53%
# Epoch 173: iteration 139/140
# Epoch 173 --- loss:0.028, Epoch accuracy:98.73%, Validation loss:0.837, Validation accuracy:80.53%
# Epoch 174: iteration 139/140
# Epoch 174 --- loss:0.037, Epoch accuracy:98.36%, Validation loss:0.870, Validation accuracy:82.11%
# Epoch 175: iteration 139/140
# Epoch 175 --- loss:0.012, Epoch accuracy:99.49%, Validation loss:0.821, Validation accuracy:82.11%
# Epoch 176: iteration 139/140
# Epoch 176 --- loss:0.041, Epoch accuracy:98.27%, Validation loss:0.992, Validation accuracy:78.95%
# Epoch 177: iteration 139/140
# Epoch 177 --- loss:0.061, Epoch accuracy:97.51%, Validation loss:0.968, Validation accuracy:78.95%
# Epoch 178: iteration 139/140
# Epoch 178 --- loss:0.039, Epoch accuracy:98.29%, Validation loss:0.991, Validation accuracy:80.00%
# Epoch 179: iteration 139/140
# Epoch 179 --- loss:0.039, Epoch accuracy:98.29%, Validation loss:0.907, Validation accuracy:80.53%
# Epoch 180: iteration 139/140
# Epoch 180 --- loss:0.017, Epoch accuracy:99.22%, Validation loss:0.900, Validation accuracy:78.42%
# Epoch 181: iteration 139/140
# Epoch 181 --- loss:0.023, Epoch accuracy:98.98%, Validation loss:0.914, Validation accuracy:81.05%
# Epoch 182: iteration 139/140
# Epoch 182 --- loss:0.046, Epoch accuracy:98.02%, Validation loss:0.896, Validation accuracy:79.47%
# Epoch 183: iteration 139/140
# Epoch 183 --- loss:0.024, Epoch accuracy:98.89%, Validation loss:0.923, Validation accuracy:81.05%
# Epoch 184: iteration 139/140
# Epoch 184 --- loss:0.026, Epoch accuracy:98.76%, Validation loss:1.022, Validation accuracy:77.37%
# Epoch 185: iteration 139/140
# Epoch 185 --- loss:0.017, Epoch accuracy:99.16%, Validation loss:0.982, Validation accuracy:81.05%
# Epoch 186: iteration 139/140
# Epoch 186 --- loss:0.021, Epoch accuracy:99.07%, Validation loss:1.133, Validation accuracy:76.84%
# Epoch 187: iteration 139/140
# Epoch 187 --- loss:0.057, Epoch accuracy:97.51%, Validation loss:1.165, Validation accuracy:78.95%
# Epoch 188: iteration 139/140
# Epoch 188 --- loss:0.045, Epoch accuracy:98.16%, Validation loss:0.862, Validation accuracy:81.58%
# Epoch 189: iteration 139/140
# Epoch 189 --- loss:0.057, Epoch accuracy:97.67%, Validation loss:0.793, Validation accuracy:81.58%
# Epoch 190: iteration 139/140
# Epoch 190 --- loss:0.100, Epoch accuracy:96.09%, Validation loss:0.961, Validation accuracy:80.00%
# Epoch 191: iteration 139/140
# Epoch 191 --- loss:0.037, Epoch accuracy:98.58%, Validation loss:0.916, Validation accuracy:77.89%
# Epoch 192: iteration 139/140
# Epoch 192 --- loss:0.033, Epoch accuracy:98.60%, Validation loss:0.898, Validation accuracy:78.42%
# Epoch 193: iteration 139/140
# Epoch 193 --- loss:0.025, Epoch accuracy:98.87%, Validation loss:0.924, Validation accuracy:80.53%
# Epoch 194: iteration 139/140
# Epoch 194 --- loss:0.041, Epoch accuracy:98.16%, Validation loss:0.832, Validation accuracy:82.63%
# Epoch 195: iteration 139/140
# Epoch 195 --- loss:0.031, Epoch accuracy:98.51%, Validation loss:0.833, Validation accuracy:82.63%
# Epoch 196: iteration 139/140
# Epoch 196 --- loss:0.082, Epoch accuracy:96.93%, Validation loss:0.901, Validation accuracy:82.63%
# Epoch 197: iteration 139/140
# Epoch 197 --- loss:0.035, Epoch accuracy:98.38%, Validation loss:0.874, Validation accuracy:79.47%
# Epoch 198: iteration 139/140
# Epoch 198 --- loss:0.025, Epoch accuracy:98.82%, Validation loss:0.847, Validation accuracy:80.00%
# Epoch 199: iteration 139/140
# Epoch 199 --- loss:0.020, Epoch accuracy:98.89%, Validation loss:0.986, Validation accuracy:81.58%
# Epoch 200: iteration 139/140
# Epoch 200 --- loss:0.026, Epoch accuracy:98.87%, Validation loss:0.978, Validation accuracy:81.05%
# Epoch 201: iteration 139/140
# Epoch 201 --- loss:0.038, Epoch accuracy:98.47%, Validation loss:0.847, Validation accuracy:82.11%
# Epoch 202: iteration 139/140
# Epoch 202 --- loss:0.053, Epoch accuracy:97.69%, Validation loss:0.896, Validation accuracy:82.11%
# Epoch 203: iteration 139/140
# Epoch 203 --- loss:0.045, Epoch accuracy:98.11%, Validation loss:1.005, Validation accuracy:77.89%
# Epoch 204: iteration 139/140
# Epoch 204 --- loss:0.027, Epoch accuracy:98.73%, Validation loss:0.888, Validation accuracy:81.58%
# Epoch 205: iteration 139/140
# Epoch 205 --- loss:0.021, Epoch accuracy:99.02%, Validation loss:0.859, Validation accuracy:82.11%
# Epoch 206: iteration 139/140
# Epoch 206 --- loss:0.091, Epoch accuracy:96.18%, Validation loss:0.925, Validation accuracy:78.95%
# Epoch 207: iteration 139/140
# Epoch 207 --- loss:0.046, Epoch accuracy:97.91%, Validation loss:0.797, Validation accuracy:82.11%
# Epoch 208: iteration 139/140
# Epoch 208 --- loss:0.036, Epoch accuracy:98.31%, Validation loss:1.027, Validation accuracy:79.47%
# Epoch 209: iteration 139/140
# Epoch 209 --- loss:0.034, Epoch accuracy:98.58%, Validation loss:1.087, Validation accuracy:77.37%
# Epoch 210: iteration 139/140
# Epoch 210 --- loss:0.024, Epoch accuracy:98.84%, Validation loss:0.814, Validation accuracy:82.63%
# Epoch 211: iteration 139/140
# Epoch 211 --- loss:0.029, Epoch accuracy:98.82%, Validation loss:1.003, Validation accuracy:78.95%
# Epoch 212: iteration 139/140
# Epoch 212 --- loss:0.043, Epoch accuracy:98.22%, Validation loss:0.998, Validation accuracy:78.95%
# Epoch 213: iteration 139/140
# Epoch 213 --- loss:0.047, Epoch accuracy:97.93%, Validation loss:0.862, Validation accuracy:82.63%
# Epoch 214: iteration 139/140
# Epoch 214 --- loss:0.022, Epoch accuracy:99.04%, Validation loss:0.853, Validation accuracy:81.58%
# Epoch 215: iteration 139/140
# Epoch 215 --- loss:0.063, Epoch accuracy:97.44%, Validation loss:0.875, Validation accuracy:79.47%
# Epoch 216: iteration 139/140
# Epoch 216 --- loss:0.025, Epoch accuracy:98.82%, Validation loss:0.919, Validation accuracy:79.47%
# Epoch 217: iteration 139/140
# Epoch 217 --- loss:0.022, Epoch accuracy:99.04%, Validation loss:0.889, Validation accuracy:81.05%
# Epoch 218: iteration 139/140
# Epoch 218 --- loss:0.016, Epoch accuracy:99.22%, Validation loss:0.979, Validation accuracy:80.00%
# Epoch 219: iteration 139/140
# Epoch 219 --- loss:0.062, Epoch accuracy:97.67%, Validation loss:0.874, Validation accuracy:79.47%
# Epoch 220: iteration 139/140
# Epoch 220 --- loss:0.037, Epoch accuracy:98.51%, Validation loss:0.812, Validation accuracy:82.11%
# Epoch 221: iteration 139/140
# Epoch 221 --- loss:0.024, Epoch accuracy:98.98%, Validation loss:0.921, Validation accuracy:79.47%
# Epoch 222: iteration 139/140
# Epoch 222 --- loss:0.034, Epoch accuracy:98.42%, Validation loss:1.173, Validation accuracy:75.79%
# Epoch 223: iteration 139/140
# Epoch 223 --- loss:0.039, Epoch accuracy:98.31%, Validation loss:0.914, Validation accuracy:77.37%
# Epoch 224: iteration 139/140
# Epoch 224 --- loss:0.030, Epoch accuracy:98.58%, Validation loss:1.027, Validation accuracy:77.89%
# Epoch 225: iteration 139/140
# Epoch 225 --- loss:0.014, Epoch accuracy:99.22%, Validation loss:0.888, Validation accuracy:81.05%
# Epoch 226: iteration 139/140
# Epoch 226 --- loss:0.018, Epoch accuracy:99.20%, Validation loss:0.868, Validation accuracy:80.00%
# Epoch 227: iteration 139/140
# Epoch 227 --- loss:0.035, Epoch accuracy:98.49%, Validation loss:0.947, Validation accuracy:81.05%
# Epoch 228: iteration 139/140
# Epoch 228 --- loss:0.063, Epoch accuracy:97.42%, Validation loss:1.088, Validation accuracy:79.47%
# Epoch 229: iteration 139/140
# Epoch 229 --- loss:0.018, Epoch accuracy:99.20%, Validation loss:0.937, Validation accuracy:82.11%
# Epoch 230: iteration 139/140
# Epoch 230 --- loss:0.026, Epoch accuracy:98.82%, Validation loss:1.073, Validation accuracy:78.95%
# Epoch 231: iteration 139/140
# Epoch 231 --- loss:0.030, Epoch accuracy:98.71%, Validation loss:1.065, Validation accuracy:80.00%
# Epoch 232: iteration 139/140
# Epoch 232 --- loss:0.032, Epoch accuracy:98.51%, Validation loss:1.263, Validation accuracy:73.68%
# Epoch 233: iteration 139/140
# Epoch 233 --- loss:0.053, Epoch accuracy:97.56%, Validation loss:0.979, Validation accuracy:78.42%
# Epoch 234: iteration 139/140
# Epoch 234 --- loss:0.082, Epoch accuracy:96.53%, Validation loss:1.021, Validation accuracy:78.42%
# Epoch 235: iteration 139/140
# Epoch 235 --- loss:0.039, Epoch accuracy:98.27%, Validation loss:0.825, Validation accuracy:83.16%
# Epoch 236: iteration 139/140
# Epoch 236 --- loss:0.017, Epoch accuracy:99.13%, Validation loss:0.895, Validation accuracy:80.53%
# Epoch 237: iteration 139/140
# Epoch 237 --- loss:0.025, Epoch accuracy:98.89%, Validation loss:1.286, Validation accuracy:78.95%
# Epoch 238: iteration 139/140
# Epoch 238 --- loss:0.027, Epoch accuracy:98.82%, Validation loss:1.042, Validation accuracy:76.84%
# Epoch 239: iteration 139/140
# Epoch 239 --- loss:0.050, Epoch accuracy:97.76%, Validation loss:1.055, Validation accuracy:77.89%
# Epoch 240: iteration 139/140
# Epoch 240 --- loss:0.042, Epoch accuracy:98.24%, Validation loss:1.017, Validation accuracy:80.00%
# Epoch 241: iteration 139/140
# Epoch 241 --- loss:0.037, Epoch accuracy:98.53%, Validation loss:0.933, Validation accuracy:78.42%
# Epoch 242: iteration 139/140
# Epoch 242 --- loss:0.031, Epoch accuracy:98.60%, Validation loss:0.953, Validation accuracy:81.58%
# Epoch 243: iteration 139/140
# Epoch 243 --- loss:0.023, Epoch accuracy:99.00%, Validation loss:0.994, Validation accuracy:80.00%
# Epoch 244: iteration 139/140
# Epoch 244 --- loss:0.026, Epoch accuracy:98.80%, Validation loss:0.888, Validation accuracy:81.05%
# Epoch 245: iteration 139/140
# Epoch 245 --- loss:0.014, Epoch accuracy:99.24%, Validation loss:0.971, Validation accuracy:80.00%
# Epoch 246: iteration 139/140
# Epoch 246 --- loss:0.062, Epoch accuracy:97.40%, Validation loss:0.903, Validation accuracy:82.11%
# Epoch 247: iteration 139/140
# Epoch 247 --- loss:0.073, Epoch accuracy:97.00%, Validation loss:1.083, Validation accuracy:80.00%
# Epoch 248: iteration 139/140
# Epoch 248 --- loss:0.038, Epoch accuracy:98.49%, Validation loss:0.907, Validation accuracy:80.53%
# Epoch 249: iteration 139/140
# Epoch 249 --- loss:0.011, Epoch accuracy:99.47%, Validation loss:0.789, Validation accuracy:82.11%
# Epoch 250: iteration 139/140
# Epoch 250 --- loss:0.041, Epoch accuracy:97.84%, Validation loss:1.006, Validation accuracy:79.47%
# Epoch 251: iteration 139/140
# Epoch 251 --- loss:0.047, Epoch accuracy:97.87%, Validation loss:0.956, Validation accuracy:80.00%
# Epoch 252: iteration 139/140
# Epoch 252 --- loss:0.035, Epoch accuracy:98.53%, Validation loss:0.911, Validation accuracy:78.95%
# Epoch 253: iteration 139/140
# Epoch 253 --- loss:0.047, Epoch accuracy:98.00%, Validation loss:0.990, Validation accuracy:78.95%
# Epoch 254: iteration 139/140
# Epoch 254 --- loss:0.031, Epoch accuracy:98.58%, Validation loss:0.831, Validation accuracy:81.05%
# Epoch 255: iteration 139/140
# Epoch 255 --- loss:0.035, Epoch accuracy:98.33%, Validation loss:0.987, Validation accuracy:79.47%
# Epoch 256: iteration 139/140
# Epoch 256 --- loss:0.031, Epoch accuracy:98.58%, Validation loss:0.824, Validation accuracy:80.53%
# Epoch 257: iteration 139/140
# Epoch 257 --- loss:0.020, Epoch accuracy:99.00%, Validation loss:0.940, Validation accuracy:80.53%
# Epoch 258: iteration 139/140
# Epoch 258 --- loss:0.041, Epoch accuracy:98.16%, Validation loss:0.902, Validation accuracy:81.05%
# Epoch 259: iteration 139/140
# Epoch 259 --- loss:0.020, Epoch accuracy:99.13%, Validation loss:0.865, Validation accuracy:82.11%
# Epoch 260: iteration 139/140
# Epoch 260 --- loss:0.033, Epoch accuracy:98.56%, Validation loss:1.020, Validation accuracy:80.00%
# Epoch 261: iteration 139/140
# Epoch 261 --- loss:0.050, Epoch accuracy:97.62%, Validation loss:0.956, Validation accuracy:80.53%
# Epoch 262: iteration 139/140
# Epoch 262 --- loss:0.028, Epoch accuracy:98.60%, Validation loss:0.951, Validation accuracy:82.11%
# Epoch 263: iteration 139/140
# Epoch 263 --- loss:0.019, Epoch accuracy:99.09%, Validation loss:0.867, Validation accuracy:83.16%
# Epoch 264: iteration 139/140
# Epoch 264 --- loss:0.011, Epoch accuracy:99.38%, Validation loss:0.841, Validation accuracy:81.05%
# Epoch 265: iteration 139/140
# Epoch 265 --- loss:0.023, Epoch accuracy:98.84%, Validation loss:0.918, Validation accuracy:82.63%
# Epoch 266: iteration 139/140
# Epoch 266 --- loss:0.070, Epoch accuracy:97.16%, Validation loss:0.934, Validation accuracy:80.53%
# Epoch 267: iteration 139/140
# Epoch 267 --- loss:0.041, Epoch accuracy:98.33%, Validation loss:1.158, Validation accuracy:80.00%
# Epoch 268: iteration 139/140
# Epoch 268 --- loss:0.042, Epoch accuracy:97.96%, Validation loss:0.892, Validation accuracy:82.63%
# Epoch 269: iteration 139/140
# Epoch 269 --- loss:0.024, Epoch accuracy:98.82%, Validation loss:0.923, Validation accuracy:83.68%
# Epoch 270: iteration 139/140
# Epoch 270 --- loss:0.045, Epoch accuracy:98.04%, Validation loss:0.940, Validation accuracy:79.47%
# Epoch 271: iteration 139/140
# Epoch 271 --- loss:0.058, Epoch accuracy:97.69%, Validation loss:0.797, Validation accuracy:77.37%
# Epoch 272: iteration 139/140
# Epoch 272 --- loss:0.052, Epoch accuracy:97.67%, Validation loss:0.905, Validation accuracy:80.00%
# Epoch 273: iteration 139/140
# Epoch 273 --- loss:0.046, Epoch accuracy:97.84%, Validation loss:1.331, Validation accuracy:75.26%
# Epoch 274: iteration 139/140
# Epoch 274 --- loss:0.052, Epoch accuracy:97.84%, Validation loss:0.983, Validation accuracy:77.37%
# Epoch 275: iteration 139/140
# Epoch 275 --- loss:0.052, Epoch accuracy:97.67%, Validation loss:0.941, Validation accuracy:80.53%
# Epoch 276: iteration 139/140
# Epoch 276 --- loss:0.027, Epoch accuracy:98.60%, Validation loss:1.158, Validation accuracy:77.37%
# Epoch 277: iteration 139/140
# Epoch 277 --- loss:0.024, Epoch accuracy:98.96%, Validation loss:0.873, Validation accuracy:81.58%
# Epoch 278: iteration 139/140
# Epoch 278 --- loss:0.008, Epoch accuracy:99.53%, Validation loss:0.828, Validation accuracy:82.63%
# Epoch 279: iteration 139/140
# Epoch 279 --- loss:0.010, Epoch accuracy:99.33%, Validation loss:0.841, Validation accuracy:80.53%
# Epoch 280: iteration 139/140
# Epoch 280 --- loss:0.010, Epoch accuracy:99.36%, Validation loss:0.923, Validation accuracy:81.58%
# Epoch 281: iteration 139/140
# Epoch 281 --- loss:0.010, Epoch accuracy:99.42%, Validation loss:0.902, Validation accuracy:80.00%
# Epoch 282: iteration 139/140
# Epoch 282 --- loss:0.025, Epoch accuracy:98.78%, Validation loss:1.055, Validation accuracy:80.53%
# Epoch 283: iteration 139/140
# Epoch 283 --- loss:0.053, Epoch accuracy:97.56%, Validation loss:0.910, Validation accuracy:78.95%
# Epoch 284: iteration 139/140
# Epoch 284 --- loss:0.038, Epoch accuracy:98.56%, Validation loss:0.903, Validation accuracy:79.47%
# Epoch 285: iteration 139/140
# Epoch 285 --- loss:0.020, Epoch accuracy:99.11%, Validation loss:0.937, Validation accuracy:78.95%
# Epoch 286: iteration 139/140
# Epoch 286 --- loss:0.057, Epoch accuracy:97.73%, Validation loss:1.132, Validation accuracy:76.32%
# Epoch 287: iteration 139/140
# Epoch 287 --- loss:0.033, Epoch accuracy:98.58%, Validation loss:0.986, Validation accuracy:80.53%
# Epoch 288: iteration 139/140
# Epoch 288 --- loss:0.033, Epoch accuracy:98.58%, Validation loss:0.840, Validation accuracy:82.11%
# Epoch 289: iteration 139/140
# Epoch 289 --- loss:0.034, Epoch accuracy:98.40%, Validation loss:0.777, Validation accuracy:81.58%
# Epoch 290: iteration 139/140
# Epoch 290 --- loss:0.056, Epoch accuracy:97.87%, Validation loss:0.820, Validation accuracy:81.05%
# Epoch 291: iteration 139/140
# Epoch 291 --- loss:0.030, Epoch accuracy:98.76%, Validation loss:1.029, Validation accuracy:80.00%
# Epoch 292: iteration 139/140
# Epoch 292 --- loss:0.024, Epoch accuracy:98.96%, Validation loss:0.971, Validation accuracy:79.47%
# Epoch 293: iteration 139/140
# Epoch 293 --- loss:0.029, Epoch accuracy:98.76%, Validation loss:0.894, Validation accuracy:79.47%
# Epoch 294: iteration 139/140
# Epoch 294 --- loss:0.023, Epoch accuracy:98.89%, Validation loss:0.949, Validation accuracy:81.05%
# Epoch 295: iteration 139/140
# Epoch 295 --- loss:0.011, Epoch accuracy:99.42%, Validation loss:0.966, Validation accuracy:80.53%
# Epoch 296: iteration 139/140
# Epoch 296 --- loss:0.040, Epoch accuracy:98.11%, Validation loss:1.050, Validation accuracy:78.95%
# Epoch 297: iteration 139/140
# Epoch 297 --- loss:0.024, Epoch accuracy:98.96%, Validation loss:1.047, Validation accuracy:80.00%
# Epoch 298: iteration 139/140
# Epoch 298 --- loss:0.057, Epoch accuracy:97.38%, Validation loss:0.920, Validation accuracy:77.89%
# Epoch 299: iteration 139/140
# Epoch 299 --- loss:0.045, Epoch accuracy:98.00%, Validation loss:1.184, Validation accuracy:78.95%
# Epoch 300: iteration 139/140
# Epoch 300 --- loss:0.016, Epoch accuracy:99.20%, Validation loss:0.835, Validation accuracy:82.63%
# Epoch 301: iteration 139/140
# Epoch 301 --- loss:0.030, Epoch accuracy:98.56%, Validation loss:0.964, Validation accuracy:80.53%
# Epoch 302: iteration 139/140
# Epoch 302 --- loss:0.109, Epoch accuracy:95.33%, Validation loss:1.013, Validation accuracy:81.58%
# Epoch 303: iteration 139/140
# Epoch 303 --- loss:0.045, Epoch accuracy:98.07%, Validation loss:0.814, Validation accuracy:82.63%
# Epoch 304: iteration 139/140
# Epoch 304 --- loss:0.019, Epoch accuracy:99.11%, Validation loss:0.854, Validation accuracy:83.16%
# Epoch 305: iteration 139/140
# Epoch 305 --- loss:0.015, Epoch accuracy:99.27%, Validation loss:0.832, Validation accuracy:82.11%
# Epoch 306: iteration 139/140
# Epoch 306 --- loss:0.008, Epoch accuracy:99.53%, Validation loss:0.778, Validation accuracy:82.63%
# Epoch 307: iteration 139/140
# Epoch 307 --- loss:0.007, Epoch accuracy:99.51%, Validation loss:0.838, Validation accuracy:82.11%
# Epoch 308: iteration 139/140
# Epoch 308 --- loss:0.012, Epoch accuracy:99.27%, Validation loss:0.922, Validation accuracy:80.53%
# Epoch 309: iteration 139/140
# Epoch 309 --- loss:0.075, Epoch accuracy:97.07%, Validation loss:1.013, Validation accuracy:74.74%
# Epoch 310: iteration 139/140
# Epoch 310 --- loss:0.041, Epoch accuracy:98.13%, Validation loss:0.979, Validation accuracy:81.05%
# Epoch 311: iteration 139/140
# Epoch 311 --- loss:0.021, Epoch accuracy:99.00%, Validation loss:0.893, Validation accuracy:79.47%
# Epoch 312: iteration 139/140
# Epoch 312 --- loss:0.017, Epoch accuracy:99.16%, Validation loss:0.780, Validation accuracy:84.21%
# Epoch 313: iteration 139/140
# Epoch 313 --- loss:0.024, Epoch accuracy:98.84%, Validation loss:0.878, Validation accuracy:83.68%
# Epoch 314: iteration 139/140
# Epoch 314 --- loss:0.018, Epoch accuracy:99.16%, Validation loss:0.874, Validation accuracy:83.16%
# Epoch 315: iteration 139/140
# Epoch 315 --- loss:0.025, Epoch accuracy:98.73%, Validation loss:0.976, Validation accuracy:83.16%
# Epoch 316: iteration 139/140
# Epoch 316 --- loss:0.076, Epoch accuracy:96.71%, Validation loss:0.712, Validation accuracy:83.16%
# Epoch 317: iteration 139/140
# Epoch 317 --- loss:0.060, Epoch accuracy:97.47%, Validation loss:1.366, Validation accuracy:76.32%
# Epoch 318: iteration 139/140
# Epoch 318 --- loss:0.080, Epoch accuracy:96.84%, Validation loss:0.881, Validation accuracy:82.11%
# Epoch 319: iteration 139/140
# Epoch 319 --- loss:0.030, Epoch accuracy:98.78%, Validation loss:0.951, Validation accuracy:79.47%
# Epoch 320: iteration 139/140
# Epoch 320 --- loss:0.017, Epoch accuracy:99.20%, Validation loss:0.860, Validation accuracy:81.05%
# Epoch 321: iteration 139/140
# Epoch 321 --- loss:0.017, Epoch accuracy:99.22%, Validation loss:0.861, Validation accuracy:81.58%
# Epoch 322: iteration 139/140
# Epoch 322 --- loss:0.019, Epoch accuracy:99.04%, Validation loss:1.005, Validation accuracy:79.47%
# Epoch 323: iteration 139/140
# Epoch 323 --- loss:0.030, Epoch accuracy:98.58%, Validation loss:0.819, Validation accuracy:81.58%
# Epoch 324: iteration 139/140
# Epoch 324 --- loss:0.062, Epoch accuracy:97.40%, Validation loss:1.017, Validation accuracy:84.21%
# Epoch 325: iteration 139/140
# Epoch 325 --- loss:0.040, Epoch accuracy:98.31%, Validation loss:0.891, Validation accuracy:80.00%
# Epoch 326: iteration 139/140
# Epoch 326 --- loss:0.032, Epoch accuracy:98.49%, Validation loss:0.927, Validation accuracy:80.00%
# Epoch 327: iteration 139/140
# Epoch 327 --- loss:0.034, Epoch accuracy:98.60%, Validation loss:0.944, Validation accuracy:79.47%
# Epoch 328: iteration 139/140
# Epoch 328 --- loss:0.020, Epoch accuracy:99.00%, Validation loss:0.914, Validation accuracy:79.47%
# Epoch 329: iteration 139/140
# Epoch 329 --- loss:0.061, Epoch accuracy:97.49%, Validation loss:0.943, Validation accuracy:78.95%
# Epoch 330: iteration 139/140
# Epoch 330 --- loss:0.069, Epoch accuracy:97.20%, Validation loss:0.901, Validation accuracy:81.58%
# Epoch 331: iteration 139/140
# Epoch 331 --- loss:0.049, Epoch accuracy:97.84%, Validation loss:0.716, Validation accuracy:82.11%
# Epoch 332: iteration 139/140
# Epoch 332 --- loss:0.034, Epoch accuracy:98.47%, Validation loss:0.711, Validation accuracy:82.63%
# Epoch 333: iteration 139/140
# Epoch 333 --- loss:0.024, Epoch accuracy:98.80%, Validation loss:0.802, Validation accuracy:80.00%
# Epoch 334: iteration 139/140
# Epoch 334 --- loss:0.021, Epoch accuracy:99.02%, Validation loss:0.773, Validation accuracy:83.68%
# Epoch 335: iteration 139/140
# Epoch 335 --- loss:0.036, Epoch accuracy:98.31%, Validation loss:0.855, Validation accuracy:81.58%
# Epoch 336: iteration 139/140
# Epoch 336 --- loss:0.015, Epoch accuracy:99.29%, Validation loss:0.807, Validation accuracy:81.58%
# Epoch 337: iteration 139/140
# Epoch 337 --- loss:0.040, Epoch accuracy:98.13%, Validation loss:1.112, Validation accuracy:79.47%
# Epoch 338: iteration 139/140
# Epoch 338 --- loss:0.036, Epoch accuracy:98.44%, Validation loss:0.898, Validation accuracy:80.00%
# Epoch 339: iteration 139/140
# Epoch 339 --- loss:0.028, Epoch accuracy:98.60%, Validation loss:0.789, Validation accuracy:82.63%
# Epoch 340: iteration 139/140
# Epoch 340 --- loss:0.030, Epoch accuracy:98.58%, Validation loss:0.905, Validation accuracy:78.95%
# Epoch 341: iteration 139/140
# Epoch 341 --- loss:0.029, Epoch accuracy:98.71%, Validation loss:0.814, Validation accuracy:81.58%
# Epoch 342: iteration 139/140
# Epoch 342 --- loss:0.018, Epoch accuracy:99.13%, Validation loss:0.758, Validation accuracy:82.11%
# Epoch 343: iteration 139/140
# Epoch 343 --- loss:0.011, Epoch accuracy:99.42%, Validation loss:0.868, Validation accuracy:81.05%
# Epoch 344: iteration 139/140
# Epoch 344 --- loss:0.017, Epoch accuracy:99.18%, Validation loss:0.853, Validation accuracy:83.16%
# Epoch 345: iteration 139/140
# Epoch 345 --- loss:0.038, Epoch accuracy:98.29%, Validation loss:0.878, Validation accuracy:81.58%
# Epoch 346: iteration 139/140
# Epoch 346 --- loss:0.049, Epoch accuracy:97.84%, Validation loss:0.942, Validation accuracy:78.95%
# Epoch 347: iteration 139/140
# Epoch 347 --- loss:0.055, Epoch accuracy:97.84%, Validation loss:0.923, Validation accuracy:82.11%
# Epoch 348: iteration 139/140
# Epoch 348 --- loss:0.019, Epoch accuracy:99.13%, Validation loss:0.851, Validation accuracy:83.16%
# Epoch 349: iteration 139/140
# Epoch 349 --- loss:0.020, Epoch accuracy:99.13%, Validation loss:0.886, Validation accuracy:82.11%

# %%
plt.title('Loss Curve for Parallel is All You Want Model')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_losses[:],'b')
plt.plot(valid_losses[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()

# %%
# pick load folder  
load_folder = 'checkpoint'  

# pick the epoch to load
epoch = '333'
model_name = f'parallel_all_you_wantFINAL-{epoch}.pkl'

# make full load path
load_path = os.path.join(load_folder, model_name)

## instantiate empty model and populate with params from binary 
model = parallel_all_you_want(len(emotions_dict))
load_checkpoint(optimizer, model, load_path)

print(f'Loaded model from {load_path}')
# Out:
# Loaded model from checkpoint/parallel_all_you_wantFINAL-333.pkl

# %%
# reinitialize validation function with model from chosen checkpoint
validate = make_validate_fnc(model,criterion)

# Convert 4D test feature set array to tensor and move to GPU
X_test_tensor = torch.tensor(X_test,device=device).float()
# Convert 4D test label set array to tensor and move to GPU
y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
inputs =  X_test_tensor                     # this is what you had
labels =  y_test_tensor
#inputs, labels = inputs.cuda(), labels.cuda() # add this line
# Get the model's performance metrics using the validation function we defined

#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

#inputs, labels = inputs.to(device), labels.to(device)
model.to('cuda') 
inputs = inputs.to('cuda')

model.to('cuda') 
labels = labels.to('cuda')

test_loss, test_acc, predicted_emotions = validate(X_test_tensor,y_test_tensor)

print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test accuracy is 78.95%
