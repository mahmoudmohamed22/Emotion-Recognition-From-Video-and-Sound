# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, glob
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import warnings; warnings.filterwarnings('ignore') #matplot lib complains about librosa

# %%
# RAVDESS native sample rate is 48k
sample_rate = 48000

# Mel Spectrograms are not directly used as a feature in this model
# Mel Spectrograms are used in calculating MFCCs, which are a higher-level representation of pitch transition
# MFCCs work better - left the mel spectrogram function here in case anyone wants to experiment
def feature_melspectrogram(
    waveform, 
    sample_rate,
    fft = 1024,
    winlen = 512,
    window='hamming',
    hop=256,
    mels=128,
    ):
    
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram = librosa.feature.melspectrogram(
        y=waveform, 
        sr=sample_rate, 
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2)
    
    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms 
    melspectrogram = librosa.power_to_db(melspectrogram, ref=np.max)
    
    return melspectrogram

def feature_mfcc(
    waveform, 
    sample_rate,
    n_mfcc = 40,
    fft = 1024,
    winlen = 512,
    window='hamming',
    #hop=256, # increases # of time steps; was not helpful
    mels=128
    ):

    # Compute the MFCCs for all STFT frames 
    # 40 mel filterbanks (n_mfcc) = 40 coefficients
    mfc_coefficients=librosa.feature.mfcc(
        y=waveform, 
        sr=sample_rate, 
        n_mfcc=n_mfcc,
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        #hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2
        ) 

    return mfc_coefficients

def get_features(waveforms, features, samplerate):

    # initialize counter to track progress
    file_count = 0

    # process each waveform individually to get its MFCCs
    for waveform in waveforms:
        mfccs = feature_mfcc(waveform, sample_rate)
        features.append(mfccs)
        file_count += 1
        # print progress 
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')
    
    # return all features from list of waveforms
    return features

def get_waveforms(file):
    
    # load an individual sample audio file
    # read the full 3 seconds of the file, cut off the first 0.5s of silence; native sample rate = 48k
    # don't need to store the sample rate that librosa.load returns
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)
    
    # make sure waveform vectors are homogenous by defining explicitly
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform
    
    # return a single file's waveform                                      
    return waveform_homo
    
# RAVDESS dataset emotions
# shift emotions left to be 0 indexed for PyTorch
emotions_dict ={
 '''
    '0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
    '7':'disgust'  '''

   
    '0':'neutral',
    '1':'calm',
    '2':'happy',
    '3':'sad',
    '4':'angry',
   
    

}

# Additional attributes from RAVDESS to play with
emotion_attributes = {
    '01': 'normal',
    '02': 'strong'
}

# %%
# path to data for glob
data_path = 'ravadessspeechsong'

##'RAVDESS dataset/Actor_*/*.wav'
dir_list = os.listdir(data_path)
dir_list.sort()
dir_list
# Out:
# ['.ipynb_checkpoints',
#  'Actor_01',
#  'Actor_02',
#  'Actor_03',
#  'Actor_04',
#  'Actor_05',
#  'Actor_06',
#  'Actor_07',
#  'Actor_08',
#  'Actor_09',
#  'Actor_10',
#  'Actor_11',
#  'Actor_12',
#  'Actor_13',
#  'Actor_14',
#  'Actor_15',
#  'Actor_16',
#  'Actor_17',
#  'Actor_18',
#  'Actor_19',
#  'Actor_20',
#  'Actor_21',
#  'Actor_22',
#  'Actor_23',
#  'Actor_24']

# %%
def load_data():
  # features and labels
  emotions = []
  # raw waveforms to augment later
  waveforms = []
  # extra labels
  intensities, genders = [],[]
  # progress counter
  file_count = 0
  for i in dir_list:
    #print(i)
    file_name = os.listdir(data_path + '/' +i+'/')
    for file in file_name:
     # print(file)
      #print(file_name)
      if file =='.ipynb_checkpoints' : continue
      file=data_path + '/' +i+'/'+file
      nm = file.split('.')[0].split('-')
      # get emotion label from the sample's file
      emotion = int(nm[2])
      #  move surprise to 0 for cleaner behaviour with PyTorch/0-indexing
      if emotion == 1:  emotion = 0
      if emotion == 2:  emotion =1
      if emotion == 3:  emotion = 2
      if emotion == 4:  emotion = 3
      if emotion == 5:  emotion = 4
      if emotion == 6:  continue
      if emotion == 7:  continue
      if emotion == 8:  continue      # surprise is now at 0 index; other emotion indeces unchanged

      # can convert emotion label to emotion string if desired, but
      # training on number is better; better convert to emotion string after predictions are ready
      # emotion = emotions_dict[str(emotion)]
            
      # get other labels we might want
      #intensity = emotion_attributes[int(nm[3])]
      if nm[3] == '01':
            intensity = 0
      else:
            intensity = 1
      # even actors are female, odd are male
      if (int((file.split("-")[6]).split(".")[0]))%2==0: 
          gender = 'female' 
      else: 
          gender = 'male'
                
      # get waveform from the sample
      waveform = get_waveforms(file)
            
      # store waveforms and labels
      waveforms.append(waveform)
      emotions.append(emotion)
      intensities.append(intensity) # store intensity in case we wish to predict
      genders.append(gender) # store gender in case we wish to predict 
            
      file_count += 1
      # keep track of data loader's progress
      print('\r'+f' Processed {file_count}/{1440} audio samples',end='')
  return waveforms, emotions, intensities, genders
      #****************************#

# %%
# load data 
# init explicitly to prevent data leakage from past sessions, since load_data() appends
waveforms, emotions, intensities, genders = [],[],[],[]
waveforms, emotions, intensities, genders = load_data()
# Out:
#  Processed 1692/1440 audio samples

# %%
print(f'Waveforms set: {len(waveforms)} samples')
# we have 1440 waveforms but we need to know their length too; should be 3 sec * 48k = 144k
print(f'Waveform signal length: {len(waveforms[0])}')
print(f'Emotions set: {len(emotions)} sample labels')
# Out:
# Waveforms set: 1692 samples
# Waveform signal length: 144000
# Emotions set: 1692 sample labels

# %%
# create storage for train, validation, test sets and their indices
train_set,valid_set,test_set = [],[],[]
X_train,X_valid,X_test = [],[],[]
y_train,y_valid,y_test = [],[],[]

# convert waveforms to array for processing
waveforms = np.array(waveforms)

# process each emotion separately to make sure we builf balanced train/valid/test sets 
for emotion_num in range(len(emotions_dict)):
        
    # find all indices of a single unique emotion
    emotion_indices = [index for index, emotion in enumerate(emotions) if emotion==emotion_num]

    # seed for reproducibility 
    np.random.seed(69)
    # shuffle indicies 
    emotion_indices = np.random.permutation(emotion_indices)

    # store dim (length) of the emotion list to make indices
    dim = len(emotion_indices)

    # store indices of training, validation and test sets in 80/10/10 proportion
    # train set is first 80%
    train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
    valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
    test_indices = emotion_indices[int(0.9*dim):]

    # create train waveforms/labels sets
    X_train.append(waveforms[train_indices,:])
    y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
    X_valid.append(waveforms[valid_indices,:])
    y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
    X_test.append(waveforms[test_indices,:])
    y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets 
    train_set.append(train_indices)
    valid_set.append(valid_indices)
    test_set.append(test_indices)

# concatenate, in order, all waveforms back into one array 
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array 
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

# make sure train, validation, test sets have no overlap/are unique
# get all unique indices across all sets and how many times each index appears (count)
uniques, count = np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)

# if each index appears just once, and we have 1440 such unique indices, then all sets are unique
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# Training waveforms:(1350, 144000), y_train:(1350,)
# Validation waveforms:(171, 144000), y_valid:(171,)
# Test waveforms:(171, 144000), y_test:(171,)
#
# Sets are unique: 1692 samples out of 1692 are unique

# %%
# initialize feature arrays
# We extract MFCC features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features 
features_train = get_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = get_features(X_valid, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features 
features_test = get_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'Features (MFC coefficient matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
#  Processed 1350/1350 waveforms
#
# Validation waveforms:
#  Processed 171/171 waveforms
#
# Test waveforms:
#  Processed 171/171 waveforms
#
# Features set: 1692 total, 1350 train, 171 validation, 171 test samples
# Features (MFC coefficient matrix) shape: 40 mel frequency coefficients x 282 time steps

# %%
def awgn_augmentation(waveform, multiples=2, bits=16, snr_min=15, snr_max=30): 
    
    # get length of waveform (should be 3*48k = 144k)
    wave_len = len(waveform)
    
    # Generate normally distributed (Gaussian) noises
    # one for each waveform and multiple (i.e. wave_len*multiples noises)
    noise = np.random.normal(size=(multiples, wave_len))
    
    # Normalize waveform and noise
    norm_constant = 2.0**(bits-1)
    norm_wave = waveform / norm_constant
    norm_noise = noise / norm_constant
    
    # Compute power of waveform and power of noise
    signal_power = np.sum(norm_wave ** 2) / wave_len
    noise_power = np.sum(norm_noise ** 2, axis=1) / wave_len
    
    # Choose random SNR in decibels in range [15,30]
    snr = np.random.randint(snr_min, snr_max)
    
    # Apply whitening transformation: make the Gaussian noise into Gaussian white noise
    # Compute the covariance matrix used to whiten each noise 
    # actual SNR = signal/noise (power)
    # actual noise power = 10**(-snr/10)
    covariance = np.sqrt((signal_power / noise_power) * 10 ** (- snr / 10))
    # Get covariance matrix with dim: (144000, 2) so we can transform 2 noises: dim (2, 144000)
    covariance = np.ones((wave_len, multiples)) * covariance

    # Since covariance and noise are arrays, * is the haddamard product 
    # Take Haddamard product of covariance and noise to generate white noise
    multiple_augmented_waveforms = waveform + covariance.T * noise
    
    return multiple_augmented_waveforms
def augment_waveforms(waveforms, features, emotions, multiples):
    # keep track of how many waveforms we've processed so we can add correct emotion label in the same order
    emotion_count = 0
    # keep track of how many augmented samples we've added
    added_count = 0
    # convert emotion array to list for more efficient appending
    emotions = emotions.tolist()

    for waveform in waveforms:

        # Generate 2 augmented multiples of the dataset, i.e. 1440 native + 1440*2 noisy = 4320 samples total
        augmented_waveforms = awgn_augmentation(waveform, multiples=multiples)

        # compute spectrogram for each of 2 augmented waveforms
        for augmented_waveform in augmented_waveforms:

            # Compute MFCCs over augmented waveforms
            augmented_mfcc = feature_mfcc(augmented_waveform, sample_rate=sample_rate)

            # append the augmented spectrogram to the rest of the native data
            features.append(augmented_mfcc)
            emotions.append(emotions[emotion_count])

            # keep track of new augmented samples
            added_count += 1

            # check progress
            print('\r'+f'Processed {emotion_count + 1}/{len(waveforms)} waveforms for {added_count}/{len(waveforms)*multiples} new augmented samples',end='')

        # keep track of the emotion labels to append in order
        emotion_count += 1
        
        # store augmented waveforms to check their shape
        augmented_waveforms_temp.append(augmented_waveforms)
    
    return features, emotions

# %%
# store augmented waveforms to verify their shape and random-ness
augmented_waveforms_temp = []

# specify multiples of our dataset to add as augmented data
multiples = 2

print('Train waveforms:') # augment waveforms of training set
features_train , y_train = augment_waveforms(X_train, features_train, y_train, multiples)


# Check new shape of extracted features and data:
print(f'\n\nNative + Augmented Features set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'{len(y_train)} training sample labels, {len(y_valid)} validation sample labels, {len(y_test)} test sample labels')
print(f'Features (MFCC matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
# Processed 1350/1350 waveforms for 2700/2700 new augmented samples
#
# Native + Augmented Features set: 4392 total, 4050 train, 171 validation, 171 test samples
# 4050 training sample labels, 171 validation sample labels, 171 test sample labels
# Features (MFCC matrix) shape: 40 mel frequency coefficients x 282 time steps

# %%
# need to make dummy input channel for CNN input feature tensor
X_train = np.expand_dims(features_train,1)
X_valid = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test,1)

# convert emotion labels from list back to numpy arrays for PyTorch to work with 
y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)

# confiorm that we have tensor-ready 4D data array
# should print (batch, channel, width, height) == (4320, 1, 128, 282) when multiples==2
print(f'Shape of 4D feature array for input tensor: {X_train.shape} train, {X_valid.shape} validation, {X_test.shape} test')
print(f'Shape of emotion labels: {y_train.shape} train, {y_valid.shape} validation, {y_test.shape} test')
# Out:
# Shape of 4D feature array for input tensor: (4050, 1, 40, 282) train, (171, 1, 40, 282) validation, (171, 1, 40, 282) test
# Shape of emotion labels: (4050,) train, (171,) validation, (171,) test

# %%
# free up some RAM - no longer need full feature set or any waveforms 
del features_train, features_valid, features_test, waveforms, augmented_waveforms_temp

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#### Scale the training data ####
# store shape so we can transform it back 
N,C,H,W = X_train.shape
# Reshape to 1D because StandardScaler operates on a 1D array
# tell numpy to infer shape of 1D array with '-1' argument
X_train = np.reshape(X_train, (N,-1)) 
X_train = scaler.fit_transform(X_train)
# Transform back to NxCxHxW 4D tensor format
X_train = np.reshape(X_train, (N,C,H,W))

##### Scale the validation set ####
N,C,H,W = X_valid.shape
X_valid = np.reshape(X_valid, (N,-1))
X_valid = scaler.transform(X_valid)
X_valid = np.reshape(X_valid, (N,C,H,W))

#### Scale the test set ####
N,C,H,W = X_test.shape
X_test = np.reshape(X_test, (N,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, (N,C,H,W))

# check shape of each set again
print(f'X_train scaled:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid scaled:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test scaled:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train scaled:(4050, 1, 40, 282), y_train:(4050,)
# X_valid scaled:(171, 1, 40, 282), y_valid:(171,)
# X_test scaled:(171, 1, 40, 282), y_test:(171,)

# %%
###### SAVE #########
# choose save file name 
filename = 'features+labels.npy'

# open file in write mode and write data
with open(filename, 'wb') as f:
    np.save(f, X_train)
    np.save(f, X_valid)
    np.save(f, X_test)
    np.save(f, y_train)
    np.save(f, y_valid)
    np.save(f, y_test)

print(f'Features and labels saved to {filename}')
# Out:
# Features and labels saved to features+labels.npy

# %%
##### LOAD #########
# choose load file name 
filename = 'features+labels.npy'

# open file in read mode and read data 
with open(filename, 'rb') as f:
    X_train = np.load(f)
    X_valid = np.load(f)
    X_test = np.load(f)
    y_train = np.load(f)
    y_valid = np.load(f)
    y_test = np.load(f)

# Check that we've recovered the right data
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train:(4050, 1, 40, 282), y_train:(4050,)
# X_valid:(171, 1, 40, 282), y_valid:(171,)
# X_test:(171, 1, 40, 282), y_test:(171,)

# %%
#change nn.sequential to take dict to make more readable 

class parallel_all_you_want(nn.Module):
    # Define all layers present in the network
    def __init__(self,num_emotions):
        super().__init__() 
        
        ################ TRANSFORMER BLOCK #############################
        # maxpool the input feature map/tensor to the transformer 
        # a rectangular kernel worked better here for the rectangular input spectrogram feature map/tensor
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1,4], stride=[1,4])
        
        # define single transformer encoder layer
        # self-attention + feedforward network from "Attention is All You Need" paper
        # 4 multi-head self-attention layers each with 40-->512--->40 feedforward network
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40, # input feature (frequency) dim after maxpooling 40*282 -> 40*70 (MFC*time)
            nhead=4, # 4 self-attention layers in each multi-head self-attention layer in each encoder block
            dim_feedforward=320, # 2 linear layers in each encoder block's feedforward network: dim 40-->512--->40
            dropout=0.4, 
            activation='relu' # ReLU: avoid saturation/tame gradient/reduce compute time
        )
        
        # I'm using 4 instead of the 6 identical stacked encoder layrs used in Attention is All You Need paper
        # Complete transformer block contains 4 full transformer encoder layers (each w/ multihead self-attention+feedforward)
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=4)
        
        ############### 1ST PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock1 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        ############### 2ND PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock2 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )

        ################# FINAL LINEAR BLOCK ####################
        # Linear softmax layer to take final concatenated embedding tensor 
        #    from parallel 2D convolutional and transformer blocks, output 8 logits 
        # Each full convolution block outputs (64*1*8) embedding flattened to dim 512 1D array 
        # Full transformer block outputs 40*70 feature map, which we time-avg to dim 40 1D array
        # 512*2+40 == 1064 input features --> 8 output emotions 
        self.fc1_linear = nn.Linear(320*2+424,num_emotions) 
        
        ### Softmax layer for the 8 output logits from final FC linear layer 
        self.softmax_out = nn.Softmax(dim=1) # dim==1 is the freq embedding
        
    # define one complete parallel fwd pass of input feature tensor thru 2*conv+1*transformer blocks
    def forward(self,x):
        
        ############ 1st parallel Conv2D block: 4 Convolutional layers ############################
        # create final feature embedding from 1st convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding1 = self.conv2Dblock1(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding1 = torch.flatten(conv2d_embedding1, start_dim=1) 
        
        ############ 2nd parallel Conv2D block: 4 Convolutional layers #############################
        # create final feature embedding from 2nd convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding2 = self.conv2Dblock2(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding2 = torch.flatten(conv2d_embedding2, start_dim=1) 
        
         
        ########## 4-encoder-layer Transformer block w/ 40-->512-->40 feedfwd network ##############
        # maxpool input feature map: 1*40*282 w/ 1*4 kernel --> 1*40*70
        x_maxpool = self.transformer_maxpool(x)

        # remove channel dim: 1*40*70 --> 40*70
        x_maxpool_reduced = torch.squeeze(x_maxpool,1)
        
        # convert maxpooled feature map format: batch * freq * time ---> time * batch * freq format
        # because transformer encoder layer requires tensor in format: time * batch * embedding (freq)
        x = x_maxpool_reduced.permute(2,0,1) 
        
        # finally, pass reduced input feature map x into transformer encoder layers
        transformer_output = self.transformer_encoder(x)
        
        # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
        # transformer outputs 2x40 (MFCC embedding*time) feature map, take mean of columns i.e. take time average
        transformer_embedding = torch.mean(transformer_output, dim=0) # dim 40x70 --> 40
        
        ############# concatenate freq embeddings from convolutional and transformer blocks ######
        # concatenate embedding tensors output by parallel 2*conv and 1*transformer blocks
        complete_embedding = torch.cat([conv2d_embedding1, conv2d_embedding2,transformer_embedding], dim=1)  

        ######### final FC linear layer, need logits for loss #########################
        output_logits = self.fc1_linear(complete_embedding)  
        
        ######### Final Softmax layer: use logits from FC linear, get softmax for prediction ######
        output_softmax = self.softmax_out(output_logits)
        
        # need output logits to compute cross entropy loss, need softmax probabilities to predict class
        return output_logits, output_softmax

# %%
from torchsummary import summary

# need device to instantiate model
device = 'cuda'

# instantiate model for 8 emotions and move to GPU 
model = parallel_all_you_want(len(emotions_dict)).to(device)

# include input feature map dims in call to summary()
#summary(model,(1,1,1))

# %%
# define loss function; CrossEntropyLoss() fairly standard for multiclass problems 
def criterion(predictions, targets): 
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# %%
# define function to create a single step of the training phase
def make_train_step(model, criterion, optimizer):
    
    # define the training step of the training phase
    def train_step(X,Y):
        
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        
        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y) 
        
        # compute gradients for the optimizer to use 
        loss.backward()
        
        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()
        
        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad() 
        
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,criterion):
    def validate(X,Y):
        
        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase: 
        with torch.no_grad(): 
            
            # set model to validation phase i.e. turn off dropout and batchnorm layers 
            model.eval()
      
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            
            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits,Y)
            
        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint(): 
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint

def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
# get training set size to calculate # iterations and minibatch indices
train_size = X_train.shape[0]

# pick minibatch size (of 32... always)
minibatch = 32

# set device to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'{device} selected')

# instantiate model and move to GPU for training
model = parallel_all_you_want(num_emotions=len(emotions_dict)).to(device) 
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )

# encountered bugs in google colab only, unless I explicitly defined optimizer in this cell...
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# instantiate the checkpoint save function
save_checkpoint = make_save_checkpoint()

# instantiate the training step function 
train_step = make_train_step(model, criterion, optimizer=optimizer)

# instantiate the validation loop function
validate = make_validate_fnc(model,criterion)

# instantiate lists to hold scalar performance metrics to plot later
train_losses=[]
valid_losses = []

# create training loop for one complete epoch (entire training set)
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):

    for epoch in range(num_epochs):
        
        # set model to train phase
        model.train()         
        
        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size) 
        
        # shuffle the training set for each epoch:
        X_train = X_train[train_indices,:,:,:] 
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate 
        epoch_acc = 0 
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)
        
        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):
            
            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch 
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size) 
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start 
            
            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:] 
            # get training minibatch labels 
            Y = Y_train[batch_start:batch_end] 

            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float() 
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor,Y_tensor) 
            
            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size
            
            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}',end='')
        
        # create tensors from validation set
        X_valid_tensor = torch.tensor(X_valid,device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor,Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
                  
        # Save checkpoint of the model
        #checkpoint_filename = '/content/gdrive/My Drive/DL/models/checkpoints/parallel_all_you_wantFINAL-{:03d}.pkl'.format(epoch)
        checkpoint_filename = 'checkpoint/parallel_all_you_wantFINAL-{:03d}.pkl'.format(epoch)
        save_checkpoint(optimizer, model, epoch, checkpoint_filename)
        
        # keep track of each epoch's progress
       
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')
# Out:
# cuda selected
# Number of trainable params:  183085

# %%
# choose number of epochs higher than reasonable so we can manually stop training 
num_epochs = 350

# train it!
train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
# Out:
# Epoch 0: iteration 125/126
# Epoch 0 --- loss:2.159, Epoch accuracy:38.27%, Validation loss:1.660, Validation accuracy:43.86%
# Epoch 1: iteration 125/126
# Epoch 1 --- loss:1.105, Epoch accuracy:53.14%, Validation loss:1.830, Validation accuracy:40.35%
# Epoch 2: iteration 125/126
# Epoch 2 --- loss:0.961, Epoch accuracy:60.42%, Validation loss:1.541, Validation accuracy:45.61%
# Epoch 3: iteration 125/126
# Epoch 3 --- loss:0.843, Epoch accuracy:65.68%, Validation loss:1.204, Validation accuracy:52.63%
# Epoch 4: iteration 125/126
# Epoch 4 --- loss:0.788, Epoch accuracy:67.53%, Validation loss:1.536, Validation accuracy:57.31%
# Epoch 5: iteration 125/126
# Epoch 5 --- loss:0.752, Epoch accuracy:69.53%, Validation loss:1.120, Validation accuracy:61.40%
# Epoch 6: iteration 125/126
# Epoch 6 --- loss:0.668, Epoch accuracy:72.89%, Validation loss:1.037, Validation accuracy:59.65%
# Epoch 7: iteration 125/126
# Epoch 7 --- loss:0.630, Epoch accuracy:74.59%, Validation loss:0.706, Validation accuracy:71.35%
# Epoch 8: iteration 125/126
# Epoch 8 --- loss:0.574, Epoch accuracy:76.91%, Validation loss:0.931, Validation accuracy:64.91%
# Epoch 9: iteration 125/126
# Epoch 9 --- loss:0.530, Epoch accuracy:78.81%, Validation loss:0.773, Validation accuracy:71.35%
# Epoch 10: iteration 125/126
# Epoch 10 --- loss:0.495, Epoch accuracy:79.90%, Validation loss:0.843, Validation accuracy:70.76%
# Epoch 11: iteration 125/126
# Epoch 11 --- loss:0.453, Epoch accuracy:81.80%, Validation loss:0.855, Validation accuracy:71.93%
# Epoch 12: iteration 125/126
# Epoch 12 --- loss:0.440, Epoch accuracy:82.62%, Validation loss:0.799, Validation accuracy:76.02%
# Epoch 13: iteration 125/126
# Epoch 13 --- loss:0.382, Epoch accuracy:85.09%, Validation loss:0.726, Validation accuracy:76.61%
# Epoch 14: iteration 125/126
# Epoch 14 --- loss:0.352, Epoch accuracy:86.47%, Validation loss:0.838, Validation accuracy:75.44%
# Epoch 15: iteration 125/126
# Epoch 15 --- loss:0.360, Epoch accuracy:85.33%, Validation loss:0.726, Validation accuracy:75.44%
# Epoch 16: iteration 125/126
# Epoch 16 --- loss:0.327, Epoch accuracy:86.99%, Validation loss:0.730, Validation accuracy:76.02%
# Epoch 17: iteration 125/126
# Epoch 17 --- loss:0.281, Epoch accuracy:88.52%, Validation loss:0.848, Validation accuracy:73.10%
# Epoch 18: iteration 125/126
# Epoch 18 --- loss:0.263, Epoch accuracy:89.53%, Validation loss:0.674, Validation accuracy:79.53%
# Epoch 19: iteration 125/126
# Epoch 19 --- loss:0.271, Epoch accuracy:88.86%, Validation loss:0.646, Validation accuracy:79.53%
# Epoch 20: iteration 125/126
# Epoch 20 --- loss:0.251, Epoch accuracy:89.65%, Validation loss:0.935, Validation accuracy:77.19%
# Epoch 21: iteration 125/126
# Epoch 21 --- loss:0.239, Epoch accuracy:90.96%, Validation loss:0.651, Validation accuracy:82.46%
# Epoch 22: iteration 125/126
# Epoch 22 --- loss:0.249, Epoch accuracy:90.30%, Validation loss:0.709, Validation accuracy:79.53%
# Epoch 23: iteration 125/126
# Epoch 23 --- loss:0.209, Epoch accuracy:92.12%, Validation loss:0.720, Validation accuracy:77.78%
# Epoch 24: iteration 125/126
# Epoch 24 --- loss:0.207, Epoch accuracy:91.70%, Validation loss:0.641, Validation accuracy:80.70%
# Epoch 25: iteration 125/126
# Epoch 25 --- loss:0.201, Epoch accuracy:92.10%, Validation loss:0.759, Validation accuracy:80.70%
# Epoch 26: iteration 125/126
# Epoch 26 --- loss:0.195, Epoch accuracy:92.30%, Validation loss:0.782, Validation accuracy:82.46%
# Epoch 27: iteration 125/126
# Epoch 27 --- loss:0.172, Epoch accuracy:92.81%, Validation loss:0.723, Validation accuracy:80.70%
# Epoch 28: iteration 125/126
# Epoch 28 --- loss:0.176, Epoch accuracy:93.21%, Validation loss:0.625, Validation accuracy:81.87%
# Epoch 29: iteration 125/126
# Epoch 29 --- loss:0.166, Epoch accuracy:93.70%, Validation loss:0.736, Validation accuracy:84.21%
# Epoch 30: iteration 125/126
# Epoch 30 --- loss:0.155, Epoch accuracy:93.98%, Validation loss:0.742, Validation accuracy:81.87%
# Epoch 31: iteration 125/126
# Epoch 31 --- loss:0.143, Epoch accuracy:94.54%, Validation loss:0.685, Validation accuracy:81.87%
# Epoch 32: iteration 125/126
# Epoch 32 --- loss:0.133, Epoch accuracy:94.62%, Validation loss:0.829, Validation accuracy:81.87%
# Epoch 33: iteration 125/126
# Epoch 33 --- loss:0.141, Epoch accuracy:94.42%, Validation loss:0.792, Validation accuracy:83.04%
# Epoch 34: iteration 125/126
# Epoch 34 --- loss:0.143, Epoch accuracy:94.40%, Validation loss:0.623, Validation accuracy:84.80%
# Epoch 35: iteration 125/126
# Epoch 35 --- loss:0.137, Epoch accuracy:94.49%, Validation loss:0.612, Validation accuracy:84.80%
# Epoch 36: iteration 125/126
# Epoch 36 --- loss:0.125, Epoch accuracy:94.84%, Validation loss:0.548, Validation accuracy:84.21%
# Epoch 37: iteration 125/126
# Epoch 37 --- loss:0.121, Epoch accuracy:95.11%, Validation loss:0.683, Validation accuracy:83.04%
# Epoch 38: iteration 125/126
# Epoch 38 --- loss:0.105, Epoch accuracy:95.78%, Validation loss:0.738, Validation accuracy:82.46%
# Epoch 39: iteration 125/126
# Epoch 39 --- loss:0.117, Epoch accuracy:95.16%, Validation loss:0.757, Validation accuracy:82.46%
# Epoch 40: iteration 125/126
# Epoch 40 --- loss:0.091, Epoch accuracy:96.49%, Validation loss:0.684, Validation accuracy:83.63%
# Epoch 41: iteration 125/126
# Epoch 41 --- loss:0.089, Epoch accuracy:96.44%, Validation loss:0.607, Validation accuracy:84.21%
# Epoch 42: iteration 125/126
# Epoch 42 --- loss:0.088, Epoch accuracy:96.40%, Validation loss:0.750, Validation accuracy:85.38%
# Epoch 43: iteration 125/126
# Epoch 43 --- loss:0.102, Epoch accuracy:96.00%, Validation loss:0.708, Validation accuracy:83.04%
# Epoch 44: iteration 125/126
# Epoch 44 --- loss:0.087, Epoch accuracy:96.44%, Validation loss:0.696, Validation accuracy:78.36%
# Epoch 45: iteration 125/126
# Epoch 45 --- loss:0.111, Epoch accuracy:95.60%, Validation loss:0.701, Validation accuracy:85.38%
# Epoch 46: iteration 125/126
# Epoch 46 --- loss:0.096, Epoch accuracy:96.05%, Validation loss:0.632, Validation accuracy:83.04%
# Epoch 47: iteration 125/126
# Epoch 47 --- loss:0.104, Epoch accuracy:95.98%, Validation loss:0.886, Validation accuracy:83.63%
# Epoch 48: iteration 125/126
# Epoch 48 --- loss:0.086, Epoch accuracy:96.40%, Validation loss:0.784, Validation accuracy:81.87%
# Epoch 49: iteration 125/126
# Epoch 49 --- loss:0.081, Epoch accuracy:96.59%, Validation loss:0.683, Validation accuracy:87.13%
# Epoch 50: iteration 125/126
# Epoch 50 --- loss:0.071, Epoch accuracy:97.21%, Validation loss:0.559, Validation accuracy:86.55%
# Epoch 51: iteration 125/126
# Epoch 51 --- loss:0.068, Epoch accuracy:97.33%, Validation loss:0.762, Validation accuracy:84.80%
# Epoch 52: iteration 125/126
# Epoch 52 --- loss:0.064, Epoch accuracy:97.33%, Validation loss:0.755, Validation accuracy:84.21%
# Epoch 53: iteration 125/126
# Epoch 53 --- loss:0.071, Epoch accuracy:97.16%, Validation loss:0.881, Validation accuracy:84.80%
# Epoch 54: iteration 125/126
# Epoch 54 --- loss:0.075, Epoch accuracy:96.89%, Validation loss:0.687, Validation accuracy:83.04%
# Epoch 55: iteration 125/126
# Epoch 55 --- loss:0.058, Epoch accuracy:97.85%, Validation loss:0.751, Validation accuracy:84.21%
# Epoch 56: iteration 125/126
# Epoch 56 --- loss:0.066, Epoch accuracy:97.38%, Validation loss:0.621, Validation accuracy:87.72%
# Epoch 57: iteration 125/126
# Epoch 57 --- loss:0.053, Epoch accuracy:97.78%, Validation loss:0.606, Validation accuracy:86.55%
# Epoch 58: iteration 125/126
# Epoch 58 --- loss:0.046, Epoch accuracy:98.05%, Validation loss:0.704, Validation accuracy:87.13%
# Epoch 59: iteration 125/126
# Epoch 59 --- loss:0.057, Epoch accuracy:97.78%, Validation loss:0.679, Validation accuracy:85.96%
# Epoch 60: iteration 125/126
# Epoch 60 --- loss:0.066, Epoch accuracy:97.28%, Validation loss:0.692, Validation accuracy:86.55%
# Epoch 61: iteration 125/126
# Epoch 61 --- loss:0.065, Epoch accuracy:97.41%, Validation loss:0.694, Validation accuracy:85.38%
# Epoch 62: iteration 125/126
# Epoch 62 --- loss:0.052, Epoch accuracy:97.95%, Validation loss:0.660, Validation accuracy:87.13%
# Epoch 63: iteration 125/126
# Epoch 63 --- loss:0.047, Epoch accuracy:98.15%, Validation loss:0.867, Validation accuracy:82.46%
# Epoch 64: iteration 125/126
# Epoch 64 --- loss:0.062, Epoch accuracy:97.60%, Validation loss:0.740, Validation accuracy:85.38%
# Epoch 65: iteration 125/126
# Epoch 65 --- loss:0.058, Epoch accuracy:97.46%, Validation loss:0.779, Validation accuracy:85.38%
# Epoch 66: iteration 125/126
# Epoch 66 --- loss:0.038, Epoch accuracy:98.62%, Validation loss:0.677, Validation accuracy:84.21%
# Epoch 67: iteration 125/126
# Epoch 67 --- loss:0.048, Epoch accuracy:98.02%, Validation loss:0.749, Validation accuracy:85.38%
# Epoch 68: iteration 125/126
# Epoch 68 --- loss:0.051, Epoch accuracy:98.10%, Validation loss:0.601, Validation accuracy:86.55%
# Epoch 69: iteration 125/126
# Epoch 69 --- loss:0.043, Epoch accuracy:98.07%, Validation loss:0.779, Validation accuracy:84.80%
# Epoch 70: iteration 125/126
# Epoch 70 --- loss:0.047, Epoch accuracy:98.37%, Validation loss:0.644, Validation accuracy:87.72%
# Epoch 71: iteration 125/126
# Epoch 71 --- loss:0.041, Epoch accuracy:98.27%, Validation loss:0.754, Validation accuracy:86.55%
# Epoch 72: iteration 125/126
# Epoch 72 --- loss:0.041, Epoch accuracy:98.40%, Validation loss:0.613, Validation accuracy:87.72%
# Epoch 73: iteration 125/126
# Epoch 73 --- loss:0.034, Epoch accuracy:98.64%, Validation loss:0.657, Validation accuracy:87.72%
# Epoch 74: iteration 125/126
# Epoch 74 --- loss:0.034, Epoch accuracy:98.44%, Validation loss:0.662, Validation accuracy:88.30%
# Epoch 75: iteration 125/126
# Epoch 75 --- loss:0.046, Epoch accuracy:98.05%, Validation loss:0.622, Validation accuracy:88.89%
# Epoch 76: iteration 125/126
# Epoch 76 --- loss:0.044, Epoch accuracy:98.20%, Validation loss:0.707, Validation accuracy:85.96%
# Epoch 77: iteration 125/126
# Epoch 77 --- loss:0.037, Epoch accuracy:98.49%, Validation loss:0.716, Validation accuracy:88.30%
# Epoch 78: iteration 125/126
# Epoch 78 --- loss:0.034, Epoch accuracy:98.54%, Validation loss:0.767, Validation accuracy:86.55%
# Epoch 79: iteration 125/126
# Epoch 79 --- loss:0.040, Epoch accuracy:98.44%, Validation loss:0.753, Validation accuracy:87.72%
# Epoch 80: iteration 125/126
# Epoch 80 --- loss:0.065, Epoch accuracy:97.16%, Validation loss:0.658, Validation accuracy:85.38%
# Epoch 81: iteration 125/126
# Epoch 81 --- loss:0.056, Epoch accuracy:97.70%, Validation loss:0.751, Validation accuracy:87.13%
# Epoch 82: iteration 125/126
# Epoch 82 --- loss:0.049, Epoch accuracy:97.85%, Validation loss:0.564, Validation accuracy:88.30%
# Epoch 83: iteration 125/126
# Epoch 83 --- loss:0.025, Epoch accuracy:98.96%, Validation loss:0.660, Validation accuracy:88.30%
# Epoch 84: iteration 125/126
# Epoch 84 --- loss:0.026, Epoch accuracy:98.86%, Validation loss:0.698, Validation accuracy:88.30%
# Epoch 85: iteration 125/126
# Epoch 85 --- loss:0.024, Epoch accuracy:98.91%, Validation loss:0.692, Validation accuracy:86.55%
# Epoch 86: iteration 125/126
# Epoch 86 --- loss:0.031, Epoch accuracy:98.79%, Validation loss:0.685, Validation accuracy:85.38%
# Epoch 87: iteration 125/126
# Epoch 87 --- loss:0.039, Epoch accuracy:98.25%, Validation loss:0.643, Validation accuracy:85.38%
# Epoch 88: iteration 125/126
# Epoch 88 --- loss:0.054, Epoch accuracy:97.78%, Validation loss:0.712, Validation accuracy:86.55%
# Epoch 89: iteration 125/126
# Epoch 89 --- loss:0.025, Epoch accuracy:98.84%, Validation loss:0.784, Validation accuracy:85.38%
# Epoch 90: iteration 125/126
# Epoch 90 --- loss:0.038, Epoch accuracy:98.25%, Validation loss:0.794, Validation accuracy:87.13%
# Epoch 91: iteration 125/126
# Epoch 91 --- loss:0.035, Epoch accuracy:98.74%, Validation loss:0.656, Validation accuracy:88.30%
# Epoch 92: iteration 125/126
# Epoch 92 --- loss:0.021, Epoch accuracy:99.01%, Validation loss:0.633, Validation accuracy:89.47%
# Epoch 93: iteration 125/126
# Epoch 93 --- loss:0.032, Epoch accuracy:98.44%, Validation loss:0.663, Validation accuracy:87.72%
# Epoch 94: iteration 125/126
# Epoch 94 --- loss:0.018, Epoch accuracy:99.19%, Validation loss:0.693, Validation accuracy:87.72%
# Epoch 95: iteration 125/126
# Epoch 95 --- loss:0.028, Epoch accuracy:98.79%, Validation loss:0.531, Validation accuracy:89.47%
# Epoch 96: iteration 125/126
# Epoch 96 --- loss:0.028, Epoch accuracy:98.69%, Validation loss:0.614, Validation accuracy:88.30%
# Epoch 97: iteration 125/126
# Epoch 97 --- loss:0.031, Epoch accuracy:98.77%, Validation loss:0.656, Validation accuracy:88.89%
# Epoch 98: iteration 125/126
# Epoch 98 --- loss:0.021, Epoch accuracy:99.04%, Validation loss:0.637, Validation accuracy:87.13%
# Epoch 99: iteration 125/126
# Epoch 99 --- loss:0.033, Epoch accuracy:98.64%, Validation loss:0.723, Validation accuracy:87.13%
# Epoch 100: iteration 125/126
# Epoch 100 --- loss:0.026, Epoch accuracy:98.99%, Validation loss:0.614, Validation accuracy:88.89%
# Epoch 101: iteration 125/126
# Epoch 101 --- loss:0.024, Epoch accuracy:98.89%, Validation loss:0.671, Validation accuracy:86.55%
# Epoch 102: iteration 125/126
# Epoch 102 --- loss:0.015, Epoch accuracy:99.23%, Validation loss:0.703, Validation accuracy:85.96%
# Epoch 103: iteration 125/126
# Epoch 103 --- loss:0.022, Epoch accuracy:98.96%, Validation loss:0.805, Validation accuracy:85.38%
# Epoch 104: iteration 125/126
# Epoch 104 --- loss:0.029, Epoch accuracy:98.64%, Validation loss:0.695, Validation accuracy:87.72%
# Epoch 105: iteration 125/126
# Epoch 105 --- loss:0.027, Epoch accuracy:98.77%, Validation loss:0.666, Validation accuracy:86.55%
# Epoch 106: iteration 125/126
# Epoch 106 --- loss:0.026, Epoch accuracy:98.96%, Validation loss:0.814, Validation accuracy:87.13%
# Epoch 107: iteration 125/126
# Epoch 107 --- loss:0.062, Epoch accuracy:97.68%, Validation loss:0.666, Validation accuracy:87.13%
# Epoch 108: iteration 125/126
# Epoch 108 --- loss:0.032, Epoch accuracy:98.54%, Validation loss:0.678, Validation accuracy:85.38%
# Epoch 109: iteration 125/126
# Epoch 109 --- loss:0.027, Epoch accuracy:98.91%, Validation loss:0.578, Validation accuracy:88.30%
# Epoch 110: iteration 125/126
# Epoch 110 --- loss:0.023, Epoch accuracy:99.01%, Validation loss:0.604, Validation accuracy:88.30%
# Epoch 111: iteration 125/126
# Epoch 111 --- loss:0.035, Epoch accuracy:98.47%, Validation loss:0.918, Validation accuracy:81.87%
# Epoch 112: iteration 125/126
# Epoch 112 --- loss:0.030, Epoch accuracy:98.62%, Validation loss:0.583, Validation accuracy:87.72%
# Epoch 113: iteration 125/126
# Epoch 113 --- loss:0.025, Epoch accuracy:98.99%, Validation loss:0.745, Validation accuracy:88.89%
# Epoch 114: iteration 125/126
# Epoch 114 --- loss:0.032, Epoch accuracy:98.62%, Validation loss:0.607, Validation accuracy:87.72%
# Epoch 115: iteration 125/126
# Epoch 115 --- loss:0.025, Epoch accuracy:98.84%, Validation loss:0.746, Validation accuracy:87.13%
# Epoch 116: iteration 125/126
# Epoch 116 --- loss:0.019, Epoch accuracy:99.19%, Validation loss:0.585, Validation accuracy:89.47%
# Epoch 117: iteration 125/126
# Epoch 117 --- loss:0.013, Epoch accuracy:99.46%, Validation loss:0.642, Validation accuracy:88.30%
# Epoch 118: iteration 125/126
# Epoch 118 --- loss:0.021, Epoch accuracy:98.96%, Validation loss:0.693, Validation accuracy:85.38%
# Epoch 119: iteration 125/126
# Epoch 119 --- loss:0.024, Epoch accuracy:98.96%, Validation loss:0.650, Validation accuracy:88.89%
# Epoch 120: iteration 125/126
# Epoch 120 --- loss:0.039, Epoch accuracy:98.20%, Validation loss:0.676, Validation accuracy:85.96%
# Epoch 121: iteration 125/126
# Epoch 121 --- loss:0.031, Epoch accuracy:98.57%, Validation loss:0.695, Validation accuracy:85.38%
# Epoch 122: iteration 125/126
# Epoch 122 --- loss:0.015, Epoch accuracy:99.31%, Validation loss:0.661, Validation accuracy:87.13%
# Epoch 123: iteration 125/126
# Epoch 123 --- loss:0.016, Epoch accuracy:99.23%, Validation loss:0.612, Validation accuracy:86.55%
# Epoch 124: iteration 125/126
# Epoch 124 --- loss:0.032, Epoch accuracy:98.59%, Validation loss:0.764, Validation accuracy:83.63%
# Epoch 125: iteration 125/126
# Epoch 125 --- loss:0.025, Epoch accuracy:98.77%, Validation loss:0.657, Validation accuracy:87.72%
# Epoch 126: iteration 125/126
# Epoch 126 --- loss:0.031, Epoch accuracy:98.74%, Validation loss:0.552, Validation accuracy:87.13%
# Epoch 127: iteration 125/126
# Epoch 127 --- loss:0.041, Epoch accuracy:98.35%, Validation loss:0.667, Validation accuracy:85.38%
# Epoch 128: iteration 125/126
# Epoch 128 --- loss:0.038, Epoch accuracy:98.47%, Validation loss:0.573, Validation accuracy:87.72%
# Epoch 129: iteration 125/126
# Epoch 129 --- loss:0.020, Epoch accuracy:99.09%, Validation loss:0.676, Validation accuracy:86.55%
# Epoch 130: iteration 125/126
# Epoch 130 --- loss:0.031, Epoch accuracy:98.67%, Validation loss:0.677, Validation accuracy:84.21%
# Epoch 131: iteration 125/126
# Epoch 131 --- loss:0.034, Epoch accuracy:98.37%, Validation loss:0.818, Validation accuracy:82.46%
# Epoch 132: iteration 125/126
# Epoch 132 --- loss:0.027, Epoch accuracy:98.69%, Validation loss:0.597, Validation accuracy:86.55%
# Epoch 133: iteration 125/126
# Epoch 133 --- loss:0.018, Epoch accuracy:99.11%, Validation loss:0.688, Validation accuracy:85.96%
# Epoch 134: iteration 125/126
# Epoch 134 --- loss:0.013, Epoch accuracy:99.31%, Validation loss:0.583, Validation accuracy:85.96%
# Epoch 135: iteration 125/126
# Epoch 135 --- loss:0.018, Epoch accuracy:99.14%, Validation loss:0.748, Validation accuracy:85.96%
# Epoch 136: iteration 125/126
# Epoch 136 --- loss:0.020, Epoch accuracy:99.09%, Validation loss:0.638, Validation accuracy:87.13%
# Epoch 137: iteration 125/126
# Epoch 137 --- loss:0.012, Epoch accuracy:99.31%, Validation loss:0.540, Validation accuracy:89.47%
# Epoch 138: iteration 125/126
# Epoch 138 --- loss:0.010, Epoch accuracy:99.46%, Validation loss:0.595, Validation accuracy:86.55%
# Epoch 139: iteration 125/126
# Epoch 139 --- loss:0.016, Epoch accuracy:99.14%, Validation loss:0.594, Validation accuracy:88.30%
# Epoch 140: iteration 125/126
# Epoch 140 --- loss:0.055, Epoch accuracy:97.65%, Validation loss:0.584, Validation accuracy:88.30%
# Epoch 141: iteration 125/126
# Epoch 141 --- loss:0.029, Epoch accuracy:98.54%, Validation loss:0.876, Validation accuracy:83.63%
# Epoch 142: iteration 125/126
# Epoch 142 --- loss:0.054, Epoch accuracy:97.75%, Validation loss:0.501, Validation accuracy:90.64%
# Epoch 143: iteration 125/126
# Epoch 143 --- loss:0.041, Epoch accuracy:98.15%, Validation loss:0.571, Validation accuracy:90.64%
# Epoch 144: iteration 125/126
# Epoch 144 --- loss:0.020, Epoch accuracy:99.19%, Validation loss:0.633, Validation accuracy:89.47%
# Epoch 145: iteration 125/126
# Epoch 145 --- loss:0.019, Epoch accuracy:99.14%, Validation loss:0.663, Validation accuracy:89.47%
# Epoch 146: iteration 125/126
# Epoch 146 --- loss:0.023, Epoch accuracy:98.89%, Validation loss:0.670, Validation accuracy:87.72%
# Epoch 147: iteration 125/126
# Epoch 147 --- loss:0.046, Epoch accuracy:98.00%, Validation loss:0.829, Validation accuracy:80.70%
# Epoch 148: iteration 125/126
# Epoch 148 --- loss:0.031, Epoch accuracy:98.64%, Validation loss:0.774, Validation accuracy:88.30%
# Epoch 149: iteration 125/126
# Epoch 149 --- loss:0.013, Epoch accuracy:99.36%, Validation loss:0.650, Validation accuracy:87.72%
# Epoch 150: iteration 125/126
# Epoch 150 --- loss:0.013, Epoch accuracy:99.33%, Validation loss:0.609, Validation accuracy:88.89%
# Epoch 151: iteration 125/126
# Epoch 151 --- loss:0.023, Epoch accuracy:98.77%, Validation loss:0.642, Validation accuracy:85.38%
# Epoch 152: iteration 125/126
# Epoch 152 --- loss:0.041, Epoch accuracy:98.22%, Validation loss:0.676, Validation accuracy:85.38%
# Epoch 153: iteration 125/126
# Epoch 153 --- loss:0.024, Epoch accuracy:98.96%, Validation loss:0.512, Validation accuracy:89.47%
# Epoch 154: iteration 125/126
# Epoch 154 --- loss:0.035, Epoch accuracy:98.27%, Validation loss:0.834, Validation accuracy:84.21%
# Epoch 155: iteration 125/126
# Epoch 155 --- loss:0.051, Epoch accuracy:97.90%, Validation loss:0.687, Validation accuracy:85.96%
# Epoch 156: iteration 125/126
# Epoch 156 --- loss:0.031, Epoch accuracy:98.77%, Validation loss:0.528, Validation accuracy:88.89%
# Epoch 157: iteration 125/126
# Epoch 157 --- loss:0.022, Epoch accuracy:98.99%, Validation loss:0.654, Validation accuracy:87.13%
# Epoch 158: iteration 125/126
# Epoch 158 --- loss:0.012, Epoch accuracy:99.43%, Validation loss:0.600, Validation accuracy:88.30%
# Epoch 159: iteration 125/126
# Epoch 159 --- loss:0.010, Epoch accuracy:99.46%, Validation loss:0.705, Validation accuracy:86.55%
# Epoch 160: iteration 125/126
# Epoch 160 --- loss:0.013, Epoch accuracy:99.28%, Validation loss:0.630, Validation accuracy:85.38%
# Epoch 161: iteration 125/126
# Epoch 161 --- loss:0.061, Epoch accuracy:97.36%, Validation loss:0.748, Validation accuracy:83.04%
# Epoch 162: iteration 125/126
# Epoch 162 --- loss:0.044, Epoch accuracy:98.05%, Validation loss:0.643, Validation accuracy:87.13%
# Epoch 163: iteration 125/126
# Epoch 163 --- loss:0.013, Epoch accuracy:99.41%, Validation loss:0.618, Validation accuracy:87.13%
# Epoch 164: iteration 125/126
# Epoch 164 --- loss:0.010, Epoch accuracy:99.46%, Validation loss:0.544, Validation accuracy:87.72%
# Epoch 165: iteration 125/126
# Epoch 165 --- loss:0.010, Epoch accuracy:99.51%, Validation loss:0.593, Validation accuracy:87.13%
# Epoch 166: iteration 125/126
# Epoch 166 --- loss:0.020, Epoch accuracy:99.01%, Validation loss:0.699, Validation accuracy:84.80%
# Epoch 167: iteration 125/126
# Epoch 167 --- loss:0.049, Epoch accuracy:98.00%, Validation loss:0.669, Validation accuracy:87.13%
# Epoch 168: iteration 125/126
# Epoch 168 --- loss:0.026, Epoch accuracy:98.94%, Validation loss:0.758, Validation accuracy:85.38%
# Epoch 169: iteration 125/126
# Epoch 169 --- loss:0.029, Epoch accuracy:98.69%, Validation loss:0.626, Validation accuracy:89.47%
# Epoch 170: iteration 125/126
# Epoch 170 --- loss:0.023, Epoch accuracy:98.94%, Validation loss:0.530, Validation accuracy:90.06%
# Epoch 171: iteration 125/126
# Epoch 171 --- loss:0.030, Epoch accuracy:98.69%, Validation loss:0.625, Validation accuracy:88.89%
# Epoch 172: iteration 125/126
# Epoch 172 --- loss:0.016, Epoch accuracy:99.16%, Validation loss:0.493, Validation accuracy:88.89%
# Epoch 173: iteration 125/126
# Epoch 173 --- loss:0.013, Epoch accuracy:99.31%, Validation loss:0.655, Validation accuracy:88.30%
# Epoch 174: iteration 125/126
# Epoch 174 --- loss:0.011, Epoch accuracy:99.46%, Validation loss:0.571, Validation accuracy:88.30%
# Epoch 175: iteration 125/126
# Epoch 175 --- loss:0.018, Epoch accuracy:99.04%, Validation loss:0.514, Validation accuracy:88.30%
# Epoch 176: iteration 125/126
# Epoch 176 --- loss:0.079, Epoch accuracy:96.74%, Validation loss:0.785, Validation accuracy:85.38%
# Epoch 177: iteration 125/126
# Epoch 177 --- loss:0.024, Epoch accuracy:99.01%, Validation loss:0.515, Validation accuracy:89.47%
# Epoch 178: iteration 125/126
# Epoch 178 --- loss:0.030, Epoch accuracy:98.57%, Validation loss:0.565, Validation accuracy:88.89%
# Epoch 179: iteration 125/126
# Epoch 179 --- loss:0.040, Epoch accuracy:98.22%, Validation loss:0.982, Validation accuracy:80.70%
# Epoch 180: iteration 125/126
# Epoch 180 --- loss:0.043, Epoch accuracy:98.00%, Validation loss:0.608, Validation accuracy:88.30%
# Epoch 181: iteration 125/126
# Epoch 181 --- loss:0.014, Epoch accuracy:99.36%, Validation loss:0.554, Validation accuracy:88.30%
# Epoch 182: iteration 125/126
# Epoch 182 --- loss:0.017, Epoch accuracy:99.06%, Validation loss:0.699, Validation accuracy:85.38%
# Epoch 183: iteration 125/126
# Epoch 183 --- loss:0.009, Epoch accuracy:99.51%, Validation loss:0.581, Validation accuracy:87.72%
# Epoch 184: iteration 125/126
# Epoch 184 --- loss:0.014, Epoch accuracy:99.31%, Validation loss:0.653, Validation accuracy:88.30%
# Epoch 185: iteration 125/126
# Epoch 185 --- loss:0.022, Epoch accuracy:98.96%, Validation loss:0.785, Validation accuracy:84.80%
# Epoch 186: iteration 125/126
# Epoch 186 --- loss:0.033, Epoch accuracy:98.52%, Validation loss:0.701, Validation accuracy:86.55%
# Epoch 187: iteration 125/126
# Epoch 187 --- loss:0.042, Epoch accuracy:98.20%, Validation loss:0.706, Validation accuracy:83.63%
# Epoch 188: iteration 125/126
# Epoch 188 --- loss:0.050, Epoch accuracy:97.73%, Validation loss:0.415, Validation accuracy:90.64%
# Epoch 189: iteration 125/126
# Epoch 189 --- loss:0.013, Epoch accuracy:99.38%, Validation loss:0.530, Validation accuracy:87.72%
# Epoch 190: iteration 125/126
# Epoch 190 --- loss:0.028, Epoch accuracy:98.74%, Validation loss:0.467, Validation accuracy:87.13%
# Epoch 191: iteration 125/126
# Epoch 191 --- loss:0.018, Epoch accuracy:99.14%, Validation loss:0.437, Validation accuracy:88.30%
# Epoch 192: iteration 125/126
# Epoch 192 --- loss:0.016, Epoch accuracy:99.14%, Validation loss:0.531, Validation accuracy:88.89%
# Epoch 193: iteration 125/126
# Epoch 193 --- loss:0.009, Epoch accuracy:99.41%, Validation loss:0.551, Validation accuracy:88.30%
# Epoch 194: iteration 125/126
# Epoch 194 --- loss:0.009, Epoch accuracy:99.43%, Validation loss:0.519, Validation accuracy:88.30%
# Epoch 195: iteration 125/126
# Epoch 195 --- loss:0.021, Epoch accuracy:98.99%, Validation loss:0.534, Validation accuracy:87.72%
# Epoch 196: iteration 125/126
# Epoch 196 --- loss:0.017, Epoch accuracy:99.09%, Validation loss:0.573, Validation accuracy:88.89%
# Epoch 197: iteration 125/126
# Epoch 197 --- loss:0.022, Epoch accuracy:98.94%, Validation loss:0.666, Validation accuracy:85.38%
# Epoch 198: iteration 125/126
# Epoch 198 --- loss:0.009, Epoch accuracy:99.51%, Validation loss:0.593, Validation accuracy:87.13%
# Epoch 199: iteration 125/126
# Epoch 199 --- loss:0.010, Epoch accuracy:99.38%, Validation loss:0.760, Validation accuracy:84.21%
# Epoch 200: iteration 125/126
# Epoch 200 --- loss:0.115, Epoch accuracy:95.36%, Validation loss:0.807, Validation accuracy:84.21%
# Epoch 201: iteration 125/126
# Epoch 201 --- loss:0.035, Epoch accuracy:98.57%, Validation loss:0.698, Validation accuracy:86.55%
# Epoch 202: iteration 125/126
# Epoch 202 --- loss:0.029, Epoch accuracy:98.72%, Validation loss:0.679, Validation accuracy:84.21%
# Epoch 203: iteration 125/126
# Epoch 203 --- loss:0.015, Epoch accuracy:99.31%, Validation loss:0.564, Validation accuracy:87.72%
# Epoch 204: iteration 125/126
# Epoch 204 --- loss:0.013, Epoch accuracy:99.33%, Validation loss:0.522, Validation accuracy:88.30%
# Epoch 205: iteration 125/126
# Epoch 205 --- loss:0.009, Epoch accuracy:99.48%, Validation loss:0.572, Validation accuracy:88.30%
# Epoch 206: iteration 125/126
# Epoch 206 --- loss:0.008, Epoch accuracy:99.51%, Validation loss:0.578, Validation accuracy:87.72%
# Epoch 207: iteration 125/126
# Epoch 207 --- loss:0.014, Epoch accuracy:99.28%, Validation loss:0.614, Validation accuracy:87.72%
# Epoch 208: iteration 125/126
# Epoch 208 --- loss:0.012, Epoch accuracy:99.33%, Validation loss:0.558, Validation accuracy:87.72%
# Epoch 209: iteration 125/126
# Epoch 209 --- loss:0.014, Epoch accuracy:99.23%, Validation loss:0.673, Validation accuracy:86.55%
# Epoch 210: iteration 125/126
# Epoch 210 --- loss:0.010, Epoch accuracy:99.46%, Validation loss:0.634, Validation accuracy:85.96%
# Epoch 211: iteration 125/126
# Epoch 211 --- loss:0.017, Epoch accuracy:99.16%, Validation loss:0.709, Validation accuracy:86.55%
# Epoch 212: iteration 125/126
# Epoch 212 --- loss:0.053, Epoch accuracy:97.31%, Validation loss:0.742, Validation accuracy:84.21%
# Epoch 213: iteration 125/126
# Epoch 213 --- loss:0.047, Epoch accuracy:97.85%, Validation loss:0.922, Validation accuracy:79.53%
# Epoch 214: iteration 125/126
# Epoch 214 --- loss:0.032, Epoch accuracy:98.62%, Validation loss:0.790, Validation accuracy:84.21%
# Epoch 215: iteration 125/126
# Epoch 215 --- loss:0.049, Epoch accuracy:98.05%, Validation loss:0.612, Validation accuracy:87.72%
# Epoch 216: iteration 125/126
# Epoch 216 --- loss:0.039, Epoch accuracy:98.30%, Validation loss:0.686, Validation accuracy:84.80%
# Epoch 217: iteration 125/126
# Epoch 217 --- loss:0.028, Epoch accuracy:98.77%, Validation loss:0.580, Validation accuracy:90.64%
# Epoch 218: iteration 125/126
# Epoch 218 --- loss:0.015, Epoch accuracy:99.23%, Validation loss:0.595, Validation accuracy:88.30%
# Epoch 219: iteration 125/126
# Epoch 219 --- loss:0.013, Epoch accuracy:99.31%, Validation loss:0.631, Validation accuracy:87.72%
# Epoch 220: iteration 125/126
# Epoch 220 --- loss:0.027, Epoch accuracy:98.91%, Validation loss:0.602, Validation accuracy:88.30%
# Epoch 221: iteration 125/126
# Epoch 221 --- loss:0.023, Epoch accuracy:99.04%, Validation loss:0.557, Validation accuracy:84.80%
# Epoch 222: iteration 125/126
# Epoch 222 --- loss:0.010, Epoch accuracy:99.41%, Validation loss:0.562, Validation accuracy:88.89%
# Epoch 223: iteration 125/126
# Epoch 223 --- loss:0.054, Epoch accuracy:97.80%, Validation loss:0.801, Validation accuracy:82.46%
# Epoch 224: iteration 125/126
# Epoch 224 --- loss:0.021, Epoch accuracy:99.06%, Validation loss:0.603, Validation accuracy:87.72%
# Epoch 225: iteration 125/126
# Epoch 225 --- loss:0.022, Epoch accuracy:98.94%, Validation loss:0.693, Validation accuracy:85.38%
# Epoch 226: iteration 125/126
# Epoch 226 --- loss:0.041, Epoch accuracy:98.02%, Validation loss:0.617, Validation accuracy:88.30%
# Epoch 227: iteration 125/126
# Epoch 227 --- loss:0.038, Epoch accuracy:98.30%, Validation loss:0.645, Validation accuracy:85.38%
# Epoch 228: iteration 125/126
# Epoch 228 --- loss:0.016, Epoch accuracy:99.21%, Validation loss:0.655, Validation accuracy:88.89%
# Epoch 229: iteration 125/126
# Epoch 229 --- loss:0.009, Epoch accuracy:99.51%, Validation loss:0.621, Validation accuracy:88.30%
# Epoch 230: iteration 125/126
# Epoch 230 --- loss:0.008, Epoch accuracy:99.48%, Validation loss:0.601, Validation accuracy:90.06%
# Epoch 231: iteration 125/126
# Epoch 231 --- loss:0.007, Epoch accuracy:99.51%, Validation loss:0.612, Validation accuracy:89.47%
# Epoch 232: iteration 125/126
# Epoch 232 --- loss:0.024, Epoch accuracy:98.86%, Validation loss:0.622, Validation accuracy:87.13%
# Epoch 233: iteration 125/126
# Epoch 233 --- loss:0.093, Epoch accuracy:96.54%, Validation loss:0.637, Validation accuracy:83.04%
# Epoch 234: iteration 125/126
# Epoch 234 --- loss:0.036, Epoch accuracy:98.30%, Validation loss:0.645, Validation accuracy:88.89%
# Epoch 235: iteration 125/126
# Epoch 235 --- loss:0.018, Epoch accuracy:99.26%, Validation loss:0.605, Validation accuracy:87.72%
# Epoch 236: iteration 125/126
# Epoch 236 --- loss:0.014, Epoch accuracy:99.38%, Validation loss:0.587, Validation accuracy:88.89%
# Epoch 237: iteration 125/126
# Epoch 237 --- loss:0.017, Epoch accuracy:99.23%, Validation loss:0.666, Validation accuracy:88.30%
# Epoch 238: iteration 125/126
# Epoch 238 --- loss:0.013, Epoch accuracy:99.38%, Validation loss:0.669, Validation accuracy:87.72%
# Epoch 239: iteration 125/126
# Epoch 239 --- loss:0.006, Epoch accuracy:99.53%, Validation loss:0.611, Validation accuracy:87.72%
# Epoch 240: iteration 125/126
# Epoch 240 --- loss:0.012, Epoch accuracy:99.28%, Validation loss:0.625, Validation accuracy:87.72%
# Epoch 241: iteration 125/126
# Epoch 241 --- loss:0.011, Epoch accuracy:99.38%, Validation loss:0.583, Validation accuracy:87.72%
# Epoch 242: iteration 125/126
# Epoch 242 --- loss:0.014, Epoch accuracy:99.26%, Validation loss:0.585, Validation accuracy:87.13%
# Epoch 243: iteration 125/126
# Epoch 243 --- loss:0.023, Epoch accuracy:98.86%, Validation loss:1.053, Validation accuracy:79.53%
# Epoch 244: iteration 125/126
# Epoch 244 --- loss:0.073, Epoch accuracy:96.86%, Validation loss:0.721, Validation accuracy:82.46%
# Epoch 245: iteration 125/126
# Epoch 245 --- loss:0.049, Epoch accuracy:97.78%, Validation loss:0.647, Validation accuracy:87.13%
# Epoch 246: iteration 125/126
# Epoch 246 --- loss:0.018, Epoch accuracy:99.19%, Validation loss:0.472, Validation accuracy:86.55%
# Epoch 247: iteration 125/126
# Epoch 247 --- loss:0.017, Epoch accuracy:99.11%, Validation loss:0.712, Validation accuracy:85.38%
# Epoch 248: iteration 125/126
# Epoch 248 --- loss:0.013, Epoch accuracy:99.38%, Validation loss:0.554, Validation accuracy:87.13%
# Epoch 249: iteration 125/126
# Epoch 249 --- loss:0.027, Epoch accuracy:98.77%, Validation loss:0.600, Validation accuracy:87.72%
# Epoch 250: iteration 125/126
# Epoch 250 --- loss:0.022, Epoch accuracy:98.86%, Validation loss:0.613, Validation accuracy:87.13%
# Epoch 251: iteration 125/126
# Epoch 251 --- loss:0.014, Epoch accuracy:99.26%, Validation loss:0.651, Validation accuracy:87.13%
# Epoch 252: iteration 125/126
# Epoch 252 --- loss:0.011, Epoch accuracy:99.31%, Validation loss:0.609, Validation accuracy:89.47%
# Epoch 253: iteration 125/126
# Epoch 253 --- loss:0.007, Epoch accuracy:99.51%, Validation loss:0.587, Validation accuracy:88.89%
# Epoch 254: iteration 125/126
# Epoch 254 --- loss:0.005, Epoch accuracy:99.53%, Validation loss:0.631, Validation accuracy:87.13%
# Epoch 255: iteration 125/126
# Epoch 255 --- loss:0.015, Epoch accuracy:99.23%, Validation loss:0.605, Validation accuracy:88.30%
# Epoch 256: iteration 125/126
# Epoch 256 --- loss:0.047, Epoch accuracy:97.95%, Validation loss:0.623, Validation accuracy:85.38%
# Epoch 257: iteration 125/126
# Epoch 257 --- loss:0.046, Epoch accuracy:97.83%, Validation loss:0.672, Validation accuracy:85.38%
# Epoch 258: iteration 125/126
# Epoch 258 --- loss:0.022, Epoch accuracy:98.91%, Validation loss:0.563, Validation accuracy:86.55%
# Epoch 259: iteration 125/126
# Epoch 259 --- loss:0.019, Epoch accuracy:99.14%, Validation loss:0.619, Validation accuracy:86.55%
# Epoch 260: iteration 125/126
# Epoch 260 --- loss:0.018, Epoch accuracy:99.11%, Validation loss:0.628, Validation accuracy:85.38%
# Epoch 261: iteration 125/126
# Epoch 261 --- loss:0.046, Epoch accuracy:98.17%, Validation loss:0.712, Validation accuracy:85.96%
# Epoch 262: iteration 125/126
# Epoch 262 --- loss:0.044, Epoch accuracy:98.05%, Validation loss:0.635, Validation accuracy:87.72%
# Epoch 263: iteration 125/126
# Epoch 263 --- loss:0.082, Epoch accuracy:96.99%, Validation loss:0.562, Validation accuracy:85.38%
# Epoch 264: iteration 125/126
# Epoch 264 --- loss:0.025, Epoch accuracy:99.01%, Validation loss:0.627, Validation accuracy:84.80%
# Epoch 265: iteration 125/126
# Epoch 265 --- loss:0.012, Epoch accuracy:99.41%, Validation loss:0.540, Validation accuracy:86.55%
# Epoch 266: iteration 125/126
# Epoch 266 --- loss:0.015, Epoch accuracy:99.23%, Validation loss:0.577, Validation accuracy:86.55%
# Epoch 267: iteration 125/126
# Epoch 267 --- loss:0.009, Epoch accuracy:99.46%, Validation loss:0.661, Validation accuracy:86.55%
# Epoch 268: iteration 125/126
# Epoch 268 --- loss:0.006, Epoch accuracy:99.53%, Validation loss:0.660, Validation accuracy:87.13%
# Epoch 269: iteration 125/126
# Epoch 269 --- loss:0.014, Epoch accuracy:99.31%, Validation loss:0.553, Validation accuracy:88.30%
# Epoch 270: iteration 125/126
# Epoch 270 --- loss:0.016, Epoch accuracy:99.23%, Validation loss:0.767, Validation accuracy:84.21%
# Epoch 271: iteration 125/126
# Epoch 271 --- loss:0.074, Epoch accuracy:96.99%, Validation loss:0.615, Validation accuracy:86.55%
# Epoch 272: iteration 125/126
# Epoch 272 --- loss:0.031, Epoch accuracy:98.64%, Validation loss:0.620, Validation accuracy:83.04%
# Epoch 273: iteration 125/126
# Epoch 273 --- loss:0.028, Epoch accuracy:98.86%, Validation loss:0.913, Validation accuracy:79.53%
# Epoch 274: iteration 125/126
# Epoch 274 --- loss:0.038, Epoch accuracy:98.32%, Validation loss:0.547, Validation accuracy:89.47%
# Epoch 275: iteration 125/126
# Epoch 275 --- loss:0.013, Epoch accuracy:99.33%, Validation loss:0.600, Validation accuracy:85.38%
# Epoch 276: iteration 125/126
# Epoch 276 --- loss:0.020, Epoch accuracy:99.06%, Validation loss:0.557, Validation accuracy:88.30%
# Epoch 277: iteration 125/126
# Epoch 277 --- loss:0.008, Epoch accuracy:99.48%, Validation loss:0.582, Validation accuracy:88.30%
# Epoch 278: iteration 125/126
# Epoch 278 --- loss:0.019, Epoch accuracy:99.04%, Validation loss:0.671, Validation accuracy:85.96%
# Epoch 279: iteration 125/126
# Epoch 279 --- loss:0.012, Epoch accuracy:99.23%, Validation loss:0.525, Validation accuracy:87.13%
# Epoch 280: iteration 125/126
# Epoch 280 --- loss:0.041, Epoch accuracy:98.12%, Validation loss:0.602, Validation accuracy:85.38%
# Epoch 281: iteration 125/126
# Epoch 281 --- loss:0.010, Epoch accuracy:99.43%, Validation loss:0.804, Validation accuracy:81.87%
# Epoch 282: iteration 125/126
# Epoch 282 --- loss:0.013, Epoch accuracy:99.33%, Validation loss:0.610, Validation accuracy:87.72%
# Epoch 283: iteration 125/126
# Epoch 283 --- loss:0.019, Epoch accuracy:99.16%, Validation loss:0.670, Validation accuracy:83.63%
# Epoch 284: iteration 125/126
# Epoch 284 --- loss:0.021, Epoch accuracy:99.09%, Validation loss:0.685, Validation accuracy:86.55%
# Epoch 285: iteration 125/126
# Epoch 285 --- loss:0.033, Epoch accuracy:98.47%, Validation loss:0.643, Validation accuracy:87.72%
# Epoch 286: iteration 125/126
# Epoch 286 --- loss:0.025, Epoch accuracy:98.86%, Validation loss:0.713, Validation accuracy:86.55%
# Epoch 287: iteration 125/126
# Epoch 287 --- loss:0.045, Epoch accuracy:97.90%, Validation loss:1.008, Validation accuracy:78.36%
# Epoch 288: iteration 125/126
# Epoch 288 --- loss:0.060, Epoch accuracy:97.80%, Validation loss:0.784, Validation accuracy:84.80%
# Epoch 289: iteration 125/126
# Epoch 289 --- loss:0.026, Epoch accuracy:98.67%, Validation loss:0.574, Validation accuracy:85.38%
# Epoch 290: iteration 125/126
# Epoch 290 --- loss:0.033, Epoch accuracy:98.44%, Validation loss:0.655, Validation accuracy:86.55%
# Epoch 291: iteration 125/126
# Epoch 291 --- loss:0.040, Epoch accuracy:98.30%, Validation loss:0.680, Validation accuracy:83.63%
# Epoch 292: iteration 125/126
# Epoch 292 --- loss:0.037, Epoch accuracy:98.47%, Validation loss:0.668, Validation accuracy:88.89%
# Epoch 293: iteration 125/126
# Epoch 293 --- loss:0.017, Epoch accuracy:99.19%, Validation loss:0.655, Validation accuracy:85.96%
# Epoch 294: iteration 125/126
# Epoch 294 --- loss:0.021, Epoch accuracy:98.96%, Validation loss:0.626, Validation accuracy:87.13%
# Epoch 295: iteration 125/126
# Epoch 295 --- loss:0.019, Epoch accuracy:99.11%, Validation loss:0.709, Validation accuracy:82.46%
# Epoch 296: iteration 125/126
# Epoch 296 --- loss:0.019, Epoch accuracy:98.94%, Validation loss:0.648, Validation accuracy:86.55%
# Epoch 297: iteration 125/126
# Epoch 297 --- loss:0.041, Epoch accuracy:97.98%, Validation loss:0.745, Validation accuracy:84.21%
# Epoch 298: iteration 125/126
# Epoch 298 --- loss:0.031, Epoch accuracy:98.62%, Validation loss:0.623, Validation accuracy:89.47%
# Epoch 299: iteration 125/126
# Epoch 299 --- loss:0.022, Epoch accuracy:98.89%, Validation loss:0.533, Validation accuracy:88.30%
# Epoch 300: iteration 125/126
# Epoch 300 --- loss:0.013, Epoch accuracy:99.26%, Validation loss:0.630, Validation accuracy:85.96%
# Epoch 301: iteration 125/126
# Epoch 301 --- loss:0.008, Epoch accuracy:99.46%, Validation loss:0.619, Validation accuracy:89.47%
# Epoch 302: iteration 125/126
# Epoch 302 --- loss:0.018, Epoch accuracy:98.99%, Validation loss:0.628, Validation accuracy:85.38%
# Epoch 303: iteration 125/126
# Epoch 303 --- loss:0.015, Epoch accuracy:99.16%, Validation loss:0.585, Validation accuracy:87.72%
# Epoch 304: iteration 125/126
# Epoch 304 --- loss:0.037, Epoch accuracy:98.42%, Validation loss:0.657, Validation accuracy:86.55%
# Epoch 305: iteration 125/126
# Epoch 305 --- loss:0.020, Epoch accuracy:99.04%, Validation loss:0.630, Validation accuracy:87.13%
# Epoch 306: iteration 125/126
# Epoch 306 --- loss:0.019, Epoch accuracy:98.99%, Validation loss:0.622, Validation accuracy:86.55%
# Epoch 307: iteration 125/126
# Epoch 307 --- loss:0.010, Epoch accuracy:99.46%, Validation loss:0.636, Validation accuracy:86.55%
# Epoch 308: iteration 125/126
# Epoch 308 --- loss:0.011, Epoch accuracy:99.36%, Validation loss:0.597, Validation accuracy:87.13%
# Epoch 309: iteration 125/126
# Epoch 309 --- loss:0.040, Epoch accuracy:98.47%, Validation loss:0.586, Validation accuracy:87.72%
# Epoch 310: iteration 125/126
# Epoch 310 --- loss:0.041, Epoch accuracy:98.25%, Validation loss:0.727, Validation accuracy:85.38%
# Epoch 311: iteration 125/126
# Epoch 311 --- loss:0.038, Epoch accuracy:98.32%, Validation loss:0.689, Validation accuracy:87.72%
# Epoch 312: iteration 125/126
# Epoch 312 --- loss:0.027, Epoch accuracy:98.74%, Validation loss:0.697, Validation accuracy:86.55%
# Epoch 313: iteration 125/126
# Epoch 313 --- loss:0.023, Epoch accuracy:98.77%, Validation loss:0.698, Validation accuracy:85.96%
# Epoch 314: iteration 125/126
# Epoch 314 --- loss:0.021, Epoch accuracy:98.91%, Validation loss:0.706, Validation accuracy:83.63%
# Epoch 315: iteration 125/126
# Epoch 315 --- loss:0.028, Epoch accuracy:98.72%, Validation loss:0.576, Validation accuracy:87.72%
# Epoch 316: iteration 125/126
# Epoch 316 --- loss:0.022, Epoch accuracy:98.94%, Validation loss:0.613, Validation accuracy:85.96%
# Epoch 317: iteration 125/126
# Epoch 317 --- loss:0.055, Epoch accuracy:97.68%, Validation loss:0.591, Validation accuracy:85.38%
# Epoch 318: iteration 125/126
# Epoch 318 --- loss:0.032, Epoch accuracy:98.72%, Validation loss:0.699, Validation accuracy:83.04%
# Epoch 319: iteration 125/126
# Epoch 319 --- loss:0.052, Epoch accuracy:97.73%, Validation loss:0.794, Validation accuracy:81.29%
# Epoch 320: iteration 125/126
# Epoch 320 --- loss:0.058, Epoch accuracy:97.46%, Validation loss:0.710, Validation accuracy:84.21%
# Epoch 321: iteration 125/126
# Epoch 321 --- loss:0.024, Epoch accuracy:98.96%, Validation loss:0.705, Validation accuracy:84.21%
# Epoch 322: iteration 125/126
# Epoch 322 --- loss:0.022, Epoch accuracy:99.06%, Validation loss:0.700, Validation accuracy:88.30%
# Epoch 323: iteration 125/126
# Epoch 323 --- loss:0.013, Epoch accuracy:99.28%, Validation loss:0.609, Validation accuracy:85.96%
# Epoch 324: iteration 125/126
# Epoch 324 --- loss:0.009, Epoch accuracy:99.41%, Validation loss:0.653, Validation accuracy:85.96%
# Epoch 325: iteration 125/126
# Epoch 325 --- loss:0.007, Epoch accuracy:99.48%, Validation loss:0.643, Validation accuracy:85.96%
# Epoch 326: iteration 125/126
# Epoch 326 --- loss:0.022, Epoch accuracy:98.72%, Validation loss:0.585, Validation accuracy:86.55%
# Epoch 327: iteration 125/126
# Epoch 327 --- loss:0.022, Epoch accuracy:98.94%, Validation loss:0.631, Validation accuracy:84.80%
# Epoch 328: iteration 125/126
# Epoch 328 --- loss:0.020, Epoch accuracy:98.77%, Validation loss:0.670, Validation accuracy:88.30%
# Epoch 329: iteration 125/126
# Epoch 329 --- loss:0.024, Epoch accuracy:98.89%, Validation loss:0.624, Validation accuracy:85.96%
# Epoch 330: iteration 125/126
# Epoch 330 --- loss:0.012, Epoch accuracy:99.31%, Validation loss:0.652, Validation accuracy:87.13%
# Epoch 331: iteration 125/126
# Epoch 331 --- loss:0.007, Epoch accuracy:99.48%, Validation loss:0.650, Validation accuracy:84.21%
# Epoch 332: iteration 125/126
# Epoch 332 --- loss:0.016, Epoch accuracy:99.14%, Validation loss:0.608, Validation accuracy:88.89%
# Epoch 333: iteration 125/126
# Epoch 333 --- loss:0.011, Epoch accuracy:99.36%, Validation loss:0.698, Validation accuracy:85.96%
# Epoch 334: iteration 125/126
# Epoch 334 --- loss:0.013, Epoch accuracy:99.31%, Validation loss:0.778, Validation accuracy:85.38%
# Epoch 335: iteration 125/126
# Epoch 335 --- loss:0.036, Epoch accuracy:98.07%, Validation loss:0.623, Validation accuracy:86.55%
# Epoch 336: iteration 125/126
# Epoch 336 --- loss:0.049, Epoch accuracy:98.00%, Validation loss:0.556, Validation accuracy:90.64%
# Epoch 337: iteration 125/126
# Epoch 337 --- loss:0.026, Epoch accuracy:98.86%, Validation loss:0.528, Validation accuracy:88.30%
# Epoch 338: iteration 125/126
# Epoch 338 --- loss:0.009, Epoch accuracy:99.48%, Validation loss:0.532, Validation accuracy:89.47%
# Epoch 339: iteration 125/126
# Epoch 339 --- loss:0.026, Epoch accuracy:98.77%, Validation loss:0.629, Validation accuracy:87.72%
# Epoch 340: iteration 125/126
# Epoch 340 --- loss:0.011, Epoch accuracy:99.41%, Validation loss:0.590, Validation accuracy:86.55%
# Epoch 341: iteration 125/126
# Epoch 341 --- loss:0.009, Epoch accuracy:99.48%, Validation loss:0.611, Validation accuracy:88.30%
# Epoch 342: iteration 125/126
# Epoch 342 --- loss:0.067, Epoch accuracy:97.01%, Validation loss:0.518, Validation accuracy:87.72%
# Epoch 343: iteration 125/126
# Epoch 343 --- loss:0.037, Epoch accuracy:98.42%, Validation loss:0.711, Validation accuracy:80.12%
# Epoch 344: iteration 125/126
# Epoch 344 --- loss:0.047, Epoch accuracy:98.27%, Validation loss:0.622, Validation accuracy:85.96%
# Epoch 345: iteration 125/126
# Epoch 345 --- loss:0.027, Epoch accuracy:98.69%, Validation loss:0.640, Validation accuracy:85.96%
# Epoch 346: iteration 125/126
# Epoch 346 --- loss:0.015, Epoch accuracy:99.26%, Validation loss:0.592, Validation accuracy:85.96%
# Epoch 347: iteration 125/126
# Epoch 347 --- loss:0.019, Epoch accuracy:99.09%, Validation loss:0.603, Validation accuracy:85.38%
# Epoch 348: iteration 125/126
# Epoch 348 --- loss:0.030, Epoch accuracy:98.47%, Validation loss:0.621, Validation accuracy:87.13%
# Epoch 349: iteration 125/126
# Epoch 349 --- loss:0.012, Epoch accuracy:99.26%, Validation loss:0.644, Validation accuracy:87.13%

# %%
plt.title('Loss Curve for Parallel is All You Want Model')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_losses[:],'b')
plt.plot(valid_losses[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()

# %%
# pick load folder  
load_folder = 'checkpoint'  

# pick the epoch to load
epoch = '269'
model_name = f'parallel_all_you_wantFINAL-{epoch}.pkl'

# make full load path
load_path = os.path.join(load_folder, model_name)

## instantiate empty model and populate with params from binary 
model = parallel_all_you_want(len(emotions_dict))
load_checkpoint(optimizer, model, load_path)

print(f'Loaded model from {load_path}')
# Out:
# Loaded model from checkpoint/parallel_all_you_wantFINAL-269.pkl

# %%
# reinitialize validation function with model from chosen checkpoint
validate = make_validate_fnc(model,criterion)

# Convert 4D test feature set array to tensor and move to GPU
X_test_tensor = torch.tensor(X_test,device=device).float()
# Convert 4D test label set array to tensor and move to GPU
y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
inputs =  X_test_tensor                     # this is what you had
labels =  y_test_tensor
#inputs, labels = inputs.cuda(), labels.cuda() # add this line
# Get the model's performance metrics using the validation function we defined

#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

#inputs, labels = inputs.to(device), labels.to(device)
model.to('cuda') 
inputs = inputs.to('cuda')

model.to('cuda') 
labels = labels.to('cuda')

test_loss, test_acc, predicted_emotions = validate(X_test_tensor,y_test_tensor)

print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test accuracy is 80.12%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

# because model tested on GPU, move prediction tensor to CPU then convert to array
predicted_emotions = predicted_emotions.cpu().numpy()
# use labels from test set
emotions_groundtruth = y_test

# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

# set labels for matrix axes from emotions
emotion_names = [emotion for emotion in emotions_dict.values()]

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
# Out:
# <AxesSubplot:title={'center':'Normalized Confusion Matrix'}>
