# %%
pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.7/dist-packages (1.5.1)

# %%
pip install torchsummaryX
# Out:
# Collecting torchsummaryX
#   Downloading torchsummaryX-1.3.0-py3-none-any.whl (3.6 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchsummaryX) (1.10.0+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchsummaryX) (1.21.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torchsummaryX) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torchsummaryX) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torchsummaryX) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torchsummaryX) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchsummaryX) (3.10.0.2)
# Installing collected packages: torchsummaryX
# Successfully installed torchsummaryX-1.3.0

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.8.0)

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, glob
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import warnings; warnings.filterwarnings('ignore') #matplot lib complains about librosa

# %%
# needed to import dataset from google drive into colab 
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# RAVDESS native sample rate is 48k
sample_rate = 48000

# Mel Spectrograms are not directly used as a feature in this model
# Mel Spectrograms are used in calculating MFCCs, which are a higher-level representation of pitch transition
# MFCCs work better - left the mel spectrogram function here in case anyone wants to experiment
def feature_melspectrogram(
    waveform, 
    sample_rate,
    fft = 1024,
    winlen = 512,
    window='hamming',
    hop=256,
    mels=128,
    ):
    
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram = librosa.feature.melspectrogram(
        y=waveform, 
        sr=sample_rate, 
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2)
    
    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms 
    melspectrogram = librosa.power_to_db(melspectrogram, ref=np.max)
    
    return melspectrogram

def feature_mfcc(
    waveform, 
    sample_rate,
    n_mfcc = 40,
    fft = 1024,
    winlen = 512,
    window='hamming',
    #hop=256, # increases # of time steps; was not helpful
    mels=128
    ):

    # Compute the MFCCs for all STFT frames 
    # 40 mel filterbanks (n_mfcc) = 40 coefficients
    mfc_coefficients=librosa.feature.mfcc(
        y=waveform, 
        sr=sample_rate, 
        n_mfcc=n_mfcc,
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        #hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2
        ) 

    return mfc_coefficients

def get_features(waveforms, features, samplerate):

    # initialize counter to track progress
    file_count = 0

    # process each waveform individually to get its MFCCs
    for waveform in waveforms:
        mfccs = feature_mfcc(waveform, sample_rate)
        features.append(mfccs)
        file_count += 1
        # print progress 
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')
    
    # return all features from list of waveforms
    return features

def get_waveforms(file):
    
    # load an individual sample audio file
    # read the full 3 seconds of the file, cut off the first 0.5s of silence; native sample rate = 48k
    # don't need to store the sample rate that librosa.load returns
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)
    
    # make sure waveform vectors are homogenous by defining explicitly
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform
    
    # return a single file's waveform                                      
    return waveform_homo
    
# RAVDESS dataset emotions
# shift emotions left to be 0 indexed for PyTorch
emotions_dict ={
    '0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
   '7':'disgust'
}

# Additional attributes from RAVDESS to play with
emotion_attributes = {
    '01': 'normal',
    '02': 'strong'
}

# %%
# path to data for glob
data_path = '/content/drive/My Drive/data_set/RAVDESS_speech'

##'RAVDESS dataset/Actor_*/*.wav'
dir_list = os.listdir(data_path)
dir_list.sort()
dir_list
# Out:
# ['Actor_01',
#  'Actor_02',
#  'Actor_03',
#  'Actor_04',
#  'Actor_05',
#  'Actor_06',
#  'Actor_07',
#  'Actor_08',
#  'Actor_09',
#  'Actor_10',
#  'Actor_11',
#  'Actor_12',
#  'Actor_13',
#  'Actor_14',
#  'Actor_15',
#  'Actor_16',
#  'Actor_17',
#  'Actor_18',
#  'Actor_19',
#  'Actor_20',
#  'Actor_21',
#  'Actor_22',
#  'Actor_23',
#  'Actor_24']

# %%
def load_data():
  # features and labels
  emotions = []
  # raw waveforms to augment later
  waveforms = []
  # extra labels
  intensities, genders = [],[]
  # progress counter
  file_count = 0
  
  for i in dir_list:
    #print(i)
    file_name = os.listdir(data_path + '/' +i+'/')
    for file in file_name:
     # print(file)
      #print(file_name)
      file=data_path + '/' +i+'/'+file
      nm = file.split('.')[0].split('-')
      # get emotion label from the sample's file
      emotion = int(nm[2])
      #  move surprise to 0 for cleaner behaviour with PyTorch/0-indexing
      if emotion == 8: emotion = 0 # surprise is now at 0 index; other emotion indeces unchanged


      if emotion == 1:  continue

      # can convert emotion label to emotion string if desired, but
      # training on number is better; better convert to emotion string after predictions are ready
      # emotion = emotions_dict[str(emotion)]
            
      # get other labels we might want
      #intensity = emotion_attributes[int(nm[3])]
      if nm[3] == '01':
            intensity = 0
      else:
            intensity = 1
      # even actors are female, odd are male
      if (int((file.split("-")[6]).split(".")[0]))%2==0: 
          gender = 'female' 
      else: 
          gender = 'male'
                
      # get waveform from the sample
      waveform = get_waveforms(file)
            
      # store waveforms and labels
      waveforms.append(waveform)
      emotions.append(emotion)
      intensities.append(intensity) # store intensity in case we wish to predict
      genders.append(gender) # store gender in case we wish to predict 
            
      file_count += 1
    
      # keep track of data loader's progress
      print('\r'+f' Processed {file_count}/{1440} audio samples',end='')
    

  return waveforms, emotions, intensities, genders

# %%
# load data 
# init explicitly to prevent data leakage from past sessions, since load_data() appends
waveforms, emotions, intensities, genders = [],[],[],[]
waveforms, emotions, intensities, genders = load_data()
# Out:
#  Processed 1344/1440 audio samples

# %%
print(f'Waveforms set: {len(waveforms)} samples')
# we have 1440 waveforms but we need to know their length too; should be 3 sec * 48k = 144k
print(f'Waveform signal length: {len(waveforms[0])}')
print(f'Emotions set: {len(emotions)} sample labels')
# Out:
# Waveforms set: 1344 samples
# Waveform signal length: 144000
# Emotions set: 1344 sample labels

# %%
# create storage for train, validation, test sets and their indices
train_set,valid_set,test_set = [],[],[]
X_train,X_valid,X_test = [],[],[]
y_train,y_valid,y_test = [],[],[]

# convert waveforms to array for processing
waveforms = np.array(waveforms)

# process each emotion separately to make sure we builf balanced train/valid/test sets 
for emotion_num in range(len(emotions_dict)):
        
    # find all indices of a single unique emotion
    emotion_indices = [index for index, emotion in enumerate(emotions) if emotion==emotion_num]

    # seed for reproducibility 
    np.random.seed(69)
    # shuffle indicies 
    emotion_indices = np.random.permutation(emotion_indices)

    # store dim (length) of the emotion list to make indices
    dim = len(emotion_indices)

    # store indices of training, validation and test sets in 80/10/10 proportion
    # train set is first 80%
    train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
    valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
    test_indices = emotion_indices[int(0.9*dim):]

    # create train waveforms/labels sets
    X_train.append(waveforms[train_indices,:])
    y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
    X_valid.append(waveforms[valid_indices,:])
    y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
    X_test.append(waveforms[test_indices,:])
    y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets 
    train_set.append(train_indices)
    valid_set.append(valid_indices)
    test_set.append(test_indices)

# concatenate, in order, all waveforms back into one array 
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array 
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

# make sure train, validation, test sets have no overlap/are unique
# get all unique indices across all sets and how many times each index appears (count)
uniques, count = np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)

# if each index appears just once, and we have 1440 such unique indices, then all sets are unique
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-2e0cfff176ab> in <module>()
#      30
#      31     # create train waveforms/labels sets
# ---> 32     X_train.append(waveforms[train_indices,:])
#      33     y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
#      34     # create validation waveforms/labels sets
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
# initialize feature arrays
# We extract MFCC features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features 
features_train = get_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = get_features(X_valid, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features 
features_test = get_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'Features (MFC coefficient matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')

# %%
def awgn_augmentation(waveform, multiples=2, bits=16, snr_min=15, snr_max=30): 
    
    # get length of waveform (should be 3*48k = 144k)
    wave_len = len(waveform)
    
    # Generate normally distributed (Gaussian) noises
    # one for each waveform and multiple (i.e. wave_len*multiples noises)
    noise = np.random.normal(size=(multiples, wave_len))
    
    # Normalize waveform and noise
    norm_constant = 2.0**(bits-1)
    norm_wave = waveform / norm_constant
    norm_noise = noise / norm_constant
    
    # Compute power of waveform and power of noise
    signal_power = np.sum(norm_wave ** 2) / wave_len
    noise_power = np.sum(norm_noise ** 2, axis=1) / wave_len
    
    # Choose random SNR in decibels in range [15,30]
    snr = np.random.randint(snr_min, snr_max)
    
    # Apply whitening transformation: make the Gaussian noise into Gaussian white noise
    # Compute the covariance matrix used to whiten each noise 
    # actual SNR = signal/noise (power)
    # actual noise power = 10**(-snr/10)
    covariance = np.sqrt((signal_power / noise_power) * 10 ** (- snr / 10))
    # Get covariance matrix with dim: (144000, 2) so we can transform 2 noises: dim (2, 144000)
    covariance = np.ones((wave_len, multiples)) * covariance

    # Since covariance and noise are arrays, * is the haddamard product 
    # Take Haddamard product of covariance and noise to generate white noise
    multiple_augmented_waveforms = waveform + covariance.T * noise
    
    return multiple_augmented_waveforms
def augment_waveforms(waveforms, features, emotions, multiples):
    # keep track of how many waveforms we've processed so we can add correct emotion label in the same order
    emotion_count = 0
    # keep track of how many augmented samples we've added
    added_count = 0
    # convert emotion array to list for more efficient appending
    emotions = emotions.tolist()

    for waveform in waveforms:

        # Generate 2 augmented multiples of the dataset, i.e. 1440 native + 1440*2 noisy = 4320 samples total
        augmented_waveforms = awgn_augmentation(waveform, multiples=multiples)

        # compute spectrogram for each of 2 augmented waveforms
        for augmented_waveform in augmented_waveforms:

            # Compute MFCCs over augmented waveforms
            augmented_mfcc = feature_mfcc(augmented_waveform, sample_rate=sample_rate)

            # append the augmented spectrogram to the rest of the native data
            features.append(augmented_mfcc)
            emotions.append(emotions[emotion_count])

            # keep track of new augmented samples
            added_count += 1

            # check progress
            print('\r'+f'Processed {emotion_count + 1}/{len(waveforms)} waveforms for {added_count}/{len(waveforms)*multiples} new augmented samples',end='')

        # keep track of the emotion labels to append in order
        emotion_count += 1
        
        # store augmented waveforms to check their shape
        augmented_waveforms_temp.append(augmented_waveforms)
    
    return features, emotions

# %%
# store augmented waveforms to verify their shape and random-ness
augmented_waveforms_temp = []

# specify multiples of our dataset to add as augmented data
multiples = 2

print('Train waveforms:') # augment waveforms of training set
features_train , y_train = augment_waveforms(X_train, features_train, y_train, multiples)

print('\n\nValidation waveforms:') # augment waveforms of validation set
features_valid, y_valid = augment_waveforms(X_valid, features_valid, y_valid, multiples)

print('\n\nTest waveforms:') # augment waveforms of test set 
features_test, y_test = augment_waveforms(X_test, features_test, y_test, multiples)

# Check new shape of extracted features and data:
print(f'\n\nNative + Augmented Features set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'{len(y_train)} training sample labels, {len(y_valid)} validation sample labels, {len(y_test)} test sample labels')
print(f'Features (MFCC matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
# Processed 994/994 waveforms for 1988/1988 new augmented samples
#
# Validation waveforms:
# Processed 124/124 waveforms for 248/248 new augmented samples
#
# Test waveforms:
# Processed 130/130 waveforms for 260/260 new augmented samples
#
# Native + Augmented Features set: 3744 total, 2982 train, 372 validation, 390 test samples
# 2982 training sample labels, 372 validation sample labels, 390 test sample labels
# Features (MFCC matrix) shape: 40 mel frequency coefficients x 282 time steps

# %%
# pick a random waveform, but same one from native and augmented set for easier comparison
plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveplot(waveforms[12], sr=sample_rate)
plt.title('Native')

plt.subplot(1, 2, 2)
# augmented waveforms are 2D len 1440 list with 2 waveforms in each position
librosa.display.waveplot(augmented_waveforms_temp[0][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveplot(augmented_waveforms_temp[2][0], sr=sample_rate)
plt.title('AWGN Augmented')

plt.subplot(1, 2, 2)
librosa.display.waveplot(augmented_waveforms_temp[7][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

# %%
# need to make dummy input channel for CNN input feature tensor
X_train = np.expand_dims(features_train,1)
X_valid = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test,1)

# convert emotion labels from list back to numpy arrays for PyTorch to work with 
y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)

# confiorm that we have tensor-ready 4D data array
# should print (batch, channel, width, height) == (4320, 1, 128, 282) when multiples==2
print(f'Shape of 4D feature array for input tensor: {X_train.shape} train, {X_valid.shape} validation, {X_test.shape} test')
print(f'Shape of emotion labels: {y_train.shape} train, {y_valid.shape} validation, {y_test.shape} test')
# Out:
# Shape of 4D feature array for input tensor: (2982, 1, 40, 282) train, (372, 1, 40, 282) validation, (390, 1, 40, 282) test
# Shape of emotion labels: (2982,) train, (372,) validation, (390,) test

# %%
# free up some RAM - no longer need full feature set or any waveforms 
del features_train, features_valid, features_test, waveforms, augmented_waveforms_temp

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#### Scale the training data ####
# store shape so we can transform it back 
N,C,H,W = X_train.shape
# Reshape to 1D because StandardScaler operates on a 1D array
# tell numpy to infer shape of 1D array with '-1' argument
X_train = np.reshape(X_train, (N,-1)) 
X_train = scaler.fit_transform(X_train)
# Transform back to NxCxHxW 4D tensor format
X_train = np.reshape(X_train, (N,C,H,W))

##### Scale the validation set ####
N,C,H,W = X_valid.shape
X_valid = np.reshape(X_valid, (N,-1))
X_valid = scaler.transform(X_valid)
X_valid = np.reshape(X_valid, (N,C,H,W))

#### Scale the test set ####
N,C,H,W = X_test.shape
X_test = np.reshape(X_test, (N,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, (N,C,H,W))

# check shape of each set again
print(f'X_train scaled:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid scaled:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test scaled:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train scaled:(2982, 1, 40, 282), y_train:(2982,)
# X_valid scaled:(372, 1, 40, 282), y_valid:(372,)
# X_test scaled:(390, 1, 40, 282), y_test:(390,)

# %%
###### SAVE #########
# choose save file name 
filename = 'features+labels.npy'

# open file in write mode and write data
with open(filename, 'wb') as f:
    np.save(f, X_train)
    np.save(f, X_valid)
    np.save(f, X_test)
    np.save(f, y_train)
    np.save(f, y_valid)
    np.save(f, y_test)

print(f'Features and labels saved to {filename}')
# Out:
# Features and labels saved to features+labels.npy

# %%
##### LOAD #########
# choose load file name 
filename = 'features+labels.npy'

# open file in read mode and read data 
with open(filename, 'rb') as f:
    X_train = np.load(f)
    X_valid = np.load(f)
    X_test = np.load(f)
    y_train = np.load(f)
    y_valid = np.load(f)
    y_test = np.load(f)

# Check that we've recovered the right data
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train:(2982, 1, 40, 282), y_train:(2982,)
# X_valid:(372, 1, 40, 282), y_valid:(372,)
# X_test:(390, 1, 40, 282), y_test:(390,)

# %%
#change nn.sequential to take dict to make more readable 

class parallel_all_you_want(nn.Module):
    # Define all layers present in the network
    def __init__(self,num_emotions):
        super().__init__() 
        
        ################ TRANSFORMER BLOCK #############################
        # maxpool the input feature map/tensor to the transformer 
        # a rectangular kernel worked better here for the rectangular input spectrogram feature map/tensor
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1,4], stride=[1,4])
        
        # define single transformer encoder layer
        # self-attention + feedforward network from "Attention is All You Need" paper
        # 4 multi-head self-attention layers each with 40-->512--->40 feedforward network
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40, # input feature (frequency) dim after maxpooling 40*282 -> 40*70 (MFC*time)
            nhead=4, # 4 self-attention layers in each multi-head self-attention layer in each encoder block
            dim_feedforward=512, # 2 linear layers in each encoder block's feedforward network: dim 40-->512--->40
            dropout=0.4, 
            activation='relu' # ReLU: avoid saturation/tame gradient/reduce compute time
        )
        
        # I'm using 4 instead of the 6 identical stacked encoder layrs used in Attention is All You Need paper
        # Complete transformer block contains 4 full transformer encoder layers (each w/ multihead self-attention+feedforward)
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=4)
        
        ############### 1ST PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock1 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        ############### 2ND PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock2 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )

        ################# FINAL LINEAR BLOCK ####################
        # Linear softmax layer to take final concatenated embedding tensor 
        #    from parallel 2D convolutional and transformer blocks, output 8 logits 
        # Each full convolution block outputs (64*1*8) embedding flattened to dim 512 1D array 
        # Full transformer block outputs 40*70 feature map, which we time-avg to dim 40 1D array
        # 512*2+40 == 1064 input features --> 8 output emotions 
        self.fc1_linear = nn.Linear(512*2+40,num_emotions) 
        
        ### Softmax layer for the 8 output logits from final FC linear layer 
        self.softmax_out = nn.Softmax(dim=1) # dim==1 is the freq embedding
        
    # define one complete parallel fwd pass of input feature tensor thru 2*conv+1*transformer blocks
    def forward(self,x):
        
        ############ 1st parallel Conv2D block: 4 Convolutional layers ############################
        # create final feature embedding from 1st convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding1 = self.conv2Dblock1(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding1 = torch.flatten(conv2d_embedding1, start_dim=1) 
        
        ############ 2nd parallel Conv2D block: 4 Convolutional layers #############################
        # create final feature embedding from 2nd convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding2 = self.conv2Dblock2(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding2 = torch.flatten(conv2d_embedding2, start_dim=1) 
        
         
        ########## 4-encoder-layer Transformer block w/ 40-->512-->40 feedfwd network ##############
        # maxpool input feature map: 1*40*282 w/ 1*4 kernel --> 1*40*70
        x_maxpool = self.transformer_maxpool(x)

        # remove channel dim: 1*40*70 --> 40*70
        x_maxpool_reduced = torch.squeeze(x_maxpool,1)
        
        # convert maxpooled feature map format: batch * freq * time ---> time * batch * freq format
        # because transformer encoder layer requires tensor in format: time * batch * embedding (freq)
        x = x_maxpool_reduced.permute(2,0,1) 
        
        # finally, pass reduced input feature map x into transformer encoder layers
        transformer_output = self.transformer_encoder(x)
        
        # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
        # transformer outputs 2x40 (MFCC embedding*time) feature map, take mean of columns i.e. take time average
        transformer_embedding = torch.mean(transformer_output, dim=0) # dim 40x70 --> 40
        
        ############# concatenate freq embeddings from convolutional and transformer blocks ######
        # concatenate embedding tensors output by parallel 2*conv and 1*transformer blocks
        complete_embedding = torch.cat([conv2d_embedding1, conv2d_embedding2,transformer_embedding], dim=1)  

        ######### final FC linear layer, need logits for loss #########################
        output_logits = self.fc1_linear(complete_embedding)  
        
        ######### Final Softmax layer: use logits from FC linear, get softmax for prediction ######
        output_softmax = self.softmax_out(output_logits)
        
        # need output logits to compute cross entropy loss, need softmax probabilities to predict class
        return output_logits, output_softmax

# %%
import keras
#from keras import torchsummary

# need device to instantiate model
device = 'cuda'

# instantiate model for 8 emotions and move to GPU 
model = parallel_all_you_want(len(emotions_dict)).to(device)

# include input feature map dims in call to summary()
#torchsummary.summary(model, input_size=(1,40,282))
#model.summary()

# %%
# define loss function; CrossEntropyLoss() fairly standard for multiclass problems 
def criterion(predictions, targets): 
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# %%
# define function to create a single step of the training phase
def make_train_step(model, criterion, optimizer):
    
    # define the training step of the training phase
    def train_step(X,Y):
        
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        
        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y) 
        
        # compute gradients for the optimizer to use 
        loss.backward()
        
        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()
        
        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad() 
        
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,criterion):
    def validate(X,Y):
        
        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase: 
        with torch.no_grad(): 
            
            # set model to validation phase i.e. turn off dropout and batchnorm layers 
            model.eval()
      
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            
            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits,Y)
            
        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint(): 
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint

def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
# get training set size to calculate # iterations and minibatch indices
train_size = X_train.shape[0]

# pick minibatch size (of 32... always)
minibatch = 32

# set device to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'{device} selected')

# instantiate model and move to GPU for training
model = parallel_all_you_want(num_emotions=len(emotions_dict)).to(device) 
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )

# encountered bugs in google colab only, unless I explicitly defined optimizer in this cell...
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# instantiate the checkpoint save function
save_checkpoint = make_save_checkpoint()

# instantiate the training step function 
train_step = make_train_step(model, criterion, optimizer=optimizer)

# instantiate the validation loop function
validate = make_validate_fnc(model,criterion)

# instantiate lists to hold scalar performance metrics to plot later
train_losses=[]
valid_losses = []

# create training loop for one complete epoch (entire training set)
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):

    for epoch in range(num_epochs):
        
        # set model to train phase
        model.train()         
        
        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size) 
        
        # shuffle the training set for each epoch:
        X_train = X_train[train_indices,:,:,:] 
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate 
        epoch_acc = 0 
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)
        
        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):
            
            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch 
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size) 
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start 
            
            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:] 
            # get training minibatch labels 
            Y = Y_train[batch_start:batch_end] 

            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float() 
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor,Y_tensor) 
            
            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size
            
            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}',end='')
        
        # create tensors from validation set
        X_valid_tensor = torch.tensor(X_valid,device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor,Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
                  
        # Save checkpoint of the model
        #checkpoint_filename = '/content/gdrive/My Drive/DL/models/checkpoints/parallel_all_you_wantFINAL-{:03d}.pkl'.format(epoch)
        checkpoint_filename = '/content/drive/My Drive/models/CNN_7_emotion/parallel_all_you_wantFINAL-{:03d}.pkl'.format(epoch)
        save_checkpoint(optimizer, model, epoch, checkpoint_filename)
        
        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')
# Out:
# cuda selected
# Number of trainable params:  247423

# %%
# choose number of epochs higher than reasonable so we can manually stop training 
num_epochs = 500

# train it!
cnnhistory=train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
# Out:
# Epoch 0: iteration 92/93
# Epoch 0 --- loss:3.358, Epoch accuracy:29.04%, Validation loss:2.036, Validation accuracy:27.96%
# Epoch 1: iteration 92/93
# Epoch 1 --- loss:1.559, Epoch accuracy:39.74%, Validation loss:1.745, Validation accuracy:34.41%
# Epoch 2: iteration 92/93
# Epoch 2 --- loss:1.452, Epoch accuracy:43.29%, Validation loss:1.513, Validation accuracy:40.32%
# Epoch 3: iteration 92/93
# Epoch 3 --- loss:1.403, Epoch accuracy:44.40%, Validation loss:1.562, Validation accuracy:35.75%
# Epoch 4: iteration 92/93
# Epoch 4 --- loss:1.314, Epoch accuracy:48.59%, Validation loss:1.805, Validation accuracy:40.59%
# Epoch 5: iteration 92/93
# Epoch 5 --- loss:1.247, Epoch accuracy:52.95%, Validation loss:1.503, Validation accuracy:47.04%
# Epoch 6: iteration 92/93
# Epoch 6 --- loss:1.183, Epoch accuracy:54.59%, Validation loss:1.331, Validation accuracy:52.42%
# Epoch 7: iteration 92/93
# Epoch 7 --- loss:1.086, Epoch accuracy:57.91%, Validation loss:1.296, Validation accuracy:51.88%
# Epoch 8: iteration 92/93
# Epoch 8 --- loss:1.041, Epoch accuracy:60.93%, Validation loss:1.281, Validation accuracy:52.42%
# Epoch 9: iteration 92/93
# Epoch 9 --- loss:0.990, Epoch accuracy:61.67%, Validation loss:1.242, Validation accuracy:52.15%
# Epoch 10: iteration 92/93
# Epoch 10 --- loss:0.931, Epoch accuracy:64.89%, Validation loss:1.295, Validation accuracy:50.81%
# Epoch 11: iteration 92/93
# Epoch 11 --- loss:0.881, Epoch accuracy:66.90%, Validation loss:1.231, Validation accuracy:55.91%
# Epoch 12: iteration 92/93
# Epoch 12 --- loss:0.821, Epoch accuracy:69.68%, Validation loss:1.264, Validation accuracy:54.30%
# Epoch 13: iteration 92/93
# Epoch 13 --- loss:0.796, Epoch accuracy:69.55%, Validation loss:1.235, Validation accuracy:56.18%
# Epoch 14: iteration 92/93
# Epoch 14 --- loss:0.758, Epoch accuracy:69.95%, Validation loss:1.046, Validation accuracy:62.90%
# Epoch 15: iteration 92/93
# Epoch 15 --- loss:0.709, Epoch accuracy:73.17%, Validation loss:1.071, Validation accuracy:61.02%
# Epoch 16: iteration 92/93
# Epoch 16 --- loss:0.680, Epoch accuracy:74.35%, Validation loss:1.082, Validation accuracy:62.37%
# Epoch 17: iteration 92/93
# Epoch 17 --- loss:0.629, Epoch accuracy:77.03%, Validation loss:1.163, Validation accuracy:57.53%
# Epoch 18: iteration 92/93
# Epoch 18 --- loss:0.584, Epoch accuracy:78.37%, Validation loss:1.208, Validation accuracy:58.87%
# Epoch 19: iteration 92/93
# Epoch 19 --- loss:0.576, Epoch accuracy:77.83%, Validation loss:1.008, Validation accuracy:65.32%
# Epoch 20: iteration 92/93
# Epoch 20 --- loss:0.545, Epoch accuracy:79.98%, Validation loss:1.034, Validation accuracy:61.02%
# Epoch 21: iteration 92/93
# Epoch 21 --- loss:0.494, Epoch accuracy:81.89%, Validation loss:1.164, Validation accuracy:61.29%
# Epoch 22: iteration 92/93
# Epoch 22 --- loss:0.463, Epoch accuracy:82.83%, Validation loss:1.149, Validation accuracy:63.71%
# Epoch 23: iteration 92/93
# Epoch 23 --- loss:0.440, Epoch accuracy:83.00%, Validation loss:1.168, Validation accuracy:63.17%
# Epoch 24: iteration 92/93
# Epoch 24 --- loss:0.414, Epoch accuracy:84.64%, Validation loss:1.141, Validation accuracy:62.63%
# Epoch 25: iteration 92/93
# Epoch 25 --- loss:0.422, Epoch accuracy:85.28%, Validation loss:1.093, Validation accuracy:64.25%
# Epoch 26: iteration 92/93
# Epoch 26 --- loss:0.366, Epoch accuracy:86.52%, Validation loss:1.298, Validation accuracy:59.68%
# Epoch 27: iteration 92/93
# Epoch 27 --- loss:0.342, Epoch accuracy:88.03%, Validation loss:1.205, Validation accuracy:65.86%
# Epoch 28: iteration 92/93
# Epoch 28 --- loss:0.368, Epoch accuracy:87.32%, Validation loss:1.131, Validation accuracy:63.71%
# Epoch 29: iteration 92/93
# Epoch 29 --- loss:0.338, Epoch accuracy:87.29%, Validation loss:1.155, Validation accuracy:64.25%
# Epoch 30: iteration 92/93
# Epoch 30 --- loss:0.311, Epoch accuracy:88.60%, Validation loss:1.158, Validation accuracy:64.52%
# Epoch 31: iteration 92/93
# Epoch 31 --- loss:0.307, Epoch accuracy:88.67%, Validation loss:1.260, Validation accuracy:62.90%
# Epoch 32: iteration 92/93
# Epoch 32 --- loss:0.302, Epoch accuracy:89.17%, Validation loss:1.139, Validation accuracy:65.32%
# Epoch 33: iteration 92/93
# Epoch 33 --- loss:0.263, Epoch accuracy:90.44%, Validation loss:1.328, Validation accuracy:65.32%
# Epoch 34: iteration 92/93
# Epoch 34 --- loss:0.269, Epoch accuracy:90.07%, Validation loss:1.180, Validation accuracy:65.05%
# Epoch 35: iteration 92/93
# Epoch 35 --- loss:0.219, Epoch accuracy:91.92%, Validation loss:1.217, Validation accuracy:64.78%
# Epoch 36: iteration 92/93
# Epoch 36 --- loss:0.224, Epoch accuracy:92.19%, Validation loss:1.514, Validation accuracy:59.41%
# Epoch 37: iteration 92/93
# Epoch 37 --- loss:0.214, Epoch accuracy:92.52%, Validation loss:1.154, Validation accuracy:64.52%
# Epoch 38: iteration 92/93
# Epoch 38 --- loss:0.239, Epoch accuracy:91.18%, Validation loss:1.364, Validation accuracy:59.68%
# Epoch 39: iteration 92/93
# Epoch 39 --- loss:0.219, Epoch accuracy:92.25%, Validation loss:1.357, Validation accuracy:62.37%
# Epoch 40: iteration 92/93
# Epoch 40 --- loss:0.225, Epoch accuracy:91.45%, Validation loss:1.425, Validation accuracy:64.52%
# Epoch 41: iteration 92/93
# Epoch 41 --- loss:0.187, Epoch accuracy:93.33%, Validation loss:1.374, Validation accuracy:64.78%
# Epoch 42: iteration 92/93
# Epoch 42 --- loss:0.165, Epoch accuracy:94.30%, Validation loss:1.547, Validation accuracy:61.02%
# Epoch 43: iteration 92/93
# Epoch 43 --- loss:0.211, Epoch accuracy:92.42%, Validation loss:1.326, Validation accuracy:63.44%
# Epoch 44: iteration 92/93
# Epoch 44 --- loss:0.164, Epoch accuracy:94.43%, Validation loss:1.409, Validation accuracy:61.29%
# Epoch 45: iteration 92/93
# Epoch 45 --- loss:0.164, Epoch accuracy:93.80%, Validation loss:1.402, Validation accuracy:64.25%
# Epoch 46: iteration 92/93
# Epoch 46 --- loss:0.154, Epoch accuracy:94.63%, Validation loss:1.364, Validation accuracy:64.25%
# Epoch 47: iteration 92/93
# Epoch 47 --- loss:0.171, Epoch accuracy:94.03%, Validation loss:1.331, Validation accuracy:67.20%
# Epoch 48: iteration 92/93
# Epoch 48 --- loss:0.152, Epoch accuracy:94.50%, Validation loss:1.434, Validation accuracy:65.05%
# Epoch 49: iteration 92/93
# Epoch 49 --- loss:0.139, Epoch accuracy:95.47%, Validation loss:1.375, Validation accuracy:65.05%
# Epoch 50: iteration 92/93
# Epoch 50 --- loss:0.162, Epoch accuracy:94.27%, Validation loss:1.506, Validation accuracy:62.90%
# Epoch 51: iteration 92/93
# Epoch 51 --- loss:0.141, Epoch accuracy:95.27%, Validation loss:1.341, Validation accuracy:65.59%
# Epoch 52: iteration 92/93
# Epoch 52 --- loss:0.131, Epoch accuracy:95.24%, Validation loss:1.381, Validation accuracy:63.98%
# Epoch 53: iteration 92/93
# Epoch 53 --- loss:0.140, Epoch accuracy:95.20%, Validation loss:1.533, Validation accuracy:64.78%
# Epoch 54: iteration 92/93
# Epoch 54 --- loss:0.123, Epoch accuracy:95.71%, Validation loss:1.632, Validation accuracy:59.95%
# Epoch 55: iteration 92/93
# Epoch 55 --- loss:0.115, Epoch accuracy:96.04%, Validation loss:1.419, Validation accuracy:64.52%
# Epoch 56: iteration 92/93
# Epoch 56 --- loss:0.118, Epoch accuracy:96.34%, Validation loss:1.634, Validation accuracy:61.56%
# Epoch 57: iteration 92/93
# Epoch 57 --- loss:0.119, Epoch accuracy:95.91%, Validation loss:1.410, Validation accuracy:65.32%
# Epoch 58: iteration 92/93
# Epoch 58 --- loss:0.117, Epoch accuracy:96.14%, Validation loss:1.557, Validation accuracy:65.59%
# Epoch 59: iteration 92/93
# Epoch 59 --- loss:0.107, Epoch accuracy:96.58%, Validation loss:1.614, Validation accuracy:63.71%
# Epoch 60: iteration 92/93
# Epoch 60 --- loss:0.101, Epoch accuracy:96.75%, Validation loss:1.600, Validation accuracy:63.44%
# Epoch 61: iteration 92/93
# Epoch 61 --- loss:0.102, Epoch accuracy:96.98%, Validation loss:1.560, Validation accuracy:63.98%
# Epoch 62: iteration 92/93
# Epoch 62 --- loss:0.094, Epoch accuracy:97.12%, Validation loss:1.520, Validation accuracy:65.32%
# Epoch 63: iteration 92/93
# Epoch 63 --- loss:0.101, Epoch accuracy:96.78%, Validation loss:1.431, Validation accuracy:65.86%
# Epoch 64: iteration 92/93
# Epoch 64 --- loss:0.124, Epoch accuracy:95.31%, Validation loss:1.578, Validation accuracy:64.78%
# Epoch 65: iteration 92/93
# Epoch 65 --- loss:0.080, Epoch accuracy:97.22%, Validation loss:1.399, Validation accuracy:68.01%
# Epoch 66: iteration 92/93
# Epoch 66 --- loss:0.085, Epoch accuracy:97.32%, Validation loss:1.345, Validation accuracy:66.67%
# Epoch 67: iteration 92/93
# Epoch 67 --- loss:0.099, Epoch accuracy:96.88%, Validation loss:1.676, Validation accuracy:65.05%
# Epoch 68: iteration 92/93
# Epoch 68 --- loss:0.087, Epoch accuracy:96.95%, Validation loss:1.571, Validation accuracy:66.94%
# Epoch 69: iteration 92/93
# Epoch 69 --- loss:0.080, Epoch accuracy:97.65%, Validation loss:1.329, Validation accuracy:67.47%
# Epoch 70: iteration 92/93
# Epoch 70 --- loss:0.095, Epoch accuracy:96.48%, Validation loss:1.390, Validation accuracy:66.67%
# Epoch 71: iteration 92/93
# Epoch 71 --- loss:0.081, Epoch accuracy:97.32%, Validation loss:1.580, Validation accuracy:69.35%
# Epoch 72: iteration 92/93
# Epoch 72 --- loss:0.090, Epoch accuracy:96.85%, Validation loss:1.564, Validation accuracy:67.74%
# Epoch 73: iteration 92/93
# Epoch 73 --- loss:0.075, Epoch accuracy:97.62%, Validation loss:1.471, Validation accuracy:67.74%
# Epoch 74: iteration 92/93
# Epoch 74 --- loss:0.077, Epoch accuracy:97.52%, Validation loss:1.483, Validation accuracy:67.20%
# Epoch 75: iteration 92/93
# Epoch 75 --- loss:0.057, Epoch accuracy:98.59%, Validation loss:1.524, Validation accuracy:67.20%
# Epoch 76: iteration 92/93
# Epoch 76 --- loss:0.075, Epoch accuracy:97.69%, Validation loss:1.408, Validation accuracy:67.20%
# Epoch 77: iteration 92/93
# Epoch 77 --- loss:0.078, Epoch accuracy:97.69%, Validation loss:1.789, Validation accuracy:61.83%
# Epoch 78: iteration 92/93
# Epoch 78 --- loss:0.074, Epoch accuracy:97.48%, Validation loss:1.502, Validation accuracy:66.40%
# Epoch 79: iteration 92/93
# Epoch 79 --- loss:0.068, Epoch accuracy:97.92%, Validation loss:1.559, Validation accuracy:66.67%
# Epoch 80: iteration 92/93
# Epoch 80 --- loss:0.069, Epoch accuracy:98.02%, Validation loss:1.714, Validation accuracy:66.94%
# Epoch 81: iteration 92/93
# Epoch 81 --- loss:0.060, Epoch accuracy:98.09%, Validation loss:1.579, Validation accuracy:66.40%
# Epoch 82: iteration 92/93
# Epoch 82 --- loss:0.074, Epoch accuracy:97.62%, Validation loss:1.570, Validation accuracy:67.47%
# Epoch 83: iteration 92/93
# Epoch 83 --- loss:0.060, Epoch accuracy:98.12%, Validation loss:1.532, Validation accuracy:66.94%
# Epoch 84: iteration 92/93
# Epoch 84 --- loss:0.073, Epoch accuracy:97.38%, Validation loss:1.584, Validation accuracy:68.28%
# Epoch 85: iteration 92/93
# Epoch 85 --- loss:0.071, Epoch accuracy:97.82%, Validation loss:1.571, Validation accuracy:66.67%
# Epoch 86: iteration 92/93
# Epoch 86 --- loss:0.054, Epoch accuracy:98.39%, Validation loss:1.754, Validation accuracy:66.13%
# Epoch 87: iteration 92/93
# Epoch 87 --- loss:0.056, Epoch accuracy:98.02%, Validation loss:1.609, Validation accuracy:66.67%
# Epoch 88: iteration 92/93
# Epoch 88 --- loss:0.043, Epoch accuracy:98.99%, Validation loss:1.449, Validation accuracy:68.82%
# Epoch 89: iteration 92/93
# Epoch 89 --- loss:0.056, Epoch accuracy:98.32%, Validation loss:1.583, Validation accuracy:66.67%
# Epoch 90: iteration 92/93
# Epoch 90 --- loss:0.056, Epoch accuracy:98.26%, Validation loss:1.489, Validation accuracy:67.74%
# Epoch 91: iteration 92/93
# Epoch 91 --- loss:0.050, Epoch accuracy:98.59%, Validation loss:1.511, Validation accuracy:66.94%
# Epoch 92: iteration 92/93
# Epoch 92 --- loss:0.051, Epoch accuracy:98.56%, Validation loss:1.549, Validation accuracy:65.86%
# Epoch 93: iteration 92/93
# Epoch 93 --- loss:0.045, Epoch accuracy:98.79%, Validation loss:1.576, Validation accuracy:68.01%
# Epoch 94: iteration 92/93
# Epoch 94 --- loss:0.053, Epoch accuracy:98.29%, Validation loss:1.619, Validation accuracy:65.86%
# Epoch 95: iteration 92/93
# Epoch 95 --- loss:0.061, Epoch accuracy:98.19%, Validation loss:1.556, Validation accuracy:66.94%
# Epoch 96: iteration 92/93
# Epoch 96 --- loss:0.051, Epoch accuracy:98.66%, Validation loss:1.694, Validation accuracy:66.13%
# Epoch 97: iteration 92/93
# Epoch 97 --- loss:0.055, Epoch accuracy:98.29%, Validation loss:1.620, Validation accuracy:67.74%
# Epoch 98: iteration 92/93
# Epoch 98 --- loss:0.045, Epoch accuracy:98.73%, Validation loss:1.621, Validation accuracy:64.78%
# Epoch 99: iteration 92/93
# Epoch 99 --- loss:0.040, Epoch accuracy:98.86%, Validation loss:1.555, Validation accuracy:68.01%
# Epoch 100: iteration 92/93
# Epoch 100 --- loss:0.038, Epoch accuracy:99.09%, Validation loss:1.636, Validation accuracy:66.13%
# Epoch 101: iteration 92/93
# Epoch 101 --- loss:0.039, Epoch accuracy:98.93%, Validation loss:1.707, Validation accuracy:67.74%
# Epoch 102: iteration 92/93
# Epoch 102 --- loss:0.038, Epoch accuracy:99.03%, Validation loss:1.695, Validation accuracy:63.98%
# Epoch 103: iteration 92/93
# Epoch 103 --- loss:0.044, Epoch accuracy:98.49%, Validation loss:1.495, Validation accuracy:66.13%
# Epoch 104: iteration 92/93
# Epoch 104 --- loss:0.047, Epoch accuracy:98.69%, Validation loss:1.716, Validation accuracy:66.67%
# Epoch 105: iteration 92/93
# Epoch 105 --- loss:0.044, Epoch accuracy:98.89%, Validation loss:1.589, Validation accuracy:68.28%
# Epoch 106: iteration 92/93
# Epoch 106 --- loss:0.049, Epoch accuracy:98.36%, Validation loss:1.720, Validation accuracy:67.47%
# Epoch 107: iteration 92/93
# Epoch 107 --- loss:0.053, Epoch accuracy:98.26%, Validation loss:1.601, Validation accuracy:69.62%
# Epoch 108: iteration 92/93
# Epoch 108 --- loss:0.055, Epoch accuracy:98.22%, Validation loss:1.712, Validation accuracy:66.94%
# Epoch 109: iteration 92/93
# Epoch 109 --- loss:0.040, Epoch accuracy:98.89%, Validation loss:1.661, Validation accuracy:66.67%
# Epoch 110: iteration 92/93
# Epoch 110 --- loss:0.036, Epoch accuracy:98.99%, Validation loss:1.621, Validation accuracy:66.13%
# Epoch 111: iteration 92/93
# Epoch 111 --- loss:0.044, Epoch accuracy:98.93%, Validation loss:1.621, Validation accuracy:66.67%
# Epoch 112: iteration 92/93
# Epoch 112 --- loss:0.043, Epoch accuracy:98.46%, Validation loss:1.596, Validation accuracy:67.47%
# Epoch 113: iteration 92/93
# Epoch 113 --- loss:0.044, Epoch accuracy:98.69%, Validation loss:1.583, Validation accuracy:66.94%
# Epoch 114: iteration 92/93
# Epoch 114 --- loss:0.032, Epoch accuracy:99.26%, Validation loss:1.548, Validation accuracy:66.13%
# Epoch 115: iteration 92/93
# Epoch 115 --- loss:0.060, Epoch accuracy:98.02%, Validation loss:1.637, Validation accuracy:66.94%
# Epoch 116: iteration 92/93
# Epoch 116 --- loss:0.032, Epoch accuracy:99.20%, Validation loss:1.524, Validation accuracy:66.67%
# Epoch 117: iteration 92/93
# Epoch 117 --- loss:0.034, Epoch accuracy:99.16%, Validation loss:1.596, Validation accuracy:66.94%
# Epoch 118: iteration 92/93
# Epoch 118 --- loss:0.031, Epoch accuracy:99.26%, Validation loss:1.511, Validation accuracy:67.20%
# Epoch 119: iteration 92/93
# Epoch 119 --- loss:0.045, Epoch accuracy:98.46%, Validation loss:1.525, Validation accuracy:66.67%
# Epoch 120: iteration 92/93
# Epoch 120 --- loss:0.040, Epoch accuracy:98.66%, Validation loss:1.668, Validation accuracy:67.74%
# Epoch 121: iteration 92/93
# Epoch 121 --- loss:0.041, Epoch accuracy:98.66%, Validation loss:1.483, Validation accuracy:66.40%
# Epoch 122: iteration 92/93
# Epoch 122 --- loss:0.037, Epoch accuracy:98.79%, Validation loss:1.568, Validation accuracy:66.67%
# Epoch 123: iteration 92/93
# Epoch 123 --- loss:0.040, Epoch accuracy:98.86%, Validation loss:1.469, Validation accuracy:69.09%
# Epoch 124: iteration 92/93
# Epoch 124 --- loss:0.033, Epoch accuracy:98.96%, Validation loss:1.589, Validation accuracy:67.47%
# Epoch 125: iteration 92/93
# Epoch 125 --- loss:0.032, Epoch accuracy:99.16%, Validation loss:1.715, Validation accuracy:67.47%
# Epoch 126: iteration 92/93
# Epoch 126 --- loss:0.032, Epoch accuracy:99.09%, Validation loss:1.617, Validation accuracy:69.09%
# Epoch 127: iteration 92/93
# Epoch 127 --- loss:0.023, Epoch accuracy:99.56%, Validation loss:1.610, Validation accuracy:68.55%
# Epoch 128: iteration 92/93
# Epoch 128 --- loss:0.035, Epoch accuracy:99.03%, Validation loss:1.641, Validation accuracy:66.67%
# Epoch 129: iteration 92/93
# Epoch 129 --- loss:0.026, Epoch accuracy:99.23%, Validation loss:1.624, Validation accuracy:68.28%
# Epoch 130: iteration 92/93
# Epoch 130 --- loss:0.027, Epoch accuracy:99.43%, Validation loss:1.668, Validation accuracy:66.67%
# Epoch 131: iteration 92/93
# Epoch 131 --- loss:0.024, Epoch accuracy:99.56%, Validation loss:1.681, Validation accuracy:68.01%
# Epoch 132: iteration 92/93
# Epoch 132 --- loss:0.037, Epoch accuracy:98.96%, Validation loss:1.598, Validation accuracy:66.67%
# Epoch 133: iteration 92/93
# Epoch 133 --- loss:0.033, Epoch accuracy:99.06%, Validation loss:1.623, Validation accuracy:68.01%
# Epoch 134: iteration 92/93
# Epoch 134 --- loss:0.025, Epoch accuracy:99.46%, Validation loss:1.624, Validation accuracy:68.82%
# Epoch 135: iteration 92/93
# Epoch 135 --- loss:0.028, Epoch accuracy:99.26%, Validation loss:1.653, Validation accuracy:67.74%
# Epoch 136: iteration 92/93
# Epoch 136 --- loss:0.049, Epoch accuracy:98.36%, Validation loss:1.806, Validation accuracy:64.78%
# Epoch 137: iteration 92/93
# Epoch 137 --- loss:0.068, Epoch accuracy:97.42%, Validation loss:1.656, Validation accuracy:66.40%
# Epoch 138: iteration 92/93
# Epoch 138 --- loss:0.038, Epoch accuracy:98.86%, Validation loss:1.824, Validation accuracy:64.52%
# Epoch 139: iteration 92/93
# Epoch 139 --- loss:0.043, Epoch accuracy:98.76%, Validation loss:1.829, Validation accuracy:63.71%
# Epoch 140: iteration 92/93
# Epoch 140 --- loss:0.036, Epoch accuracy:98.99%, Validation loss:1.560, Validation accuracy:68.82%
# Epoch 141: iteration 92/93
# Epoch 141 --- loss:0.034, Epoch accuracy:98.99%, Validation loss:1.745, Validation accuracy:66.13%
# Epoch 142: iteration 92/93
# Epoch 142 --- loss:0.032, Epoch accuracy:99.03%, Validation loss:1.625, Validation accuracy:65.59%
# Epoch 143: iteration 92/93
# Epoch 143 --- loss:0.035, Epoch accuracy:98.83%, Validation loss:1.605, Validation accuracy:66.94%
# Epoch 144: iteration 92/93
# Epoch 144 --- loss:0.043, Epoch accuracy:98.39%, Validation loss:1.659, Validation accuracy:66.94%
# Epoch 145: iteration 92/93
# Epoch 145 --- loss:0.026, Epoch accuracy:99.33%, Validation loss:1.590, Validation accuracy:68.28%
# Epoch 146: iteration 92/93
# Epoch 146 --- loss:0.026, Epoch accuracy:99.33%, Validation loss:1.601, Validation accuracy:68.28%
# Epoch 147: iteration 92/93
# Epoch 147 --- loss:0.033, Epoch accuracy:99.03%, Validation loss:1.612, Validation accuracy:68.82%
# Epoch 148: iteration 92/93
# Epoch 148 --- loss:0.065, Epoch accuracy:97.69%, Validation loss:1.713, Validation accuracy:68.01%
# Epoch 149: iteration 92/93
# Epoch 149 --- loss:0.032, Epoch accuracy:99.13%, Validation loss:1.678, Validation accuracy:67.20%
# Epoch 150: iteration 92/93
# Epoch 150 --- loss:0.028, Epoch accuracy:99.26%, Validation loss:1.799, Validation accuracy:64.78%
# Epoch 151: iteration 92/93
# Epoch 151 --- loss:0.037, Epoch accuracy:98.99%, Validation loss:1.914, Validation accuracy:64.25%
# Epoch 152: iteration 92/93
# Epoch 152 --- loss:0.035, Epoch accuracy:98.99%, Validation loss:1.700, Validation accuracy:66.94%
# Epoch 153: iteration 92/93
# Epoch 153 --- loss:0.032, Epoch accuracy:99.09%, Validation loss:1.688, Validation accuracy:66.40%
# Epoch 154: iteration 92/93
# Epoch 154 --- loss:0.024, Epoch accuracy:99.53%, Validation loss:1.546, Validation accuracy:69.35%
# Epoch 155: iteration 92/93
# Epoch 155 --- loss:0.027, Epoch accuracy:99.30%, Validation loss:1.831, Validation accuracy:67.47%
# Epoch 156: iteration 92/93
# Epoch 156 --- loss:0.021, Epoch accuracy:99.46%, Validation loss:1.576, Validation accuracy:69.09%
# Epoch 157: iteration 92/93
# Epoch 157 --- loss:0.027, Epoch accuracy:99.40%, Validation loss:1.682, Validation accuracy:66.67%
# Epoch 158: iteration 92/93
# Epoch 158 --- loss:0.041, Epoch accuracy:98.59%, Validation loss:1.788, Validation accuracy:67.47%
# Epoch 159: iteration 92/93
# Epoch 159 --- loss:0.037, Epoch accuracy:98.96%, Validation loss:1.818, Validation accuracy:65.86%
# Epoch 160: iteration 92/93
# Epoch 160 --- loss:0.033, Epoch accuracy:99.09%, Validation loss:1.710, Validation accuracy:69.35%
# Epoch 161: iteration 92/93
# Epoch 161 --- loss:0.025, Epoch accuracy:99.36%, Validation loss:1.597, Validation accuracy:69.89%
# Epoch 162: iteration 92/93
# Epoch 162 --- loss:0.040, Epoch accuracy:98.83%, Validation loss:1.594, Validation accuracy:65.59%
# Epoch 163: iteration 92/93
# Epoch 163 --- loss:0.032, Epoch accuracy:98.93%, Validation loss:1.581, Validation accuracy:69.09%
# Epoch 164: iteration 92/93
# Epoch 164 --- loss:0.034, Epoch accuracy:99.13%, Validation loss:1.746, Validation accuracy:63.71%
# Epoch 165: iteration 92/93
# Epoch 165 --- loss:0.031, Epoch accuracy:99.16%, Validation loss:1.777, Validation accuracy:65.32%
# Epoch 166: iteration 92/93
# Epoch 166 --- loss:0.071, Epoch accuracy:97.38%, Validation loss:1.613, Validation accuracy:66.94%
# Epoch 167: iteration 92/93
# Epoch 167 --- loss:0.036, Epoch accuracy:98.93%, Validation loss:1.794, Validation accuracy:66.40%
# Epoch 168: iteration 92/93
# Epoch 168 --- loss:0.030, Epoch accuracy:99.13%, Validation loss:1.694, Validation accuracy:66.94%
# Epoch 169: iteration 92/93
# Epoch 169 --- loss:0.030, Epoch accuracy:99.13%, Validation loss:1.677, Validation accuracy:68.01%
# Epoch 170: iteration 92/93
# Epoch 170 --- loss:0.086, Epoch accuracy:97.22%, Validation loss:1.691, Validation accuracy:66.67%
# Epoch 171: iteration 92/93
# Epoch 171 --- loss:0.059, Epoch accuracy:97.89%, Validation loss:1.652, Validation accuracy:68.82%
# Epoch 172: iteration 92/93
# Epoch 172 --- loss:0.033, Epoch accuracy:98.96%, Validation loss:1.612, Validation accuracy:68.55%
# Epoch 173: iteration 92/93
# Epoch 173 --- loss:0.028, Epoch accuracy:99.30%, Validation loss:1.533, Validation accuracy:69.09%
# Epoch 174: iteration 92/93
# Epoch 174 --- loss:0.031, Epoch accuracy:99.03%, Validation loss:1.499, Validation accuracy:68.55%
# Epoch 175: iteration 92/93
# Epoch 175 --- loss:0.027, Epoch accuracy:99.20%, Validation loss:1.594, Validation accuracy:69.09%
# Epoch 176: iteration 92/93
# Epoch 176 --- loss:0.034, Epoch accuracy:98.93%, Validation loss:1.629, Validation accuracy:68.82%
# Epoch 177: iteration 92/93
# Epoch 177 --- loss:0.020, Epoch accuracy:99.60%, Validation loss:1.613, Validation accuracy:68.55%
# Epoch 178: iteration 92/93
# Epoch 178 --- loss:0.021, Epoch accuracy:99.60%, Validation loss:1.617, Validation accuracy:69.62%
# Epoch 179: iteration 92/93
# Epoch 179 --- loss:0.020, Epoch accuracy:99.60%, Validation loss:1.523, Validation accuracy:71.51%
# Epoch 180: iteration 92/93
# Epoch 180 --- loss:0.021, Epoch accuracy:99.43%, Validation loss:1.735, Validation accuracy:68.01%
# Epoch 181: iteration 92/93
# Epoch 181 --- loss:0.017, Epoch accuracy:99.60%, Validation loss:1.598, Validation accuracy:68.82%
# Epoch 182: iteration 92/93
# Epoch 182 --- loss:0.022, Epoch accuracy:99.53%, Validation loss:1.639, Validation accuracy:67.20%
# Epoch 183: iteration 92/93
# Epoch 183 --- loss:0.027, Epoch accuracy:99.23%, Validation loss:1.691, Validation accuracy:67.47%
# Epoch 184: iteration 92/93
# Epoch 184 --- loss:0.059, Epoch accuracy:97.89%, Validation loss:1.793, Validation accuracy:65.59%
# Epoch 185: iteration 92/93
# Epoch 185 --- loss:0.051, Epoch accuracy:98.26%, Validation loss:1.598, Validation accuracy:68.28%
# Epoch 186: iteration 92/93
# Epoch 186 --- loss:0.049, Epoch accuracy:98.19%, Validation loss:1.525, Validation accuracy:69.35%
# Epoch 187: iteration 92/93
# Epoch 187 --- loss:0.037, Epoch accuracy:98.96%, Validation loss:1.611, Validation accuracy:68.82%
# Epoch 188: iteration 92/93
# Epoch 188 --- loss:0.030, Epoch accuracy:99.16%, Validation loss:1.562, Validation accuracy:67.20%
# Epoch 189: iteration 92/93
# Epoch 189 --- loss:0.024, Epoch accuracy:99.46%, Validation loss:1.599, Validation accuracy:67.47%
# Epoch 190: iteration 92/93
# Epoch 190 --- loss:0.022, Epoch accuracy:99.56%, Validation loss:1.540, Validation accuracy:70.16%
# Epoch 191: iteration 92/93
# Epoch 191 --- loss:0.022, Epoch accuracy:99.53%, Validation loss:1.609, Validation accuracy:69.35%
# Epoch 192: iteration 92/93
# Epoch 192 --- loss:0.021, Epoch accuracy:99.50%, Validation loss:1.704, Validation accuracy:68.28%
# Epoch 193: iteration 92/93
# Epoch 193 --- loss:0.019, Epoch accuracy:99.50%, Validation loss:1.612, Validation accuracy:69.35%
# Epoch 194: iteration 92/93
# Epoch 194 --- loss:0.016, Epoch accuracy:99.66%, Validation loss:1.695, Validation accuracy:69.09%
# Epoch 195: iteration 92/93
# Epoch 195 --- loss:0.017, Epoch accuracy:99.73%, Validation loss:1.565, Validation accuracy:69.35%
# Epoch 196: iteration 92/93
# Epoch 196 --- loss:0.015, Epoch accuracy:99.70%, Validation loss:1.832, Validation accuracy:63.98%
# Epoch 197: iteration 92/93
# Epoch 197 --- loss:0.032, Epoch accuracy:99.03%, Validation loss:1.727, Validation accuracy:66.94%
# Epoch 198: iteration 92/93
# Epoch 198 --- loss:0.043, Epoch accuracy:98.46%, Validation loss:1.634, Validation accuracy:66.67%
# Epoch 199: iteration 92/93
# Epoch 199 --- loss:0.025, Epoch accuracy:99.13%, Validation loss:1.740, Validation accuracy:66.94%
# Epoch 200: iteration 92/93
# Epoch 200 --- loss:0.024, Epoch accuracy:99.40%, Validation loss:1.758, Validation accuracy:66.13%
# Epoch 201: iteration 92/93
# Epoch 201 --- loss:0.036, Epoch accuracy:98.93%, Validation loss:1.790, Validation accuracy:65.59%
# Epoch 202: iteration 92/93
# Epoch 202 --- loss:0.036, Epoch accuracy:98.96%, Validation loss:1.648, Validation accuracy:66.94%
# Epoch 203: iteration 92/93
# Epoch 203 --- loss:0.028, Epoch accuracy:99.16%, Validation loss:1.551, Validation accuracy:68.28%
# Epoch 204: iteration 92/93
# Epoch 204 --- loss:0.028, Epoch accuracy:99.20%, Validation loss:2.078, Validation accuracy:60.48%
# Epoch 205: iteration 92/93
# Epoch 205 --- loss:0.044, Epoch accuracy:98.32%, Validation loss:1.652, Validation accuracy:69.09%
# Epoch 206: iteration 92/93
# Epoch 206 --- loss:0.033, Epoch accuracy:99.09%, Validation loss:1.822, Validation accuracy:64.25%
# Epoch 207: iteration 92/93
# Epoch 207 --- loss:0.028, Epoch accuracy:99.33%, Validation loss:1.768, Validation accuracy:66.13%
# Epoch 208: iteration 92/93
# Epoch 208 --- loss:0.037, Epoch accuracy:98.83%, Validation loss:1.650, Validation accuracy:66.13%
# Epoch 209: iteration 92/93
# Epoch 209 --- loss:0.022, Epoch accuracy:99.36%, Validation loss:1.643, Validation accuracy:66.67%
# Epoch 210: iteration 92/93
# Epoch 210 --- loss:0.027, Epoch accuracy:99.16%, Validation loss:1.707, Validation accuracy:69.89%
# Epoch 211: iteration 92/93
# Epoch 211 --- loss:0.032, Epoch accuracy:99.16%, Validation loss:1.600, Validation accuracy:67.74%
# Epoch 212: iteration 92/93
# Epoch 212 --- loss:0.033, Epoch accuracy:98.99%, Validation loss:1.761, Validation accuracy:64.52%
# Epoch 213: iteration 92/93
# Epoch 213 --- loss:0.026, Epoch accuracy:99.16%, Validation loss:1.677, Validation accuracy:68.01%
# Epoch 214: iteration 92/93
# Epoch 214 --- loss:0.023, Epoch accuracy:99.50%, Validation loss:1.580, Validation accuracy:68.82%
# Epoch 215: iteration 92/93
# Epoch 215 --- loss:0.021, Epoch accuracy:99.46%, Validation loss:1.695, Validation accuracy:66.94%
# Epoch 216: iteration 92/93
# Epoch 216 --- loss:0.024, Epoch accuracy:99.30%, Validation loss:1.791, Validation accuracy:65.05%
# Epoch 217: iteration 92/93
# Epoch 217 --- loss:0.072, Epoch accuracy:97.65%, Validation loss:1.652, Validation accuracy:68.01%
# Epoch 218: iteration 92/93
# Epoch 218 --- loss:0.042, Epoch accuracy:98.56%, Validation loss:1.730, Validation accuracy:67.47%
# Epoch 219: iteration 92/93
# Epoch 219 --- loss:0.046, Epoch accuracy:98.46%, Validation loss:1.722, Validation accuracy:68.01%
# Epoch 220: iteration 92/93
# Epoch 220 --- loss:0.042, Epoch accuracy:98.46%, Validation loss:1.702, Validation accuracy:67.74%
# Epoch 221: iteration 92/93
# Epoch 221 --- loss:0.026, Epoch accuracy:99.23%, Validation loss:1.743, Validation accuracy:65.05%
# Epoch 222: iteration 92/93
# Epoch 222 --- loss:0.025, Epoch accuracy:99.36%, Validation loss:1.711, Validation accuracy:65.05%
# Epoch 223: iteration 92/93
# Epoch 223 --- loss:0.024, Epoch accuracy:99.26%, Validation loss:1.761, Validation accuracy:65.59%
# Epoch 224: iteration 92/93
# Epoch 224 --- loss:0.014, Epoch accuracy:99.73%, Validation loss:1.706, Validation accuracy:67.20%
# Epoch 225: iteration 92/93
# Epoch 225 --- loss:0.014, Epoch accuracy:99.70%, Validation loss:1.876, Validation accuracy:64.25%
# Epoch 226: iteration 92/93
# Epoch 226 --- loss:0.023, Epoch accuracy:99.40%, Validation loss:1.777, Validation accuracy:66.40%
# Epoch 227: iteration 92/93
# Epoch 227 --- loss:0.013, Epoch accuracy:99.80%, Validation loss:1.661, Validation accuracy:68.55%
# Epoch 228: iteration 92/93
# Epoch 228 --- loss:0.019, Epoch accuracy:99.53%, Validation loss:1.674, Validation accuracy:67.20%
# Epoch 229: iteration 92/93
# Epoch 229 --- loss:0.024, Epoch accuracy:99.43%, Validation loss:1.602, Validation accuracy:68.28%
# Epoch 230: iteration 92/93
# Epoch 230 --- loss:0.050, Epoch accuracy:98.49%, Validation loss:2.229, Validation accuracy:62.37%
# Epoch 231: iteration 92/93
# Epoch 231 --- loss:0.066, Epoch accuracy:97.65%, Validation loss:1.855, Validation accuracy:65.59%
# Epoch 232: iteration 92/93
# Epoch 232 --- loss:0.057, Epoch accuracy:98.26%, Validation loss:1.615, Validation accuracy:68.01%
# Epoch 233: iteration 92/93
# Epoch 233 --- loss:0.078, Epoch accuracy:97.12%, Validation loss:1.793, Validation accuracy:62.90%
# Epoch 234: iteration 92/93
# Epoch 234 --- loss:0.044, Epoch accuracy:98.56%, Validation loss:1.481, Validation accuracy:68.28%
# Epoch 235: iteration 92/93
# Epoch 235 --- loss:0.034, Epoch accuracy:98.86%, Validation loss:1.672, Validation accuracy:65.32%
# Epoch 236: iteration 92/93
# Epoch 236 --- loss:0.032, Epoch accuracy:99.13%, Validation loss:1.600, Validation accuracy:65.59%
# Epoch 237: iteration 92/93
# Epoch 237 --- loss:0.022, Epoch accuracy:99.43%, Validation loss:1.711, Validation accuracy:67.20%
# Epoch 238: iteration 92/93
# Epoch 238 --- loss:0.017, Epoch accuracy:99.66%, Validation loss:1.555, Validation accuracy:68.82%
# Epoch 239: iteration 92/93
# Epoch 239 --- loss:0.022, Epoch accuracy:99.43%, Validation loss:1.650, Validation accuracy:66.67%
# Epoch 240: iteration 92/93
# Epoch 240 --- loss:0.025, Epoch accuracy:99.50%, Validation loss:1.619, Validation accuracy:68.28%
# Epoch 241: iteration 92/93
# Epoch 241 --- loss:0.020, Epoch accuracy:99.43%, Validation loss:1.618, Validation accuracy:66.94%
# Epoch 242: iteration 92/93
# Epoch 242 --- loss:0.018, Epoch accuracy:99.63%, Validation loss:1.687, Validation accuracy:66.94%
# Epoch 243: iteration 92/93
# Epoch 243 --- loss:0.028, Epoch accuracy:99.13%, Validation loss:1.660, Validation accuracy:69.09%
# Epoch 244: iteration 92/93
# Epoch 244 --- loss:0.045, Epoch accuracy:98.66%, Validation loss:1.615, Validation accuracy:68.28%
# Epoch 245: iteration 92/93
# Epoch 245 --- loss:0.020, Epoch accuracy:99.53%, Validation loss:1.581, Validation accuracy:66.40%
# Epoch 246: iteration 92/93
# Epoch 246 --- loss:0.052, Epoch accuracy:98.02%, Validation loss:1.749, Validation accuracy:65.59%
# Epoch 247: iteration 92/93
# Epoch 247 --- loss:0.035, Epoch accuracy:99.03%, Validation loss:1.722, Validation accuracy:65.86%
# Epoch 248: iteration 92/93
# Epoch 248 --- loss:0.025, Epoch accuracy:99.46%, Validation loss:1.653, Validation accuracy:67.74%
# Epoch 249: iteration 92/93
# Epoch 249 --- loss:0.029, Epoch accuracy:99.13%, Validation loss:1.640, Validation accuracy:66.67%
# Epoch 250: iteration 92/93
# Epoch 250 --- loss:0.022, Epoch accuracy:99.46%, Validation loss:1.649, Validation accuracy:67.47%
# Epoch 251: iteration 92/93
# Epoch 251 --- loss:0.019, Epoch accuracy:99.40%, Validation loss:1.821, Validation accuracy:68.01%
# Epoch 252: iteration 92/93
# Epoch 252 --- loss:0.016, Epoch accuracy:99.70%, Validation loss:1.608, Validation accuracy:66.67%
# Epoch 253: iteration 92/93
# Epoch 253 --- loss:0.034, Epoch accuracy:98.76%, Validation loss:1.624, Validation accuracy:65.05%
# Epoch 254: iteration 92/93
# Epoch 254 --- loss:0.025, Epoch accuracy:99.30%, Validation loss:1.668, Validation accuracy:67.20%
# Epoch 255: iteration 92/93
# Epoch 255 --- loss:0.031, Epoch accuracy:98.96%, Validation loss:1.752, Validation accuracy:65.32%
# Epoch 256: iteration 92/93
# Epoch 256 --- loss:0.055, Epoch accuracy:97.95%, Validation loss:1.709, Validation accuracy:66.40%
# Epoch 257: iteration 92/93
# Epoch 257 --- loss:0.021, Epoch accuracy:99.50%, Validation loss:1.691, Validation accuracy:67.74%
# Epoch 258: iteration 92/93
# Epoch 258 --- loss:0.023, Epoch accuracy:99.36%, Validation loss:1.579, Validation accuracy:66.94%
# Epoch 259: iteration 92/93
# Epoch 259 --- loss:0.024, Epoch accuracy:99.33%, Validation loss:1.659, Validation accuracy:67.74%
# Epoch 260: iteration 92/93
# Epoch 260 --- loss:0.015, Epoch accuracy:99.70%, Validation loss:1.676, Validation accuracy:68.28%
# Epoch 261: iteration 92/93
# Epoch 261 --- loss:0.019, Epoch accuracy:99.40%, Validation loss:1.726, Validation accuracy:67.47%
# Epoch 262: iteration 92/93
# Epoch 262 --- loss:0.018, Epoch accuracy:99.53%, Validation loss:1.627, Validation accuracy:69.09%
# Epoch 263: iteration 92/93
# Epoch 263 --- loss:0.016, Epoch accuracy:99.66%, Validation loss:1.580, Validation accuracy:68.82%
# Epoch 264: iteration 92/93
# Epoch 264 --- loss:0.014, Epoch accuracy:99.70%, Validation loss:1.703, Validation accuracy:67.74%
# Epoch 265: iteration 92/93
# Epoch 265 --- loss:0.013, Epoch accuracy:99.60%, Validation loss:1.641, Validation accuracy:68.55%
# Epoch 266: iteration 92/93
# Epoch 266 --- loss:0.018, Epoch accuracy:99.56%, Validation loss:1.569, Validation accuracy:68.01%
# Epoch 267: iteration 92/93
# Epoch 267 --- loss:0.029, Epoch accuracy:99.16%, Validation loss:1.629, Validation accuracy:66.94%
# Epoch 268: iteration 92/93
# Epoch 268 --- loss:0.035, Epoch accuracy:98.89%, Validation loss:1.632, Validation accuracy:66.13%
# Epoch 269: iteration 92/93
# Epoch 269 --- loss:0.042, Epoch accuracy:98.59%, Validation loss:1.910, Validation accuracy:63.44%
# Epoch 270: iteration 92/93
# Epoch 270 --- loss:0.073, Epoch accuracy:97.59%, Validation loss:1.830, Validation accuracy:64.78%
# Epoch 271: iteration 92/93
# Epoch 271 --- loss:0.046, Epoch accuracy:98.52%, Validation loss:1.585, Validation accuracy:64.25%
# Epoch 272: iteration 92/93
# Epoch 272 --- loss:0.072, Epoch accuracy:97.42%, Validation loss:1.476, Validation accuracy:71.24%
# Epoch 273: iteration 92/93
# Epoch 273 --- loss:0.038, Epoch accuracy:98.89%, Validation loss:1.589, Validation accuracy:70.16%
# Epoch 274: iteration 92/93
# Epoch 274 --- loss:0.035, Epoch accuracy:98.99%, Validation loss:1.697, Validation accuracy:66.67%
# Epoch 275: iteration 92/93
# Epoch 275 --- loss:0.024, Epoch accuracy:99.40%, Validation loss:1.561, Validation accuracy:69.09%
# Epoch 276: iteration 92/93
# Epoch 276 --- loss:0.026, Epoch accuracy:99.20%, Validation loss:1.516, Validation accuracy:69.35%
# Epoch 277: iteration 92/93
# Epoch 277 --- loss:0.031, Epoch accuracy:98.99%, Validation loss:1.565, Validation accuracy:68.28%
# Epoch 278: iteration 92/93
# Epoch 278 --- loss:0.021, Epoch accuracy:99.40%, Validation loss:1.683, Validation accuracy:69.09%
# Epoch 279: iteration 92/93
# Epoch 279 --- loss:0.027, Epoch accuracy:99.30%, Validation loss:1.518, Validation accuracy:69.09%
# Epoch 280: iteration 92/93
# Epoch 280 --- loss:0.041, Epoch accuracy:98.59%, Validation loss:1.670, Validation accuracy:65.32%
# Epoch 281: iteration 92/93
# Epoch 281 --- loss:0.059, Epoch accuracy:98.09%, Validation loss:1.577, Validation accuracy:70.70%
# Epoch 282: iteration 92/93
# Epoch 282 --- loss:0.030, Epoch accuracy:99.09%, Validation loss:1.694, Validation accuracy:68.01%
# Epoch 283: iteration 92/93
# Epoch 283 --- loss:0.046, Epoch accuracy:98.39%, Validation loss:1.549, Validation accuracy:65.05%
# Epoch 284: iteration 92/93
# Epoch 284 --- loss:0.041, Epoch accuracy:98.76%, Validation loss:1.619, Validation accuracy:68.01%
# Epoch 285: iteration 92/93
# Epoch 285 --- loss:0.016, Epoch accuracy:99.63%, Validation loss:1.643, Validation accuracy:70.97%
# Epoch 286: iteration 92/93
# Epoch 286 --- loss:0.027, Epoch accuracy:99.16%, Validation loss:1.562, Validation accuracy:70.97%
# Epoch 287: iteration 92/93
# Epoch 287 --- loss:0.021, Epoch accuracy:99.43%, Validation loss:1.702, Validation accuracy:64.78%
# Epoch 288: iteration 92/93
# Epoch 288 --- loss:0.037, Epoch accuracy:98.89%, Validation loss:1.649, Validation accuracy:67.74%
# Epoch 289: iteration 92/93
# Epoch 289 --- loss:0.045, Epoch accuracy:98.52%, Validation loss:1.656, Validation accuracy:68.28%
# Epoch 290: iteration 92/93
# Epoch 290 --- loss:0.041, Epoch accuracy:98.52%, Validation loss:1.800, Validation accuracy:67.20%
# Epoch 291: iteration 92/93
# Epoch 291 --- loss:0.041, Epoch accuracy:98.73%, Validation loss:1.505, Validation accuracy:66.94%
# Epoch 292: iteration 92/93
# Epoch 292 --- loss:0.034, Epoch accuracy:98.93%, Validation loss:1.510, Validation accuracy:69.62%
# Epoch 293: iteration 92/93
# Epoch 293 --- loss:0.032, Epoch accuracy:99.03%, Validation loss:1.699, Validation accuracy:68.55%
# Epoch 294: iteration 92/93
# Epoch 294 --- loss:0.020, Epoch accuracy:99.50%, Validation loss:1.523, Validation accuracy:70.16%
# Epoch 295: iteration 92/93
# Epoch 295 --- loss:0.015, Epoch accuracy:99.63%, Validation loss:1.751, Validation accuracy:65.59%
# Epoch 296: iteration 92/93
# Epoch 296 --- loss:0.022, Epoch accuracy:99.46%, Validation loss:1.662, Validation accuracy:67.74%
# Epoch 297: iteration 92/93
# Epoch 297 --- loss:0.068, Epoch accuracy:97.45%, Validation loss:1.715, Validation accuracy:66.13%
# Epoch 298: iteration 92/93
# Epoch 298 --- loss:0.034, Epoch accuracy:98.96%, Validation loss:1.648, Validation accuracy:68.28%
# Epoch 299: iteration 92/93
# Epoch 299 --- loss:0.045, Epoch accuracy:98.42%, Validation loss:1.629, Validation accuracy:66.40%
# Epoch 300: iteration 92/93
# Epoch 300 --- loss:0.032, Epoch accuracy:98.96%, Validation loss:1.480, Validation accuracy:67.74%
# Epoch 301: iteration 92/93
# Epoch 301 --- loss:0.017, Epoch accuracy:99.56%, Validation loss:1.504, Validation accuracy:70.70%
# Epoch 302: iteration 92/93
# Epoch 302 --- loss:0.018, Epoch accuracy:99.46%, Validation loss:1.551, Validation accuracy:69.09%
# Epoch 303: iteration 92/93
# Epoch 303 --- loss:0.035, Epoch accuracy:98.86%, Validation loss:1.573, Validation accuracy:69.09%
# Epoch 304: iteration 92/93
# Epoch 304 --- loss:0.022, Epoch accuracy:99.30%, Validation loss:1.658, Validation accuracy:66.40%
# Epoch 305: iteration 92/93
# Epoch 305 --- loss:0.032, Epoch accuracy:99.03%, Validation loss:1.713, Validation accuracy:63.98%
# Epoch 306: iteration 92/93
# Epoch 306 --- loss:0.030, Epoch accuracy:98.96%, Validation loss:1.874, Validation accuracy:67.20%
# Epoch 307: iteration 92/93
# Epoch 307 --- loss:0.052, Epoch accuracy:98.19%, Validation loss:2.093, Validation accuracy:59.95%
# Epoch 308: iteration 92/93
# Epoch 308 --- loss:0.071, Epoch accuracy:97.35%, Validation loss:1.678, Validation accuracy:67.20%
# Epoch 309: iteration 92/93
# Epoch 309 --- loss:0.032, Epoch accuracy:99.13%, Validation loss:1.852, Validation accuracy:65.32%
# Epoch 310: iteration 92/93
# Epoch 310 --- loss:0.033, Epoch accuracy:99.09%, Validation loss:1.507, Validation accuracy:67.20%
# Epoch 311: iteration 92/93
# Epoch 311 --- loss:0.014, Epoch accuracy:99.77%, Validation loss:1.712, Validation accuracy:67.20%
# Epoch 312: iteration 92/93
# Epoch 312 --- loss:0.016, Epoch accuracy:99.56%, Validation loss:1.667, Validation accuracy:66.94%
# Epoch 313: iteration 92/93
# Epoch 313 --- loss:0.017, Epoch accuracy:99.66%, Validation loss:1.611, Validation accuracy:68.28%
# Epoch 314: iteration 92/93
# Epoch 314 --- loss:0.018, Epoch accuracy:99.56%, Validation loss:1.762, Validation accuracy:66.67%
# Epoch 315: iteration 92/93
# Epoch 315 --- loss:0.036, Epoch accuracy:98.73%, Validation loss:1.681, Validation accuracy:66.67%
# Epoch 316: iteration 92/93
# Epoch 316 --- loss:0.028, Epoch accuracy:99.20%, Validation loss:1.621, Validation accuracy:69.09%
# Epoch 317: iteration 92/93
# Epoch 317 --- loss:0.039, Epoch accuracy:98.69%, Validation loss:1.773, Validation accuracy:66.13%
# Epoch 318: iteration 92/93
# Epoch 318 --- loss:0.039, Epoch accuracy:98.86%, Validation loss:1.673, Validation accuracy:65.86%
# Epoch 319: iteration 92/93
# Epoch 319 --- loss:0.020, Epoch accuracy:99.56%, Validation loss:1.660, Validation accuracy:66.13%
# Epoch 320: iteration 92/93
# Epoch 320 --- loss:0.015, Epoch accuracy:99.80%, Validation loss:1.572, Validation accuracy:69.09%
# Epoch 321: iteration 92/93
# Epoch 321 --- loss:0.012, Epoch accuracy:99.70%, Validation loss:1.626, Validation accuracy:68.28%
# Epoch 322: iteration 92/93
# Epoch 322 --- loss:0.096, Epoch accuracy:96.55%, Validation loss:1.899, Validation accuracy:63.17%
# Epoch 323: iteration 92/93
# Epoch 323 --- loss:0.038, Epoch accuracy:98.76%, Validation loss:1.598, Validation accuracy:68.01%
# Epoch 324: iteration 92/93
# Epoch 324 --- loss:0.036, Epoch accuracy:98.76%, Validation loss:1.599, Validation accuracy:68.55%
# Epoch 325: iteration 92/93
# Epoch 325 --- loss:0.030, Epoch accuracy:99.16%, Validation loss:1.817, Validation accuracy:67.20%
# Epoch 326: iteration 92/93
# Epoch 326 --- loss:0.020, Epoch accuracy:99.53%, Validation loss:1.788, Validation accuracy:66.67%
# Epoch 327: iteration 92/93
# Epoch 327 --- loss:0.021, Epoch accuracy:99.36%, Validation loss:2.002, Validation accuracy:60.22%
# Epoch 328: iteration 92/93
# Epoch 328 --- loss:0.029, Epoch accuracy:99.20%, Validation loss:1.571, Validation accuracy:70.43%
# Epoch 329: iteration 92/93
# Epoch 329 --- loss:0.054, Epoch accuracy:98.05%, Validation loss:1.936, Validation accuracy:63.17%
# Epoch 330: iteration 92/93
# Epoch 330 --- loss:0.044, Epoch accuracy:98.52%, Validation loss:1.692, Validation accuracy:65.32%
# Epoch 331: iteration 92/93
# Epoch 331 --- loss:0.022, Epoch accuracy:99.30%, Validation loss:1.671, Validation accuracy:69.89%
# Epoch 332: iteration 92/93
# Epoch 332 --- loss:0.020, Epoch accuracy:99.50%, Validation loss:1.607, Validation accuracy:68.01%
# Epoch 333: iteration 92/93
# Epoch 333 --- loss:0.017, Epoch accuracy:99.50%, Validation loss:1.651, Validation accuracy:68.28%
# Epoch 334: iteration 92/93
# Epoch 334 --- loss:0.015, Epoch accuracy:99.66%, Validation loss:1.652, Validation accuracy:67.74%
# Epoch 335: iteration 92/93
# Epoch 335 --- loss:0.012, Epoch accuracy:99.73%, Validation loss:1.579, Validation accuracy:68.28%
# Epoch 336: iteration 92/93
# Epoch 336 --- loss:0.012, Epoch accuracy:99.60%, Validation loss:1.608, Validation accuracy:68.55%
# Epoch 337: iteration 92/93
# Epoch 337 --- loss:0.028, Epoch accuracy:99.06%, Validation loss:1.734, Validation accuracy:66.67%
# Epoch 338: iteration 92/93
# Epoch 338 --- loss:0.027, Epoch accuracy:99.13%, Validation loss:1.615, Validation accuracy:68.28%
# Epoch 339: iteration 92/93
# Epoch 339 --- loss:0.014, Epoch accuracy:99.63%, Validation loss:1.627, Validation accuracy:68.01%
# Epoch 340: iteration 92/93
# Epoch 340 --- loss:0.016, Epoch accuracy:99.56%, Validation loss:1.684, Validation accuracy:66.67%
# Epoch 341: iteration 92/93
# Epoch 341 --- loss:0.011, Epoch accuracy:99.70%, Validation loss:1.586, Validation accuracy:69.09%
# Epoch 342: iteration 92/93
# Epoch 342 --- loss:0.012, Epoch accuracy:99.70%, Validation loss:1.639, Validation accuracy:66.94%
# Epoch 343: iteration 92/93
# Epoch 343 --- loss:0.038, Epoch accuracy:98.79%, Validation loss:1.901, Validation accuracy:64.25%
# Epoch 344: iteration 92/93
# Epoch 344 --- loss:0.040, Epoch accuracy:98.76%, Validation loss:1.782, Validation accuracy:66.13%
# Epoch 345: iteration 92/93
# Epoch 345 --- loss:0.040, Epoch accuracy:98.56%, Validation loss:1.558, Validation accuracy:68.55%
# Epoch 346: iteration 92/93
# Epoch 346 --- loss:0.053, Epoch accuracy:98.16%, Validation loss:1.867, Validation accuracy:65.32%
# Epoch 347: iteration 92/93
# Epoch 347 --- loss:0.071, Epoch accuracy:97.45%, Validation loss:1.809, Validation accuracy:62.90%
# Epoch 348: iteration 92/93
# Epoch 348 --- loss:0.022, Epoch accuracy:99.40%, Validation loss:1.711, Validation accuracy:65.86%
# Epoch 349: iteration 92/93
# Epoch 349 --- loss:0.039, Epoch accuracy:98.73%, Validation loss:1.563, Validation accuracy:69.89%
# Epoch 350: iteration 92/93
# Epoch 350 --- loss:0.025, Epoch accuracy:99.36%, Validation loss:1.719, Validation accuracy:65.59%
# Epoch 351: iteration 92/93
# Epoch 351 --- loss:0.024, Epoch accuracy:99.40%, Validation loss:1.575, Validation accuracy:69.35%
# Epoch 352: iteration 92/93
# Epoch 352 --- loss:0.021, Epoch accuracy:99.36%, Validation loss:1.680, Validation accuracy:65.05%
# Epoch 353: iteration 92/93
# Epoch 353 --- loss:0.017, Epoch accuracy:99.56%, Validation loss:1.573, Validation accuracy:66.67%
# Epoch 354: iteration 92/93
# Epoch 354 --- loss:0.018, Epoch accuracy:99.43%, Validation loss:1.591, Validation accuracy:66.67%
# Epoch 355: iteration 92/93
# Epoch 355 --- loss:0.021, Epoch accuracy:99.40%, Validation loss:1.651, Validation accuracy:68.28%
# Epoch 356: iteration 92/93
# Epoch 356 --- loss:0.031, Epoch accuracy:98.93%, Validation loss:1.761, Validation accuracy:67.20%
# Epoch 357: iteration 92/93
# Epoch 357 --- loss:0.029, Epoch accuracy:99.20%, Validation loss:1.799, Validation accuracy:65.32%
# Epoch 358: iteration 92/93
# Epoch 358 --- loss:0.093, Epoch accuracy:97.18%, Validation loss:2.719, Validation accuracy:48.12%
# Epoch 359: iteration 92/93
# Epoch 359 --- loss:0.173, Epoch accuracy:94.80%, Validation loss:1.635, Validation accuracy:63.98%
# Epoch 360: iteration 92/93
# Epoch 360 --- loss:0.037, Epoch accuracy:98.83%, Validation loss:1.443, Validation accuracy:70.16%
# Epoch 361: iteration 92/93
# Epoch 361 --- loss:0.034, Epoch accuracy:98.86%, Validation loss:1.611, Validation accuracy:64.52%
# Epoch 362: iteration 92/93
# Epoch 362 --- loss:0.040, Epoch accuracy:98.63%, Validation loss:1.478, Validation accuracy:68.82%
# Epoch 363: iteration 92/93
# Epoch 363 --- loss:0.019, Epoch accuracy:99.56%, Validation loss:1.434, Validation accuracy:68.55%
# Epoch 364: iteration 92/93
# Epoch 364 --- loss:0.013, Epoch accuracy:99.70%, Validation loss:1.483, Validation accuracy:69.35%
# Epoch 365: iteration 92/93
# Epoch 365 --- loss:0.015, Epoch accuracy:99.70%, Validation loss:1.558, Validation accuracy:68.01%
# Epoch 366: iteration 92/93
# Epoch 366 --- loss:0.015, Epoch accuracy:99.60%, Validation loss:1.630, Validation accuracy:68.82%
# Epoch 367: iteration 92/93
# Epoch 367 --- loss:0.011, Epoch accuracy:99.73%, Validation loss:1.499, Validation accuracy:70.70%
# Epoch 368: iteration 92/93
# Epoch 368 --- loss:0.023, Epoch accuracy:99.43%, Validation loss:1.528, Validation accuracy:71.24%
# Epoch 369: iteration 92/93
# Epoch 369 --- loss:0.013, Epoch accuracy:99.80%, Validation loss:1.619, Validation accuracy:68.55%
# Epoch 370: iteration 92/93
# Epoch 370 --- loss:0.019, Epoch accuracy:99.46%, Validation loss:1.889, Validation accuracy:64.25%
# Epoch 371: iteration 92/93
# Epoch 371 --- loss:0.026, Epoch accuracy:99.13%, Validation loss:1.620, Validation accuracy:68.01%
# Epoch 372: iteration 92/93
# Epoch 372 --- loss:0.016, Epoch accuracy:99.53%, Validation loss:1.537, Validation accuracy:69.09%
# Epoch 373: iteration 92/93
# Epoch 373 --- loss:0.013, Epoch accuracy:99.60%, Validation loss:1.723, Validation accuracy:67.20%
# Epoch 374: iteration 92/93
# Epoch 374 --- loss:0.012, Epoch accuracy:99.70%, Validation loss:1.761, Validation accuracy:66.94%
# Epoch 375: iteration 92/93
# Epoch 375 --- loss:0.023, Epoch accuracy:99.40%, Validation loss:1.682, Validation accuracy:66.94%
# Epoch 376: iteration 92/93
# Epoch 376 --- loss:0.024, Epoch accuracy:99.23%, Validation loss:1.666, Validation accuracy:68.01%
# Epoch 377: iteration 92/93
# Epoch 377 --- loss:0.159, Epoch accuracy:94.80%, Validation loss:1.724, Validation accuracy:66.67%
# Epoch 378: iteration 92/93
# Epoch 378 --- loss:0.074, Epoch accuracy:97.62%, Validation loss:1.473, Validation accuracy:66.40%
# Epoch 379: iteration 92/93
# Epoch 379 --- loss:0.045, Epoch accuracy:98.63%, Validation loss:1.487, Validation accuracy:70.16%
# Epoch 380: iteration 92/93
# Epoch 380 --- loss:0.027, Epoch accuracy:99.26%, Validation loss:1.861, Validation accuracy:63.98%
# Epoch 381: iteration 92/93
# Epoch 381 --- loss:0.020, Epoch accuracy:99.60%, Validation loss:1.647, Validation accuracy:69.09%
# Epoch 382: iteration 92/93
# Epoch 382 --- loss:0.014, Epoch accuracy:99.70%, Validation loss:1.614, Validation accuracy:69.09%
# Epoch 383: iteration 92/93
# Epoch 383 --- loss:0.017, Epoch accuracy:99.53%, Validation loss:1.626, Validation accuracy:68.82%
# Epoch 384: iteration 92/93
# Epoch 384 --- loss:0.016, Epoch accuracy:99.60%, Validation loss:1.587, Validation accuracy:70.70%
# Epoch 385: iteration 92/93
# Epoch 385 --- loss:0.011, Epoch accuracy:99.73%, Validation loss:1.514, Validation accuracy:69.09%
# Epoch 386: iteration 92/93
# Epoch 386 --- loss:0.012, Epoch accuracy:99.77%, Validation loss:1.740, Validation accuracy:67.74%
# Epoch 387: iteration 92/93
# Epoch 387 --- loss:0.010, Epoch accuracy:99.77%, Validation loss:1.690, Validation accuracy:68.01%
# Epoch 388: iteration 92/93
# Epoch 388 --- loss:0.012, Epoch accuracy:99.60%, Validation loss:1.641, Validation accuracy:68.01%
# Epoch 389: iteration 92/93
# Epoch 389 --- loss:0.069, Epoch accuracy:97.69%, Validation loss:1.576, Validation accuracy:67.74%
# Epoch 390: iteration 92/93
# Epoch 390 --- loss:0.043, Epoch accuracy:98.49%, Validation loss:1.508, Validation accuracy:68.28%
# Epoch 391: iteration 92/93
# Epoch 391 --- loss:0.017, Epoch accuracy:99.53%, Validation loss:1.696, Validation accuracy:67.20%
# Epoch 392: iteration 92/93
# Epoch 392 --- loss:0.046, Epoch accuracy:98.46%, Validation loss:1.591, Validation accuracy:65.59%
# Epoch 393: iteration 92/93
# Epoch 393 --- loss:0.056, Epoch accuracy:98.26%, Validation loss:2.029, Validation accuracy:61.56%
# Epoch 394: iteration 92/93
# Epoch 394 --- loss:0.070, Epoch accuracy:97.59%, Validation loss:1.764, Validation accuracy:65.32%
# Epoch 395: iteration 92/93
# Epoch 395 --- loss:0.023, Epoch accuracy:99.40%, Validation loss:1.626, Validation accuracy:68.28%
# Epoch 396: iteration 92/93
# Epoch 396 --- loss:0.015, Epoch accuracy:99.63%, Validation loss:1.616, Validation accuracy:65.05%
# Epoch 397: iteration 92/93
# Epoch 397 --- loss:0.016, Epoch accuracy:99.60%, Validation loss:1.646, Validation accuracy:65.86%
# Epoch 398: iteration 92/93
# Epoch 398 --- loss:0.015, Epoch accuracy:99.60%, Validation loss:1.672, Validation accuracy:67.20%
# Epoch 399: iteration 92/93
# Epoch 399 --- loss:0.021, Epoch accuracy:99.26%, Validation loss:1.780, Validation accuracy:65.86%
# Epoch 400: iteration 92/93
# Epoch 400 --- loss:0.038, Epoch accuracy:98.76%, Validation loss:1.498, Validation accuracy:68.82%
# Epoch 401: iteration 92/93
# Epoch 401 --- loss:0.017, Epoch accuracy:99.66%, Validation loss:1.567, Validation accuracy:67.74%
# Epoch 402: iteration 92/93
# Epoch 402 --- loss:0.056, Epoch accuracy:97.89%, Validation loss:1.574, Validation accuracy:66.13%
# Epoch 403: iteration 92/93
# Epoch 403 --- loss:0.058, Epoch accuracy:97.85%, Validation loss:1.556, Validation accuracy:68.01%
# Epoch 404: iteration 92/93
# Epoch 404 --- loss:0.039, Epoch accuracy:98.63%, Validation loss:1.732, Validation accuracy:66.13%
# Epoch 405: iteration 92/93
# Epoch 405 --- loss:0.042, Epoch accuracy:98.49%, Validation loss:1.768, Validation accuracy:65.86%
# Epoch 406: iteration 92/93
# Epoch 406 --- loss:0.047, Epoch accuracy:98.49%, Validation loss:1.614, Validation accuracy:68.01%
# Epoch 407: iteration 92/93
# Epoch 407 --- loss:0.034, Epoch accuracy:98.83%, Validation loss:1.626, Validation accuracy:65.32%
# Epoch 408: iteration 92/93
# Epoch 408 --- loss:0.022, Epoch accuracy:99.43%, Validation loss:1.588, Validation accuracy:66.94%
# Epoch 409: iteration 92/93
# Epoch 409 --- loss:0.018, Epoch accuracy:99.53%, Validation loss:1.592, Validation accuracy:69.09%
# Epoch 410: iteration 92/93
# Epoch 410 --- loss:0.012, Epoch accuracy:99.66%, Validation loss:1.588, Validation accuracy:68.01%
# Epoch 411: iteration 92/93
# Epoch 411 --- loss:0.023, Epoch accuracy:99.33%, Validation loss:1.777, Validation accuracy:65.32%
# Epoch 412: iteration 92/93
# Epoch 412 --- loss:0.013, Epoch accuracy:99.73%, Validation loss:1.620, Validation accuracy:67.47%
# Epoch 413: iteration 92/93
# Epoch 413 --- loss:0.013, Epoch accuracy:99.60%, Validation loss:1.626, Validation accuracy:66.67%
# Epoch 414: iteration 92/93
# Epoch 414 --- loss:0.012, Epoch accuracy:99.63%, Validation loss:1.795, Validation accuracy:64.25%
# Epoch 415: iteration 92/93
# Epoch 415 --- loss:0.010, Epoch accuracy:99.77%, Validation loss:1.564, Validation accuracy:69.62%
# Epoch 416: iteration 92/93
# Epoch 416 --- loss:0.008, Epoch accuracy:99.80%, Validation loss:1.671, Validation accuracy:65.86%
# Epoch 417: iteration 92/93
# Epoch 417 --- loss:0.009, Epoch accuracy:99.77%, Validation loss:1.633, Validation accuracy:67.74%
# Epoch 418: iteration 92/93
# Epoch 418 --- loss:0.010, Epoch accuracy:99.66%, Validation loss:1.634, Validation accuracy:66.94%
# Epoch 419: iteration 92/93
# Epoch 419 --- loss:0.011, Epoch accuracy:99.66%, Validation loss:1.692, Validation accuracy:67.20%
# Epoch 420: iteration 92/93
# Epoch 420 --- loss:0.010, Epoch accuracy:99.73%, Validation loss:1.646, Validation accuracy:68.55%
# Epoch 421: iteration 92/93
# Epoch 421 --- loss:0.019, Epoch accuracy:99.30%, Validation loss:1.766, Validation accuracy:68.28%
# Epoch 422: iteration 92/93
# Epoch 422 --- loss:0.111, Epoch accuracy:95.77%, Validation loss:1.601, Validation accuracy:66.13%
# Epoch 423: iteration 92/93
# Epoch 423 --- loss:0.063, Epoch accuracy:97.75%, Validation loss:1.464, Validation accuracy:66.94%
# Epoch 424: iteration 92/93
# Epoch 424 --- loss:0.034, Epoch accuracy:98.99%, Validation loss:1.485, Validation accuracy:68.55%
# Epoch 425: iteration 92/93
# Epoch 425 --- loss:0.027, Epoch accuracy:99.13%, Validation loss:1.557, Validation accuracy:66.13%
# Epoch 426: iteration 92/93
# Epoch 426 --- loss:0.027, Epoch accuracy:99.30%, Validation loss:1.709, Validation accuracy:63.44%
# Epoch 427: iteration 92/93
# Epoch 427 --- loss:0.026, Epoch accuracy:99.40%, Validation loss:1.625, Validation accuracy:66.94%
# Epoch 428: iteration 92/93
# Epoch 428 --- loss:0.012, Epoch accuracy:99.73%, Validation loss:1.630, Validation accuracy:67.20%
# Epoch 429: iteration 92/93
# Epoch 429 --- loss:0.015, Epoch accuracy:99.60%, Validation loss:1.621, Validation accuracy:65.59%
# Epoch 430: iteration 92/93
# Epoch 430 --- loss:0.015, Epoch accuracy:99.60%, Validation loss:1.781, Validation accuracy:66.40%
# Epoch 431: iteration 92/93
# Epoch 431 --- loss:0.061, Epoch accuracy:97.85%, Validation loss:1.872, Validation accuracy:63.98%
# Epoch 432: iteration 92/93
# Epoch 432 --- loss:0.046, Epoch accuracy:98.39%, Validation loss:1.872, Validation accuracy:63.71%
# Epoch 433: iteration 92/93
# Epoch 433 --- loss:0.061, Epoch accuracy:97.65%, Validation loss:1.897, Validation accuracy:61.83%
# Epoch 434: iteration 92/93
# Epoch 434 --- loss:0.023, Epoch accuracy:99.43%, Validation loss:1.688, Validation accuracy:65.86%
# Epoch 435: iteration 92/93
# Epoch 435 --- loss:0.027, Epoch accuracy:98.99%, Validation loss:1.852, Validation accuracy:65.32%
# Epoch 436: iteration 92/93
# Epoch 436 --- loss:0.037, Epoch accuracy:98.79%, Validation loss:1.588, Validation accuracy:65.59%
# Epoch 437: iteration 92/93
# Epoch 437 --- loss:0.025, Epoch accuracy:99.09%, Validation loss:1.850, Validation accuracy:66.67%
# Epoch 438: iteration 92/93
# Epoch 438 --- loss:0.077, Epoch accuracy:97.38%, Validation loss:1.797, Validation accuracy:65.32%
# Epoch 439: iteration 92/93
# Epoch 439 --- loss:0.052, Epoch accuracy:98.29%, Validation loss:1.687, Validation accuracy:65.32%
# Epoch 440: iteration 92/93
# Epoch 440 --- loss:0.035, Epoch accuracy:98.79%, Validation loss:1.619, Validation accuracy:68.55%
# Epoch 441: iteration 92/93
# Epoch 441 --- loss:0.020, Epoch accuracy:99.36%, Validation loss:1.653, Validation accuracy:69.35%
# Epoch 442: iteration 92/93
# Epoch 442 --- loss:0.019, Epoch accuracy:99.40%, Validation loss:1.637, Validation accuracy:66.40%
# Epoch 443: iteration 92/93
# Epoch 443 --- loss:0.018, Epoch accuracy:99.60%, Validation loss:1.733, Validation accuracy:66.67%
# Epoch 444: iteration 92/93
# Epoch 444 --- loss:0.011, Epoch accuracy:99.70%, Validation loss:1.543, Validation accuracy:70.16%
# Epoch 445: iteration 92/93
# Epoch 445 --- loss:0.026, Epoch accuracy:99.16%, Validation loss:1.747, Validation accuracy:68.28%
# Epoch 446: iteration 92/93
# Epoch 446 --- loss:0.049, Epoch accuracy:98.05%, Validation loss:1.674, Validation accuracy:66.67%
# Epoch 447: iteration 92/93
# Epoch 447 --- loss:0.038, Epoch accuracy:98.63%, Validation loss:1.712, Validation accuracy:66.67%
# Epoch 448: iteration 92/93
# Epoch 448 --- loss:0.019, Epoch accuracy:99.53%, Validation loss:1.673, Validation accuracy:70.16%
# Epoch 449: iteration 92/93
# Epoch 449 --- loss:0.017, Epoch accuracy:99.70%, Validation loss:1.818, Validation accuracy:65.59%
# Epoch 450: iteration 92/93
# Epoch 450 --- loss:0.015, Epoch accuracy:99.60%, Validation loss:1.553, Validation accuracy:68.28%
# Epoch 451: iteration 92/93
# Epoch 451 --- loss:0.054, Epoch accuracy:98.09%, Validation loss:1.863, Validation accuracy:65.32%
# Epoch 452: iteration 92/93
# Epoch 452 --- loss:0.042, Epoch accuracy:98.69%, Validation loss:1.945, Validation accuracy:60.75%
# Epoch 453: iteration 92/93
# Epoch 453 --- loss:0.192, Epoch accuracy:93.43%, Validation loss:1.564, Validation accuracy:66.94%
# Epoch 454: iteration 92/93
# Epoch 454 --- loss:0.059, Epoch accuracy:98.19%, Validation loss:1.510, Validation accuracy:69.62%
# Epoch 455: iteration 92/93
# Epoch 455 --- loss:0.028, Epoch accuracy:99.16%, Validation loss:1.647, Validation accuracy:66.40%
# Epoch 456: iteration 92/93
# Epoch 456 --- loss:0.026, Epoch accuracy:99.23%, Validation loss:1.592, Validation accuracy:70.16%
# Epoch 457: iteration 92/93
# Epoch 457 --- loss:0.022, Epoch accuracy:99.33%, Validation loss:1.717, Validation accuracy:65.05%
# Epoch 458: iteration 92/93
# Epoch 458 --- loss:0.021, Epoch accuracy:99.43%, Validation loss:1.692, Validation accuracy:69.35%
# Epoch 459: iteration 92/93
# Epoch 459 --- loss:0.013, Epoch accuracy:99.73%, Validation loss:1.709, Validation accuracy:66.94%
# Epoch 460: iteration 92/93
# Epoch 460 --- loss:0.011, Epoch accuracy:99.70%, Validation loss:1.591, Validation accuracy:68.28%
# Epoch 461: iteration 92/93
# Epoch 461 --- loss:0.011, Epoch accuracy:99.73%, Validation loss:1.573, Validation accuracy:68.28%
# Epoch 462: iteration 92/93
# Epoch 462 --- loss:0.014, Epoch accuracy:99.60%, Validation loss:1.612, Validation accuracy:67.47%
# Epoch 463: iteration 92/93
# Epoch 463 --- loss:0.011, Epoch accuracy:99.70%, Validation loss:1.710, Validation accuracy:66.67%
# Epoch 464: iteration 92/93
# Epoch 464 --- loss:0.012, Epoch accuracy:99.70%, Validation loss:1.621, Validation accuracy:68.01%
# Epoch 465: iteration 92/93
# Epoch 465 --- loss:0.009, Epoch accuracy:99.80%, Validation loss:1.652, Validation accuracy:68.28%
# Epoch 466: iteration 92/93
# Epoch 466 --- loss:0.010, Epoch accuracy:99.70%, Validation loss:1.659, Validation accuracy:67.74%
# Epoch 467: iteration 92/93
# Epoch 467 --- loss:0.012, Epoch accuracy:99.70%, Validation loss:1.637, Validation accuracy:67.47%
# Epoch 468: iteration 92/93
# Epoch 468 --- loss:0.008, Epoch accuracy:99.77%, Validation loss:1.593, Validation accuracy:69.62%
# Epoch 469: iteration 92/93
# Epoch 469 --- loss:0.008, Epoch accuracy:99.80%, Validation loss:1.656, Validation accuracy:68.55%
# Epoch 470: iteration 92/93
# Epoch 470 --- loss:0.036, Epoch accuracy:98.73%, Validation loss:1.693, Validation accuracy:66.40%
# Epoch 471: iteration 92/93
# Epoch 471 --- loss:0.030, Epoch accuracy:98.93%, Validation loss:1.716, Validation accuracy:66.13%
# Epoch 472: iteration 92/93
# Epoch 472 --- loss:0.023, Epoch accuracy:99.23%, Validation loss:1.806, Validation accuracy:66.94%
# Epoch 473: iteration 92/93
# Epoch 473 --- loss:0.019, Epoch accuracy:99.56%, Validation loss:1.841, Validation accuracy:64.52%
# Epoch 474: iteration 92/93
# Epoch 474 --- loss:0.023, Epoch accuracy:99.20%, Validation loss:1.842, Validation accuracy:63.17%
# Epoch 475: iteration 92/93
# Epoch 475 --- loss:0.051, Epoch accuracy:98.26%, Validation loss:1.606, Validation accuracy:69.62%
# Epoch 476: iteration 92/93
# Epoch 476 --- loss:0.056, Epoch accuracy:98.02%, Validation loss:1.754, Validation accuracy:63.44%
# Epoch 477: iteration 92/93
# Epoch 477 --- loss:0.033, Epoch accuracy:99.16%, Validation loss:1.790, Validation accuracy:65.59%
# Epoch 478: iteration 92/93
# Epoch 478 --- loss:0.038, Epoch accuracy:98.69%, Validation loss:1.703, Validation accuracy:66.67%
# Epoch 479: iteration 92/93
# Epoch 479 --- loss:0.022, Epoch accuracy:99.30%, Validation loss:1.740, Validation accuracy:65.05%
# Epoch 480: iteration 92/93
# Epoch 480 --- loss:0.016, Epoch accuracy:99.70%, Validation loss:1.744, Validation accuracy:66.13%
# Epoch 481: iteration 92/93
# Epoch 481 --- loss:0.011, Epoch accuracy:99.73%, Validation loss:1.705, Validation accuracy:67.47%
# Epoch 482: iteration 92/93
# Epoch 482 --- loss:0.014, Epoch accuracy:99.60%, Validation loss:1.726, Validation accuracy:65.32%
# Epoch 483: iteration 92/93
# Epoch 483 --- loss:0.027, Epoch accuracy:98.96%, Validation loss:1.688, Validation accuracy:66.67%
# Epoch 484: iteration 92/93
# Epoch 484 --- loss:0.087, Epoch accuracy:96.68%, Validation loss:2.122, Validation accuracy:59.68%
# Epoch 485: iteration 92/93
# Epoch 485 --- loss:0.050, Epoch accuracy:98.36%, Validation loss:1.760, Validation accuracy:64.25%
# Epoch 486: iteration 92/93
# Epoch 486 --- loss:0.026, Epoch accuracy:99.36%, Validation loss:1.658, Validation accuracy:65.86%
# Epoch 487: iteration 92/93
# Epoch 487 --- loss:0.027, Epoch accuracy:99.16%, Validation loss:1.579, Validation accuracy:67.20%
# Epoch 488: iteration 92/93
# Epoch 488 --- loss:0.024, Epoch accuracy:99.23%, Validation loss:1.696, Validation accuracy:65.05%
# Epoch 489: iteration 92/93
# Epoch 489 --- loss:0.013, Epoch accuracy:99.73%, Validation loss:1.611, Validation accuracy:68.28%
# Epoch 490: iteration 92/93
# Epoch 490 --- loss:0.024, Epoch accuracy:99.26%, Validation loss:1.849, Validation accuracy:63.98%
# Epoch 491: iteration 92/93
# Epoch 491 --- loss:0.039, Epoch accuracy:98.73%, Validation loss:1.783, Validation accuracy:62.90%
# Epoch 492: iteration 92/93
# Epoch 492 --- loss:0.075, Epoch accuracy:97.28%, Validation loss:1.704, Validation accuracy:65.59%
# Epoch 493: iteration 92/93
# Epoch 493 --- loss:0.077, Epoch accuracy:97.05%, Validation loss:1.496, Validation accuracy:70.43%
# Epoch 494: iteration 92/93
# Epoch 494 --- loss:0.023, Epoch accuracy:99.50%, Validation loss:1.725, Validation accuracy:65.59%
# Epoch 495: iteration 92/93
# Epoch 495 --- loss:0.015, Epoch accuracy:99.66%, Validation loss:1.522, Validation accuracy:68.55%
# Epoch 496: iteration 92/93
# Epoch 496 --- loss:0.015, Epoch accuracy:99.53%, Validation loss:1.617, Validation accuracy:65.86%
# Epoch 497: iteration 92/93
# Epoch 497 --- loss:0.013, Epoch accuracy:99.70%, Validation loss:1.597, Validation accuracy:66.94%
# Epoch 498: iteration 92/93
# Epoch 498 --- loss:0.009, Epoch accuracy:99.80%, Validation loss:1.573, Validation accuracy:68.55%
# Epoch 499: iteration 92/93
# Epoch 499 --- loss:0.011, Epoch accuracy:99.70%, Validation loss:1.795, Validation accuracy:64.25%

# %%
plt.title('Loss Curve for Parallel is All You Want Model')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_losses[:],'b')
plt.plot(valid_losses[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()

# %%
# pick load folder  
load_folder = '/content/drive/My Drive/models/CNN_7_emotion/'  

# pick the epoch to load
epoch = '499'
model_name = f'parallel_all_you_wantFINAL-{epoch}.pkl'

# make full load path
load_path = os.path.join(load_folder, model_name)

## instantiate empty model and populate with params from binary 
model = parallel_all_you_want(len(emotions_dict))
load_checkpoint(optimizer, model, load_path)

print(f'Loaded model from {load_path}')
# Out:
# Loaded model from /content/drive/My Drive/models/CNN_7_emotion/parallel_all_you_wantFINAL-499.pkl

# %%
# reinitialize validation function with model from chosen checkpoint
validate = make_validate_fnc(model,criterion)

# Convert 4D test feature set array to tensor and move to GPU
X_test_tensor = torch.tensor(X_test,device=device).float()
# Convert 4D test label set array to tensor and move to GPU
y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
inputs =  X_test_tensor                     # this is what you had
labels =  y_test_tensor
#inputs, labels = inputs.cuda(), labels.cuda() # add this line
# Get the model's performance metrics using the validation function we defined

#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

#inputs, labels = inputs.to(device), labels.to(device)
model.to('cuda') 
inputs = inputs.to('cuda')

model.to('cuda') 
labels = labels.to('cuda')

test_loss, test_acc, predicted_emotions = validate(X_test_tensor,y_test_tensor)

print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test accuracy is 64.87%
