# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Orignial Notebook: https://github.com/MITESHPUTHRANNEU/Speech-Emotion-Analyzer/blob/master/final_results_gender_test.ipynb
# This notebook author: Reza Chu
# Last Editing Date: 31st May 2019

## Python
import os
import random
import sys

import IPython
from IPython.display import Audio
from IPython.display import Image
import matplotlib.pyplot as plt

## Package
import glob 
import keras
import IPython.display as ipd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.graph_objs as go
import plotly.offline as py
import plotly.tools as tls
import seaborn as sns
import scipy.io.wavfile
import tensorflow as tf
py.init_notebook_mode(connected=True)

## Keras
from keras import regularizers
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from keras.callbacks import  History, ReduceLROnPlateau, CSVLogger
from keras.models import Model, Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.preprocessing import sequence
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils
from tensorflow.keras.utils import to_categorical

## Sklearn
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder

## Rest
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile
from tqdm import tqdm

input_duration=3
# % pylab inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#only SAVEE data set
import time
import os
import librosa
from librosa import display
import matplotlib.pyplot as plt
#sad/sa2dc.avi
labels = []
video_name=[]
audio_name=[]
features=[]
count=0
start_time = time.time()
CLASSES_LIST=['KL','JK ','JE','DC']
DATASET_DIR = '/content/drive/My Drive/SAVEE'
emotion_LIST = ["neutral", "happy", "sad","angry","fearful"]
for class_index, class_name in enumerate(CLASSES_LIST):
#for subdir, dirs, files in os.walk(path):
  print(class_name)
  #dir=subdir.split('/')[4]
  #print(dir)
  
  files= os.listdir(os.path.join(DATASET_DIR, class_name))
  for file in files:
      try:
        print(file)
        #Load librosa array, obtain mfcss, store the file and the mcss information in a new array
        X, sample_rate = librosa.load(DATASET_DIR+'/'+class_name+'/'+file, res_type='kaiser_fast')
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) 
        count +=1
        # The instruction below converts the labels (from 1 to 8) to a series from 0 to 7
        # This is because our predictor needs to start from 0 otherwise it will try to predict also 0.
        #file = int(file[7:8]) - 1 
        #0 = neutral, 1 = happy, 2 = sad, 3 = angry, 4 = fearful, 6 = disgust, 7 = surprised
        if file.startswith('a'):
            emotion=3
            c='a'
    
        elif file.startswith('f'):
            emotion=4
            c='f'
        elif file.startswith('h'):
            emotion=1
            c='h'
        elif file.startswith('n'):
            emotion=0
            c='n'
        elif file.startswith('sa'):
            emotion=2
            c='sa'
       
        else:
            continue
        my_class_name=class_name
        my_class_name=my_class_name.replace(" ", "")
        num=file.split('.')[0]
        #print(num)
        if(c=='sa'):
          num=num[2:]
        else:
          num=num[1:]
        num=int(num)
        num=str(num)
        #print(num)
       
        v=emotion_LIST[emotion]+'/'+c+num+my_class_name.lower()+'.avi'
        video_name.append(v)
        a=class_name+'/'+file

        audio_name.append(a)
        labels.append(emotion)
        
        features.append(mfccs)
      # If the file is not valid, skip it
      except ValueError:
        continue

print("--- Data loaded. Loading time: %s seconds ---" % (time.time() - start_time))
# Out:
# KL
# a01.wav
# a02.wav
# a03.wav
# a04.wav
# a05.wav
# a07.wav
# a10.wav
# a09.wav
# a08.wav
# a06.wav
# a15.wav
# a14.wav
# a13.wav
# a12.wav
# a11.wav
# d05.wav
# d04.wav
# d03.wav
# d02.wav
# d01.wav
# d10.wav
# d09.wav
# d08.wav
# d07.wav
# d06.wav
# d15.wav
# d14.wav
# d13.wav
# d12.wav
# d11.wav
# f05.wav
# f04.wav
# f03.wav
# f02.wav
# f01.wav
# f10.wav
# f09.wav
# f08.wav
# f07.wav
# f06.wav
# f15.wav
# f14.wav
# f13.wav
# f12.wav
# f11.wav
# h05.wav
# h04.wav
# h03.wav
# h02.wav
# h01.wav
# h10.wav
# h09.wav
# h08.wav
# h07.wav
# h06.wav
# h15.wav
# h14.wav
# h13.wav
# h12.wav
# h11.wav
# sa05.wav
# sa04.wav
# sa03.wav
# sa02.wav
# sa01.wav
# sa10.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa11.wav
# sa14.wav
# sa13.wav
# sa12.wav
# sa15.wav
# su05.wav
# su03.wav
# su02.wav
# su01.wav
# su10.wav
# su09.wav
# su08.wav
# su07.wav
# su06.wav
# su15.wav
# su14.wav
# su13.wav
# su12.wav
# su11.wav
# su04.wav
# n01.wav
# n05.wav
# n04.wav
# n03.wav
# n02.wav
# n10.wav
# n09.wav
# n08.wav
# n07.wav
# n06.wav
# n20.wav
# n19.wav
# n18.wav
# n17.wav
# n16.wav
# n25.wav
# n24.wav
# n23.wav
# n22.wav
# n21.wav
# n30.wav
# n29.wav
# n28.wav
# n27.wav
# n26.wav
# n15.wav
# n14.wav
# n13.wav
# n12.wav
# n11.wav
# JK
# a01.wav
# a02.wav
# a03.wav
# a04.wav
# a05.wav
# a06.wav
# a07.wav
# a08.wav
# a09.wav
# a10.wav
# a11.wav
# a12.wav
# a13.wav
# a14.wav
# a15.wav
# d01.wav
# d02.wav
# d03.wav
# d04.wav
# d06.wav
# d07.wav
# d08.wav
# d09.wav
# d11.wav
# d12.wav
# d13.wav
# d14.wav
# d15.wav
# d05.wav
# d10.wav
# f01.wav
# f02.wav
# f03.wav
# f04.wav
# f05.wav
# f06.wav
# f07.wav
# f08.wav
# f10.wav
# f11.wav
# f12.wav
# f13.wav
# f14.wav
# f15.wav
# f09.wav
# h01.wav
# h02.wav
# h03.wav
# h04.wav
# h05.wav
# h06.wav
# h07.wav
# h08.wav
# h09.wav
# h10.wav
# h11.wav
# h12.wav
# h13.wav
# h14.wav
# h15.wav
# n01.wav
# n02.wav
# n03.wav
# n04.wav
# n05.wav
# n06.wav
# n07.wav
# n08.wav
# n09.wav
# n10.wav
# n11.wav
# n12.wav
# n13.wav
# n14.wav
# n15.wav
# n20.wav
# n19.wav
# n18.wav
# n17.wav
# n16.wav
# n25.wav
# n23.wav
# n22.wav
# n21.wav
# n26.wav
# n30.wav
# n29.wav
# n28.wav
# n27.wav
# sa05.wav
# sa04.wav
# sa03.wav
# sa02.wav
# sa01.wav
# sa10.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa15.wav
# sa14.wav
# sa13.wav
# sa12.wav
# sa11.wav
# su05.wav
# su04.wav
# su15.wav
# su14.wav
# su13.wav
# su12.wav
# su11.wav
# su10.wav
# su09.wav
# su08.wav
# su07.wav
# su06.wav
# su03.wav
# su02.wav
# su01.wav
# n24.wav
# JE
# a01.wav
# a02.wav
# a03.wav
# a04.wav
# a05.wav
# a07.wav
# a06.wav
# a08.wav
# a09.wav
# a10.wav
# a11.wav
# a12.wav
# a13.wav
# a14.wav
# a15.wav
# d05.wav
# d04.wav
# d03.wav
# d02.wav
# d01.wav
# d09.wav
# d08.wav
# d07.wav
# d06.wav
# d10.wav
# d15.wav
# d14.wav
# d13.wav
# d12.wav
# d11.wav
# f05.wav
# f04.wav
# f03.wav
# f02.wav
# f01.wav
# f10.wav
# f09.wav
# f08.wav
# f07.wav
# f06.wav
# f14.wav
# f13.wav
# f12.wav
# f11.wav
# f15.wav
# h05.wav
# h04.wav
# h03.wav
# h02.wav
# h01.wav
# h10.wav
# h09.wav
# h08.wav
# h07.wav
# h06.wav
# h14.wav
# h13.wav
# h12.wav
# h11.wav
# h15.wav
# n18.wav
# n17.wav
# n16.wav
# n05.wav
# n04.wav
# n03.wav
# n02.wav
# n01.wav
# n10.wav
# n09.wav
# n08.wav
# n07.wav
# n06.wav
# n15.wav
# n14.wav
# n13.wav
# n12.wav
# n11.wav
# n20.wav
# n19.wav
# n25.wav
# n24.wav
# n23.wav
# n22.wav
# n21.wav
# n30.wav
# n29.wav
# n28.wav
# n27.wav
# n26.wav
# sa04.wav
# sa03.wav
# sa02.wav
# sa01.wav
# sa13.wav
# sa12.wav
# sa11.wav
# sa05.wav
# sa10.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa15.wav
# sa14.wav
# su05.wav
# su04.wav
# su03.wav
# su02.wav
# su01.wav
# su10.wav
# su09.wav
# su08.wav
# su07.wav
# su06.wav
# su13.wav
# su12.wav
# su11.wav
# su15.wav
# su14.wav
# DC
# a15.wav
# a14.wav
# a05.wav
# a04.wav
# a03.wav
# a02.wav
# a01.wav
# a06.wav
# a07.wav
# a08.wav
# a09.wav
# a10.wav
# a13.wav
# a12.wav
# a11.wav
# d01.wav
# d02.wav
# d03.wav
# d04.wav
# d05.wav
# d10.wav
# d09.wav
# d08.wav
# d07.wav
# d06.wav
# d15.wav
# d14.wav
# d13.wav
# d12.wav
# d11.wav
# f01.wav
# f02.wav
# f03.wav
# f04.wav
# f05.wav
# f10.wav
# f09.wav
# f08.wav
# f07.wav
# f06.wav
# f15.wav
# f14.wav
# f13.wav
# f12.wav
# f11.wav
# h01.wav
# h02.wav
# h03.wav
# h04.wav
# h05.wav
# h10.wav
# h09.wav
# h08.wav
# h07.wav
# h06.wav
# h11.wav
# h12.wav
# h13.wav
# h14.wav
# h15.wav
# n05.wav
# n04.wav
# n03.wav
# n02.wav
# n01.wav
# n06.wav
# n07.wav
# n08.wav
# n09.wav
# n10.wav
# n11.wav
# n12.wav
# n13.wav
# n14.wav
# n15.wav
# n20.wav
# n19.wav
# n18.wav
# n17.wav
# n16.wav
# n21.wav
# n22.wav
# n23.wav
# n24.wav
# n25.wav
# n26.wav
# n27.wav
# n28.wav
# n29.wav
# n30.wav
# sa01.wav
# sa02.wav
# sa03.wav
# sa04.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa11.wav
# sa12.wav
# sa13.wav
# sa14.wav
# sa15.wav
# sa05.wav
# sa10.wav
# su01.wav
# su02.wav
# su03.wav
# su04.wav
# su05.wav
# su06.wav
# su07.wav
# su08.wav
# su09.wav
# su11.wav
# su12.wav
# su13.wav
# su14.wav
# su15.wav
# su10.wav
# --- Data loaded. Loading time: 109.99098062515259 seconds ---

# %%
seed_constant = 588156

# %%
from sklearn.model_selection import train_test_split
# Split the Data into Train ( 80% ) and Test Set ( 20% ).
x_train, x_test, y_train, y_test,video_train_path,video_test_path,audio_train_path,audio_test_path = train_test_split(features, labels,video_name,audio_name,
                                                                            test_size = 0.10, shuffle = True,
                                                                            random_state = seed_constant)

# %%
# Split train the Data into Train ( 80% ) and valid Set ( 20% ).
x_train, x_valid, y_train, y_valid,video_train_path,video_valid_path,audio_train_path,audio_valid_path = train_test_split(x_train, y_train,video_train_path,audio_train_path,
                                                                            test_size = 0.11, shuffle = True,
                                                                            random_state = seed_constant)

# %%
#288,36,36
len(x_train),len(x_valid),len(x_test),len(y_train),len(y_valid),len(y_test),len(video_train_path),len(video_valid_path),len(video_test_path),len(audio_train_path),len(audio_valid_path),len(audio_test_path)
# Out:
# (288, 36, 36, 288, 36, 36, 288, 36, 36, 288, 36, 36)

# %%
import joblib

save_dir = '/content/drive/My Drive/fusion/savee/audio/data_set/expert1'

savedvX = joblib.dump(y_train, os.path.join(save_dir, 'train/labels_train'))
savedvX = joblib.dump(y_test, os.path.join(save_dir, 'test/labels_test'))
savedvX = joblib.dump(y_valid, os.path.join(save_dir, 'valid/labels_valid'))
savedvX = joblib.dump(video_train_path, os.path.join(save_dir, 'train/video_train_path'))
savedvX = joblib.dump(video_test_path, os.path.join(save_dir, 'test/video_test_path'))
savedvX = joblib.dump(video_valid_path, os.path.join(save_dir, 'valid/video_valid_path'))
savedvX = joblib.dump(audio_train_path, os.path.join(save_dir, 'train/audio_train_path'))
savedvX = joblib.dump(audio_test_path, os.path.join(save_dir, 'test/audio_test_path'))
savedvX = joblib.dump(audio_valid_path, os.path.join(save_dir, 'valid/audio_valid_path'))

# %%
x_valid=np.asarray(x_valid)
x_test=np.asarray(x_test)
x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
y_test=np.asarray(y_test)
y_valid=np.asarray(y_valid)
x_valid.shape,x_test.shape,x_train.shape,y_valid.shape,y_test.shape,y_train.shape
# Out:
# ((36, 40), (36, 40), (288, 40), (36,), (36,), (288,))

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras import optimizers
from keras.models import InputLayer

model = Sequential(InputLayer((40,1)))
model.add(BatchNormalization())

model.add(Conv1D(128, 12,padding='same', ))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=(5)))


model.add(Conv1D(256,12,padding='same',))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(MaxPooling1D(pool_size=(5)))

model.add(Flatten())
model.add(Dense(5))
model.add(Activation('softmax'))
opt = tf.keras.optimizers.Adam(lr=0.0002)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 40, 1)            4
#  ormalization)
#
#  conv1d (Conv1D)             (None, 40, 128)           1664
#
#  batch_normalization_1 (Batc  (None, 40, 128)          512
#  hNormalization)
#
#  activation (Activation)     (None, 40, 128)           0
#
#  dropout (Dropout)           (None, 40, 128)           0
#
#  max_pooling1d (MaxPooling1D  (None, 8, 128)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 8, 256)            393472
#
#  batch_normalization_2 (Batc  (None, 8, 256)           1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8, 256)            0
#
#  dropout_1 (Dropout)         (None, 8, 256)            0
#
#  max_pooling1d_1 (MaxPooling  (None, 1, 256)           0
#  1D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 5)                 1285
#
#  activation_2 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 397,961
# Trainable params: 397,191
# Non-trainable params: 770
# _________________________________________________________________

# %%
x_traincnn = np.expand_dims(x_train, axis=2)
x_testcnn = np.expand_dims(x_test, axis=2)
x_valid= np.expand_dims(x_valid, axis=2)
x_traincnn.shape, x_testcnn.shape , x_valid.shape
# Out:
# ((288, 40, 1), (36, 40, 1), (36, 40, 1))

# %%
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = opt, metrics = ["accuracy"])

early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 65, mode = 'min', restore_best_weights = True)
cnnhistory=model.fit(x_traincnn, y_train, batch_size=16, epochs=500 , shuffle = True, 
                     validation_data=(x_valid, y_valid), callbacks = [early_stopping_callback])
# Out:
# Epoch 1/500
# 18/18 [==============================] - 13s 23ms/step - loss: 2.0021 - accuracy: 0.3090 - val_loss: 1.5458 - val_accuracy: 0.3056
# Epoch 2/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.7553 - accuracy: 0.3576 - val_loss: 1.5838 - val_accuracy: 0.1944
# Epoch 3/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.5890 - accuracy: 0.3854 - val_loss: 1.5952 - val_accuracy: 0.1667
# Epoch 4/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.3876 - accuracy: 0.4340 - val_loss: 1.6571 - val_accuracy: 0.1667
# Epoch 5/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.2372 - accuracy: 0.5069 - val_loss: 1.7436 - val_accuracy: 0.1667
# Epoch 6/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.2003 - accuracy: 0.5486 - val_loss: 1.8220 - val_accuracy: 0.1667
# Epoch 7/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.1399 - accuracy: 0.5764 - val_loss: 1.8257 - val_accuracy: 0.1667
# Epoch 8/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.1729 - accuracy: 0.5556 - val_loss: 1.9404 - val_accuracy: 0.1667
# Epoch 9/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0826 - accuracy: 0.5868 - val_loss: 2.0182 - val_accuracy: 0.1667
# Epoch 10/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0891 - accuracy: 0.5729 - val_loss: 2.2062 - val_accuracy: 0.1667
# Epoch 11/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0113 - accuracy: 0.5938 - val_loss: 2.1221 - val_accuracy: 0.1667
# Epoch 12/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.9861 - accuracy: 0.6458 - val_loss: 2.4609 - val_accuracy: 0.1667
# Epoch 13/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0314 - accuracy: 0.6319 - val_loss: 2.3205 - val_accuracy: 0.1667
# Epoch 14/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8962 - accuracy: 0.6701 - val_loss: 2.5308 - val_accuracy: 0.1667
# Epoch 15/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8898 - accuracy: 0.6701 - val_loss: 2.4858 - val_accuracy: 0.1667
# Epoch 16/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8399 - accuracy: 0.6944 - val_loss: 2.6228 - val_accuracy: 0.1667
# Epoch 17/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8880 - accuracy: 0.6667 - val_loss: 2.2281 - val_accuracy: 0.1667
# Epoch 18/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8774 - accuracy: 0.6562 - val_loss: 2.5164 - val_accuracy: 0.1667
# Epoch 19/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8354 - accuracy: 0.6771 - val_loss: 2.2842 - val_accuracy: 0.1667
# Epoch 20/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8181 - accuracy: 0.6736 - val_loss: 2.1273 - val_accuracy: 0.1667
# Epoch 21/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8210 - accuracy: 0.6875 - val_loss: 2.1837 - val_accuracy: 0.1667
# Epoch 22/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7616 - accuracy: 0.6979 - val_loss: 2.0667 - val_accuracy: 0.1667
# Epoch 23/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7992 - accuracy: 0.6875 - val_loss: 1.7040 - val_accuracy: 0.1944
# Epoch 24/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8215 - accuracy: 0.7083 - val_loss: 1.5292 - val_accuracy: 0.2500
# Epoch 25/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7953 - accuracy: 0.7014 - val_loss: 1.8034 - val_accuracy: 0.1944
# Epoch 26/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7463 - accuracy: 0.7014 - val_loss: 1.3231 - val_accuracy: 0.3056
# Epoch 27/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7318 - accuracy: 0.6979 - val_loss: 1.4365 - val_accuracy: 0.2778
# Epoch 28/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.7462 - accuracy: 0.7049 - val_loss: 1.1635 - val_accuracy: 0.5000
# Epoch 29/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7305 - accuracy: 0.7361 - val_loss: 1.2144 - val_accuracy: 0.5278
# Epoch 30/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6994 - accuracy: 0.7153 - val_loss: 1.0566 - val_accuracy: 0.5556
# Epoch 31/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7122 - accuracy: 0.7083 - val_loss: 1.1069 - val_accuracy: 0.5278
# Epoch 32/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6956 - accuracy: 0.7118 - val_loss: 0.9521 - val_accuracy: 0.6389
# Epoch 33/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6409 - accuracy: 0.7500 - val_loss: 1.0317 - val_accuracy: 0.5833
# Epoch 34/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7348 - accuracy: 0.6979 - val_loss: 0.9449 - val_accuracy: 0.6389
# Epoch 35/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6940 - accuracy: 0.7188 - val_loss: 1.0143 - val_accuracy: 0.6389
# Epoch 36/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6875 - accuracy: 0.7396 - val_loss: 0.8723 - val_accuracy: 0.6667
# Epoch 37/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6179 - accuracy: 0.7222 - val_loss: 0.9867 - val_accuracy: 0.5278
# Epoch 38/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6104 - accuracy: 0.7674 - val_loss: 0.8582 - val_accuracy: 0.6944
# Epoch 39/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6940 - accuracy: 0.7465 - val_loss: 1.0006 - val_accuracy: 0.5000
# Epoch 40/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7623 - accuracy: 0.6944 - val_loss: 1.1149 - val_accuracy: 0.5833
# Epoch 41/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6563 - accuracy: 0.7465 - val_loss: 0.7951 - val_accuracy: 0.6667
# Epoch 42/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6899 - accuracy: 0.7118 - val_loss: 1.0545 - val_accuracy: 0.6111
# Epoch 43/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5713 - accuracy: 0.7639 - val_loss: 0.9832 - val_accuracy: 0.5833
# Epoch 44/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5642 - accuracy: 0.7500 - val_loss: 0.7713 - val_accuracy: 0.6944
# Epoch 45/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5658 - accuracy: 0.7569 - val_loss: 0.8888 - val_accuracy: 0.6944
# Epoch 46/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5520 - accuracy: 0.7778 - val_loss: 0.9696 - val_accuracy: 0.5278
# Epoch 47/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5447 - accuracy: 0.8021 - val_loss: 0.7365 - val_accuracy: 0.6944
# Epoch 48/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5761 - accuracy: 0.7812 - val_loss: 0.7287 - val_accuracy: 0.6944
# Epoch 49/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6869 - accuracy: 0.7465 - val_loss: 0.9815 - val_accuracy: 0.6944
# Epoch 50/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6004 - accuracy: 0.7569 - val_loss: 0.8122 - val_accuracy: 0.6111
# Epoch 51/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6264 - accuracy: 0.7604 - val_loss: 1.0149 - val_accuracy: 0.6111
# Epoch 52/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5570 - accuracy: 0.7812 - val_loss: 0.7461 - val_accuracy: 0.6667
# Epoch 53/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5082 - accuracy: 0.7812 - val_loss: 0.7789 - val_accuracy: 0.6667
# Epoch 54/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5614 - accuracy: 0.7535 - val_loss: 0.8691 - val_accuracy: 0.6667
# Epoch 55/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5556 - accuracy: 0.7708 - val_loss: 0.7753 - val_accuracy: 0.6944
# Epoch 56/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4970 - accuracy: 0.7951 - val_loss: 0.8474 - val_accuracy: 0.7222
# Epoch 57/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6199 - accuracy: 0.7674 - val_loss: 0.8710 - val_accuracy: 0.6667
# Epoch 58/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5207 - accuracy: 0.8021 - val_loss: 0.8285 - val_accuracy: 0.6111
# Epoch 59/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5181 - accuracy: 0.8021 - val_loss: 0.7719 - val_accuracy: 0.6944
# Epoch 60/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5176 - accuracy: 0.7778 - val_loss: 0.7496 - val_accuracy: 0.6667
# Epoch 61/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5224 - accuracy: 0.7812 - val_loss: 0.8547 - val_accuracy: 0.5833
# Epoch 62/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4837 - accuracy: 0.7986 - val_loss: 0.6820 - val_accuracy: 0.6944
# Epoch 63/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4704 - accuracy: 0.7986 - val_loss: 0.7981 - val_accuracy: 0.6944
# Epoch 64/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4677 - accuracy: 0.7882 - val_loss: 0.6856 - val_accuracy: 0.6944
# Epoch 65/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4506 - accuracy: 0.8299 - val_loss: 0.8090 - val_accuracy: 0.6944
# Epoch 66/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4909 - accuracy: 0.7986 - val_loss: 0.7095 - val_accuracy: 0.6389
# Epoch 67/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4606 - accuracy: 0.7917 - val_loss: 0.7463 - val_accuracy: 0.6667
# Epoch 68/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4661 - accuracy: 0.8125 - val_loss: 0.8065 - val_accuracy: 0.6389
# Epoch 69/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4754 - accuracy: 0.8368 - val_loss: 0.6635 - val_accuracy: 0.7222
# Epoch 70/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4703 - accuracy: 0.8090 - val_loss: 0.8304 - val_accuracy: 0.6944
# Epoch 71/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4301 - accuracy: 0.8403 - val_loss: 0.6028 - val_accuracy: 0.7222
# Epoch 72/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5019 - accuracy: 0.7986 - val_loss: 0.8682 - val_accuracy: 0.6944
# Epoch 73/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4452 - accuracy: 0.8403 - val_loss: 0.6854 - val_accuracy: 0.7222
# Epoch 74/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4619 - accuracy: 0.8299 - val_loss: 0.7092 - val_accuracy: 0.6944
# Epoch 75/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3985 - accuracy: 0.8403 - val_loss: 0.8152 - val_accuracy: 0.5556
# Epoch 76/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4693 - accuracy: 0.8333 - val_loss: 0.8058 - val_accuracy: 0.6389
# Epoch 77/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4562 - accuracy: 0.8021 - val_loss: 0.7872 - val_accuracy: 0.6667
# Epoch 78/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4221 - accuracy: 0.8160 - val_loss: 0.6104 - val_accuracy: 0.7222
# Epoch 79/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3929 - accuracy: 0.8472 - val_loss: 0.7081 - val_accuracy: 0.7222
# Epoch 80/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3976 - accuracy: 0.8333 - val_loss: 0.6938 - val_accuracy: 0.7222
# Epoch 81/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4222 - accuracy: 0.8438 - val_loss: 0.7246 - val_accuracy: 0.6944
# Epoch 82/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3985 - accuracy: 0.8472 - val_loss: 0.5836 - val_accuracy: 0.7500
# Epoch 83/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4058 - accuracy: 0.8125 - val_loss: 0.6852 - val_accuracy: 0.7222
# Epoch 84/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3356 - accuracy: 0.8750 - val_loss: 0.6352 - val_accuracy: 0.7222
# Epoch 85/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3948 - accuracy: 0.8403 - val_loss: 0.6150 - val_accuracy: 0.6944
# Epoch 86/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3965 - accuracy: 0.8368 - val_loss: 0.7560 - val_accuracy: 0.7222
# Epoch 87/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3927 - accuracy: 0.8507 - val_loss: 0.7461 - val_accuracy: 0.6944
# Epoch 88/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3795 - accuracy: 0.8333 - val_loss: 0.5878 - val_accuracy: 0.8056
# Epoch 89/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4063 - accuracy: 0.8507 - val_loss: 0.7091 - val_accuracy: 0.7500
# Epoch 90/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3747 - accuracy: 0.8438 - val_loss: 0.6795 - val_accuracy: 0.6944
# Epoch 91/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3216 - accuracy: 0.8681 - val_loss: 0.6614 - val_accuracy: 0.7500
# Epoch 92/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3315 - accuracy: 0.8646 - val_loss: 0.6229 - val_accuracy: 0.7500
# Epoch 93/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2890 - accuracy: 0.9097 - val_loss: 0.6453 - val_accuracy: 0.7500
# Epoch 94/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3335 - accuracy: 0.8715 - val_loss: 0.7604 - val_accuracy: 0.6667
# Epoch 95/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3196 - accuracy: 0.8715 - val_loss: 0.6900 - val_accuracy: 0.7222
# Epoch 96/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3135 - accuracy: 0.8958 - val_loss: 0.6606 - val_accuracy: 0.7222
# Epoch 97/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3790 - accuracy: 0.8333 - val_loss: 0.7693 - val_accuracy: 0.6667
# Epoch 98/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3549 - accuracy: 0.8438 - val_loss: 0.8656 - val_accuracy: 0.6667
# Epoch 99/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3281 - accuracy: 0.8681 - val_loss: 0.5262 - val_accuracy: 0.8056
# Epoch 100/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3396 - accuracy: 0.8750 - val_loss: 0.6803 - val_accuracy: 0.6944
# Epoch 101/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2836 - accuracy: 0.8958 - val_loss: 0.6941 - val_accuracy: 0.7222
# Epoch 102/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2888 - accuracy: 0.8993 - val_loss: 0.7368 - val_accuracy: 0.7222
# Epoch 103/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3925 - accuracy: 0.8576 - val_loss: 0.6369 - val_accuracy: 0.7500
# Epoch 104/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2584 - accuracy: 0.8819 - val_loss: 0.7575 - val_accuracy: 0.6944
# Epoch 105/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2971 - accuracy: 0.8681 - val_loss: 0.5043 - val_accuracy: 0.7778
# Epoch 106/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3121 - accuracy: 0.8785 - val_loss: 0.5619 - val_accuracy: 0.7500
# Epoch 107/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3042 - accuracy: 0.8819 - val_loss: 0.5994 - val_accuracy: 0.7500
# Epoch 108/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2811 - accuracy: 0.8819 - val_loss: 0.5562 - val_accuracy: 0.7778
# Epoch 109/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3321 - accuracy: 0.8507 - val_loss: 0.6394 - val_accuracy: 0.6944
# Epoch 110/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3070 - accuracy: 0.8507 - val_loss: 0.5867 - val_accuracy: 0.7778
# Epoch 111/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2591 - accuracy: 0.9028 - val_loss: 0.6927 - val_accuracy: 0.6667
# Epoch 112/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3358 - accuracy: 0.8715 - val_loss: 0.6777 - val_accuracy: 0.8056
# Epoch 113/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3423 - accuracy: 0.8611 - val_loss: 0.5988 - val_accuracy: 0.7778
# Epoch 114/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3391 - accuracy: 0.8611 - val_loss: 0.6389 - val_accuracy: 0.8056
# Epoch 115/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3060 - accuracy: 0.8750 - val_loss: 0.6197 - val_accuracy: 0.8056
# Epoch 116/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2396 - accuracy: 0.8993 - val_loss: 0.5240 - val_accuracy: 0.7778
# Epoch 117/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2579 - accuracy: 0.8993 - val_loss: 0.8113 - val_accuracy: 0.7222
# Epoch 118/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2802 - accuracy: 0.8993 - val_loss: 0.5031 - val_accuracy: 0.8056
# Epoch 119/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2737 - accuracy: 0.8924 - val_loss: 0.5671 - val_accuracy: 0.8056
# Epoch 120/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2422 - accuracy: 0.9062 - val_loss: 0.7795 - val_accuracy: 0.6944
# Epoch 121/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2354 - accuracy: 0.9097 - val_loss: 0.6518 - val_accuracy: 0.7500
# Epoch 122/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2343 - accuracy: 0.9062 - val_loss: 0.6510 - val_accuracy: 0.7778
# Epoch 123/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2915 - accuracy: 0.8715 - val_loss: 0.6524 - val_accuracy: 0.7222
# Epoch 124/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2983 - accuracy: 0.8819 - val_loss: 0.7110 - val_accuracy: 0.7500
# Epoch 125/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2929 - accuracy: 0.8924 - val_loss: 0.7621 - val_accuracy: 0.6944
# Epoch 126/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2428 - accuracy: 0.8993 - val_loss: 0.5455 - val_accuracy: 0.7500
# Epoch 127/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2568 - accuracy: 0.8993 - val_loss: 0.7271 - val_accuracy: 0.6944
# Epoch 128/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2509 - accuracy: 0.9028 - val_loss: 0.5480 - val_accuracy: 0.7778
# Epoch 129/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2189 - accuracy: 0.9028 - val_loss: 0.5946 - val_accuracy: 0.7500
# Epoch 130/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2551 - accuracy: 0.9097 - val_loss: 0.6742 - val_accuracy: 0.7778
# Epoch 131/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2682 - accuracy: 0.8889 - val_loss: 0.5951 - val_accuracy: 0.7778
# Epoch 132/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2319 - accuracy: 0.9375 - val_loss: 0.6676 - val_accuracy: 0.7500
# Epoch 133/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2273 - accuracy: 0.9167 - val_loss: 0.6163 - val_accuracy: 0.8056
# Epoch 134/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2214 - accuracy: 0.9097 - val_loss: 0.5373 - val_accuracy: 0.7222
# Epoch 135/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2175 - accuracy: 0.9097 - val_loss: 0.5280 - val_accuracy: 0.7778
# Epoch 136/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2980 - accuracy: 0.8889 - val_loss: 0.6520 - val_accuracy: 0.7778
# Epoch 137/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2181 - accuracy: 0.9271 - val_loss: 0.6276 - val_accuracy: 0.7500
# Epoch 138/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2441 - accuracy: 0.8993 - val_loss: 0.5450 - val_accuracy: 0.7778
# Epoch 139/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1969 - accuracy: 0.9167 - val_loss: 0.5362 - val_accuracy: 0.8056
# Epoch 140/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2107 - accuracy: 0.9201 - val_loss: 0.5439 - val_accuracy: 0.7778
# Epoch 141/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1766 - accuracy: 0.9340 - val_loss: 0.5932 - val_accuracy: 0.7778
# Epoch 142/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1986 - accuracy: 0.9236 - val_loss: 0.6046 - val_accuracy: 0.7500
# Epoch 143/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2020 - accuracy: 0.9132 - val_loss: 0.6455 - val_accuracy: 0.8056
# Epoch 144/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1816 - accuracy: 0.9410 - val_loss: 0.4712 - val_accuracy: 0.8889
# Epoch 145/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2325 - accuracy: 0.9236 - val_loss: 0.6198 - val_accuracy: 0.6667
# Epoch 146/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2587 - accuracy: 0.8993 - val_loss: 0.5468 - val_accuracy: 0.7778
# Epoch 147/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2117 - accuracy: 0.9236 - val_loss: 0.6616 - val_accuracy: 0.6944
# Epoch 148/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2261 - accuracy: 0.9097 - val_loss: 0.5742 - val_accuracy: 0.7222
# Epoch 149/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1640 - accuracy: 0.9444 - val_loss: 0.5796 - val_accuracy: 0.8056
# Epoch 150/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2213 - accuracy: 0.9097 - val_loss: 0.5453 - val_accuracy: 0.7778
# Epoch 151/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1836 - accuracy: 0.9340 - val_loss: 0.6280 - val_accuracy: 0.7778
# Epoch 152/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2085 - accuracy: 0.9236 - val_loss: 0.5417 - val_accuracy: 0.7778
# Epoch 153/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1679 - accuracy: 0.9375 - val_loss: 0.4942 - val_accuracy: 0.7778
# Epoch 154/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1776 - accuracy: 0.9410 - val_loss: 0.4550 - val_accuracy: 0.8333
# Epoch 155/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2158 - accuracy: 0.9167 - val_loss: 0.7846 - val_accuracy: 0.6944
# Epoch 156/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1889 - accuracy: 0.9201 - val_loss: 0.6154 - val_accuracy: 0.7500
# Epoch 157/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1581 - accuracy: 0.9444 - val_loss: 0.6741 - val_accuracy: 0.7222
# Epoch 158/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1872 - accuracy: 0.9444 - val_loss: 0.9053 - val_accuracy: 0.7500
# Epoch 159/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1793 - accuracy: 0.9375 - val_loss: 0.7286 - val_accuracy: 0.7222
# Epoch 160/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1801 - accuracy: 0.9306 - val_loss: 0.6314 - val_accuracy: 0.7778
# Epoch 161/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2068 - accuracy: 0.9271 - val_loss: 0.6555 - val_accuracy: 0.7500
# Epoch 162/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1432 - accuracy: 0.9688 - val_loss: 0.6738 - val_accuracy: 0.7778
# Epoch 163/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2378 - accuracy: 0.9062 - val_loss: 0.8191 - val_accuracy: 0.7500
# Epoch 164/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1904 - accuracy: 0.9167 - val_loss: 0.5449 - val_accuracy: 0.7778
# Epoch 165/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1569 - accuracy: 0.9479 - val_loss: 0.7444 - val_accuracy: 0.7500
# Epoch 166/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1599 - accuracy: 0.9514 - val_loss: 0.7403 - val_accuracy: 0.7500
# Epoch 167/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1656 - accuracy: 0.9410 - val_loss: 0.6810 - val_accuracy: 0.6944
# Epoch 168/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1709 - accuracy: 0.9201 - val_loss: 0.7724 - val_accuracy: 0.7222
# Epoch 169/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1541 - accuracy: 0.9410 - val_loss: 0.4846 - val_accuracy: 0.8333
# Epoch 170/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1886 - accuracy: 0.9097 - val_loss: 0.6519 - val_accuracy: 0.8056
# Epoch 171/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1777 - accuracy: 0.9271 - val_loss: 0.7360 - val_accuracy: 0.7500
# Epoch 172/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1337 - accuracy: 0.9479 - val_loss: 0.6203 - val_accuracy: 0.7222
# Epoch 173/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1492 - accuracy: 0.9444 - val_loss: 0.5425 - val_accuracy: 0.8056
# Epoch 174/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1843 - accuracy: 0.9306 - val_loss: 0.6409 - val_accuracy: 0.7500
# Epoch 175/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1416 - accuracy: 0.9479 - val_loss: 0.5802 - val_accuracy: 0.7500
# Epoch 176/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1804 - accuracy: 0.9236 - val_loss: 0.7584 - val_accuracy: 0.7222
# Epoch 177/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1661 - accuracy: 0.9479 - val_loss: 0.6757 - val_accuracy: 0.8056
# Epoch 178/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1759 - accuracy: 0.9340 - val_loss: 0.5856 - val_accuracy: 0.7500
# Epoch 179/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1460 - accuracy: 0.9549 - val_loss: 0.6033 - val_accuracy: 0.7778
# Epoch 180/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1124 - accuracy: 0.9618 - val_loss: 0.6582 - val_accuracy: 0.7500
# Epoch 181/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1500 - accuracy: 0.9444 - val_loss: 0.5062 - val_accuracy: 0.7778
# Epoch 182/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1221 - accuracy: 0.9653 - val_loss: 0.5170 - val_accuracy: 0.7778
# Epoch 183/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1364 - accuracy: 0.9549 - val_loss: 0.6430 - val_accuracy: 0.7222
# Epoch 184/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1564 - accuracy: 0.9306 - val_loss: 0.5499 - val_accuracy: 0.8056
# Epoch 185/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1175 - accuracy: 0.9688 - val_loss: 0.7779 - val_accuracy: 0.8333
# Epoch 186/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1792 - accuracy: 0.9375 - val_loss: 0.4519 - val_accuracy: 0.7500
# Epoch 187/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1147 - accuracy: 0.9514 - val_loss: 0.5289 - val_accuracy: 0.7500
# Epoch 188/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1623 - accuracy: 0.9444 - val_loss: 0.5506 - val_accuracy: 0.7778
# Epoch 189/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1266 - accuracy: 0.9444 - val_loss: 0.5219 - val_accuracy: 0.8056
# Epoch 190/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0945 - accuracy: 0.9688 - val_loss: 0.4827 - val_accuracy: 0.8611
# Epoch 191/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1343 - accuracy: 0.9618 - val_loss: 0.6451 - val_accuracy: 0.7778
# Epoch 192/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1187 - accuracy: 0.9618 - val_loss: 0.5287 - val_accuracy: 0.8056
# Epoch 193/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1159 - accuracy: 0.9583 - val_loss: 0.5895 - val_accuracy: 0.7778
# Epoch 194/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1420 - accuracy: 0.9479 - val_loss: 0.5531 - val_accuracy: 0.8056
# Epoch 195/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0906 - accuracy: 0.9757 - val_loss: 0.7339 - val_accuracy: 0.7778
# Epoch 196/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0937 - accuracy: 0.9757 - val_loss: 0.6088 - val_accuracy: 0.7500
# Epoch 197/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1123 - accuracy: 0.9514 - val_loss: 0.5989 - val_accuracy: 0.7500
# Epoch 198/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1271 - accuracy: 0.9479 - val_loss: 0.7036 - val_accuracy: 0.8333
# Epoch 199/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0851 - accuracy: 0.9792 - val_loss: 0.5436 - val_accuracy: 0.7778
# Epoch 200/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1134 - accuracy: 0.9549 - val_loss: 0.5610 - val_accuracy: 0.8056
# Epoch 201/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1464 - accuracy: 0.9618 - val_loss: 0.6495 - val_accuracy: 0.7500
# Epoch 202/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1237 - accuracy: 0.9514 - val_loss: 0.5594 - val_accuracy: 0.7778
# Epoch 203/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1124 - accuracy: 0.9583 - val_loss: 0.4841 - val_accuracy: 0.8333
# Epoch 204/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0927 - accuracy: 0.9688 - val_loss: 0.5733 - val_accuracy: 0.8056
# Epoch 205/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1207 - accuracy: 0.9583 - val_loss: 0.3946 - val_accuracy: 0.8611
# Epoch 206/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0955 - accuracy: 0.9688 - val_loss: 0.6494 - val_accuracy: 0.7778
# Epoch 207/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1333 - accuracy: 0.9444 - val_loss: 0.5272 - val_accuracy: 0.8333
# Epoch 208/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0934 - accuracy: 0.9688 - val_loss: 0.5381 - val_accuracy: 0.7778
# Epoch 209/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1303 - accuracy: 0.9375 - val_loss: 0.5909 - val_accuracy: 0.8611
# Epoch 210/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1174 - accuracy: 0.9514 - val_loss: 0.7378 - val_accuracy: 0.7500
# Epoch 211/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0920 - accuracy: 0.9722 - val_loss: 0.6038 - val_accuracy: 0.8611
# Epoch 212/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0915 - accuracy: 0.9653 - val_loss: 0.5842 - val_accuracy: 0.8889
# Epoch 213/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0827 - accuracy: 0.9792 - val_loss: 0.5931 - val_accuracy: 0.8889
# Epoch 214/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0679 - accuracy: 0.9861 - val_loss: 0.6084 - val_accuracy: 0.8333
# Epoch 215/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0983 - accuracy: 0.9757 - val_loss: 0.3874 - val_accuracy: 0.8333
# Epoch 216/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1020 - accuracy: 0.9583 - val_loss: 0.6791 - val_accuracy: 0.8611
# Epoch 217/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0938 - accuracy: 0.9757 - val_loss: 0.5935 - val_accuracy: 0.8611
# Epoch 218/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1414 - accuracy: 0.9549 - val_loss: 0.6105 - val_accuracy: 0.8056
# Epoch 219/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0919 - accuracy: 0.9688 - val_loss: 0.6591 - val_accuracy: 0.7500
# Epoch 220/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0745 - accuracy: 0.9826 - val_loss: 0.7654 - val_accuracy: 0.8056
# Epoch 221/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0936 - accuracy: 0.9618 - val_loss: 0.4278 - val_accuracy: 0.8333
# Epoch 222/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0748 - accuracy: 0.9826 - val_loss: 0.9583 - val_accuracy: 0.7222
# Epoch 223/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1143 - accuracy: 0.9549 - val_loss: 0.5650 - val_accuracy: 0.7778
# Epoch 224/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0889 - accuracy: 0.9826 - val_loss: 0.4839 - val_accuracy: 0.7778
# Epoch 225/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0776 - accuracy: 0.9826 - val_loss: 0.6888 - val_accuracy: 0.8056
# Epoch 226/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1003 - accuracy: 0.9583 - val_loss: 0.4865 - val_accuracy: 0.8056
# Epoch 227/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0981 - accuracy: 0.9618 - val_loss: 0.6663 - val_accuracy: 0.7778
# Epoch 228/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1109 - accuracy: 0.9618 - val_loss: 0.4175 - val_accuracy: 0.8611
# Epoch 229/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0795 - accuracy: 0.9757 - val_loss: 0.7438 - val_accuracy: 0.7778
# Epoch 230/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0846 - accuracy: 0.9688 - val_loss: 0.5101 - val_accuracy: 0.7778
# Epoch 231/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0856 - accuracy: 0.9757 - val_loss: 0.6265 - val_accuracy: 0.8333
# Epoch 232/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0865 - accuracy: 0.9618 - val_loss: 0.7102 - val_accuracy: 0.7778
# Epoch 233/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0730 - accuracy: 0.9861 - val_loss: 0.5597 - val_accuracy: 0.7500
# Epoch 234/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1101 - accuracy: 0.9549 - val_loss: 0.4790 - val_accuracy: 0.7778
# Epoch 235/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0852 - accuracy: 0.9757 - val_loss: 0.8113 - val_accuracy: 0.7500
# Epoch 236/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0864 - accuracy: 0.9792 - val_loss: 0.7489 - val_accuracy: 0.8056
# Epoch 237/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0708 - accuracy: 0.9792 - val_loss: 0.6621 - val_accuracy: 0.7778
# Epoch 238/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0631 - accuracy: 0.9792 - val_loss: 0.8104 - val_accuracy: 0.7778
# Epoch 239/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0911 - accuracy: 0.9757 - val_loss: 0.5914 - val_accuracy: 0.8611
# Epoch 240/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0710 - accuracy: 0.9722 - val_loss: 0.6759 - val_accuracy: 0.7500
# Epoch 241/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0720 - accuracy: 0.9861 - val_loss: 0.5390 - val_accuracy: 0.7500
# Epoch 242/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0735 - accuracy: 0.9826 - val_loss: 0.7878 - val_accuracy: 0.8056
# Epoch 243/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0824 - accuracy: 0.9757 - val_loss: 0.5961 - val_accuracy: 0.8056
# Epoch 244/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0464 - accuracy: 0.9965 - val_loss: 0.5853 - val_accuracy: 0.7778
# Epoch 245/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0778 - accuracy: 0.9583 - val_loss: 0.6511 - val_accuracy: 0.7778
# Epoch 246/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0692 - accuracy: 0.9757 - val_loss: 0.6875 - val_accuracy: 0.7500
# Epoch 247/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0523 - accuracy: 0.9826 - val_loss: 0.6161 - val_accuracy: 0.7500
# Epoch 248/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0634 - accuracy: 0.9861 - val_loss: 0.6352 - val_accuracy: 0.7778
# Epoch 249/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0574 - accuracy: 0.9861 - val_loss: 0.5776 - val_accuracy: 0.8056
# Epoch 250/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0698 - accuracy: 0.9826 - val_loss: 0.5243 - val_accuracy: 0.8056
# Epoch 251/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0674 - accuracy: 0.9826 - val_loss: 0.6827 - val_accuracy: 0.7222
# Epoch 252/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0712 - accuracy: 0.9722 - val_loss: 0.4714 - val_accuracy: 0.7778
# Epoch 253/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0658 - accuracy: 0.9792 - val_loss: 0.6070 - val_accuracy: 0.8611
# Epoch 254/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9826 - val_loss: 0.5359 - val_accuracy: 0.8056
# Epoch 255/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0784 - accuracy: 0.9722 - val_loss: 0.7821 - val_accuracy: 0.7500
# Epoch 256/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0802 - accuracy: 0.9688 - val_loss: 0.6040 - val_accuracy: 0.8056
# Epoch 257/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0541 - accuracy: 0.9792 - val_loss: 0.5896 - val_accuracy: 0.7500
# Epoch 258/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0453 - accuracy: 0.9896 - val_loss: 0.6857 - val_accuracy: 0.7778
# Epoch 259/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0616 - accuracy: 0.9722 - val_loss: 0.5005 - val_accuracy: 0.7778
# Epoch 260/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0384 - accuracy: 1.0000 - val_loss: 0.4953 - val_accuracy: 0.8333
# Epoch 261/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0419 - accuracy: 0.9896 - val_loss: 0.6652 - val_accuracy: 0.7500
# Epoch 262/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0351 - accuracy: 0.9931 - val_loss: 0.5130 - val_accuracy: 0.8333
# Epoch 263/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0456 - accuracy: 0.9931 - val_loss: 0.7294 - val_accuracy: 0.8056
# Epoch 264/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0538 - accuracy: 0.9826 - val_loss: 0.5879 - val_accuracy: 0.8056
# Epoch 265/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.6788 - val_accuracy: 0.8333
# Epoch 266/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0442 - accuracy: 0.9896 - val_loss: 0.6835 - val_accuracy: 0.7778
# Epoch 267/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0607 - accuracy: 0.9792 - val_loss: 0.6237 - val_accuracy: 0.8333
# Epoch 268/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0428 - accuracy: 0.9931 - val_loss: 0.5264 - val_accuracy: 0.7778
# Epoch 269/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0394 - accuracy: 0.9931 - val_loss: 0.7019 - val_accuracy: 0.7500
# Epoch 270/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0659 - accuracy: 0.9757 - val_loss: 0.8461 - val_accuracy: 0.7500
# Epoch 271/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0736 - accuracy: 0.9792 - val_loss: 0.6457 - val_accuracy: 0.7778
# Epoch 272/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0635 - accuracy: 0.9792 - val_loss: 0.6566 - val_accuracy: 0.7500
# Epoch 273/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0510 - accuracy: 0.9896 - val_loss: 0.6071 - val_accuracy: 0.7778
# Epoch 274/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0353 - accuracy: 0.9931 - val_loss: 0.5063 - val_accuracy: 0.8611
# Epoch 275/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0393 - accuracy: 0.9965 - val_loss: 0.7779 - val_accuracy: 0.7778
# Epoch 276/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0462 - accuracy: 0.9896 - val_loss: 0.5594 - val_accuracy: 0.8056
# Epoch 277/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0585 - accuracy: 0.9826 - val_loss: 0.6465 - val_accuracy: 0.7778
# Epoch 278/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0384 - accuracy: 0.9965 - val_loss: 0.7644 - val_accuracy: 0.7778
# Epoch 279/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0590 - accuracy: 0.9826 - val_loss: 0.6200 - val_accuracy: 0.7500
# Epoch 280/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0335 - accuracy: 0.9965 - val_loss: 0.5761 - val_accuracy: 0.7778

# %%
plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.plot(cnnhistory.history['accuracy'])
plt.plot(cnnhistory.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %%
loss, acc =model.evaluate(x_traincnn,y_train )
print("Restored model train, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0564 - accuracy: 0.9965
# Restored model train, accuracy: 99.65%

# %%
loss, acc = model.evaluate(x_test, y_test)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4975 - accuracy: 0.8333
# Restored model, accuracy: 83.33%

# %%
#predictions = model.predict_classes(x_testcnn)
predictions = model.predict(x_test)
predictions
# Out:
# array([[9.74916637e-01, 1.24632847e-04, 2.47446783e-02, 3.29051727e-05,
#         1.81222509e-04],
#        [2.36903480e-03, 2.57389643e-03, 4.73638147e-06, 9.94571865e-01,
#         4.80410614e-04],
#        [2.49752048e-07, 3.56832629e-07, 9.94895399e-01, 4.70279410e-05,
#         5.05694700e-03],
#        [8.73361349e-01, 1.32360728e-04, 1.18726514e-01, 1.74836568e-05,
#         7.76229752e-03],
#        [9.19468462e-01, 1.46912062e-03, 6.53215349e-02, 1.24307070e-02,
#         1.31021312e-03],
#        [3.59503756e-05, 3.74499219e-03, 1.09130669e-05, 9.05854821e-01,
#         9.03533027e-02],
#        [1.11877325e-03, 1.75690351e-04, 9.37313795e-01, 5.50213084e-03,
#         5.58896326e-02],
#        [5.97610235e-01, 2.02646654e-04, 4.01718289e-01, 4.73290947e-06,
#         4.64015058e-04],
#        [9.99948025e-01, 2.89382865e-06, 4.38716961e-05, 5.21183301e-06,
#         4.52367317e-08],
#        [7.22350955e-01, 2.46254531e-05, 2.77429044e-01, 6.91858190e-07,
#         1.94695196e-04],
#        [9.74222839e-01, 2.05057358e-06, 2.55302973e-02, 4.99497173e-06,
#         2.39826710e-04],
#        [9.99961615e-01, 1.49341633e-06, 1.99425867e-05, 1.28360307e-05,
#         4.03066360e-06],
#        [2.91555393e-02, 2.56644585e-03, 6.89655304e-01, 6.29024289e-05,
#         2.78559804e-01],
#        [3.10713222e-04, 7.35551536e-01, 2.25833118e-01, 1.54472413e-02,
#         2.28573196e-02],
#        [9.61194098e-01, 6.31518706e-05, 3.87000814e-02, 1.92332864e-05,
#         2.34472682e-05],
#        [2.93709927e-05, 1.11962976e-02, 2.38713455e-05, 9.88549531e-01,
#         2.00917115e-04],
#        [3.25613841e-02, 1.33271933e-01, 1.07245995e-02, 8.22992444e-01,
#         4.49595507e-04],
#        [9.95346606e-01, 6.24086024e-05, 4.58126282e-03, 2.27952683e-06,
#         7.49002857e-06],
#        [9.99241948e-01, 6.20817718e-06, 9.23355547e-05, 6.56149583e-04,
#         3.28400165e-06],
#        [9.60229576e-01, 8.93474615e-04, 4.97831171e-03, 1.13540515e-03,
#         3.27631831e-02],
#        [9.63730156e-01, 2.26582097e-06, 4.10979585e-04, 3.55993025e-02,
#         2.57267588e-04],
#        [4.77547474e-06, 9.79685009e-01, 2.02573929e-07, 3.31001938e-03,
#         1.69999972e-02],
#        [1.21941703e-05, 6.14513992e-04, 1.22572814e-07, 2.23045191e-03,
#         9.97142732e-01],
#        [2.64609838e-07, 8.31129774e-03, 2.01516614e-05, 9.90651846e-01,
#         1.01647747e-03],
#        [9.72489953e-01, 1.51760026e-03, 1.26142381e-02, 2.36287643e-03,
#         1.10152941e-02],
#        [2.04291995e-04, 3.67000520e-01, 6.24592155e-02, 5.62814713e-01,
#         7.52132991e-03],
#        [8.85045111e-01, 2.76104473e-02, 7.11304322e-02, 4.56347270e-03,
#         1.16504291e-02],
#        [9.98387694e-01, 5.86074657e-06, 1.36575440e-03, 1.74041692e-04,
#         6.66079359e-05],
#        [1.60034069e-05, 8.68713390e-03, 2.90563491e-07, 9.91263032e-01,
#         3.35918448e-05],
#        [2.26212689e-03, 3.74386132e-01, 2.66689644e-03, 9.21284407e-03,
#         6.11471951e-01],
#        [9.96506512e-01, 2.26163152e-07, 3.39830876e-03, 6.72223105e-05,
#         2.76606388e-05],
#        [9.55560863e-01, 5.50019694e-03, 3.46905328e-02, 8.79325555e-04,
#         3.36908456e-03],
#        [6.49776848e-05, 6.46289513e-02, 4.54082829e-06, 9.18977022e-01,
#         1.63245350e-02],
#        [9.99949574e-01, 2.16721537e-06, 1.28389011e-05, 3.52135830e-05,
#         1.82326232e-07],
#        [9.57420230e-01, 1.19574623e-04, 3.95965427e-02, 1.28769805e-03,
#         1.57581607e-03],
#        [7.56897975e-07, 9.19299197e-08, 9.59212661e-01, 4.77521680e-05,
#         4.07387614e-02]], dtype=float32)

# %%
df_audio_test = pd.DataFrame(predictions,columns=["OA_"+str(i) for i in range(5)])

# %%
y_test
# Out:
# array([0, 3, 2, 0, 0, 1, 2, 0, 0, 0, 2, 0, 4, 1, 0, 3, 3, 0, 0, 0, 0, 1,
#        4, 3, 0, 1, 0, 0, 3, 1, 0, 0, 3, 0, 2, 2])

# %%
new_Ytest = y_test.astype(int)
new_Ytest
# Out:
# array([0, 3, 2, 0, 0, 1, 2, 0, 0, 0, 2, 0, 4, 1, 0, 3, 3, 0, 0, 0, 0, 1,
#        4, 3, 0, 1, 0, 0, 3, 1, 0, 0, 3, 0, 2, 2])

# %%
preds1=predictions.argmax(axis=1)
preds1
# Out:
# array([0, 3, 2, 0, 0, 3, 2, 0, 0, 0, 0, 0, 2, 1, 0, 3, 3, 0, 0, 0, 0, 1,
#        4, 3, 0, 3, 0, 0, 3, 4, 0, 0, 3, 0, 0, 2])

# %%
abc = preds1.astype(int).flatten()
from sklearn.metrics import confusion_matrix
c = confusion_matrix(new_Ytest, abc) 
c
# Out:
# array([[18,  0,  0,  0,  0],
#        [ 0,  2,  0,  2,  1],
#        [ 2,  0,  3,  0,  0],
#        [ 0,  0,  0,  6,  0],
#        [ 0,  0,  1,  0,  1]])

# %%
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
import seaborn as sn

print(classification_report(y_test,abc))

acc = float(accuracy_score(y_test,abc))*100
print("----accuracy score %s ----" % acc)

cm = confusion_matrix(y_test,abc)
#df_cm = pd.DataFrame(cm)
class_names = ['neutral', 'happy','sad','angry', 'fearful' ]
df_cm = pd.DataFrame(cm, index=class_names, columns=class_names,)
sn.heatmap(df_cm, annot=True, fmt='')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95        18
#            1       1.00      0.40      0.57         5
#            2       0.75      0.60      0.67         5
#            3       0.75      1.00      0.86         6
#            4       0.50      0.50      0.50         2
#
#     accuracy                           0.83        36
#    macro avg       0.78      0.70      0.71        36
# weighted avg       0.85      0.83      0.82        36
#
# ----accuracy score 83.33333333333334 ----

# %%
model.save('/content/drive/My Drive/fusion/savee/audio/model/expert1/best_CNN_model')
print("MODEL SAVED")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/fusion/savee/audio/model/expert1/best_CNN_model/assets
# MODEL SAVED

# %%
model_file_name = f'/content/drive/My Drive/fusion/savee/audio/model/expert1/best_CNN_model___Loss_{loss}___Accuracy_{acc}.h5'

# Save the Model.
model.save(model_file_name)

# %%
# serialize model to JSON
model_json = model.to_json()
with open("/content/drive/My Drive/fusion/savee/audio/model/expert1/best_CNN_model.json", "w") as json_file:
    json_file.write(model_json)

# %%
prediction_train = model.predict(x_traincnn)
prediction_train
# Out:
# array([[4.09712411e-05, 1.44630596e-02, 1.82021467e-05, 9.85317290e-01,
#         1.60479263e-04],
#        [1.83125121e-05, 8.83401752e-01, 1.00672347e-04, 1.15040034e-01,
#         1.43923180e-03],
#        [9.99976873e-01, 6.15728595e-06, 1.64550584e-05, 4.35525067e-07,
#         2.21058709e-08],
#        ...,
#        [2.38302089e-02, 8.73243332e-01, 2.56893714e-03, 4.77229021e-02,
#         5.26345558e-02],
#        [3.85566760e-04, 8.92205921e-04, 6.41412441e-07, 1.07549934e-03,
#         9.97646034e-01],
#        [1.03373686e-03, 1.33018097e-04, 5.89505871e-05, 9.85883772e-01,
#         1.28904665e-02]], dtype=float32)

# %%
df_audio_train = pd.DataFrame(prediction_train,columns=["OA_"+str(i) for i in range(5)])

# %%
prediction_valid = model.predict(x_valid)
prediction_valid
# Out:
# array([[2.37955317e-01, 6.70127411e-05, 7.48821378e-01, 3.64873302e-03,
#         9.50753037e-03],
#        [2.11375263e-05, 1.40626263e-03, 8.38809371e-01, 5.00078080e-03,
#         1.54762417e-01],
#        [9.93745029e-01, 8.98149665e-05, 8.25177849e-05, 6.05335319e-03,
#         2.94012480e-05],
#        [9.98785675e-01, 1.12499697e-06, 9.18692618e-04, 1.89436505e-05,
#         2.75589497e-04],
#        [1.84532299e-04, 3.69666368e-02, 2.38475506e-04, 9.62376654e-01,
#         2.33661645e-04],
#        [1.04497458e-05, 6.03036761e-01, 1.94304357e-05, 1.58186276e-02,
#         3.81114781e-01],
#        [2.27448127e-05, 6.69077411e-02, 1.23561724e-04, 8.01197946e-01,
#         1.31747946e-01],
#        [2.05825131e-06, 7.56949748e-06, 7.62274683e-01, 5.89164905e-04,
#         2.37126499e-01],
#        [5.47416694e-02, 4.27542662e-04, 5.46344336e-06, 9.44812238e-01,
#         1.30241951e-05],
#        [9.72120523e-01, 2.46707586e-05, 3.62671417e-04, 2.74506547e-02,
#         4.14851238e-05],
#        [2.37803280e-01, 2.99852574e-04, 7.54879355e-01, 3.52155836e-03,
#         3.49600660e-03],
#        [8.94695288e-04, 8.37280357e-04, 7.48591381e-04, 9.97477233e-01,
#         4.20429787e-05],
#        [6.58318750e-04, 1.26392553e-02, 1.47471175e-01, 2.88593146e-04,
#         8.38942707e-01],
#        [3.55963408e-07, 2.27948069e-03, 9.76812001e-03, 1.52124441e-03,
#         9.86430883e-01],
#        [5.41012585e-01, 1.26240423e-06, 4.58985031e-01, 1.55283555e-08,
#         1.12539033e-06],
#        [1.00868701e-05, 9.47861791e-01, 6.06151472e-04, 1.28712010e-04,
#         5.13932928e-02],
#        [9.99978185e-01, 4.00181790e-07, 1.30849967e-05, 6.81622487e-06,
#         1.59365186e-06],
#        [2.36545294e-03, 8.94732654e-01, 7.83170108e-05, 5.02597401e-03,
#         9.77976248e-02],
#        [4.22424525e-01, 5.26933691e-05, 5.77518284e-01, 5.22856453e-07,
#         3.94170456e-06],
#        [6.50253892e-01, 7.71668347e-05, 3.42654318e-01, 1.13130605e-04,
#         6.90157432e-03],
#        [6.37438439e-04, 8.97626340e-01, 3.02021681e-06, 1.79742817e-02,
#         8.37588683e-02],
#        [2.53477822e-07, 7.08438392e-08, 9.79786754e-01, 5.46092451e-06,
#         2.02074181e-02],
#        [2.08151887e-05, 4.19571111e-03, 4.64442564e-06, 9.95736122e-01,
#         4.26862935e-05],
#        [7.68815503e-02, 8.65165740e-02, 1.62213705e-02, 4.12905127e-01,
#         4.07475382e-01],
#        [4.99584305e-04, 7.73581088e-01, 3.19311308e-04, 6.12567784e-03,
#         2.19474375e-01],
#        [9.99908805e-01, 2.31971467e-06, 8.74267243e-06, 8.00597045e-05,
#         7.39241202e-08],
#        [6.97101533e-01, 4.05320607e-05, 2.71556795e-01, 1.50159613e-04,
#         3.11509725e-02],
#        [3.54077711e-05, 3.21071178e-01, 4.89694139e-05, 6.77935839e-01,
#         9.08628164e-04],
#        [1.11511676e-04, 7.87808094e-03, 5.77009559e-05, 7.72537314e-05,
#         9.91875470e-01],
#        [9.99479353e-01, 1.70423959e-06, 4.48242994e-04, 6.89199733e-05,
#         1.73321985e-06],
#        [1.52569264e-05, 2.69165845e-03, 9.82693450e-07, 1.38163287e-03,
#         9.95910525e-01],
#        [7.87913978e-01, 3.43397202e-04, 2.08093613e-01, 4.32620523e-04,
#         3.21639981e-03],
#        [3.46606504e-03, 6.90832913e-01, 2.54035025e-04, 2.98399121e-01,
#         7.04782829e-03],
#        [6.73489978e-07, 4.29461747e-01, 9.03618420e-05, 5.54448724e-01,
#         1.59984678e-02],
#        [9.77864087e-01, 1.01778778e-06, 2.17810813e-02, 1.01352787e-04,
#         2.52548110e-04],
#        [4.85034036e-07, 9.96106565e-01, 2.28202566e-07, 3.04463273e-03,
#         8.48045689e-04]], dtype=float32)

# %%
df_audio_valid = pd.DataFrame(prediction_valid,columns=["OA_"+str(i) for i in range(5)])

# %%
import joblib

save_dir = '/content/drive/My Drive/fusion/savee/audio/data_set/expert1'

savedvX = joblib.dump(df_audio_train, os.path.join(save_dir, 'train/predict_train'))
savedvX = joblib.dump(df_audio_test, os.path.join(save_dir, 'test/predict_test'))
savedvX = joblib.dump(df_audio_valid, os.path.join(save_dir, 'valid/predict_valid'))
