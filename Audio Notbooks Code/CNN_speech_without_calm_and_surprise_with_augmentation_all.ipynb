# %%
pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.7/dist-packages (1.5.1)

# %%
pip install torchsummaryX
# Out:
# Requirement already satisfied: torchsummaryX in /usr/local/lib/python3.7/dist-packages (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchsummaryX) (1.21.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torchsummaryX) (1.3.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchsummaryX) (1.10.0+cu111)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torchsummaryX) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torchsummaryX) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torchsummaryX) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchsummaryX) (3.10.0.2)

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.8.0)

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, glob
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import warnings; warnings.filterwarnings('ignore') #matplot lib complains about librosa

# %%
# needed to import dataset from google drive into colab 
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# RAVDESS native sample rate is 48k
sample_rate = 48000

# Mel Spectrograms are not directly used as a feature in this model
# Mel Spectrograms are used in calculating MFCCs, which are a higher-level representation of pitch transition
# MFCCs work better - left the mel spectrogram function here in case anyone wants to experiment
def feature_melspectrogram(
    waveform, 
    sample_rate,
    fft = 1024,
    winlen = 512,
    window='hamming',
    hop=256,
    mels=128,
    ):
    
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram = librosa.feature.melspectrogram(
        y=waveform, 
        sr=sample_rate, 
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2)
    
    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms 
    melspectrogram = librosa.power_to_db(melspectrogram, ref=np.max)
    
    return melspectrogram

def feature_mfcc(
    waveform, 
    sample_rate,
    n_mfcc = 40,
    fft = 1024,
    winlen = 512,
    window='hamming',
    #hop=256, # increases # of time steps; was not helpful
    mels=128
    ):

    # Compute the MFCCs for all STFT frames 
    # 40 mel filterbanks (n_mfcc) = 40 coefficients
    mfc_coefficients=librosa.feature.mfcc(
        y=waveform, 
        sr=sample_rate, 
        n_mfcc=n_mfcc,
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        #hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2
        ) 

    return mfc_coefficients

def get_features(waveforms, features, samplerate):

    # initialize counter to track progress
    file_count = 0

    # process each waveform individually to get its MFCCs
    for waveform in waveforms:
        mfccs = feature_mfcc(waveform, sample_rate)
        features.append(mfccs)
        file_count += 1
        # print progress 
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')
    
    # return all features from list of waveforms
    return features

def get_waveforms(file):
    
    # load an individual sample audio file
    # read the full 3 seconds of the file, cut off the first 0.5s of silence; native sample rate = 48k
    # don't need to store the sample rate that librosa.load returns
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)
    
    # make sure waveform vectors are homogenous by defining explicitly
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform
    
    # return a single file's waveform                                      
    return waveform_homo
    
# RAVDESS dataset emotions
# shift emotions left to be 0 indexed for PyTorch
emotions_dict ={
 ''''0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
    '7':'disgust'  '''

   
    '0':'neutral',
    '1':'happy',
    '2':'sad',
    '3':'angry',
    '4':'fearful',
    '5':'disgust'

}

# Additional attributes from RAVDESS to play with
emotion_attributes = {
    '01': 'normal',
    '02': 'strong'
}

# %%
# path to data for glob
data_path = '/content/drive/My Drive/data_set/RAVDESS_speech'

##'RAVDESS dataset/Actor_*/*.wav'
dir_list = os.listdir(data_path)
dir_list.sort()
dir_list
# Out:
# ['Actor_01',
#  'Actor_02',
#  'Actor_03',
#  'Actor_04',
#  'Actor_05',
#  'Actor_06',
#  'Actor_07',
#  'Actor_08',
#  'Actor_09',
#  'Actor_10',
#  'Actor_11',
#  'Actor_12',
#  'Actor_13',
#  'Actor_14',
#  'Actor_15',
#  'Actor_16',
#  'Actor_17',
#  'Actor_18',
#  'Actor_19',
#  'Actor_20',
#  'Actor_21',
#  'Actor_22',
#  'Actor_23',
#  'Actor_24']

# %%
def load_data():
  # features and labels
  emotions = []
  # raw waveforms to augment later
  waveforms = []
  # extra labels
  intensities, genders = [],[]
  # progress counter
  file_count = 0
  
  for i in dir_list:
    #print(i)
    file_name = os.listdir(data_path + '/' +i+'/')
    for file in file_name:
     # print(file)
      #print(file_name)
      file=data_path + '/' +i+'/'+file
      nm = file.split('.')[0].split('-')
      # get emotion label from the sample's file
      emotion = int(nm[2])
      #  move surprise to 0 for cleaner behaviour with PyTorch/0-indexing
      if emotion == 1:  emotion = 0
      if emotion == 2:  continue
      if emotion == 3:  emotion = 1
      if emotion == 4:  emotion = 2
      if emotion == 5:  emotion = 3
      if emotion == 6:  emotion = 4
      if emotion == 7:  emotion = 5
      if emotion == 8:  continue   # surprise is now at 0 index; other emotion indeces unchanged
      # can convert emotion label to emotion string if desired, but
      # training on number is better; better convert to emotion string after predictions are ready
      # emotion = emotions_dict[str(emotion)]
            
      # get other labels we might want
      #intensity = emotion_attributes[int(nm[3])]
      if nm[3] == '01':
            intensity = 0
      else:
            intensity = 1
            
      # even actors are female, odd are male
      if (int((file.split("-")[6]).split(".")[0]))%2==0: 
          gender = 'female' 
      else: 
          gender = 'male'
                
      # get waveform from the sample
      waveform = get_waveforms(file)
            
      # store waveforms and labels
      waveforms.append(waveform)
      emotions.append(emotion)
      intensities.append(intensity) # store intensity in case we wish to predict
      genders.append(gender) # store gender in case we wish to predict 
            
      file_count += 1
    
      # keep track of data loader's progress
      print('\r'+f' Processed {file_count}/{1440} audio samples',end='')
    

  return waveforms, emotions, intensities, genders

# %%
# load data 
# init explicitly to prevent data leakage from past sessions, since load_data() appends
waveforms, emotions, intensities, genders = [],[],[],[]
waveforms, emotions, intensities, genders = load_data()
# Out:
#  Processed 1056/1440 audio samples

# %%
print(f'Waveforms set: {len(waveforms)} samples')
# we have 1440 waveforms but we need to know their length too; should be 3 sec * 48k = 144k
print(f'Waveform signal length: {len(waveforms[0])}')
print(f'Emotions set: {len(emotions)} sample labels')
# Out:
# Waveforms set: 1056 samples
# Waveform signal length: 144000
# Emotions set: 1056 sample labels

# %%
# create storage for train, validation, test sets and their indices
train_set,valid_set,test_set = [],[],[]
X_train,X_valid,X_test = [],[],[]
y_train,y_valid,y_test = [],[],[]

# convert waveforms to array for processing
waveforms = np.array(waveforms)

# process each emotion separately to make sure we builf balanced train/valid/test sets 
for emotion_num in range(len(emotions_dict)):
        
    # find all indices of a single unique emotion
    emotion_indices = [index for index, emotion in enumerate(emotions) if emotion==emotion_num]

    # seed for reproducibility 
    np.random.seed(69)
    # shuffle indicies 
    emotion_indices = np.random.permutation(emotion_indices)

    # store dim (length) of the emotion list to make indices
    dim = len(emotion_indices)

    # store indices of training, validation and test sets in 80/10/10 proportion
    # train set is first 80%
    train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
    valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
    test_indices = emotion_indices[int(0.9*dim):]

    # create train waveforms/labels sets
    X_train.append(waveforms[train_indices,:])
    y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
    X_valid.append(waveforms[valid_indices,:])
    y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
    X_test.append(waveforms[test_indices,:])
    y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets 
    train_set.append(train_indices)
    valid_set.append(valid_indices)
    test_set.append(test_indices)

# concatenate, in order, all waveforms back into one array 
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array 
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

# make sure train, validation, test sets have no overlap/are unique
# get all unique indices across all sets and how many times each index appears (count)
uniques, count = np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)

# if each index appears just once, and we have 1440 such unique indices, then all sets are unique
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# Training waveforms:(841, 144000), y_train:(841,)
# Validation waveforms:(105, 144000), y_valid:(105,)
# Test waveforms:(110, 144000), y_test:(110,)
#
# Sets are unique: 1056 samples out of 1056 are unique

# %%
# initialize feature arrays
# We extract MFCC features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features 
features_train = get_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = get_features(X_valid, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features 
features_test = get_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'Features (MFC coefficient matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
#  Processed 841/841 waveforms
#
# Validation waveforms:
#  Processed 105/105 waveforms
#
# Test waveforms:
#  Processed 110/110 waveforms
#
# Features set: 1056 total, 841 train, 105 validation, 110 test samples
# Features (MFC coefficient matrix) shape: 40 mel frequency coefficients x 282 time steps

# %%
def awgn_augmentation(waveform, multiples=2, bits=16, snr_min=15, snr_max=30): 
    
    # get length of waveform (should be 3*48k = 144k)
    wave_len = len(waveform)
    
    # Generate normally distributed (Gaussian) noises
    # one for each waveform and multiple (i.e. wave_len*multiples noises)
    noise = np.random.normal(size=(multiples, wave_len))
    
    # Normalize waveform and noise
    norm_constant = 2.0**(bits-1)
    norm_wave = waveform / norm_constant
    norm_noise = noise / norm_constant
    
    # Compute power of waveform and power of noise
    signal_power = np.sum(norm_wave ** 2) / wave_len
    noise_power = np.sum(norm_noise ** 2, axis=1) / wave_len
    
    # Choose random SNR in decibels in range [15,30]
    snr = np.random.randint(snr_min, snr_max)
    
    # Apply whitening transformation: make the Gaussian noise into Gaussian white noise
    # Compute the covariance matrix used to whiten each noise 
    # actual SNR = signal/noise (power)
    # actual noise power = 10**(-snr/10)
    covariance = np.sqrt((signal_power / noise_power) * 10 ** (- snr / 10))
    # Get covariance matrix with dim: (144000, 2) so we can transform 2 noises: dim (2, 144000)
    covariance = np.ones((wave_len, multiples)) * covariance

    # Since covariance and noise are arrays, * is the haddamard product 
    # Take Haddamard product of covariance and noise to generate white noise
    multiple_augmented_waveforms = waveform + covariance.T * noise
    
    return multiple_augmented_waveforms
def augment_waveforms(waveforms, features, emotions, multiples):
    # keep track of how many waveforms we've processed so we can add correct emotion label in the same order
    emotion_count = 0
    # keep track of how many augmented samples we've added
    added_count = 0
    # convert emotion array to list for more efficient appending
    emotions = emotions.tolist()

    for waveform in waveforms:

        # Generate 2 augmented multiples of the dataset, i.e. 1440 native + 1440*2 noisy = 4320 samples total
        augmented_waveforms = awgn_augmentation(waveform, multiples=multiples)

        # compute spectrogram for each of 2 augmented waveforms
        for augmented_waveform in augmented_waveforms:

            # Compute MFCCs over augmented waveforms
            augmented_mfcc = feature_mfcc(augmented_waveform, sample_rate=sample_rate)

            # append the augmented spectrogram to the rest of the native data
            features.append(augmented_mfcc)
            emotions.append(emotions[emotion_count])

            # keep track of new augmented samples
            added_count += 1

            # check progress
            print('\r'+f'Processed {emotion_count + 1}/{len(waveforms)} waveforms for {added_count}/{len(waveforms)*multiples} new augmented samples',end='')

        # keep track of the emotion labels to append in order
        emotion_count += 1
        
        # store augmented waveforms to check their shape
        augmented_waveforms_temp.append(augmented_waveforms)
    
    return features, emotions

# %%
# store augmented waveforms to verify their shape and random-ness
augmented_waveforms_temp = []

# specify multiples of our dataset to add as augmented data
multiples = 2

print('Train waveforms:') # augment waveforms of training set
features_train , y_train = augment_waveforms(X_train, features_train, y_train, multiples)

print('\n\nValidation waveforms:') # augment waveforms of validation set
features_valid, y_valid = augment_waveforms(X_valid, features_valid, y_valid, multiples)

print('\n\nTest waveforms:') # augment waveforms of test set 
features_test, y_test = augment_waveforms(X_test, features_test, y_test, multiples)

# Check new shape of extracted features and data:
print(f'\n\nNative + Augmented Features set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'{len(y_train)} training sample labels, {len(y_valid)} validation sample labels, {len(y_test)} test sample labels')
print(f'Features (MFCC matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
# Processed 841/841 waveforms for 1682/1682 new augmented samples
#
# Validation waveforms:
# Processed 105/105 waveforms for 210/210 new augmented samples
#
# Test waveforms:
# Processed 110/110 waveforms for 220/220 new augmented samples
#
# Native + Augmented Features set: 3168 total, 2523 train, 315 validation, 330 test samples
# 2523 training sample labels, 315 validation sample labels, 330 test sample labels
# Features (MFCC matrix) shape: 40 mel frequency coefficients x 282 time steps

# %%
# pick a random waveform, but same one from native and augmented set for easier comparison
plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveplot(waveforms[12], sr=sample_rate)
plt.title('Native')

plt.subplot(1, 2, 2)
# augmented waveforms are 2D len 1440 list with 2 waveforms in each position
librosa.display.waveplot(augmented_waveforms_temp[0][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveplot(augmented_waveforms_temp[2][0], sr=sample_rate)
plt.title('AWGN Augmented')

plt.subplot(1, 2, 2)
librosa.display.waveplot(augmented_waveforms_temp[7][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

# %%
# need to make dummy input channel for CNN input feature tensor
X_train = np.expand_dims(features_train,1)
X_valid = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test,1)

# convert emotion labels from list back to numpy arrays for PyTorch to work with 
y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)

# confiorm that we have tensor-ready 4D data array
# should print (batch, channel, width, height) == (4320, 1, 128, 282) when multiples==2
print(f'Shape of 4D feature array for input tensor: {X_train.shape} train, {X_valid.shape} validation, {X_test.shape} test')
print(f'Shape of emotion labels: {y_train.shape} train, {y_valid.shape} validation, {y_test.shape} test')
# Out:
# Shape of 4D feature array for input tensor: (2523, 1, 40, 282) train, (315, 1, 40, 282) validation, (330, 1, 40, 282) test
# Shape of emotion labels: (2523,) train, (315,) validation, (330,) test

# %%
# free up some RAM - no longer need full feature set or any waveforms 
del features_train, features_valid, features_test, waveforms, augmented_waveforms_temp

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#### Scale the training data ####
# store shape so we can transform it back 
N,C,H,W = X_train.shape
# Reshape to 1D because StandardScaler operates on a 1D array
# tell numpy to infer shape of 1D array with '-1' argument
X_train = np.reshape(X_train, (N,-1)) 
X_train = scaler.fit_transform(X_train)
# Transform back to NxCxHxW 4D tensor format
X_train = np.reshape(X_train, (N,C,H,W))

##### Scale the validation set ####
N,C,H,W = X_valid.shape
X_valid = np.reshape(X_valid, (N,-1))
X_valid = scaler.transform(X_valid)
X_valid = np.reshape(X_valid, (N,C,H,W))

#### Scale the test set ####
N,C,H,W = X_test.shape
X_test = np.reshape(X_test, (N,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, (N,C,H,W))

# check shape of each set again
print(f'X_train scaled:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid scaled:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test scaled:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train scaled:(2523, 1, 40, 282), y_train:(2523,)
# X_valid scaled:(315, 1, 40, 282), y_valid:(315,)
# X_test scaled:(330, 1, 40, 282), y_test:(330,)

# %%
###### SAVE #########
# choose save file name 
filename = 'features+labels.npy'

# open file in write mode and write data
with open(filename, 'wb') as f:
    np.save(f, X_train)
    np.save(f, X_valid)
    np.save(f, X_test)
    np.save(f, y_train)
    np.save(f, y_valid)
    np.save(f, y_test)

print(f'Features and labels saved to {filename}')
# Out:
# Features and labels saved to features+labels.npy

# %%
##### LOAD #########
# choose load file name 
filename = 'features+labels.npy'

# open file in read mode and read data 
with open(filename, 'rb') as f:
    X_train = np.load(f)
    X_valid = np.load(f)
    X_test = np.load(f)
    y_train = np.load(f)
    y_valid = np.load(f)
    y_test = np.load(f)

# Check that we've recovered the right data
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train:(2523, 1, 40, 282), y_train:(2523,)
# X_valid:(315, 1, 40, 282), y_valid:(315,)
# X_test:(330, 1, 40, 282), y_test:(330,)

# %%
#change nn.sequential to take dict to make more readable 

class parallel_all_you_want(nn.Module):
    # Define all layers present in the network
    def __init__(self,num_emotions):
        super().__init__() 
        
        ################ TRANSFORMER BLOCK #############################
        # maxpool the input feature map/tensor to the transformer 
        # a rectangular kernel worked better here for the rectangular input spectrogram feature map/tensor
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1,4], stride=[1,4])
        
        # define single transformer encoder layer
        # self-attention + feedforward network from "Attention is All You Need" paper
        # 4 multi-head self-attention layers each with 40-->512--->40 feedforward network
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40, # input feature (frequency) dim after maxpooling 40*282 -> 40*70 (MFC*time)
            nhead=4, # 4 self-attention layers in each multi-head self-attention layer in each encoder block
            dim_feedforward=512, # 2 linear layers in each encoder block's feedforward network: dim 40-->512--->40
            dropout=0.4, 
            activation='relu' # ReLU: avoid saturation/tame gradient/reduce compute time
        )
        
        # I'm using 4 instead of the 6 identical stacked encoder layrs used in Attention is All You Need paper
        # Complete transformer block contains 4 full transformer encoder layers (each w/ multihead self-attention+feedforward)
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=4)
        
        ############### 1ST PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock1 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        ############### 2ND PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock2 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )

        ################# FINAL LINEAR BLOCK ####################
        # Linear softmax layer to take final concatenated embedding tensor 
        #    from parallel 2D convolutional and transformer blocks, output 8 logits 
        # Each full convolution block outputs (64*1*8) embedding flattened to dim 512 1D array 
        # Full transformer block outputs 40*70 feature map, which we time-avg to dim 40 1D array
        # 512*2+40 == 1064 input features --> 8 output emotions 
        self.fc1_linear = nn.Linear(512*2+40,num_emotions) 
        
        ### Softmax layer for the 8 output logits from final FC linear layer 
        self.softmax_out = nn.Softmax(dim=1) # dim==1 is the freq embedding
        
    # define one complete parallel fwd pass of input feature tensor thru 2*conv+1*transformer blocks
    def forward(self,x):
        
        ############ 1st parallel Conv2D block: 4 Convolutional layers ############################
        # create final feature embedding from 1st convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding1 = self.conv2Dblock1(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding1 = torch.flatten(conv2d_embedding1, start_dim=1) 
        
        ############ 2nd parallel Conv2D block: 4 Convolutional layers #############################
        # create final feature embedding from 2nd convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding2 = self.conv2Dblock2(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding2 = torch.flatten(conv2d_embedding2, start_dim=1) 
        
         
        ########## 4-encoder-layer Transformer block w/ 40-->512-->40 feedfwd network ##############
        # maxpool input feature map: 1*40*282 w/ 1*4 kernel --> 1*40*70
        x_maxpool = self.transformer_maxpool(x)

        # remove channel dim: 1*40*70 --> 40*70
        x_maxpool_reduced = torch.squeeze(x_maxpool,1)
        
        # convert maxpooled feature map format: batch * freq * time ---> time * batch * freq format
        # because transformer encoder layer requires tensor in format: time * batch * embedding (freq)
        x = x_maxpool_reduced.permute(2,0,1) 
        
        # finally, pass reduced input feature map x into transformer encoder layers
        transformer_output = self.transformer_encoder(x)
        
        # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
        # transformer outputs 2x40 (MFCC embedding*time) feature map, take mean of columns i.e. take time average
        transformer_embedding = torch.mean(transformer_output, dim=0) # dim 40x70 --> 40
        
        ############# concatenate freq embeddings from convolutional and transformer blocks ######
        # concatenate embedding tensors output by parallel 2*conv and 1*transformer blocks
        complete_embedding = torch.cat([conv2d_embedding1, conv2d_embedding2,transformer_embedding], dim=1)  

        ######### final FC linear layer, need logits for loss #########################
        output_logits = self.fc1_linear(complete_embedding)  
        
        ######### Final Softmax layer: use logits from FC linear, get softmax for prediction ######
        output_softmax = self.softmax_out(output_logits)
        
        # need output logits to compute cross entropy loss, need softmax probabilities to predict class
        return output_logits, output_softmax

# %%
import keras
#from keras import torchsummary

# need device to instantiate model
device = 'cuda'

# instantiate model for 8 emotions and move to GPU 
model = parallel_all_you_want(len(emotions_dict)).to(device)

# include input feature map dims in call to summary()
#torchsummary.summary(model, input_size=(1,40,282))
#model.summary()

# %%
# define loss function; CrossEntropyLoss() fairly standard for multiclass problems 
def criterion(predictions, targets): 
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# %%
# define function to create a single step of the training phase
def make_train_step(model, criterion, optimizer):
    
    # define the training step of the training phase
    def train_step(X,Y):
        
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        
        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y) 
        
        # compute gradients for the optimizer to use 
        loss.backward()
        
        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()
        
        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad() 
        
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,criterion):
    def validate(X,Y):
        
        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase: 
        with torch.no_grad(): 
            
            # set model to validation phase i.e. turn off dropout and batchnorm layers 
            model.eval()
      
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            
            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits,Y)
            
        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint(): 
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint

def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
# get training set size to calculate # iterations and minibatch indices
train_size = X_train.shape[0]

# pick minibatch size (of 32... always)
minibatch = 32

# set device to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'{device} selected')

# instantiate model and move to GPU for training
model = parallel_all_you_want(num_emotions=len(emotions_dict)).to(device) 
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )

# encountered bugs in google colab only, unless I explicitly defined optimizer in this cell...
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# instantiate the checkpoint save function
save_checkpoint = make_save_checkpoint()

# instantiate the training step function 
train_step = make_train_step(model, criterion, optimizer=optimizer)

# instantiate the validation loop function
validate = make_validate_fnc(model,criterion)

# instantiate lists to hold scalar performance metrics to plot later
train_losses=[]
valid_losses = []

# create training loop for one complete epoch (entire training set)
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):

    for epoch in range(num_epochs):
        
        # set model to train phase
        model.train()         
        
        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size) 
        
        # shuffle the training set for each epoch:
        X_train = X_train[train_indices,:,:,:] 
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate 
        epoch_acc = 0 
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)
        
        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):
            
            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch 
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size) 
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start 
            
            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:] 
            # get training minibatch labels 
            Y = Y_train[batch_start:batch_end] 

            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float() 
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor,Y_tensor) 
            
            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size
            
            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}',end='')
        
        # create tensors from validation set
        X_valid_tensor = torch.tensor(X_valid,device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor,Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
                  
        # Save checkpoint of the model
        #checkpoint_filename = '/content/gdrive/My Drive/DL/models/checkpoints/parallel_all_you_wantFINAL-{:03d}.pkl'.format(epoch)
        checkpoint_filename = '/content/drive/My Drive/models/CNN_6_emotions/parallel_all_you_wantFINAL-{:03d}.pkl'.format(epoch)
        save_checkpoint(optimizer, model, epoch, checkpoint_filename)
        
        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')
# Out:
# cuda selected
# Number of trainable params:  246358

# %%
# choose number of epochs higher than reasonable so we can manually stop training 
num_epochs = 500

# train it!
cnnhistory=train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
# Out:
# Epoch 0: iteration 77/78
# Epoch 0 --- loss:3.216, Epoch accuracy:27.74%, Validation loss:2.007, Validation accuracy:23.81%
# Epoch 1: iteration 77/78
# Epoch 1 --- loss:1.436, Epoch accuracy:40.67%, Validation loss:1.938, Validation accuracy:30.79%
# Epoch 2: iteration 77/78
# Epoch 2 --- loss:1.293, Epoch accuracy:47.25%, Validation loss:1.707, Validation accuracy:39.05%
# Epoch 3: iteration 77/78
# Epoch 3 --- loss:1.209, Epoch accuracy:48.63%, Validation loss:1.612, Validation accuracy:41.59%
# Epoch 4: iteration 77/78
# Epoch 4 --- loss:1.154, Epoch accuracy:52.16%, Validation loss:1.688, Validation accuracy:40.63%
# Epoch 5: iteration 77/78
# Epoch 5 --- loss:1.122, Epoch accuracy:55.17%, Validation loss:1.378, Validation accuracy:45.08%
# Epoch 6: iteration 77/78
# Epoch 6 --- loss:1.025, Epoch accuracy:57.95%, Validation loss:1.500, Validation accuracy:45.08%
# Epoch 7: iteration 77/78
# Epoch 7 --- loss:0.964, Epoch accuracy:60.88%, Validation loss:1.529, Validation accuracy:45.40%
# Epoch 8: iteration 77/78
# Epoch 8 --- loss:0.913, Epoch accuracy:65.20%, Validation loss:1.288, Validation accuracy:52.70%
# Epoch 9: iteration 77/78
# Epoch 9 --- loss:0.891, Epoch accuracy:64.01%, Validation loss:1.586, Validation accuracy:48.57%
# Epoch 10: iteration 77/78
# Epoch 10 --- loss:0.811, Epoch accuracy:67.30%, Validation loss:1.209, Validation accuracy:53.02%
# Epoch 11: iteration 77/78
# Epoch 11 --- loss:0.766, Epoch accuracy:70.39%, Validation loss:1.218, Validation accuracy:56.51%
# Epoch 12: iteration 77/78
# Epoch 12 --- loss:0.733, Epoch accuracy:70.51%, Validation loss:1.398, Validation accuracy:50.16%
# Epoch 13: iteration 77/78
# Epoch 13 --- loss:0.699, Epoch accuracy:72.06%, Validation loss:1.241, Validation accuracy:52.70%
# Epoch 14: iteration 77/78
# Epoch 14 --- loss:0.655, Epoch accuracy:74.04%, Validation loss:1.205, Validation accuracy:53.33%
# Epoch 15: iteration 77/78
# Epoch 15 --- loss:0.622, Epoch accuracy:75.11%, Validation loss:1.390, Validation accuracy:54.29%
# Epoch 16: iteration 77/78
# Epoch 16 --- loss:0.574, Epoch accuracy:77.05%, Validation loss:1.481, Validation accuracy:52.38%
# Epoch 17: iteration 77/78
# Epoch 17 --- loss:0.533, Epoch accuracy:79.03%, Validation loss:1.313, Validation accuracy:53.65%
# Epoch 18: iteration 77/78
# Epoch 18 --- loss:0.503, Epoch accuracy:79.63%, Validation loss:1.348, Validation accuracy:55.56%
# Epoch 19: iteration 77/78
# Epoch 19 --- loss:0.477, Epoch accuracy:80.94%, Validation loss:1.291, Validation accuracy:61.27%
# Epoch 20: iteration 77/78
# Epoch 20 --- loss:0.494, Epoch accuracy:80.18%, Validation loss:1.293, Validation accuracy:61.27%
# Epoch 21: iteration 77/78
# Epoch 21 --- loss:0.456, Epoch accuracy:81.21%, Validation loss:1.158, Validation accuracy:63.81%
# Epoch 22: iteration 77/78
# Epoch 22 --- loss:0.382, Epoch accuracy:84.46%, Validation loss:1.304, Validation accuracy:57.46%
# Epoch 23: iteration 77/78
# Epoch 23 --- loss:0.368, Epoch accuracy:85.33%, Validation loss:1.515, Validation accuracy:57.78%
# Epoch 24: iteration 77/78
# Epoch 24 --- loss:0.346, Epoch accuracy:86.68%, Validation loss:1.357, Validation accuracy:61.27%
# Epoch 25: iteration 77/78
# Epoch 25 --- loss:0.321, Epoch accuracy:86.44%, Validation loss:1.488, Validation accuracy:60.32%
# Epoch 26: iteration 77/78
# Epoch 26 --- loss:0.334, Epoch accuracy:85.77%, Validation loss:1.633, Validation accuracy:58.10%
# Epoch 27: iteration 77/78
# Epoch 27 --- loss:0.288, Epoch accuracy:88.27%, Validation loss:1.573, Validation accuracy:61.59%
# Epoch 28: iteration 77/78
# Epoch 28 --- loss:0.289, Epoch accuracy:88.23%, Validation loss:1.376, Validation accuracy:60.63%
# Epoch 29: iteration 77/78
# Epoch 29 --- loss:0.288, Epoch accuracy:87.67%, Validation loss:1.341, Validation accuracy:62.54%
# Epoch 30: iteration 77/78
# Epoch 30 --- loss:0.270, Epoch accuracy:89.18%, Validation loss:1.748, Validation accuracy:58.73%
# Epoch 31: iteration 77/78
# Epoch 31 --- loss:0.232, Epoch accuracy:90.17%, Validation loss:1.446, Validation accuracy:60.95%
# Epoch 32: iteration 77/78
# Epoch 32 --- loss:0.238, Epoch accuracy:89.89%, Validation loss:1.583, Validation accuracy:60.00%
# Epoch 33: iteration 77/78
# Epoch 33 --- loss:0.226, Epoch accuracy:90.88%, Validation loss:1.585, Validation accuracy:59.68%
# Epoch 34: iteration 77/78
# Epoch 34 --- loss:0.181, Epoch accuracy:92.55%, Validation loss:1.548, Validation accuracy:63.49%
# Epoch 35: iteration 77/78
# Epoch 35 --- loss:0.204, Epoch accuracy:91.32%, Validation loss:1.703, Validation accuracy:59.05%
# Epoch 36: iteration 77/78
# Epoch 36 --- loss:0.156, Epoch accuracy:93.90%, Validation loss:1.903, Validation accuracy:56.83%
# Epoch 37: iteration 77/78
# Epoch 37 --- loss:0.181, Epoch accuracy:93.02%, Validation loss:1.716, Validation accuracy:61.59%
# Epoch 38: iteration 77/78
# Epoch 38 --- loss:0.186, Epoch accuracy:91.72%, Validation loss:1.426, Validation accuracy:62.22%
# Epoch 39: iteration 77/78
# Epoch 39 --- loss:0.151, Epoch accuracy:93.98%, Validation loss:1.657, Validation accuracy:60.63%
# Epoch 40: iteration 77/78
# Epoch 40 --- loss:0.120, Epoch accuracy:95.24%, Validation loss:1.508, Validation accuracy:62.54%
# Epoch 41: iteration 77/78
# Epoch 41 --- loss:0.147, Epoch accuracy:93.78%, Validation loss:1.764, Validation accuracy:60.95%
# Epoch 42: iteration 77/78
# Epoch 42 --- loss:0.167, Epoch accuracy:92.94%, Validation loss:1.793, Validation accuracy:61.27%
# Epoch 43: iteration 77/78
# Epoch 43 --- loss:0.137, Epoch accuracy:94.17%, Validation loss:1.700, Validation accuracy:59.05%
# Epoch 44: iteration 77/78
# Epoch 44 --- loss:0.126, Epoch accuracy:94.57%, Validation loss:1.725, Validation accuracy:60.95%
# Epoch 45: iteration 77/78
# Epoch 45 --- loss:0.122, Epoch accuracy:95.12%, Validation loss:1.828, Validation accuracy:57.14%
# Epoch 46: iteration 77/78
# Epoch 46 --- loss:0.103, Epoch accuracy:95.88%, Validation loss:2.024, Validation accuracy:58.41%
# Epoch 47: iteration 77/78
# Epoch 47 --- loss:0.121, Epoch accuracy:94.65%, Validation loss:1.650, Validation accuracy:61.59%
# Epoch 48: iteration 77/78
# Epoch 48 --- loss:0.106, Epoch accuracy:95.52%, Validation loss:1.674, Validation accuracy:64.44%
# Epoch 49: iteration 77/78
# Epoch 49 --- loss:0.099, Epoch accuracy:96.04%, Validation loss:1.626, Validation accuracy:64.44%
# Epoch 50: iteration 77/78
# Epoch 50 --- loss:0.123, Epoch accuracy:94.85%, Validation loss:1.661, Validation accuracy:63.49%
# Epoch 51: iteration 77/78
# Epoch 51 --- loss:0.079, Epoch accuracy:96.47%, Validation loss:1.747, Validation accuracy:63.49%
# Epoch 52: iteration 77/78
# Epoch 52 --- loss:0.119, Epoch accuracy:93.98%, Validation loss:1.938, Validation accuracy:61.90%
# Epoch 53: iteration 77/78
# Epoch 53 --- loss:0.074, Epoch accuracy:96.71%, Validation loss:1.684, Validation accuracy:66.35%
# Epoch 54: iteration 77/78
# Epoch 54 --- loss:0.058, Epoch accuracy:97.27%, Validation loss:1.764, Validation accuracy:62.22%
# Epoch 55: iteration 77/78
# Epoch 55 --- loss:0.090, Epoch accuracy:96.31%, Validation loss:1.672, Validation accuracy:64.44%
# Epoch 56: iteration 77/78
# Epoch 56 --- loss:0.097, Epoch accuracy:95.32%, Validation loss:1.838, Validation accuracy:63.49%
# Epoch 57: iteration 77/78
# Epoch 57 --- loss:0.079, Epoch accuracy:96.16%, Validation loss:1.805, Validation accuracy:63.49%
# Epoch 58: iteration 77/78
# Epoch 58 --- loss:0.078, Epoch accuracy:96.27%, Validation loss:1.985, Validation accuracy:58.41%
# Epoch 59: iteration 77/78
# Epoch 59 --- loss:0.094, Epoch accuracy:95.76%, Validation loss:1.783, Validation accuracy:62.54%
# Epoch 60: iteration 77/78
# Epoch 60 --- loss:0.063, Epoch accuracy:96.99%, Validation loss:1.815, Validation accuracy:63.49%
# Epoch 61: iteration 77/78
# Epoch 61 --- loss:0.081, Epoch accuracy:96.55%, Validation loss:1.730, Validation accuracy:64.76%
# Epoch 62: iteration 77/78
# Epoch 62 --- loss:0.059, Epoch accuracy:97.07%, Validation loss:1.833, Validation accuracy:60.63%
# Epoch 63: iteration 77/78
# Epoch 63 --- loss:0.051, Epoch accuracy:97.46%, Validation loss:1.803, Validation accuracy:62.86%
# Epoch 64: iteration 77/78
# Epoch 64 --- loss:0.070, Epoch accuracy:96.75%, Validation loss:1.943, Validation accuracy:63.17%
# Epoch 65: iteration 77/78
# Epoch 65 --- loss:0.066, Epoch accuracy:96.59%, Validation loss:1.866, Validation accuracy:59.68%
# Epoch 66: iteration 77/78
# Epoch 66 --- loss:0.046, Epoch accuracy:97.74%, Validation loss:1.756, Validation accuracy:64.44%
# Epoch 67: iteration 77/78
# Epoch 67 --- loss:0.062, Epoch accuracy:97.03%, Validation loss:1.943, Validation accuracy:60.32%
# Epoch 68: iteration 77/78
# Epoch 68 --- loss:0.048, Epoch accuracy:97.70%, Validation loss:1.775, Validation accuracy:63.17%
# Epoch 69: iteration 77/78
# Epoch 69 --- loss:0.045, Epoch accuracy:97.82%, Validation loss:2.036, Validation accuracy:60.63%
# Epoch 70: iteration 77/78
# Epoch 70 --- loss:0.077, Epoch accuracy:96.59%, Validation loss:2.140, Validation accuracy:60.95%
# Epoch 71: iteration 77/78
# Epoch 71 --- loss:0.053, Epoch accuracy:97.54%, Validation loss:1.862, Validation accuracy:63.49%
# Epoch 72: iteration 77/78
# Epoch 72 --- loss:0.046, Epoch accuracy:97.66%, Validation loss:2.094, Validation accuracy:62.86%
# Epoch 73: iteration 77/78
# Epoch 73 --- loss:0.047, Epoch accuracy:97.70%, Validation loss:1.865, Validation accuracy:64.44%
# Epoch 74: iteration 77/78
# Epoch 74 --- loss:0.043, Epoch accuracy:97.82%, Validation loss:1.954, Validation accuracy:61.90%
# Epoch 75: iteration 77/78
# Epoch 75 --- loss:0.046, Epoch accuracy:97.66%, Validation loss:1.964, Validation accuracy:61.59%
# Epoch 76: iteration 77/78
# Epoch 76 --- loss:0.036, Epoch accuracy:98.06%, Validation loss:1.956, Validation accuracy:62.22%
# Epoch 77: iteration 77/78
# Epoch 77 --- loss:0.042, Epoch accuracy:97.66%, Validation loss:1.884, Validation accuracy:63.17%
# Epoch 78: iteration 77/78
# Epoch 78 --- loss:0.046, Epoch accuracy:97.54%, Validation loss:1.989, Validation accuracy:65.40%
# Epoch 79: iteration 77/78
# Epoch 79 --- loss:0.042, Epoch accuracy:97.86%, Validation loss:2.131, Validation accuracy:61.27%
# Epoch 80: iteration 77/78
# Epoch 80 --- loss:0.041, Epoch accuracy:97.74%, Validation loss:1.937, Validation accuracy:64.13%
# Epoch 81: iteration 77/78
# Epoch 81 --- loss:0.067, Epoch accuracy:96.55%, Validation loss:1.925, Validation accuracy:63.17%
# Epoch 82: iteration 77/78
# Epoch 82 --- loss:0.050, Epoch accuracy:97.15%, Validation loss:1.845, Validation accuracy:66.03%
# Epoch 83: iteration 77/78
# Epoch 83 --- loss:0.067, Epoch accuracy:96.71%, Validation loss:2.009, Validation accuracy:61.27%
# Epoch 84: iteration 77/78
# Epoch 84 --- loss:0.032, Epoch accuracy:98.26%, Validation loss:1.872, Validation accuracy:65.71%
# Epoch 85: iteration 77/78
# Epoch 85 --- loss:0.044, Epoch accuracy:97.58%, Validation loss:1.833, Validation accuracy:65.71%
# Epoch 86: iteration 77/78
# Epoch 86 --- loss:0.038, Epoch accuracy:97.98%, Validation loss:1.907, Validation accuracy:66.35%
# Epoch 87: iteration 77/78
# Epoch 87 --- loss:0.038, Epoch accuracy:97.94%, Validation loss:1.986, Validation accuracy:61.59%
# Epoch 88: iteration 77/78
# Epoch 88 --- loss:0.029, Epoch accuracy:98.41%, Validation loss:1.959, Validation accuracy:63.17%
# Epoch 89: iteration 77/78
# Epoch 89 --- loss:0.030, Epoch accuracy:98.26%, Validation loss:1.985, Validation accuracy:64.44%
# Epoch 90: iteration 77/78
# Epoch 90 --- loss:0.019, Epoch accuracy:98.69%, Validation loss:1.878, Validation accuracy:65.71%
# Epoch 91: iteration 77/78
# Epoch 91 --- loss:0.027, Epoch accuracy:98.30%, Validation loss:1.932, Validation accuracy:64.44%
# Epoch 92: iteration 77/78
# Epoch 92 --- loss:0.023, Epoch accuracy:98.53%, Validation loss:1.976, Validation accuracy:64.44%
# Epoch 93: iteration 77/78
# Epoch 93 --- loss:0.024, Epoch accuracy:98.53%, Validation loss:2.033, Validation accuracy:60.63%
# Epoch 94: iteration 77/78
# Epoch 94 --- loss:0.027, Epoch accuracy:98.14%, Validation loss:1.974, Validation accuracy:64.44%
# Epoch 95: iteration 77/78
# Epoch 95 --- loss:0.036, Epoch accuracy:97.86%, Validation loss:1.971, Validation accuracy:65.71%
# Epoch 96: iteration 77/78
# Epoch 96 --- loss:0.040, Epoch accuracy:97.94%, Validation loss:2.037, Validation accuracy:62.86%
# Epoch 97: iteration 77/78
# Epoch 97 --- loss:0.032, Epoch accuracy:98.30%, Validation loss:1.875, Validation accuracy:66.03%
# Epoch 98: iteration 77/78
# Epoch 98 --- loss:0.027, Epoch accuracy:98.37%, Validation loss:1.941, Validation accuracy:63.81%
# Epoch 99: iteration 77/78
# Epoch 99 --- loss:0.032, Epoch accuracy:98.06%, Validation loss:1.923, Validation accuracy:66.98%
# Epoch 100: iteration 77/78
# Epoch 100 --- loss:0.016, Epoch accuracy:98.85%, Validation loss:1.822, Validation accuracy:66.67%
# Epoch 101: iteration 77/78
# Epoch 101 --- loss:0.014, Epoch accuracy:98.85%, Validation loss:1.911, Validation accuracy:65.40%
# Epoch 102: iteration 77/78
# Epoch 102 --- loss:0.015, Epoch accuracy:98.73%, Validation loss:1.838, Validation accuracy:67.62%
# Epoch 103: iteration 77/78
# Epoch 103 --- loss:0.035, Epoch accuracy:98.02%, Validation loss:1.985, Validation accuracy:63.81%
# Epoch 104: iteration 77/78
# Epoch 104 --- loss:0.035, Epoch accuracy:97.90%, Validation loss:2.162, Validation accuracy:60.63%
# Epoch 105: iteration 77/78
# Epoch 105 --- loss:0.026, Epoch accuracy:98.34%, Validation loss:1.831, Validation accuracy:64.76%
# Epoch 106: iteration 77/78
# Epoch 106 --- loss:0.029, Epoch accuracy:98.30%, Validation loss:2.162, Validation accuracy:63.17%
# Epoch 107: iteration 77/78
# Epoch 107 --- loss:0.034, Epoch accuracy:97.78%, Validation loss:1.850, Validation accuracy:66.35%
# Epoch 108: iteration 77/78
# Epoch 108 --- loss:0.024, Epoch accuracy:98.37%, Validation loss:1.905, Validation accuracy:65.08%
# Epoch 109: iteration 77/78
# Epoch 109 --- loss:0.030, Epoch accuracy:98.22%, Validation loss:2.032, Validation accuracy:63.49%
# Epoch 110: iteration 77/78
# Epoch 110 --- loss:0.034, Epoch accuracy:98.10%, Validation loss:1.791, Validation accuracy:66.35%
# Epoch 111: iteration 77/78
# Epoch 111 --- loss:0.020, Epoch accuracy:98.61%, Validation loss:1.827, Validation accuracy:65.40%
# Epoch 112: iteration 77/78
# Epoch 112 --- loss:0.016, Epoch accuracy:98.77%, Validation loss:1.783, Validation accuracy:64.44%
# Epoch 113: iteration 77/78
# Epoch 113 --- loss:0.019, Epoch accuracy:98.65%, Validation loss:1.788, Validation accuracy:66.67%
# Epoch 114: iteration 77/78
# Epoch 114 --- loss:0.017, Epoch accuracy:98.73%, Validation loss:1.770, Validation accuracy:66.67%
# Epoch 115: iteration 77/78
# Epoch 115 --- loss:0.016, Epoch accuracy:98.69%, Validation loss:1.828, Validation accuracy:65.40%
# Epoch 116: iteration 77/78
# Epoch 116 --- loss:0.023, Epoch accuracy:98.45%, Validation loss:1.773, Validation accuracy:68.89%
# Epoch 117: iteration 77/78
# Epoch 117 --- loss:0.022, Epoch accuracy:98.45%, Validation loss:1.885, Validation accuracy:67.62%
# Epoch 118: iteration 77/78
# Epoch 118 --- loss:0.031, Epoch accuracy:98.10%, Validation loss:1.910, Validation accuracy:64.13%
# Epoch 119: iteration 77/78
# Epoch 119 --- loss:0.066, Epoch accuracy:96.59%, Validation loss:1.882, Validation accuracy:64.13%
# Epoch 120: iteration 77/78
# Epoch 120 --- loss:0.026, Epoch accuracy:98.41%, Validation loss:1.971, Validation accuracy:63.81%
# Epoch 121: iteration 77/78
# Epoch 121 --- loss:0.032, Epoch accuracy:98.02%, Validation loss:1.995, Validation accuracy:64.13%
# Epoch 122: iteration 77/78
# Epoch 122 --- loss:0.024, Epoch accuracy:98.26%, Validation loss:2.008, Validation accuracy:61.27%
# Epoch 123: iteration 77/78
# Epoch 123 --- loss:0.019, Epoch accuracy:98.73%, Validation loss:1.839, Validation accuracy:64.76%
# Epoch 124: iteration 77/78
# Epoch 124 --- loss:0.020, Epoch accuracy:98.49%, Validation loss:1.778, Validation accuracy:66.35%
# Epoch 125: iteration 77/78
# Epoch 125 --- loss:0.010, Epoch accuracy:98.85%, Validation loss:1.840, Validation accuracy:65.08%
# Epoch 126: iteration 77/78
# Epoch 126 --- loss:0.014, Epoch accuracy:98.77%, Validation loss:1.848, Validation accuracy:62.86%
# Epoch 127: iteration 77/78
# Epoch 127 --- loss:0.019, Epoch accuracy:98.61%, Validation loss:1.723, Validation accuracy:67.30%
# Epoch 128: iteration 77/78
# Epoch 128 --- loss:0.017, Epoch accuracy:98.69%, Validation loss:1.839, Validation accuracy:66.35%
# Epoch 129: iteration 77/78
# Epoch 129 --- loss:0.015, Epoch accuracy:98.73%, Validation loss:1.924, Validation accuracy:65.40%
# Epoch 130: iteration 77/78
# Epoch 130 --- loss:0.017, Epoch accuracy:98.65%, Validation loss:1.943, Validation accuracy:64.44%
# Epoch 131: iteration 77/78
# Epoch 131 --- loss:0.035, Epoch accuracy:97.86%, Validation loss:1.853, Validation accuracy:63.17%
# Epoch 132: iteration 77/78
# Epoch 132 --- loss:0.018, Epoch accuracy:98.57%, Validation loss:1.803, Validation accuracy:65.08%
# Epoch 133: iteration 77/78
# Epoch 133 --- loss:0.018, Epoch accuracy:98.53%, Validation loss:2.099, Validation accuracy:57.78%
# Epoch 134: iteration 77/78
# Epoch 134 --- loss:0.031, Epoch accuracy:98.10%, Validation loss:1.950, Validation accuracy:63.49%
# Epoch 135: iteration 77/78
# Epoch 135 --- loss:0.018, Epoch accuracy:98.77%, Validation loss:1.878, Validation accuracy:65.08%
# Epoch 136: iteration 77/78
# Epoch 136 --- loss:0.011, Epoch accuracy:98.85%, Validation loss:1.854, Validation accuracy:68.57%
# Epoch 137: iteration 77/78
# Epoch 137 --- loss:0.009, Epoch accuracy:98.93%, Validation loss:1.828, Validation accuracy:67.62%
# Epoch 138: iteration 77/78
# Epoch 138 --- loss:0.012, Epoch accuracy:98.73%, Validation loss:1.931, Validation accuracy:63.81%
# Epoch 139: iteration 77/78
# Epoch 139 --- loss:0.017, Epoch accuracy:98.69%, Validation loss:1.808, Validation accuracy:65.08%
# Epoch 140: iteration 77/78
# Epoch 140 --- loss:0.016, Epoch accuracy:98.65%, Validation loss:1.773, Validation accuracy:66.98%
# Epoch 141: iteration 77/78
# Epoch 141 --- loss:0.027, Epoch accuracy:98.18%, Validation loss:1.858, Validation accuracy:63.17%
# Epoch 142: iteration 77/78
# Epoch 142 --- loss:0.157, Epoch accuracy:93.42%, Validation loss:2.059, Validation accuracy:61.59%
# Epoch 143: iteration 77/78
# Epoch 143 --- loss:0.042, Epoch accuracy:97.74%, Validation loss:1.954, Validation accuracy:61.27%
# Epoch 144: iteration 77/78
# Epoch 144 --- loss:0.014, Epoch accuracy:98.85%, Validation loss:1.873, Validation accuracy:61.90%
# Epoch 145: iteration 77/78
# Epoch 145 --- loss:0.025, Epoch accuracy:98.26%, Validation loss:1.989, Validation accuracy:61.59%
# Epoch 146: iteration 77/78
# Epoch 146 --- loss:0.020, Epoch accuracy:98.57%, Validation loss:1.709, Validation accuracy:67.62%
# Epoch 147: iteration 77/78
# Epoch 147 --- loss:0.014, Epoch accuracy:98.89%, Validation loss:1.812, Validation accuracy:65.71%
# Epoch 148: iteration 77/78
# Epoch 148 --- loss:0.012, Epoch accuracy:98.89%, Validation loss:1.825, Validation accuracy:64.44%
# Epoch 149: iteration 77/78
# Epoch 149 --- loss:0.018, Epoch accuracy:98.57%, Validation loss:1.848, Validation accuracy:65.40%
# Epoch 150: iteration 77/78
# Epoch 150 --- loss:0.010, Epoch accuracy:98.93%, Validation loss:1.701, Validation accuracy:67.30%
# Epoch 151: iteration 77/78
# Epoch 151 --- loss:0.019, Epoch accuracy:98.37%, Validation loss:1.953, Validation accuracy:62.22%
# Epoch 152: iteration 77/78
# Epoch 152 --- loss:0.044, Epoch accuracy:97.66%, Validation loss:1.859, Validation accuracy:64.76%
# Epoch 153: iteration 77/78
# Epoch 153 --- loss:0.019, Epoch accuracy:98.61%, Validation loss:1.955, Validation accuracy:62.22%
# Epoch 154: iteration 77/78
# Epoch 154 --- loss:0.024, Epoch accuracy:98.49%, Validation loss:1.911, Validation accuracy:64.44%
# Epoch 155: iteration 77/78
# Epoch 155 --- loss:0.017, Epoch accuracy:98.77%, Validation loss:1.795, Validation accuracy:64.44%
# Epoch 156: iteration 77/78
# Epoch 156 --- loss:0.016, Epoch accuracy:98.61%, Validation loss:1.815, Validation accuracy:63.17%
# Epoch 157: iteration 77/78
# Epoch 157 --- loss:0.010, Epoch accuracy:98.93%, Validation loss:1.766, Validation accuracy:66.03%
# Epoch 158: iteration 77/78
# Epoch 158 --- loss:0.015, Epoch accuracy:98.77%, Validation loss:1.785, Validation accuracy:64.76%
# Epoch 159: iteration 77/78
# Epoch 159 --- loss:0.015, Epoch accuracy:98.65%, Validation loss:1.722, Validation accuracy:66.98%
# Epoch 160: iteration 77/78
# Epoch 160 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:1.770, Validation accuracy:65.40%
# Epoch 161: iteration 77/78
# Epoch 161 --- loss:0.008, Epoch accuracy:98.93%, Validation loss:1.730, Validation accuracy:66.35%
# Epoch 162: iteration 77/78
# Epoch 162 --- loss:0.015, Epoch accuracy:98.65%, Validation loss:1.757, Validation accuracy:66.35%
# Epoch 163: iteration 77/78
# Epoch 163 --- loss:0.014, Epoch accuracy:98.73%, Validation loss:1.796, Validation accuracy:64.44%
# Epoch 164: iteration 77/78
# Epoch 164 --- loss:0.065, Epoch accuracy:96.99%, Validation loss:2.071, Validation accuracy:60.00%
# Epoch 165: iteration 77/78
# Epoch 165 --- loss:0.084, Epoch accuracy:95.88%, Validation loss:1.993, Validation accuracy:59.68%
# Epoch 166: iteration 77/78
# Epoch 166 --- loss:0.040, Epoch accuracy:97.86%, Validation loss:1.780, Validation accuracy:66.03%
# Epoch 167: iteration 77/78
# Epoch 167 --- loss:0.026, Epoch accuracy:98.45%, Validation loss:1.761, Validation accuracy:68.25%
# Epoch 168: iteration 77/78
# Epoch 168 --- loss:0.013, Epoch accuracy:98.81%, Validation loss:1.721, Validation accuracy:66.03%
# Epoch 169: iteration 77/78
# Epoch 169 --- loss:0.011, Epoch accuracy:98.85%, Validation loss:1.697, Validation accuracy:65.71%
# Epoch 170: iteration 77/78
# Epoch 170 --- loss:0.015, Epoch accuracy:98.81%, Validation loss:1.721, Validation accuracy:65.40%
# Epoch 171: iteration 77/78
# Epoch 171 --- loss:0.016, Epoch accuracy:98.73%, Validation loss:1.780, Validation accuracy:66.35%
# Epoch 172: iteration 77/78
# Epoch 172 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:1.865, Validation accuracy:63.49%
# Epoch 173: iteration 77/78
# Epoch 173 --- loss:0.017, Epoch accuracy:98.53%, Validation loss:1.780, Validation accuracy:66.03%
# Epoch 174: iteration 77/78
# Epoch 174 --- loss:0.010, Epoch accuracy:98.85%, Validation loss:1.744, Validation accuracy:65.40%
# Epoch 175: iteration 77/78
# Epoch 175 --- loss:0.008, Epoch accuracy:98.93%, Validation loss:1.787, Validation accuracy:64.76%
# Epoch 176: iteration 77/78
# Epoch 176 --- loss:0.007, Epoch accuracy:98.93%, Validation loss:1.803, Validation accuracy:66.03%
# Epoch 177: iteration 77/78
# Epoch 177 --- loss:0.008, Epoch accuracy:98.93%, Validation loss:1.745, Validation accuracy:67.62%
# Epoch 178: iteration 77/78
# Epoch 178 --- loss:0.007, Epoch accuracy:98.93%, Validation loss:1.774, Validation accuracy:66.03%
# Epoch 179: iteration 77/78
# Epoch 179 --- loss:0.010, Epoch accuracy:98.89%, Validation loss:1.804, Validation accuracy:65.08%
# Epoch 180: iteration 77/78
# Epoch 180 --- loss:0.008, Epoch accuracy:98.93%, Validation loss:1.740, Validation accuracy:65.08%
# Epoch 181: iteration 77/78
# Epoch 181 --- loss:0.016, Epoch accuracy:98.61%, Validation loss:1.840, Validation accuracy:65.40%
# Epoch 182: iteration 77/78
# Epoch 182 --- loss:0.010, Epoch accuracy:98.89%, Validation loss:1.751, Validation accuracy:67.94%
# Epoch 183: iteration 77/78
# Epoch 183 --- loss:0.012, Epoch accuracy:98.89%, Validation loss:1.801, Validation accuracy:64.76%
# Epoch 184: iteration 77/78
# Epoch 184 --- loss:0.012, Epoch accuracy:98.61%, Validation loss:1.800, Validation accuracy:67.30%
# Epoch 185: iteration 77/78
# Epoch 185 --- loss:0.009, Epoch accuracy:98.93%, Validation loss:1.788, Validation accuracy:65.08%
# Epoch 186: iteration 77/78
# Epoch 186 --- loss:0.012, Epoch accuracy:98.73%, Validation loss:1.830, Validation accuracy:67.30%
# Epoch 187: iteration 77/78
# Epoch 187 --- loss:0.011, Epoch accuracy:98.93%, Validation loss:1.792, Validation accuracy:64.44%
# Epoch 188: iteration 77/78
# Epoch 188 --- loss:0.016, Epoch accuracy:98.69%, Validation loss:1.813, Validation accuracy:66.03%
# Epoch 189: iteration 77/78
# Epoch 189 --- loss:0.029, Epoch accuracy:98.22%, Validation loss:1.957, Validation accuracy:63.17%
# Epoch 190: iteration 77/78
# Epoch 190 --- loss:0.034, Epoch accuracy:97.94%, Validation loss:1.927, Validation accuracy:65.40%
# Epoch 191: iteration 77/78
# Epoch 191 --- loss:0.012, Epoch accuracy:98.85%, Validation loss:1.840, Validation accuracy:64.76%
# Epoch 192: iteration 77/78
# Epoch 192 --- loss:0.009, Epoch accuracy:98.93%, Validation loss:1.847, Validation accuracy:67.30%
# Epoch 193: iteration 77/78
# Epoch 193 --- loss:0.032, Epoch accuracy:97.90%, Validation loss:1.851, Validation accuracy:65.71%
# Epoch 194: iteration 77/78
# Epoch 194 --- loss:0.093, Epoch accuracy:96.04%, Validation loss:2.423, Validation accuracy:58.41%
# Epoch 195: iteration 77/78
# Epoch 195 --- loss:0.173, Epoch accuracy:93.10%, Validation loss:1.969, Validation accuracy:60.00%
# Epoch 196: iteration 77/78
# Epoch 196 --- loss:0.036, Epoch accuracy:97.90%, Validation loss:1.717, Validation accuracy:62.86%
# Epoch 197: iteration 77/78
# Epoch 197 --- loss:0.030, Epoch accuracy:98.34%, Validation loss:1.917, Validation accuracy:60.63%
# Epoch 198: iteration 77/78
# Epoch 198 --- loss:0.021, Epoch accuracy:98.53%, Validation loss:1.725, Validation accuracy:65.08%
# Epoch 199: iteration 77/78
# Epoch 199 --- loss:0.015, Epoch accuracy:98.85%, Validation loss:1.637, Validation accuracy:68.57%
# Epoch 200: iteration 77/78
# Epoch 200 --- loss:0.012, Epoch accuracy:98.81%, Validation loss:1.787, Validation accuracy:62.86%
# Epoch 201: iteration 77/78
# Epoch 201 --- loss:0.015, Epoch accuracy:98.77%, Validation loss:1.707, Validation accuracy:65.08%
# Epoch 202: iteration 77/78
# Epoch 202 --- loss:0.018, Epoch accuracy:98.57%, Validation loss:1.827, Validation accuracy:62.22%
# Epoch 203: iteration 77/78
# Epoch 203 --- loss:0.016, Epoch accuracy:98.69%, Validation loss:1.689, Validation accuracy:64.76%
# Epoch 204: iteration 77/78
# Epoch 204 --- loss:0.014, Epoch accuracy:98.77%, Validation loss:1.723, Validation accuracy:66.03%
# Epoch 205: iteration 77/78
# Epoch 205 --- loss:0.013, Epoch accuracy:98.81%, Validation loss:1.752, Validation accuracy:66.67%
# Epoch 206: iteration 77/78
# Epoch 206 --- loss:0.009, Epoch accuracy:98.89%, Validation loss:1.670, Validation accuracy:67.62%
# Epoch 207: iteration 77/78
# Epoch 207 --- loss:0.010, Epoch accuracy:98.93%, Validation loss:1.783, Validation accuracy:64.76%
# Epoch 208: iteration 77/78
# Epoch 208 --- loss:0.010, Epoch accuracy:98.93%, Validation loss:1.723, Validation accuracy:64.44%
# Epoch 209: iteration 77/78
# Epoch 209 --- loss:0.010, Epoch accuracy:98.81%, Validation loss:1.730, Validation accuracy:64.76%
# Epoch 210: iteration 77/78
# Epoch 210 --- loss:0.009, Epoch accuracy:98.89%, Validation loss:1.733, Validation accuracy:66.98%
# Epoch 211: iteration 77/78
# Epoch 211 --- loss:0.009, Epoch accuracy:98.93%, Validation loss:1.703, Validation accuracy:66.67%
# Epoch 212: iteration 77/78
# Epoch 212 --- loss:0.008, Epoch accuracy:98.93%, Validation loss:1.693, Validation accuracy:67.62%
# Epoch 213: iteration 77/78
# Epoch 213 --- loss:0.007, Epoch accuracy:98.93%, Validation loss:1.765, Validation accuracy:65.08%
# Epoch 214: iteration 77/78
# Epoch 214 --- loss:0.011, Epoch accuracy:98.81%, Validation loss:1.811, Validation accuracy:64.44%
# Epoch 215: iteration 77/78
# Epoch 215 --- loss:0.011, Epoch accuracy:98.89%, Validation loss:1.788, Validation accuracy:67.94%
# Epoch 216: iteration 77/78
# Epoch 216 --- loss:0.019, Epoch accuracy:98.41%, Validation loss:1.799, Validation accuracy:67.30%
# Epoch 217: iteration 77/78
# Epoch 217 --- loss:0.015, Epoch accuracy:98.81%, Validation loss:1.782, Validation accuracy:65.71%
# Epoch 218: iteration 77/78
# Epoch 218 --- loss:0.012, Epoch accuracy:98.89%, Validation loss:1.772, Validation accuracy:66.35%
# Epoch 219: iteration 77/78
# Epoch 219 --- loss:0.060, Epoch accuracy:97.03%, Validation loss:1.734, Validation accuracy:66.35%
# Epoch 220: iteration 77/78
# Epoch 220 --- loss:0.040, Epoch accuracy:97.78%, Validation loss:1.919, Validation accuracy:63.81%
# Epoch 221: iteration 77/78
# Epoch 221 --- loss:0.024, Epoch accuracy:98.45%, Validation loss:1.759, Validation accuracy:66.98%
# Epoch 222: iteration 77/78
# Epoch 222 --- loss:0.016, Epoch accuracy:98.61%, Validation loss:1.712, Validation accuracy:70.48%
# Epoch 223: iteration 77/78
# Epoch 223 --- loss:0.025, Epoch accuracy:98.26%, Validation loss:1.923, Validation accuracy:66.67%
# Epoch 224: iteration 77/78
# Epoch 224 --- loss:0.032, Epoch accuracy:97.86%, Validation loss:1.831, Validation accuracy:64.76%
# Epoch 225: iteration 77/78
# Epoch 225 --- loss:0.049, Epoch accuracy:97.27%, Validation loss:1.868, Validation accuracy:63.81%
# Epoch 226: iteration 77/78
# Epoch 226 --- loss:0.091, Epoch accuracy:96.04%, Validation loss:1.628, Validation accuracy:67.94%
# Epoch 227: iteration 77/78
# Epoch 227 --- loss:0.041, Epoch accuracy:97.90%, Validation loss:1.688, Validation accuracy:66.98%
# Epoch 228: iteration 77/78
# Epoch 228 --- loss:0.020, Epoch accuracy:98.57%, Validation loss:1.713, Validation accuracy:66.35%
# Epoch 229: iteration 77/78
# Epoch 229 --- loss:0.025, Epoch accuracy:98.37%, Validation loss:1.697, Validation accuracy:68.25%
# Epoch 230: iteration 77/78
# Epoch 230 --- loss:0.013, Epoch accuracy:98.81%, Validation loss:1.733, Validation accuracy:67.62%
# Epoch 231: iteration 77/78
# Epoch 231 --- loss:0.012, Epoch accuracy:98.73%, Validation loss:1.814, Validation accuracy:65.71%
# Epoch 232: iteration 77/78
# Epoch 232 --- loss:0.010, Epoch accuracy:98.89%, Validation loss:1.812, Validation accuracy:65.08%
# Epoch 233: iteration 77/78
# Epoch 233 --- loss:0.011, Epoch accuracy:98.81%, Validation loss:1.736, Validation accuracy:69.52%
# Epoch 234: iteration 77/78
# Epoch 234 --- loss:0.009, Epoch accuracy:98.89%, Validation loss:1.761, Validation accuracy:67.30%
# Epoch 235: iteration 77/78
# Epoch 235 --- loss:0.009, Epoch accuracy:98.89%, Validation loss:1.768, Validation accuracy:69.52%
# Epoch 236: iteration 77/78
# Epoch 236 --- loss:0.011, Epoch accuracy:98.85%, Validation loss:1.810, Validation accuracy:66.98%
# Epoch 237: iteration 77/78
# Epoch 237 --- loss:0.016, Epoch accuracy:98.49%, Validation loss:1.890, Validation accuracy:64.13%
# Epoch 238: iteration 77/78
# Epoch 238 --- loss:0.023, Epoch accuracy:98.57%, Validation loss:1.946, Validation accuracy:62.86%
# Epoch 239: iteration 77/78
# Epoch 239 --- loss:0.012, Epoch accuracy:98.85%, Validation loss:1.796, Validation accuracy:66.98%
# Epoch 240: iteration 77/78
# Epoch 240 --- loss:0.016, Epoch accuracy:98.53%, Validation loss:2.110, Validation accuracy:61.90%
# Epoch 241: iteration 77/78
# Epoch 241 --- loss:0.072, Epoch accuracy:96.47%, Validation loss:2.158, Validation accuracy:59.37%
# Epoch 242: iteration 77/78
# Epoch 242 --- loss:0.037, Epoch accuracy:98.06%, Validation loss:1.834, Validation accuracy:66.03%
# Epoch 243: iteration 77/78
# Epoch 243 --- loss:0.022, Epoch accuracy:98.45%, Validation loss:1.862, Validation accuracy:66.35%
# Epoch 244: iteration 77/78
# Epoch 244 --- loss:0.016, Epoch accuracy:98.69%, Validation loss:1.730, Validation accuracy:68.57%
# Epoch 245: iteration 77/78
# Epoch 245 --- loss:0.013, Epoch accuracy:98.85%, Validation loss:1.729, Validation accuracy:66.98%
# Epoch 246: iteration 77/78
# Epoch 246 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:1.722, Validation accuracy:63.81%
# Epoch 247: iteration 77/78
# Epoch 247 --- loss:0.026, Epoch accuracy:98.22%, Validation loss:1.994, Validation accuracy:63.49%
# Epoch 248: iteration 77/78
# Epoch 248 --- loss:0.023, Epoch accuracy:98.41%, Validation loss:1.903, Validation accuracy:63.49%
# Epoch 249: iteration 77/78
# Epoch 249 --- loss:0.025, Epoch accuracy:98.18%, Validation loss:1.932, Validation accuracy:65.08%
# Epoch 250: iteration 77/78
# Epoch 250 --- loss:0.016, Epoch accuracy:98.65%, Validation loss:1.774, Validation accuracy:68.57%
# Epoch 251: iteration 77/78
# Epoch 251 --- loss:0.015, Epoch accuracy:98.61%, Validation loss:1.818, Validation accuracy:66.03%
# Epoch 252: iteration 77/78
# Epoch 252 --- loss:0.010, Epoch accuracy:98.89%, Validation loss:1.820, Validation accuracy:66.03%
# Epoch 253: iteration 77/78
# Epoch 253 --- loss:0.012, Epoch accuracy:98.73%, Validation loss:1.952, Validation accuracy:65.08%
# Epoch 254: iteration 77/78
# Epoch 254 --- loss:0.049, Epoch accuracy:97.15%, Validation loss:1.992, Validation accuracy:62.54%
# Epoch 255: iteration 77/78
# Epoch 255 --- loss:0.078, Epoch accuracy:96.04%, Validation loss:1.943, Validation accuracy:64.13%
# Epoch 256: iteration 77/78
# Epoch 256 --- loss:0.046, Epoch accuracy:97.46%, Validation loss:2.067, Validation accuracy:64.44%
# Epoch 257: iteration 77/78
# Epoch 257 --- loss:0.020, Epoch accuracy:98.49%, Validation loss:1.823, Validation accuracy:64.44%
# Epoch 258: iteration 77/78
# Epoch 258 --- loss:0.042, Epoch accuracy:97.50%, Validation loss:1.714, Validation accuracy:65.08%
# Epoch 259: iteration 77/78
# Epoch 259 --- loss:0.077, Epoch accuracy:96.51%, Validation loss:1.867, Validation accuracy:66.98%
# Epoch 260: iteration 77/78
# Epoch 260 --- loss:0.036, Epoch accuracy:97.90%, Validation loss:1.716, Validation accuracy:64.13%
# Epoch 261: iteration 77/78
# Epoch 261 --- loss:0.018, Epoch accuracy:98.73%, Validation loss:1.803, Validation accuracy:66.67%
# Epoch 262: iteration 77/78
# Epoch 262 --- loss:0.017, Epoch accuracy:98.57%, Validation loss:1.784, Validation accuracy:67.62%
# Epoch 263: iteration 77/78
# Epoch 263 --- loss:0.027, Epoch accuracy:98.18%, Validation loss:1.809, Validation accuracy:66.98%
# Epoch 264: iteration 77/78
# Epoch 264 --- loss:0.018, Epoch accuracy:98.49%, Validation loss:1.813, Validation accuracy:65.08%
# Epoch 265: iteration 77/78
# Epoch 265 --- loss:0.011, Epoch accuracy:98.81%, Validation loss:1.813, Validation accuracy:65.08%
# Epoch 266: iteration 77/78
# Epoch 266 --- loss:0.008, Epoch accuracy:98.89%, Validation loss:1.745, Validation accuracy:67.30%
# Epoch 267: iteration 77/78
# Epoch 267 --- loss:0.009, Epoch accuracy:98.93%, Validation loss:1.784, Validation accuracy:66.35%
# Epoch 268: iteration 77/78
# Epoch 268 --- loss:0.019, Epoch accuracy:98.53%, Validation loss:1.982, Validation accuracy:65.40%
# Epoch 269: iteration 77/78
# Epoch 269 --- loss:0.068, Epoch accuracy:96.55%, Validation loss:2.151, Validation accuracy:63.49%
# Epoch 270: iteration 77/78
# Epoch 270 --- loss:0.031, Epoch accuracy:98.30%, Validation loss:1.617, Validation accuracy:67.94%
# Epoch 271: iteration 77/78
# Epoch 271 --- loss:0.023, Epoch accuracy:98.34%, Validation loss:1.828, Validation accuracy:63.81%
# Epoch 272: iteration 77/78
# Epoch 272 --- loss:0.015, Epoch accuracy:98.77%, Validation loss:1.784, Validation accuracy:66.98%
# Epoch 273: iteration 77/78
# Epoch 273 --- loss:0.012, Epoch accuracy:98.81%, Validation loss:1.833, Validation accuracy:66.67%
# Epoch 274: iteration 77/78
# Epoch 274 --- loss:0.010, Epoch accuracy:98.85%, Validation loss:1.835, Validation accuracy:65.08%
# Epoch 275: iteration 77/78
# Epoch 275 --- loss:0.010, Epoch accuracy:98.77%, Validation loss:1.801, Validation accuracy:65.40%
# Epoch 276: iteration 77/78
# Epoch 276 --- loss:0.016, Epoch accuracy:98.65%, Validation loss:1.882, Validation accuracy:64.76%
# Epoch 277: iteration 77/78
# Epoch 277 --- loss:0.021, Epoch accuracy:98.45%, Validation loss:1.888, Validation accuracy:63.81%
# Epoch 278: iteration 77/78
# Epoch 278 --- loss:0.010, Epoch accuracy:98.89%, Validation loss:1.772, Validation accuracy:66.67%
# Epoch 279: iteration 77/78
# Epoch 279 --- loss:0.014, Epoch accuracy:98.61%, Validation loss:1.747, Validation accuracy:66.35%
# Epoch 280: iteration 77/78
# Epoch 280 --- loss:0.026, Epoch accuracy:98.26%, Validation loss:1.709, Validation accuracy:67.62%
# Epoch 281: iteration 77/78
# Epoch 281 --- loss:0.010, Epoch accuracy:98.81%, Validation loss:1.890, Validation accuracy:68.89%
# Epoch 282: iteration 77/78
# Epoch 282 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:1.765, Validation accuracy:66.98%
# Epoch 283: iteration 77/78
# Epoch 283 --- loss:0.009, Epoch accuracy:98.89%, Validation loss:1.772, Validation accuracy:68.25%
# Epoch 284: iteration 77/78
# Epoch 284 --- loss:0.008, Epoch accuracy:98.81%, Validation loss:1.777, Validation accuracy:65.40%
# Epoch 285: iteration 77/78
# Epoch 285 --- loss:0.007, Epoch accuracy:98.93%, Validation loss:1.881, Validation accuracy:66.67%
# Epoch 286: iteration 77/78
# Epoch 286 --- loss:0.008, Epoch accuracy:98.93%, Validation loss:1.776, Validation accuracy:66.98%
# Epoch 287: iteration 77/78
# Epoch 287 --- loss:0.007, Epoch accuracy:98.89%, Validation loss:1.843, Validation accuracy:66.98%
# Epoch 288: iteration 77/78
# Epoch 288 --- loss:0.019, Epoch accuracy:98.53%, Validation loss:1.871, Validation accuracy:66.98%
# Epoch 289: iteration 77/78
# Epoch 289 --- loss:0.018, Epoch accuracy:98.41%, Validation loss:1.857, Validation accuracy:66.98%
# Epoch 290: iteration 77/78
# Epoch 290 --- loss:0.042, Epoch accuracy:97.98%, Validation loss:1.823, Validation accuracy:66.67%
# Epoch 291: iteration 77/78
# Epoch 291 --- loss:0.045, Epoch accuracy:97.70%, Validation loss:1.965, Validation accuracy:63.81%
# Epoch 292: iteration 77/78
# Epoch 292 --- loss:0.024, Epoch accuracy:98.41%, Validation loss:2.067, Validation accuracy:64.76%
# Epoch 293: iteration 77/78
# Epoch 293 --- loss:0.023, Epoch accuracy:98.41%, Validation loss:1.884, Validation accuracy:65.08%
# Epoch 294: iteration 77/78
# Epoch 294 --- loss:0.043, Epoch accuracy:97.46%, Validation loss:1.951, Validation accuracy:66.35%
# Epoch 295: iteration 77/78
# Epoch 295 --- loss:0.039, Epoch accuracy:97.74%, Validation loss:1.821, Validation accuracy:64.76%
# Epoch 296: iteration 77/78
# Epoch 296 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:1.817, Validation accuracy:63.81%
# Epoch 297: iteration 77/78
# Epoch 297 --- loss:0.013, Epoch accuracy:98.69%, Validation loss:1.736, Validation accuracy:67.94%
# Epoch 298: iteration 77/78
# Epoch 298 --- loss:0.019, Epoch accuracy:98.49%, Validation loss:1.790, Validation accuracy:66.98%
# Epoch 299: iteration 77/78
# Epoch 299 --- loss:0.018, Epoch accuracy:98.53%, Validation loss:1.726, Validation accuracy:67.94%
# Epoch 300: iteration 77/78
# Epoch 300 --- loss:0.036, Epoch accuracy:97.86%, Validation loss:1.994, Validation accuracy:63.81%
# Epoch 301: iteration 77/78
# Epoch 301 --- loss:0.080, Epoch accuracy:96.04%, Validation loss:2.188, Validation accuracy:63.81%
# Epoch 302: iteration 77/78
# Epoch 302 --- loss:0.063, Epoch accuracy:96.67%, Validation loss:1.810, Validation accuracy:65.40%
# Epoch 303: iteration 77/78
# Epoch 303 --- loss:0.029, Epoch accuracy:98.26%, Validation loss:1.780, Validation accuracy:66.67%
# Epoch 304: iteration 77/78
# Epoch 304 --- loss:0.017, Epoch accuracy:98.61%, Validation loss:1.725, Validation accuracy:66.67%
# Epoch 305: iteration 77/78
# Epoch 305 --- loss:0.033, Epoch accuracy:97.90%, Validation loss:1.723, Validation accuracy:67.62%
# Epoch 306: iteration 77/78
# Epoch 306 --- loss:0.019, Epoch accuracy:98.45%, Validation loss:1.721, Validation accuracy:67.94%
# Epoch 307: iteration 77/78
# Epoch 307 --- loss:0.015, Epoch accuracy:98.61%, Validation loss:1.723, Validation accuracy:66.98%
# Epoch 308: iteration 77/78
# Epoch 308 --- loss:0.030, Epoch accuracy:97.98%, Validation loss:1.864, Validation accuracy:65.40%
# Epoch 309: iteration 77/78
# Epoch 309 --- loss:0.014, Epoch accuracy:98.73%, Validation loss:1.956, Validation accuracy:65.08%
# Epoch 310: iteration 77/78
# Epoch 310 --- loss:0.012, Epoch accuracy:98.81%, Validation loss:1.809, Validation accuracy:68.57%
# Epoch 311: iteration 77/78
# Epoch 311 --- loss:0.011, Epoch accuracy:98.81%, Validation loss:1.964, Validation accuracy:67.62%
# Epoch 312: iteration 77/78
# Epoch 312 --- loss:0.011, Epoch accuracy:98.73%, Validation loss:1.856, Validation accuracy:67.30%
# Epoch 313: iteration 77/78
# Epoch 313 --- loss:0.023, Epoch accuracy:98.18%, Validation loss:1.769, Validation accuracy:66.03%
# Epoch 314: iteration 77/78
# Epoch 314 --- loss:0.013, Epoch accuracy:98.73%, Validation loss:1.749, Validation accuracy:66.67%
# Epoch 315: iteration 77/78
# Epoch 315 --- loss:0.009, Epoch accuracy:98.89%, Validation loss:1.806, Validation accuracy:64.76%
# Epoch 316: iteration 77/78
# Epoch 316 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:1.777, Validation accuracy:66.98%
# Epoch 317: iteration 77/78
# Epoch 317 --- loss:0.009, Epoch accuracy:98.81%, Validation loss:1.862, Validation accuracy:65.40%
# Epoch 318: iteration 77/78
# Epoch 318 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:1.779, Validation accuracy:65.40%
# Epoch 319: iteration 77/78
# Epoch 319 --- loss:0.009, Epoch accuracy:98.89%, Validation loss:1.907, Validation accuracy:66.35%
# Epoch 320: iteration 77/78
# Epoch 320 --- loss:0.077, Epoch accuracy:96.63%, Validation loss:2.527, Validation accuracy:56.51%
# Epoch 321: iteration 77/78
# Epoch 321 --- loss:0.143, Epoch accuracy:93.50%, Validation loss:1.837, Validation accuracy:68.25%
# Epoch 322: iteration 77/78
# Epoch 322 --- loss:0.051, Epoch accuracy:97.19%, Validation loss:1.793, Validation accuracy:66.03%
# Epoch 323: iteration 77/78
# Epoch 323 --- loss:0.025, Epoch accuracy:98.49%, Validation loss:1.681, Validation accuracy:66.35%
# Epoch 324: iteration 77/78
# Epoch 324 --- loss:0.018, Epoch accuracy:98.57%, Validation loss:1.960, Validation accuracy:62.54%
# Epoch 325: iteration 77/78
# Epoch 325 --- loss:0.025, Epoch accuracy:98.26%, Validation loss:1.734, Validation accuracy:65.40%
# Epoch 326: iteration 77/78
# Epoch 326 --- loss:0.027, Epoch accuracy:98.14%, Validation loss:1.922, Validation accuracy:66.67%
# Epoch 327: iteration 77/78
# Epoch 327 --- loss:0.013, Epoch accuracy:98.81%, Validation loss:1.840, Validation accuracy:66.98%
# Epoch 328: iteration 77/78
# Epoch 328 --- loss:0.010, Epoch accuracy:98.81%, Validation loss:1.663, Validation accuracy:66.98%
# Epoch 329: iteration 77/78
# Epoch 329 --- loss:0.015, Epoch accuracy:98.57%, Validation loss:1.760, Validation accuracy:66.35%
# Epoch 330: iteration 77/78
# Epoch 330 --- loss:0.012, Epoch accuracy:98.73%, Validation loss:1.752, Validation accuracy:65.71%
# Epoch 331: iteration 77/78
# Epoch 331 --- loss:0.012, Epoch accuracy:98.73%, Validation loss:1.886, Validation accuracy:63.81%
# Epoch 332: iteration 77/78
# Epoch 332 --- loss:0.008, Epoch accuracy:98.89%, Validation loss:1.758, Validation accuracy:65.71%
# Epoch 333: iteration 77/78
# Epoch 333 --- loss:0.008, Epoch accuracy:98.89%, Validation loss:1.755, Validation accuracy:66.98%
# Epoch 334: iteration 77/78
# Epoch 334 --- loss:0.008, Epoch accuracy:98.93%, Validation loss:1.747, Validation accuracy:65.08%
# Epoch 335: iteration 77/78
# Epoch 335 --- loss:0.009, Epoch accuracy:98.85%, Validation loss:1.805, Validation accuracy:65.08%
# Epoch 336: iteration 77/78
# Epoch 336 --- loss:0.010, Epoch accuracy:98.81%, Validation loss:1.698, Validation accuracy:66.98%
# Epoch 337: iteration 77/78
# Epoch 337 --- loss:0.006, Epoch accuracy:98.93%, Validation loss:1.739, Validation accuracy:67.94%
# Epoch 338: iteration 77/78
# Epoch 338 --- loss:0.009, Epoch accuracy:98.85%, Validation loss:1.786, Validation accuracy:67.62%
# Epoch 339: iteration 77/78
# Epoch 339 --- loss:0.007, Epoch accuracy:98.93%, Validation loss:1.808, Validation accuracy:66.98%
# Epoch 340: iteration 77/78
# Epoch 340 --- loss:0.008, Epoch accuracy:98.85%, Validation loss:1.754, Validation accuracy:67.62%
# Epoch 341: iteration 77/78
# Epoch 341 --- loss:0.021, Epoch accuracy:98.41%, Validation loss:1.918, Validation accuracy:64.13%
# Epoch 342: iteration 77/78
# Epoch 342 --- loss:0.226, Epoch accuracy:91.87%, Validation loss:1.699, Validation accuracy:65.08%
# Epoch 343: iteration 77/78
# Epoch 343 --- loss:0.055, Epoch accuracy:97.15%, Validation loss:1.738, Validation accuracy:66.35%
# Epoch 344: iteration 77/78
# Epoch 344 --- loss:0.023, Epoch accuracy:98.65%, Validation loss:1.795, Validation accuracy:64.44%
# Epoch 345: iteration 77/78
# Epoch 345 --- loss:0.018, Epoch accuracy:98.69%, Validation loss:1.719, Validation accuracy:68.89%
# Epoch 346: iteration 77/78
# Epoch 346 --- loss:0.016, Epoch accuracy:98.69%, Validation loss:1.696, Validation accuracy:66.03%
# Epoch 347: iteration 77/78
# Epoch 347 --- loss:0.011, Epoch accuracy:98.85%, Validation loss:1.681, Validation accuracy:64.76%
# Epoch 348: iteration 77/78
# Epoch 348 --- loss:0.012, Epoch accuracy:98.81%, Validation loss:1.828, Validation accuracy:64.76%
# Epoch 349: iteration 77/78
# Epoch 349 --- loss:0.045, Epoch accuracy:97.46%, Validation loss:1.891, Validation accuracy:63.49%
# Epoch 350: iteration 77/78
# Epoch 350 --- loss:0.027, Epoch accuracy:98.30%, Validation loss:1.759, Validation accuracy:65.40%
# Epoch 351: iteration 77/78
# Epoch 351 --- loss:0.021, Epoch accuracy:98.45%, Validation loss:1.776, Validation accuracy:64.13%
# Epoch 352: iteration 77/78
# Epoch 352 --- loss:0.018, Epoch accuracy:98.61%, Validation loss:1.899, Validation accuracy:66.35%
# Epoch 353: iteration 77/78
# Epoch 353 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:1.869, Validation accuracy:66.98%
# Epoch 354: iteration 77/78
# Epoch 354 --- loss:0.007, Epoch accuracy:98.93%, Validation loss:1.708, Validation accuracy:68.25%
# Epoch 355: iteration 77/78
# Epoch 355 --- loss:0.006, Epoch accuracy:98.93%, Validation loss:1.663, Validation accuracy:67.30%
# Epoch 356: iteration 77/78
# Epoch 356 --- loss:0.009, Epoch accuracy:98.81%, Validation loss:1.691, Validation accuracy:65.71%
# Epoch 357: iteration 77/78
# Epoch 357 --- loss:0.026, Epoch accuracy:98.22%, Validation loss:1.647, Validation accuracy:68.89%
# Epoch 358: iteration 77/78
# Epoch 358 --- loss:0.009, Epoch accuracy:98.85%, Validation loss:2.156, Validation accuracy:62.86%
# Epoch 359: iteration 77/78
# Epoch 359 --- loss:0.032, Epoch accuracy:97.98%, Validation loss:1.747, Validation accuracy:64.44%
# Epoch 360: iteration 77/78
# Epoch 360 --- loss:0.040, Epoch accuracy:97.70%, Validation loss:1.853, Validation accuracy:62.22%
# Epoch 361: iteration 77/78
# Epoch 361 --- loss:0.087, Epoch accuracy:95.88%, Validation loss:1.718, Validation accuracy:65.71%
# Epoch 362: iteration 77/78
# Epoch 362 --- loss:0.016, Epoch accuracy:98.77%, Validation loss:1.634, Validation accuracy:67.62%
# Epoch 363: iteration 77/78
# Epoch 363 --- loss:0.010, Epoch accuracy:98.81%, Validation loss:1.642, Validation accuracy:68.57%
# Epoch 364: iteration 77/78
# Epoch 364 --- loss:0.007, Epoch accuracy:98.93%, Validation loss:1.614, Validation accuracy:68.57%
# Epoch 365: iteration 77/78
# Epoch 365 --- loss:0.009, Epoch accuracy:98.81%, Validation loss:1.719, Validation accuracy:66.03%
# Epoch 366: iteration 77/78
# Epoch 366 --- loss:0.008, Epoch accuracy:98.85%, Validation loss:1.723, Validation accuracy:67.94%
# Epoch 367: iteration 77/78
# Epoch 367 --- loss:0.006, Epoch accuracy:98.93%, Validation loss:1.703, Validation accuracy:67.62%
# Epoch 368: iteration 77/78
# Epoch 368 --- loss:0.007, Epoch accuracy:98.89%, Validation loss:1.804, Validation accuracy:66.67%
# Epoch 369: iteration 77/78
# Epoch 369 --- loss:0.008, Epoch accuracy:98.85%, Validation loss:1.700, Validation accuracy:66.67%
# Epoch 370: iteration 77/78
# Epoch 370 --- loss:0.005, Epoch accuracy:98.93%, Validation loss:1.670, Validation accuracy:68.25%
# Epoch 371: iteration 77/78
# Epoch 371 --- loss:0.005, Epoch accuracy:98.93%, Validation loss:1.772, Validation accuracy:66.98%
# Epoch 372: iteration 77/78
# Epoch 372 --- loss:0.008, Epoch accuracy:98.89%, Validation loss:1.768, Validation accuracy:68.89%
# Epoch 373: iteration 77/78
# Epoch 373 --- loss:0.007, Epoch accuracy:98.89%, Validation loss:1.737, Validation accuracy:67.94%
# Epoch 374: iteration 77/78
# Epoch 374 --- loss:0.006, Epoch accuracy:98.89%, Validation loss:1.743, Validation accuracy:68.89%
# Epoch 375: iteration 77/78
# Epoch 375 --- loss:0.005, Epoch accuracy:98.93%, Validation loss:1.701, Validation accuracy:68.25%
# Epoch 376: iteration 77/78
# Epoch 376 --- loss:0.060, Epoch accuracy:96.75%, Validation loss:1.908, Validation accuracy:66.98%
# Epoch 377: iteration 77/78
# Epoch 377 --- loss:0.046, Epoch accuracy:97.42%, Validation loss:2.053, Validation accuracy:62.22%
# Epoch 378: iteration 77/78
# Epoch 378 --- loss:0.053, Epoch accuracy:96.87%, Validation loss:1.827, Validation accuracy:67.94%
# Epoch 379: iteration 77/78
# Epoch 379 --- loss:0.066, Epoch accuracy:96.43%, Validation loss:1.863, Validation accuracy:62.54%
# Epoch 380: iteration 77/78
# Epoch 380 --- loss:0.102, Epoch accuracy:95.44%, Validation loss:2.084, Validation accuracy:61.59%
# Epoch 381: iteration 77/78
# Epoch 381 --- loss:0.051, Epoch accuracy:97.34%, Validation loss:1.744, Validation accuracy:65.08%
# Epoch 382: iteration 77/78
# Epoch 382 --- loss:0.023, Epoch accuracy:98.57%, Validation loss:1.781, Validation accuracy:65.40%
# Epoch 383: iteration 77/78
# Epoch 383 --- loss:0.028, Epoch accuracy:98.02%, Validation loss:1.791, Validation accuracy:65.40%
# Epoch 384: iteration 77/78
# Epoch 384 --- loss:0.027, Epoch accuracy:98.30%, Validation loss:1.721, Validation accuracy:65.71%
# Epoch 385: iteration 77/78
# Epoch 385 --- loss:0.017, Epoch accuracy:98.49%, Validation loss:1.836, Validation accuracy:65.71%
# Epoch 386: iteration 77/78
# Epoch 386 --- loss:0.028, Epoch accuracy:98.34%, Validation loss:1.963, Validation accuracy:62.86%
# Epoch 387: iteration 77/78
# Epoch 387 --- loss:0.067, Epoch accuracy:96.59%, Validation loss:1.652, Validation accuracy:68.25%
# Epoch 388: iteration 77/78
# Epoch 388 --- loss:0.032, Epoch accuracy:98.02%, Validation loss:1.861, Validation accuracy:66.67%
# Epoch 389: iteration 77/78
# Epoch 389 --- loss:0.019, Epoch accuracy:98.61%, Validation loss:1.793, Validation accuracy:68.25%
# Epoch 390: iteration 77/78
# Epoch 390 --- loss:0.014, Epoch accuracy:98.77%, Validation loss:1.693, Validation accuracy:68.25%
# Epoch 391: iteration 77/78
# Epoch 391 --- loss:0.018, Epoch accuracy:98.53%, Validation loss:1.735, Validation accuracy:66.35%
# Epoch 392: iteration 77/78
# Epoch 392 --- loss:0.011, Epoch accuracy:98.89%, Validation loss:1.776, Validation accuracy:66.35%
# Epoch 393: iteration 77/78
# Epoch 393 --- loss:0.007, Epoch accuracy:98.89%, Validation loss:1.742, Validation accuracy:67.94%
# Epoch 394: iteration 77/78
# Epoch 394 --- loss:0.014, Epoch accuracy:98.69%, Validation loss:1.870, Validation accuracy:67.94%
# Epoch 395: iteration 77/78
# Epoch 395 --- loss:0.007, Epoch accuracy:98.89%, Validation loss:1.780, Validation accuracy:67.62%
# Epoch 396: iteration 77/78
# Epoch 396 --- loss:0.006, Epoch accuracy:98.93%, Validation loss:1.771, Validation accuracy:67.94%
# Epoch 397: iteration 77/78
# Epoch 397 --- loss:0.006, Epoch accuracy:98.93%, Validation loss:1.807, Validation accuracy:68.57%
# Epoch 398: iteration 77/78
# Epoch 398 --- loss:0.008, Epoch accuracy:98.89%, Validation loss:1.822, Validation accuracy:69.21%
# Epoch 399: iteration 77/78
# Epoch 399 --- loss:0.005, Epoch accuracy:98.93%, Validation loss:1.701, Validation accuracy:69.52%
# Epoch 400: iteration 77/78
# Epoch 400 --- loss:0.008, Epoch accuracy:98.85%, Validation loss:1.800, Validation accuracy:68.25%
# Epoch 401: iteration 77/78
# Epoch 401 --- loss:0.006, Epoch accuracy:98.89%, Validation loss:1.748, Validation accuracy:67.62%
# Epoch 402: iteration 77/78
# Epoch 402 --- loss:0.005, Epoch accuracy:98.93%, Validation loss:1.795, Validation accuracy:67.94%
# Epoch 403: iteration 77/78
# Epoch 403 --- loss:0.005, Epoch accuracy:98.93%, Validation loss:1.799, Validation accuracy:67.30%
# Epoch 404: iteration 77/78
# Epoch 404 --- loss:0.007, Epoch accuracy:98.85%, Validation loss:1.705, Validation accuracy:68.25%
# Epoch 405: iteration 77/78
# Epoch 405 --- loss:0.007, Epoch accuracy:98.93%, Validation loss:1.767, Validation accuracy:66.67%
# Epoch 406: iteration 77/78
# Epoch 406 --- loss:0.005, Epoch accuracy:98.93%, Validation loss:1.765, Validation accuracy:68.25%
# Epoch 407: iteration 77/78
# Epoch 407 --- loss:0.006, Epoch accuracy:98.85%, Validation loss:1.716, Validation accuracy:68.25%
# Epoch 408: iteration 77/78
# Epoch 408 --- loss:0.006, Epoch accuracy:98.89%, Validation loss:1.727, Validation accuracy:66.98%
# Epoch 409: iteration 77/78
# Epoch 409 --- loss:0.085, Epoch accuracy:95.92%, Validation loss:1.936, Validation accuracy:63.49%
# Epoch 410: iteration 77/78
# Epoch 410 --- loss:0.084, Epoch accuracy:96.27%, Validation loss:1.722, Validation accuracy:64.76%
# Epoch 411: iteration 77/78
# Epoch 411 --- loss:0.036, Epoch accuracy:97.86%, Validation loss:1.842, Validation accuracy:66.35%
# Epoch 412: iteration 77/78
# Epoch 412 --- loss:0.015, Epoch accuracy:98.81%, Validation loss:1.726, Validation accuracy:65.71%
# Epoch 413: iteration 77/78
# Epoch 413 --- loss:0.018, Epoch accuracy:98.45%, Validation loss:1.715, Validation accuracy:69.21%
# Epoch 414: iteration 77/78
# Epoch 414 --- loss:0.010, Epoch accuracy:98.85%, Validation loss:1.778, Validation accuracy:67.30%
# Epoch 415: iteration 77/78
# Epoch 415 --- loss:0.007, Epoch accuracy:98.93%, Validation loss:1.800, Validation accuracy:65.08%
# Epoch 416: iteration 77/78
# Epoch 416 --- loss:0.036, Epoch accuracy:97.98%, Validation loss:1.741, Validation accuracy:65.40%
# Epoch 417: iteration 77/78
# Epoch 417 --- loss:0.011, Epoch accuracy:98.85%, Validation loss:1.736, Validation accuracy:66.35%
# Epoch 418: iteration 77/78
# Epoch 418 --- loss:0.016, Epoch accuracy:98.61%, Validation loss:1.766, Validation accuracy:68.25%
# Epoch 419: iteration 77/78
# Epoch 419 --- loss:0.012, Epoch accuracy:98.81%, Validation loss:1.660, Validation accuracy:66.67%
# Epoch 420: iteration 77/78
# Epoch 420 --- loss:0.015, Epoch accuracy:98.57%, Validation loss:1.851, Validation accuracy:65.40%
# Epoch 421: iteration 77/78
# Epoch 421 --- loss:0.012, Epoch accuracy:98.73%, Validation loss:1.727, Validation accuracy:68.25%
# Epoch 422: iteration 77/78
# Epoch 422 --- loss:0.016, Epoch accuracy:98.57%, Validation loss:1.721, Validation accuracy:67.94%
# Epoch 423: iteration 77/78
# Epoch 423 --- loss:0.060, Epoch accuracy:96.95%, Validation loss:2.287, Validation accuracy:61.90%
# Epoch 424: iteration 77/78
# Epoch 424 --- loss:0.107, Epoch accuracy:94.97%, Validation loss:1.726, Validation accuracy:64.76%
# Epoch 425: iteration 77/78
# Epoch 425 --- loss:0.037, Epoch accuracy:97.86%, Validation loss:1.670, Validation accuracy:63.17%
# Epoch 426: iteration 77/78
# Epoch 426 --- loss:0.024, Epoch accuracy:98.34%, Validation loss:1.801, Validation accuracy:66.98%
# Epoch 427: iteration 77/78
# Epoch 427 --- loss:0.025, Epoch accuracy:98.26%, Validation loss:1.669, Validation accuracy:68.89%
# Epoch 428: iteration 77/78
# Epoch 428 --- loss:0.049, Epoch accuracy:97.07%, Validation loss:1.748, Validation accuracy:65.08%
# Epoch 429: iteration 77/78
# Epoch 429 --- loss:0.075, Epoch accuracy:96.31%, Validation loss:1.803, Validation accuracy:65.40%
# Epoch 430: iteration 77/78
# Epoch 430 --- loss:0.061, Epoch accuracy:96.51%, Validation loss:1.622, Validation accuracy:67.94%
# Epoch 431: iteration 77/78
# Epoch 431 --- loss:0.040, Epoch accuracy:97.74%, Validation loss:1.682, Validation accuracy:69.84%
# Epoch 432: iteration 77/78
# Epoch 432 --- loss:0.021, Epoch accuracy:98.49%, Validation loss:1.635, Validation accuracy:66.03%
# Epoch 433: iteration 77/78
# Epoch 433 --- loss:0.013, Epoch accuracy:98.77%, Validation loss:1.820, Validation accuracy:64.13%
# Epoch 434: iteration 77/78
# Epoch 434 --- loss:0.013, Epoch accuracy:98.69%, Validation loss:1.753, Validation accuracy:66.35%
# Epoch 435: iteration 77/78
# Epoch 435 --- loss:0.009, Epoch accuracy:98.81%, Validation loss:1.672, Validation accuracy:68.25%
# Epoch 436: iteration 77/78
# Epoch 436 --- loss:0.007, Epoch accuracy:98.93%, Validation loss:1.663, Validation accuracy:68.89%
# Epoch 437: iteration 77/78
# Epoch 437 --- loss:0.008, Epoch accuracy:98.89%, Validation loss:1.624, Validation accuracy:71.11%
# Epoch 438: iteration 77/78
# Epoch 438 --- loss:0.006, Epoch accuracy:98.93%, Validation loss:1.651, Validation accuracy:68.25%
# Epoch 439: iteration 77/78
# Epoch 439 --- loss:0.005, Epoch accuracy:98.93%, Validation loss:1.663, Validation accuracy:68.89%
# Epoch 440: iteration 77/78
# Epoch 440 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:1.595, Validation accuracy:69.84%
# Epoch 441: iteration 77/78
# Epoch 441 --- loss:0.008, Epoch accuracy:98.85%, Validation loss:1.729, Validation accuracy:68.57%
# Epoch 442: iteration 77/78
# Epoch 442 --- loss:0.007, Epoch accuracy:98.93%, Validation loss:1.722, Validation accuracy:68.25%
# Epoch 443: iteration 77/78
# Epoch 443 --- loss:0.008, Epoch accuracy:98.89%, Validation loss:1.708, Validation accuracy:66.98%
# Epoch 444: iteration 77/78
# Epoch 444 --- loss:0.026, Epoch accuracy:98.02%, Validation loss:1.962, Validation accuracy:61.90%
# Epoch 445: iteration 77/78
# Epoch 445 --- loss:0.022, Epoch accuracy:98.49%, Validation loss:1.687, Validation accuracy:66.35%
# Epoch 446: iteration 77/78
# Epoch 446 --- loss:0.032, Epoch accuracy:97.90%, Validation loss:1.906, Validation accuracy:62.86%
# Epoch 447: iteration 77/78
# Epoch 447 --- loss:0.009, Epoch accuracy:98.89%, Validation loss:1.834, Validation accuracy:65.40%
# Epoch 448: iteration 77/78
# Epoch 448 --- loss:0.123, Epoch accuracy:95.16%, Validation loss:1.894, Validation accuracy:60.63%
# Epoch 449: iteration 77/78
# Epoch 449 --- loss:0.134, Epoch accuracy:94.33%, Validation loss:1.659, Validation accuracy:66.35%
# Epoch 450: iteration 77/78
# Epoch 450 --- loss:0.026, Epoch accuracy:98.49%, Validation loss:1.799, Validation accuracy:64.13%
# Epoch 451: iteration 77/78
# Epoch 451 --- loss:0.023, Epoch accuracy:98.34%, Validation loss:1.570, Validation accuracy:68.89%
# Epoch 452: iteration 77/78
# Epoch 452 --- loss:0.038, Epoch accuracy:97.78%, Validation loss:1.702, Validation accuracy:66.03%
# Epoch 453: iteration 77/78
# Epoch 453 --- loss:0.016, Epoch accuracy:98.73%, Validation loss:1.580, Validation accuracy:69.52%
# Epoch 454: iteration 77/78
# Epoch 454 --- loss:0.013, Epoch accuracy:98.81%, Validation loss:1.592, Validation accuracy:68.57%
# Epoch 455: iteration 77/78
# Epoch 455 --- loss:0.017, Epoch accuracy:98.53%, Validation loss:1.681, Validation accuracy:67.30%
# Epoch 456: iteration 77/78
# Epoch 456 --- loss:0.022, Epoch accuracy:98.41%, Validation loss:1.685, Validation accuracy:68.89%
# Epoch 457: iteration 77/78
# Epoch 457 --- loss:0.008, Epoch accuracy:98.93%, Validation loss:1.593, Validation accuracy:69.21%
# Epoch 458: iteration 77/78
# Epoch 458 --- loss:0.010, Epoch accuracy:98.81%, Validation loss:1.664, Validation accuracy:68.25%
# Epoch 459: iteration 77/78
# Epoch 459 --- loss:0.012, Epoch accuracy:98.81%, Validation loss:1.766, Validation accuracy:67.30%
# Epoch 460: iteration 77/78
# Epoch 460 --- loss:0.007, Epoch accuracy:98.93%, Validation loss:1.645, Validation accuracy:70.48%
# Epoch 461: iteration 77/78
# Epoch 461 --- loss:0.012, Epoch accuracy:98.73%, Validation loss:1.622, Validation accuracy:67.94%
# Epoch 462: iteration 77/78
# Epoch 462 --- loss:0.007, Epoch accuracy:98.89%, Validation loss:1.704, Validation accuracy:66.98%
# Epoch 463: iteration 77/78
# Epoch 463 --- loss:0.007, Epoch accuracy:98.89%, Validation loss:1.679, Validation accuracy:69.52%
# Epoch 464: iteration 77/78
# Epoch 464 --- loss:0.008, Epoch accuracy:98.89%, Validation loss:1.680, Validation accuracy:69.52%
# Epoch 465: iteration 77/78
# Epoch 465 --- loss:0.011, Epoch accuracy:98.69%, Validation loss:1.755, Validation accuracy:68.57%
# Epoch 466: iteration 77/78
# Epoch 466 --- loss:0.007, Epoch accuracy:98.85%, Validation loss:1.971, Validation accuracy:63.49%
# Epoch 467: iteration 77/78
# Epoch 467 --- loss:0.082, Epoch accuracy:95.80%, Validation loss:1.729, Validation accuracy:67.30%
# Epoch 468: iteration 77/78
# Epoch 468 --- loss:0.058, Epoch accuracy:97.07%, Validation loss:1.579, Validation accuracy:68.89%
# Epoch 469: iteration 77/78
# Epoch 469 --- loss:0.013, Epoch accuracy:98.85%, Validation loss:1.636, Validation accuracy:66.03%
# Epoch 470: iteration 77/78
# Epoch 470 --- loss:0.009, Epoch accuracy:98.85%, Validation loss:1.644, Validation accuracy:66.98%
# Epoch 471: iteration 77/78
# Epoch 471 --- loss:0.009, Epoch accuracy:98.89%, Validation loss:1.610, Validation accuracy:69.52%
# Epoch 472: iteration 77/78
# Epoch 472 --- loss:0.009, Epoch accuracy:98.85%, Validation loss:1.577, Validation accuracy:68.57%
# Epoch 473: iteration 77/78
# Epoch 473 --- loss:0.011, Epoch accuracy:98.85%, Validation loss:1.680, Validation accuracy:68.57%
# Epoch 474: iteration 77/78
# Epoch 474 --- loss:0.008, Epoch accuracy:98.89%, Validation loss:1.609, Validation accuracy:68.89%
# Epoch 475: iteration 77/78
# Epoch 475 --- loss:0.010, Epoch accuracy:98.81%, Validation loss:1.639, Validation accuracy:68.25%
# Epoch 476: iteration 77/78
# Epoch 476 --- loss:0.006, Epoch accuracy:98.89%, Validation loss:1.575, Validation accuracy:69.21%
# Epoch 477: iteration 77/78
# Epoch 477 --- loss:0.007, Epoch accuracy:98.89%, Validation loss:1.642, Validation accuracy:67.62%
# Epoch 478: iteration 77/78
# Epoch 478 --- loss:0.010, Epoch accuracy:98.81%, Validation loss:1.637, Validation accuracy:68.57%
# Epoch 479: iteration 77/78
# Epoch 479 --- loss:0.010, Epoch accuracy:98.73%, Validation loss:1.586, Validation accuracy:71.11%
# Epoch 480: iteration 77/78
# Epoch 480 --- loss:0.008, Epoch accuracy:98.93%, Validation loss:1.645, Validation accuracy:69.84%
# Epoch 481: iteration 77/78
# Epoch 481 --- loss:0.051, Epoch accuracy:97.34%, Validation loss:2.180, Validation accuracy:66.03%
# Epoch 482: iteration 77/78
# Epoch 482 --- loss:0.094, Epoch accuracy:95.72%, Validation loss:1.746, Validation accuracy:64.13%
# Epoch 483: iteration 77/78
# Epoch 483 --- loss:0.193, Epoch accuracy:92.03%, Validation loss:1.684, Validation accuracy:68.89%
# Epoch 484: iteration 77/78
# Epoch 484 --- loss:0.034, Epoch accuracy:98.10%, Validation loss:1.865, Validation accuracy:60.95%
# Epoch 485: iteration 77/78
# Epoch 485 --- loss:0.022, Epoch accuracy:98.53%, Validation loss:1.665, Validation accuracy:66.98%
# Epoch 486: iteration 77/78
# Epoch 486 --- loss:0.014, Epoch accuracy:98.77%, Validation loss:1.738, Validation accuracy:68.25%
# Epoch 487: iteration 77/78
# Epoch 487 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:1.760, Validation accuracy:67.62%
# Epoch 488: iteration 77/78
# Epoch 488 --- loss:0.009, Epoch accuracy:98.85%, Validation loss:1.884, Validation accuracy:66.98%
# Epoch 489: iteration 77/78
# Epoch 489 --- loss:0.013, Epoch accuracy:98.69%, Validation loss:1.707, Validation accuracy:68.89%
# Epoch 490: iteration 77/78
# Epoch 490 --- loss:0.008, Epoch accuracy:98.93%, Validation loss:1.789, Validation accuracy:68.25%
# Epoch 491: iteration 77/78
# Epoch 491 --- loss:0.010, Epoch accuracy:98.77%, Validation loss:1.754, Validation accuracy:68.57%
# Epoch 492: iteration 77/78
# Epoch 492 --- loss:0.018, Epoch accuracy:98.41%, Validation loss:1.863, Validation accuracy:67.30%
# Epoch 493: iteration 77/78
# Epoch 493 --- loss:0.015, Epoch accuracy:98.65%, Validation loss:1.838, Validation accuracy:66.03%
# Epoch 494: iteration 77/78
# Epoch 494 --- loss:0.025, Epoch accuracy:98.22%, Validation loss:1.857, Validation accuracy:65.40%
# Epoch 495: iteration 77/78
# Epoch 495 --- loss:0.024, Epoch accuracy:98.18%, Validation loss:1.942, Validation accuracy:67.30%
# Epoch 496: iteration 77/78
# Epoch 496 --- loss:0.017, Epoch accuracy:98.81%, Validation loss:1.730, Validation accuracy:68.57%
# Epoch 497: iteration 77/78
# Epoch 497 --- loss:0.018, Epoch accuracy:98.41%, Validation loss:1.727, Validation accuracy:67.94%
# Epoch 498: iteration 77/78
# Epoch 498 --- loss:0.010, Epoch accuracy:98.93%, Validation loss:1.807, Validation accuracy:67.94%
# Epoch 499: iteration 77/78
# Epoch 499 --- loss:0.031, Epoch accuracy:97.90%, Validation loss:1.785, Validation accuracy:71.11%

# %%
plt.title('Loss Curve for Parallel is All You Want Model')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_losses[:],'b')
plt.plot(valid_losses[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()

# %%
# pick load folder  
load_folder = '/content/drive/My Drive/models/CNN_6_emotions/'  

# pick the epoch to load
epoch = '499'
model_name = f'parallel_all_you_wantFINAL-{epoch}.pkl'

# make full load path
load_path = os.path.join(load_folder, model_name)

## instantiate empty model and populate with params from binary 
model = parallel_all_you_want(len(emotions_dict))
load_checkpoint(optimizer, model, load_path)

print(f'Loaded model from {load_path}')
# Out:
# Loaded model from /content/drive/My Drive/models/CNN_6_emotions/parallel_all_you_wantFINAL-499.pkl

# %%
# reinitialize validation function with model from chosen checkpoint
validate = make_validate_fnc(model,criterion)

# Convert 4D test feature set array to tensor and move to GPU
X_test_tensor = torch.tensor(X_test,device=device).float()
# Convert 4D test label set array to tensor and move to GPU
y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
inputs =  X_test_tensor                     # this is what you had
labels =  y_test_tensor
#inputs, labels = inputs.cuda(), labels.cuda() # add this line
# Get the model's performance metrics using the validation function we defined

#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

#inputs, labels = inputs.to(device), labels.to(device)
model.to('cuda') 
inputs = inputs.to('cuda')

model.to('cuda') 
labels = labels.to('cuda')

test_loss, test_acc, predicted_emotions = validate(X_test_tensor,y_test_tensor)

print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test accuracy is 72.12%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

# because model tested on GPU, move prediction tensor to CPU then convert to array
predicted_emotions = predicted_emotions.cpu().numpy()
# use labels from test set
emotions_groundtruth = y_test

# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

# set labels for matrix axes from emotions
emotion_names = [emotion for emotion in emotions_dict.values()]

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

plt.show()
