# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Orignial Notebook: https://github.com/MITESHPUTHRANNEU/Speech-Emotion-Analyzer/blob/master/final_results_gender_test.ipynb
# This notebook author: Reza Chu
# Last Editing Date: 31st May 2019

## Python
import os
import random
import sys

import IPython
from IPython.display import Audio
from IPython.display import Image
import matplotlib.pyplot as plt

## Package
import glob 
import keras
import IPython.display as ipd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.graph_objs as go
import plotly.offline as py
import plotly.tools as tls
import seaborn as sns
import scipy.io.wavfile
import tensorflow as tf
py.init_notebook_mode(connected=True)

## Keras
from keras import regularizers
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from keras.callbacks import  History, ReduceLROnPlateau, CSVLogger
from keras.models import Model, Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.preprocessing import sequence
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils
from tensorflow.keras.utils import to_categorical

## Sklearn
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder

## Rest
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile
from tqdm import tqdm

input_duration=3
# % pylab inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#only SAVEE data set
import time
import os
import librosa
from librosa import display
import matplotlib.pyplot as plt
#sad/sa2dc.avi
labels = []
video_name=[]
audio_name=[]
features=[]
count=0
start_time = time.time()
CLASSES_LIST=['KL','JK ','JE','DC']
DATASET_DIR = '/content/drive/My Drive/SAVEE'
emotion_LIST = ["neutral", "happy", "sad","angry","fearful"]
for class_index, class_name in enumerate(CLASSES_LIST):
#for subdir, dirs, files in os.walk(path):
  print(class_name)
  #dir=subdir.split('/')[4]
  #print(dir)
  
  files= os.listdir(os.path.join(DATASET_DIR, class_name))
  for file in files:
      try:
        print(file)
        #Load librosa array, obtain mfcss, store the file and the mcss information in a new array
        X, sample_rate = librosa.load(DATASET_DIR+'/'+class_name+'/'+file, res_type='kaiser_fast')
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) 
        count +=1
        # The instruction below converts the labels (from 1 to 8) to a series from 0 to 7
        # This is because our predictor needs to start from 0 otherwise it will try to predict also 0.
        #file = int(file[7:8]) - 1 
        #0 = neutral, 1 = happy, 2 = sad, 3 = angry, 4 = fearful, 6 = disgust, 7 = surprised
        if file.startswith('a'):
            emotion=3
            c='a'
    
        elif file.startswith('f'):
            emotion=4
            c='f'
        elif file.startswith('h'):
            emotion=1
            c='h'
        elif file.startswith('n'):
            emotion=0
            c='n'
        elif file.startswith('sa'):
            emotion=2
            c='sa'
       
        else:
            continue
        my_class_name=class_name
        my_class_name=my_class_name.replace(" ", "")
        num=file.split('.')[0]
        #print(num)
        if(c=='sa'):
          num=num[2:]
        else:
          num=num[1:]
        num=int(num)
        num=str(num)
        #print(num)
       
        v=emotion_LIST[emotion]+'/'+c+num+my_class_name.lower()+'.avi'
        video_name.append(v)
        a=class_name+'/'+file

        audio_name.append(a)
        labels.append(emotion)
        
        features.append(mfccs)
      # If the file is not valid, skip it
      except ValueError:
        continue

print("--- Data loaded. Loading time: %s seconds ---" % (time.time() - start_time))
# Out:
# KL
# a01.wav
# a02.wav
# a03.wav
# a04.wav
# a05.wav
# a07.wav
# a10.wav
# a09.wav
# a08.wav
# a06.wav
# a15.wav
# a14.wav
# a13.wav
# a12.wav
# a11.wav
# d05.wav
# d04.wav
# d03.wav
# d02.wav
# d01.wav
# d10.wav
# d09.wav
# d08.wav
# d07.wav
# d06.wav
# d15.wav
# d14.wav
# d13.wav
# d12.wav
# d11.wav
# f05.wav
# f04.wav
# f03.wav
# f02.wav
# f01.wav
# f10.wav
# f09.wav
# f08.wav
# f07.wav
# f06.wav
# f15.wav
# f14.wav
# f13.wav
# f12.wav
# f11.wav
# h05.wav
# h04.wav
# h03.wav
# h02.wav
# h01.wav
# h10.wav
# h09.wav
# h08.wav
# h07.wav
# h06.wav
# h15.wav
# h14.wav
# h13.wav
# h12.wav
# h11.wav
# sa05.wav
# sa04.wav
# sa03.wav
# sa02.wav
# sa01.wav
# sa10.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa11.wav
# sa14.wav
# sa13.wav
# sa12.wav
# sa15.wav
# su05.wav
# su03.wav
# su02.wav
# su01.wav
# su10.wav
# su09.wav
# su08.wav
# su07.wav
# su06.wav
# su15.wav
# su14.wav
# su13.wav
# su12.wav
# su11.wav
# su04.wav
# n01.wav
# n05.wav
# n04.wav
# n03.wav
# n02.wav
# n10.wav
# n09.wav
# n08.wav
# n07.wav
# n06.wav
# n20.wav
# n19.wav
# n18.wav
# n17.wav
# n16.wav
# n25.wav
# n24.wav
# n23.wav
# n22.wav
# n21.wav
# n30.wav
# n29.wav
# n28.wav
# n27.wav
# n26.wav
# n15.wav
# n14.wav
# n13.wav
# n12.wav
# n11.wav
# JK
# a01.wav
# a02.wav
# a03.wav
# a04.wav
# a05.wav
# a06.wav
# a07.wav
# a08.wav
# a09.wav
# a10.wav
# a11.wav
# a12.wav
# a13.wav
# a14.wav
# a15.wav
# d01.wav
# d02.wav
# d03.wav
# d04.wav
# d06.wav
# d07.wav
# d08.wav
# d09.wav
# d11.wav
# d12.wav
# d13.wav
# d14.wav
# d15.wav
# d05.wav
# d10.wav
# f01.wav
# f02.wav
# f03.wav
# f04.wav
# f05.wav
# f06.wav
# f07.wav
# f08.wav
# f10.wav
# f11.wav
# f12.wav
# f13.wav
# f14.wav
# f15.wav
# f09.wav
# h01.wav
# h02.wav
# h03.wav
# h04.wav
# h05.wav
# h06.wav
# h07.wav
# h08.wav
# h09.wav
# h10.wav
# h11.wav
# h12.wav
# h13.wav
# h14.wav
# h15.wav
# n01.wav
# n02.wav
# n03.wav
# n04.wav
# n05.wav
# n06.wav
# n07.wav
# n08.wav
# n09.wav
# n10.wav
# n11.wav
# n12.wav
# n13.wav
# n14.wav
# n15.wav
# n20.wav
# n19.wav
# n18.wav
# n17.wav
# n16.wav
# n25.wav
# n23.wav
# n22.wav
# n21.wav
# n26.wav
# n30.wav
# n29.wav
# n28.wav
# n27.wav
# sa05.wav
# sa04.wav
# sa03.wav
# sa02.wav
# sa01.wav
# sa10.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa15.wav
# sa14.wav
# sa13.wav
# sa12.wav
# sa11.wav
# su05.wav
# su04.wav
# su15.wav
# su14.wav
# su13.wav
# su12.wav
# su11.wav
# su10.wav
# su09.wav
# su08.wav
# su07.wav
# su06.wav
# su03.wav
# su02.wav
# su01.wav
# n24.wav
# JE
# a01.wav
# a02.wav
# a03.wav
# a04.wav
# a05.wav
# a07.wav
# a06.wav
# a08.wav
# a09.wav
# a10.wav
# a11.wav
# a12.wav
# a13.wav
# a14.wav
# a15.wav
# d05.wav
# d04.wav
# d03.wav
# d02.wav
# d01.wav
# d09.wav
# d08.wav
# d07.wav
# d06.wav
# d10.wav
# d15.wav
# d14.wav
# d13.wav
# d12.wav
# d11.wav
# f05.wav
# f04.wav
# f03.wav
# f02.wav
# f01.wav
# f10.wav
# f09.wav
# f08.wav
# f07.wav
# f06.wav
# f14.wav
# f13.wav
# f12.wav
# f11.wav
# f15.wav
# h05.wav
# h04.wav
# h03.wav
# h02.wav
# h01.wav
# h10.wav
# h09.wav
# h08.wav
# h07.wav
# h06.wav
# h14.wav
# h13.wav
# h12.wav
# h11.wav
# h15.wav
# n18.wav
# n17.wav
# n16.wav
# n05.wav
# n04.wav
# n03.wav
# n02.wav
# n01.wav
# n10.wav
# n09.wav
# n08.wav
# n07.wav
# n06.wav
# n15.wav
# n14.wav
# n13.wav
# n12.wav
# n11.wav
# n20.wav
# n19.wav
# n25.wav
# n24.wav
# n23.wav
# n22.wav
# n21.wav
# n30.wav
# n29.wav
# n28.wav
# n27.wav
# n26.wav
# sa04.wav
# sa03.wav
# sa02.wav
# sa01.wav
# sa13.wav
# sa12.wav
# sa11.wav
# sa05.wav
# sa10.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa15.wav
# sa14.wav
# su05.wav
# su04.wav
# su03.wav
# su02.wav
# su01.wav
# su10.wav
# su09.wav
# su08.wav
# su07.wav
# su06.wav
# su13.wav
# su12.wav
# su11.wav
# su15.wav
# su14.wav
# DC
# a15.wav
# a14.wav
# a05.wav
# a04.wav
# a03.wav
# a02.wav
# a01.wav
# a06.wav
# a07.wav
# a08.wav
# a09.wav
# a10.wav
# a13.wav
# a12.wav
# a11.wav
# d01.wav
# d02.wav
# d03.wav
# d04.wav
# d05.wav
# d10.wav
# d09.wav
# d08.wav
# d07.wav
# d06.wav
# d15.wav
# d14.wav
# d13.wav
# d12.wav
# d11.wav
# f01.wav
# f02.wav
# f03.wav
# f04.wav
# f05.wav
# f10.wav
# f09.wav
# f08.wav
# f07.wav
# f06.wav
# f15.wav
# f14.wav
# f13.wav
# f12.wav
# f11.wav
# h01.wav
# h02.wav
# h03.wav
# h04.wav
# h05.wav
# h10.wav
# h09.wav
# h08.wav
# h07.wav
# h06.wav
# h11.wav
# h12.wav
# h13.wav
# h14.wav
# h15.wav
# n05.wav
# n04.wav
# n03.wav
# n02.wav
# n01.wav
# n06.wav
# n07.wav
# n08.wav
# n09.wav
# n10.wav
# n11.wav
# n12.wav
# n13.wav
# n14.wav
# n15.wav
# n20.wav
# n19.wav
# n18.wav
# n17.wav
# n16.wav
# n21.wav
# n22.wav
# n23.wav
# n24.wav
# n25.wav
# n26.wav
# n27.wav
# n28.wav
# n29.wav
# n30.wav
# sa01.wav
# sa02.wav
# sa03.wav
# sa04.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa11.wav
# sa12.wav
# sa13.wav
# sa14.wav
# sa15.wav
# sa05.wav
# sa10.wav
# su01.wav
# su02.wav
# su03.wav
# su04.wav
# su05.wav
# su06.wav
# su07.wav
# su08.wav
# su09.wav
# su11.wav
# su12.wav
# su13.wav
# su14.wav
# su15.wav
# su10.wav
# --- Data loaded. Loading time: 49.62665128707886 seconds ---

# %%
seed_constant = 42

# %%
from sklearn.model_selection import train_test_split
# Split the Data into Train ( 80% ) and Test Set ( 20% ).
x_train, x_test, y_train, y_test,video_train_path,video_test_path,audio_train_path,audio_test_path = train_test_split(features, labels,video_name,audio_name,
                                                                            test_size = 0.10, shuffle = True,
                                                                            random_state = seed_constant)

# %%
# Split train the Data into Train ( 80% ) and valid Set ( 20% ).
x_train, x_valid, y_train, y_valid,video_train_path,video_valid_path,audio_train_path,audio_valid_path = train_test_split(x_train, y_train,video_train_path,audio_train_path,
                                                                            test_size = 0.11, shuffle = True,
                                                                            random_state = seed_constant)

# %%
#288,36,36
len(x_train),len(x_valid),len(x_test),len(y_train),len(y_valid),len(y_test),len(video_train_path),len(video_valid_path),len(video_test_path),len(audio_train_path),len(audio_valid_path),len(audio_test_path)
# Out:
# (288, 36, 36, 288, 36, 36, 288, 36, 36, 288, 36, 36)

# %%
import joblib

save_dir = '/content/drive/My Drive/fusion/savee/audio/data_set/expert4'

savedvX = joblib.dump(y_train, os.path.join(save_dir, 'train/labels_train'))
savedvX = joblib.dump(y_test, os.path.join(save_dir, 'test/labels_test'))
savedvX = joblib.dump(y_valid, os.path.join(save_dir, 'valid/labels_valid'))
savedvX = joblib.dump(video_train_path, os.path.join(save_dir, 'train/video_train_path'))
savedvX = joblib.dump(video_test_path, os.path.join(save_dir, 'test/video_test_path'))
savedvX = joblib.dump(video_valid_path, os.path.join(save_dir, 'valid/video_valid_path'))
savedvX = joblib.dump(audio_train_path, os.path.join(save_dir, 'train/audio_train_path'))
savedvX = joblib.dump(audio_test_path, os.path.join(save_dir, 'test/audio_test_path'))
savedvX = joblib.dump(audio_valid_path, os.path.join(save_dir, 'valid/audio_valid_path'))

# %%
x_valid=np.asarray(x_valid)
x_test=np.asarray(x_test)
x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
y_test=np.asarray(y_test)
y_valid=np.asarray(y_valid)
x_valid.shape,x_test.shape,x_train.shape,y_valid.shape,y_test.shape,y_train.shape
# Out:
# ((36, 40), (36, 40), (288, 40), (36,), (36,), (288,))

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras import optimizers
from keras.models import InputLayer

model = Sequential(InputLayer((40,1)))
model.add(BatchNormalization())

model.add(Conv1D(128, 12,padding='same', ))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=(5)))


model.add(Conv1D(256,12,padding='same',))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(MaxPooling1D(pool_size=(5)))

model.add(Flatten())
model.add(Dense(5))
model.add(Activation('softmax'))
opt = tf.keras.optimizers.Adam(lr=0.0002)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 40, 1)            4
#  ormalization)
#
#  conv1d (Conv1D)             (None, 40, 128)           1664
#
#  batch_normalization_1 (Batc  (None, 40, 128)          512
#  hNormalization)
#
#  activation (Activation)     (None, 40, 128)           0
#
#  dropout (Dropout)           (None, 40, 128)           0
#
#  max_pooling1d (MaxPooling1D  (None, 8, 128)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 8, 256)            393472
#
#  batch_normalization_2 (Batc  (None, 8, 256)           1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8, 256)            0
#
#  dropout_1 (Dropout)         (None, 8, 256)            0
#
#  max_pooling1d_1 (MaxPooling  (None, 1, 256)           0
#  1D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 5)                 1285
#
#  activation_2 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 397,961
# Trainable params: 397,191
# Non-trainable params: 770
# _________________________________________________________________

# %%
x_traincnn = np.expand_dims(x_train, axis=2)
x_testcnn = np.expand_dims(x_test, axis=2)
x_valid= np.expand_dims(x_valid, axis=2)
x_traincnn.shape, x_testcnn.shape , x_valid.shape
# Out:
# ((288, 40, 1), (36, 40, 1), (36, 40, 1))

# %%
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = opt, metrics = ["accuracy"])

early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 65, mode = 'min', restore_best_weights = True)
cnnhistory=model.fit(x_traincnn, y_train, batch_size=16, epochs=500 , shuffle = True, 
                     validation_data=(x_valid, y_valid), callbacks = [early_stopping_callback])
# Out:
# Epoch 1/500
# 18/18 [==============================] - 12s 21ms/step - loss: 1.9409 - accuracy: 0.3229 - val_loss: 1.5698 - val_accuracy: 0.2222
# Epoch 2/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.5472 - accuracy: 0.4306 - val_loss: 1.5818 - val_accuracy: 0.1111
# Epoch 3/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.3443 - accuracy: 0.4757 - val_loss: 1.7332 - val_accuracy: 0.0833
# Epoch 4/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.4176 - accuracy: 0.4271 - val_loss: 1.9137 - val_accuracy: 0.0833
# Epoch 5/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.2385 - accuracy: 0.5451 - val_loss: 1.9069 - val_accuracy: 0.0833
# Epoch 6/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.1770 - accuracy: 0.5382 - val_loss: 2.1394 - val_accuracy: 0.0833
# Epoch 7/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.1669 - accuracy: 0.5556 - val_loss: 2.3096 - val_accuracy: 0.0833
# Epoch 8/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.9829 - accuracy: 0.6146 - val_loss: 2.3176 - val_accuracy: 0.0833
# Epoch 9/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0352 - accuracy: 0.6285 - val_loss: 2.4399 - val_accuracy: 0.0833
# Epoch 10/500
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0372 - accuracy: 0.6111 - val_loss: 2.8792 - val_accuracy: 0.0833
# Epoch 11/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.9048 - accuracy: 0.6840 - val_loss: 3.0668 - val_accuracy: 0.0833
# Epoch 12/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8584 - accuracy: 0.6701 - val_loss: 3.1416 - val_accuracy: 0.0833
# Epoch 13/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.9316 - accuracy: 0.6562 - val_loss: 3.3173 - val_accuracy: 0.0833
# Epoch 14/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8626 - accuracy: 0.6667 - val_loss: 3.1761 - val_accuracy: 0.0833
# Epoch 15/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8576 - accuracy: 0.6597 - val_loss: 3.5346 - val_accuracy: 0.0833
# Epoch 16/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7677 - accuracy: 0.7257 - val_loss: 2.9789 - val_accuracy: 0.0833
# Epoch 17/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7454 - accuracy: 0.6979 - val_loss: 3.3592 - val_accuracy: 0.0833
# Epoch 18/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8256 - accuracy: 0.7014 - val_loss: 3.4578 - val_accuracy: 0.0833
# Epoch 19/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8181 - accuracy: 0.6910 - val_loss: 3.2189 - val_accuracy: 0.0833
# Epoch 20/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8010 - accuracy: 0.6875 - val_loss: 2.7422 - val_accuracy: 0.0833
# Epoch 21/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7609 - accuracy: 0.7326 - val_loss: 2.5688 - val_accuracy: 0.0833
# Epoch 22/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8096 - accuracy: 0.6910 - val_loss: 2.7040 - val_accuracy: 0.0833
# Epoch 23/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7986 - accuracy: 0.7083 - val_loss: 2.0757 - val_accuracy: 0.0833
# Epoch 24/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7739 - accuracy: 0.6979 - val_loss: 1.9854 - val_accuracy: 0.1111
# Epoch 25/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7959 - accuracy: 0.7014 - val_loss: 2.2025 - val_accuracy: 0.0833
# Epoch 26/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6970 - accuracy: 0.7500 - val_loss: 1.2663 - val_accuracy: 0.3611
# Epoch 27/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6463 - accuracy: 0.7361 - val_loss: 1.5116 - val_accuracy: 0.2500
# Epoch 28/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6403 - accuracy: 0.7569 - val_loss: 1.2506 - val_accuracy: 0.3889
# Epoch 29/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7450 - accuracy: 0.7188 - val_loss: 1.7035 - val_accuracy: 0.1944
# Epoch 30/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6469 - accuracy: 0.7604 - val_loss: 1.0394 - val_accuracy: 0.5833
# Epoch 31/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6359 - accuracy: 0.7465 - val_loss: 1.1706 - val_accuracy: 0.4167
# Epoch 32/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6397 - accuracy: 0.7569 - val_loss: 0.8996 - val_accuracy: 0.6389
# Epoch 33/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6700 - accuracy: 0.7188 - val_loss: 1.0254 - val_accuracy: 0.5833
# Epoch 34/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6557 - accuracy: 0.7361 - val_loss: 0.8451 - val_accuracy: 0.6389
# Epoch 35/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6383 - accuracy: 0.7569 - val_loss: 0.9024 - val_accuracy: 0.6111
# Epoch 36/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6370 - accuracy: 0.7361 - val_loss: 1.0686 - val_accuracy: 0.6111
# Epoch 37/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5854 - accuracy: 0.7847 - val_loss: 0.7821 - val_accuracy: 0.6944
# Epoch 38/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5908 - accuracy: 0.7743 - val_loss: 0.7878 - val_accuracy: 0.7778
# Epoch 39/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6202 - accuracy: 0.7188 - val_loss: 0.8715 - val_accuracy: 0.7500
# Epoch 40/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6614 - accuracy: 0.7153 - val_loss: 0.8510 - val_accuracy: 0.7778
# Epoch 41/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6650 - accuracy: 0.7569 - val_loss: 0.7451 - val_accuracy: 0.8056
# Epoch 42/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6019 - accuracy: 0.7743 - val_loss: 0.7802 - val_accuracy: 0.7222
# Epoch 43/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6192 - accuracy: 0.7326 - val_loss: 0.9108 - val_accuracy: 0.6667
# Epoch 44/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6591 - accuracy: 0.7569 - val_loss: 0.7064 - val_accuracy: 0.7500
# Epoch 45/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5182 - accuracy: 0.8229 - val_loss: 0.6278 - val_accuracy: 0.8056
# Epoch 46/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5385 - accuracy: 0.7986 - val_loss: 0.7269 - val_accuracy: 0.7500
# Epoch 47/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5752 - accuracy: 0.7778 - val_loss: 0.6687 - val_accuracy: 0.7500
# Epoch 48/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5365 - accuracy: 0.7812 - val_loss: 0.8199 - val_accuracy: 0.6389
# Epoch 49/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6300 - accuracy: 0.7326 - val_loss: 0.7461 - val_accuracy: 0.7222
# Epoch 50/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5623 - accuracy: 0.7917 - val_loss: 0.6286 - val_accuracy: 0.7778
# Epoch 51/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5427 - accuracy: 0.8125 - val_loss: 0.7307 - val_accuracy: 0.8333
# Epoch 52/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4858 - accuracy: 0.7917 - val_loss: 0.6661 - val_accuracy: 0.7222
# Epoch 53/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4977 - accuracy: 0.8125 - val_loss: 0.7794 - val_accuracy: 0.6667
# Epoch 54/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4772 - accuracy: 0.8194 - val_loss: 0.6299 - val_accuracy: 0.7778
# Epoch 55/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5864 - accuracy: 0.7674 - val_loss: 0.6062 - val_accuracy: 0.7500
# Epoch 56/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5256 - accuracy: 0.7569 - val_loss: 0.6479 - val_accuracy: 0.7778
# Epoch 57/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5508 - accuracy: 0.7812 - val_loss: 0.6916 - val_accuracy: 0.8333
# Epoch 58/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5503 - accuracy: 0.8125 - val_loss: 0.6699 - val_accuracy: 0.7778
# Epoch 59/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4948 - accuracy: 0.7917 - val_loss: 0.7073 - val_accuracy: 0.6944
# Epoch 60/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5079 - accuracy: 0.7917 - val_loss: 0.5972 - val_accuracy: 0.8056
# Epoch 61/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5003 - accuracy: 0.8160 - val_loss: 0.7376 - val_accuracy: 0.7500
# Epoch 62/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4974 - accuracy: 0.8160 - val_loss: 0.7061 - val_accuracy: 0.7500
# Epoch 63/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4581 - accuracy: 0.8194 - val_loss: 0.7573 - val_accuracy: 0.6667
# Epoch 64/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4490 - accuracy: 0.8368 - val_loss: 0.6175 - val_accuracy: 0.8611
# Epoch 65/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4648 - accuracy: 0.8194 - val_loss: 0.6346 - val_accuracy: 0.7778
# Epoch 66/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4534 - accuracy: 0.8229 - val_loss: 0.6823 - val_accuracy: 0.7222
# Epoch 67/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5451 - accuracy: 0.7847 - val_loss: 0.7847 - val_accuracy: 0.6389
# Epoch 68/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4870 - accuracy: 0.7986 - val_loss: 0.6757 - val_accuracy: 0.7500
# Epoch 69/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4367 - accuracy: 0.8333 - val_loss: 0.6929 - val_accuracy: 0.7222
# Epoch 70/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3607 - accuracy: 0.8681 - val_loss: 0.8007 - val_accuracy: 0.6389
# Epoch 71/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4098 - accuracy: 0.8438 - val_loss: 0.7126 - val_accuracy: 0.7500
# Epoch 72/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4123 - accuracy: 0.8299 - val_loss: 0.6383 - val_accuracy: 0.7778
# Epoch 73/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4243 - accuracy: 0.8368 - val_loss: 0.7007 - val_accuracy: 0.6944
# Epoch 74/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4399 - accuracy: 0.7917 - val_loss: 0.6845 - val_accuracy: 0.7222
# Epoch 75/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4460 - accuracy: 0.8090 - val_loss: 0.5682 - val_accuracy: 0.8611
# Epoch 76/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4594 - accuracy: 0.8194 - val_loss: 0.6723 - val_accuracy: 0.6944
# Epoch 77/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4091 - accuracy: 0.8472 - val_loss: 0.8457 - val_accuracy: 0.6667
# Epoch 78/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3874 - accuracy: 0.8472 - val_loss: 0.6481 - val_accuracy: 0.7778
# Epoch 79/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3790 - accuracy: 0.8368 - val_loss: 0.6847 - val_accuracy: 0.7222
# Epoch 80/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3993 - accuracy: 0.8403 - val_loss: 0.6168 - val_accuracy: 0.8333
# Epoch 81/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4054 - accuracy: 0.8194 - val_loss: 0.5716 - val_accuracy: 0.8611
# Epoch 82/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3874 - accuracy: 0.8542 - val_loss: 0.6266 - val_accuracy: 0.7500
# Epoch 83/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3691 - accuracy: 0.8715 - val_loss: 0.5882 - val_accuracy: 0.8056
# Epoch 84/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3705 - accuracy: 0.8646 - val_loss: 0.6774 - val_accuracy: 0.6667
# Epoch 85/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3981 - accuracy: 0.8472 - val_loss: 0.5753 - val_accuracy: 0.8056
# Epoch 86/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3798 - accuracy: 0.8576 - val_loss: 0.5831 - val_accuracy: 0.8333
# Epoch 87/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3636 - accuracy: 0.8368 - val_loss: 0.5550 - val_accuracy: 0.8611
# Epoch 88/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4016 - accuracy: 0.8299 - val_loss: 0.5683 - val_accuracy: 0.8333
# Epoch 89/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3485 - accuracy: 0.8472 - val_loss: 0.6221 - val_accuracy: 0.7222
# Epoch 90/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3777 - accuracy: 0.8264 - val_loss: 0.6399 - val_accuracy: 0.6944
# Epoch 91/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3232 - accuracy: 0.8646 - val_loss: 0.6275 - val_accuracy: 0.7500
# Epoch 92/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3654 - accuracy: 0.8576 - val_loss: 0.6898 - val_accuracy: 0.6944
# Epoch 93/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3100 - accuracy: 0.8889 - val_loss: 0.5492 - val_accuracy: 0.8611
# Epoch 94/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2955 - accuracy: 0.8924 - val_loss: 0.7049 - val_accuracy: 0.7500
# Epoch 95/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3453 - accuracy: 0.8507 - val_loss: 0.7620 - val_accuracy: 0.6667
# Epoch 96/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3160 - accuracy: 0.8785 - val_loss: 0.6344 - val_accuracy: 0.7500
# Epoch 97/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2645 - accuracy: 0.8854 - val_loss: 0.5768 - val_accuracy: 0.8056
# Epoch 98/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2683 - accuracy: 0.8889 - val_loss: 0.6231 - val_accuracy: 0.8056
# Epoch 99/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3210 - accuracy: 0.8646 - val_loss: 0.8246 - val_accuracy: 0.6944
# Epoch 100/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4016 - accuracy: 0.8542 - val_loss: 0.6811 - val_accuracy: 0.7222
# Epoch 101/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3246 - accuracy: 0.8715 - val_loss: 0.6692 - val_accuracy: 0.7500
# Epoch 102/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2858 - accuracy: 0.8854 - val_loss: 0.6072 - val_accuracy: 0.7778
# Epoch 103/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3216 - accuracy: 0.8750 - val_loss: 0.6680 - val_accuracy: 0.8056
# Epoch 104/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2633 - accuracy: 0.8993 - val_loss: 0.6969 - val_accuracy: 0.7778
# Epoch 105/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2573 - accuracy: 0.9028 - val_loss: 0.7460 - val_accuracy: 0.6944
# Epoch 106/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2987 - accuracy: 0.9062 - val_loss: 0.7430 - val_accuracy: 0.7222
# Epoch 107/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2922 - accuracy: 0.8924 - val_loss: 0.6232 - val_accuracy: 0.7778
# Epoch 108/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.8715 - val_loss: 0.7867 - val_accuracy: 0.7222
# Epoch 109/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2846 - accuracy: 0.8889 - val_loss: 0.6250 - val_accuracy: 0.7778
# Epoch 110/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3322 - accuracy: 0.8542 - val_loss: 0.7983 - val_accuracy: 0.6944
# Epoch 111/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3091 - accuracy: 0.8889 - val_loss: 0.8365 - val_accuracy: 0.6667
# Epoch 112/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2965 - accuracy: 0.8854 - val_loss: 0.6512 - val_accuracy: 0.8056
# Epoch 113/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2630 - accuracy: 0.9028 - val_loss: 0.6035 - val_accuracy: 0.7500
# Epoch 114/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2577 - accuracy: 0.8958 - val_loss: 0.7446 - val_accuracy: 0.7222
# Epoch 115/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2358 - accuracy: 0.9201 - val_loss: 0.6920 - val_accuracy: 0.7222
# Epoch 116/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2155 - accuracy: 0.9236 - val_loss: 0.5921 - val_accuracy: 0.8056
# Epoch 117/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2458 - accuracy: 0.9028 - val_loss: 0.6108 - val_accuracy: 0.7778
# Epoch 118/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2770 - accuracy: 0.8993 - val_loss: 0.6542 - val_accuracy: 0.7500
# Epoch 119/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2637 - accuracy: 0.8854 - val_loss: 0.6801 - val_accuracy: 0.8611
# Epoch 120/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2216 - accuracy: 0.8993 - val_loss: 0.6644 - val_accuracy: 0.7222
# Epoch 121/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2629 - accuracy: 0.8993 - val_loss: 0.6602 - val_accuracy: 0.7778
# Epoch 122/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2634 - accuracy: 0.8993 - val_loss: 0.6652 - val_accuracy: 0.8056
# Epoch 123/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2962 - accuracy: 0.8750 - val_loss: 0.7365 - val_accuracy: 0.7500
# Epoch 124/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2646 - accuracy: 0.8958 - val_loss: 0.6285 - val_accuracy: 0.7500
# Epoch 125/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2733 - accuracy: 0.9062 - val_loss: 0.6554 - val_accuracy: 0.7222
# Epoch 126/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2694 - accuracy: 0.9132 - val_loss: 0.5683 - val_accuracy: 0.7778
# Epoch 127/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2626 - accuracy: 0.9028 - val_loss: 0.6550 - val_accuracy: 0.8333
# Epoch 128/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2015 - accuracy: 0.9062 - val_loss: 0.5815 - val_accuracy: 0.7500
# Epoch 129/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2789 - accuracy: 0.8750 - val_loss: 0.7351 - val_accuracy: 0.7500
# Epoch 130/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2419 - accuracy: 0.8993 - val_loss: 0.6362 - val_accuracy: 0.7500
# Epoch 131/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2293 - accuracy: 0.9097 - val_loss: 0.4972 - val_accuracy: 0.8333
# Epoch 132/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2554 - accuracy: 0.8750 - val_loss: 0.8530 - val_accuracy: 0.6667
# Epoch 133/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2076 - accuracy: 0.9340 - val_loss: 0.5544 - val_accuracy: 0.7500
# Epoch 134/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2207 - accuracy: 0.9097 - val_loss: 0.7540 - val_accuracy: 0.7222
# Epoch 135/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1780 - accuracy: 0.9375 - val_loss: 0.6094 - val_accuracy: 0.8056
# Epoch 136/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1678 - accuracy: 0.9618 - val_loss: 0.5582 - val_accuracy: 0.7778
# Epoch 137/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2158 - accuracy: 0.9167 - val_loss: 0.5762 - val_accuracy: 0.8056
# Epoch 138/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2100 - accuracy: 0.9167 - val_loss: 0.5672 - val_accuracy: 0.8333
# Epoch 139/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2314 - accuracy: 0.9132 - val_loss: 0.5372 - val_accuracy: 0.8056
# Epoch 140/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2123 - accuracy: 0.9201 - val_loss: 0.5452 - val_accuracy: 0.8333
# Epoch 141/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2098 - accuracy: 0.9236 - val_loss: 0.6272 - val_accuracy: 0.7778
# Epoch 142/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1838 - accuracy: 0.9201 - val_loss: 0.5807 - val_accuracy: 0.7778
# Epoch 143/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2067 - accuracy: 0.9271 - val_loss: 0.6444 - val_accuracy: 0.7778
# Epoch 144/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2052 - accuracy: 0.9236 - val_loss: 0.6284 - val_accuracy: 0.7778
# Epoch 145/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2066 - accuracy: 0.9201 - val_loss: 0.7362 - val_accuracy: 0.7500
# Epoch 146/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2337 - accuracy: 0.8924 - val_loss: 0.8095 - val_accuracy: 0.7500
# Epoch 147/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2207 - accuracy: 0.8993 - val_loss: 0.6786 - val_accuracy: 0.7222
# Epoch 148/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1816 - accuracy: 0.9375 - val_loss: 0.7056 - val_accuracy: 0.8056
# Epoch 149/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1912 - accuracy: 0.9340 - val_loss: 0.5111 - val_accuracy: 0.7500
# Epoch 150/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2231 - accuracy: 0.9201 - val_loss: 0.6229 - val_accuracy: 0.8056
# Epoch 151/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1766 - accuracy: 0.9236 - val_loss: 0.5028 - val_accuracy: 0.8611
# Epoch 152/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2341 - accuracy: 0.8924 - val_loss: 0.5752 - val_accuracy: 0.7500
# Epoch 153/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1624 - accuracy: 0.9514 - val_loss: 0.5732 - val_accuracy: 0.7778
# Epoch 154/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2184 - accuracy: 0.9167 - val_loss: 0.6782 - val_accuracy: 0.7222
# Epoch 155/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2180 - accuracy: 0.9201 - val_loss: 0.5568 - val_accuracy: 0.7778
# Epoch 156/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2080 - accuracy: 0.9236 - val_loss: 0.6074 - val_accuracy: 0.8333
# Epoch 157/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2702 - accuracy: 0.8924 - val_loss: 0.5433 - val_accuracy: 0.8056
# Epoch 158/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2227 - accuracy: 0.9062 - val_loss: 0.5488 - val_accuracy: 0.7778
# Epoch 159/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2463 - accuracy: 0.8924 - val_loss: 0.6130 - val_accuracy: 0.7778
# Epoch 160/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1757 - accuracy: 0.9375 - val_loss: 0.6074 - val_accuracy: 0.7500
# Epoch 161/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1455 - accuracy: 0.9410 - val_loss: 0.6497 - val_accuracy: 0.7222
# Epoch 162/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1922 - accuracy: 0.9340 - val_loss: 0.6167 - val_accuracy: 0.7778
# Epoch 163/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2556 - accuracy: 0.8958 - val_loss: 0.5337 - val_accuracy: 0.8333
# Epoch 164/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1550 - accuracy: 0.9306 - val_loss: 0.6468 - val_accuracy: 0.7500
# Epoch 165/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1931 - accuracy: 0.9271 - val_loss: 0.4651 - val_accuracy: 0.8056
# Epoch 166/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1485 - accuracy: 0.9583 - val_loss: 0.5872 - val_accuracy: 0.8056
# Epoch 167/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1577 - accuracy: 0.9340 - val_loss: 0.6309 - val_accuracy: 0.7500
# Epoch 168/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1622 - accuracy: 0.9306 - val_loss: 0.5023 - val_accuracy: 0.7778
# Epoch 169/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1900 - accuracy: 0.9306 - val_loss: 0.9411 - val_accuracy: 0.6667
# Epoch 170/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1959 - accuracy: 0.9306 - val_loss: 0.5965 - val_accuracy: 0.7222
# Epoch 171/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1450 - accuracy: 0.9479 - val_loss: 0.5867 - val_accuracy: 0.8056
# Epoch 172/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1716 - accuracy: 0.9306 - val_loss: 0.5578 - val_accuracy: 0.8056
# Epoch 173/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1906 - accuracy: 0.9340 - val_loss: 0.6284 - val_accuracy: 0.8056
# Epoch 174/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1584 - accuracy: 0.9514 - val_loss: 0.5048 - val_accuracy: 0.7778
# Epoch 175/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1413 - accuracy: 0.9410 - val_loss: 0.5027 - val_accuracy: 0.8056
# Epoch 176/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1577 - accuracy: 0.9375 - val_loss: 0.5469 - val_accuracy: 0.7778
# Epoch 177/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1162 - accuracy: 0.9653 - val_loss: 0.7011 - val_accuracy: 0.7222
# Epoch 178/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1501 - accuracy: 0.9549 - val_loss: 0.6010 - val_accuracy: 0.7500
# Epoch 179/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1581 - accuracy: 0.9375 - val_loss: 0.6815 - val_accuracy: 0.7500
# Epoch 180/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1438 - accuracy: 0.9514 - val_loss: 0.7099 - val_accuracy: 0.7500
# Epoch 181/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1268 - accuracy: 0.9583 - val_loss: 0.5726 - val_accuracy: 0.7778
# Epoch 182/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1350 - accuracy: 0.9514 - val_loss: 0.5487 - val_accuracy: 0.7500
# Epoch 183/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1202 - accuracy: 0.9514 - val_loss: 0.7399 - val_accuracy: 0.7500
# Epoch 184/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0980 - accuracy: 0.9618 - val_loss: 0.5762 - val_accuracy: 0.7778
# Epoch 185/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1540 - accuracy: 0.9514 - val_loss: 0.6136 - val_accuracy: 0.7500
# Epoch 186/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1422 - accuracy: 0.9479 - val_loss: 0.5938 - val_accuracy: 0.8056
# Epoch 187/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1282 - accuracy: 0.9514 - val_loss: 0.6102 - val_accuracy: 0.8056
# Epoch 188/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1261 - accuracy: 0.9549 - val_loss: 0.5928 - val_accuracy: 0.8056
# Epoch 189/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1520 - accuracy: 0.9444 - val_loss: 0.7098 - val_accuracy: 0.8056
# Epoch 190/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1249 - accuracy: 0.9583 - val_loss: 0.5611 - val_accuracy: 0.7500
# Epoch 191/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1233 - accuracy: 0.9583 - val_loss: 0.6061 - val_accuracy: 0.7778
# Epoch 192/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1208 - accuracy: 0.9653 - val_loss: 0.5895 - val_accuracy: 0.7778
# Epoch 193/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1083 - accuracy: 0.9618 - val_loss: 0.4956 - val_accuracy: 0.7778
# Epoch 194/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0940 - accuracy: 0.9722 - val_loss: 0.5557 - val_accuracy: 0.8333
# Epoch 195/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1083 - accuracy: 0.9653 - val_loss: 0.5918 - val_accuracy: 0.7778
# Epoch 196/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1134 - accuracy: 0.9479 - val_loss: 0.5600 - val_accuracy: 0.8333
# Epoch 197/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1039 - accuracy: 0.9583 - val_loss: 0.5701 - val_accuracy: 0.8056
# Epoch 198/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1220 - accuracy: 0.9583 - val_loss: 0.6904 - val_accuracy: 0.8056
# Epoch 199/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0858 - accuracy: 0.9653 - val_loss: 0.5870 - val_accuracy: 0.8056
# Epoch 200/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0729 - accuracy: 0.9826 - val_loss: 0.5840 - val_accuracy: 0.8056
# Epoch 201/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1095 - accuracy: 0.9618 - val_loss: 0.5874 - val_accuracy: 0.7500
# Epoch 202/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0961 - accuracy: 0.9618 - val_loss: 0.4912 - val_accuracy: 0.8333
# Epoch 203/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0967 - accuracy: 0.9792 - val_loss: 0.5632 - val_accuracy: 0.8056
# Epoch 204/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0902 - accuracy: 0.9688 - val_loss: 0.5927 - val_accuracy: 0.7500
# Epoch 205/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0907 - accuracy: 0.9653 - val_loss: 0.4895 - val_accuracy: 0.8056
# Epoch 206/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0748 - accuracy: 0.9861 - val_loss: 0.6941 - val_accuracy: 0.7778
# Epoch 207/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1184 - accuracy: 0.9479 - val_loss: 0.4606 - val_accuracy: 0.8333
# Epoch 208/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0803 - accuracy: 0.9896 - val_loss: 0.6143 - val_accuracy: 0.8056
# Epoch 209/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1169 - accuracy: 0.9653 - val_loss: 0.4858 - val_accuracy: 0.8333
# Epoch 210/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0965 - accuracy: 0.9618 - val_loss: 0.6313 - val_accuracy: 0.8056
# Epoch 211/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0971 - accuracy: 0.9688 - val_loss: 0.4486 - val_accuracy: 0.8056
# Epoch 212/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0887 - accuracy: 0.9722 - val_loss: 0.4969 - val_accuracy: 0.8611
# Epoch 213/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1043 - accuracy: 0.9583 - val_loss: 0.6527 - val_accuracy: 0.7778
# Epoch 214/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1064 - accuracy: 0.9653 - val_loss: 0.5787 - val_accuracy: 0.7778
# Epoch 215/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0954 - accuracy: 0.9688 - val_loss: 0.5738 - val_accuracy: 0.7778
# Epoch 216/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0665 - accuracy: 0.9931 - val_loss: 0.5875 - val_accuracy: 0.7500
# Epoch 217/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0809 - accuracy: 0.9722 - val_loss: 0.5984 - val_accuracy: 0.7778
# Epoch 218/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0979 - accuracy: 0.9722 - val_loss: 0.7065 - val_accuracy: 0.8056
# Epoch 219/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1410 - accuracy: 0.9375 - val_loss: 0.6173 - val_accuracy: 0.7778
# Epoch 220/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1177 - accuracy: 0.9549 - val_loss: 0.4262 - val_accuracy: 0.8333
# Epoch 221/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1064 - accuracy: 0.9688 - val_loss: 0.4538 - val_accuracy: 0.8333
# Epoch 222/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0895 - accuracy: 0.9757 - val_loss: 0.6147 - val_accuracy: 0.7222
# Epoch 223/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1178 - accuracy: 0.9618 - val_loss: 0.5839 - val_accuracy: 0.7222
# Epoch 224/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0957 - accuracy: 0.9653 - val_loss: 0.5937 - val_accuracy: 0.8056
# Epoch 225/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0963 - accuracy: 0.9549 - val_loss: 0.5231 - val_accuracy: 0.7778
# Epoch 226/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1096 - accuracy: 0.9757 - val_loss: 0.6142 - val_accuracy: 0.8056
# Epoch 227/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1073 - accuracy: 0.9583 - val_loss: 0.6352 - val_accuracy: 0.7778
# Epoch 228/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1079 - accuracy: 0.9688 - val_loss: 0.6098 - val_accuracy: 0.8333
# Epoch 229/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1015 - accuracy: 0.9688 - val_loss: 0.7065 - val_accuracy: 0.7500
# Epoch 230/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0881 - accuracy: 0.9618 - val_loss: 0.4118 - val_accuracy: 0.8056
# Epoch 231/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0831 - accuracy: 0.9653 - val_loss: 0.5774 - val_accuracy: 0.7500
# Epoch 232/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1012 - accuracy: 0.9583 - val_loss: 0.5872 - val_accuracy: 0.8056
# Epoch 233/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0920 - accuracy: 0.9688 - val_loss: 0.5080 - val_accuracy: 0.7222
# Epoch 234/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0852 - accuracy: 0.9688 - val_loss: 0.5130 - val_accuracy: 0.7500
# Epoch 235/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0476 - accuracy: 0.9931 - val_loss: 0.5406 - val_accuracy: 0.7778
# Epoch 236/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0685 - accuracy: 0.9792 - val_loss: 0.6478 - val_accuracy: 0.7778
# Epoch 237/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0746 - accuracy: 0.9722 - val_loss: 0.5315 - val_accuracy: 0.8056
# Epoch 238/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0617 - accuracy: 0.9757 - val_loss: 0.7015 - val_accuracy: 0.7222
# Epoch 239/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0775 - accuracy: 0.9757 - val_loss: 0.5101 - val_accuracy: 0.8056
# Epoch 240/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0522 - accuracy: 0.9896 - val_loss: 0.6091 - val_accuracy: 0.7778
# Epoch 241/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0678 - accuracy: 0.9792 - val_loss: 0.4724 - val_accuracy: 0.8333
# Epoch 242/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0331 - accuracy: 0.9965 - val_loss: 0.5372 - val_accuracy: 0.7778
# Epoch 243/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0551 - accuracy: 0.9896 - val_loss: 0.5427 - val_accuracy: 0.7778
# Epoch 244/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0961 - accuracy: 0.9688 - val_loss: 0.5766 - val_accuracy: 0.7500
# Epoch 245/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9861 - val_loss: 0.6757 - val_accuracy: 0.7778
# Epoch 246/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0882 - accuracy: 0.9757 - val_loss: 0.5068 - val_accuracy: 0.8056
# Epoch 247/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1056 - accuracy: 0.9618 - val_loss: 0.5071 - val_accuracy: 0.8056
# Epoch 248/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0920 - accuracy: 0.9583 - val_loss: 0.6813 - val_accuracy: 0.7778
# Epoch 249/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0666 - accuracy: 0.9722 - val_loss: 0.5127 - val_accuracy: 0.8056
# Epoch 250/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0721 - accuracy: 0.9722 - val_loss: 0.5335 - val_accuracy: 0.8333
# Epoch 251/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0635 - accuracy: 0.9792 - val_loss: 0.5432 - val_accuracy: 0.8056
# Epoch 252/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0844 - accuracy: 0.9792 - val_loss: 0.5824 - val_accuracy: 0.8056
# Epoch 253/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0634 - accuracy: 0.9792 - val_loss: 0.5270 - val_accuracy: 0.8056
# Epoch 254/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0692 - accuracy: 0.9688 - val_loss: 0.5578 - val_accuracy: 0.7500
# Epoch 255/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0586 - accuracy: 0.9861 - val_loss: 0.5952 - val_accuracy: 0.7778
# Epoch 256/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0654 - accuracy: 0.9861 - val_loss: 0.5056 - val_accuracy: 0.7778
# Epoch 257/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0532 - accuracy: 0.9896 - val_loss: 0.5153 - val_accuracy: 0.7500
# Epoch 258/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0427 - accuracy: 0.9931 - val_loss: 0.5903 - val_accuracy: 0.7500
# Epoch 259/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0498 - accuracy: 0.9861 - val_loss: 0.5696 - val_accuracy: 0.7778
# Epoch 260/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0635 - accuracy: 0.9792 - val_loss: 0.5246 - val_accuracy: 0.7778
# Epoch 261/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0527 - accuracy: 0.9896 - val_loss: 0.4687 - val_accuracy: 0.8056
# Epoch 262/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0465 - accuracy: 0.9931 - val_loss: 0.5163 - val_accuracy: 0.7500
# Epoch 263/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0499 - accuracy: 0.9896 - val_loss: 0.5003 - val_accuracy: 0.7778
# Epoch 264/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0447 - accuracy: 0.9965 - val_loss: 0.4798 - val_accuracy: 0.7778
# Epoch 265/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0486 - accuracy: 0.9826 - val_loss: 0.4948 - val_accuracy: 0.8056
# Epoch 266/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0756 - accuracy: 0.9722 - val_loss: 0.4691 - val_accuracy: 0.8333
# Epoch 267/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0455 - accuracy: 0.9792 - val_loss: 0.4707 - val_accuracy: 0.8056
# Epoch 268/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9792 - val_loss: 0.6116 - val_accuracy: 0.7500
# Epoch 269/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0480 - accuracy: 0.9861 - val_loss: 0.4872 - val_accuracy: 0.7778
# Epoch 270/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.9896 - val_loss: 0.4914 - val_accuracy: 0.7778
# Epoch 271/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0417 - accuracy: 0.9861 - val_loss: 0.4974 - val_accuracy: 0.7778
# Epoch 272/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0433 - accuracy: 0.9826 - val_loss: 0.5904 - val_accuracy: 0.7500
# Epoch 273/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0470 - accuracy: 0.9896 - val_loss: 0.4706 - val_accuracy: 0.8056
# Epoch 274/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0430 - accuracy: 0.9931 - val_loss: 0.5666 - val_accuracy: 0.7778
# Epoch 275/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0335 - accuracy: 0.9931 - val_loss: 0.5413 - val_accuracy: 0.7778
# Epoch 276/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0508 - accuracy: 0.9861 - val_loss: 0.4988 - val_accuracy: 0.8056
# Epoch 277/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.9896 - val_loss: 0.6660 - val_accuracy: 0.8056
# Epoch 278/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0460 - accuracy: 0.9896 - val_loss: 0.4485 - val_accuracy: 0.8056
# Epoch 279/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0478 - accuracy: 0.9861 - val_loss: 0.4367 - val_accuracy: 0.7778
# Epoch 280/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0671 - accuracy: 0.9792 - val_loss: 0.5641 - val_accuracy: 0.7778
# Epoch 281/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0634 - accuracy: 0.9757 - val_loss: 0.5218 - val_accuracy: 0.7778
# Epoch 282/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0637 - accuracy: 0.9757 - val_loss: 0.4744 - val_accuracy: 0.8056
# Epoch 283/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0548 - accuracy: 0.9757 - val_loss: 0.5794 - val_accuracy: 0.7500
# Epoch 284/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 0.5625 - val_accuracy: 0.8056
# Epoch 285/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0719 - accuracy: 0.9722 - val_loss: 0.7748 - val_accuracy: 0.7778
# Epoch 286/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0596 - accuracy: 0.9792 - val_loss: 0.8600 - val_accuracy: 0.7778
# Epoch 287/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0376 - accuracy: 0.9931 - val_loss: 0.5469 - val_accuracy: 0.7778
# Epoch 288/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0603 - accuracy: 0.9757 - val_loss: 0.5684 - val_accuracy: 0.8056
# Epoch 289/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0448 - accuracy: 0.9931 - val_loss: 0.6424 - val_accuracy: 0.8056
# Epoch 290/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0402 - accuracy: 0.9896 - val_loss: 0.5001 - val_accuracy: 0.8333
# Epoch 291/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0674 - accuracy: 0.9722 - val_loss: 0.5080 - val_accuracy: 0.8611
# Epoch 292/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0488 - accuracy: 0.9826 - val_loss: 0.7261 - val_accuracy: 0.7222
# Epoch 293/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0304 - accuracy: 1.0000 - val_loss: 0.5949 - val_accuracy: 0.8333
# Epoch 294/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0488 - accuracy: 0.9896 - val_loss: 0.6605 - val_accuracy: 0.7778
# Epoch 295/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0556 - accuracy: 0.9792 - val_loss: 0.5215 - val_accuracy: 0.8056

# %%
plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.plot(cnnhistory.history['accuracy'])
plt.plot(cnnhistory.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %%
loss, acc =model.evaluate(x_traincnn,y_train )
print("Restored model train, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0787 - accuracy: 0.9792
# Restored model train, accuracy: 97.92%

# %%
loss, acc = model.evaluate(x_test, y_test)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8132 - accuracy: 0.6389
# Restored model, accuracy: 63.89%

# %%
#predictions = model.predict_classes(x_testcnn)
predictions = model.predict(x_test)
predictions
# Out:
# array([[1.28732959e-03, 4.55148891e-02, 1.27940420e-02, 9.40399945e-01,
#         3.84802752e-06],
#        [9.19204831e-06, 7.00959861e-01, 2.22241179e-05, 5.03525697e-03,
#         2.93973476e-01],
#        [7.37633454e-05, 7.59875834e-01, 2.03064247e-03, 4.30893786e-02,
#         1.94930434e-01],
#        [4.00136050e-04, 7.90076077e-01, 7.97451648e-04, 1.20050088e-03,
#         2.07525894e-01],
#        [5.33622205e-01, 9.76069350e-05, 4.66013670e-01, 2.51642050e-04,
#         1.48750851e-05],
#        [5.45485564e-05, 1.14095835e-02, 9.10658059e-07, 9.88448918e-01,
#         8.59642096e-05],
#        [7.40400210e-05, 1.52721986e-01, 1.26653314e-02, 6.88928902e-01,
#         1.45609677e-01],
#        [9.78339538e-02, 2.98677129e-04, 9.01198208e-01, 1.14228851e-05,
#         6.57752389e-04],
#        [9.37390566e-01, 9.89503857e-09, 6.26086369e-02, 2.96411542e-07,
#         4.06931662e-07],
#        [1.70028522e-06, 1.81658473e-02, 1.01985588e-05, 9.81819630e-01,
#         2.74682452e-06],
#        [9.91544008e-01, 2.48010852e-03, 4.48546000e-03, 8.92407843e-04,
#         5.97924460e-04],
#        [1.87822778e-04, 9.12880132e-05, 9.95305300e-01, 1.46584655e-03,
#         2.94988230e-03],
#        [4.98847694e-05, 2.25279722e-02, 1.71224144e-03, 9.75704968e-01,
#         4.83484746e-06],
#        [9.97940958e-01, 3.31753313e-07, 2.02176161e-03, 3.68519759e-05,
#         3.11606918e-08],
#        [6.88021964e-06, 4.05731983e-03, 1.62271164e-07, 2.23637362e-05,
#         9.95913208e-01],
#        [5.89289819e-04, 9.90030408e-01, 1.66389309e-05, 9.13269352e-03,
#         2.30948222e-04],
#        [5.89196454e-04, 8.90777819e-03, 2.99802468e-05, 7.55153087e-05,
#         9.90397573e-01],
#        [1.33552694e-05, 9.98568535e-01, 3.41555678e-05, 2.19037480e-04,
#         1.16493076e-03],
#        [3.50447923e-01, 3.60501144e-04, 4.21281308e-01, 2.27374449e-01,
#         5.35815139e-04],
#        [7.10819964e-04, 2.12962877e-05, 9.86730933e-01, 1.24978563e-02,
#         3.91513022e-05],
#        [2.04465255e-01, 8.25278054e-04, 7.78332531e-01, 1.59616154e-02,
#         4.15332557e-04],
#        [2.46435793e-05, 7.19781458e-01, 1.81400019e-03, 2.78284669e-01,
#         9.52662740e-05],
#        [9.99251544e-01, 1.87092255e-07, 6.39053003e-04, 1.09170818e-04,
#         5.11572509e-08],
#        [3.13460660e-05, 9.46747184e-01, 7.48343809e-05, 1.49185127e-02,
#         3.82280834e-02],
#        [4.56137321e-04, 3.45209078e-03, 5.05108200e-03, 8.28464329e-01,
#         1.62576333e-01],
#        [8.91889358e-05, 2.25169688e-01, 9.10189282e-03, 7.65617549e-01,
#         2.17467623e-05],
#        [2.22994387e-01, 3.23382759e-04, 7.76248276e-01, 2.50323763e-04,
#         1.83565164e-04],
#        [9.99180734e-01, 7.25039868e-08, 8.11290694e-04, 7.84468193e-06,
#         4.39566890e-08],
#        [1.83582500e-01, 3.29995185e-01, 1.05949184e-02, 6.30925968e-02,
#         4.12734777e-01],
#        [3.43945384e-01, 7.56625086e-04, 6.41787112e-01, 2.00467440e-03,
#         1.15062296e-02],
#        [6.40289436e-05, 4.68488215e-05, 9.99624610e-01, 1.12380192e-04,
#         1.52221750e-04],
#        [1.66296447e-03, 4.00329009e-04, 6.91449328e-04, 9.78118896e-01,
#         1.91264190e-02],
#        [4.55419951e-07, 1.26661979e-08, 9.99941945e-01, 3.69977943e-06,
#         5.39032699e-05],
#        [9.34753835e-01, 3.75633477e-04, 6.48154840e-02, 9.46817727e-06,
#         4.55626905e-05],
#        [7.20508833e-05, 2.88690478e-01, 1.47025980e-06, 8.88331840e-07,
#         7.11235106e-01],
#        [2.67960429e-01, 4.86692004e-02, 3.34529787e-01, 3.13613474e-01,
#         3.52271721e-02]], dtype=float32)

# %%
df_audio_test = pd.DataFrame(predictions,columns=["OA_"+str(i) for i in range(5)])

# %%
y_test
# Out:
# array([1, 1, 4, 1, 2, 3, 4, 2, 0, 1, 0, 2, 1, 0, 4, 1, 4, 1, 0, 2, 0, 1,
#        0, 1, 4, 1, 0, 0, 4, 0, 2, 3, 2, 0, 4, 1])

# %%
new_Ytest = y_test.astype(int)
new_Ytest
# Out:
# array([1, 1, 4, 1, 2, 3, 4, 2, 0, 1, 0, 2, 1, 0, 4, 1, 4, 1, 0, 2, 0, 1,
#        0, 1, 4, 1, 0, 0, 4, 0, 2, 3, 2, 0, 4, 1])

# %%
preds1=predictions.argmax(axis=1)
preds1
# Out:
# array([3, 1, 1, 1, 0, 3, 3, 2, 0, 3, 0, 2, 3, 0, 4, 1, 4, 1, 2, 2, 2, 1,
#        0, 1, 3, 3, 2, 0, 4, 2, 2, 3, 2, 0, 4, 2])

# %%
abc = preds1.astype(int).flatten()
from sklearn.metrics import confusion_matrix
c = confusion_matrix(new_Ytest, abc) 
c
# Out:
# array([[6, 0, 4, 0, 0],
#        [0, 6, 1, 4, 0],
#        [1, 0, 5, 0, 0],
#        [0, 0, 0, 2, 0],
#        [0, 1, 0, 2, 4]])

# %%
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
import seaborn as sn

print(classification_report(y_test,abc))

acc = float(accuracy_score(y_test,abc))*100
print("----accuracy score %s ----" % acc)

cm = confusion_matrix(y_test,abc)
#df_cm = pd.DataFrame(cm)
class_names = ['neutral', 'happy','sad','angry', 'fearful' ]
df_cm = pd.DataFrame(cm, index=class_names, columns=class_names,)
sn.heatmap(df_cm, annot=True, fmt='')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.60      0.71        10
#            1       0.86      0.55      0.67        11
#            2       0.50      0.83      0.62         6
#            3       0.25      1.00      0.40         2
#            4       1.00      0.57      0.73         7
#
#     accuracy                           0.64        36
#    macro avg       0.69      0.71      0.62        36
# weighted avg       0.79      0.64      0.67        36
#
# ----accuracy score 63.888888888888886 ----

# %%
model.save('/content/drive/My Drive/fusion/savee/audio/model/expert4/best_CNN_model')
print("MODEL SAVED")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/fusion/savee/audio/model/expert4/best_CNN_model/assets
# MODEL SAVED

# %%
model_file_name = f'/content/drive/My Drive/fusion/savee/audio/model/expert4/best_CNN_model___Loss_{loss}___Accuracy_{acc}.h5'

# Save the Model.
model.save(model_file_name)

# %%
# serialize model to JSON
model_json = model.to_json()
with open("/content/drive/My Drive/fusion/savee/audio/model/expert4/best_CNN_model.json", "w") as json_file:
    json_file.write(model_json)

# %%
prediction_train = model.predict(x_traincnn)
prediction_train
# Out:
# array([[3.0060331e-04, 7.2686719e-03, 6.3861597e-07, 3.5681841e-03,
#         9.8886186e-01],
#        [5.6586834e-04, 7.5182296e-02, 8.3508778e-05, 9.2352444e-01,
#         6.4384559e-04],
#        [2.5840274e-05, 3.9613172e-03, 2.0683259e-05, 9.9598962e-01,
#         2.5738411e-06],
#        ...,
#        [2.3839107e-06, 2.7441984e-02, 7.2154962e-06, 9.7244185e-01,
#         1.0662414e-04],
#        [7.9514736e-01, 2.8138727e-04, 2.0436867e-01, 1.8874520e-05,
#         1.8371567e-04],
#        [7.0314294e-01, 1.1290108e-03, 2.9213142e-01, 2.2798108e-06,
#         3.5942970e-03]], dtype=float32)

# %%
df_audio_train = pd.DataFrame(prediction_train,columns=["OA_"+str(i) for i in range(5)])

# %%
prediction_valid = model.predict(x_valid)
prediction_valid
# Out:
# array([[1.87410228e-02, 2.01206465e-04, 9.81049299e-01, 6.94283108e-06,
#         1.63704703e-06],
#        [8.23846931e-05, 1.79841638e-01, 4.76164601e-08, 1.00762828e-03,
#         8.19068313e-01],
#        [3.65588511e-03, 4.20248369e-04, 8.17123830e-01, 4.90309503e-07,
#         1.78799555e-01],
#        [9.94604766e-01, 4.17947234e-07, 1.60073210e-03, 3.79272527e-03,
#         1.30540332e-06],
#        [5.29447719e-02, 1.92597926e-01, 4.83712554e-02, 6.37430787e-01,
#         6.86552078e-02],
#        [5.25448620e-01, 6.01755921e-04, 4.68036145e-01, 5.86436084e-03,
#         4.91006540e-05],
#        [9.97181773e-01, 1.38683930e-07, 2.61240406e-03, 2.04607000e-04,
#         1.11649319e-06],
#        [4.48586419e-02, 9.50937510e-01, 1.85403740e-03, 2.16699531e-03,
#         1.82843010e-04],
#        [6.10741961e-04, 2.21281946e-02, 4.34103640e-06, 1.46877789e-03,
#         9.75787938e-01],
#        [9.99276936e-01, 5.39657549e-06, 7.05956074e-04, 1.03521361e-05,
#         1.47637195e-06],
#        [5.29481213e-06, 9.48034763e-01, 5.80070831e-04, 1.57930460e-02,
#         3.55867930e-02],
#        [1.84529617e-05, 3.33278507e-01, 1.59191870e-04, 6.66455030e-01,
#         8.88184222e-05],
#        [1.30044718e-04, 9.55772936e-01, 5.91626449e-05, 1.91370081e-02,
#         2.49008127e-02],
#        [9.98915792e-01, 1.39353148e-07, 5.50514495e-04, 5.33483340e-04,
#         1.64722465e-07],
#        [9.53831553e-01, 3.68564064e-03, 2.10897364e-02, 1.27332322e-02,
#         8.65978654e-03],
#        [8.70844722e-01, 6.16397243e-04, 1.28147855e-01, 3.63653206e-04,
#         2.73508031e-05],
#        [2.76578844e-01, 1.07126005e-04, 7.21495748e-01, 6.00703934e-04,
#         1.21763430e-03],
#        [1.60103489e-03, 7.45555805e-03, 5.50801269e-06, 5.06215030e-04,
#         9.90431726e-01],
#        [7.68035889e-01, 1.43942934e-05, 2.31602952e-01, 4.99120797e-05,
#         2.96843413e-04],
#        [3.08446979e-05, 9.75706100e-01, 3.24679044e-04, 2.09323876e-02,
#         3.00594373e-03],
#        [9.98000324e-01, 8.30344902e-07, 1.94839318e-03, 5.03139563e-05,
#         1.13517686e-07],
#        [1.35774030e-06, 9.76438761e-01, 1.17199961e-05, 1.69691592e-02,
#         6.57890411e-03],
#        [1.06385280e-03, 2.98984261e-04, 3.09553370e-03, 9.95514810e-01,
#         2.68059775e-05],
#        [1.77026188e-04, 5.08297443e-01, 2.70564778e-05, 4.91484672e-01,
#         1.37277411e-05],
#        [1.26821036e-02, 1.06046182e-05, 9.87256646e-01, 1.34044171e-07,
#         5.04774398e-05],
#        [9.73235667e-01, 4.65475168e-04, 2.55635101e-02, 7.29795545e-04,
#         5.61489469e-06],
#        [7.76085556e-01, 1.04711951e-04, 2.23635659e-01, 1.73524910e-04,
#         5.46382353e-07],
#        [9.15113151e-01, 1.25576422e-04, 8.14900994e-02, 4.18478121e-05,
#         3.22926138e-03],
#        [5.59721411e-06, 3.49145196e-02, 6.66955657e-06, 9.65058863e-01,
#         1.43713187e-05],
#        [3.54332864e-01, 5.51818162e-02, 3.42135459e-01, 1.01504829e-02,
#         2.38199368e-01],
#        [9.99367535e-01, 3.81892136e-08, 6.32198411e-04, 3.05714082e-07,
#         2.38568472e-08],
#        [8.25448334e-01, 7.56511581e-04, 1.70373410e-01, 3.41345658e-05,
#         3.38766188e-03],
#        [1.36908682e-04, 9.78390992e-01, 9.05398338e-06, 4.91916842e-04,
#         2.09711641e-02],
#        [1.52096991e-05, 2.02809693e-04, 4.07855865e-03, 1.39276505e-01,
#         8.56426895e-01],
#        [4.66536367e-05, 8.59024405e-01, 2.72039251e-05, 8.01060069e-03,
#         1.32891089e-01],
#        [1.40179705e-03, 3.08478740e-03, 5.44986352e-02, 9.24829721e-01,
#         1.61851179e-02]], dtype=float32)

# %%
df_audio_valid = pd.DataFrame(prediction_valid,columns=["OA_"+str(i) for i in range(5)])

# %%
import joblib

save_dir = '/content/drive/My Drive/fusion/savee/audio/data_set/expert4'

savedvX = joblib.dump(df_audio_train, os.path.join(save_dir, 'train/predict_train'))
savedvX = joblib.dump(df_audio_test, os.path.join(save_dir, 'test/predict_test'))
savedvX = joblib.dump(df_audio_valid, os.path.join(save_dir, 'valid/predict_valid'))
