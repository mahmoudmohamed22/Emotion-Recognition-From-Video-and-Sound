# %%
# Orignial Notebook: https://github.com/MITESHPUTHRANNEU/Speech-Emotion-Analyzer/blob/master/final_results_gender_test.ipynb
# This notebook author: Reza Chu
# Last Editing Date: 31st May 2019

## Python
import os
import random
import sys

import IPython
from IPython.display import Audio
from IPython.display import Image
import matplotlib.pyplot as plt

## Package
import glob 
import keras
import IPython.display as ipd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.graph_objs as go
import plotly.offline as py
import plotly.tools as tls
import seaborn as sns
import scipy.io.wavfile
import tensorflow as tf
py.init_notebook_mode(connected=True)

## Keras
from keras import regularizers
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from keras.callbacks import  History, ReduceLROnPlateau, CSVLogger
from keras.models import Model, Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.preprocessing import sequence
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils
from tensorflow.keras.utils import to_categorical

## Sklearn
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder

## Rest
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile
from tqdm import tqdm

input_duration=3
# % pylab inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#only SAVEE data set
import time
import os
import librosa
from librosa import display
import matplotlib.pyplot as plt
#sad/sa2dc.avi
labels = []
video_name=[]
audio_name=[]
count=0
start_time = time.time()
CLASSES_LIST=['KL','JK ','JE','DC']
DATASET_DIR = '/content/drive/My Drive/SAVEE'
emotion_LIST = ["neutral", "calm", "happy", "sad","angry","fearful"]
for class_index, class_name in enumerate(CLASSES_LIST):
#for subdir, dirs, files in os.walk(path):
  print(class_name)
  #dir=subdir.split('/')[4]
  #print(dir)
  
  files= os.listdir(os.path.join(DATASET_DIR, class_name))
  for file in files:
      try:
        print(file)
        #Load librosa array, obtain mfcss, store the file and the mcss information in a new array
        #X, sample_rate = librosa.load(os.path.join(subdir,file), res_type='kaiser_fast')
        #mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) 
        count +=1
        # The instruction below converts the labels (from 1 to 8) to a series from 0 to 7
        # This is because our predictor needs to start from 0 otherwise it will try to predict also 0.
        #file = int(file[7:8]) - 1 
        #0 = neutral, 1 = happy, 2 = sad, 3 = angry, 4 = fearful, 6 = disgust, 7 = surprised
        if file.startswith('a'):
            emotion=3
       # elif file.startswith('d'):
         #   emotion=6
        elif file.startswith('f'):
            emotion=4
        elif file.startswith('h'):
            emotion=1
        elif file.startswith('n'):
            emotion=0
        elif file.startswith('sa'):
            emotion=2
       # elif file.startswith('su'):
        #    emotion=7
        else:
            continue
        v=emotion_LIST[emotion]+'/'+file.split('.')[0]+class_name.lower()+'.avi'
        video_name.append(v)
        a=class_name+'/'+file

        audio_name.append(a)
        #arr = mfccs, emotion
        labels.append(emotion)
      # If the file is not valid, skip it
      except ValueError:
        continue

print("--- Data loaded. Loading time: %s seconds ---" % (time.time() - start_time))
# Out:
# KL
# a01.wav
# a02.wav
# a03.wav
# a04.wav
# a05.wav
# a07.wav
# a10.wav
# a09.wav
# a08.wav
# a06.wav
# a15.wav
# a14.wav
# a13.wav
# a12.wav
# a11.wav
# d05.wav
# d04.wav
# d03.wav
# d02.wav
# d01.wav
# d10.wav
# d09.wav
# d08.wav
# d07.wav
# d06.wav
# d15.wav
# d14.wav
# d13.wav
# d12.wav
# d11.wav
# f05.wav
# f04.wav
# f03.wav
# f02.wav
# f01.wav
# f10.wav
# f09.wav
# f08.wav
# f07.wav
# f06.wav
# f15.wav
# f14.wav
# f13.wav
# f12.wav
# f11.wav
# h05.wav
# h04.wav
# h03.wav
# h02.wav
# h01.wav
# h10.wav
# h09.wav
# h08.wav
# h07.wav
# h06.wav
# h15.wav
# h14.wav
# h13.wav
# h12.wav
# h11.wav
# sa05.wav
# sa04.wav
# sa03.wav
# sa02.wav
# sa01.wav
# sa10.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa11.wav
# sa14.wav
# sa13.wav
# sa12.wav
# sa15.wav
# su05.wav
# su03.wav
# su02.wav
# su01.wav
# su10.wav
# su09.wav
# su08.wav
# su07.wav
# su06.wav
# su15.wav
# su14.wav
# su13.wav
# su12.wav
# su11.wav
# su04.wav
# n01.wav
# n05.wav
# n04.wav
# n03.wav
# n02.wav
# n10.wav
# n09.wav
# n08.wav
# n07.wav
# n06.wav
# n20.wav
# n19.wav
# n18.wav
# n17.wav
# n16.wav
# n25.wav
# n24.wav
# n23.wav
# n22.wav
# n21.wav
# n30.wav
# n29.wav
# n28.wav
# n27.wav
# n26.wav
# n15.wav
# n14.wav
# n13.wav
# n12.wav
# n11.wav
# JK
# a01.wav
# a02.wav
# a03.wav
# a04.wav
# a05.wav
# a06.wav
# a07.wav
# a08.wav
# a09.wav
# a10.wav
# a11.wav
# a12.wav
# a13.wav
# a14.wav
# a15.wav
# d01.wav
# d02.wav
# d03.wav
# d04.wav
# d06.wav
# d07.wav
# d08.wav
# d09.wav
# d11.wav
# d12.wav
# d13.wav
# d14.wav
# d15.wav
# d05.wav
# d10.wav
# f01.wav
# f02.wav
# f03.wav
# f04.wav
# f05.wav
# f06.wav
# f07.wav
# f08.wav
# f10.wav
# f11.wav
# f12.wav
# f13.wav
# f14.wav
# f15.wav
# f09.wav
# h01.wav
# h02.wav
# h03.wav
# h04.wav
# h05.wav
# h06.wav
# h07.wav
# h08.wav
# h09.wav
# h10.wav
# h11.wav
# h12.wav
# h13.wav
# h14.wav
# h15.wav
# n01.wav
# n02.wav
# n03.wav
# n04.wav
# n05.wav
# n06.wav
# n07.wav
# n08.wav
# n09.wav
# n10.wav
# n11.wav
# n12.wav
# n13.wav
# n14.wav
# n15.wav
# n20.wav
# n19.wav
# n18.wav
# n17.wav
# n16.wav
# n25.wav
# n23.wav
# n22.wav
# n21.wav
# n26.wav
# n30.wav
# n29.wav
# n28.wav
# n27.wav
# sa05.wav
# sa04.wav
# sa03.wav
# sa02.wav
# sa01.wav
# sa10.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa15.wav
# sa14.wav
# sa13.wav
# sa12.wav
# sa11.wav
# su05.wav
# su04.wav
# su15.wav
# su14.wav
# su13.wav
# su12.wav
# su11.wav
# su10.wav
# su09.wav
# su08.wav
# su07.wav
# su06.wav
# su03.wav
# su02.wav
# su01.wav
# n24.wav
# JE
# a01.wav
# a02.wav
# a03.wav
# a04.wav
# a05.wav
# a07.wav
# a06.wav
# a08.wav
# a09.wav
# a10.wav
# a11.wav
# a12.wav
# a13.wav
# a14.wav
# a15.wav
# d05.wav
# d04.wav
# d03.wav
# d02.wav
# d01.wav
# d09.wav
# d08.wav
# d07.wav
# d06.wav
# d10.wav
# d15.wav
# d14.wav
# d13.wav
# d12.wav
# d11.wav
# f05.wav
# f04.wav
# f03.wav
# f02.wav
# f01.wav
# f10.wav
# f09.wav
# f08.wav
# f07.wav
# f06.wav
# f14.wav
# f13.wav
# f12.wav
# f11.wav
# f15.wav
# h05.wav
# h04.wav
# h03.wav
# h02.wav
# h01.wav
# h10.wav
# h09.wav
# h08.wav
# h07.wav
# h06.wav
# h14.wav
# h13.wav
# h12.wav
# h11.wav
# h15.wav
# n18.wav
# n17.wav
# n16.wav
# n05.wav
# n04.wav
# n03.wav
# n02.wav
# n01.wav
# n10.wav
# n09.wav
# n08.wav
# n07.wav
# n06.wav
# n15.wav
# n14.wav
# n13.wav
# n12.wav
# n11.wav
# n20.wav
# n19.wav
# n25.wav
# n24.wav
# n23.wav
# n22.wav
# n21.wav
# n30.wav
# n29.wav
# n28.wav
# n27.wav
# n26.wav
# sa04.wav
# sa03.wav
# sa02.wav
# sa01.wav
# sa13.wav
# sa12.wav
# sa11.wav
# sa05.wav
# sa10.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa15.wav
# sa14.wav
# su05.wav
# su04.wav
# su03.wav
# su02.wav
# su01.wav
# su10.wav
# su09.wav
# su08.wav
# su07.wav
# su06.wav
# su13.wav
# su12.wav
# su11.wav
# su15.wav
# su14.wav
# DC
# a15.wav
# a14.wav
# a05.wav
# a04.wav
# a03.wav
# a02.wav
# a01.wav
# a06.wav
# a07.wav
# a08.wav
# a09.wav
# a10.wav
# a13.wav
# a12.wav
# a11.wav
# d01.wav
# d02.wav
# d03.wav
# d04.wav
# d05.wav
# d10.wav
# d09.wav
# d08.wav
# d07.wav
# d06.wav
# d15.wav
# d14.wav
# d13.wav
# d12.wav
# d11.wav
# f01.wav
# f02.wav
# f03.wav
# f04.wav
# f05.wav
# f10.wav
# f09.wav
# f08.wav
# f07.wav
# f06.wav
# f15.wav
# f14.wav
# f13.wav
# f12.wav
# f11.wav
# h01.wav
# h02.wav
# h03.wav
# h04.wav
# h05.wav
# h10.wav
# h09.wav
# h08.wav
# h07.wav
# h06.wav
# h11.wav
# h12.wav
# h13.wav
# h14.wav
# h15.wav
# n05.wav
# n04.wav
# n03.wav
# n02.wav
# n01.wav
# n06.wav
# n07.wav
# n08.wav
# n09.wav
# n10.wav
# n11.wav
# n12.wav
# n13.wav
# n14.wav
# n15.wav
# n20.wav
# n19.wav
# n18.wav
# n17.wav
# n16.wav
# n21.wav
# n22.wav
# n23.wav
# n24.wav
# n25.wav
# n26.wav
# n27.wav
# n28.wav
# n29.wav
# n30.wav
# sa01.wav
# sa02.wav
# sa03.wav
# sa04.wav
# sa09.wav
# sa08.wav
# sa07.wav
# sa06.wav
# sa11.wav
# sa12.wav
# sa13.wav
# sa14.wav
# sa15.wav
# sa05.wav
# sa10.wav
# su01.wav
# su02.wav
# su03.wav
# su04.wav
# su05.wav
# su06.wav
# su07.wav
# su08.wav
# su09.wav
# su11.wav
# su12.wav
# su13.wav
# su14.wav
# su15.wav
# su10.wav
# --- Data loaded. Loading time: 0.07540678977966309 seconds ---

# %%
audio_name
# Out:
# ['KL/a01.wav',
#  'KL/a02.wav',
#  'KL/a03.wav',
#  'KL/a04.wav',
#  'KL/a05.wav',
#  'KL/a07.wav',
#  'KL/a10.wav',
#  'KL/a09.wav',
#  'KL/a08.wav',
#  'KL/a06.wav',
#  'KL/a15.wav',
#  'KL/a14.wav',
#  'KL/a13.wav',
#  'KL/a12.wav',
#  'KL/a11.wav',
#  'KL/f05.wav',
#  'KL/f04.wav',
#  'KL/f03.wav',
#  'KL/f02.wav',
#  'KL/f01.wav',
#  'KL/f10.wav',
#  'KL/f09.wav',
#  'KL/f08.wav',
#  'KL/f07.wav',
#  'KL/f06.wav',
#  'KL/f15.wav',
#  'KL/f14.wav',
#  'KL/f13.wav',
#  'KL/f12.wav',
#  'KL/f11.wav',
#  'KL/h05.wav',
#  'KL/h04.wav',
#  'KL/h03.wav',
#  'KL/h02.wav',
#  'KL/h01.wav',
#  'KL/h10.wav',
#  'KL/h09.wav',
#  'KL/h08.wav',
#  'KL/h07.wav',
#  'KL/h06.wav',
#  'KL/h15.wav',
#  'KL/h14.wav',
#  'KL/h13.wav',
#  'KL/h12.wav',
#  'KL/h11.wav',
#  'KL/sa05.wav',
#  'KL/sa04.wav',
#  'KL/sa03.wav',
#  'KL/sa02.wav',
#  'KL/sa01.wav',
#  'KL/sa10.wav',
#  'KL/sa09.wav',
#  'KL/sa08.wav',
#  'KL/sa07.wav',
#  'KL/sa06.wav',
#  'KL/sa11.wav',
#  'KL/sa14.wav',
#  'KL/sa13.wav',
#  'KL/sa12.wav',
#  'KL/sa15.wav',
#  'KL/n01.wav',
#  'KL/n05.wav',
#  'KL/n04.wav',
#  'KL/n03.wav',
#  'KL/n02.wav',
#  'KL/n10.wav',
#  'KL/n09.wav',
#  'KL/n08.wav',
#  'KL/n07.wav',
#  'KL/n06.wav',
#  'KL/n20.wav',
#  'KL/n19.wav',
#  'KL/n18.wav',
#  'KL/n17.wav',
#  'KL/n16.wav',
#  'KL/n25.wav',
#  'KL/n24.wav',
#  'KL/n23.wav',
#  'KL/n22.wav',
#  'KL/n21.wav',
#  'KL/n30.wav',
#  'KL/n29.wav',
#  'KL/n28.wav',
#  'KL/n27.wav',
#  'KL/n26.wav',
#  'KL/n15.wav',
#  'KL/n14.wav',
#  'KL/n13.wav',
#  'KL/n12.wav',
#  'KL/n11.wav',
#  'JK /a01.wav',
#  'JK /a02.wav',
#  'JK /a03.wav',
#  'JK /a04.wav',
#  'JK /a05.wav',
#  'JK /a06.wav',
#  'JK /a07.wav',
#  'JK /a08.wav',
#  'JK /a09.wav',
#  'JK /a10.wav',
#  'JK /a11.wav',
#  'JK /a12.wav',
#  'JK /a13.wav',
#  'JK /a14.wav',
#  'JK /a15.wav',
#  'JK /f01.wav',
#  'JK /f02.wav',
#  'JK /f03.wav',
#  'JK /f04.wav',
#  'JK /f05.wav',
#  'JK /f06.wav',
#  'JK /f07.wav',
#  'JK /f08.wav',
#  'JK /f10.wav',
#  'JK /f11.wav',
#  'JK /f12.wav',
#  'JK /f13.wav',
#  'JK /f14.wav',
#  'JK /f15.wav',
#  'JK /f09.wav',
#  'JK /h01.wav',
#  'JK /h02.wav',
#  'JK /h03.wav',
#  'JK /h04.wav',
#  'JK /h05.wav',
#  'JK /h06.wav',
#  'JK /h07.wav',
#  'JK /h08.wav',
#  'JK /h09.wav',
#  'JK /h10.wav',
#  'JK /h11.wav',
#  'JK /h12.wav',
#  'JK /h13.wav',
#  'JK /h14.wav',
#  'JK /h15.wav',
#  'JK /n01.wav',
#  'JK /n02.wav',
#  'JK /n03.wav',
#  'JK /n04.wav',
#  'JK /n05.wav',
#  'JK /n06.wav',
#  'JK /n07.wav',
#  'JK /n08.wav',
#  'JK /n09.wav',
#  'JK /n10.wav',
#  'JK /n11.wav',
#  'JK /n12.wav',
#  'JK /n13.wav',
#  'JK /n14.wav',
#  'JK /n15.wav',
#  'JK /n20.wav',
#  'JK /n19.wav',
#  'JK /n18.wav',
#  'JK /n17.wav',
#  'JK /n16.wav',
#  'JK /n25.wav',
#  'JK /n23.wav',
#  'JK /n22.wav',
#  'JK /n21.wav',
#  'JK /n26.wav',
#  'JK /n30.wav',
#  'JK /n29.wav',
#  'JK /n28.wav',
#  'JK /n27.wav',
#  'JK /sa05.wav',
#  'JK /sa04.wav',
#  'JK /sa03.wav',
#  'JK /sa02.wav',
#  'JK /sa01.wav',
#  'JK /sa10.wav',
#  'JK /sa09.wav',
#  'JK /sa08.wav',
#  'JK /sa07.wav',
#  'JK /sa06.wav',
#  'JK /sa15.wav',
#  'JK /sa14.wav',
#  'JK /sa13.wav',
#  'JK /sa12.wav',
#  'JK /sa11.wav',
#  'JK /n24.wav',
#  'JE/a01.wav',
#  'JE/a02.wav',
#  'JE/a03.wav',
#  'JE/a04.wav',
#  'JE/a05.wav',
#  'JE/a07.wav',
#  'JE/a06.wav',
#  'JE/a08.wav',
#  'JE/a09.wav',
#  'JE/a10.wav',
#  'JE/a11.wav',
#  'JE/a12.wav',
#  'JE/a13.wav',
#  'JE/a14.wav',
#  'JE/a15.wav',
#  'JE/f05.wav',
#  'JE/f04.wav',
#  'JE/f03.wav',
#  'JE/f02.wav',
#  'JE/f01.wav',
#  'JE/f10.wav',
#  'JE/f09.wav',
#  'JE/f08.wav',
#  'JE/f07.wav',
#  'JE/f06.wav',
#  'JE/f14.wav',
#  'JE/f13.wav',
#  'JE/f12.wav',
#  'JE/f11.wav',
#  'JE/f15.wav',
#  'JE/h05.wav',
#  'JE/h04.wav',
#  'JE/h03.wav',
#  'JE/h02.wav',
#  'JE/h01.wav',
#  'JE/h10.wav',
#  'JE/h09.wav',
#  'JE/h08.wav',
#  'JE/h07.wav',
#  'JE/h06.wav',
#  'JE/h14.wav',
#  'JE/h13.wav',
#  'JE/h12.wav',
#  'JE/h11.wav',
#  'JE/h15.wav',
#  'JE/n18.wav',
#  'JE/n17.wav',
#  'JE/n16.wav',
#  'JE/n05.wav',
#  'JE/n04.wav',
#  'JE/n03.wav',
#  'JE/n02.wav',
#  'JE/n01.wav',
#  'JE/n10.wav',
#  'JE/n09.wav',
#  'JE/n08.wav',
#  'JE/n07.wav',
#  'JE/n06.wav',
#  'JE/n15.wav',
#  'JE/n14.wav',
#  'JE/n13.wav',
#  'JE/n12.wav',
#  'JE/n11.wav',
#  'JE/n20.wav',
#  'JE/n19.wav',
#  'JE/n25.wav',
#  'JE/n24.wav',
#  'JE/n23.wav',
#  'JE/n22.wav',
#  'JE/n21.wav',
#  'JE/n30.wav',
#  'JE/n29.wav',
#  'JE/n28.wav',
#  'JE/n27.wav',
#  'JE/n26.wav',
#  'JE/sa04.wav',
#  'JE/sa03.wav',
#  'JE/sa02.wav',
#  'JE/sa01.wav',
#  'JE/sa13.wav',
#  'JE/sa12.wav',
#  'JE/sa11.wav',
#  'JE/sa05.wav',
#  'JE/sa10.wav',
#  'JE/sa09.wav',
#  'JE/sa08.wav',
#  'JE/sa07.wav',
#  'JE/sa06.wav',
#  'JE/sa15.wav',
#  'JE/sa14.wav',
#  'DC/a15.wav',
#  'DC/a14.wav',
#  'DC/a05.wav',
#  'DC/a04.wav',
#  'DC/a03.wav',
#  'DC/a02.wav',
#  'DC/a01.wav',
#  'DC/a06.wav',
#  'DC/a07.wav',
#  'DC/a08.wav',
#  'DC/a09.wav',
#  'DC/a10.wav',
#  'DC/a13.wav',
#  'DC/a12.wav',
#  'DC/a11.wav',
#  'DC/f01.wav',
#  'DC/f02.wav',
#  'DC/f03.wav',
#  'DC/f04.wav',
#  'DC/f05.wav',
#  'DC/f10.wav',
#  'DC/f09.wav',
#  'DC/f08.wav',
#  'DC/f07.wav',
#  'DC/f06.wav',
#  'DC/f15.wav',
#  'DC/f14.wav',
#  'DC/f13.wav',
#  'DC/f12.wav',
#  'DC/f11.wav',
#  'DC/h01.wav',
#  'DC/h02.wav',
#  'DC/h03.wav',
#  'DC/h04.wav',
#  'DC/h05.wav',
#  'DC/h10.wav',
#  'DC/h09.wav',
#  'DC/h08.wav',
#  'DC/h07.wav',
#  'DC/h06.wav',
#  'DC/h11.wav',
#  'DC/h12.wav',
#  'DC/h13.wav',
#  'DC/h14.wav',
#  'DC/h15.wav',
#  'DC/n05.wav',
#  'DC/n04.wav',
#  'DC/n03.wav',
#  'DC/n02.wav',
#  'DC/n01.wav',
#  'DC/n06.wav',
#  'DC/n07.wav',
#  'DC/n08.wav',
#  'DC/n09.wav',
#  'DC/n10.wav',
#  'DC/n11.wav',
#  'DC/n12.wav',
#  'DC/n13.wav',
#  'DC/n14.wav',
#  'DC/n15.wav',
#  'DC/n20.wav',
#  'DC/n19.wav',
#  'DC/n18.wav',
#  'DC/n17.wav',
#  'DC/n16.wav',
#  'DC/n21.wav',
#  'DC/n22.wav',
#  'DC/n23.wav',
#  'DC/n24.wav',
#  'DC/n25.wav',
#  'DC/n26.wav',
#  'DC/n27.wav',
#  'DC/n28.wav',
#  'DC/n29.wav',
#  'DC/n30.wav',
#  'DC/sa01.wav',
#  'DC/sa02.wav',
#  'DC/sa03.wav',
#  'DC/sa04.wav',
#  'DC/sa09.wav',
#  'DC/sa08.wav',
#  'DC/sa07.wav',
#  'DC/sa06.wav',
#  'DC/sa11.wav',
#  'DC/sa12.wav',
#  'DC/sa13.wav',
#  'DC/sa14.wav',
#  'DC/sa15.wav',
#  'DC/sa05.wav',
#  'DC/sa10.wav']

# %%
video_name
# Out:
# ['sad/a01kl.avi',
#  'sad/a02kl.avi',
#  'sad/a03kl.avi',
#  'sad/a04kl.avi',
#  'sad/a05kl.avi',
#  'sad/a07kl.avi',
#  'sad/a10kl.avi',
#  'sad/a09kl.avi',
#  'sad/a08kl.avi',
#  'sad/a06kl.avi',
#  'sad/a15kl.avi',
#  'sad/a14kl.avi',
#  'sad/a13kl.avi',
#  'sad/a12kl.avi',
#  'sad/a11kl.avi',
#  'angry/f05kl.avi',
#  'angry/f04kl.avi',
#  'angry/f03kl.avi',
#  'angry/f02kl.avi',
#  'angry/f01kl.avi',
#  'angry/f10kl.avi',
#  'angry/f09kl.avi',
#  'angry/f08kl.avi',
#  'angry/f07kl.avi',
#  'angry/f06kl.avi',
#  'angry/f15kl.avi',
#  'angry/f14kl.avi',
#  'angry/f13kl.avi',
#  'angry/f12kl.avi',
#  'angry/f11kl.avi',
#  'calm/h05kl.avi',
#  'calm/h04kl.avi',
#  'calm/h03kl.avi',
#  'calm/h02kl.avi',
#  'calm/h01kl.avi',
#  'calm/h10kl.avi',
#  'calm/h09kl.avi',
#  'calm/h08kl.avi',
#  'calm/h07kl.avi',
#  'calm/h06kl.avi',
#  'calm/h15kl.avi',
#  'calm/h14kl.avi',
#  'calm/h13kl.avi',
#  'calm/h12kl.avi',
#  'calm/h11kl.avi',
#  'happy/sa05kl.avi',
#  'happy/sa04kl.avi',
#  'happy/sa03kl.avi',
#  'happy/sa02kl.avi',
#  'happy/sa01kl.avi',
#  'happy/sa10kl.avi',
#  'happy/sa09kl.avi',
#  'happy/sa08kl.avi',
#  'happy/sa07kl.avi',
#  'happy/sa06kl.avi',
#  'happy/sa11kl.avi',
#  'happy/sa14kl.avi',
#  'happy/sa13kl.avi',
#  'happy/sa12kl.avi',
#  'happy/sa15kl.avi',
#  'neutral/n01kl.avi',
#  'neutral/n05kl.avi',
#  'neutral/n04kl.avi',
#  'neutral/n03kl.avi',
#  'neutral/n02kl.avi',
#  'neutral/n10kl.avi',
#  'neutral/n09kl.avi',
#  'neutral/n08kl.avi',
#  'neutral/n07kl.avi',
#  'neutral/n06kl.avi',
#  'neutral/n20kl.avi',
#  'neutral/n19kl.avi',
#  'neutral/n18kl.avi',
#  'neutral/n17kl.avi',
#  'neutral/n16kl.avi',
#  'neutral/n25kl.avi',
#  'neutral/n24kl.avi',
#  'neutral/n23kl.avi',
#  'neutral/n22kl.avi',
#  'neutral/n21kl.avi',
#  'neutral/n30kl.avi',
#  'neutral/n29kl.avi',
#  'neutral/n28kl.avi',
#  'neutral/n27kl.avi',
#  'neutral/n26kl.avi',
#  'neutral/n15kl.avi',
#  'neutral/n14kl.avi',
#  'neutral/n13kl.avi',
#  'neutral/n12kl.avi',
#  'neutral/n11kl.avi',
#  'sad/a01jk .avi',
#  'sad/a02jk .avi',
#  'sad/a03jk .avi',
#  'sad/a04jk .avi',
#  'sad/a05jk .avi',
#  'sad/a06jk .avi',
#  'sad/a07jk .avi',
#  'sad/a08jk .avi',
#  'sad/a09jk .avi',
#  'sad/a10jk .avi',
#  'sad/a11jk .avi',
#  'sad/a12jk .avi',
#  'sad/a13jk .avi',
#  'sad/a14jk .avi',
#  'sad/a15jk .avi',
#  'angry/f01jk .avi',
#  'angry/f02jk .avi',
#  'angry/f03jk .avi',
#  'angry/f04jk .avi',
#  'angry/f05jk .avi',
#  'angry/f06jk .avi',
#  'angry/f07jk .avi',
#  'angry/f08jk .avi',
#  'angry/f10jk .avi',
#  'angry/f11jk .avi',
#  'angry/f12jk .avi',
#  'angry/f13jk .avi',
#  'angry/f14jk .avi',
#  'angry/f15jk .avi',
#  'angry/f09jk .avi',
#  'calm/h01jk .avi',
#  'calm/h02jk .avi',
#  'calm/h03jk .avi',
#  'calm/h04jk .avi',
#  'calm/h05jk .avi',
#  'calm/h06jk .avi',
#  'calm/h07jk .avi',
#  'calm/h08jk .avi',
#  'calm/h09jk .avi',
#  'calm/h10jk .avi',
#  'calm/h11jk .avi',
#  'calm/h12jk .avi',
#  'calm/h13jk .avi',
#  'calm/h14jk .avi',
#  'calm/h15jk .avi',
#  'neutral/n01jk .avi',
#  'neutral/n02jk .avi',
#  'neutral/n03jk .avi',
#  'neutral/n04jk .avi',
#  'neutral/n05jk .avi',
#  'neutral/n06jk .avi',
#  'neutral/n07jk .avi',
#  'neutral/n08jk .avi',
#  'neutral/n09jk .avi',
#  'neutral/n10jk .avi',
#  'neutral/n11jk .avi',
#  'neutral/n12jk .avi',
#  'neutral/n13jk .avi',
#  'neutral/n14jk .avi',
#  'neutral/n15jk .avi',
#  'neutral/n20jk .avi',
#  'neutral/n19jk .avi',
#  'neutral/n18jk .avi',
#  'neutral/n17jk .avi',
#  'neutral/n16jk .avi',
#  'neutral/n25jk .avi',
#  'neutral/n23jk .avi',
#  'neutral/n22jk .avi',
#  'neutral/n21jk .avi',
#  'neutral/n26jk .avi',
#  'neutral/n30jk .avi',
#  'neutral/n29jk .avi',
#  'neutral/n28jk .avi',
#  'neutral/n27jk .avi',
#  'happy/sa05jk .avi',
#  'happy/sa04jk .avi',
#  'happy/sa03jk .avi',
#  'happy/sa02jk .avi',
#  'happy/sa01jk .avi',
#  'happy/sa10jk .avi',
#  'happy/sa09jk .avi',
#  'happy/sa08jk .avi',
#  'happy/sa07jk .avi',
#  'happy/sa06jk .avi',
#  'happy/sa15jk .avi',
#  'happy/sa14jk .avi',
#  'happy/sa13jk .avi',
#  'happy/sa12jk .avi',
#  'happy/sa11jk .avi',
#  'neutral/n24jk .avi',
#  'sad/a01je.avi',
#  'sad/a02je.avi',
#  'sad/a03je.avi',
#  'sad/a04je.avi',
#  'sad/a05je.avi',
#  'sad/a07je.avi',
#  'sad/a06je.avi',
#  'sad/a08je.avi',
#  'sad/a09je.avi',
#  'sad/a10je.avi',
#  'sad/a11je.avi',
#  'sad/a12je.avi',
#  'sad/a13je.avi',
#  'sad/a14je.avi',
#  'sad/a15je.avi',
#  'angry/f05je.avi',
#  'angry/f04je.avi',
#  'angry/f03je.avi',
#  'angry/f02je.avi',
#  'angry/f01je.avi',
#  'angry/f10je.avi',
#  'angry/f09je.avi',
#  'angry/f08je.avi',
#  'angry/f07je.avi',
#  'angry/f06je.avi',
#  'angry/f14je.avi',
#  'angry/f13je.avi',
#  'angry/f12je.avi',
#  'angry/f11je.avi',
#  'angry/f15je.avi',
#  'calm/h05je.avi',
#  'calm/h04je.avi',
#  'calm/h03je.avi',
#  'calm/h02je.avi',
#  'calm/h01je.avi',
#  'calm/h10je.avi',
#  'calm/h09je.avi',
#  'calm/h08je.avi',
#  'calm/h07je.avi',
#  'calm/h06je.avi',
#  'calm/h14je.avi',
#  'calm/h13je.avi',
#  'calm/h12je.avi',
#  'calm/h11je.avi',
#  'calm/h15je.avi',
#  'neutral/n18je.avi',
#  'neutral/n17je.avi',
#  'neutral/n16je.avi',
#  'neutral/n05je.avi',
#  'neutral/n04je.avi',
#  'neutral/n03je.avi',
#  'neutral/n02je.avi',
#  'neutral/n01je.avi',
#  'neutral/n10je.avi',
#  'neutral/n09je.avi',
#  'neutral/n08je.avi',
#  'neutral/n07je.avi',
#  'neutral/n06je.avi',
#  'neutral/n15je.avi',
#  'neutral/n14je.avi',
#  'neutral/n13je.avi',
#  'neutral/n12je.avi',
#  'neutral/n11je.avi',
#  'neutral/n20je.avi',
#  'neutral/n19je.avi',
#  'neutral/n25je.avi',
#  'neutral/n24je.avi',
#  'neutral/n23je.avi',
#  'neutral/n22je.avi',
#  'neutral/n21je.avi',
#  'neutral/n30je.avi',
#  'neutral/n29je.avi',
#  'neutral/n28je.avi',
#  'neutral/n27je.avi',
#  'neutral/n26je.avi',
#  'happy/sa04je.avi',
#  'happy/sa03je.avi',
#  'happy/sa02je.avi',
#  'happy/sa01je.avi',
#  'happy/sa13je.avi',
#  'happy/sa12je.avi',
#  'happy/sa11je.avi',
#  'happy/sa05je.avi',
#  'happy/sa10je.avi',
#  'happy/sa09je.avi',
#  'happy/sa08je.avi',
#  'happy/sa07je.avi',
#  'happy/sa06je.avi',
#  'happy/sa15je.avi',
#  'happy/sa14je.avi',
#  'sad/a15dc.avi',
#  'sad/a14dc.avi',
#  'sad/a05dc.avi',
#  'sad/a04dc.avi',
#  'sad/a03dc.avi',
#  'sad/a02dc.avi',
#  'sad/a01dc.avi',
#  'sad/a06dc.avi',
#  'sad/a07dc.avi',
#  'sad/a08dc.avi',
#  'sad/a09dc.avi',
#  'sad/a10dc.avi',
#  'sad/a13dc.avi',
#  'sad/a12dc.avi',
#  'sad/a11dc.avi',
#  'angry/f01dc.avi',
#  'angry/f02dc.avi',
#  'angry/f03dc.avi',
#  'angry/f04dc.avi',
#  'angry/f05dc.avi',
#  'angry/f10dc.avi',
#  'angry/f09dc.avi',
#  'angry/f08dc.avi',
#  'angry/f07dc.avi',
#  'angry/f06dc.avi',
#  'angry/f15dc.avi',
#  'angry/f14dc.avi',
#  'angry/f13dc.avi',
#  'angry/f12dc.avi',
#  'angry/f11dc.avi',
#  'calm/h01dc.avi',
#  'calm/h02dc.avi',
#  'calm/h03dc.avi',
#  'calm/h04dc.avi',
#  'calm/h05dc.avi',
#  'calm/h10dc.avi',
#  'calm/h09dc.avi',
#  'calm/h08dc.avi',
#  'calm/h07dc.avi',
#  'calm/h06dc.avi',
#  'calm/h11dc.avi',
#  'calm/h12dc.avi',
#  'calm/h13dc.avi',
#  'calm/h14dc.avi',
#  'calm/h15dc.avi',
#  'neutral/n05dc.avi',
#  'neutral/n04dc.avi',
#  'neutral/n03dc.avi',
#  'neutral/n02dc.avi',
#  'neutral/n01dc.avi',
#  'neutral/n06dc.avi',
#  'neutral/n07dc.avi',
#  'neutral/n08dc.avi',
#  'neutral/n09dc.avi',
#  'neutral/n10dc.avi',
#  'neutral/n11dc.avi',
#  'neutral/n12dc.avi',
#  'neutral/n13dc.avi',
#  'neutral/n14dc.avi',
#  'neutral/n15dc.avi',
#  'neutral/n20dc.avi',
#  'neutral/n19dc.avi',
#  'neutral/n18dc.avi',
#  'neutral/n17dc.avi',
#  'neutral/n16dc.avi',
#  'neutral/n21dc.avi',
#  'neutral/n22dc.avi',
#  'neutral/n23dc.avi',
#  'neutral/n24dc.avi',
#  'neutral/n25dc.avi',
#  'neutral/n26dc.avi',
#  'neutral/n27dc.avi',
#  'neutral/n28dc.avi',
#  'neutral/n29dc.avi',
#  'neutral/n30dc.avi',
#  'happy/sa01dc.avi',
#  'happy/sa02dc.avi',
#  'happy/sa03dc.avi',
#  'happy/sa04dc.avi',
#  'happy/sa09dc.avi',
#  'happy/sa08dc.avi',
#  'happy/sa07dc.avi',
#  'happy/sa06dc.avi',
#  'happy/sa11dc.avi',
#  'happy/sa12dc.avi',
#  'happy/sa13dc.avi',
#  'happy/sa14dc.avi',
#  'happy/sa15dc.avi',
#  'happy/sa05dc.avi',
#  'happy/sa10dc.avi']

# %%
seed_constant = np.random.randint(1000000)
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)
seed_constant
# Out:
# 588156

# %%
from sklearn.model_selection import train_test_split
# Split the Data into Train ( 80% ) and Test Set ( 20% ).
audio_train, audio_test, labels_train, labels_test,video_train_path,video_test_path = train_test_split(audio_name, labels,video_name,
                                                                            test_size = 0.10, shuffle = True,
                                                                            random_state = seed_constant)

# %%
# Split train the Data into Train ( 80% ) and valid Set ( 20% ).
audio_train, audio_valid, labels_train, labels_valid,video_train_path,video_valid_path = train_test_split(audio_train, labels_train,video_train_path,
                                                                            test_size = 0.11, shuffle = True,
                                                                            random_state = seed_constant)

# %%
#288,36,36
len(audio_train),len(audio_valid),len(audio_test),len(labels_train),len(labels_valid),len(labels_test),len(video_train_path),len(video_valid_path),len(video_test_path)
# Out:
# (288, 36, 36, 288, 36, 36, 288, 36, 36)

# %%
import joblib

save_dir = '/content/drive/My Drive/fusion/savee/audio/data_set/expert1'

savedvX = joblib.dump(labels_train, os.path.join(save_dir, 'train/labels_train'))
savedvX = joblib.dump(labels_test, os.path.join(save_dir, 'test/labels_test'))
savedvX = joblib.dump(labels_valid, os.path.join(save_dir, 'valid/labels_valid'))
savedvX = joblib.dump(video_train_path, os.path.join(save_dir, 'train/video_train_path'))
savedvX = joblib.dump(video_test_path, os.path.join(save_dir, 'test/video_test_path'))
savedvX = joblib.dump(video_valid_path, os.path.join(save_dir, 'valid/video_valid_path'))

# %%
#radvass speech and song
import time
import os
import librosa
from librosa import display
import matplotlib.pyplot as plt
DATASET_DIR = '/content/drive/My Drive/SAVEE/'
count=0
x_test = []
X_valid=[]
start_time = time.time()

for path in audio_valid :
      try:
        count +=1
        #Load librosa array, obtain mfcss, store the file and the mcss information in a new array
        X, sample_rate = librosa.load(DATASET_DIR+path, res_type='kaiser_fast')
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) 
        # The instruction below converts the labels (from 1 to 8) to a series from 0 to 7
        # This is because our predictor needs to start from 0 otherwise it will try to predict also 0.
        #emo = int(file[7:8]) - 1 
        #arr = X, emo
        X_valid.append(mfccs)
      # If the file is not valid, skip it
      except ValueError:
        continue

for path in audio_test:
      try:
        count +=1
        #Load librosa array, obtain mfcss, store the file and the mcss information in a new array
        X, sample_rate = librosa.load(DATASET_DIR+path, res_type='kaiser_fast')
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) 
        # The instruction below converts the labels (from 1 to 8) to a series from 0 to 7
        # This is because our predictor needs to start from 0 otherwise it will try to predict also 0.
        #emo = int(file[7:8]) - 1 
        #arr = X, emo
        x_test.append(mfccs)
      # If the file is not valid, skip it
      except ValueError:
        continue
print("--- Data loaded. Loading time: %s seconds ---" % (time.time() - start_time))
# Out:
# --- Data loaded. Loading time: 6.922230243682861 seconds ---

# %%
X_valid=np.asarray(X_valid)
x_test=np.asarray(x_test)
X_valid.shape,x_test.shape
# Out:
# ((36, 40), (36, 40))

# %%
train_lst=[]
for i in range(len(audio_train)):
  X, sample_rate = librosa.load(DATASET_DIR+audio_train[i], res_type='kaiser_fast')
  emo=labels_train[i]
  x=X
  arr=x,emo
  train_lst.append(arr)
  x=librosa.effects.time_stretch(X,0.5)
  arr=x,emo
  train_lst.append(arr)
  x=librosa.effects.time_stretch(X,1.5)
  arr=x,emo
  train_lst.append(arr)
  x=librosa.effects.pitch_shift(X,sample_rate,2)
  arr=x,emo
  train_lst.append(arr)

# %%
x_train, y_train = zip(*train_lst)

# %%
x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
y_train.shape
# Out:
# (1152,)

# %%
X_train=[]
for i in range(x_train.size):
  X_train.append(np.mean(librosa.feature.mfcc(y=x_train[i], sr=sample_rate, n_mfcc=40).T,axis=0))

# %%
X_train=np.asarray(X_train)
labels_valid=np.asarray(labels_valid)
labels_test=np.asarray(labels_test)
X_train.shape,y_train.shape,X_valid.shape,labels_valid.shape,x_test.shape,labels_test.shape
# Out:
# ((1152, 40), (1152,), (36, 40), (36,), (36, 40), (36,))

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras import optimizers
from keras.models import InputLayer

model = Sequential(InputLayer((40,1)))
model.add(BatchNormalization())

model.add(Conv1D(128, 12,padding='same', ))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=(5)))


model.add(Conv1D(256,12,padding='same',))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(MaxPooling1D(pool_size=(5)))

model.add(Flatten())
model.add(Dense(5))
model.add(Activation('softmax'))

opt = tf.keras.optimizers.Adam(lr=0.0002)
#opt = tf.keras.optimizers.RMSprop(lr=0.0001, rho=0.9, epsilon=1e-07, decay=0.0)
#opt = tf.keras.optimizers.SGD(lr=0.001, momentum=0.0, decay=0.0, nesterov=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 40, 1)            4
#  ormalization)
#
#  conv1d (Conv1D)             (None, 40, 128)           1664
#
#  batch_normalization_1 (Batc  (None, 40, 128)          512
#  hNormalization)
#
#  activation (Activation)     (None, 40, 128)           0
#
#  dropout (Dropout)           (None, 40, 128)           0
#
#  max_pooling1d (MaxPooling1D  (None, 8, 128)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 8, 256)            393472
#
#  batch_normalization_2 (Batc  (None, 8, 256)           1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8, 256)            0
#
#  dropout_1 (Dropout)         (None, 8, 256)            0
#
#  max_pooling1d_1 (MaxPooling  (None, 1, 256)           0
#  1D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 5)                 1285
#
#  activation_2 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 397,961
# Trainable params: 397,191
# Non-trainable params: 770
# _________________________________________________________________

# %%
# Create an Instance of Early Stopping Callback.
#early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 25, mode = 'min', restore_best_weights = True)
 
# Compile the model and specify loss function, optimizer and metrics to the model.
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = opt, metrics = ["accuracy"])

# Start training the model.
cnnhistory = model.fit(X_train, y_train, epochs = 200, batch_size = 16 ,
                                             #shuffle = True,
                        validation_data=(X_valid, labels_valid))
                                             #, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/200
# 72/72 [==============================] - 3s 9ms/step - loss: 1.7103 - accuracy: 0.3724 - val_loss: 1.7724 - val_accuracy: 0.1667
# Epoch 2/200
# 72/72 [==============================] - 0s 5ms/step - loss: 1.3080 - accuracy: 0.4939 - val_loss: 2.2876 - val_accuracy: 0.1667
# Epoch 3/200
# 72/72 [==============================] - 0s 5ms/step - loss: 1.0945 - accuracy: 0.5972 - val_loss: 2.7363 - val_accuracy: 0.1667
# Epoch 4/200
# 72/72 [==============================] - 0s 5ms/step - loss: 1.0753 - accuracy: 0.6042 - val_loss: 2.5400 - val_accuracy: 0.1667
# Epoch 5/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.9859 - accuracy: 0.6467 - val_loss: 2.5727 - val_accuracy: 0.1667
# Epoch 6/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.8594 - accuracy: 0.6589 - val_loss: 2.2445 - val_accuracy: 0.1667
# Epoch 7/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.8341 - accuracy: 0.6701 - val_loss: 1.3648 - val_accuracy: 0.4444
# Epoch 8/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.7897 - accuracy: 0.6797 - val_loss: 1.1737 - val_accuracy: 0.4722
# Epoch 9/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.7805 - accuracy: 0.6875 - val_loss: 1.0852 - val_accuracy: 0.5556
# Epoch 10/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.7402 - accuracy: 0.7092 - val_loss: 0.9273 - val_accuracy: 0.5833
# Epoch 11/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.7177 - accuracy: 0.6988 - val_loss: 1.0068 - val_accuracy: 0.5556
# Epoch 12/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6967 - accuracy: 0.7179 - val_loss: 1.0769 - val_accuracy: 0.6111
# Epoch 13/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6964 - accuracy: 0.7179 - val_loss: 1.0616 - val_accuracy: 0.5556
# Epoch 14/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6600 - accuracy: 0.7378 - val_loss: 0.9346 - val_accuracy: 0.5000
# Epoch 15/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6582 - accuracy: 0.7231 - val_loss: 0.9369 - val_accuracy: 0.5833
# Epoch 16/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.5909 - accuracy: 0.7561 - val_loss: 0.8723 - val_accuracy: 0.6389
# Epoch 17/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6004 - accuracy: 0.7569 - val_loss: 1.1003 - val_accuracy: 0.5556
# Epoch 18/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.5950 - accuracy: 0.7656 - val_loss: 1.0080 - val_accuracy: 0.5833
# Epoch 19/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.5517 - accuracy: 0.7665 - val_loss: 0.8931 - val_accuracy: 0.6389
# Epoch 20/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.5338 - accuracy: 0.7856 - val_loss: 0.7836 - val_accuracy: 0.6389
# Epoch 21/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.5342 - accuracy: 0.7786 - val_loss: 1.0014 - val_accuracy: 0.6111
# Epoch 22/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.5699 - accuracy: 0.7622 - val_loss: 0.8372 - val_accuracy: 0.5278
# Epoch 23/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.5113 - accuracy: 0.7882 - val_loss: 0.9970 - val_accuracy: 0.6389
# Epoch 24/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.5030 - accuracy: 0.7839 - val_loss: 1.0170 - val_accuracy: 0.6111
# Epoch 25/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.4639 - accuracy: 0.8203 - val_loss: 0.7744 - val_accuracy: 0.6944
# Epoch 26/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.4721 - accuracy: 0.8012 - val_loss: 0.8072 - val_accuracy: 0.6667
# Epoch 27/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.4276 - accuracy: 0.8203 - val_loss: 0.8754 - val_accuracy: 0.5833
# Epoch 28/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.4167 - accuracy: 0.8333 - val_loss: 0.6715 - val_accuracy: 0.6944
# Epoch 29/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.4345 - accuracy: 0.8194 - val_loss: 0.9217 - val_accuracy: 0.6389
# Epoch 30/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.4217 - accuracy: 0.8264 - val_loss: 0.6576 - val_accuracy: 0.7222
# Epoch 31/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3950 - accuracy: 0.8359 - val_loss: 0.7062 - val_accuracy: 0.7222
# Epoch 32/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3832 - accuracy: 0.8394 - val_loss: 0.9102 - val_accuracy: 0.6944
# Epoch 33/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3993 - accuracy: 0.8247 - val_loss: 0.7313 - val_accuracy: 0.6667
# Epoch 34/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3720 - accuracy: 0.8472 - val_loss: 0.9821 - val_accuracy: 0.6667
# Epoch 35/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3663 - accuracy: 0.8420 - val_loss: 0.8518 - val_accuracy: 0.5833
# Epoch 36/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3664 - accuracy: 0.8516 - val_loss: 0.8083 - val_accuracy: 0.7222
# Epoch 37/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3230 - accuracy: 0.8750 - val_loss: 0.7437 - val_accuracy: 0.7500
# Epoch 38/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3317 - accuracy: 0.8663 - val_loss: 0.9438 - val_accuracy: 0.6389
# Epoch 39/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3240 - accuracy: 0.8689 - val_loss: 0.7054 - val_accuracy: 0.7222
# Epoch 40/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3184 - accuracy: 0.8689 - val_loss: 0.9537 - val_accuracy: 0.6667
# Epoch 41/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3199 - accuracy: 0.8646 - val_loss: 0.7559 - val_accuracy: 0.7500
# Epoch 42/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3405 - accuracy: 0.8550 - val_loss: 0.8574 - val_accuracy: 0.6667
# Epoch 43/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3182 - accuracy: 0.8628 - val_loss: 0.9881 - val_accuracy: 0.6944
# Epoch 44/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3241 - accuracy: 0.8637 - val_loss: 0.7586 - val_accuracy: 0.7778
# Epoch 45/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2877 - accuracy: 0.8924 - val_loss: 0.7066 - val_accuracy: 0.7500
# Epoch 46/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2544 - accuracy: 0.8898 - val_loss: 0.8038 - val_accuracy: 0.6667
# Epoch 47/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2568 - accuracy: 0.8993 - val_loss: 0.7105 - val_accuracy: 0.7222
# Epoch 48/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2396 - accuracy: 0.9045 - val_loss: 0.7940 - val_accuracy: 0.6944
# Epoch 49/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2232 - accuracy: 0.9141 - val_loss: 0.6052 - val_accuracy: 0.6944
# Epoch 50/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3023 - accuracy: 0.8828 - val_loss: 0.8830 - val_accuracy: 0.6389
# Epoch 51/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2610 - accuracy: 0.8924 - val_loss: 0.6138 - val_accuracy: 0.6944
# Epoch 52/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2496 - accuracy: 0.8915 - val_loss: 0.7748 - val_accuracy: 0.6944
# Epoch 53/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2277 - accuracy: 0.9036 - val_loss: 0.7283 - val_accuracy: 0.7222
# Epoch 54/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2274 - accuracy: 0.9089 - val_loss: 0.7902 - val_accuracy: 0.7500
# Epoch 55/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2481 - accuracy: 0.9002 - val_loss: 0.7777 - val_accuracy: 0.7500
# Epoch 56/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2104 - accuracy: 0.9219 - val_loss: 0.8284 - val_accuracy: 0.7222
# Epoch 57/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2136 - accuracy: 0.9210 - val_loss: 0.8640 - val_accuracy: 0.7222
# Epoch 58/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2062 - accuracy: 0.9227 - val_loss: 0.7380 - val_accuracy: 0.7500
# Epoch 59/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1933 - accuracy: 0.9280 - val_loss: 0.6183 - val_accuracy: 0.7778
# Epoch 60/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1962 - accuracy: 0.9210 - val_loss: 0.8259 - val_accuracy: 0.7222
# Epoch 61/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2188 - accuracy: 0.9149 - val_loss: 0.8481 - val_accuracy: 0.6944
# Epoch 62/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1851 - accuracy: 0.9306 - val_loss: 0.6122 - val_accuracy: 0.7500
# Epoch 63/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1896 - accuracy: 0.9245 - val_loss: 0.6394 - val_accuracy: 0.6667
# Epoch 64/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1723 - accuracy: 0.9375 - val_loss: 0.6356 - val_accuracy: 0.7222
# Epoch 65/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1713 - accuracy: 0.9271 - val_loss: 0.7868 - val_accuracy: 0.7500
# Epoch 66/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1585 - accuracy: 0.9384 - val_loss: 0.7134 - val_accuracy: 0.7778
# Epoch 67/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1723 - accuracy: 0.9332 - val_loss: 0.7124 - val_accuracy: 0.6667
# Epoch 68/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1684 - accuracy: 0.9323 - val_loss: 0.7050 - val_accuracy: 0.6944
# Epoch 69/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1983 - accuracy: 0.9193 - val_loss: 0.7191 - val_accuracy: 0.7222
# Epoch 70/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1477 - accuracy: 0.9479 - val_loss: 0.7687 - val_accuracy: 0.7500
# Epoch 71/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1686 - accuracy: 0.9384 - val_loss: 0.6282 - val_accuracy: 0.7778
# Epoch 72/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1585 - accuracy: 0.9427 - val_loss: 0.6027 - val_accuracy: 0.7500
# Epoch 73/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1387 - accuracy: 0.9453 - val_loss: 0.7845 - val_accuracy: 0.7222
# Epoch 74/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1394 - accuracy: 0.9453 - val_loss: 0.6745 - val_accuracy: 0.7500
# Epoch 75/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1443 - accuracy: 0.9436 - val_loss: 0.8811 - val_accuracy: 0.7222
# Epoch 76/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1444 - accuracy: 0.9479 - val_loss: 0.6036 - val_accuracy: 0.7778
# Epoch 77/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1618 - accuracy: 0.9332 - val_loss: 0.6300 - val_accuracy: 0.7778
# Epoch 78/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1464 - accuracy: 0.9410 - val_loss: 0.7717 - val_accuracy: 0.7222
# Epoch 79/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1316 - accuracy: 0.9523 - val_loss: 0.7444 - val_accuracy: 0.7222
# Epoch 80/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1138 - accuracy: 0.9618 - val_loss: 0.8305 - val_accuracy: 0.7222
# Epoch 81/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1188 - accuracy: 0.9549 - val_loss: 0.7663 - val_accuracy: 0.7778
# Epoch 82/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1306 - accuracy: 0.9488 - val_loss: 0.6448 - val_accuracy: 0.7222
# Epoch 83/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1097 - accuracy: 0.9609 - val_loss: 0.8251 - val_accuracy: 0.7222
# Epoch 84/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1284 - accuracy: 0.9557 - val_loss: 0.7238 - val_accuracy: 0.7500
# Epoch 85/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1105 - accuracy: 0.9609 - val_loss: 0.6650 - val_accuracy: 0.7778
# Epoch 86/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1253 - accuracy: 0.9549 - val_loss: 0.8225 - val_accuracy: 0.7500
# Epoch 87/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1121 - accuracy: 0.9609 - val_loss: 0.9747 - val_accuracy: 0.7500
# Epoch 88/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0936 - accuracy: 0.9688 - val_loss: 0.8464 - val_accuracy: 0.7500
# Epoch 89/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1003 - accuracy: 0.9679 - val_loss: 0.7071 - val_accuracy: 0.7778
# Epoch 90/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1182 - accuracy: 0.9575 - val_loss: 0.6901 - val_accuracy: 0.7500
# Epoch 91/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1238 - accuracy: 0.9531 - val_loss: 0.6493 - val_accuracy: 0.6944
# Epoch 92/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0974 - accuracy: 0.9731 - val_loss: 0.6475 - val_accuracy: 0.7222
# Epoch 93/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1044 - accuracy: 0.9609 - val_loss: 0.8524 - val_accuracy: 0.7222
# Epoch 94/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0834 - accuracy: 0.9748 - val_loss: 0.8789 - val_accuracy: 0.6389
# Epoch 95/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0818 - accuracy: 0.9714 - val_loss: 0.6840 - val_accuracy: 0.7500
# Epoch 96/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0904 - accuracy: 0.9696 - val_loss: 0.6466 - val_accuracy: 0.7500
# Epoch 97/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0866 - accuracy: 0.9670 - val_loss: 0.7910 - val_accuracy: 0.7778
# Epoch 98/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0897 - accuracy: 0.9661 - val_loss: 0.7809 - val_accuracy: 0.7778
# Epoch 99/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0906 - accuracy: 0.9688 - val_loss: 0.7554 - val_accuracy: 0.7222
# Epoch 100/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0980 - accuracy: 0.9670 - val_loss: 0.8298 - val_accuracy: 0.7500
# Epoch 101/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0899 - accuracy: 0.9653 - val_loss: 0.5767 - val_accuracy: 0.7500
# Epoch 102/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0841 - accuracy: 0.9705 - val_loss: 0.6761 - val_accuracy: 0.7500
# Epoch 103/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0721 - accuracy: 0.9783 - val_loss: 0.7782 - val_accuracy: 0.7500
# Epoch 104/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0844 - accuracy: 0.9740 - val_loss: 0.6786 - val_accuracy: 0.7778
# Epoch 105/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0809 - accuracy: 0.9696 - val_loss: 0.7969 - val_accuracy: 0.7222
# Epoch 106/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0592 - accuracy: 0.9792 - val_loss: 0.8247 - val_accuracy: 0.7500
# Epoch 107/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0962 - accuracy: 0.9635 - val_loss: 0.6455 - val_accuracy: 0.7778
# Epoch 108/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0853 - accuracy: 0.9661 - val_loss: 0.8501 - val_accuracy: 0.7500
# Epoch 109/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0763 - accuracy: 0.9731 - val_loss: 0.8338 - val_accuracy: 0.7778
# Epoch 110/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0516 - accuracy: 0.9861 - val_loss: 0.7484 - val_accuracy: 0.7778
# Epoch 111/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0590 - accuracy: 0.9809 - val_loss: 0.7436 - val_accuracy: 0.7222
# Epoch 112/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0650 - accuracy: 0.9783 - val_loss: 0.8055 - val_accuracy: 0.7778
# Epoch 113/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0852 - accuracy: 0.9705 - val_loss: 0.7598 - val_accuracy: 0.7500
# Epoch 114/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1493 - accuracy: 0.9436 - val_loss: 0.7626 - val_accuracy: 0.7500
# Epoch 115/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0683 - accuracy: 0.9774 - val_loss: 0.6776 - val_accuracy: 0.7500
# Epoch 116/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0780 - accuracy: 0.9722 - val_loss: 0.7100 - val_accuracy: 0.8056
# Epoch 117/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0758 - accuracy: 0.9696 - val_loss: 0.9374 - val_accuracy: 0.7222
# Epoch 118/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0619 - accuracy: 0.9809 - val_loss: 1.0113 - val_accuracy: 0.7778
# Epoch 119/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0506 - accuracy: 0.9852 - val_loss: 0.7190 - val_accuracy: 0.7778
# Epoch 120/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0547 - accuracy: 0.9835 - val_loss: 0.6404 - val_accuracy: 0.6944
# Epoch 121/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0648 - accuracy: 0.9783 - val_loss: 0.7489 - val_accuracy: 0.7500
# Epoch 122/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0725 - accuracy: 0.9705 - val_loss: 0.8409 - val_accuracy: 0.8056
# Epoch 123/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0714 - accuracy: 0.9740 - val_loss: 0.7637 - val_accuracy: 0.6944
# Epoch 124/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0691 - accuracy: 0.9722 - val_loss: 0.9105 - val_accuracy: 0.6944
# Epoch 125/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0492 - accuracy: 0.9870 - val_loss: 0.9583 - val_accuracy: 0.7778
# Epoch 126/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0569 - accuracy: 0.9844 - val_loss: 0.7019 - val_accuracy: 0.7222
# Epoch 127/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0556 - accuracy: 0.9835 - val_loss: 0.6700 - val_accuracy: 0.7222
# Epoch 128/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0650 - accuracy: 0.9757 - val_loss: 0.6310 - val_accuracy: 0.7778
# Epoch 129/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0542 - accuracy: 0.9800 - val_loss: 0.7727 - val_accuracy: 0.7500
# Epoch 130/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0575 - accuracy: 0.9809 - val_loss: 0.5717 - val_accuracy: 0.7778
# Epoch 131/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0575 - accuracy: 0.9766 - val_loss: 0.6428 - val_accuracy: 0.7778
# Epoch 132/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0394 - accuracy: 0.9905 - val_loss: 0.6849 - val_accuracy: 0.7500
# Epoch 133/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0431 - accuracy: 0.9861 - val_loss: 0.6216 - val_accuracy: 0.7222
# Epoch 134/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0401 - accuracy: 0.9905 - val_loss: 0.7068 - val_accuracy: 0.7222
# Epoch 135/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0612 - accuracy: 0.9792 - val_loss: 0.8637 - val_accuracy: 0.7222
# Epoch 136/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0742 - accuracy: 0.9757 - val_loss: 0.7214 - val_accuracy: 0.7500
# Epoch 137/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0459 - accuracy: 0.9878 - val_loss: 0.7924 - val_accuracy: 0.7500
# Epoch 138/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0303 - accuracy: 0.9922 - val_loss: 0.6747 - val_accuracy: 0.7500
# Epoch 139/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0701 - accuracy: 0.9783 - val_loss: 0.8078 - val_accuracy: 0.8056
# Epoch 140/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0602 - accuracy: 0.9774 - val_loss: 0.8575 - val_accuracy: 0.7222
# Epoch 141/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9800 - val_loss: 0.6334 - val_accuracy: 0.8333
# Epoch 142/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0554 - accuracy: 0.9826 - val_loss: 0.7218 - val_accuracy: 0.7778
# Epoch 143/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0466 - accuracy: 0.9826 - val_loss: 0.8884 - val_accuracy: 0.7778
# Epoch 144/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0574 - accuracy: 0.9774 - val_loss: 0.6597 - val_accuracy: 0.7778
# Epoch 145/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0535 - accuracy: 0.9844 - val_loss: 0.8405 - val_accuracy: 0.7222
# Epoch 146/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0364 - accuracy: 0.9905 - val_loss: 0.7336 - val_accuracy: 0.7778
# Epoch 147/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0320 - accuracy: 0.9905 - val_loss: 0.8950 - val_accuracy: 0.7222
# Epoch 148/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0481 - accuracy: 0.9809 - val_loss: 0.7630 - val_accuracy: 0.7778
# Epoch 149/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0509 - accuracy: 0.9800 - val_loss: 0.7885 - val_accuracy: 0.7500
# Epoch 150/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0291 - accuracy: 0.9905 - val_loss: 0.7726 - val_accuracy: 0.7500
# Epoch 151/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0286 - accuracy: 0.9931 - val_loss: 0.6142 - val_accuracy: 0.7222
# Epoch 152/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0307 - accuracy: 0.9931 - val_loss: 0.7495 - val_accuracy: 0.6944
# Epoch 153/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.9896 - val_loss: 0.7468 - val_accuracy: 0.7778
# Epoch 154/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0484 - accuracy: 0.9887 - val_loss: 0.8512 - val_accuracy: 0.8056
# Epoch 155/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0510 - accuracy: 0.9870 - val_loss: 1.0239 - val_accuracy: 0.7222
# Epoch 156/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0622 - accuracy: 0.9740 - val_loss: 0.7660 - val_accuracy: 0.7500
# Epoch 157/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0374 - accuracy: 0.9913 - val_loss: 0.7877 - val_accuracy: 0.7222
# Epoch 158/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0312 - accuracy: 0.9913 - val_loss: 0.7033 - val_accuracy: 0.7500
# Epoch 159/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0239 - accuracy: 0.9922 - val_loss: 0.6955 - val_accuracy: 0.8056
# Epoch 160/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0646 - accuracy: 0.9731 - val_loss: 0.7643 - val_accuracy: 0.7500
# Epoch 161/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0517 - accuracy: 0.9818 - val_loss: 0.7859 - val_accuracy: 0.7778
# Epoch 162/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0235 - accuracy: 0.9948 - val_loss: 0.8645 - val_accuracy: 0.7222
# Epoch 163/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0259 - accuracy: 0.9922 - val_loss: 0.9502 - val_accuracy: 0.7222
# Epoch 164/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0282 - accuracy: 0.9905 - val_loss: 0.6471 - val_accuracy: 0.7222
# Epoch 165/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0474 - accuracy: 0.9835 - val_loss: 0.6800 - val_accuracy: 0.6944
# Epoch 166/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0327 - accuracy: 0.9913 - val_loss: 1.0754 - val_accuracy: 0.7222
# Epoch 167/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0359 - accuracy: 0.9861 - val_loss: 0.8533 - val_accuracy: 0.6944
# Epoch 168/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0342 - accuracy: 0.9905 - val_loss: 0.9462 - val_accuracy: 0.7500
# Epoch 169/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0373 - accuracy: 0.9870 - val_loss: 0.9072 - val_accuracy: 0.6944
# Epoch 170/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0279 - accuracy: 0.9922 - val_loss: 0.8521 - val_accuracy: 0.6667
# Epoch 171/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0248 - accuracy: 0.9948 - val_loss: 0.7447 - val_accuracy: 0.6944
# Epoch 172/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0239 - accuracy: 0.9931 - val_loss: 0.7214 - val_accuracy: 0.7222
# Epoch 173/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0315 - accuracy: 0.9922 - val_loss: 0.7324 - val_accuracy: 0.7778
# Epoch 174/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0323 - accuracy: 0.9896 - val_loss: 0.7751 - val_accuracy: 0.8056
# Epoch 175/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0525 - accuracy: 0.9800 - val_loss: 0.5642 - val_accuracy: 0.7778
# Epoch 176/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0515 - accuracy: 0.9792 - val_loss: 0.7970 - val_accuracy: 0.7500
# Epoch 177/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0428 - accuracy: 0.9844 - val_loss: 0.8073 - val_accuracy: 0.7500
# Epoch 178/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0474 - accuracy: 0.9835 - val_loss: 0.6803 - val_accuracy: 0.8056
# Epoch 179/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0310 - accuracy: 0.9896 - val_loss: 0.8298 - val_accuracy: 0.7500
# Epoch 180/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 0.9948 - val_loss: 0.8003 - val_accuracy: 0.7500
# Epoch 181/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 0.9913 - val_loss: 0.8504 - val_accuracy: 0.7500
# Epoch 182/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0315 - accuracy: 0.9887 - val_loss: 0.6410 - val_accuracy: 0.7778
# Epoch 183/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0384 - accuracy: 0.9905 - val_loss: 1.1638 - val_accuracy: 0.6944
# Epoch 184/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0642 - accuracy: 0.9740 - val_loss: 0.7969 - val_accuracy: 0.7778
# Epoch 185/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0368 - accuracy: 0.9905 - val_loss: 1.0260 - val_accuracy: 0.7500
# Epoch 186/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0350 - accuracy: 0.9870 - val_loss: 0.8025 - val_accuracy: 0.7222
# Epoch 187/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0480 - accuracy: 0.9818 - val_loss: 0.9665 - val_accuracy: 0.7500
# Epoch 188/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0509 - accuracy: 0.9852 - val_loss: 0.6759 - val_accuracy: 0.7500
# Epoch 189/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0412 - accuracy: 0.9870 - val_loss: 1.0246 - val_accuracy: 0.6944
# Epoch 190/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0167 - accuracy: 0.9983 - val_loss: 0.7989 - val_accuracy: 0.7500
# Epoch 191/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0273 - accuracy: 0.9931 - val_loss: 0.6594 - val_accuracy: 0.7500
# Epoch 192/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0284 - accuracy: 0.9887 - val_loss: 0.6381 - val_accuracy: 0.7500
# Epoch 193/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 0.9957 - val_loss: 0.7311 - val_accuracy: 0.8056
# Epoch 194/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0186 - accuracy: 0.9965 - val_loss: 0.8519 - val_accuracy: 0.7222
# Epoch 195/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0249 - accuracy: 0.9913 - val_loss: 0.7030 - val_accuracy: 0.7500
# Epoch 196/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0325 - accuracy: 0.9905 - val_loss: 1.1847 - val_accuracy: 0.7500
# Epoch 197/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0382 - accuracy: 0.9878 - val_loss: 0.9282 - val_accuracy: 0.7778
# Epoch 198/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 0.9931 - val_loss: 0.8243 - val_accuracy: 0.6667
# Epoch 199/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0230 - accuracy: 0.9931 - val_loss: 0.8672 - val_accuracy: 0.7778
# Epoch 200/200
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 0.9957 - val_loss: 0.7575 - val_accuracy: 0.7222

# %%
plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
loss, acc = model.evaluate(x_test, labels_test)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4045 - accuracy: 0.9167
# Restored model, accuracy: 91.67%

# %%
#predictions = model.predict_classes(x_testcnn)
predictions = model.predict(x_test)
predictions
# Out:
# array([[9.83537972e-01, 6.11236419e-06, 1.64529961e-02, 1.90891751e-06,
#         1.03955927e-06],
#        [3.07560753e-04, 1.91580461e-04, 2.43829589e-07, 9.99480307e-01,
#         2.03359414e-05],
#        [5.18385150e-07, 5.30504494e-08, 9.98173594e-01, 1.54579640e-04,
#         1.67128490e-03],
#        [9.99433219e-01, 5.66782205e-07, 5.29034762e-04, 7.02784009e-09,
#         3.71808746e-05],
#        [9.39853311e-01, 9.33100000e-06, 5.49240112e-02, 5.19892573e-03,
#         1.44456462e-05],
#        [2.02675672e-08, 7.62617201e-05, 1.79393556e-09, 9.99911308e-01,
#         1.23546697e-05],
#        [3.09937546e-04, 7.80249957e-06, 9.98606741e-01, 3.38483915e-05,
#         1.04176009e-03],
#        [9.85105515e-01, 1.26594955e-07, 1.48928035e-02, 6.26197272e-09,
#         1.53779081e-06],
#        [9.99996066e-01, 7.49537179e-08, 3.72358704e-06, 5.29848521e-08,
#         7.64587560e-11],
#        [9.19728756e-01, 4.60405818e-06, 8.02234188e-02, 1.23432491e-08,
#         4.31530498e-05],
#        [8.69463205e-01, 1.99338910e-08, 1.30535766e-01, 4.26536140e-08,
#         9.80056825e-07],
#        [9.99994159e-01, 3.00129949e-10, 5.73810576e-06, 5.27096731e-08,
#         4.27854241e-09],
#        [8.54028796e-04, 3.13436124e-03, 8.14677253e-02, 1.78535156e-05,
#         9.14526045e-01],
#        [5.96487155e-07, 9.97634292e-01, 1.09172845e-03, 8.42698500e-04,
#         4.30662825e-04],
#        [9.61391389e-01, 1.41121873e-07, 3.86080965e-02, 2.28309489e-07,
#         2.23159205e-07],
#        [4.80622987e-07, 3.28463279e-02, 9.13465738e-06, 9.67117608e-01,
#         2.65741310e-05],
#        [7.72988563e-03, 3.73853266e-01, 6.48872405e-02, 5.53264618e-01,
#         2.65031616e-04],
#        [9.97929692e-01, 1.08996595e-07, 2.07011122e-03, 6.84027128e-08,
#         4.47167636e-08],
#        [9.99867797e-01, 1.30467530e-08, 1.08792439e-04, 2.33866122e-05,
#         8.57500915e-09],
#        [9.99790490e-01, 1.32526372e-06, 1.33408830e-04, 1.28990150e-05,
#         6.18167323e-05],
#        [9.95964050e-01, 1.16436860e-08, 1.33366499e-04, 3.89847555e-03,
#         4.05453420e-06],
#        [5.61156206e-08, 9.97693479e-01, 6.92281718e-11, 5.19807974e-04,
#         1.78668310e-03],
#        [1.52411462e-06, 4.05985222e-04, 1.27268464e-07, 7.97712011e-04,
#         9.98794675e-01],
#        [3.13555972e-08, 1.19152348e-02, 1.04989135e-06, 9.88014996e-01,
#         6.86913700e-05],
#        [9.99961972e-01, 5.64203106e-07, 3.33277530e-05, 1.11009376e-06,
#         3.00045895e-06],
#        [2.89204672e-05, 6.29965425e-01, 1.04370527e-03, 3.68899018e-01,
#         6.29164351e-05],
#        [9.99913096e-01, 2.97145416e-05, 1.95261728e-05, 2.15386426e-05,
#         1.61510488e-05],
#        [9.99851227e-01, 1.34023441e-08, 1.35394846e-04, 1.28037218e-05,
#         5.95273036e-07],
#        [8.51908268e-08, 1.23312243e-03, 5.86949467e-09, 9.98766422e-01,
#         3.77797193e-07],
#        [1.35772607e-05, 6.35098815e-01, 8.68727267e-03, 6.47673151e-03,
#         3.49723667e-01],
#        [9.97331619e-01, 1.23065158e-09, 2.66306475e-03, 5.19792366e-06,
#         1.43303581e-07],
#        [9.97759700e-01, 1.39244949e-03, 6.10291259e-04, 6.61271188e-05,
#         1.71377294e-04],
#        [1.33226149e-06, 2.78734360e-02, 6.13203766e-10, 9.72090244e-01,
#         3.50296687e-05],
#        [9.99998927e-01, 1.46360601e-09, 6.92764729e-07, 4.33694794e-07,
#         2.31145866e-10],
#        [6.77763164e-01, 1.97653222e-07, 3.22080553e-01, 1.05429681e-04,
#         5.07198602e-05],
#        [1.34928644e-06, 1.44716836e-10, 9.97847319e-01, 1.11525412e-06,
#         2.15031579e-03]], dtype=float32)

# %%
df_audio_test = pd.DataFrame(predictions,columns=["OA_"+str(i) for i in range(5)])

# %%
labels_test
# Out:
# array([0, 3, 2, 0, 0, 1, 2, 0, 0, 0, 2, 0, 4, 1, 0, 3, 3, 0, 0, 0, 0, 1,
#        4, 3, 0, 1, 0, 0, 3, 1, 0, 0, 3, 0, 2, 2])

# %%
new_Ytest = labels_test.astype(int)
new_Ytest
# Out:
# array([0, 3, 2, 0, 0, 1, 2, 0, 0, 0, 2, 0, 4, 1, 0, 3, 3, 0, 0, 0, 0, 1,
#        4, 3, 0, 1, 0, 0, 3, 1, 0, 0, 3, 0, 2, 2])

# %%
preds1=predictions.argmax(axis=1)
preds1
# Out:
# array([0, 3, 2, 0, 0, 3, 2, 0, 0, 0, 0, 0, 4, 1, 0, 3, 3, 0, 0, 0, 0, 1,
#        4, 3, 0, 1, 0, 0, 3, 1, 0, 0, 3, 0, 0, 2])

# %%
abc = preds1.astype(int).flatten()
from sklearn.metrics import confusion_matrix
c = confusion_matrix(new_Ytest, abc) 
c
# Out:
# array([[18,  0,  0,  0,  0],
#        [ 0,  4,  0,  1,  0],
#        [ 2,  0,  3,  0,  0],
#        [ 0,  0,  0,  6,  0],
#        [ 0,  0,  0,  0,  2]])

# %%
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
import seaborn as sn

print(classification_report(labels_test,abc))

acc = float(accuracy_score(labels_test,abc))*100
print("----accuracy score %s ----" % acc)

cm = confusion_matrix(labels_test,abc)
#df_cm = pd.DataFrame(cm)
class_names = ['neutral', 'happy','sad','angry', 'fearful' ]
df_cm = pd.DataFrame(cm, index=class_names, columns=class_names,)
sn.heatmap(df_cm, annot=True, fmt='')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95        18
#            1       1.00      0.80      0.89         5
#            2       1.00      0.60      0.75         5
#            3       0.86      1.00      0.92         6
#            4       1.00      1.00      1.00         2
#
#     accuracy                           0.92        36
#    macro avg       0.95      0.88      0.90        36
# weighted avg       0.93      0.92      0.91        36
#
# ----accuracy score 91.66666666666666 ----

# %%
model.save('/content/drive/My Drive/fusion/savee/audio/model/expert1/best_CNN_model')
print("MODEL SAVED")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/fusion/savee/audio/model/expert1/best_CNN_model/assets
# MODEL SAVED

# %%
model_file_name = f'/content/drive/My Drive/fusion/savee/audio/model/expert1/best_CNN_model___Loss_{loss}___Accuracy_{acc}.h5'

# Save the Model.
model.save(model_file_name)

# %%
# serialize model to JSON
model_json = model.to_json()
with open("/content/drive/My Drive/fusion/savee/audio/model/expert1/best_CNN_model.json", "w") as json_file:
    json_file.write(model_json)

# %%
count=0
new_x_train=[]
for path in audio_train :
      try:
        count +=1
        #Load librosa array, obtain mfcss, store the file and the mcss information in a new array
        X, sample_rate = librosa.load(DATASET_DIR+path, res_type='kaiser_fast')
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) 
        # The instruction below converts the labels (from 1 to 8) to a series from 0 to 7
        # This is because our predictor needs to start from 0 otherwise it will try to predict also 0.
        #emo = int(file[7:8]) - 1 
        #arr = X, emo
        new_x_train.append(mfccs)
      # If the file is not valid, skip it
      except ValueError:
        continue
print("--- Data loaded. Loading time: %s seconds ---" % (time.time() - start_time))
# Out:
# --- Data loaded. Loading time: 307.88195061683655 seconds ---

# %%
new_x_train=np.asarray(new_x_train)
prediction_train = model.predict(new_x_train)
prediction_train
# Out:
# array([[4.0156906e-06, 1.2235508e-02, 3.4994689e-06, 9.8775536e-01,
#         1.6637740e-06],
#        [7.3231902e-08, 9.9217767e-01, 2.6037515e-06, 7.8172097e-03,
#         2.3665209e-06],
#        [9.9999964e-01, 3.1105343e-10, 3.3079732e-07, 4.4367125e-11,
#         9.3500771e-13],
#        ...,
#        [1.2860904e-04, 9.9867249e-01, 2.7703304e-06, 7.6535711e-04,
#         4.3086233e-04],
#        [1.5551095e-05, 1.6544557e-03, 9.6469250e-07, 1.7234206e-05,
#         9.9831176e-01],
#        [4.1764488e-05, 4.6737332e-06, 1.7016751e-07, 9.9990988e-01,
#         4.3478838e-05]], dtype=float32)

# %%
df_audio_train = pd.DataFrame(prediction_train,columns=["OA_"+str(i) for i in range(5)])

# %%
prediction_valid = model.predict(X_valid)
prediction_valid
# Out:
# array([[8.98045823e-02, 7.58607030e-06, 9.01195228e-01, 3.14555666e-03,
#         5.84705314e-03],
#        [7.03287296e-05, 9.61285787e-06, 9.99546230e-01, 9.39661641e-06,
#         3.64415726e-04],
#        [9.99931574e-01, 4.49499247e-08, 3.57345493e-06, 6.48267742e-05,
#         3.56961252e-08],
#        [9.99982476e-01, 7.23650697e-12, 1.75467485e-05, 1.45089185e-08,
#         8.57717009e-09],
#        [9.02949978e-06, 2.49328434e-01, 2.45722204e-05, 7.50625372e-01,
#         1.24902617e-05],
#        [8.17242108e-05, 9.15755928e-01, 7.20439175e-08, 1.69690344e-02,
#         6.71932548e-02],
#        [3.14678203e-08, 1.01924306e-02, 6.88884165e-06, 9.73621845e-01,
#         1.61788743e-02],
#        [1.55519793e-08, 1.64673907e-07, 9.96639490e-01, 1.23125517e-07,
#         3.36011522e-03],
#        [4.80241375e-03, 2.22365452e-06, 3.28180683e-08, 9.95195329e-01,
#         3.62869592e-08],
#        [9.99926209e-01, 5.03489375e-08, 3.53547398e-06, 6.98256699e-05,
#         4.32916579e-07],
#        [7.93358386e-02, 7.04459744e-05, 9.09316957e-01, 1.02721276e-02,
#         1.00467924e-03],
#        [8.46602372e-04, 1.01937354e-03, 1.63748488e-03, 9.96495068e-01,
#         1.42573685e-06],
#        [2.76914452e-05, 1.35172512e-02, 8.75144720e-01, 2.49933382e-05,
#         1.11285284e-01],
#        [2.55198444e-07, 9.75833237e-02, 1.97045788e-01, 8.89527728e-04,
#         7.04481184e-01],
#        [8.27598989e-01, 4.56077061e-08, 1.72400996e-01, 3.50040240e-11,
#         9.38930622e-09],
#        [1.83315223e-07, 9.71684396e-01, 4.26043896e-03, 2.03308809e-06,
#         2.40529068e-02],
#        [9.99940157e-01, 1.25526756e-09, 5.93125515e-05, 4.26000270e-07,
#         9.70770273e-08],
#        [6.04098113e-06, 9.94644165e-01, 1.65570837e-05, 4.91126964e-04,
#         4.84207040e-03],
#        [3.80461477e-02, 1.85948650e-07, 9.61953640e-01, 4.73105288e-09,
#         1.37247094e-08],
#        [9.40622747e-01, 2.88284878e-06, 5.87488450e-02, 1.31525292e-06,
#         6.24217442e-04],
#        [1.77526133e-04, 3.55885595e-01, 1.28006064e-07, 6.42124414e-01,
#         1.81233964e-03],
#        [5.61118952e-07, 2.77173839e-11, 9.98508155e-01, 3.39914621e-08,
#         1.49128353e-03],
#        [4.42965131e-07, 6.30101236e-03, 4.31149054e-08, 9.93698239e-01,
#         2.04574619e-07],
#        [7.54125509e-03, 1.68878008e-02, 3.88575136e-04, 9.40326035e-01,
#         3.48563045e-02],
#        [6.19606482e-08, 9.30476427e-01, 1.36745598e-06, 1.47473011e-05,
#         6.95073977e-02],
#        [9.99999404e-01, 2.76223333e-09, 1.14482482e-07, 5.34394417e-07,
#         6.02589367e-11],
#        [1.22229736e-02, 9.11589668e-05, 9.12478745e-01, 6.28568159e-06,
#         7.52008036e-02],
#        [4.70400391e-06, 6.06198192e-01, 4.94575797e-05, 3.93707514e-01,
#         4.01503676e-05],
#        [2.58644795e-05, 2.97537423e-03, 4.47887601e-03, 3.95899551e-05,
#         9.92480278e-01],
#        [9.99997497e-01, 1.19164589e-09, 2.36644632e-06, 1.57643726e-07,
#         4.44223724e-09],
#        [1.79212961e-07, 8.19700712e-04, 3.73335610e-07, 2.73682108e-05,
#         9.99152422e-01],
#        [8.86503994e-01, 3.90845707e-05, 1.13390893e-01, 1.21466028e-05,
#         5.39017456e-05],
#        [1.02544427e-05, 9.77499545e-01, 2.92919449e-05, 2.23026779e-02,
#         1.58229974e-04],
#        [5.19750962e-08, 8.04386437e-02, 2.17753310e-07, 9.19229805e-01,
#         3.31225310e-04],
#        [9.68479693e-01, 8.19324271e-08, 3.14260870e-02, 4.67738755e-05,
#         4.73133186e-05],
#        [4.90275598e-09, 9.99923944e-01, 1.25823810e-10, 1.13832093e-05,
#         6.47244087e-05]], dtype=float32)

# %%
df_audio_valid = pd.DataFrame(prediction_valid,columns=["OA_"+str(i) for i in range(5)])

# %%
import joblib

save_dir = '/content/drive/My Drive/fusion/savee/audio/data_set/expert1'

savedvX = joblib.dump(df_audio_train, os.path.join(save_dir, 'train/predict_train'))
savedvX = joblib.dump(df_audio_test, os.path.join(save_dir, 'test/predict_test'))
savedvX = joblib.dump(df_audio_valid, os.path.join(save_dir, 'valid/predict_valid'))
